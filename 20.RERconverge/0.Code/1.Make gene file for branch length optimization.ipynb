# %%
from Bio import SeqIO
from Bio import Phylo
import os
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/"
list_of_files = os.listdir(f"{location}/20.RERconverge/3.HYPHY branch length optimization/1.Gene_sequences/")
for file_name in list_of_files:
    if file_name.endswith("_aligned.fas"):
        output = ''
        sequence_file = SeqIO.parse(f"{location}/20.RERconverge/3.HYPHY branch length optimization/1.Gene_sequences/{file_name}", 'fasta')
        species_list_1 = []
        for records in sequence_file:
            species_list_1.append(("_".join(records.id.split("_")[:-1])).split("-")[0])
            output += f">{('_'.join(records.id.split('_')[:-1])).split('-')[0]}\n{records.seq}\n\n"
        with open(f"{location}/20.RERconverge/3.HYPHY branch length optimization/2.Gene_sequences_final/ng_{file_name}", 'w') as out_file:
            out_file.write(output)

print(species_list_1)    
# with open
# Out:
# ['Bicyclus_anynana', 'Coenonympha_glycerion', 'Erebia_aethiops', 'Erebia_ligea', 'Hipparchia_semele', 'Lasiommata_megera', 'Maniola_hyperantus', 'Maniola_jurtina', 'Melanargia_galathea', 'Oeneis_ivallda', 'Pararge_aegeria', 'Anthocharis_cardamines', 'Aporia_crataegi', 'Leptophobia_aripa', 'Pieris_brassicae', 'Pieris_mannii', 'Pieris_melete', 'Pieris_napi', 'Pieris_rapae', 'Colias_croceus', 'Colias_eurytheme', 'Colias_nastes', 'Phoebis_sennae', 'Zerene_cesonia', 'Leptidea_juvernica', 'Leptidea_reali', 'Leptidea_sinapis', 'Hestina_assimilis', 'Danaus_chrysippus', 'Dircenna_loreta', 'Mechanitis_mazaeus', 'Mechanitis_messenoides', 'Melinaea_marsaeus_rileyi', 'Melinaea_menophilus', 'Napeogenes_inachia', 'Napeogenes_sylphis', 'Argynnis_bischoffii_washingtonia', 'Boloria_euphrosyne', 'Boloria_selene', 'Brenthis_daphne', 'Brenthis_hecate', 'Brenthis_ino', 'Dryadula_phaetusa', 'Dryas_iulia_moderata', 'Eueides_isabella', 'Fabriciana_adippe', 'Heliconius_charithonia', 'Heliconius_nattereri', 'P
# ...

# %%
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/8.For Phylogeny"
sequence_file = SeqIO.parse(f"{location}/10.All_gene_sequences/cad.fas", 'fasta')
species_list_1 = []
for records in sequence_file:
    species = records.id.split('-')[0]
    species_list_1.append(species)
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/"
period_sequence_file = SeqIO.parse(f"{location}/6.Period Exon Analysis/11.Alignment/00.Alignment/period_aligned_prank.fas.best.fas", 'fasta')

for records in period_sequence_file:
    species = records.id.split('-')[0]
    if species not in species_list_1:
        print(species)
# Out:
# Danaus_plexippus
