# %%
def sequence_extractor(Species, Scaff, reverse_c, start, end, frame = 1, trans = 1 ):
    from Bio import SeqIO
    from Bio.Seq import Seq
    import os
    
    out_Seq = ''
    
    
    #Genome folder
    entries = os.listdir("/mnt/f/Genomes_2023-12-26/"+Species)
    
    #Get genome file from Genome folder
    for file_names  in entries:
        if ".nhr" in file_names:
            Genome_name = file_names[:-4]
            break
    
    #Read the genome file
    fasta_file = open(("/mnt/f/Genomes_2023-12-26/"+Species+"/"+Genome_name),'r')
    
    #Extract the sequence 
    for record in SeqIO.parse(fasta_file,"fasta"):
        if record.id == Scaff:
            sequence = str(record.seq)
            out_Seq = Seq(sequence[start-1:end])
            if reverse_c == 1:
                out_Seq = out_Seq.reverse_complement()
                
    if len(out_Seq) < 10000: #fixing error due to mistake in typing the coordinate, change this for longer sequence
#        print (out_Seq)
        if frame == 1 :
            out_trans = out_Seq[0:]
        if frame == 2 :
            out_trans = out_Seq[1:]
        if frame == 3 :
            out_trans = out_Seq[2:]
    else:
        print ("too long")
        assert(False)
        
        
    #    break
    fasta_file.close()
    if trans == 1:
        return (out_trans.translate())
    else:
        return(out_Seq)
#

# %%
import os
from Bio import SeqIO

# %%
#%reset -f
blast_location = "/mnt/h/My Drive/Circadian Rhythm Genes Project/8.For Phylogeny/5.Coliadinae"
query_species = "Colias_croceus"


species_list = os.listdir(f"{blast_location}/1.Blast_result")
if "desktop.ini" in species_list:
    species_list.remove("desktop.ini")


query_file = SeqIO.parse(f"{blast_location}/1.Query/query.txt", 'fasta')
query_name_list = []

for records in query_file:
    query_name_list.append(records.id)



for species in species_list:
    # print(species_name)
    # species = species_name.split(".")[1]
    header = "Species," + "Scaffold," + "Start," + "Stop," + "Complement," + "Error," + "Gene,"+ "Query_start," + "Query_stop,"+ "Query_Length\n" 
    Output_Sequence = header
    scaff = "Intial_value"
    scaff_old = "Intial_value"
    old_end = 0
    
#Run for each query in the query list
    for i in range(len(query_name_list)):
        query_name = query_name_list[i]
        Length_switch = "0"
        with open(f"{blast_location}/1.Blast_result/{species}/{species}_blast_out.txt",'r') as tblast_out:
            lines_in_file = tblast_out.readlines()
        #print(lines_in_file)

        result_section_switch = 0
        start_coor_switch = 0
        query_start_coor_switch = 0
        stop_coor_switch = 0
        error = "N"
        break_switch = 0

        start = 0
        stop = 0
        start_coor = 0
        stop_coor = 0
        query_length = 0

        for lines in lines_in_file:

#             print(lines)
            if query_name in lines:
            #Initialize that results can now be checked
                result_section_switch = 1
                query_species_split = lines.split(" ")[1].split("_")
#                 print(query_species_split)
                query_species = str(query_species_split[0]+"_"+query_species_split[1].rstrip())
                print(query_species)
            if result_section_switch == 1 and "Lambda" in lines:
            #This block indicates end of the results block in blast output
                result_section_switch == 0
                
                break

            if result_section_switch == 1:
            #While checking the result
                if "Length=" in lines and Length_switch == "0":
                #Get query length from the blast output
                    
                    query_length = int(lines.split("=")[1].rstrip())
                    
                    Length_switch = 1 #Indicated length has been acquired
                    
                if ("Score" in lines or ">" in lines) and (start_coor_switch == 1):
    #                print (lines)
                    break
        
                if ">" in lines:
                #Start of the first result
                    scaff = lines.split(" ")[0][1:] #Scaffold from the result
#                     if scaff_old != "Intial_value" and scaff_old != scaff:
#                         error = "Y"
                    scaff_old = scaff
                    
                if "Query" in lines and "=" not in lines:
                #Read the query line in output
                    if query_start_coor_switch == 0:
#                        print(lines)
                        query_start_coor = int(lines.split(" ")[2])
                        query_start_coor_switch = 1
                        #Query start coordinate fixed
            
                    query_stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting query stop coordinates for multiline result
    #                print (stop_coor)
                    
                if "Sbjct" in lines:
                #Read the blast target line
                    if start_coor_switch == 0:
                        start_coor = int(lines.split(" ")[2])
                        start_coor_switch = 1
                    stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting target stop coordinates for multiline result
                
                

        
        if break_switch == 1:
            break

        if start_coor < stop_coor:
            complement = "0" #Forward complement
            
            length = (stop_coor-start_coor)/3
            start = start_coor
            stop = stop_coor

        elif start_coor > stop_coor:
            complement = "1" #Reverse complement
            length = (-stop_coor+start_coor)/3
            start = stop_coor
            stop = start_coor

        else:
            error = "Y"
        
        
        
        

        #Check if the length of target (blast hit) is significantly smaller than query
        if length < query_length - 0.2*query_length:
            error = "Y"

        old_trans = ''
#             print(start, stop)


# #Check for Met or STOP at the start and end
#         while True and (start != 0 or stop != 0):
#             if (query_name == query_name_list[0] or query_name == query_name_list[-1]):
#                 frame = 1
#                 translated_sequence = (sequence_extractor(species, scaff, int(complement), start, stop,frame ))

#                 if translated_sequence == old_trans:
#                     break
                    
# #Check for Met at the beginning of first exon

#                 if query_name == query_name_list[0] :
#                     if translated_sequence[0] != "M":
#                         print(translated_sequence)
# #                             print(start, stop)
#                         if complement == "0":
#                             start = int(start) - 3
#                         if complement == "1":
#                             stop = int(stop) + 3
#                         old_trans = translated_sequence
#                     if "*" in translated_sequence:
#                         error = "Y"
#                         break
#                     if translated_sequence[0] == "M":
#                         break

# #Check for stop at the end of last exon

#                 if query_name == query_name_list[-1]:
#                     if translated_sequence[-1] != "*":
#                         print(translated_sequence)
# #                             print(start, stop)
#                         if complement == "0":
#                             stop = int(stop) + 3
#                         if complement == "1":
#                             start = int(start) - 3
#                         old_trans = translated_sequence
#                     if translated_sequence[-1] == "*":

#                         break
#             else:
#                 break
        
        
#Add offset at the beginning and end of each exon
#         if (start != 0 or stop != 0):
            
#             start_modifier = int(query_name.split("Frame")[1][1])
#             stop_modifier = int(query_name.split("rightoh")[1][1])
#         else:
        start_modifier = 0
        stop_modifier = 0            

        seq_length = query_length
        
        
#Get exon start and end by adding or removing codons
        
    #if not the beginning
        if query_start_coor != "1" and query_name != query_name_list[0]:
            if complement == "0":
                start = int(start) - 3*(int(query_start_coor)-1)                
            if complement == "1":
                stop = int(stop) + 3*(int(query_start_coor)-1)
    
    #For the end
        if query_stop_coor != str(seq_length) and query_name != query_name_list[-1]:
            if complement == "0":
                stop = int(stop) + 3*(int(seq_length)-int(query_stop_coor))
            if complement == "1":
                

                start = int(start) - 3*(int(seq_length)-int(query_stop_coor))
 
        
        
        
#Adding or removing 3' and 5' overhangs for forward and reverse complement
    #For forward complement
        if complement == "0":
            start = int(start) - int(start_modifier)
            stop = int(stop) +  int(stop_modifier)
#             if old_end != 0 and old_end > stop:

#                 error = "Y"
            old_end = stop

    #For reverse complement
        if complement == "1":
            start = int(start) - int(stop_modifier)
            stop = int(stop) +  int(start_modifier)
#             if old_end != 0 and old_end < stop:
#                 error = "Y"
            old_end = stop

    #Simple check for lenghth
        if start == 0 or stop == 0:
            error = "Y"
            
           
        output_format = str(species.split("\n")[0])+"," + str(scaff) +"," + str(start)+"," + str(stop)+"," + str(complement)+"," + str(error)+  ","+ str(query_name)+","+ str(query_start_coor)+","+str(query_stop_coor)+","+str(query_length)+ "\n"  
        print(output_format)
#         assert False
        Output_Sequence = Output_Sequence + output_format

    print(Output_Sequence)
    output_file = open(f"{blast_location}/1.Blast_result/{species}/{species}_coordinates.csv",'w')
    output_file.write(Output_Sequence)
    output_file.close()
# Out:
# Colias_croceus
# Colias_behrii,JARWMC010000002.1,5897125,5897781,0,N,Colias_croceus_rps5,1,219,219
#
# Colias_croceus
# Colias_behrii,JARWMC010000003.1,3641209,3641733,0,N,Colias_croceus_wg,1,175,175
#
# Colias_croceus
# Colias_behrii,JARWMC010000005.1,3729620,3730138,0,N,Colias_croceus_rps2,1,173,173
#
# Colias_croceus
# Colias_behrii,JARWMC010000007.1,3880985,3881971,1,N,Colias_croceus_mdh,1,329,329
#
# Colias_croceus
# Colias_behrii,JARWMC010000004.1,5810214,5811437,0,N,Colias_croceus_idh,1,408,408
#
# Colias_croceus
# Colias_behrii,JARWMC010000003.1,8767552,8768256,1,N,Colias_croceus_ddc,1,235,235
#
# Colias_croceus
# Colias_behrii,JARWMC010000016.1,8440708,8441703,1,N,Colias_croceus_gapdh,1,332,332
#
# Colias_croceus
# Colias_behrii,JARWMC010000002.1,10794961,10796310,0,N,Colias_croceus_ef1,2,441,462
#
# Colias_croceus
# Colias_behrii,JARWMC010000012.1,12489455,12490231,1,N,Colias_croceus_hcl,1,259,259
#
# Colias_croceus
# Colias_behrii,JARWMC010000006.1,2553521,2554978,1,N,Colias_croceus_cat,14,482,482
#
# Colias_croceus
# Colias_behrii,JARWMC010000004.1,7417143,7420280,0,N,Colias_croceus_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Colias_behrii,JARWMC010000002.1,5897125,5897781,0,N,Colias_croceus_rps5,1,219,219
# Colias_behrii,JARWMC010000003.1,3641209,3641733,0,N,Colias_croceus_wg,1,175,175
# Colias_behrii,JARWMC010000005.1,3729620,3730138,0,N,Colias_croceus_rps2,1,173,173
# Colias_behrii,JARWMC010000007.1,3880985,3881971,1,N,Colias_croceus_mdh,1,329,329
# Colias_behrii,JARWMC010000004.1,5810214,5811437,0,N,Colias_croceus_idh,1,408,408
# Colias_behrii,JARWMC010000003.1,8767552,8768256,1,N,Colias_croceus_ddc,1,235,235
# Colias_behrii,JARWMC010000016.1,8440708,8441703,1,N,Colias_croceus_gapdh,1,332,332
# Colias_behrii,JARWMC010000002.1,10794961,10796310,0,N,Colias_croceus_ef1,2,441,462
# Colias_behrii,JARWMC010000012.1,12489455,12490231,1,N,Colias_croceus_hcl,1,259,259
# Colias_behrii,JARWMC010000006.1,2553521,2554978,1,N,Colias_croceus_cat,14,482,482
# Colias_behrii,JARWMC010000004.1,7417143,7420280,0,N,Colias_croceus_cad,1,1046,1046
#
# Colias_croceus
# Colias_croceus,NC_059538.1,5218796,5219452,0,N,Colias_croceus_rps5,1,219,219
#
# Colias_croceus
# Colias_croceus,NC_059539.1,3245110,3245634,0,N,Colias_croceus_wg,1,175,175
#
# Colias_croceus
# Colias_croceus,NC_059541.1,9371257,9371775,1,N,Colias_croceus_rps2,1,173,173
#
# Colias_croceus
# Colias_croceus,NC_059544.1,3284986,3285972,1,N,Colias_croceus_mdh,1,329,329
#
# Colias_croceus
# Colias_croceus,NC_059540.1,5183156,5184379,0,N,Colias_croceus_idh,1,408,408
#
# Colias_croceus
# Colias_croceus,NC_059539.1,7726033,7726737,1,N,Colias_croceus_ddc,1,235,235
#
# Colias_croceus
# Colias_croceus,NC_059551.1,3289895,3290890,0,N,Colias_croceus_gapdh,1,332,332
#
# Colias_croceus
# Colias_croceus,NC_059537.1,3519697,3521082,0,N,Colias_croceus_ef1,1,462,462
#
# Colias_croceus
# Colias_croceus,NC_059549.1,10547352,10548128,1,N,Colias_croceus_hcl,1,259,259
#
# Colias_croceus
# Colias_croceus,NC_059568.1,239261,240706,0,N,Colias_croceus_cat,1,482,482
#
# Colias_croceus
# Colias_croceus,NC_059540.1,6484268,6487405,0,N,Colias_croceus_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Colias_croceus,NC_059538.1,5218796,5219452,0,N,Colias_croceus_rps5,1,219,219
# Colias_croceus,NC_059539.1,3245110,3245634,0,N,Colias_croceus_wg,1,175,175
# Colias_croceus,NC_059541.1,9371257,9371775,1,N,Colias_croceus_rps2,1,173,173
# Colias_croceus,NC_059544.1,3284986,3285972,1,N,Colias_croceus_mdh,1,329,329
# Colias_croceus,NC_059540.1,5183156,5184379,0,N,Colias_croceus_idh,1,408,408
# Colias_croceus,NC_059539.1,7726033,7726737,1,N,Colias_croceus_ddc,1,235,235
# Colias_croceus,NC_059551.1,3289895,3290890,0,N,Colias_croceus_gapdh,1,332,332
# Colias_croceus,NC_059537.1,3519697,3521082,0,N,Colias_croceus_ef1,1,462,462
# Colias_croceus,NC_059549.1,10547352,10548128,1,N,Colias_croceus_hcl,1,259,259
# Colias_croceus,NC_059568.1,239261,240706,0,N,Colias_croceus_cat,1,482,482
# Colias_croceus,NC_059540.1,6484268,6487405,0,N,Colias_croceus_cad,1,1046,1046
#
# Colias_croceus
# Colias_eurytheme,CAJQZN010000045.1,70360,71016,0,N,Colias_croceus_rps5,1,219,219
#
# Colias_croceus
# Colias_eurytheme,CAJQZN010043569.1,22621,23145,1,N,Colias_croceus_wg,1,175,175
#
# Colias_croceus
# Colias_eurytheme,CAJQZN010023122.1,4320,4838,0,N,Colias_croceus_rps2,1,173,173
#
# Colias_croceus
# Colias_eurytheme,CAJQZN010017460.1,17347,18333,1,N,Colias_croceus_mdh,1,329,329
#
# Colias_croceus
# Colias_eurytheme,CAJQZN010040646.1,21285,22508,0,N,Colias_croceus_idh,1,408,408
#
# Colias_croceus
# Colias_eurytheme,CAJQZN010037531.1,4533,5237,0,N,Colias_croceus_ddc,1,235,235
#
# Colias_croceus
# Colias_eurytheme,CAJQZN010021018.1,8091,9086,1,N,Colias_croceus_gapdh,1,332,332
#
# Colias_croceus
# Colias_eurytheme,CAJQZN010033949.1,2135,3520,1,N,Colias_croceus_ef1,1,462,462
#
# Colias_croceus
# Colias_eurytheme,CAJQZN010038386.1,11097,11873,1,N,Colias_croceus_hcl,1,259,259
#
# Colias_croceus
# Colias_eurytheme,CAJQZN010040486.1,77581,79026,0,N,Colias_croceus_cat,1,422,482
#
# Colias_croceus
# Colias_eurytheme,CAJQZN010030549.1,5763,8900,1,N,Colias_croceus_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Colias_eurytheme,CAJQZN010000045.1,70360,71016,0,N,Colias_croceus_rps5,1,219,219
# Colias_eurytheme,CAJQZN010043569.1,22621,23145,1,N,Colias_croceus_wg,1,175,175
# Colias_eurytheme,CAJQZN010023122.1,4320,4838,0,N,Colias_croceus_rps2,1,173,173
# Colias_eurytheme,CAJQZN010017460.1,17347,18333,1,N,Colias_croceus_mdh,1,329,329
# Colias_eurytheme,CAJQZN010040646.1,21285,22508,0,N,Colias_croceus_idh,1,408,408
# Colias_eurytheme,CAJQZN010037531.1,4533,5237,0,N,Colias_croceus_ddc,1,235,235
# Colias_eurytheme,CAJQZN010021018.1,8091,9086,1,N,Colias_croceus_gapdh,1,332,332
# Colias_eurytheme,CAJQZN010033949.1,2135,3520,1,N,Colias_croceus_ef1,1,462,462
# Colias_eurytheme,CAJQZN010038386.1,11097,11873,1,N,Colias_croceus_hcl,1,259,259
# Colias_eurytheme,CAJQZN010040486.1,77581,79026,0,N,Colias_croceus_cat,1,422,482
# Colias_eurytheme,CAJQZN010030549.1,5763,8900,1,N,Colias_croceus_cad,1,1046,1046
#
# Colias_croceus
# Colias_nastes,CAJQZM010011753.1,1750,2406,1,N,Colias_croceus_rps5,1,219,219
#
# Colias_croceus
# Colias_nastes,CAJQZM010038627.1,-156,368,1,Y,Colias_croceus_wg,1,122,175
#
# Colias_croceus
# Colias_nastes,CAJQZM010024979.1,411,929,0,N,Colias_croceus_rps2,1,173,173
#
# Colias_croceus
# Colias_nastes,CAJQZM010043258.1,13470,14456,1,N,Colias_croceus_mdh,1,329,329
#
# Colias_croceus
# Colias_nastes,CAJQZM010038817.1,802,2025,0,N,Colias_croceus_idh,1,408,408
#
# Colias_croceus
# Colias_nastes,CAJQZM010026943.1,1556,2260,0,N,Colias_croceus_ddc,1,235,235
#
# Colias_croceus
# Colias_nastes,CAJQZM010040790.1,25700,26695,1,N,Colias_croceus_gapdh,1,332,332
#
# Colias_croceus
# Colias_nastes,CAJQZM010040432.1,3465,4850,1,N,Colias_croceus_ef1,1,462,462
#
# Colias_croceus
# Colias_nastes,CAJQZM010023028.1,2957,3733,0,N,Colias_croceus_hcl,1,259,259
#
# Colias_croceus
# Colias_nastes,CAJQZM010027421.1,5166,6611,1,N,Colias_croceus_cat,1,482,482
#
# Colias_croceus
# Colias_nastes,CAJQZM010039989.1,38654,41791,1,N,Colias_croceus_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Colias_nastes,CAJQZM010011753.1,1750,2406,1,N,Colias_croceus_rps5,1,219,219
# Colias_nastes,CAJQZM010038627.1,-156,368,1,Y,Colias_croceus_wg,1,122,175
# Colias_nastes,CAJQZM010024979.1,411,929,0,N,Colias_croceus_rps2,1,173,173
# Colias_nastes,CAJQZM010043258.1,13470,14456,1,N,Colias_croceus_mdh,1,329,329
# Colias_nastes,CAJQZM010038817.1,802,2025,0,N,Colias_croceus_idh,1,408,408
# Colias_nastes,CAJQZM010026943.1,1556,2260,0,N,Colias_croceus_ddc,1,235,235
# Colias_nastes,CAJQZM010040790.1,25700,26695,1,N,Colias_croceus_gapdh,1,332,332
# Colias_nastes,CAJQZM010040432.1,3465,4850,1,N,Colias_croceus_ef1,1,462,462
# Colias_nastes,CAJQZM010023028.1,2957,3733,0,N,Colias_croceus_hcl,1,259,259
# Colias_nastes,CAJQZM010027421.1,5166,6611,1,N,Colias_croceus_cat,1,482,482
# Colias_nastes,CAJQZM010039989.1,38654,41791,1,N,Colias_croceus_cad,1,1046,1046
#
# Colias_croceus
# Eurema_hecabe,JADANM010001663.1,4923751,4924407,1,N,Colias_croceus_rps5,1,219,219
#
# Colias_croceus
# Eurema_hecabe,JADANM010006787.1,7634851,7635375,1,N,Colias_croceus_wg,1,175,175
#
# Colias_croceus
# Eurema_hecabe,JADANM010005989.1,7043045,7043563,1,N,Colias_croceus_rps2,1,173,173
#
# Colias_croceus
# Eurema_hecabe,JADANM010003811.1,6720632,6721618,0,N,Colias_croceus_mdh,1,329,329
#
# Colias_croceus
# Eurema_hecabe,JADANM010001810.1,4057413,4058636,0,N,Colias_croceus_idh,1,408,408
#
# Colias_croceus
# Eurema_hecabe,JADANM010003939.1,9891,10595,0,N,Colias_croceus_ddc,1,235,235
#
# Colias_croceus
# Eurema_hecabe,JADANM010005346.1,2877667,2878662,0,N,Colias_croceus_gapdh,1,332,332
#
# Colias_croceus
# Eurema_hecabe,JADANM010006098.1,2376019,2377404,0,N,Colias_croceus_ef1,1,370,462
#
# Colias_croceus
# Eurema_hecabe,JADANM010006502.1,1827049,1827825,1,N,Colias_croceus_hcl,1,259,259
#
# Colias_croceus
# Eurema_hecabe,JADANM010005835.1,8900536,8901981,0,N,Colias_croceus_cat,1,482,482
# Colias_croceus
# Eurema_hecabe,JADANM010001810.1,5074844,5077981,0,N,Colias_croceus_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Eurema_hecabe,JADANM010001663.1,4923751,4924407,1,N,Colias_croceus_rps5,1,219,219
# Eurema_hecabe,JADANM010006787.1,7634851,7635375,1,N,Colias_croceus_wg,1,175,175
# Eurema_hecabe,JADANM010005989.1,7043045,7043563,1,N,Colias_croceus_rps2,1,173,173
# Eurema_hecabe,JADANM010003811.1,6720632,6721618,0,N,Colias_croceus_mdh,1,329,329
# Eurema_hecabe,JADANM010001810.1,4057413,4058636,0,N,Colias_croceus_idh,1,408,408
# Eurema_hecabe,JADANM010003939.1,9891,10595,0,N,Colias_croceus_ddc,1,235,235
# Eurema_hecabe,JADANM010005346.1,2877667,2878662,0,N,Colias_croceus_gapdh,1,332,332
# Eurema_hecabe,JADANM010006098.1,2376019,2377404,0,N,Colias_croceus_ef1,1,370,462
# Eurema_hecabe,JADANM010006502.1,1827049,1827825,1,N,Colias_croceus_hcl,1,259,259
# Eurema_hecabe,JADANM010005835.1,8900536,8901981,0,N,Colias_croceus_cat,1,482,482
# Eurema_hecabe,JADANM010001810.1,5074844,5077981,0,N,Colias_croceus_cad,1,1046,1046
#
# Colias_croceus
# Phoebis_sennae,LQNK01001926.1,76803,77459,1,N,Colias_croceus_rps5,1,219,219
#
# Colias_croceus
# Phoebis_sennae,LQNK01001975.1,71177,71701,0,N,Colias_croceus_wg,1,175,175
#
# Colias_croceus
# Phoebis_sennae,LQNK01000558.1,162575,163093,0,N,Colias_croceus_rps2,1,173,173
#
# Colias_croceus
# Phoebis_sennae,LQNK01001073.1,116430,117416,1,N,Colias_croceus_mdh,1,329,329
#
# Colias_croceus
# Phoebis_sennae,LQNK01000129.1,861114,862337,1,N,Colias_croceus_idh,1,408,408
#
# Colias_croceus
# Phoebis_sennae,LQNK01000843.1,374770,375474,0,N,Colias_croceus_ddc,1,235,235
#
# Colias_croceus
# Phoebis_sennae,LQNK01000077.1,551566,552561,0,N,Colias_croceus_gapdh,1,332,332
#
# Colias_croceus
# Phoebis_sennae,LQNK01001215.1,18972,20357,0,N,Colias_croceus_ef1,1,462,462
#
# Colias_croceus
# Phoebis_sennae,LQNK01002131.1,125052,125828,1,N,Colias_croceus_hcl,1,259,259
#
# Colias_croceus
# Phoebis_sennae,LQNK01000462.1,30726,32171,0,N,Colias_croceus_cat,1,482,482
#
# Colias_croceus
# Phoebis_sennae,LQNK01000765.1,359185,362322,1,N,Colias_croceus_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Phoebis_sennae,LQNK01001926.1,76803,77459,1,N,Colias_croceus_rps5,1,219,219
# Phoebis_sennae,LQNK01001975.1,71177,71701,0,N,Colias_croceus_wg,1,175,175
# Phoebis_sennae,LQNK01000558.1,162575,163093,0,N,Colias_croceus_rps2,1,173,173
# Phoebis_sennae,LQNK01001073.1,116430,117416,1,N,Colias_croceus_mdh,1,329,329
# Phoebis_sennae,LQNK01000129.1,861114,862337,1,N,Colias_croceus_idh,1,408,408
# Phoebis_sennae,LQNK01000843.1,374770,375474,0,N,Colias_croceus_ddc,1,235,235
# Phoebis_sennae,LQNK01000077.1,551566,552561,0,N,Colias_croceus_gapdh,1,332,332
# Phoebis_sennae,LQNK01001215.1,18972,20357,0,N,Colias_croceus_ef1,1,462,462
# Phoebis_sennae,LQNK01002131.1,125052,125828,1,N,Colias_croceus_hcl,1,259,259
# Phoebis_sennae,LQNK01000462.1,30726,32171,0,N,Colias_croceus_cat,1,482,482
# Phoebis_sennae,LQNK01000765.1,359185,362322,1,N,Colias_croceus_cad,1,1046,1046
#
# Colias_croceus
# Zerene_cesonia,NC_052112.1,4286458,4287114,0,N,Colias_croceus_rps5,1,219,219
#
# Colias_croceus
# Zerene_cesonia,NC_052102.1,8675941,8676465,1,N,Colias_croceus_wg,1,175,175
#
# Colias_croceus
# Zerene_cesonia,NC_052118.1,7948359,7948877,1,N,Colias_croceus_rps2,1,173,173
#
# Colias_croceus
# Zerene_cesonia,NC_052120.1,7751590,7752576,0,N,Colias_croceus_mdh,1,329,329
#
# Colias_croceus
# Zerene_cesonia,NC_052121.1,6582173,6583396,1,N,Colias_croceus_idh,1,408,408
#
# Colias_croceus
# Zerene_cesonia,NC_052102.1,4569070,4569774,0,N,Colias_croceus_ddc,1,235,235
#
# Colias_croceus
# Zerene_cesonia,NC_052106.1,2573127,2574122,0,N,Colias_croceus_gapdh,1,332,332
#
# Colias_croceus
# Zerene_cesonia,NC_052111.1,331274,332659,0,N,Colias_croceus_ef1,1,462,462
#
# Colias_croceus
# Zerene_cesonia,NC_052119.1,441722,442498,0,N,Colias_croceus_hcl,1,259,259
#
# Colias_croceus
# Zerene_cesonia,NC_052122.1,12383770,12385215,1,N,Colias_croceus_cat,1,482,482
#
# Colias_croceus
# Zerene_cesonia,NC_052121.1,5468793,5471930,1,N,Colias_croceus_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Zerene_cesonia,NC_052112.1,4286458,4287114,0,N,Colias_croceus_rps5,1,219,219
# Zerene_cesonia,NC_052102.1,8675941,8676465,1,N,Colias_croceus_wg,1,175,175
# Zerene_cesonia,NC_052118.1,7948359,7948877,1,N,Colias_croceus_rps2,1,173,173
# Zerene_cesonia,NC_052120.1,7751590,7752576,0,N,Colias_croceus_mdh,1,329,329
# Zerene_cesonia,NC_052121.1,6582173,6583396,1,N,Colias_croceus_idh,1,408,408
# Zerene_cesonia,NC_052102.1,4569070,4569774,0,N,Colias_croceus_ddc,1,235,235
# Zerene_cesonia,NC_052106.1,2573127,2574122,0,N,Colias_croceus_gapdh,1,332,332
# Zerene_cesonia,NC_052111.1,331274,332659,0,N,Colias_croceus_ef1,1,462,462
# Zerene_cesonia,NC_052119.1,441722,442498,0,N,Colias_croceus_hcl,1,259,259
# Zerene_cesonia,NC_052122.1,12383770,12385215,1,N,Colias_croceus_cat,1,482,482
# Zerene_cesonia,NC_052121.1,5468793,5471930,1,N,Colias_croceus_cad,1,1046,1046
#
# Colias_croceus
# Leptidea_juvernica,CATIXQ010000027.1,7541472,7542128,1,N,Colias_croceus_rps5,1,219,219
#
# Colias_croceus
# Leptidea_juvernica,CATIXQ010000008.1,1842767,1843291,1,N,Colias_croceus_wg,1,175,175
#
# Colias_croceus
# Leptidea_juvernica,CATIXQ010000035.1,5707006,5707524,1,N,Colias_croceus_rps2,1,173,173
#
# Colias_croceus
# Leptidea_juvernica,CATIXQ010000024.1,11248833,11249819,0,N,Colias_croceus_mdh,1,329,329
#
# Colias_croceus
# Leptidea_juvernica,CATIXQ010000023.1,6089363,6090586,1,N,Colias_croceus_idh,1,408,408
#
# Colias_croceus
# Leptidea_juvernica,CATIXQ010000009.1,14119752,14120456,0,N,Colias_croceus_ddc,1,235,235
#
# Colias_croceus
# Leptidea_juvernica,CATIXQ010000014.1,7870658,7871653,0,N,Colias_croceus_gapdh,1,332,332
#
# Colias_croceus
# Leptidea_juvernica,CATIXQ010000025.1,6044626,6046011,0,N,Colias_croceus_ef1,1,462,462
#
# Colias_croceus
# Leptidea_juvernica,CATIXQ010000005.1,3991705,3992481,0,N,Colias_croceus_hcl,1,259,259
#
# Colias_croceus
# Leptidea_juvernica,CATIXQ010000001.1,12166361,12167809,0,N,Colias_croceus_cat,1,482,482
#
# Colias_croceus
# Leptidea_juvernica,CATIXQ010000005.1,19028075,19031212,1,N,Colias_croceus_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Leptidea_juvernica,CATIXQ010000027.1,7541472,7542128,1,N,Colias_croceus_rps5,1,219,219
# Leptidea_juvernica,CATIXQ010000008.1,1842767,1843291,1,N,Colias_croceus_wg,1,175,175
# Leptidea_juvernica,CATIXQ010000035.1,5707006,5707524,1,N,Colias_croceus_rps2,1,173,173
# Leptidea_juvernica,CATIXQ010000024.1,11248833,11249819,0,N,Colias_croceus_mdh,1,329,329
# Leptidea_juvernica,CATIXQ010000023.1,6089363,6090586,1,N,Colias_croceus_idh,1,408,408
# Leptidea_juvernica,CATIXQ010000009.1,14119752,14120456,0,N,Colias_croceus_ddc,1,235,235
# Leptidea_juvernica,CATIXQ010000014.1,7870658,7871653,0,N,Colias_croceus_gapdh,1,332,332
# Leptidea_juvernica,CATIXQ010000025.1,6044626,6046011,0,N,Colias_croceus_ef1,1,462,462
# Leptidea_juvernica,CATIXQ010000005.1,3991705,3992481,0,N,Colias_croceus_hcl,1,259,259
# Leptidea_juvernica,CATIXQ010000001.1,12166361,12167809,0,N,Colias_croceus_cat,1,482,482
# Leptidea_juvernica,CATIXQ010000005.1,19028075,19031212,1,N,Colias_croceus_cad,1,1046,1046
#
# Colias_croceus
# Leptidea_reali,CATIXK010000025.1,3048472,3049128,1,N,Colias_croceus_rps5,1,219,219
#
# Colias_croceus
# Leptidea_reali,CATIXK010000006.1,25439228,25439752,0,N,Colias_croceus_wg,1,175,175
#
# Colias_croceus
# Leptidea_reali,CATIXK010000001.1,22098147,22098665,0,N,Colias_croceus_rps2,1,173,173
#
# Colias_croceus
# Leptidea_reali,CATIXK010000026.1,5615869,5616855,1,N,Colias_croceus_mdh,1,329,329
#
# Colias_croceus
# Leptidea_reali,CATIXK010000009.1,24193222,24194445,0,N,Colias_croceus_idh,1,408,408
#
# Colias_croceus
# Leptidea_reali,CATIXK010000001.1,21488711,21489415,1,N,Colias_croceus_ddc,1,235,235
#
# Colias_croceus
# Leptidea_reali,CATIXK010000012.1,12464475,12465470,0,N,Colias_croceus_gapdh,1,332,332
#
# Colias_croceus
# Leptidea_reali,CATIXK010000020.1,890335,891720,0,N,Colias_croceus_ef1,1,462,462
#
# Colias_croceus
# Leptidea_reali,CATIXK010000019.1,4911732,4912508,1,N,Colias_croceus_hcl,1,259,259
#
# Colias_croceus
# Leptidea_reali,CATIXK010000017.1,11967778,11969226,0,N,Colias_croceus_cat,1,482,482
#
# Colias_croceus
# Leptidea_reali,CATIXK010000014.1,7387126,7390263,1,N,Colias_croceus_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Leptidea_reali,CATIXK010000025.1,3048472,3049128,1,N,Colias_croceus_rps5,1,219,219
# Leptidea_reali,CATIXK010000006.1,25439228,25439752,0,N,Colias_croceus_wg,1,175,175
# Leptidea_reali,CATIXK010000001.1,22098147,22098665,0,N,Colias_croceus_rps2,1,173,173
# Leptidea_reali,CATIXK010000026.1,5615869,5616855,1,N,Colias_croceus_mdh,1,329,329
# Leptidea_reali,CATIXK010000009.1,24193222,24194445,0,N,Colias_croceus_idh,1,408,408
# Leptidea_reali,CATIXK010000001.1,21488711,21489415,1,N,Colias_croceus_ddc,1,235,235
# Leptidea_reali,CATIXK010000012.1,12464475,12465470,0,N,Colias_croceus_gapdh,1,332,332
# Leptidea_reali,CATIXK010000020.1,890335,891720,0,N,Colias_croceus_ef1,1,462,462
# Leptidea_reali,CATIXK010000019.1,4911732,4912508,1,N,Colias_croceus_hcl,1,259,259
# Leptidea_reali,CATIXK010000017.1,11967778,11969226,0,N,Colias_croceus_cat,1,482,482
# Leptidea_reali,CATIXK010000014.1,7387126,7390263,1,N,Colias_croceus_cad,1,1046,1046
# Colias_croceus
# Leptidea_sinapis,NC_066272.1,11751465,11752121,0,N,Colias_croceus_rps5,1,219,219
#
# Colias_croceus
# Leptidea_sinapis,NC_066268.1,15254203,15254727,0,N,Colias_croceus_wg,1,175,175
#
# Colias_croceus
# Leptidea_sinapis,NC_066299.1,9779759,9780277,0,N,Colias_croceus_rps2,1,173,173
#
# Colias_croceus
# Leptidea_sinapis,NC_066278.1,14120943,14121929,1,N,Colias_croceus_mdh,1,329,329
#
# Colias_croceus
# Leptidea_sinapis,NC_066274.1,1233308,1234531,1,N,Colias_croceus_idh,1,408,408
#
# Colias_croceus
# Leptidea_sinapis,NC_066281.1,10843002,10843706,0,N,Colias_croceus_ddc,1,235,235
#
# Colias_croceus
# Leptidea_sinapis,NC_066273.1,4059238,4060233,0,N,Colias_croceus_gapdh,1,332,332
#
# Colias_croceus
# Leptidea_sinapis,NC_066308.1,8168777,8170162,1,N,Colias_croceus_ef1,1,462,462
#
# Colias_croceus
# Leptidea_sinapis,NC_066298.1,7138307,7139083,1,N,Colias_croceus_hcl,1,259,259
#
# Colias_croceus
# Leptidea_sinapis,NC_066312.1,23945829,23947277,1,N,Colias_croceus_cat,1,482,482
#
# Colias_croceus
# Leptidea_sinapis,NC_066270.1,8425936,8429073,0,N,Colias_croceus_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Leptidea_sinapis,NC_066272.1,11751465,11752121,0,N,Colias_croceus_rps5,1,219,219
# Leptidea_sinapis,NC_066268.1,15254203,15254727,0,N,Colias_croceus_wg,1,175,175
# Leptidea_sinapis,NC_066299.1,9779759,9780277,0,N,Colias_croceus_rps2,1,173,173
# Leptidea_sinapis,NC_066278.1,14120943,14121929,1,N,Colias_croceus_mdh,1,329,329
# Leptidea_sinapis,NC_066274.1,1233308,1234531,1,N,Colias_croceus_idh,1,408,408
# Leptidea_sinapis,NC_066281.1,10843002,10843706,0,N,Colias_croceus_ddc,1,235,235
# Leptidea_sinapis,NC_066273.1,4059238,4060233,0,N,Colias_croceus_gapdh,1,332,332
# Leptidea_sinapis,NC_066308.1,8168777,8170162,1,N,Colias_croceus_ef1,1,462,462
# Leptidea_sinapis,NC_066298.1,7138307,7139083,1,N,Colias_croceus_hcl,1,259,259
# Leptidea_sinapis,NC_066312.1,23945829,23947277,1,N,Colias_croceus_cat,1,482,482
# Leptidea_sinapis,NC_066270.1,8425936,8429073,0,N,Colias_croceus_cad,1,1046,1046
