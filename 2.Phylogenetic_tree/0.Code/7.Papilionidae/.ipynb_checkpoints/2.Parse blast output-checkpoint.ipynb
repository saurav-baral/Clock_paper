# %%
def sequence_extractor(Species, Scaff, reverse_c, start, end, frame = 1, trans = 1 ):
    from Bio import SeqIO
    from Bio.Seq import Seq
    import os
    
    out_Seq = ''
    
    
    #Genome folder
    entries = os.listdir("/mnt/f/Genomes_2023-12-26/"+Species)
    
    #Get genome file from Genome folder
    for file_names  in entries:
        if ".nhr" in file_names:
            Genome_name = file_names[:-4]
            break
    
    #Read the genome file
    fasta_file = open(("/mnt/f/Genomes_2023-12-26/"+Species+"/"+Genome_name),'r')
    
    #Extract the sequence 
    for record in SeqIO.parse(fasta_file,"fasta"):
        if record.id == Scaff:
            sequence = str(record.seq)
            out_Seq = Seq(sequence[start-1:end])
            if reverse_c == 1:
                out_Seq = out_Seq.reverse_complement()
                
    if len(out_Seq) < 10000: #fixing error due to mistake in typing the coordinate, change this for longer sequence
#        print (out_Seq)
        if frame == 1 :
            out_trans = out_Seq[0:]
        if frame == 2 :
            out_trans = out_Seq[1:]
        if frame == 3 :
            out_trans = out_Seq[2:]
    else:
        print ("too long")
        assert(False)
        
        
    #    break
    fasta_file.close()
    if trans == 1:
        return (out_trans.translate())
    else:
        return(out_Seq)
#

# %%
import os
from Bio import SeqIO

# %%
#%reset -f
blast_location = "/mnt/h/My Drive/Circadian Rhythm Genes Project/8.For Phylogeny/7.Papilionidae"
# query_species = "Pieris_brassicae"


species_list = os.listdir(f"{blast_location}/1.Blast_result")
if "desktop.ini" in species_list:
    species_list.remove("desktop.ini")


query_file = SeqIO.parse(f"{blast_location}/1.Query/query.txt", 'fasta')
query_name_list = []

for records in query_file:
    query_name_list.append(records.id)



for species in species_list:
    # print(species_name)
    # species = species_name.split(".")[1]
    header = "Species," + "Scaffold," + "Start," + "Stop," + "Complement," + "Error," + "Gene,"+ "Query_start," + "Query_stop,"+ "Query_Length\n" 
    Output_Sequence = header
    scaff = "Intial_value"
    scaff_old = "Intial_value"
    old_end = 0
    
#Run for each query in the query list
    for i in range(len(query_name_list)):
        query_name = query_name_list[i]
        Length_switch = "0"
        with open(f"{blast_location}/1.Blast_result/{species}/{species}_blast_out.txt",'r') as tblast_out:
            lines_in_file = tblast_out.readlines()
        #print(lines_in_file)

        result_section_switch = 0
        start_coor_switch = 0
        query_start_coor_switch = 0
        stop_coor_switch = 0
        error = "N"
        break_switch = 0

        start = 0
        stop = 0
        start_coor = 0
        stop_coor = 0
        query_length = 0

        for lines in lines_in_file:

#             print(lines)
            if query_name in lines:
            #Initialize that results can now be checked
                result_section_switch = 1
                query_species_split = lines.split(" ")[1].split("_")
#                 print(query_species_split)
                query_species = str(query_species_split[0]+"_"+query_species_split[1].rstrip())
                print(query_species)
            if result_section_switch == 1 and "Lambda" in lines:
            #This block indicates end of the results block in blast output
                result_section_switch == 0
                
                break

            if result_section_switch == 1:
            #While checking the result
                if "Length=" in lines and Length_switch == "0":
                #Get query length from the blast output
                    
                    query_length = int(lines.split("=")[1].rstrip())
                    
                    Length_switch = 1 #Indicated length has been acquired
                    
                if ("Score" in lines or ">" in lines) and (start_coor_switch == 1):
    #                print (lines)
                    break
        
                if ">" in lines:
                #Start of the first result
                    scaff = lines.split(" ")[0][1:] #Scaffold from the result
#                     if scaff_old != "Intial_value" and scaff_old != scaff:
#                         error = "Y"
                    scaff_old = scaff
                    
                if "Query" in lines and "=" not in lines:
                #Read the query line in output
                    if query_start_coor_switch == 0:
#                        print(lines)
                        query_start_coor = int(lines.split(" ")[2])
                        query_start_coor_switch = 1
                        #Query start coordinate fixed
            
                    query_stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting query stop coordinates for multiline result
    #                print (stop_coor)
                    
                if "Sbjct" in lines:
                #Read the blast target line
                    if start_coor_switch == 0:
                        start_coor = int(lines.split(" ")[2])
                        start_coor_switch = 1
                    stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting target stop coordinates for multiline result
                
                

        
        if break_switch == 1:
            break

        if start_coor < stop_coor:
            complement = "0" #Forward complement
            
            length = (stop_coor-start_coor)/3
            start = start_coor
            stop = stop_coor

        elif start_coor > stop_coor:
            complement = "1" #Reverse complement
            length = (-stop_coor+start_coor)/3
            start = stop_coor
            stop = start_coor

        else:
            error = "Y"
        
        
        
        

        #Check if the length of target (blast hit) is significantly smaller than query
        if length < query_length - 0.2*query_length:
            error = "Y"

        old_trans = ''
#             print(start, stop)


# #Check for Met or STOP at the start and end
#         while True and (start != 0 or stop != 0):
#             if (query_name == query_name_list[0] or query_name == query_name_list[-1]):
#                 frame = 1
#                 translated_sequence = (sequence_extractor(species, scaff, int(complement), start, stop,frame ))

#                 if translated_sequence == old_trans:
#                     break
                    
# #Check for Met at the beginning of first exon

#                 if query_name == query_name_list[0] :
#                     if translated_sequence[0] != "M":
#                         print(translated_sequence)
# #                             print(start, stop)
#                         if complement == "0":
#                             start = int(start) - 3
#                         if complement == "1":
#                             stop = int(stop) + 3
#                         old_trans = translated_sequence
#                     if "*" in translated_sequence:
#                         error = "Y"
#                         break
#                     if translated_sequence[0] == "M":
#                         break

# #Check for stop at the end of last exon

#                 if query_name == query_name_list[-1]:
#                     if translated_sequence[-1] != "*":
#                         print(translated_sequence)
# #                             print(start, stop)
#                         if complement == "0":
#                             stop = int(stop) + 3
#                         if complement == "1":
#                             start = int(start) - 3
#                         old_trans = translated_sequence
#                     if translated_sequence[-1] == "*":

#                         break
#             else:
#                 break
        
        
#Add offset at the beginning and end of each exon
#         if (start != 0 or stop != 0):
            
#             start_modifier = int(query_name.split("Frame")[1][1])
#             stop_modifier = int(query_name.split("rightoh")[1][1])
#         else:
        start_modifier = 0
        stop_modifier = 0            

        seq_length = query_length
        
        
#Get exon start and end by adding or removing codons
        
    #if not the beginning
        if query_start_coor != "1" and query_name != query_name_list[0]:
            if complement == "0":
                start = int(start) - 3*(int(query_start_coor)-1)                
            if complement == "1":
                stop = int(stop) + 3*(int(query_start_coor)-1)
    
    #For the end
        if query_stop_coor != str(seq_length) and query_name != query_name_list[-1]:
            if complement == "0":
                stop = int(stop) + 3*(int(seq_length)-int(query_stop_coor))
            if complement == "1":
                

                start = int(start) - 3*(int(seq_length)-int(query_stop_coor))
 
        
        
        
#Adding or removing 3' and 5' overhangs for forward and reverse complement
    #For forward complement
        if complement == "0":
            start = int(start) - int(start_modifier)
            stop = int(stop) +  int(stop_modifier)
#             if old_end != 0 and old_end > stop:

#                 error = "Y"
            old_end = stop

    #For reverse complement
        if complement == "1":
            start = int(start) - int(stop_modifier)
            stop = int(stop) +  int(start_modifier)
#             if old_end != 0 and old_end < stop:
#                 error = "Y"
            old_end = stop

    #Simple check for lenghth
        if start == 0 or stop == 0:
            error = "Y"
            
           
        output_format = str(species.split("\n")[0])+"," + str(scaff) +"," + str(start)+"," + str(stop)+"," + str(complement)+"," + str(error)+  ","+ str(query_name)+","+ str(query_start_coor)+","+str(query_stop_coor)+","+str(query_length)+ "\n"  
        print(output_format)
#         assert False
        Output_Sequence = Output_Sequence + output_format

    print(Output_Sequence)
    output_file = open(f"{blast_location}/1.Blast_result/{species}/{species}_coordinates.csv",'w')
    output_file.write(Output_Sequence)
    output_file.close()
# Out:
# Papilio_xuthus
# Baronia_brevicornis,JASFAT010001101.1,487742,488398,1,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Baronia_brevicornis,JASFAT010000337.1,183648,184172,1,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Baronia_brevicornis,JASFAT010001798.1,4279,4797,1,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Baronia_brevicornis,JASFAT010002612.1,106344,107333,1,Y,Papilio_xuthus_mdh,173,330,330
#
# Papilio_xuthus
# Baronia_brevicornis,JASFAT010002346.1,58664,59887,1,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Baronia_brevicornis,JASFAT010002062.1,27758,28462,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Baronia_brevicornis,JASFAT010001809.1,166153,167148,1,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Baronia_brevicornis,JASFAT010004130.1,121690,123075,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Baronia_brevicornis,JASFAT010000720.1,5013,5789,1,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Baronia_brevicornis,JASFAT010001628.1,49094,50554,1,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Baronia_brevicornis,JASFAT010001824.1,396283,399423,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Baronia_brevicornis,JASFAT010001101.1,487742,488398,1,N,Papilio_xuthus_rps5,1,219,219
# Baronia_brevicornis,JASFAT010000337.1,183648,184172,1,N,Papilio_xuthus_wg,1,175,175
# Baronia_brevicornis,JASFAT010001798.1,4279,4797,1,N,Papilio_xuthus_rps2,1,173,173
# Baronia_brevicornis,JASFAT010002612.1,106344,107333,1,Y,Papilio_xuthus_mdh,173,330,330
# Baronia_brevicornis,JASFAT010002346.1,58664,59887,1,N,Papilio_xuthus_idh,1,408,408
# Baronia_brevicornis,JASFAT010002062.1,27758,28462,1,N,Papilio_xuthus_DDC,1,235,235
# Baronia_brevicornis,JASFAT010001809.1,166153,167148,1,N,Papilio_xuthus_gapdh,1,332,332
# Baronia_brevicornis,JASFAT010004130.1,121690,123075,0,N,Papilio_xuthus_ef1,1,462,462
# Baronia_brevicornis,JASFAT010000720.1,5013,5789,1,N,Papilio_xuthus_hcl,1,259,259
# Baronia_brevicornis,JASFAT010001628.1,49094,50554,1,N,Papilio_xuthus_CAT,1,487,487
# Baronia_brevicornis,JASFAT010001824.1,396283,399423,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Battus_philenor,JAQMYT010000005.1,6902970,6903626,1,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Battus_philenor,JAQMYT010000002.1,5339275,5339799,0,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Battus_philenor,JAQMYT010000004.1,4495332,4495850,1,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Battus_philenor,JAQMYT010000012.1,4767207,4768184,1,Y,Papilio_xuthus_mdh,138,330,330
#
# Papilio_xuthus
# Battus_philenor,JAQMYT010000006.1,10235516,10236739,1,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Battus_philenor,JAQMYT010000002.1,10527385,10528089,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Battus_philenor,JAQMYT010000015.1,4318295,4319290,0,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Battus_philenor,JAQMYT010000003.1,13809656,13811041,1,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Battus_philenor,JAQMYT010000014.1,13850589,13851365,0,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Battus_philenor,JAQMYT010000001.1,7371560,7373020,0,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Battus_philenor,JAQMYT010000006.1,8492917,8496057,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Battus_philenor,JAQMYT010000005.1,6902970,6903626,1,N,Papilio_xuthus_rps5,1,219,219
# Battus_philenor,JAQMYT010000002.1,5339275,5339799,0,N,Papilio_xuthus_wg,1,175,175
# Battus_philenor,JAQMYT010000004.1,4495332,4495850,1,N,Papilio_xuthus_rps2,1,173,173
# Battus_philenor,JAQMYT010000012.1,4767207,4768184,1,Y,Papilio_xuthus_mdh,138,330,330
# Battus_philenor,JAQMYT010000006.1,10235516,10236739,1,N,Papilio_xuthus_idh,1,408,408
# Battus_philenor,JAQMYT010000002.1,10527385,10528089,1,N,Papilio_xuthus_DDC,1,235,235
# Battus_philenor,JAQMYT010000015.1,4318295,4319290,0,N,Papilio_xuthus_gapdh,1,332,332
# Battus_philenor,JAQMYT010000003.1,13809656,13811041,1,N,Papilio_xuthus_ef1,1,462,462
# Battus_philenor,JAQMYT010000014.1,13850589,13851365,0,N,Papilio_xuthus_hcl,1,259,259
# Battus_philenor,JAQMYT010000001.1,7371560,7373020,0,N,Papilio_xuthus_CAT,1,487,487
# Battus_philenor,JAQMYT010000006.1,8492917,8496057,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Iphiclides_podalirius,OW152817.1,7242357,7243013,1,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Iphiclides_podalirius,OW152816.1,4238279,4238803,0,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Iphiclides_podalirius,OW152815.1,13546838,13547356,0,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Iphiclides_podalirius,OW152821.1,12507907,12508896,0,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Iphiclides_podalirius,OW152819.1,10950808,10952031,1,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Iphiclides_podalirius,OW152816.1,10620310,10621014,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Iphiclides_podalirius,OW152827.1,4013066,4014061,0,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Iphiclides_podalirius,OW152814.1,14757476,14758861,1,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Iphiclides_podalirius,OW152829.1,1526340,1527116,0,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Iphiclides_podalirius,OW152813.1,2004221,2005681,0,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Iphiclides_podalirius,OW152819.1,8974445,8977585,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Iphiclides_podalirius,OW152817.1,7242357,7243013,1,N,Papilio_xuthus_rps5,1,219,219
# Iphiclides_podalirius,OW152816.1,4238279,4238803,0,N,Papilio_xuthus_wg,1,175,175
# Iphiclides_podalirius,OW152815.1,13546838,13547356,0,N,Papilio_xuthus_rps2,1,173,173
# Iphiclides_podalirius,OW152821.1,12507907,12508896,0,N,Papilio_xuthus_mdh,1,330,330
# Iphiclides_podalirius,OW152819.1,10950808,10952031,1,N,Papilio_xuthus_idh,1,408,408
# Iphiclides_podalirius,OW152816.1,10620310,10621014,1,N,Papilio_xuthus_DDC,1,235,235
# Iphiclides_podalirius,OW152827.1,4013066,4014061,0,N,Papilio_xuthus_gapdh,1,332,332
# Iphiclides_podalirius,OW152814.1,14757476,14758861,1,N,Papilio_xuthus_ef1,1,462,462
# Iphiclides_podalirius,OW152829.1,1526340,1527116,0,N,Papilio_xuthus_hcl,1,259,259
# Iphiclides_podalirius,OW152813.1,2004221,2005681,0,N,Papilio_xuthus_CAT,1,487,487
# Iphiclides_podalirius,OW152819.1,8974445,8977585,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Luehdorfia_chinensis,JAHVAK010000223.1,1219992,1220648,1,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Luehdorfia_chinensis,JAHVAK010000103.1,8399244,8399768,1,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Luehdorfia_chinensis,JAHVAK010000015.1,4175421,4175939,1,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Luehdorfia_chinensis,JAHVAK010000353.1,6727149,6728138,0,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Luehdorfia_chinensis,JAHVAK010000227.1,4170851,4172074,0,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Luehdorfia_chinensis,JAHVAK010000335.1,484156,484860,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Luehdorfia_chinensis,JAHVAK010000625.1,2233869,2234864,1,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Luehdorfia_chinensis,JAHVAK010000527.1,3591679,3593064,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Luehdorfia_chinensis,JAHVAK010000033.1,17167753,17168529,1,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Luehdorfia_chinensis,JAHVAK010000142.1,1724618,1726078,0,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Luehdorfia_chinensis,JAHVAK010000227.1,7153910,7157050,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Luehdorfia_chinensis,JAHVAK010000223.1,1219992,1220648,1,N,Papilio_xuthus_rps5,1,219,219
# Luehdorfia_chinensis,JAHVAK010000103.1,8399244,8399768,1,N,Papilio_xuthus_wg,1,175,175
# Luehdorfia_chinensis,JAHVAK010000015.1,4175421,4175939,1,N,Papilio_xuthus_rps2,1,173,173
# Luehdorfia_chinensis,JAHVAK010000353.1,6727149,6728138,0,N,Papilio_xuthus_mdh,1,330,330
# Luehdorfia_chinensis,JAHVAK010000227.1,4170851,4172074,0,N,Papilio_xuthus_idh,1,408,408
# Luehdorfia_chinensis,JAHVAK010000335.1,484156,484860,1,N,Papilio_xuthus_DDC,1,235,235
# Luehdorfia_chinensis,JAHVAK010000625.1,2233869,2234864,1,N,Papilio_xuthus_gapdh,1,332,332
# Luehdorfia_chinensis,JAHVAK010000527.1,3591679,3593064,0,N,Papilio_xuthus_ef1,1,462,462
# Luehdorfia_chinensis,JAHVAK010000033.1,17167753,17168529,1,N,Papilio_xuthus_hcl,1,259,259
# Luehdorfia_chinensis,JAHVAK010000142.1,1724618,1726078,0,N,Papilio_xuthus_CAT,1,487,487
# Luehdorfia_chinensis,JAHVAK010000227.1,7153910,7157050,0,N,Papilio_xuthus_cad,1,1047,1047
# Papilio_xuthus
# Ornithoptera_alexandrae,JARDVY010000023.1,7493313,7493969,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Ornithoptera_alexandrae,JARDVY010000027.1,10288892,10289416,1,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Ornithoptera_alexandrae,JARDVY010000030.1,2726004,2726522,1,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Ornithoptera_alexandrae,JARDVY010000017.1,6107943,6108932,0,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Ornithoptera_alexandrae,JARDVY010000037.1,5059008,5060231,0,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Ornithoptera_alexandrae,JARDVY010000027.1,5564915,5565619,0,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Ornithoptera_alexandrae,JARDVY010000293.1,3061045,3062040,0,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Ornithoptera_alexandrae,JARDVY010000288.1,11202699,11204084,1,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Ornithoptera_alexandrae,JARDVY010000034.1,809424,810200,1,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Ornithoptera_alexandrae,JARDVY010000297.1,1786084,1787544,0,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Ornithoptera_alexandrae,JARDVY010000037.1,6474578,6477718,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Ornithoptera_alexandrae,JARDVY010000023.1,7493313,7493969,0,N,Papilio_xuthus_rps5,1,219,219
# Ornithoptera_alexandrae,JARDVY010000027.1,10288892,10289416,1,N,Papilio_xuthus_wg,1,175,175
# Ornithoptera_alexandrae,JARDVY010000030.1,2726004,2726522,1,N,Papilio_xuthus_rps2,1,173,173
# Ornithoptera_alexandrae,JARDVY010000017.1,6107943,6108932,0,N,Papilio_xuthus_mdh,1,330,330
# Ornithoptera_alexandrae,JARDVY010000037.1,5059008,5060231,0,N,Papilio_xuthus_idh,1,408,408
# Ornithoptera_alexandrae,JARDVY010000027.1,5564915,5565619,0,N,Papilio_xuthus_DDC,1,235,235
# Ornithoptera_alexandrae,JARDVY010000293.1,3061045,3062040,0,N,Papilio_xuthus_gapdh,1,332,332
# Ornithoptera_alexandrae,JARDVY010000288.1,11202699,11204084,1,N,Papilio_xuthus_ef1,1,462,462
# Ornithoptera_alexandrae,JARDVY010000034.1,809424,810200,1,N,Papilio_xuthus_hcl,1,259,259
# Ornithoptera_alexandrae,JARDVY010000297.1,1786084,1787544,0,N,Papilio_xuthus_CAT,1,487,487
# Ornithoptera_alexandrae,JARDVY010000037.1,6474578,6477718,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Ornithoptera_priamus,JARDWD010000484.1,334470,335126,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Ornithoptera_priamus,JARDWD010000313.1,3196768,3197292,0,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Ornithoptera_priamus,JARDWD010000308.1,3034089,3034607,1,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Ornithoptera_priamus,JARDWD010000392.1,1729162,1730151,1,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Ornithoptera_priamus,JARDWD010000355.1,4940199,4941422,0,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Ornithoptera_priamus,JARDWD010000394.1,9191075,9191779,0,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Ornithoptera_priamus,JARDWD010000616.1,1516499,1517494,0,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Ornithoptera_priamus,JARDWD010000527.1,2535192,2536577,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Ornithoptera_priamus,JARDWD010000617.1,786179,786955,1,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Ornithoptera_priamus,JARDWD010000839.1,1024044,1025504,0,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Ornithoptera_priamus,JARDWD010000355.1,6362692,6365832,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Ornithoptera_priamus,JARDWD010000484.1,334470,335126,0,N,Papilio_xuthus_rps5,1,219,219
# Ornithoptera_priamus,JARDWD010000313.1,3196768,3197292,0,N,Papilio_xuthus_wg,1,175,175
# Ornithoptera_priamus,JARDWD010000308.1,3034089,3034607,1,N,Papilio_xuthus_rps2,1,173,173
# Ornithoptera_priamus,JARDWD010000392.1,1729162,1730151,1,N,Papilio_xuthus_mdh,1,330,330
# Ornithoptera_priamus,JARDWD010000355.1,4940199,4941422,0,N,Papilio_xuthus_idh,1,408,408
# Ornithoptera_priamus,JARDWD010000394.1,9191075,9191779,0,N,Papilio_xuthus_DDC,1,235,235
# Ornithoptera_priamus,JARDWD010000616.1,1516499,1517494,0,N,Papilio_xuthus_gapdh,1,332,332
# Ornithoptera_priamus,JARDWD010000527.1,2535192,2536577,0,N,Papilio_xuthus_ef1,1,462,462
# Ornithoptera_priamus,JARDWD010000617.1,786179,786955,1,N,Papilio_xuthus_hcl,1,259,259
# Ornithoptera_priamus,JARDWD010000839.1,1024044,1025504,0,N,Papilio_xuthus_CAT,1,487,487
# Ornithoptera_priamus,JARDWD010000355.1,6362692,6365832,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Papilio_dardanus_tibullus,QDHC01001697.1,1212,1868,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Papilio_dardanus_tibullus,QDHC01004124.1,576938,577462,1,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Papilio_dardanus_tibullus,QDHC01000263.1,441023,441541,1,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Papilio_dardanus_tibullus,QDHC01007041.1,2031358,2032347,1,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Papilio_dardanus_tibullus,QDHC01003693.1,194291,195514,0,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Papilio_dardanus_tibullus,QDHC01002768.1,1574234,1574938,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Papilio_dardanus_tibullus,QDHC01004189.1,189512,190507,0,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Papilio_dardanus_tibullus,QDHC01001532.1,336984,338369,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Papilio_dardanus_tibullus,QDHC01002456.1,876645,877421,1,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Papilio_dardanus_tibullus,QDHC01004916.1,1229360,1230820,1,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Papilio_dardanus_tibullus,QDHC01000144.1,1060892,1064032,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Papilio_dardanus_tibullus,QDHC01001697.1,1212,1868,0,N,Papilio_xuthus_rps5,1,219,219
# Papilio_dardanus_tibullus,QDHC01004124.1,576938,577462,1,N,Papilio_xuthus_wg,1,175,175
# Papilio_dardanus_tibullus,QDHC01000263.1,441023,441541,1,N,Papilio_xuthus_rps2,1,173,173
# Papilio_dardanus_tibullus,QDHC01007041.1,2031358,2032347,1,N,Papilio_xuthus_mdh,1,330,330
# Papilio_dardanus_tibullus,QDHC01003693.1,194291,195514,0,N,Papilio_xuthus_idh,1,408,408
# Papilio_dardanus_tibullus,QDHC01002768.1,1574234,1574938,1,N,Papilio_xuthus_DDC,1,235,235
# Papilio_dardanus_tibullus,QDHC01004189.1,189512,190507,0,N,Papilio_xuthus_gapdh,1,332,332
# Papilio_dardanus_tibullus,QDHC01001532.1,336984,338369,0,N,Papilio_xuthus_ef1,1,462,462
# Papilio_dardanus_tibullus,QDHC01002456.1,876645,877421,1,N,Papilio_xuthus_hcl,1,259,259
# Papilio_dardanus_tibullus,QDHC01004916.1,1229360,1230820,1,N,Papilio_xuthus_CAT,1,487,487
# Papilio_dardanus_tibullus,QDHC01000144.1,1060892,1064032,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Papilio_demoleus,JAGSMY010000012.1,6277918,6278574,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Papilio_demoleus,JAGSMY010000006.1,8456798,8457322,1,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Papilio_demoleus,JAGSMY010000025.1,2243730,2244248,1,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Papilio_demoleus,JAGSMY010000002.1,2477892,2478881,1,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Papilio_demoleus,JAGSMY010000016.1,6655442,6656665,1,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Papilio_demoleus,JAGSMY010000006.1,4442365,4443069,0,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Papilio_demoleus,JAGSMY010000001.1,2372455,2373450,0,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Papilio_demoleus,JAGSMY010000017.1,1907483,1908868,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Papilio_demoleus,JAGSMY010000007.1,8553870,8554646,1,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Papilio_demoleus,JAGSMY010000004.1,284555,286015,0,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Papilio_demoleus,JAGSMY010000016.1,5393528,5396668,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Papilio_demoleus,JAGSMY010000012.1,6277918,6278574,0,N,Papilio_xuthus_rps5,1,219,219
# Papilio_demoleus,JAGSMY010000006.1,8456798,8457322,1,N,Papilio_xuthus_wg,1,175,175
# Papilio_demoleus,JAGSMY010000025.1,2243730,2244248,1,N,Papilio_xuthus_rps2,1,173,173
# Papilio_demoleus,JAGSMY010000002.1,2477892,2478881,1,N,Papilio_xuthus_mdh,1,330,330
# Papilio_demoleus,JAGSMY010000016.1,6655442,6656665,1,N,Papilio_xuthus_idh,1,408,408
# Papilio_demoleus,JAGSMY010000006.1,4442365,4443069,0,N,Papilio_xuthus_DDC,1,235,235
# Papilio_demoleus,JAGSMY010000001.1,2372455,2373450,0,N,Papilio_xuthus_gapdh,1,332,332
# Papilio_demoleus,JAGSMY010000017.1,1907483,1908868,0,N,Papilio_xuthus_ef1,1,462,462
# Papilio_demoleus,JAGSMY010000007.1,8553870,8554646,1,N,Papilio_xuthus_hcl,1,259,259
# Papilio_demoleus,JAGSMY010000004.1,284555,286015,0,N,Papilio_xuthus_CAT,1,487,487
# Papilio_demoleus,JAGSMY010000016.1,5393528,5396668,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Papilio_elwesi,CM056689.1,11761786,11762442,1,N,Papilio_xuthus_rps5,1,219,219
# Papilio_xuthus
# Papilio_elwesi,CM056687.1,2811388,2811912,0,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Papilio_elwesi,CM056691.1,11949136,11949654,0,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Papilio_elwesi,CM056693.1,9994747,9995736,0,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Papilio_elwesi,CM056690.1,5259272,5260495,0,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Papilio_elwesi,CM056687.1,9010801,9011505,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Papilio_elwesi,CM056701.1,6517773,6518768,1,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Papilio_elwesi,CM056688.1,2615684,2617069,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Papilio_elwesi,CM056697.1,5781699,5782475,0,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Papilio_elwesi,CM056717.1,19023176,19024636,1,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Papilio_elwesi,CM056690.1,7459319,7462459,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Papilio_elwesi,CM056689.1,11761786,11762442,1,N,Papilio_xuthus_rps5,1,219,219
# Papilio_elwesi,CM056687.1,2811388,2811912,0,N,Papilio_xuthus_wg,1,175,175
# Papilio_elwesi,CM056691.1,11949136,11949654,0,N,Papilio_xuthus_rps2,1,173,173
# Papilio_elwesi,CM056693.1,9994747,9995736,0,N,Papilio_xuthus_mdh,1,330,330
# Papilio_elwesi,CM056690.1,5259272,5260495,0,N,Papilio_xuthus_idh,1,408,408
# Papilio_elwesi,CM056687.1,9010801,9011505,1,N,Papilio_xuthus_DDC,1,235,235
# Papilio_elwesi,CM056701.1,6517773,6518768,1,N,Papilio_xuthus_gapdh,1,332,332
# Papilio_elwesi,CM056688.1,2615684,2617069,0,N,Papilio_xuthus_ef1,1,462,462
# Papilio_elwesi,CM056697.1,5781699,5782475,0,N,Papilio_xuthus_hcl,1,259,259
# Papilio_elwesi,CM056717.1,19023176,19024636,1,N,Papilio_xuthus_CAT,1,487,487
# Papilio_elwesi,CM056690.1,7459319,7462459,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Papilio_gigon,JAODUI010000023.1,5260706,5261362,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Papilio_gigon,JAODUI010000007.1,1919442,1919966,0,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Papilio_gigon,JAODUI010000028.1,1699812,1700330,1,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Papilio_gigon,JAODUI010000030.1,6174894,6175883,0,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Papilio_gigon,JAODUI010000027.1,3290596,3291819,0,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Papilio_gigon,JAODUI010000001.1,5740421,5741125,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Papilio_gigon,JAODUI010000007.1,5512791,5513786,1,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Papilio_gigon,JAODUI010000012.1,1440720,1442105,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Papilio_gigon,JAODUI010000029.1,6955837,6956613,1,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Papilio_gigon,JAODUI010000025.1,8778034,8779494,1,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Papilio_gigon,JAODUI010000027.1,4500212,4503352,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Papilio_gigon,JAODUI010000023.1,5260706,5261362,0,N,Papilio_xuthus_rps5,1,219,219
# Papilio_gigon,JAODUI010000007.1,1919442,1919966,0,N,Papilio_xuthus_wg,1,175,175
# Papilio_gigon,JAODUI010000028.1,1699812,1700330,1,N,Papilio_xuthus_rps2,1,173,173
# Papilio_gigon,JAODUI010000030.1,6174894,6175883,0,N,Papilio_xuthus_mdh,1,330,330
# Papilio_gigon,JAODUI010000027.1,3290596,3291819,0,N,Papilio_xuthus_idh,1,408,408
# Papilio_gigon,JAODUI010000001.1,5740421,5741125,1,N,Papilio_xuthus_DDC,1,235,235
# Papilio_gigon,JAODUI010000007.1,5512791,5513786,1,N,Papilio_xuthus_gapdh,1,332,332
# Papilio_gigon,JAODUI010000012.1,1440720,1442105,0,N,Papilio_xuthus_ef1,1,462,462
# Papilio_gigon,JAODUI010000029.1,6955837,6956613,1,N,Papilio_xuthus_hcl,1,259,259
# Papilio_gigon,JAODUI010000025.1,8778034,8779494,1,N,Papilio_xuthus_CAT,1,487,487
# Papilio_gigon,JAODUI010000027.1,4500212,4503352,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Papilio_glaucus,JWHW01053549.1,41,697,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Papilio_glaucus,JWHW01032353.1,55041,55565,1,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Papilio_glaucus,JWHW01003782.1,14994,15512,0,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Papilio_glaucus,JWHW01038862.1,221681,222670,1,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Papilio_glaucus,JWHW01002376.1,624510,625733,0,N,Papilio_xuthus_idh,21,408,408
#
# Papilio_xuthus
# Papilio_glaucus,JWHW01027266.1,662268,662972,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Papilio_glaucus,JWHW01053466.1,185226,186221,0,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Papilio_glaucus,JWHW01029517.1,125599,126984,1,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Papilio_glaucus,JWHW01028415.1,102859,103635,1,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Papilio_glaucus,JWHW01016986.1,161012,162472,1,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Papilio_glaucus,JWHW01015791.1,67421,70561,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Papilio_glaucus,JWHW01053549.1,41,697,0,N,Papilio_xuthus_rps5,1,219,219
# Papilio_glaucus,JWHW01032353.1,55041,55565,1,N,Papilio_xuthus_wg,1,175,175
# Papilio_glaucus,JWHW01003782.1,14994,15512,0,N,Papilio_xuthus_rps2,1,173,173
# Papilio_glaucus,JWHW01038862.1,221681,222670,1,N,Papilio_xuthus_mdh,1,330,330
# Papilio_glaucus,JWHW01002376.1,624510,625733,0,N,Papilio_xuthus_idh,21,408,408
# Papilio_glaucus,JWHW01027266.1,662268,662972,1,N,Papilio_xuthus_DDC,1,235,235
# Papilio_glaucus,JWHW01053466.1,185226,186221,0,N,Papilio_xuthus_gapdh,1,332,332
# Papilio_glaucus,JWHW01029517.1,125599,126984,1,N,Papilio_xuthus_ef1,1,462,462
# Papilio_glaucus,JWHW01028415.1,102859,103635,1,N,Papilio_xuthus_hcl,1,259,259
# Papilio_glaucus,JWHW01016986.1,161012,162472,1,N,Papilio_xuthus_CAT,1,487,487
# Papilio_glaucus,JWHW01015791.1,67421,70561,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Papilio_machaon,NC_059988.1,6226441,6227097,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Papilio_machaon,NC_059986.1,2351692,2352216,0,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Papilio_machaon,NC_059990.1,2131274,2131792,1,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Papilio_machaon,NC_059992.1,7016899,7017888,0,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Papilio_machaon,NC_059989.1,3790226,3791449,0,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Papilio_machaon,NC_059986.1,6432869,6433573,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Papilio_machaon,NC_060000.1,5983439,5984434,1,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Papilio_machaon,NC_059987.1,1712050,1713435,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Papilio_machaon,NC_059996.1,653641,654417,0,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Papilio_machaon,NC_060016.1,10956613,10958073,1,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Papilio_machaon,NC_059989.1,5010537,5013677,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Papilio_machaon,NC_059988.1,6226441,6227097,0,N,Papilio_xuthus_rps5,1,219,219
# Papilio_machaon,NC_059986.1,2351692,2352216,0,N,Papilio_xuthus_wg,1,175,175
# Papilio_machaon,NC_059990.1,2131274,2131792,1,N,Papilio_xuthus_rps2,1,173,173
# Papilio_machaon,NC_059992.1,7016899,7017888,0,N,Papilio_xuthus_mdh,1,330,330
# Papilio_machaon,NC_059989.1,3790226,3791449,0,N,Papilio_xuthus_idh,1,408,408
# Papilio_machaon,NC_059986.1,6432869,6433573,1,N,Papilio_xuthus_DDC,1,235,235
# Papilio_machaon,NC_060000.1,5983439,5984434,1,N,Papilio_xuthus_gapdh,1,332,332
# Papilio_machaon,NC_059987.1,1712050,1713435,0,N,Papilio_xuthus_ef1,1,462,462
# Papilio_machaon,NC_059996.1,653641,654417,0,N,Papilio_xuthus_hcl,1,259,259
# Papilio_machaon,NC_060016.1,10956613,10958073,1,N,Papilio_xuthus_CAT,1,487,487
# Papilio_machaon,NC_059989.1,5010537,5013677,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Papilio_memnon,LD688947.1,36004,36660,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Papilio_memnon,LD699455.1,2042240,2042764,0,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Papilio_memnon,LD688932.1,6991623,6992141,0,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Papilio_memnon,LD688971.1,6256544,6257533,0,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Papilio_memnon,LD688941.1,3351496,3352719,0,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Papilio_memnon,LD699455.1,5699208,5699912,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Papilio_memnon,LD688935.1,3983814,3984809,1,N,Papilio_xuthus_gapdh,1,332,332
# Papilio_xuthus
# Papilio_memnon,LD689013.1,105991,107376,1,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Papilio_memnon,LD700012.1,2713372,2714148,1,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Papilio_memnon,LD688966.1,341845,343305,0,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Papilio_memnon,LD688941.1,4484017,4487157,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Papilio_memnon,LD688947.1,36004,36660,0,N,Papilio_xuthus_rps5,1,219,219
# Papilio_memnon,LD699455.1,2042240,2042764,0,N,Papilio_xuthus_wg,1,175,175
# Papilio_memnon,LD688932.1,6991623,6992141,0,N,Papilio_xuthus_rps2,1,173,173
# Papilio_memnon,LD688971.1,6256544,6257533,0,N,Papilio_xuthus_mdh,1,330,330
# Papilio_memnon,LD688941.1,3351496,3352719,0,N,Papilio_xuthus_idh,1,408,408
# Papilio_memnon,LD699455.1,5699208,5699912,1,N,Papilio_xuthus_DDC,1,235,235
# Papilio_memnon,LD688935.1,3983814,3984809,1,N,Papilio_xuthus_gapdh,1,332,332
# Papilio_memnon,LD689013.1,105991,107376,1,N,Papilio_xuthus_ef1,1,462,462
# Papilio_memnon,LD700012.1,2713372,2714148,1,N,Papilio_xuthus_hcl,1,259,259
# Papilio_memnon,LD688966.1,341845,343305,0,N,Papilio_xuthus_CAT,1,487,487
# Papilio_memnon,LD688941.1,4484017,4487157,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Papilio_polytes,NW_013527359.1,3853750,3854406,1,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Papilio_polytes,NW_013525102.1,5583425,5583949,1,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Papilio_polytes,NW_013525381.1,427144,427662,1,Y,Papilio_xuthus_rps2,50,173,173
#
# Papilio_xuthus
# Papilio_polytes,NW_013525270.1,1807979,1808968,0,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Papilio_polytes,NW_013527915.1,716165,717388,1,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Papilio_polytes,NW_013525102.1,1937064,1937768,0,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Papilio_polytes,NW_013526027.1,1668948,1669943,1,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Papilio_polytes,NW_013525069.1,2486165,2487550,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Papilio_polytes,NW_013525512.1,833643,834419,1,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Papilio_polytes,NW_013524901.1,1519068,1520495,1,N,Papilio_xuthus_CAT,4,485,487
#
# Papilio_xuthus
# Papilio_polytes,NW_013527915.1,6074685,6077825,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Papilio_polytes,NW_013527359.1,3853750,3854406,1,N,Papilio_xuthus_rps5,1,219,219
# Papilio_polytes,NW_013525102.1,5583425,5583949,1,N,Papilio_xuthus_wg,1,175,175
# Papilio_polytes,NW_013525381.1,427144,427662,1,Y,Papilio_xuthus_rps2,50,173,173
# Papilio_polytes,NW_013525270.1,1807979,1808968,0,N,Papilio_xuthus_mdh,1,330,330
# Papilio_polytes,NW_013527915.1,716165,717388,1,N,Papilio_xuthus_idh,1,408,408
# Papilio_polytes,NW_013525102.1,1937064,1937768,0,N,Papilio_xuthus_DDC,1,235,235
# Papilio_polytes,NW_013526027.1,1668948,1669943,1,N,Papilio_xuthus_gapdh,1,332,332
# Papilio_polytes,NW_013525069.1,2486165,2487550,0,N,Papilio_xuthus_ef1,1,462,462
# Papilio_polytes,NW_013525512.1,833643,834419,1,N,Papilio_xuthus_hcl,1,259,259
# Papilio_polytes,NW_013524901.1,1519068,1520495,1,N,Papilio_xuthus_CAT,4,485,487
# Papilio_polytes,NW_013527915.1,6074685,6077825,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Papilio_protenor,JAGSMZ010000006.1,3099715,3100371,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Papilio_protenor,JAGSMZ010000002.1,1903913,1904437,0,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Papilio_protenor,JAGSMZ010000005.1,2351872,2352390,0,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Papilio_protenor,JAGSMZ010000011.1,2359705,2360694,1,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Papilio_protenor,JAGSMZ010000022.1,3759575,3760798,0,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Papilio_protenor,JAGSMZ010000002.1,5793523,5794227,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Papilio_protenor,JAGSMZ010000025.1,193147,194142,1,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Papilio_protenor,JAGSMZ010000024.1,1595186,1596571,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Papilio_protenor,JAGSMZ010000026.1,6761744,6762520,1,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Papilio_protenor,JAGSMZ010000035.1,2773733,2775193,1,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Papilio_protenor,JAGSMZ010000022.1,4972272,4975412,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Papilio_protenor,JAGSMZ010000006.1,3099715,3100371,0,N,Papilio_xuthus_rps5,1,219,219
# Papilio_protenor,JAGSMZ010000002.1,1903913,1904437,0,N,Papilio_xuthus_wg,1,175,175
# Papilio_protenor,JAGSMZ010000005.1,2351872,2352390,0,N,Papilio_xuthus_rps2,1,173,173
# Papilio_protenor,JAGSMZ010000011.1,2359705,2360694,1,N,Papilio_xuthus_mdh,1,330,330
# Papilio_protenor,JAGSMZ010000022.1,3759575,3760798,0,N,Papilio_xuthus_idh,1,408,408
# Papilio_protenor,JAGSMZ010000002.1,5793523,5794227,1,N,Papilio_xuthus_DDC,1,235,235
# Papilio_protenor,JAGSMZ010000025.1,193147,194142,1,N,Papilio_xuthus_gapdh,1,332,332
# Papilio_protenor,JAGSMZ010000024.1,1595186,1596571,0,N,Papilio_xuthus_ef1,1,462,462
# Papilio_protenor,JAGSMZ010000026.1,6761744,6762520,1,N,Papilio_xuthus_hcl,1,259,259
# Papilio_protenor,JAGSMZ010000035.1,2773733,2775193,1,N,Papilio_xuthus_CAT,1,487,487
# Papilio_protenor,JAGSMZ010000022.1,4972272,4975412,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Papilio_xuthus,NW_013530969.1,3529637,3530293,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Papilio_xuthus,NW_013533994.1,3254605,3255129,1,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Papilio_xuthus,NW_013530391.1,2259312,2259830,0,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Papilio_xuthus,NW_013529697.1,6217992,6218981,0,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Papilio_xuthus,NW_013529869.1,2179291,2180514,1,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Papilio_xuthus,NW_013531052.1,590618,591322,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Papilio_xuthus,NW_013533657.1,5524664,5525659,1,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Papilio_xuthus,NW_013532703.1,14825450,14826835,1,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Papilio_xuthus,NW_013530935.1,480796,481572,0,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Papilio_xuthus,NW_013533632.1,350618,352078,0,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Papilio_xuthus,NW_013529869.1,1009626,1012766,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Papilio_xuthus,NW_013530969.1,3529637,3530293,0,N,Papilio_xuthus_rps5,1,219,219
# Papilio_xuthus,NW_013533994.1,3254605,3255129,1,N,Papilio_xuthus_wg,1,175,175
# Papilio_xuthus,NW_013530391.1,2259312,2259830,0,N,Papilio_xuthus_rps2,1,173,173
# Papilio_xuthus,NW_013529697.1,6217992,6218981,0,N,Papilio_xuthus_mdh,1,330,330
# Papilio_xuthus,NW_013529869.1,2179291,2180514,1,N,Papilio_xuthus_idh,1,408,408
# Papilio_xuthus,NW_013531052.1,590618,591322,1,N,Papilio_xuthus_DDC,1,235,235
# Papilio_xuthus,NW_013533657.1,5524664,5525659,1,N,Papilio_xuthus_gapdh,1,332,332
# Papilio_xuthus,NW_013532703.1,14825450,14826835,1,N,Papilio_xuthus_ef1,1,462,462
# Papilio_xuthus,NW_013530935.1,480796,481572,0,N,Papilio_xuthus_hcl,1,259,259
# Papilio_xuthus,NW_013533632.1,350618,352078,0,N,Papilio_xuthus_CAT,1,487,487
# Papilio_xuthus,NW_013529869.1,1009626,1012766,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Parnassius_glacialis,JAVANC010000001.1,23345916,23346572,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Parnassius_glacialis,JAVANC010000017.1,42916734,42917258,1,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Parnassius_glacialis,JAVANC010000004.1,41393858,41394376,1,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Parnassius_glacialis,JAVANC010000010.1,40023557,40024546,0,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Parnassius_glacialis,JAVANC010000016.1,18717801,18719024,0,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Parnassius_glacialis,JAVANC010000017.1,24272390,24273094,0,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Parnassius_glacialis,JAVANC010000011.1,30620166,30621161,1,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Parnassius_glacialis,JAVANC010000013.1,12757565,12758950,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Parnassius_glacialis,JAVANC010000009.1,2203575,2204351,0,N,Papilio_xuthus_hcl,1,259,259
# Papilio_xuthus
# Parnassius_glacialis,JAVANC010000004.1,5199851,5201311,0,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Parnassius_glacialis,JAVANC010000016.1,25051434,25054574,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Parnassius_glacialis,JAVANC010000001.1,23345916,23346572,0,N,Papilio_xuthus_rps5,1,219,219
# Parnassius_glacialis,JAVANC010000017.1,42916734,42917258,1,N,Papilio_xuthus_wg,1,175,175
# Parnassius_glacialis,JAVANC010000004.1,41393858,41394376,1,N,Papilio_xuthus_rps2,1,173,173
# Parnassius_glacialis,JAVANC010000010.1,40023557,40024546,0,N,Papilio_xuthus_mdh,1,330,330
# Parnassius_glacialis,JAVANC010000016.1,18717801,18719024,0,N,Papilio_xuthus_idh,1,408,408
# Parnassius_glacialis,JAVANC010000017.1,24272390,24273094,0,N,Papilio_xuthus_DDC,1,235,235
# Parnassius_glacialis,JAVANC010000011.1,30620166,30621161,1,N,Papilio_xuthus_gapdh,1,332,332
# Parnassius_glacialis,JAVANC010000013.1,12757565,12758950,0,N,Papilio_xuthus_ef1,1,462,462
# Parnassius_glacialis,JAVANC010000009.1,2203575,2204351,0,N,Papilio_xuthus_hcl,1,259,259
# Parnassius_glacialis,JAVANC010000004.1,5199851,5201311,0,N,Papilio_xuthus_CAT,1,487,487
# Parnassius_glacialis,JAVANC010000016.1,25051434,25054574,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Sericinus_montela,JAGSMR010000021.1,6941569,6942225,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Sericinus_montela,JAGSMR010000012.1,16467745,16468269,1,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Sericinus_montela,JAGSMR010000057.1,4616165,4616683,1,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Sericinus_montela,JAGSMR010000011.1,709836,710825,1,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Sericinus_montela,JAGSMR010000008.1,5627324,5628547,0,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Sericinus_montela,JAGSMR010000012.1,9270881,9271585,0,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Sericinus_montela,JAGSMR010000020.1,966252,967247,1,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Sericinus_montela,JAGSMR010000016.1,3258853,3260238,1,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Sericinus_montela,JAGSMR010000046.1,3277157,3277933,0,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Sericinus_montela,JAGSMR010000028.1,4099771,4101231,1,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Sericinus_montela,JAGSMR010000008.1,7901898,7905038,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Sericinus_montela,JAGSMR010000021.1,6941569,6942225,0,N,Papilio_xuthus_rps5,1,219,219
# Sericinus_montela,JAGSMR010000012.1,16467745,16468269,1,N,Papilio_xuthus_wg,1,175,175
# Sericinus_montela,JAGSMR010000057.1,4616165,4616683,1,N,Papilio_xuthus_rps2,1,173,173
# Sericinus_montela,JAGSMR010000011.1,709836,710825,1,N,Papilio_xuthus_mdh,1,330,330
# Sericinus_montela,JAGSMR010000008.1,5627324,5628547,0,N,Papilio_xuthus_idh,1,408,408
# Sericinus_montela,JAGSMR010000012.1,9270881,9271585,0,N,Papilio_xuthus_DDC,1,235,235
# Sericinus_montela,JAGSMR010000020.1,966252,967247,1,N,Papilio_xuthus_gapdh,1,332,332
# Sericinus_montela,JAGSMR010000016.1,3258853,3260238,1,N,Papilio_xuthus_ef1,1,462,462
# Sericinus_montela,JAGSMR010000046.1,3277157,3277933,0,N,Papilio_xuthus_hcl,1,259,259
# Sericinus_montela,JAGSMR010000028.1,4099771,4101231,1,N,Papilio_xuthus_CAT,1,487,487
# Sericinus_montela,JAGSMR010000008.1,7901898,7905038,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Teinopalpus_imperialis,JAGSMU010000011.1,12518601,12519257,1,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Teinopalpus_imperialis,JAGSMU010000012.1,2093776,2094300,0,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Teinopalpus_imperialis,JAGSMU010000025.1,6109881,6110399,0,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Teinopalpus_imperialis,JAGSMU010000013.1,5091998,5092987,1,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Teinopalpus_imperialis,JAGSMU010000016.1,10876387,10877610,1,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Teinopalpus_imperialis,JAGSMU010000012.1,9056070,9056774,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Teinopalpus_imperialis,JAGSMU010000001.1,4910197,4911192,0,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Teinopalpus_imperialis,JAGSMU010000020.1,1732088,1733473,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Teinopalpus_imperialis,JAGSMU010000019.1,16553946,16554722,0,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Teinopalpus_imperialis,JAGSMU010000054.1,1246460,1247920,0,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Teinopalpus_imperialis,JAGSMU010000016.1,8577626,8580766,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Teinopalpus_imperialis,JAGSMU010000011.1,12518601,12519257,1,N,Papilio_xuthus_rps5,1,219,219
# Teinopalpus_imperialis,JAGSMU010000012.1,2093776,2094300,0,N,Papilio_xuthus_wg,1,175,175
# Teinopalpus_imperialis,JAGSMU010000025.1,6109881,6110399,0,N,Papilio_xuthus_rps2,1,173,173
# Teinopalpus_imperialis,JAGSMU010000013.1,5091998,5092987,1,N,Papilio_xuthus_mdh,1,330,330
# Teinopalpus_imperialis,JAGSMU010000016.1,10876387,10877610,1,N,Papilio_xuthus_idh,1,408,408
# Teinopalpus_imperialis,JAGSMU010000012.1,9056070,9056774,1,N,Papilio_xuthus_DDC,1,235,235
# Teinopalpus_imperialis,JAGSMU010000001.1,4910197,4911192,0,N,Papilio_xuthus_gapdh,1,332,332
# Teinopalpus_imperialis,JAGSMU010000020.1,1732088,1733473,0,N,Papilio_xuthus_ef1,1,462,462
# Teinopalpus_imperialis,JAGSMU010000019.1,16553946,16554722,0,N,Papilio_xuthus_hcl,1,259,259
# Teinopalpus_imperialis,JAGSMU010000054.1,1246460,1247920,0,N,Papilio_xuthus_CAT,1,487,487
# Teinopalpus_imperialis,JAGSMU010000016.1,8577626,8580766,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Troides_aeacus,CM067272.1,6048395,6049051,1,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Troides_aeacus,CM067271.1,10726561,10727085,1,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Troides_aeacus,CM067275.1,3239004,3239522,1,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Troides_aeacus,CM067276.1,9919712,9920701,0,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Troides_aeacus,CM067273.1,5176374,5177597,0,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Troides_aeacus,CM067271.1,5751699,5752403,0,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Troides_aeacus,CM067283.1,3192498,3193493,0,N,Papilio_xuthus_gapdh,1,332,332
#
# Papilio_xuthus
# Troides_aeacus,CM067269.1,2744352,2745737,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Troides_aeacus,CM067279.1,903108,903884,1,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Troides_aeacus,CM067268.1,11869107,11870567,0,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Troides_aeacus,CM067273.1,6657704,6660844,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Troides_aeacus,CM067272.1,6048395,6049051,1,N,Papilio_xuthus_rps5,1,219,219
# Troides_aeacus,CM067271.1,10726561,10727085,1,N,Papilio_xuthus_wg,1,175,175
# Troides_aeacus,CM067275.1,3239004,3239522,1,N,Papilio_xuthus_rps2,1,173,173
# Troides_aeacus,CM067276.1,9919712,9920701,0,N,Papilio_xuthus_mdh,1,330,330
# Troides_aeacus,CM067273.1,5176374,5177597,0,N,Papilio_xuthus_idh,1,408,408
# Troides_aeacus,CM067271.1,5751699,5752403,0,N,Papilio_xuthus_DDC,1,235,235
# Troides_aeacus,CM067283.1,3192498,3193493,0,N,Papilio_xuthus_gapdh,1,332,332
# Troides_aeacus,CM067269.1,2744352,2745737,0,N,Papilio_xuthus_ef1,1,462,462
# Troides_aeacus,CM067279.1,903108,903884,1,N,Papilio_xuthus_hcl,1,259,259
# Troides_aeacus,CM067268.1,11869107,11870567,0,N,Papilio_xuthus_CAT,1,487,487
# Troides_aeacus,CM067273.1,6657704,6660844,0,N,Papilio_xuthus_cad,1,1047,1047
#
# Papilio_xuthus
# Troides_oblongomaculatus,JARDWC010000087.1,2298259,2298915,0,N,Papilio_xuthus_rps5,1,219,219
#
# Papilio_xuthus
# Troides_oblongomaculatus,JARDWC010000431.1,3505256,3505780,0,N,Papilio_xuthus_wg,1,175,175
#
# Papilio_xuthus
# Troides_oblongomaculatus,JARDWC010000136.1,10520517,10521035,0,N,Papilio_xuthus_rps2,1,173,173
#
# Papilio_xuthus
# Troides_oblongomaculatus,JARDWC010000113.1,627646,628635,1,N,Papilio_xuthus_mdh,1,330,330
#
# Papilio_xuthus
# Troides_oblongomaculatus,JARDWC010000001.1,8555685,8556908,1,N,Papilio_xuthus_idh,1,408,408
#
# Papilio_xuthus
# Troides_oblongomaculatus,JARDWC010000431.1,8522879,8523583,1,N,Papilio_xuthus_DDC,1,235,235
#
# Papilio_xuthus
# Troides_oblongomaculatus,JARDWC010000444.1,2927037,2928032,1,N,Papilio_xuthus_gapdh,1,332,332
# Papilio_xuthus
# Troides_oblongomaculatus,JARDWC010000099.1,2062605,2063990,0,N,Papilio_xuthus_ef1,1,462,462
#
# Papilio_xuthus
# Troides_oblongomaculatus,JARDWC010000381.1,3587947,3588723,0,N,Papilio_xuthus_hcl,1,259,259
#
# Papilio_xuthus
# Troides_oblongomaculatus,JARDWC010000447.1,5315635,5317095,0,N,Papilio_xuthus_CAT,1,487,487
#
# Papilio_xuthus
# Troides_oblongomaculatus,JARDWC010000001.1,7094751,7097891,1,N,Papilio_xuthus_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Troides_oblongomaculatus,JARDWC010000087.1,2298259,2298915,0,N,Papilio_xuthus_rps5,1,219,219
# Troides_oblongomaculatus,JARDWC010000431.1,3505256,3505780,0,N,Papilio_xuthus_wg,1,175,175
# Troides_oblongomaculatus,JARDWC010000136.1,10520517,10521035,0,N,Papilio_xuthus_rps2,1,173,173
# Troides_oblongomaculatus,JARDWC010000113.1,627646,628635,1,N,Papilio_xuthus_mdh,1,330,330
# Troides_oblongomaculatus,JARDWC010000001.1,8555685,8556908,1,N,Papilio_xuthus_idh,1,408,408
# Troides_oblongomaculatus,JARDWC010000431.1,8522879,8523583,1,N,Papilio_xuthus_DDC,1,235,235
# Troides_oblongomaculatus,JARDWC010000444.1,2927037,2928032,1,N,Papilio_xuthus_gapdh,1,332,332
# Troides_oblongomaculatus,JARDWC010000099.1,2062605,2063990,0,N,Papilio_xuthus_ef1,1,462,462
# Troides_oblongomaculatus,JARDWC010000381.1,3587947,3588723,0,N,Papilio_xuthus_hcl,1,259,259
# Troides_oblongomaculatus,JARDWC010000447.1,5315635,5317095,0,N,Papilio_xuthus_CAT,1,487,487
# Troides_oblongomaculatus,JARDWC010000001.1,7094751,7097891,1,N,Papilio_xuthus_cad,1,1047,1047
