# %%
from Bio import SeqIO
import os
import subprocess

location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/8.For Phylogeny/9.Gene_sequences"

list_of_files = os.listdir(location)

if "desktop.ini" in list_of_files:
    list_of_files.remove("desktop.ini")
    
for file in (list_of_files):
    subprocess.run(f'cd {location}\nprank -d={file} -o={file}.aligned.fas -codon -iterate=10', shell = True, stderr = subprocess.DEVNULL)
# Out:
# Bicyclus_anynana_cad
# Coenonympha_glycerion_cad
# Erebia_aethiops_cad
# Erebia_ligea_cad
# Hipparchia_semele_cad
# Lasiommata_megera_cad
# Maniola_hyperantus_cad
# Maniola_jurtina_cad
# Melanargia_galathea_cad
# Oeneis_ivallda_cad
# Pararge_aegeria_cad
# Anthocharis_cardamines_cad
# Aporia_crataegi_cad
# Leptophobia_aripa_cad
# Pieris_brassicae_cad
# Pieris_mannii_cad
# Pieris_melete_cad
# Pieris_napi_cad
# Pieris_rapae_cad
# Colias_croceus_cad
# Colias_eurytheme_cad
# Colias_nastes_cad
# Phoebis_sennae_cad
# Zerene_cesonia_cad
# Leptidea_juvernica_cad
# Leptidea_reali_cad
# Leptidea_sinapis_cad
# Hestina_assimilis_cad
# Danaus_chrysippus_cad
# Dircenna_loreta_cad
# Mechanitis_mazaeus_cad
# Mechanitis_messenoides_cad
# Melinaea_marsaeus_rileyi_cad
# Melinaea_menophilus_cad
# Napeogenes_inachia_cad
# Napeogenes_sylphis_cad
# Argynnis_bischoffii_washingtonia_cad
# Boloria_euphrosyne_cad
# Boloria_selene_cad
# Brenthis_daphne_cad
# Brenthis_hecate_cad
# Brenthis_ino_cad
# ...
