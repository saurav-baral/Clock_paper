# %%
def sequence_extractor(Species, Scaff, reverse_c, start, end, frame = 1, trans = 1 ):
    from Bio import SeqIO
    from Bio.Seq import Seq
    import os
    
    out_Seq = ''
    
    
    #Genome folder
    entries = os.listdir("/mnt/f/Genomes_2023-12-26/"+Species)
    
    #Get genome file from Genome folder
    for file_names  in entries:
        if ".nhr" in file_names:
            Genome_name = file_names[:-4]
            break
    
    #Read the genome file
    fasta_file = open(("/mnt/f/Genomes_2023-12-26/"+Species+"/"+Genome_name),'r')
    
    #Extract the sequence 
    for record in SeqIO.parse(fasta_file,"fasta"):
        if record.id == Scaff:
            sequence = str(record.seq)
            out_Seq = Seq(sequence[start-1:end])
            if reverse_c == 1:
                out_Seq = out_Seq.reverse_complement()
                
    if len(out_Seq) < 10000: #fixing error due to mistake in typing the coordinate, change this for longer sequence
#        print (out_Seq)
        if frame == 1 :
            out_trans = out_Seq[0:]
        if frame == 2 :
            out_trans = out_Seq[1:]
        if frame == 3 :
            out_trans = out_Seq[2:]
    else:
        print ("too long")
        assert(False)
        
        
    #    break
    fasta_file.close()
    if trans == 1:
        return (out_trans.translate())
    else:
        return(out_Seq)
#

# %%
import os
from Bio import SeqIO

# %%
#%reset -f
blast_location = "/mnt/h/My Drive/Circadian Rhythm Genes Project/8.For Phylogeny/3.Satyrine"
query_species = "Bicyclus_anynana"


species_list = os.listdir(f"{blast_location}/1.Blast_result")

query_file = SeqIO.parse(f"{blast_location}/1.Query/query.txt", 'fasta')
query_name_list = []

for records in query_file:
    query_name_list.append(records.id)



for species in species_list:
    # print(species_name)
    # species = species_name.split(".")[1]
    header = "Species," + "Scaffold," + "Start," + "Stop," + "Complement," + "Error," + "Gene,"+ "Query_start," + "Query_stop,"+ "Query_Length\n" 
    Output_Sequence = header
    scaff = "Intial_value"
    scaff_old = "Intial_value"
    old_end = 0
    
#Run for each query in the query list
    for i in range(len(query_name_list)):
        query_name = query_name_list[i]
        Length_switch = "0"
        with open(f"{blast_location}/1.Blast_result/{species}/{species}_blast_out.txt",'r') as tblast_out:
            lines_in_file = tblast_out.readlines()
        #print(lines_in_file)

        result_section_switch = 0
        start_coor_switch = 0
        query_start_coor_switch = 0
        stop_coor_switch = 0
        error = "N"
        break_switch = 0

        start = 0
        stop = 0
        start_coor = 0
        stop_coor = 0
        query_length = 0

        for lines in lines_in_file:

#             print(lines)
            if query_name in lines:
            #Initialize that results can now be checked
                result_section_switch = 1
                query_species_split = lines.split(" ")[1].split("_")
#                 print(query_species_split)
                query_species = str(query_species_split[0]+"_"+query_species_split[1].rstrip())
                print(query_species)
            if result_section_switch == 1 and "Lambda" in lines:
            #This block indicates end of the results block in blast output
                result_section_switch == 0
                
                break

            if result_section_switch == 1:
            #While checking the result
                if "Length=" in lines and Length_switch == "0":
                #Get query length from the blast output
                    
                    query_length = int(lines.split("=")[1].rstrip())
                    
                    Length_switch = 1 #Indicated length has been acquired
                    
                if ("Score" in lines or ">" in lines) and (start_coor_switch == 1):
    #                print (lines)
                    break
        
                if ">" in lines:
                #Start of the first result
                    scaff = lines.split(" ")[0][1:] #Scaffold from the result
#                     if scaff_old != "Intial_value" and scaff_old != scaff:
#                         error = "Y"
                    scaff_old = scaff
                    
                if "Query" in lines and "=" not in lines:
                #Read the query line in output
                    if query_start_coor_switch == 0:
#                        print(lines)
                        query_start_coor = int(lines.split(" ")[2])
                        query_start_coor_switch = 1
                        #Query start coordinate fixed
            
                    query_stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting query stop coordinates for multiline result
    #                print (stop_coor)
                    
                if "Sbjct" in lines:
                #Read the blast target line
                    if start_coor_switch == 0:
                        start_coor = int(lines.split(" ")[2])
                        start_coor_switch = 1
                    stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting target stop coordinates for multiline result
                
                

        
        if break_switch == 1:
            break

        if start_coor < stop_coor:
            complement = "0" #Forward complement
            
            length = (stop_coor-start_coor)/3
            start = start_coor
            stop = stop_coor

        elif start_coor > stop_coor:
            complement = "1" #Reverse complement
            length = (-stop_coor+start_coor)/3
            start = stop_coor
            stop = start_coor

        else:
            error = "Y"
        
        
        
        

        #Check if the length of target (blast hit) is significantly smaller than query
        if length < query_length - 0.2*query_length:
            error = "Y"

        old_trans = ''
#             print(start, stop)


# #Check for Met or STOP at the start and end
#         while True and (start != 0 or stop != 0):
#             if (query_name == query_name_list[0] or query_name == query_name_list[-1]):
#                 frame = 1
#                 translated_sequence = (sequence_extractor(species, scaff, int(complement), start, stop,frame ))

#                 if translated_sequence == old_trans:
#                     break
                    
# #Check for Met at the beginning of first exon

#                 if query_name == query_name_list[0] :
#                     if translated_sequence[0] != "M":
#                         print(translated_sequence)
# #                             print(start, stop)
#                         if complement == "0":
#                             start = int(start) - 3
#                         if complement == "1":
#                             stop = int(stop) + 3
#                         old_trans = translated_sequence
#                     if "*" in translated_sequence:
#                         error = "Y"
#                         break
#                     if translated_sequence[0] == "M":
#                         break

# #Check for stop at the end of last exon

#                 if query_name == query_name_list[-1]:
#                     if translated_sequence[-1] != "*":
#                         print(translated_sequence)
# #                             print(start, stop)
#                         if complement == "0":
#                             stop = int(stop) + 3
#                         if complement == "1":
#                             start = int(start) - 3
#                         old_trans = translated_sequence
#                     if translated_sequence[-1] == "*":

#                         break
#             else:
#                 break
        
        
#Add offset at the beginning and end of each exon
#         if (start != 0 or stop != 0):
            
#             start_modifier = int(query_name.split("Frame")[1][1])
#             stop_modifier = int(query_name.split("rightoh")[1][1])
#         else:
        start_modifier = 0
        stop_modifier = 0            

        seq_length = query_length
        
        
#Get exon start and end by adding or removing codons
        
    #if not the beginning
        if query_start_coor != "1" and query_name != query_name_list[0]:
            if complement == "0":
                start = int(start) - 3*(int(query_start_coor)-1)                
            if complement == "1":
                stop = int(stop) + 3*(int(query_start_coor)-1)
    
    #For the end
        if query_stop_coor != str(seq_length) and query_name != query_name_list[-1]:
            if complement == "0":
                stop = int(stop) + 3*(int(seq_length)-int(query_stop_coor))
            if complement == "1":
                

                start = int(start) - 3*(int(seq_length)-int(query_stop_coor))
 
        
        
        
#Adding or removing 3' and 5' overhangs for forward and reverse complement
    #For forward complement
        if complement == "0":
            start = int(start) - int(start_modifier)
            stop = int(stop) +  int(stop_modifier)
#             if old_end != 0 and old_end > stop:

#                 error = "Y"
            old_end = stop

    #For reverse complement
        if complement == "1":
            start = int(start) - int(stop_modifier)
            stop = int(stop) +  int(start_modifier)
#             if old_end != 0 and old_end < stop:
#                 error = "Y"
            old_end = stop

    #Simple check for lenghth
        if start == 0 or stop == 0:
            error = "Y"
            
           
        output_format = str(species.split("\n")[0])+"," + str(scaff) +"," + str(start)+"," + str(stop)+"," + str(complement)+"," + str(error)+  ","+ str(query_name)+","+ str(query_start_coor)+","+str(query_stop_coor)+","+str(query_length)+ "\n"  
        print(output_format)
#         assert False
        Output_Sequence = Output_Sequence + output_format

    print(Output_Sequence)
    output_file = open(f"{blast_location}/1.Blast_result/{species}/{species}_coordinates.csv",'w')
    output_file.write(Output_Sequence)
    output_file.close()
# Out:
# Bicyclus_anynana
# Bicyclus_anynana,NC_069086.1,11483690,11484343,0,N,Bicyclus_anynana_rps5,1,218,218
#
# Bicyclus_anynana
# Bicyclus_anynana,NC_069085.1,15161126,15161650,1,N,Bicyclus_anynana_wg,1,175,175
#
# Bicyclus_anynana
# Bicyclus_anynana,NC_069088.1,14786334,14786852,1,N,Bicyclus_anynana_rps2,1,173,173
#
# Bicyclus_anynana
# Bicyclus_anynana,NC_069091.1,4302552,4303541,1,N,Bicyclus_anynana_mdh,1,330,330
#
# Bicyclus_anynana
# Bicyclus_anynana,NC_069087.1,7018552,7019775,0,N,Bicyclus_anynana_idh,1,408,408
#
# Bicyclus_anynana
# Bicyclus_anynana,NC_069085.1,7848095,7848799,0,N,Bicyclus_anynana_ddc,1,235,235
#
# Bicyclus_anynana
# Bicyclus_anynana,NC_069101.1,8211585,8212580,0,N,Bicyclus_anynana_gapdh,1,332,332
#
# Bicyclus_anynana
# Bicyclus_anynana,NC_069083.1,16542533,16543918,1,N,Bicyclus_anynana_ef1,1,462,462
#
# Bicyclus_anynana
# Bicyclus_anynana,NC_069095.1,13512390,13513166,1,N,Bicyclus_anynana_hcl,1,259,259
#
# Bicyclus_anynana
# Bicyclus_anynana,NC_069110.1,13793257,13794717,1,N,Bicyclus_anynana_cat,1,487,487
#
# Bicyclus_anynana
# Bicyclus_anynana,NC_069087.1,9201226,9204366,0,N,Bicyclus_anynana_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Bicyclus_anynana,NC_069086.1,11483690,11484343,0,N,Bicyclus_anynana_rps5,1,218,218
# Bicyclus_anynana,NC_069085.1,15161126,15161650,1,N,Bicyclus_anynana_wg,1,175,175
# Bicyclus_anynana,NC_069088.1,14786334,14786852,1,N,Bicyclus_anynana_rps2,1,173,173
# Bicyclus_anynana,NC_069091.1,4302552,4303541,1,N,Bicyclus_anynana_mdh,1,330,330
# Bicyclus_anynana,NC_069087.1,7018552,7019775,0,N,Bicyclus_anynana_idh,1,408,408
# Bicyclus_anynana,NC_069085.1,7848095,7848799,0,N,Bicyclus_anynana_ddc,1,235,235
# Bicyclus_anynana,NC_069101.1,8211585,8212580,0,N,Bicyclus_anynana_gapdh,1,332,332
# Bicyclus_anynana,NC_069083.1,16542533,16543918,1,N,Bicyclus_anynana_ef1,1,462,462
# Bicyclus_anynana,NC_069095.1,13512390,13513166,1,N,Bicyclus_anynana_hcl,1,259,259
# Bicyclus_anynana,NC_069110.1,13793257,13794717,1,N,Bicyclus_anynana_cat,1,487,487
# Bicyclus_anynana,NC_069087.1,9201226,9204366,0,N,Bicyclus_anynana_cad,1,1047,1047
#
# Bicyclus_anynana
# Coenonympha_glycerion,OY979630.1,7820902,7821558,1,N,Bicyclus_anynana_rps5,1,218,218
#
# Bicyclus_anynana
# Coenonympha_glycerion,OY979629.1,14988771,14989295,1,N,Bicyclus_anynana_wg,1,175,175
#
# Bicyclus_anynana
# Coenonympha_glycerion,OY979632.1,14129484,14130002,1,N,Bicyclus_anynana_rps2,1,173,173
#
# Bicyclus_anynana
# Coenonympha_glycerion,OY979635.1,12735815,12736804,0,N,Bicyclus_anynana_mdh,1,330,330
#
# Bicyclus_anynana
# Coenonympha_glycerion,OY979628.1,12388155,12389378,1,N,Bicyclus_anynana_idh,1,408,408
#
# Bicyclus_anynana
# Coenonympha_glycerion,OY979629.1,7749400,7750104,0,N,Bicyclus_anynana_ddc,1,235,235
#
# Bicyclus_anynana
# Coenonympha_glycerion,OY979645.1,10857308,10858303,1,N,Bicyclus_anynana_gapdh,1,332,332
#
# Bicyclus_anynana
# Coenonympha_glycerion,OY979627.1,16008458,16009843,1,N,Bicyclus_anynana_ef1,1,462,462
#
# Bicyclus_anynana
# Coenonympha_glycerion,OY979642.1,698669,699445,0,N,Bicyclus_anynana_hcl,1,259,259
#
# Bicyclus_anynana
# Coenonympha_glycerion,OY979633.1,12279944,12281404,1,N,Bicyclus_anynana_cat,1,487,487
#
# Bicyclus_anynana
# Coenonympha_glycerion,OY979628.1,10475365,10478505,0,N,Bicyclus_anynana_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Coenonympha_glycerion,OY979630.1,7820902,7821558,1,N,Bicyclus_anynana_rps5,1,218,218
# Coenonympha_glycerion,OY979629.1,14988771,14989295,1,N,Bicyclus_anynana_wg,1,175,175
# Coenonympha_glycerion,OY979632.1,14129484,14130002,1,N,Bicyclus_anynana_rps2,1,173,173
# Coenonympha_glycerion,OY979635.1,12735815,12736804,0,N,Bicyclus_anynana_mdh,1,330,330
# Coenonympha_glycerion,OY979628.1,12388155,12389378,1,N,Bicyclus_anynana_idh,1,408,408
# Coenonympha_glycerion,OY979629.1,7749400,7750104,0,N,Bicyclus_anynana_ddc,1,235,235
# Coenonympha_glycerion,OY979645.1,10857308,10858303,1,N,Bicyclus_anynana_gapdh,1,332,332
# Erebia_ligea,OU785219.1,17596455,17596979,1,N,Bicyclus_anynana_wg,1,175,175
#
# Bicyclus_anynana
# Erebia_ligea,OU785224.1,16037586,16038104,1,N,Bicyclus_anynana_rps2,1,173,173
# Bicyclus_anynana
# Erebia_ligea,OU785227.1,15392748,15393737,0,N,Bicyclus_anynana_mdh,1,330,330
#
# Bicyclus_anynana
# Erebia_ligea,OU785223.1,13779872,13781095,1,N,Bicyclus_anynana_idh,1,408,408
#
# Bicyclus_anynana
# Erebia_ligea,OU785219.1,9144482,9145186,0,N,Bicyclus_anynana_ddc,1,235,235
#
# Bicyclus_anynana
# Erebia_ligea,OU785238.1,4900149,4901144,0,N,Bicyclus_anynana_gapdh,1,332,332
#
# Bicyclus_anynana
# Erebia_ligea,OU785226.1,2300356,2301741,0,N,Bicyclus_anynana_ef1,1,462,462
#
# Bicyclus_anynana
# Erebia_ligea,OU785232.1,848750,849526,0,N,Bicyclus_anynana_hcl,1,259,259
#
# Bicyclus_anynana
# Erebia_ligea,OU785222.1,7157559,7159019,0,N,Bicyclus_anynana_cat,1,487,487
#
# Bicyclus_anynana
# Erebia_ligea,OU785223.1,11304140,11307280,1,N,Bicyclus_anynana_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Erebia_ligea,OU785220.1,8978403,8979059,1,N,Bicyclus_anynana_rps5,1,218,218
# Erebia_ligea,OU785219.1,17596455,17596979,1,N,Bicyclus_anynana_wg,1,175,175
# Erebia_ligea,OU785224.1,16037586,16038104,1,N,Bicyclus_anynana_rps2,1,173,173
# Erebia_ligea,OU785227.1,15392748,15393737,0,N,Bicyclus_anynana_mdh,1,330,330
# Erebia_ligea,OU785223.1,13779872,13781095,1,N,Bicyclus_anynana_idh,1,408,408
# Erebia_ligea,OU785219.1,9144482,9145186,0,N,Bicyclus_anynana_ddc,1,235,235
# Erebia_ligea,OU785238.1,4900149,4901144,0,N,Bicyclus_anynana_gapdh,1,332,332
# Erebia_ligea,OU785226.1,2300356,2301741,0,N,Bicyclus_anynana_ef1,1,462,462
# Erebia_ligea,OU785232.1,848750,849526,0,N,Bicyclus_anynana_hcl,1,259,259
# Erebia_ligea,OU785222.1,7157559,7159019,0,N,Bicyclus_anynana_cat,1,487,487
# Erebia_ligea,OU785223.1,11304140,11307280,1,N,Bicyclus_anynana_cad,1,1047,1047
#
# Bicyclus_anynana
# Hipparchia_semele,OW121711.1,6975906,6976559,1,N,Bicyclus_anynana_rps5,1,218,218
#
# Bicyclus_anynana
# Hipparchia_semele,OW121709.1,13598235,13598759,1,N,Bicyclus_anynana_wg,1,175,175
#
# Bicyclus_anynana
# Hipparchia_semele,OW121713.1,3786478,3786996,0,N,Bicyclus_anynana_rps2,1,173,173
#
# Bicyclus_anynana
# Hipparchia_semele,OW121717.1,11087930,11088919,0,N,Bicyclus_anynana_mdh,1,330,330
#
# Bicyclus_anynana
# Hipparchia_semele,OW121712.1,5946971,5948194,0,N,Bicyclus_anynana_idh,1,408,408
#
# Bicyclus_anynana
# Hipparchia_semele,OW121709.1,6965158,6965862,0,N,Bicyclus_anynana_ddc,1,235,235
#
# Bicyclus_anynana
# Hipparchia_semele,OW121726.1,3753749,3754744,0,N,Bicyclus_anynana_gapdh,1,332,332
#
# Bicyclus_anynana
# Hipparchia_semele,OW121710.1,3011375,3012760,0,N,Bicyclus_anynana_ef1,1,462,462
#
# Bicyclus_anynana
# Hipparchia_semele,OW121720.1,533162,533938,0,N,Bicyclus_anynana_hcl,1,259,259
#
# Bicyclus_anynana
# Hipparchia_semele,OW121737.1,10203542,10205002,1,N,Bicyclus_anynana_cat,1,487,487
#
# Bicyclus_anynana
# Hipparchia_semele,OW121712.1,7770471,7773611,0,N,Bicyclus_anynana_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Hipparchia_semele,OW121711.1,6975906,6976559,1,N,Bicyclus_anynana_rps5,1,218,218
# Hipparchia_semele,OW121709.1,13598235,13598759,1,N,Bicyclus_anynana_wg,1,175,175
# Hipparchia_semele,OW121713.1,3786478,3786996,0,N,Bicyclus_anynana_rps2,1,173,173
# Hipparchia_semele,OW121717.1,11087930,11088919,0,N,Bicyclus_anynana_mdh,1,330,330
# Hipparchia_semele,OW121712.1,5946971,5948194,0,N,Bicyclus_anynana_idh,1,408,408
# Hipparchia_semele,OW121709.1,6965158,6965862,0,N,Bicyclus_anynana_ddc,1,235,235
# Hipparchia_semele,OW121726.1,3753749,3754744,0,N,Bicyclus_anynana_gapdh,1,332,332
# Hipparchia_semele,OW121710.1,3011375,3012760,0,N,Bicyclus_anynana_ef1,1,462,462
# Hipparchia_semele,OW121720.1,533162,533938,0,N,Bicyclus_anynana_hcl,1,259,259
# Hipparchia_semele,OW121737.1,10203542,10205002,1,N,Bicyclus_anynana_cat,1,487,487
# Hipparchia_semele,OW121712.1,7770471,7773611,0,N,Bicyclus_anynana_cad,1,1047,1047
#
# Bicyclus_anynana
# Lasiommata_megera,OV743311.1,11543352,11544005,0,N,Bicyclus_anynana_rps5,1,218,218
#
# Bicyclus_anynana
# Lasiommata_megera,OV743309.1,4648199,4648723,0,N,Bicyclus_anynana_wg,1,175,175
#
# Bicyclus_anynana
# Lasiommata_megera,OV743310.1,4630672,4631190,0,N,Bicyclus_anynana_rps2,1,173,173
#
# Bicyclus_anynana
# Lasiommata_megera,OV743315.1,13702087,13703076,0,N,Bicyclus_anynana_mdh,1,330,330
#
# Bicyclus_anynana
# Lasiommata_megera,OV743312.1,12210320,12211543,1,N,Bicyclus_anynana_idh,1,408,408
#
# Bicyclus_anynana
# Lasiommata_megera,OV743309.1,12053849,12054553,1,N,Bicyclus_anynana_ddc,1,235,235
#
# Bicyclus_anynana
# Lasiommata_megera,OV743325.1,11792062,11793057,1,N,Bicyclus_anynana_gapdh,1,332,332
#
# Bicyclus_anynana
# Lasiommata_megera,OV743308.1,16986516,16987901,1,N,Bicyclus_anynana_ef1,1,462,462
#
# Bicyclus_anynana
# Lasiommata_megera,OV743320.1,648135,648911,0,N,Bicyclus_anynana_hcl,1,259,259
#
# Bicyclus_anynana
# Lasiommata_megera,OV743307.1,10296459,10297919,0,N,Bicyclus_anynana_cat,1,487,487
#
# Bicyclus_anynana
# Lasiommata_megera,OV743312.1,10059843,10062983,1,N,Bicyclus_anynana_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Lasiommata_megera,OV743311.1,11543352,11544005,0,N,Bicyclus_anynana_rps5,1,218,218
# Lasiommata_megera,OV743309.1,4648199,4648723,0,N,Bicyclus_anynana_wg,1,175,175
# Lasiommata_megera,OV743310.1,4630672,4631190,0,N,Bicyclus_anynana_rps2,1,173,173
# Lasiommata_megera,OV743315.1,13702087,13703076,0,N,Bicyclus_anynana_mdh,1,330,330
# Lasiommata_megera,OV743312.1,12210320,12211543,1,N,Bicyclus_anynana_idh,1,408,408
# Lasiommata_megera,OV743309.1,12053849,12054553,1,N,Bicyclus_anynana_ddc,1,235,235
# Lasiommata_megera,OV743325.1,11792062,11793057,1,N,Bicyclus_anynana_gapdh,1,332,332
# Lasiommata_megera,OV743308.1,16986516,16987901,1,N,Bicyclus_anynana_ef1,1,462,462
# Lasiommata_megera,OV743320.1,648135,648911,0,N,Bicyclus_anynana_hcl,1,259,259
# Lasiommata_megera,OV743307.1,10296459,10297919,0,N,Bicyclus_anynana_cat,1,487,487
# Lasiommata_megera,OV743312.1,10059843,10062983,1,N,Bicyclus_anynana_cad,1,1047,1047
#
# Bicyclus_anynana
# Maniola_hyperantus,NC_048539.1,10202149,10202805,0,N,Bicyclus_anynana_rps5,1,218,218
#
# Bicyclus_anynana
# Maniola_hyperantus,NC_048536.1,4352786,4353310,0,N,Bicyclus_anynana_wg,1,175,175
#
# Bicyclus_anynana
# Maniola_hyperantus,NC_048541.1,3966082,3966600,0,N,Bicyclus_anynana_rps2,1,173,173
#
# Bicyclus_anynana
# Maniola_hyperantus,NC_048543.1,11944985,11945974,0,N,Bicyclus_anynana_mdh,1,330,330
#
# Bicyclus_anynana
# Maniola_hyperantus,NC_048538.1,11287973,11289196,1,N,Bicyclus_anynana_idh,1,408,408
#
# Bicyclus_anynana
# Maniola_hyperantus,NC_048536.1,11309462,11310166,1,N,Bicyclus_anynana_ddc,1,235,235
#
# Bicyclus_anynana
# Maniola_hyperantus,NC_048554.1,3891938,3892933,0,N,Bicyclus_anynana_gapdh,1,332,332
#
# Bicyclus_anynana
# Maniola_hyperantus,NC_048537.1,3312241,3313626,0,N,Bicyclus_anynana_ef1,1,462,462
#
# Bicyclus_anynana
# Maniola_hyperantus,NC_048546.1,665453,666229,0,N,Bicyclus_anynana_hcl,1,259,259
#
# Bicyclus_anynana
# Maniola_hyperantus,NC_048564.1,10991294,10992757,1,N,Bicyclus_anynana_cat,1,487,487
#
# Bicyclus_anynana
# Maniola_hyperantus,NC_048538.1,9357346,9360486,1,N,Bicyclus_anynana_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
#
# Maniola_jurtina,NC_060029.1,6955070,6955774,0,N,Bicyclus_anynana_ddc,1,235,235
# Maniola_jurtina,NC_060045.1,9898902,9899897,1,N,Bicyclus_anynana_gapdh,1,332,332
# Maniola_jurtina,NC_060030.1,2967844,2969229,0,N,Bicyclus_anynana_ef1,1,462,462
# Maniola_jurtina,NC_060040.1,14514977,14515753,1,N,Bicyclus_anynana_hcl,1,259,259
# Maniola_jurtina,NC_060058.1,15091157,15092620,0,N,Bicyclus_anynana_cat,1,487,487
# Maniola_jurtina,NC_060031.1,8035326,8038466,0,N,Bicyclus_anynana_cad,1,1047,1047
#
# Bicyclus_anynana
# Melanargia_galathea,OV049863.1,10562285,10562947,1,N,Bicyclus_anynana_rps5,1,218,218
#
# Bicyclus_anynana
# Melanargia_galathea,OV049862.1,5936256,5936780,0,N,Bicyclus_anynana_wg,1,175,175
#
# Bicyclus_anynana
# Melanargia_galathea,OV049866.1,19012510,19013028,1,N,Bicyclus_anynana_rps2,1,173,173
#
# Bicyclus_anynana
# Melanargia_galathea,OV049867.1,5791100,5792089,1,N,Bicyclus_anynana_mdh,1,330,330
#
# Bicyclus_anynana
# Melanargia_galathea,OV049864.1,9295900,9297123,0,N,Bicyclus_anynana_idh,1,408,408
#
# Bicyclus_anynana
# Melanargia_galathea,OV049862.1,15576853,15577557,1,N,Bicyclus_anynana_ddc,1,235,235
#
# Bicyclus_anynana
# Melanargia_galathea,OV049876.1,14341017,14342012,1,N,Bicyclus_anynana_gapdh,1,332,332
#
# Bicyclus_anynana
# Melanargia_galathea,OV049859.1,4737416,4738801,0,N,Bicyclus_anynana_ef1,1,462,462
#
# Bicyclus_anynana
# Melanargia_galathea,OV049870.1,21268797,21269573,1,N,Bicyclus_anynana_hcl,1,259,259
#
# Bicyclus_anynana
# Melanargia_galathea,OV049860.1,17416576,17418036,1,N,Bicyclus_anynana_cat,1,487,487
#
# Bicyclus_anynana
# Melanargia_galathea,OV049864.1,12320829,12323969,0,N,Bicyclus_anynana_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Melanargia_galathea,OV049863.1,10562285,10562947,1,N,Bicyclus_anynana_rps5,1,218,218
# Melanargia_galathea,OV049862.1,5936256,5936780,0,N,Bicyclus_anynana_wg,1,175,175
# Melanargia_galathea,OV049866.1,19012510,19013028,1,N,Bicyclus_anynana_rps2,1,173,173
# Melanargia_galathea,OV049867.1,5791100,5792089,1,N,Bicyclus_anynana_mdh,1,330,330
# Melanargia_galathea,OV049864.1,9295900,9297123,0,N,Bicyclus_anynana_idh,1,408,408
# Melanargia_galathea,OV049862.1,15576853,15577557,1,N,Bicyclus_anynana_ddc,1,235,235
# Melanargia_galathea,OV049876.1,14341017,14342012,1,N,Bicyclus_anynana_gapdh,1,332,332
# Melanargia_galathea,OV049859.1,4737416,4738801,0,N,Bicyclus_anynana_ef1,1,462,462
# Melanargia_galathea,OV049870.1,21268797,21269573,1,N,Bicyclus_anynana_hcl,1,259,259
# Melanargia_galathea,OV049860.1,17416576,17418036,1,N,Bicyclus_anynana_cat,1,487,487
# Melanargia_galathea,OV049864.1,12320829,12323969,0,N,Bicyclus_anynana_cad,1,1047,1047
#
# Bicyclus_anynana
# Oeneis_ivallda,JARPMR010000005.1,18297517,18298173,1,N,Bicyclus_anynana_rps5,1,218,218
#
# Bicyclus_anynana
# Oeneis_ivallda,JARPMR010000002.1,7243721,7244245,0,N,Bicyclus_anynana_wg,2,175,175
#
# Bicyclus_anynana
# Oeneis_ivallda,JARPMR010000030.1,1499809,1500327,0,N,Bicyclus_anynana_rps2,1,173,173
#
# Bicyclus_anynana
# Oeneis_ivallda,JARPMR010000010.1,6701190,6702179,1,N,Bicyclus_anynana_mdh,1,330,330
#
# Bicyclus_anynana
# Oeneis_ivallda,JARPMR010000006.1,10148375,10149598,0,N,Bicyclus_anynana_idh,1,408,408
#
# Bicyclus_anynana
# Oeneis_ivallda,JARPMR010000002.1,18679339,18680043,1,N,Bicyclus_anynana_ddc,1,235,235
#
# Bicyclus_anynana
# Oeneis_ivallda,JARPMR010000019.1,17249100,17250095,1,N,Bicyclus_anynana_gapdh,1,332,332
#
# Bicyclus_anynana
# Oeneis_ivallda,JARPMR010000003.1,5871996,5873381,0,N,Bicyclus_anynana_ef1,1,462,462
#
# Bicyclus_anynana
# Oeneis_ivallda,JARPMR010000015.1,1187252,1188028,0,N,Bicyclus_anynana_hcl,1,259,259
#
# Bicyclus_anynana
# Oeneis_ivallda,JARPMR010000001.1,24020291,24021751,1,N,Bicyclus_anynana_cat,1,487,487
#
# Bicyclus_anynana
# Oeneis_ivallda,JARPMR010000006.1,13750256,13753396,0,N,Bicyclus_anynana_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Oeneis_ivallda,JARPMR010000005.1,18297517,18298173,1,N,Bicyclus_anynana_rps5,1,218,218
# Oeneis_ivallda,JARPMR010000002.1,7243721,7244245,0,N,Bicyclus_anynana_wg,2,175,175
# Oeneis_ivallda,JARPMR010000030.1,1499809,1500327,0,N,Bicyclus_anynana_rps2,1,173,173
# Oeneis_ivallda,JARPMR010000010.1,6701190,6702179,1,N,Bicyclus_anynana_mdh,1,330,330
# Oeneis_ivallda,JARPMR010000006.1,10148375,10149598,0,N,Bicyclus_anynana_idh,1,408,408
# Oeneis_ivallda,JARPMR010000002.1,18679339,18680043,1,N,Bicyclus_anynana_ddc,1,235,235
# Oeneis_ivallda,JARPMR010000019.1,17249100,17250095,1,N,Bicyclus_anynana_gapdh,1,332,332
# Oeneis_ivallda,JARPMR010000003.1,5871996,5873381,0,N,Bicyclus_anynana_ef1,1,462,462
# Oeneis_ivallda,JARPMR010000015.1,1187252,1188028,0,N,Bicyclus_anynana_hcl,1,259,259
# Oeneis_ivallda,JARPMR010000001.1,24020291,24021751,1,N,Bicyclus_anynana_cat,1,487,487
# Oeneis_ivallda,JARPMR010000006.1,13750256,13753396,0,N,Bicyclus_anynana_cad,1,1047,1047
#
# Bicyclus_anynana
# Pararge_aegeria,NC_053183.1,8818510,8819163,1,N,Bicyclus_anynana_rps5,1,218,218
#
# Bicyclus_anynana
# Pararge_aegeria,NC_053182.1,16434376,16434900,1,N,Bicyclus_anynana_wg,1,175,175
#
# Bicyclus_anynana
# Pararge_aegeria,NC_053184.1,15813827,15814345,1,N,Bicyclus_anynana_rps2,1,173,173
#
# Bicyclus_anynana
# Pararge_aegeria,NC_053190.1,14291871,14292860,0,N,Bicyclus_anynana_mdh,1,330,330
#
# Bicyclus_anynana
# Pararge_aegeria,NC_053185.1,13048460,13049683,1,N,Bicyclus_anynana_idh,1,408,408
#
# Bicyclus_anynana
# Pararge_aegeria,NC_053182.1,8903608,8904312,0,N,Bicyclus_anynana_ddc,1,235,235
#
# Bicyclus_anynana
# Pararge_aegeria,NC_053196.1,5263527,5264522,0,N,Bicyclus_anynana_gapdh,1,332,332
#
# Bicyclus_anynana
# Pararge_aegeria,NC_053181.1,17873394,17874779,1,N,Bicyclus_anynana_ef1,1,462,462
#
# Bicyclus_anynana
# Pararge_aegeria,NC_053194.1,712344,713120,0,N,Bicyclus_anynana_hcl,1,259,259
#
# Bicyclus_anynana
# Pararge_aegeria,NC_053208.1,10063224,10064684,0,N,Bicyclus_anynana_cat,1,487,487
#
# Bicyclus_anynana
# Pararge_aegeria,NC_053185.1,10705223,10708363,1,N,Bicyclus_anynana_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Pararge_aegeria,NC_053183.1,8818510,8819163,1,N,Bicyclus_anynana_rps5,1,218,218
# Pararge_aegeria,NC_053182.1,16434376,16434900,1,N,Bicyclus_anynana_wg,1,175,175
# Pararge_aegeria,NC_053184.1,15813827,15814345,1,N,Bicyclus_anynana_rps2,1,173,173
# Pararge_aegeria,NC_053190.1,14291871,14292860,0,N,Bicyclus_anynana_mdh,1,330,330
# Pararge_aegeria,NC_053185.1,13048460,13049683,1,N,Bicyclus_anynana_idh,1,408,408
# Pararge_aegeria,NC_053182.1,8903608,8904312,0,N,Bicyclus_anynana_ddc,1,235,235
# Pararge_aegeria,NC_053196.1,5263527,5264522,0,N,Bicyclus_anynana_gapdh,1,332,332
# Pararge_aegeria,NC_053181.1,17873394,17874779,1,N,Bicyclus_anynana_ef1,1,462,462
# Pararge_aegeria,NC_053194.1,712344,713120,0,N,Bicyclus_anynana_hcl,1,259,259
# Pararge_aegeria,NC_053208.1,10063224,10064684,0,N,Bicyclus_anynana_cat,1,487,487
# Pararge_aegeria,NC_053185.1,10705223,10708363,1,N,Bicyclus_anynana_cad,1,1047,1047
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[7], line 29
#      27 query_name = query_name_list[i]
#      28 Length_switch = "0"
# ---> 29 with open(f"{blast_location}/1.Blast_result/{species}/{species}_blast_out.txt",'r') as tblast_out:
#      30     lines_in_file = tblast_out.readlines()
#      31 #print(lines_in_file)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# NotADirectoryError: [Errno 20] Not a directory: '/mnt/h/My Drive/Circadian Rhythm Genes Project/8.For Phylogeny/3.Satyrine/1.Blast_result/desktop.ini/desktop.ini_blast_out.txt'
