# %%
def sequence_extractor(Species, Scaff, reverse_c, start, end, frame = 1, trans = 1 ):
    from Bio import SeqIO
    from Bio.Seq import Seq
    import os
    
    out_Seq = ''
    
    
    #Genome folder
    entries = os.listdir("/mnt/f/Genomes_2023-12-26/"+Species)
    
    #Get genome file from Genome folder
    for file_names  in entries:
        if ".nhr" in file_names:
            Genome_name = file_names[:-4]
            break
    
    #Read the genome file
    fasta_file = open(("/mnt/f/Genomes_2023-12-26/"+Species+"/"+Genome_name),'r')
    
    #Extract the sequence 
    for record in SeqIO.parse(fasta_file,"fasta"):
        if record.id == Scaff:
            sequence = str(record.seq)
            out_Seq = Seq(sequence[start-1:end])
            if reverse_c == 1:
                out_Seq = out_Seq.reverse_complement()
                
    if len(out_Seq) < 10000: #fixing error due to mistake in typing the coordinate, change this for longer sequence
#        print (out_Seq)
        if frame == 1 :
            out_trans = out_Seq[0:]
        if frame == 2 :
            out_trans = out_Seq[1:]
        if frame == 3 :
            out_trans = out_Seq[2:]
    else:
        print ("too long")
        assert(False)
        
        
    #    break
    fasta_file.close()
    if trans == 1:
        return (out_trans.translate())
    else:
        return(out_Seq)
#

# %%
import os
from Bio import SeqIO

# %%
#%reset -f
blast_location = "/mnt/h/My Drive/Circadian Rhythm Genes Project/8.For Phylogeny/8.Lycaenidae"
# query_species = "Pieris_brassicae"


species_list = os.listdir(f"{blast_location}/1.Blast_result")
if "desktop.ini" in species_list:
    species_list.remove("desktop.ini")


query_file = SeqIO.parse(f"{blast_location}/1.Query/query.txt", 'fasta')
query_name_list = []

for records in query_file:
    query_name_list.append(records.id)



for species in species_list:
    # print(species_name)
    # species = species_name.split(".")[1]
    header = "Species," + "Scaffold," + "Start," + "Stop," + "Complement," + "Error," + "Gene,"+ "Query_start," + "Query_stop,"+ "Query_Length\n" 
    Output_Sequence = header
    scaff = "Intial_value"
    scaff_old = "Intial_value"
    old_end = 0
    
#Run for each query in the query list
    for i in range(len(query_name_list)):
        query_name = query_name_list[i]
        Length_switch = "0"
        with open(f"{blast_location}/1.Blast_result/{species}/{species}_blast_out.txt",'r') as tblast_out:
            lines_in_file = tblast_out.readlines()
        #print(lines_in_file)

        result_section_switch = 0
        start_coor_switch = 0
        query_start_coor_switch = 0
        stop_coor_switch = 0
        error = "N"
        break_switch = 0

        start = 0
        stop = 0
        start_coor = 0
        stop_coor = 0
        query_length = 0

        for lines in lines_in_file:

#             print(lines)
            if query_name in lines:
            #Initialize that results can now be checked
                result_section_switch = 1
                query_species_split = lines.split(" ")[1].split("_")
#                 print(query_species_split)
                query_species = str(query_species_split[0]+"_"+query_species_split[1].rstrip())
                print(query_species)
            if result_section_switch == 1 and "Lambda" in lines:
            #This block indicates end of the results block in blast output
                result_section_switch == 0
                
                break

            if result_section_switch == 1:
            #While checking the result
                if "Length=" in lines and Length_switch == "0":
                #Get query length from the blast output
                    
                    query_length = int(lines.split("=")[1].rstrip())
                    
                    Length_switch = 1 #Indicated length has been acquired
                    
                if ("Score" in lines or ">" in lines) and (start_coor_switch == 1):
    #                print (lines)
                    break
        
                if ">" in lines:
                #Start of the first result
                    scaff = lines.split(" ")[0][1:] #Scaffold from the result
#                     if scaff_old != "Intial_value" and scaff_old != scaff:
#                         error = "Y"
                    scaff_old = scaff
                    
                if "Query" in lines and "=" not in lines:
                #Read the query line in output
                    if query_start_coor_switch == 0:
#                        print(lines)
                        query_start_coor = int(lines.split(" ")[2])
                        query_start_coor_switch = 1
                        #Query start coordinate fixed
            
                    query_stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting query stop coordinates for multiline result
    #                print (stop_coor)
                    
                if "Sbjct" in lines:
                #Read the blast target line
                    if start_coor_switch == 0:
                        start_coor = int(lines.split(" ")[2])
                        start_coor_switch = 1
                    stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting target stop coordinates for multiline result
                
                

        
        if break_switch == 1:
            break

        if start_coor < stop_coor:
            complement = "0" #Forward complement
            
            length = (stop_coor-start_coor)/3
            start = start_coor
            stop = stop_coor

        elif start_coor > stop_coor:
            complement = "1" #Reverse complement
            length = (-stop_coor+start_coor)/3
            start = stop_coor
            stop = start_coor

        else:
            error = "Y"
        
        
        
        

        #Check if the length of target (blast hit) is significantly smaller than query
        if length < query_length - 0.2*query_length:
            error = "Y"

        old_trans = ''
#             print(start, stop)


# #Check for Met or STOP at the start and end
#         while True and (start != 0 or stop != 0):
#             if (query_name == query_name_list[0] or query_name == query_name_list[-1]):
#                 frame = 1
#                 translated_sequence = (sequence_extractor(species, scaff, int(complement), start, stop,frame ))

#                 if translated_sequence == old_trans:
#                     break
                    
# #Check for Met at the beginning of first exon

#                 if query_name == query_name_list[0] :
#                     if translated_sequence[0] != "M":
#                         print(translated_sequence)
# #                             print(start, stop)
#                         if complement == "0":
#                             start = int(start) - 3
#                         if complement == "1":
#                             stop = int(stop) + 3
#                         old_trans = translated_sequence
#                     if "*" in translated_sequence:
#                         error = "Y"
#                         break
#                     if translated_sequence[0] == "M":
#                         break

# #Check for stop at the end of last exon

#                 if query_name == query_name_list[-1]:
#                     if translated_sequence[-1] != "*":
#                         print(translated_sequence)
# #                             print(start, stop)
#                         if complement == "0":
#                             stop = int(stop) + 3
#                         if complement == "1":
#                             start = int(start) - 3
#                         old_trans = translated_sequence
#                     if translated_sequence[-1] == "*":

#                         break
#             else:
#                 break
        
        
#Add offset at the beginning and end of each exon
#         if (start != 0 or stop != 0):
            
#             start_modifier = int(query_name.split("Frame")[1][1])
#             stop_modifier = int(query_name.split("rightoh")[1][1])
#         else:
        start_modifier = 0
        stop_modifier = 0            

        seq_length = query_length
        
        
#Get exon start and end by adding or removing codons
        
    #if not the beginning
        if query_start_coor != "1" and query_name != query_name_list[0]:
            if complement == "0":
                start = int(start) - 3*(int(query_start_coor)-1)                
            if complement == "1":
                stop = int(stop) + 3*(int(query_start_coor)-1)
    
    #For the end
        if query_stop_coor != str(seq_length) and query_name != query_name_list[-1]:
            if complement == "0":
                stop = int(stop) + 3*(int(seq_length)-int(query_stop_coor))
            if complement == "1":
                

                start = int(start) - 3*(int(seq_length)-int(query_stop_coor))
 
        
        
        
#Adding or removing 3' and 5' overhangs for forward and reverse complement
    #For forward complement
        if complement == "0":
            start = int(start) - int(start_modifier)
            stop = int(stop) +  int(stop_modifier)
#             if old_end != 0 and old_end > stop:

#                 error = "Y"
            old_end = stop

    #For reverse complement
        if complement == "1":
            start = int(start) - int(stop_modifier)
            stop = int(stop) +  int(start_modifier)
#             if old_end != 0 and old_end < stop:
#                 error = "Y"
            old_end = stop

    #Simple check for lenghth
        if start == 0 or stop == 0:
            error = "Y"
            
           
        output_format = str(species.split("\n")[0])+"," + str(scaff) +"," + str(start)+"," + str(stop)+"," + str(complement)+"," + str(error)+  ","+ str(query_name)+","+ str(query_start_coor)+","+str(query_stop_coor)+","+str(query_length)+ "\n"  
        print(output_format)
#         assert False
        Output_Sequence = Output_Sequence + output_format

    print(Output_Sequence)
    output_file = open(f"{blast_location}/1.Blast_result/{species}/{species}_coordinates.csv",'w')
    output_file.write(Output_Sequence)
    output_file.close()
# Out:
# Aricia_agestis
# Aricia_agestis,NC_056413.1,11323163,11323819,0,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Aricia_agestis,NC_056406.1,22835297,22835821,0,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Aricia_agestis,NC_056412.1,15196939,15197457,1,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Aricia_agestis,NC_056407.1,11345344,11346333,0,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Aricia_agestis,NC_056416.1,11639252,11640475,1,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Aricia_agestis,NC_056406.1,17121218,17121922,0,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Aricia_agestis,NC_056422.1,4056506,4057501,0,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Aricia_agestis,NC_056414.1,17879257,17880642,0,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Aricia_agestis,NC_056419.1,15106095,15106871,1,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Aricia_agestis,NC_056428.1,25411921,25413381,0,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Aricia_agestis,NC_056416.1,9320173,9323313,1,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Aricia_agestis,NC_056413.1,11323163,11323819,0,N,Aricia_agestis_rps5,1,219,219
# Aricia_agestis,NC_056406.1,22835297,22835821,0,N,Aricia_agestis_wg,1,175,175
# Aricia_agestis,NC_056412.1,15196939,15197457,1,N,Aricia_agestis_rps2,1,173,173
# Aricia_agestis,NC_056407.1,11345344,11346333,0,N,Aricia_agestis_mdh,1,330,330
# Aricia_agestis,NC_056416.1,11639252,11640475,1,N,Aricia_agestis_idh,1,408,408
# Aricia_agestis,NC_056406.1,17121218,17121922,0,N,Aricia_agestis_ddc,1,235,235
# Aricia_agestis,NC_056422.1,4056506,4057501,0,N,Aricia_agestis_gapdh,1,332,332
# Aricia_agestis,NC_056414.1,17879257,17880642,0,N,Aricia_agestis_ef1,1,462,462
# Aricia_agestis,NC_056419.1,15106095,15106871,1,N,Aricia_agestis_hcl,1,259,259
# Aricia_agestis,NC_056428.1,25411921,25413381,0,N,Aricia_agestis_cat,1,487,487
# Aricia_agestis,NC_056416.1,9320173,9323313,1,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Aricia_artaxerxes,OW569295.1,11855832,11856488,0,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Aricia_artaxerxes,OW569288.1,24396902,24397426,0,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Aricia_artaxerxes,OW569294.1,16170529,16171047,1,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Aricia_artaxerxes,OW569289.1,14498579,14499568,1,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Aricia_artaxerxes,OW569298.1,6145100,6146323,0,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Aricia_artaxerxes,OW569288.1,18370294,18370998,0,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Aricia_artaxerxes,OW569304.1,11279084,11280079,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Aricia_artaxerxes,OW569296.1,18766994,18768379,0,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Aricia_artaxerxes,OW569301.1,838285,839061,0,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Aricia_artaxerxes,OW569310.1,27045739,27047199,0,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Aricia_artaxerxes,OW569298.1,8595459,8598599,0,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Aricia_artaxerxes,OW569295.1,11855832,11856488,0,N,Aricia_agestis_rps5,1,219,219
# Aricia_artaxerxes,OW569288.1,24396902,24397426,0,N,Aricia_agestis_wg,1,175,175
# Aricia_artaxerxes,OW569294.1,16170529,16171047,1,N,Aricia_agestis_rps2,1,173,173
# Aricia_artaxerxes,OW569289.1,14498579,14499568,1,N,Aricia_agestis_mdh,1,330,330
# Aricia_artaxerxes,OW569298.1,6145100,6146323,0,N,Aricia_agestis_idh,1,408,408
# Aricia_artaxerxes,OW569288.1,18370294,18370998,0,N,Aricia_agestis_ddc,1,235,235
# Aricia_artaxerxes,OW569304.1,11279084,11280079,1,N,Aricia_agestis_gapdh,1,332,332
# Aricia_artaxerxes,OW569296.1,18766994,18768379,0,N,Aricia_agestis_ef1,1,462,462
# Aricia_artaxerxes,OW569301.1,838285,839061,0,N,Aricia_agestis_hcl,1,259,259
# Aricia_artaxerxes,OW569310.1,27045739,27047199,0,N,Aricia_agestis_cat,1,487,487
# Aricia_artaxerxes,OW569298.1,8595459,8598599,0,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Calycopis_cecrops,LUGF01056665.1,87069,87725,0,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Calycopis_cecrops,LUGF01057051.1,279062,279586,1,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Calycopis_cecrops,LUGF01030368.1,173077,173595,0,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Calycopis_cecrops,LUGF01016424.1,64144,65133,0,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Calycopis_cecrops,LUGF01059748.1,796615,797838,0,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Calycopis_cecrops,LUGF01050576.1,539394,540098,1,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Calycopis_cecrops,LUGF01002654.1,231377,232372,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Calycopis_cecrops,LUGF01030159.1,252676,254061,0,N,Aricia_agestis_ef1,1,461,462
#
# Aricia_agestis
# Calycopis_cecrops,LUGF01043823.1,118025,118801,1,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Calycopis_cecrops,LUGF01052489.1,99270,100730,0,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Calycopis_cecrops,LUGF01055665.1,180952,184092,0,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Calycopis_cecrops,LUGF01056665.1,87069,87725,0,N,Aricia_agestis_rps5,1,219,219
# Calycopis_cecrops,LUGF01057051.1,279062,279586,1,N,Aricia_agestis_wg,1,175,175
# Calycopis_cecrops,LUGF01030368.1,173077,173595,0,N,Aricia_agestis_rps2,1,173,173
# Calycopis_cecrops,LUGF01016424.1,64144,65133,0,N,Aricia_agestis_mdh,1,330,330
# Calycopis_cecrops,LUGF01059748.1,796615,797838,0,N,Aricia_agestis_idh,1,408,408
# Calycopis_cecrops,LUGF01050576.1,539394,540098,1,N,Aricia_agestis_ddc,1,235,235
# Calycopis_cecrops,LUGF01002654.1,231377,232372,1,N,Aricia_agestis_gapdh,1,332,332
# Calycopis_cecrops,LUGF01030159.1,252676,254061,0,N,Aricia_agestis_ef1,1,461,462
# Calycopis_cecrops,LUGF01043823.1,118025,118801,1,N,Aricia_agestis_hcl,1,259,259
# Calycopis_cecrops,LUGF01052489.1,99270,100730,0,N,Aricia_agestis_cat,1,487,487
# Calycopis_cecrops,LUGF01055665.1,180952,184092,0,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Celastrina_argiolus,LR994584.1,8662888,8663547,1,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Celastrina_argiolus,LR994577.1,4371118,4371642,0,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Celastrina_argiolus,LR994601.1,3875465,3875983,1,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Celastrina_argiolus,LR994579.1,11871233,11872222,0,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Celastrina_argiolus,LR994587.1,13313974,13315197,1,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Celastrina_argiolus,LR994577.1,11618191,11618895,1,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Celastrina_argiolus,LR994595.1,12318669,12319664,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Celastrina_argiolus,LR994585.1,3281595,3282980,0,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Celastrina_argiolus,LR994589.1,803029,803805,0,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Celastrina_argiolus,LR994583.1,7219418,7220878,0,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Celastrina_argiolus,LR994587.1,10751652,10754792,1,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Celastrina_argiolus,LR994584.1,8662888,8663547,1,N,Aricia_agestis_rps5,1,219,219
# Celastrina_argiolus,LR994577.1,4371118,4371642,0,N,Aricia_agestis_wg,1,175,175
# Celastrina_argiolus,LR994601.1,3875465,3875983,1,N,Aricia_agestis_rps2,1,173,173
# Celastrina_argiolus,LR994579.1,11871233,11872222,0,N,Aricia_agestis_mdh,1,330,330
# Celastrina_argiolus,LR994587.1,13313974,13315197,1,N,Aricia_agestis_idh,1,408,408
# Celastrina_argiolus,LR994577.1,11618191,11618895,1,N,Aricia_agestis_ddc,1,235,235
# Celastrina_argiolus,LR994595.1,12318669,12319664,1,N,Aricia_agestis_gapdh,1,332,332
# Celastrina_argiolus,LR994585.1,3281595,3282980,0,N,Aricia_agestis_ef1,1,462,462
# Celastrina_argiolus,LR994589.1,803029,803805,0,N,Aricia_agestis_hcl,1,259,259
# Celastrina_argiolus,LR994583.1,7219418,7220878,0,N,Aricia_agestis_cat,1,487,487
# Celastrina_argiolus,LR994587.1,10751652,10754792,1,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Cyaniris_semiargus,LR994554.1,11665515,11666171,0,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Cyaniris_semiargus,LR994546.1,5416313,5416837,1,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Cyaniris_semiargus,LR994553.1,16179195,16179713,1,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Cyaniris_semiargus,LR994548.1,12502370,12503359,1,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Cyaniris_semiargus,LR994557.1,12047827,12049050,1,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Cyaniris_semiargus,LR994546.1,11052783,11053487,1,N,Aricia_agestis_ddc,1,234,235
# Aricia_agestis
# Cyaniris_semiargus,LR994564.1,11020125,11021120,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Cyaniris_semiargus,LR994555.1,18654888,18656273,0,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Cyaniris_semiargus,LR994561.1,15439375,15440151,1,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Cyaniris_semiargus,LR994547.1,7485365,7486825,0,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Cyaniris_semiargus,LR994557.1,9625163,9628303,1,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Cyaniris_semiargus,LR994554.1,11665515,11666171,0,N,Aricia_agestis_rps5,1,219,219
# Cyaniris_semiargus,LR994546.1,5416313,5416837,1,N,Aricia_agestis_wg,1,175,175
# Cyaniris_semiargus,LR994553.1,16179195,16179713,1,N,Aricia_agestis_rps2,1,173,173
# Cyaniris_semiargus,LR994548.1,12502370,12503359,1,N,Aricia_agestis_mdh,1,330,330
# Cyaniris_semiargus,LR994557.1,12047827,12049050,1,N,Aricia_agestis_idh,1,408,408
# Cyaniris_semiargus,LR994546.1,11052783,11053487,1,N,Aricia_agestis_ddc,1,234,235
# Cyaniris_semiargus,LR994564.1,11020125,11021120,1,N,Aricia_agestis_gapdh,1,332,332
# Cyaniris_semiargus,LR994555.1,18654888,18656273,0,N,Aricia_agestis_ef1,1,462,462
# Cyaniris_semiargus,LR994561.1,15439375,15440151,1,N,Aricia_agestis_hcl,1,259,259
# Cyaniris_semiargus,LR994547.1,7485365,7486825,0,N,Aricia_agestis_cat,1,487,487
# Cyaniris_semiargus,LR994557.1,9625163,9628303,1,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Cyclargus_thomasi,JAOTAV010036077.1,15573,16229,0,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Cyclargus_thomasi,JAOTAV010000001.1,411879,412403,0,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Cyclargus_thomasi,JAOTAV010000028.1,186399,186917,1,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Cyclargus_thomasi,JAOTAV010026371.1,13044,14033,1,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Cyclargus_thomasi,JAOTAV010001635.1,32434,33657,1,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Cyclargus_thomasi,JAOTAV010068983.1,6111,6815,0,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Cyclargus_thomasi,JAOTAV010000007.1,1533437,1534432,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Cyclargus_thomasi,JAOTAV010000012.1,137847,139232,0,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Cyclargus_thomasi,JAOTAV010000003.1,50370,51146,0,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Cyclargus_thomasi,JAOTAV010000025.1,1491984,1493444,1,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Cyclargus_thomasi,JAOTAV010012446.1,17554,20694,1,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Cyclargus_thomasi,JAOTAV010036077.1,15573,16229,0,N,Aricia_agestis_rps5,1,219,219
# Cyclargus_thomasi,JAOTAV010000001.1,411879,412403,0,N,Aricia_agestis_wg,1,175,175
# Cyclargus_thomasi,JAOTAV010000028.1,186399,186917,1,N,Aricia_agestis_rps2,1,173,173
# Cyclargus_thomasi,JAOTAV010026371.1,13044,14033,1,N,Aricia_agestis_mdh,1,330,330
# Cyclargus_thomasi,JAOTAV010001635.1,32434,33657,1,N,Aricia_agestis_idh,1,408,408
# Cyclargus_thomasi,JAOTAV010068983.1,6111,6815,0,N,Aricia_agestis_ddc,1,235,235
# Cyclargus_thomasi,JAOTAV010000007.1,1533437,1534432,1,N,Aricia_agestis_gapdh,1,332,332
# Cyclargus_thomasi,JAOTAV010000012.1,137847,139232,0,N,Aricia_agestis_ef1,1,462,462
# Cyclargus_thomasi,JAOTAV010000003.1,50370,51146,0,N,Aricia_agestis_hcl,1,259,259
# Cyclargus_thomasi,JAOTAV010000025.1,1491984,1493444,1,N,Aricia_agestis_cat,1,487,487
# Cyclargus_thomasi,JAOTAV010012446.1,17554,20694,1,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Eumaeus_atala,JAFELO010001500.1,572387,573043,1,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Eumaeus_atala,JAFELO010000644.1,36395,36919,0,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Eumaeus_atala,JAFELO010000143.1,45669,46187,0,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Eumaeus_atala,JAFELO010000453.1,266974,267963,1,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Eumaeus_atala,JAFELO010008651.1,607421,608644,0,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Eumaeus_atala,JAFELO010000362.1,926495,927199,1,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Eumaeus_atala,JAFELO010000106.1,370147,371142,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Eumaeus_atala,JAFELO010000036.1,1372861,1374246,0,N,Aricia_agestis_ef1,1,461,462
#
# Aricia_agestis
# Eumaeus_atala,JAFELO010000197.1,508478,509254,1,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Eumaeus_atala,JAFELO010000086.1,271703,273163,1,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Eumaeus_atala,JAFELO010000358.1,306670,309810,1,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Eumaeus_atala,JAFELO010001500.1,572387,573043,1,N,Aricia_agestis_rps5,1,219,219
# Eumaeus_atala,JAFELO010000644.1,36395,36919,0,N,Aricia_agestis_wg,1,175,175
# Eumaeus_atala,JAFELO010000143.1,45669,46187,0,N,Aricia_agestis_rps2,1,173,173
# Eumaeus_atala,JAFELO010000453.1,266974,267963,1,N,Aricia_agestis_mdh,1,330,330
# Eumaeus_atala,JAFELO010008651.1,607421,608644,0,N,Aricia_agestis_idh,1,408,408
# Eumaeus_atala,JAFELO010000362.1,926495,927199,1,N,Aricia_agestis_ddc,1,235,235
# Eumaeus_atala,JAFELO010000106.1,370147,371142,1,N,Aricia_agestis_gapdh,1,332,332
# Eumaeus_atala,JAFELO010000036.1,1372861,1374246,0,N,Aricia_agestis_ef1,1,461,462
# Eumaeus_atala,JAFELO010000197.1,508478,509254,1,N,Aricia_agestis_hcl,1,259,259
# Eumaeus_atala,JAFELO010000086.1,271703,273163,1,N,Aricia_agestis_cat,1,487,487
# Eumaeus_atala,JAFELO010000358.1,306670,309810,1,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Glaucopsyche_alexis,FR990050.1,10771866,10772522,1,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Glaucopsyche_alexis,FR990043.1,5403072,5403596,0,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Glaucopsyche_alexis,FR990049.1,6667530,6668048,0,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Glaucopsyche_alexis,FR990047.1,15474761,15475750,0,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Glaucopsyche_alexis,FR990053.1,16801365,16802588,1,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Glaucopsyche_alexis,FR990043.1,15090381,15091085,1,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Glaucopsyche_alexis,FR990062.1,15462354,15463349,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Glaucopsyche_alexis,FR990051.1,22433171,22434556,1,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Glaucopsyche_alexis,FR990059.1,21057312,21058088,1,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Glaucopsyche_alexis,FR990042.1,8569300,8570760,0,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Glaucopsyche_alexis,FR990053.1,13642792,13645932,1,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Glaucopsyche_alexis,FR990050.1,10771866,10772522,1,N,Aricia_agestis_rps5,1,219,219
# Glaucopsyche_alexis,FR990043.1,5403072,5403596,0,N,Aricia_agestis_wg,1,175,175
# Glaucopsyche_alexis,FR990049.1,6667530,6668048,0,N,Aricia_agestis_rps2,1,173,173
# Glaucopsyche_alexis,FR990047.1,15474761,15475750,0,N,Aricia_agestis_mdh,1,330,330
# Glaucopsyche_alexis,FR990053.1,16801365,16802588,1,N,Aricia_agestis_idh,1,408,408
# Glaucopsyche_alexis,FR990043.1,15090381,15091085,1,N,Aricia_agestis_ddc,1,235,235
# Glaucopsyche_alexis,FR990062.1,15462354,15463349,1,N,Aricia_agestis_gapdh,1,332,332
# Glaucopsyche_alexis,FR990051.1,22433171,22434556,1,N,Aricia_agestis_ef1,1,462,462
# Glaucopsyche_alexis,FR990059.1,21057312,21058088,1,N,Aricia_agestis_hcl,1,259,259
# Glaucopsyche_alexis,FR990042.1,8569300,8570760,0,N,Aricia_agestis_cat,1,487,487
# Glaucopsyche_alexis,FR990053.1,13642792,13645932,1,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Helleia_helle,OY971421.1,15005450,15006106,0,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Helleia_helle,OY971414.1,29174719,29175243,1,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Helleia_helle,OY971423.1,5409153,5409671,0,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Helleia_helle,OY971418.1,15627856,15628845,0,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Helleia_helle,OY971424.1,7843383,7844606,0,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Helleia_helle,OY971414.1,20358084,20358788,0,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Helleia_helle,OY971432.1,13945207,13946202,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Helleia_helle,OY971422.1,23287371,23288756,0,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Helleia_helle,OY971428.1,1123683,1124459,0,N,Aricia_agestis_hcl,1,259,259
# Aricia_agestis
# Helleia_helle,OY971420.1,18195134,18196594,1,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Helleia_helle,OY971424.1,10790380,10793520,0,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Helleia_helle,OY971421.1,15005450,15006106,0,N,Aricia_agestis_rps5,1,219,219
# Helleia_helle,OY971414.1,29174719,29175243,1,N,Aricia_agestis_wg,1,175,175
# Helleia_helle,OY971423.1,5409153,5409671,0,N,Aricia_agestis_rps2,1,173,173
# Helleia_helle,OY971418.1,15627856,15628845,0,N,Aricia_agestis_mdh,1,330,330
# Helleia_helle,OY971424.1,7843383,7844606,0,N,Aricia_agestis_idh,1,408,408
# Helleia_helle,OY971414.1,20358084,20358788,0,N,Aricia_agestis_ddc,1,235,235
# Helleia_helle,OY971432.1,13945207,13946202,1,N,Aricia_agestis_gapdh,1,332,332
# Helleia_helle,OY971422.1,23287371,23288756,0,N,Aricia_agestis_ef1,1,462,462
# Helleia_helle,OY971428.1,1123683,1124459,0,N,Aricia_agestis_hcl,1,259,259
# Helleia_helle,OY971420.1,18195134,18196594,1,N,Aricia_agestis_cat,1,487,487
# Helleia_helle,OY971424.1,10790380,10793520,0,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Lycaena_phlaeas,HG995170.1,7777760,7778416,1,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Lycaena_phlaeas,HG995163.1,22596634,22597158,1,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Lycaena_phlaeas,HG995174.1,14078695,14079213,1,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Lycaena_phlaeas,HG995166.1,9486787,9487776,1,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Lycaena_phlaeas,HG995172.1,11650193,11651416,1,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Lycaena_phlaeas,HG995163.1,15726917,15727621,0,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Lycaena_phlaeas,HG995181.1,3963889,3964884,0,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Lycaena_phlaeas,HG995171.1,18244536,18245921,0,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Lycaena_phlaeas,HG995176.1,633263,634039,0,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Lycaena_phlaeas,HG995168.1,14294878,14296338,1,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Lycaena_phlaeas,HG995172.1,9337373,9340513,1,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Lycaena_phlaeas,HG995170.1,7777760,7778416,1,N,Aricia_agestis_rps5,1,219,219
# Lycaena_phlaeas,HG995163.1,22596634,22597158,1,N,Aricia_agestis_wg,1,175,175
# Lycaena_phlaeas,HG995174.1,14078695,14079213,1,N,Aricia_agestis_rps2,1,173,173
# Lycaena_phlaeas,HG995166.1,9486787,9487776,1,N,Aricia_agestis_mdh,1,330,330
# Lycaena_phlaeas,HG995172.1,11650193,11651416,1,N,Aricia_agestis_idh,1,408,408
# Lycaena_phlaeas,HG995163.1,15726917,15727621,0,N,Aricia_agestis_ddc,1,235,235
# Lycaena_phlaeas,HG995181.1,3963889,3964884,0,N,Aricia_agestis_gapdh,1,332,332
# Lycaena_phlaeas,HG995171.1,18244536,18245921,0,N,Aricia_agestis_ef1,1,462,462
# Lycaena_phlaeas,HG995176.1,633263,634039,0,N,Aricia_agestis_hcl,1,259,259
# Lycaena_phlaeas,HG995168.1,14294878,14296338,1,N,Aricia_agestis_cat,1,487,487
# Lycaena_phlaeas,HG995172.1,9337373,9340513,1,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Lysandra_bellargus,HG995333.1,2542031,2542687,0,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Lysandra_bellargus,HG995349.1,6331110,6331634,1,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Lysandra_bellargus,HG995338.1,5884502,5885020,1,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Lysandra_bellargus,HG995326.1,12860083,12861072,0,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Lysandra_bellargus,HG995334.1,4678499,4679722,1,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Lysandra_bellargus,HG995346.1,7160846,7161550,0,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Lysandra_bellargus,CAJOSW010000075.1,15310,16305,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Lysandra_bellargus,HG995328.1,11825263,11826648,0,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Lysandra_bellargus,HG995353.1,774862,775638,0,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Lysandra_bellargus,HG995319.1,20420868,20422328,1,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Lysandra_bellargus,HG995334.1,1863757,1866897,1,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Lysandra_bellargus,HG995333.1,2542031,2542687,0,N,Aricia_agestis_rps5,1,219,219
# Lysandra_bellargus,HG995349.1,6331110,6331634,1,N,Aricia_agestis_wg,1,175,175
# Lysandra_bellargus,HG995338.1,5884502,5885020,1,N,Aricia_agestis_rps2,1,173,173
# Lysandra_bellargus,HG995326.1,12860083,12861072,0,N,Aricia_agestis_mdh,1,330,330
# Lysandra_bellargus,HG995334.1,4678499,4679722,1,N,Aricia_agestis_idh,1,408,408
# Lysandra_bellargus,HG995346.1,7160846,7161550,0,N,Aricia_agestis_ddc,1,235,235
# Lysandra_bellargus,CAJOSW010000075.1,15310,16305,1,N,Aricia_agestis_gapdh,1,332,332
# Lysandra_bellargus,HG995328.1,11825263,11826648,0,N,Aricia_agestis_ef1,1,462,462
# Lysandra_bellargus,HG995353.1,774862,775638,0,N,Aricia_agestis_hcl,1,259,259
# Lysandra_bellargus,HG995319.1,20420868,20422328,1,N,Aricia_agestis_cat,1,487,487
# Lysandra_bellargus,HG995334.1,1863757,1866897,1,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Lysandra_coridon,HG992094.1,3172429,3173085,1,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Lysandra_coridon,HG992117.1,434059,434583,1,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Lysandra_coridon,HG992091.1,5301878,5302396,0,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Lysandra_coridon,HG992062.1,1814412,1815401,1,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Lysandra_coridon,HG992087.1,1279144,1280367,0,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Lysandra_coridon,HG992133.1,2024327,2025031,0,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Lysandra_coridon,HG992135.1,3377663,3378658,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Lysandra_coridon,HG992073.1,798977,800362,1,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Lysandra_coridon,HG992125.1,3945567,3946343,1,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Lysandra_coridon,HG992055.1,9793160,9794620,1,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Lysandra_coridon,HG992087.1,4130376,4133516,0,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Lysandra_coridon,HG992094.1,3172429,3173085,1,N,Aricia_agestis_rps5,1,219,219
# Lysandra_coridon,HG992117.1,434059,434583,1,N,Aricia_agestis_wg,1,175,175
# Lysandra_coridon,HG992091.1,5301878,5302396,0,N,Aricia_agestis_rps2,1,173,173
# Lysandra_coridon,HG992062.1,1814412,1815401,1,N,Aricia_agestis_mdh,1,330,330
# Lysandra_coridon,HG992087.1,1279144,1280367,0,N,Aricia_agestis_idh,1,408,408
# Lysandra_coridon,HG992133.1,2024327,2025031,0,N,Aricia_agestis_ddc,1,235,235
# Lysandra_coridon,HG992135.1,3377663,3378658,1,N,Aricia_agestis_gapdh,1,332,332
# Lysandra_coridon,HG992073.1,798977,800362,1,N,Aricia_agestis_ef1,1,462,462
# Lysandra_coridon,HG992125.1,3945567,3946343,1,N,Aricia_agestis_hcl,1,259,259
# Lysandra_coridon,HG992055.1,9793160,9794620,1,N,Aricia_agestis_cat,1,487,487
# Lysandra_coridon,HG992087.1,4130376,4133516,0,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Phengaris_arion,OY751440.1,14003204,14003860,0,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Phengaris_arion,OY751432.1,36543459,36543983,1,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Phengaris_arion,OY751438.1,5755310,5755828,0,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Phengaris_arion,OY751431.1,34561037,34562026,1,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Phengaris_arion,OY751442.1,7103556,7104779,0,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Phengaris_arion,OY751432.1,28440287,28440991,0,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Phengaris_arion,OY751451.1,5139696,5140691,0,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Phengaris_arion,OY751441.1,3685988,3687373,0,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Phengaris_arion,OY751445.1,18291938,18292714,1,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Phengaris_arion,OY751437.1,8080277,8081737,0,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Phengaris_arion,OY751442.1,9605720,9608860,0,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Phengaris_arion,OY751440.1,14003204,14003860,0,N,Aricia_agestis_rps5,1,219,219
# Phengaris_arion,OY751432.1,36543459,36543983,1,N,Aricia_agestis_wg,1,175,175
# Phengaris_arion,OY751438.1,5755310,5755828,0,N,Aricia_agestis_rps2,1,173,173
# Phengaris_arion,OY751431.1,34561037,34562026,1,N,Aricia_agestis_mdh,1,330,330
# Phengaris_arion,OY751442.1,7103556,7104779,0,N,Aricia_agestis_idh,1,408,408
# Phengaris_arion,OY751432.1,28440287,28440991,0,N,Aricia_agestis_ddc,1,235,235
# Phengaris_arion,OY751451.1,5139696,5140691,0,N,Aricia_agestis_gapdh,1,332,332
# Phengaris_arion,OY751441.1,3685988,3687373,0,N,Aricia_agestis_ef1,1,462,462
# Phengaris_arion,OY751445.1,18291938,18292714,1,N,Aricia_agestis_hcl,1,259,259
# Phengaris_arion,OY751437.1,8080277,8081737,0,N,Aricia_agestis_cat,1,487,487
# Phengaris_arion,OY751442.1,9605720,9608860,0,N,Aricia_agestis_cad,1,1047,1047
# Aricia_agestis
# Plebejus_argus,FR989934.1,9994602,9995258,0,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Plebejus_argus,FR989927.1,21549262,21549786,1,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Plebejus_argus,FR989936.1,3756696,3757214,0,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Plebejus_argus,FR989929.1,10016217,10017206,1,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Plebejus_argus,FR989938.1,10603452,10604675,1,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Plebejus_argus,FR989927.1,15080416,15081120,0,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Plebejus_argus,FR989945.1,3641732,3642727,0,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Plebejus_argus,FR989935.1,567507,568892,1,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Plebejus_argus,FR989941.1,563597,564373,0,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Plebejus_argus,FR989932.1,13500878,13502338,1,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Plebejus_argus,FR989938.1,8498000,8501140,1,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Plebejus_argus,FR989934.1,9994602,9995258,0,N,Aricia_agestis_rps5,1,219,219
# Plebejus_argus,FR989927.1,21549262,21549786,1,N,Aricia_agestis_wg,1,175,175
# Plebejus_argus,FR989936.1,3756696,3757214,0,N,Aricia_agestis_rps2,1,173,173
# Plebejus_argus,FR989929.1,10016217,10017206,1,N,Aricia_agestis_mdh,1,330,330
# Plebejus_argus,FR989938.1,10603452,10604675,1,N,Aricia_agestis_idh,1,408,408
# Plebejus_argus,FR989927.1,15080416,15081120,0,N,Aricia_agestis_ddc,1,235,235
# Plebejus_argus,FR989945.1,3641732,3642727,0,N,Aricia_agestis_gapdh,1,332,332
# Plebejus_argus,FR989935.1,567507,568892,1,N,Aricia_agestis_ef1,1,462,462
# Plebejus_argus,FR989941.1,563597,564373,0,N,Aricia_agestis_hcl,1,259,259
# Plebejus_argus,FR989932.1,13500878,13502338,1,N,Aricia_agestis_cat,1,487,487
# Plebejus_argus,FR989938.1,8498000,8501140,1,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Polyommatus_icarus,OW569328.1,9117773,9118429,1,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Polyommatus_icarus,OW569321.1,5929314,5929838,1,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Polyommatus_icarus,OW569326.1,18607757,18608275,1,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Polyommatus_icarus,OW569324.1,12652658,12653647,0,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Polyommatus_icarus,OW569332.1,7016476,7017699,0,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Polyommatus_icarus,OW569321.1,11778915,11779619,1,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Polyommatus_icarus,OW569338.1,13242698,13243693,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Polyommatus_icarus,OW569329.1,808799,810184,1,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Polyommatus_icarus,OW569334.1,865826,866602,0,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Polyommatus_icarus,OW569320.1,21379999,21381459,0,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Polyommatus_icarus,OW569332.1,9836485,9839625,0,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Polyommatus_icarus,OW569328.1,9117773,9118429,1,N,Aricia_agestis_rps5,1,219,219
# Polyommatus_icarus,OW569321.1,5929314,5929838,1,N,Aricia_agestis_wg,1,175,175
# Polyommatus_icarus,OW569326.1,18607757,18608275,1,N,Aricia_agestis_rps2,1,173,173
# Polyommatus_icarus,OW569324.1,12652658,12653647,0,N,Aricia_agestis_mdh,1,330,330
# Polyommatus_icarus,OW569332.1,7016476,7017699,0,N,Aricia_agestis_idh,1,408,408
# Polyommatus_icarus,OW569321.1,11778915,11779619,1,N,Aricia_agestis_ddc,1,235,235
# Polyommatus_icarus,OW569338.1,13242698,13243693,1,N,Aricia_agestis_gapdh,1,332,332
# Polyommatus_icarus,OW569329.1,808799,810184,1,N,Aricia_agestis_ef1,1,462,462
# Polyommatus_icarus,OW569334.1,865826,866602,0,N,Aricia_agestis_hcl,1,259,259
# Polyommatus_icarus,OW569320.1,21379999,21381459,0,N,Aricia_agestis_cat,1,487,487
# Polyommatus_icarus,OW569332.1,9836485,9839625,0,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Polyommatus_iphigenia,OY730184.1,31805158,31805814,1,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Polyommatus_iphigenia,OY730189.1,28081380,28081904,0,N,Aricia_agestis_wg,1,175,175
#
# Aricia_agestis
# Polyommatus_iphigenia,OY730180.1,27956733,27957251,1,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Polyommatus_iphigenia,OY730188.1,20093732,20094721,0,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Polyommatus_iphigenia,OY730183.1,8689805,8691028,1,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Polyommatus_iphigenia,OY730189.1,21580259,21580963,0,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Polyommatus_iphigenia,OY730183.1,39078907,39079902,0,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Polyommatus_iphigenia,OY730177.1,21419622,21421007,0,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Polyommatus_iphigenia,OY730182.1,20850170,20850946,1,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Polyommatus_iphigenia,OY730178.1,21916803,21918263,0,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Polyommatus_iphigenia,OY730189.1,18089359,18092499,1,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Polyommatus_iphigenia,OY730184.1,31805158,31805814,1,N,Aricia_agestis_rps5,1,219,219
# Polyommatus_iphigenia,OY730189.1,28081380,28081904,0,N,Aricia_agestis_wg,1,175,175
# Polyommatus_iphigenia,OY730180.1,27956733,27957251,1,N,Aricia_agestis_rps2,1,173,173
# Polyommatus_iphigenia,OY730188.1,20093732,20094721,0,N,Aricia_agestis_mdh,1,330,330
# Polyommatus_iphigenia,OY730183.1,8689805,8691028,1,N,Aricia_agestis_idh,1,408,408
# Polyommatus_iphigenia,OY730189.1,21580259,21580963,0,N,Aricia_agestis_ddc,1,235,235
# Polyommatus_iphigenia,OY730183.1,39078907,39079902,0,N,Aricia_agestis_gapdh,1,332,332
# Polyommatus_iphigenia,OY730177.1,21419622,21421007,0,N,Aricia_agestis_ef1,1,462,462
# Polyommatus_iphigenia,OY730182.1,20850170,20850946,1,N,Aricia_agestis_hcl,1,259,259
# Polyommatus_iphigenia,OY730178.1,21916803,21918263,0,N,Aricia_agestis_cat,1,487,487
# Polyommatus_iphigenia,OY730189.1,18089359,18092499,1,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Calephelis_nemesis,NJDD01003967.1,239222,239878,1,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Calephelis_nemesis,NJDD01003703.1,167784,168308,1,N,Aricia_agestis_wg,2,175,175
#
# Aricia_agestis
# Calephelis_nemesis,NJDD01002832.1,4650,5168,1,N,Aricia_agestis_rps2,1,173,173
#
# Aricia_agestis
# Calephelis_nemesis,NJDD01011805.1,104794,105783,0,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Calephelis_nemesis,NJDD01001033.1,131656,132879,1,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Calephelis_nemesis,NJDD01001204.1,266957,267661,0,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Calephelis_nemesis,NJDD01007232.1,29132,30127,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Calephelis_nemesis,NJDD01000376.1,339882,341267,1,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Calephelis_nemesis,NJDD01000387.1,550036,550812,0,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Calephelis_nemesis,NJDD01001107.1,33671,35131,0,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Calephelis_nemesis,NJDD01002477.1,164825,167959,1,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Calephelis_nemesis,NJDD01003967.1,239222,239878,1,N,Aricia_agestis_rps5,1,219,219
# Calephelis_nemesis,NJDD01003703.1,167784,168308,1,N,Aricia_agestis_wg,2,175,175
# Calephelis_nemesis,NJDD01002832.1,4650,5168,1,N,Aricia_agestis_rps2,1,173,173
# Calephelis_nemesis,NJDD01011805.1,104794,105783,0,N,Aricia_agestis_mdh,1,330,330
# Calephelis_nemesis,NJDD01001033.1,131656,132879,1,N,Aricia_agestis_idh,1,408,408
# Calephelis_nemesis,NJDD01001204.1,266957,267661,0,N,Aricia_agestis_ddc,1,235,235
# Calephelis_nemesis,NJDD01007232.1,29132,30127,1,N,Aricia_agestis_gapdh,1,332,332
# Calephelis_nemesis,NJDD01000376.1,339882,341267,1,N,Aricia_agestis_ef1,1,462,462
# Calephelis_nemesis,NJDD01000387.1,550036,550812,0,N,Aricia_agestis_hcl,1,259,259
# Calephelis_nemesis,NJDD01001107.1,33671,35131,0,N,Aricia_agestis_cat,1,487,487
# Calephelis_nemesis,NJDD01002477.1,164825,167959,1,N,Aricia_agestis_cad,1,1047,1047
#
# Aricia_agestis
# Calephelis_virginiensis,NJDC01030411.1,235692,236348,0,N,Aricia_agestis_rps5,1,219,219
#
# Aricia_agestis
# Calephelis_virginiensis,NJDC01000384.1,102347,102871,0,N,Aricia_agestis_wg,2,175,175
#
# Aricia_agestis
# Calephelis_virginiensis,NJDC01008229.1,33634,34152,0,N,Aricia_agestis_rps2,1,173,173
# Aricia_agestis
# Calephelis_virginiensis,NJDC01001726.1,129045,130034,1,N,Aricia_agestis_mdh,1,330,330
#
# Aricia_agestis
# Calephelis_virginiensis,NJDC01010377.1,11927,13150,0,N,Aricia_agestis_idh,1,408,408
#
# Aricia_agestis
# Calephelis_virginiensis,NJDC01001975.1,312838,313542,1,N,Aricia_agestis_ddc,1,235,235
#
# Aricia_agestis
# Calephelis_virginiensis,NJDC01004103.1,7547,8542,1,N,Aricia_agestis_gapdh,1,332,332
#
# Aricia_agestis
# Calephelis_virginiensis,NJDC01005918.1,151996,153381,0,N,Aricia_agestis_ef1,1,462,462
#
# Aricia_agestis
# Calephelis_virginiensis,NJDC01003747.1,103095,103871,0,N,Aricia_agestis_hcl,1,259,259
#
# Aricia_agestis
# Calephelis_virginiensis,NJDC01058095.1,304084,305544,1,N,Aricia_agestis_cat,1,487,487
#
# Aricia_agestis
# Calephelis_virginiensis,NJDC01006117.1,233179,236313,1,N,Aricia_agestis_cad,1,1047,1047
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Calephelis_virginiensis,NJDC01030411.1,235692,236348,0,N,Aricia_agestis_rps5,1,219,219
# Calephelis_virginiensis,NJDC01000384.1,102347,102871,0,N,Aricia_agestis_wg,2,175,175
# Calephelis_virginiensis,NJDC01008229.1,33634,34152,0,N,Aricia_agestis_rps2,1,173,173
# Calephelis_virginiensis,NJDC01001726.1,129045,130034,1,N,Aricia_agestis_mdh,1,330,330
# Calephelis_virginiensis,NJDC01010377.1,11927,13150,0,N,Aricia_agestis_idh,1,408,408
# Calephelis_virginiensis,NJDC01001975.1,312838,313542,1,N,Aricia_agestis_ddc,1,235,235
# Calephelis_virginiensis,NJDC01004103.1,7547,8542,1,N,Aricia_agestis_gapdh,1,332,332
# Calephelis_virginiensis,NJDC01005918.1,151996,153381,0,N,Aricia_agestis_ef1,1,462,462
# Calephelis_virginiensis,NJDC01003747.1,103095,103871,0,N,Aricia_agestis_hcl,1,259,259
# Calephelis_virginiensis,NJDC01058095.1,304084,305544,1,N,Aricia_agestis_cat,1,487,487
# Calephelis_virginiensis,NJDC01006117.1,233179,236313,1,N,Aricia_agestis_cad,1,1047,1047
