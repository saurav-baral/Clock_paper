# %%
def sequence_extractor(Species, Scaff, reverse_c, start, end, frame = 1, trans = 1 ):
    from Bio import SeqIO
    from Bio.Seq import Seq
    import os
    
    out_Seq = ''
    
    
    #Genome folder
    entries = os.listdir("/mnt/f/Genomes_2023-12-26/"+Species)
    
    #Get genome file from Genome folder
    for file_names  in entries:
        if ".nhr" in file_names:
            Genome_name = file_names[:-4]
            break
    
    #Read the genome file
    fasta_file = open(("/mnt/f/Genomes_2023-12-26/"+Species+"/"+Genome_name),'r')
    
    #Extract the sequence 
    for record in SeqIO.parse(fasta_file,"fasta"):
        if record.id == Scaff:
            sequence = str(record.seq)
            out_Seq = Seq(sequence[start-1:end])
            if reverse_c == 1:
                out_Seq = out_Seq.reverse_complement()
                
    if len(out_Seq) < 10000: #fixing error due to mistake in typing the coordinate, change this for longer sequence
#        print (out_Seq)
        if frame == 1 :
            out_trans = out_Seq[0:]
        if frame == 2 :
            out_trans = out_Seq[1:]
        if frame == 3 :
            out_trans = out_Seq[2:]
    else:
        print ("too long")
        assert(False)
        
        
    #    break
    fasta_file.close()
    if trans == 1:
        return (out_trans.translate())
    else:
        return(out_Seq)
#

# %%
import os
from Bio import SeqIO

# %%
#%reset -f
blast_location = "/mnt/h/My Drive/Circadian Rhythm Genes Project/8.For Phylogeny/4.Pierinae"
query_species = "Pieris_brassicae"


species_list = os.listdir(f"{blast_location}/1.Blast_result")
if "desktop.ini" in species_list:
    species_list.remove("desktop.ini")


query_file = SeqIO.parse(f"{blast_location}/1.Query/query.txt", 'fasta')
query_name_list = []

for records in query_file:
    query_name_list.append(records.id)



for species in species_list:
    # print(species_name)
    # species = species_name.split(".")[1]
    header = "Species," + "Scaffold," + "Start," + "Stop," + "Complement," + "Error," + "Gene,"+ "Query_start," + "Query_stop,"+ "Query_Length\n" 
    Output_Sequence = header
    scaff = "Intial_value"
    scaff_old = "Intial_value"
    old_end = 0
    
#Run for each query in the query list
    for i in range(len(query_name_list)):
        query_name = query_name_list[i]
        Length_switch = "0"
        with open(f"{blast_location}/1.Blast_result/{species}/{species}_blast_out.txt",'r') as tblast_out:
            lines_in_file = tblast_out.readlines()
        #print(lines_in_file)

        result_section_switch = 0
        start_coor_switch = 0
        query_start_coor_switch = 0
        stop_coor_switch = 0
        error = "N"
        break_switch = 0

        start = 0
        stop = 0
        start_coor = 0
        stop_coor = 0
        query_length = 0

        for lines in lines_in_file:

#             print(lines)
            if query_name in lines:
            #Initialize that results can now be checked
                result_section_switch = 1
                query_species_split = lines.split(" ")[1].split("_")
#                 print(query_species_split)
                query_species = str(query_species_split[0]+"_"+query_species_split[1].rstrip())
                print(query_species)
            if result_section_switch == 1 and "Lambda" in lines:
            #This block indicates end of the results block in blast output
                result_section_switch == 0
                
                break

            if result_section_switch == 1:
            #While checking the result
                if "Length=" in lines and Length_switch == "0":
                #Get query length from the blast output
                    
                    query_length = int(lines.split("=")[1].rstrip())
                    
                    Length_switch = 1 #Indicated length has been acquired
                    
                if ("Score" in lines or ">" in lines) and (start_coor_switch == 1):
    #                print (lines)
                    break
        
                if ">" in lines:
                #Start of the first result
                    scaff = lines.split(" ")[0][1:] #Scaffold from the result
#                     if scaff_old != "Intial_value" and scaff_old != scaff:
#                         error = "Y"
                    scaff_old = scaff
                    
                if "Query" in lines and "=" not in lines:
                #Read the query line in output
                    if query_start_coor_switch == 0:
#                        print(lines)
                        query_start_coor = int(lines.split(" ")[2])
                        query_start_coor_switch = 1
                        #Query start coordinate fixed
            
                    query_stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting query stop coordinates for multiline result
    #                print (stop_coor)
                    
                if "Sbjct" in lines:
                #Read the blast target line
                    if start_coor_switch == 0:
                        start_coor = int(lines.split(" ")[2])
                        start_coor_switch = 1
                    stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting target stop coordinates for multiline result
                
                

        
        if break_switch == 1:
            break

        if start_coor < stop_coor:
            complement = "0" #Forward complement
            
            length = (stop_coor-start_coor)/3
            start = start_coor
            stop = stop_coor

        elif start_coor > stop_coor:
            complement = "1" #Reverse complement
            length = (-stop_coor+start_coor)/3
            start = stop_coor
            stop = start_coor

        else:
            error = "Y"
        
        
        
        

        #Check if the length of target (blast hit) is significantly smaller than query
        if length < query_length - 0.2*query_length:
            error = "Y"

        old_trans = ''
#             print(start, stop)


# #Check for Met or STOP at the start and end
#         while True and (start != 0 or stop != 0):
#             if (query_name == query_name_list[0] or query_name == query_name_list[-1]):
#                 frame = 1
#                 translated_sequence = (sequence_extractor(species, scaff, int(complement), start, stop,frame ))

#                 if translated_sequence == old_trans:
#                     break
                    
# #Check for Met at the beginning of first exon

#                 if query_name == query_name_list[0] :
#                     if translated_sequence[0] != "M":
#                         print(translated_sequence)
# #                             print(start, stop)
#                         if complement == "0":
#                             start = int(start) - 3
#                         if complement == "1":
#                             stop = int(stop) + 3
#                         old_trans = translated_sequence
#                     if "*" in translated_sequence:
#                         error = "Y"
#                         break
#                     if translated_sequence[0] == "M":
#                         break

# #Check for stop at the end of last exon

#                 if query_name == query_name_list[-1]:
#                     if translated_sequence[-1] != "*":
#                         print(translated_sequence)
# #                             print(start, stop)
#                         if complement == "0":
#                             stop = int(stop) + 3
#                         if complement == "1":
#                             start = int(start) - 3
#                         old_trans = translated_sequence
#                     if translated_sequence[-1] == "*":

#                         break
#             else:
#                 break
        
        
#Add offset at the beginning and end of each exon
#         if (start != 0 or stop != 0):
            
#             start_modifier = int(query_name.split("Frame")[1][1])
#             stop_modifier = int(query_name.split("rightoh")[1][1])
#         else:
        start_modifier = 0
        stop_modifier = 0            

        seq_length = query_length
        
        
#Get exon start and end by adding or removing codons
        
    #if not the beginning
        if query_start_coor != "1" and query_name != query_name_list[0]:
            if complement == "0":
                start = int(start) - 3*(int(query_start_coor)-1)                
            if complement == "1":
                stop = int(stop) + 3*(int(query_start_coor)-1)
    
    #For the end
        if query_stop_coor != str(seq_length) and query_name != query_name_list[-1]:
            if complement == "0":
                stop = int(stop) + 3*(int(seq_length)-int(query_stop_coor))
            if complement == "1":
                

                start = int(start) - 3*(int(seq_length)-int(query_stop_coor))
 
        
        
        
#Adding or removing 3' and 5' overhangs for forward and reverse complement
    #For forward complement
        if complement == "0":
            start = int(start) - int(start_modifier)
            stop = int(stop) +  int(stop_modifier)
#             if old_end != 0 and old_end > stop:

#                 error = "Y"
            old_end = stop

    #For reverse complement
        if complement == "1":
            start = int(start) - int(stop_modifier)
            stop = int(stop) +  int(start_modifier)
#             if old_end != 0 and old_end < stop:
#                 error = "Y"
            old_end = stop

    #Simple check for lenghth
        if start == 0 or stop == 0:
            error = "Y"
            
           
        output_format = str(species.split("\n")[0])+"," + str(scaff) +"," + str(start)+"," + str(stop)+"," + str(complement)+"," + str(error)+  ","+ str(query_name)+","+ str(query_start_coor)+","+str(query_stop_coor)+","+str(query_length)+ "\n"  
        print(output_format)
#         assert False
        Output_Sequence = Output_Sequence + output_format

    print(Output_Sequence)
    output_file = open(f"{blast_location}/1.Blast_result/{species}/{species}_coordinates.csv",'w')
    output_file.write(Output_Sequence)
    output_file.close()
# Out:
# Pieris_brassicae
# Anthocharis_cardamines,FR989953.1,8403228,8403884,1,N,Pieris_brassicae_rps5,1,219,219
#
# Pieris_brassicae
# Anthocharis_cardamines,FR989955.1,10530615,10531139,1,N,Pieris_brassicae_wg,1,175,175
#
# Pieris_brassicae
# Anthocharis_cardamines,FR989957.1,10287581,10288099,1,N,Pieris_brassicae_rps2,1,173,173
#
# Pieris_brassicae
# Anthocharis_cardamines,FR989958.1,3630396,3631379,1,N,Pieris_brassicae_mdh,1,328,328
#
# Pieris_brassicae
# Anthocharis_cardamines,FR989954.1,8450646,8451869,1,N,Pieris_brassicae_idh,1,408,408
#
# Pieris_brassicae
# Anthocharis_cardamines,FR989955.1,5636655,5637359,0,N,Pieris_brassicae_ddc,1,235,235
#
# Pieris_brassicae
# Anthocharis_cardamines,FR989966.1,3414093,3415088,0,N,Pieris_brassicae_gapdh,1,332,332
#
# Pieris_brassicae
# Anthocharis_cardamines,FR989952.1,2573769,2575154,0,N,Pieris_brassicae_ef1,1,461,462
#
# Pieris_brassicae
# Anthocharis_cardamines,FR989961.1,482260,483036,0,N,Pieris_brassicae_hcl,1,259,259
#
# Pieris_brassicae
# Anthocharis_cardamines,FR989951.1,16294806,16296263,1,N,Pieris_brassicae_cat,3,489,489
#
# Pieris_brassicae
# Anthocharis_cardamines,FR989954.1,6983619,6986756,1,N,Pieris_brassicae_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Anthocharis_cardamines,FR989953.1,8403228,8403884,1,N,Pieris_brassicae_rps5,1,219,219
# Anthocharis_cardamines,FR989955.1,10530615,10531139,1,N,Pieris_brassicae_wg,1,175,175
# Anthocharis_cardamines,FR989957.1,10287581,10288099,1,N,Pieris_brassicae_rps2,1,173,173
# Anthocharis_cardamines,FR989958.1,3630396,3631379,1,N,Pieris_brassicae_mdh,1,328,328
# Anthocharis_cardamines,FR989954.1,8450646,8451869,1,N,Pieris_brassicae_idh,1,408,408
# Anthocharis_cardamines,FR989955.1,5636655,5637359,0,N,Pieris_brassicae_ddc,1,235,235
# Anthocharis_cardamines,FR989966.1,3414093,3415088,0,N,Pieris_brassicae_gapdh,1,332,332
# Anthocharis_cardamines,FR989952.1,2573769,2575154,0,N,Pieris_brassicae_ef1,1,461,462
# Anthocharis_cardamines,FR989961.1,482260,483036,0,N,Pieris_brassicae_hcl,1,259,259
# Anthocharis_cardamines,FR989951.1,16294806,16296263,1,N,Pieris_brassicae_cat,3,489,489
# Anthocharis_cardamines,FR989954.1,6983619,6986756,1,N,Pieris_brassicae_cad,1,1046,1046
#
# Pieris_brassicae
# Aporia_crataegi,OU538748.1,5303996,5304652,0,N,Pieris_brassicae_rps5,1,219,219
#
# Pieris_brassicae
# Aporia_crataegi,OU538736.1,5404408,5404932,0,N,Pieris_brassicae_wg,1,175,175
#
# Pieris_brassicae
# Aporia_crataegi,OU538740.1,5474508,5475026,0,N,Pieris_brassicae_rps2,1,173,173
#
# Pieris_brassicae
# Aporia_crataegi,OU538743.1,6947935,6948918,0,N,Pieris_brassicae_mdh,1,328,328
#
# Pieris_brassicae
# Aporia_crataegi,OU538743.1,4557626,4558849,0,N,Pieris_brassicae_idh,1,408,408
#
# Pieris_brassicae
# Aporia_crataegi,OU538729.1,2590129,2590833,1,N,Pieris_brassicae_ddc,1,235,235
#
# Pieris_brassicae
# Aporia_crataegi,OU538738.1,5110808,5111803,0,N,Pieris_brassicae_gapdh,1,332,332
#
# Pieris_brassicae
# Aporia_crataegi,OU538745.1,5768851,5770236,0,N,Pieris_brassicae_ef1,1,461,462
#
# Pieris_brassicae
# Aporia_crataegi,OU538748.1,358574,359350,0,N,Pieris_brassicae_hcl,1,259,259
#
# Pieris_brassicae
# Aporia_crataegi,OU538732.1,9739609,9741066,1,N,Pieris_brassicae_cat,1,489,489
#
# Pieris_brassicae
# Aporia_crataegi,OU538743.1,5647198,5650335,0,N,Pieris_brassicae_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Aporia_crataegi,OU538748.1,5303996,5304652,0,N,Pieris_brassicae_rps5,1,219,219
# Aporia_crataegi,OU538736.1,5404408,5404932,0,N,Pieris_brassicae_wg,1,175,175
# Aporia_crataegi,OU538740.1,5474508,5475026,0,N,Pieris_brassicae_rps2,1,173,173
# Aporia_crataegi,OU538743.1,6947935,6948918,0,N,Pieris_brassicae_mdh,1,328,328
# Aporia_crataegi,OU538743.1,4557626,4558849,0,N,Pieris_brassicae_idh,1,408,408
# Aporia_crataegi,OU538729.1,2590129,2590833,1,N,Pieris_brassicae_ddc,1,235,235
# Aporia_crataegi,OU538738.1,5110808,5111803,0,N,Pieris_brassicae_gapdh,1,332,332
# Aporia_crataegi,OU538745.1,5768851,5770236,0,N,Pieris_brassicae_ef1,1,461,462
# Aporia_crataegi,OU538748.1,358574,359350,0,N,Pieris_brassicae_hcl,1,259,259
# Aporia_crataegi,OU538732.1,9739609,9741066,1,N,Pieris_brassicae_cat,1,489,489
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Pieris_melete,CAVNZK010000002.1,1073394,1074050,1,N,Pieris_brassicae_rps5,1,219,219
# Pieris_melete,CAVNZK010000358.1,1267113,1267637,1,N,Pieris_brassicae_wg,1,175,175
# Pieris_melete,CAVNZK010000345.1,5382465,5382983,0,N,Pieris_brassicae_rps2,1,173,173
# Pieris_melete,CAVNZK010000040.1,2212625,2213608,0,N,Pieris_brassicae_mdh,1,328,328
# Pieris_melete,CAVNZK010000046.1,937209,938432,1,N,Pieris_brassicae_idh,1,408,408
# Pieris_melete,CAVNZK010000028.1,1284362,1285066,1,N,Pieris_brassicae_ddc,1,235,235
# Pieris_melete,CAVNZK010000087.1,2028013,2029008,1,N,Pieris_brassicae_gapdh,1,332,332
# Pieris_melete,CAVNZK010000147.1,447237,448619,0,N,Pieris_brassicae_ef1,1,462,462
# Pieris_melete,CAVNZK010000326.1,3018858,3019634,1,N,Pieris_brassicae_hcl,1,259,259
# Pieris_melete,CAVNZK010000240.1,928509,929975,0,N,Pieris_brassicae_cat,1,489,489
# Pieris_melete,CAVNZK010000016.1,539900,543037,0,N,Pieris_brassicae_cad,1,1046,1046
#
# Pieris_brassicae
# Pieris_napi,NC_062247.1,6746143,6746799,0,N,Pieris_brassicae_rps5,1,219,219
#
# Pieris_brassicae
# Pieris_napi,NC_062240.1,8651111,8651635,0,N,Pieris_brassicae_wg,1,175,175
#
# Pieris_brassicae
# Pieris_napi,NC_062252.1,5650797,5651315,0,N,Pieris_brassicae_rps2,1,173,173
#
# Pieris_brassicae
# Pieris_napi,NC_062246.1,4357957,4358940,1,N,Pieris_brassicae_mdh,1,328,328
#
# Pieris_brassicae
# Pieris_napi,NC_062243.1,11902911,11904134,1,N,Pieris_brassicae_idh,1,408,408
#
# Pieris_brassicae
# Pieris_napi,NC_062248.1,5725730,5726434,0,N,Pieris_brassicae_ddc,1,235,235
#
# Pieris_brassicae
# Pieris_napi,NC_062255.1,8628452,8629447,0,N,Pieris_brassicae_gapdh,1,332,332
#
# Pieris_brassicae
# Pieris_napi,NC_062253.1,3592449,3593831,1,N,Pieris_brassicae_ef1,1,462,462
#
# Pieris_brassicae
# Pieris_napi,NC_062242.1,3993201,3993977,1,N,Pieris_brassicae_hcl,1,259,259
#
# Pieris_brassicae
# Pieris_napi,NC_062259.1,12962946,12964412,1,N,Pieris_brassicae_cat,1,489,489
#
# Pieris_brassicae
# Pieris_napi,NC_062243.1,10352662,10355799,1,N,Pieris_brassicae_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Pieris_napi,NC_062247.1,6746143,6746799,0,N,Pieris_brassicae_rps5,1,219,219
# Pieris_napi,NC_062240.1,8651111,8651635,0,N,Pieris_brassicae_wg,1,175,175
# Pieris_napi,NC_062252.1,5650797,5651315,0,N,Pieris_brassicae_rps2,1,173,173
# Pieris_napi,NC_062246.1,4357957,4358940,1,N,Pieris_brassicae_mdh,1,328,328
# Pieris_napi,NC_062243.1,11902911,11904134,1,N,Pieris_brassicae_idh,1,408,408
# Pieris_napi,NC_062248.1,5725730,5726434,0,N,Pieris_brassicae_ddc,1,235,235
# Pieris_napi,NC_062255.1,8628452,8629447,0,N,Pieris_brassicae_gapdh,1,332,332
# Pieris_napi,NC_062253.1,3592449,3593831,1,N,Pieris_brassicae_ef1,1,462,462
# Pieris_napi,NC_062242.1,3993201,3993977,1,N,Pieris_brassicae_hcl,1,259,259
# Pieris_napi,NC_062259.1,12962946,12964412,1,N,Pieris_brassicae_cat,1,489,489
# Pieris_napi,NC_062243.1,10352662,10355799,1,N,Pieris_brassicae_cad,1,1046,1046
#
# Pieris_brassicae
# Pieris_rapae,NC_059520.1,4903369,4904025,1,N,Pieris_brassicae_rps5,1,219,219
#
# Pieris_brassicae
# Pieris_rapae,NC_059518.1,4080185,4080709,1,N,Pieris_brassicae_wg,1,175,175
#
# Pieris_brassicae
# Pieris_rapae,NC_059526.1,4841164,4841682,0,N,Pieris_brassicae_rps2,1,173,173
#
# Pieris_brassicae
# Pieris_rapae,NC_059523.1,6841917,6842900,0,N,Pieris_brassicae_mdh,1,328,328
#
# Pieris_brassicae
# Pieris_rapae,NC_059515.1,1204730,1205953,0,N,Pieris_brassicae_idh,1,408,408
#
# Pieris_brassicae
# Pieris_rapae,NC_059524.1,4665326,4666030,0,N,Pieris_brassicae_ddc,1,235,235
#
# Pieris_brassicae
# Pieris_rapae,NC_059529.1,1822835,1823830,1,N,Pieris_brassicae_gapdh,1,332,332
#
# Pieris_brassicae
# Pieris_rapae,NC_059528.1,6212279,6213664,0,N,Pieris_brassicae_ef1,1,462,462
#
# Pieris_brassicae
# Pieris_rapae,NC_059517.1,3364878,3365654,1,N,Pieris_brassicae_hcl,1,259,259
#
# Pieris_brassicae
# Pieris_rapae,NC_059534.1,11102485,11103951,1,N,Pieris_brassicae_cat,1,489,489
#
# Pieris_brassicae
# Pieris_rapae,NC_059515.1,2594664,2597801,0,N,Pieris_brassicae_cad,1,1046,1046
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Pieris_rapae,NC_059520.1,4903369,4904025,1,N,Pieris_brassicae_rps5,1,219,219
# Pieris_rapae,NC_059518.1,4080185,4080709,1,N,Pieris_brassicae_wg,1,175,175
# Pieris_rapae,NC_059526.1,4841164,4841682,0,N,Pieris_brassicae_rps2,1,173,173
# Pieris_rapae,NC_059523.1,6841917,6842900,0,N,Pieris_brassicae_mdh,1,328,328
# Pieris_rapae,NC_059515.1,1204730,1205953,0,N,Pieris_brassicae_idh,1,408,408
# Pieris_rapae,NC_059524.1,4665326,4666030,0,N,Pieris_brassicae_ddc,1,235,235
# Pieris_rapae,NC_059529.1,1822835,1823830,1,N,Pieris_brassicae_gapdh,1,332,332
# Pieris_rapae,NC_059528.1,6212279,6213664,0,N,Pieris_brassicae_ef1,1,462,462
# Pieris_rapae,NC_059517.1,3364878,3365654,1,N,Pieris_brassicae_hcl,1,259,259
# Pieris_rapae,NC_059534.1,11102485,11103951,1,N,Pieris_brassicae_cat,1,489,489
# Pieris_rapae,NC_059515.1,2594664,2597801,0,N,Pieris_brassicae_cad,1,1046,1046
