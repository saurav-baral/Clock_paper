# %%
list_of_species = ["Anthocharis_cardamines","Aporia_crataegi","Argynnis_bischoffii_washingtonia","Aricia_agestis","Aricia_artaxerxes","Baronia_brevicornis","Battus_philenor","Bicyclus_anynana","Boloria_euphrosyne","Boloria_selene","Brenthis_daphne","Brenthis_hecate","Brenthis_ino","Calycopis_cecrops","Celastrina_argiolus","Charaxes_varanes","Coenonympha_glycerion","Colias_behrii","Colias_croceus","Colias_eurytheme","Colias_nastes","Cyaniris_semiargus","Cyclargus_thomasi","Danaus_chrysippus","Danaus_plexippus","Dircenna_loreta","Dryadula_phaetusa","Dryas_iulia_moderata","Elymnias_hypermnestra","Erebia_aethiops","Erebia_ligea","Eueides_isabella","Eumaeus_atala","Euphydryas_editha","Eurema_hecabe","Fabriciana_adippe","Glaucopsyche_alexis","Heliconius_charithonia","Heliconius_nattereri","Heliconius_sara","Helleia_helle","Hestina_assimilis","Hipparchia_semele","Hypolimnas_misippus","Iphiclides_podalirius","Lasiommata_megera","Leptidea_juvernica","Leptidea_reali","Leptidea_sinapis","Leptophobia_aripa","Limenitis_camilla","Luehdorfia_chinensis","Lycaena_phlaeas","Lysandra_bellargus","Lysandra_coridon","Maniola_hyperantus","Maniola_jurtina","Mechanitis_mazaeus","Mechanitis_messenoides","Melanargia_galathea","Melinaea_marsaeus_rileyi","Melinaea_menophilus","Melitaea_cinxia","Mellicta_athalia","Napeogenes_inachia","Napeogenes_sylphis","Nymphalis_c-album","Nymphalis_io","Nymphalis_polychloros","Nymphalis_urticae","Oeneis_ivallda","Ornithoptera_alexandrae","Ornithoptera_priamus","Papilio_dardanus_tibullus","Papilio_demoleus","Papilio_elwesi","Papilio_gigon","Papilio_glaucus","Papilio_machaon","Papilio_memnon","Papilio_polytes","Papilio_protenor","Papilio_xuthus","Pararge_aegeria","Parnassius_glacialis","Phengaris_arion","Philaethria_dido","Phoebis_sennae","Pieris_brassicae","Pieris_mannii","Pieris_melete","Pieris_napi","Pieris_rapae","Plebejus_argus","Polyommatus_icarus","Polyommatus_iphigenia","Sericinus_montela","Teinopalpus_imperialis","Troides_aeacus","Troides_oblongomaculatus","Vanessa_atalanta","Vanessa_cardui","Vanessa_tameamea","Zerene_cesonia"]

from Bio import SeqIO
import os

gene = "10.Cycle_Exon_Analysis"
location = f"/mnt/g/My Drive/Circadian Rhythm Genes Project/{gene}"

fasta_file = SeqIO.parse(f"{location}/12.Family_specific_tests_Cycle/Combined/Combined_Cycle.fas", 'fasta')
new_species_list = []
for records in fasta_file:
    new_species_list.append(records.id.split("-")[0])

for species in list_of_species:
    if species not in new_species_list:
        print(species)
# Out:
# Baronia_brevicornis
# Calycopis_cecrops
# Charaxes_varanes
# Colias_behrii
# Colias_nastes
# Cyclargus_thomasi
# Helleia_helle
# Nymphalis_c-album
# Papilio_dardanus_tibullus
# Papilio_demoleus
