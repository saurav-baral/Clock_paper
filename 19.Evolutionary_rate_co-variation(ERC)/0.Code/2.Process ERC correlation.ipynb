# %%
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/2.Two_state"
candidate_gene=["period.fas.ClipKIT","timeless.fas.ClipKIT","clock.fas.ClipKIT","cycle.fas.ClipKIT","cry2.fas.ClipKIT",]
candidate_gene=["period.fas.ClipKIT","timeless.fas.ClipKIT","clock.fas.ClipKIT","cycle.fas.ClipKIT","cwo.fas.ClipKIT","cry1a.fas.ClipKIT","cry1b.fas.ClipKIT","cry2.fas.ClipKIT","timeout.fas.ClipKIT"]

import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

csv_file = pd.read_csv(f"{location}/ERC_correlation_diapause.csv")
csv_file.index = csv_file.columns
string_to_remove = "_nostop.fas.aligned.fas.best"
csv_file.columns = csv_file.columns.str.replace(string_to_remove, "", regex=False)
csv_file.index = csv_file.index.str.replace(string_to_remove, "", regex=False)


selected_columns = csv_file[candidate_gene]
# filtered_df = selected_columns.nlargest(100, 'period')
filtered_df = selected_columns[selected_columns.gt(0.3).any(axis=1)]
# filtered_df = filtered_df.fillna(1)

print(filtered_df)
# Out:
#                          period.fas.ClipKIT  timeless.fas.ClipKIT  \
# 11864at7088.fas.ClipKIT            0.116013              0.147123
# 5091at7088.fas.ClipKIT             0.208020              0.130465
# 4306at7088.fas.ClipKIT             0.313259              0.382990
# 6279at7088.fas.ClipKIT             0.023274              0.029238
# 10940at7088.fas.ClipKIT            0.178967              0.121752
# ...                                     ...                   ...
# 3931at7088.fas.ClipKIT             0.142316              0.149117
# 5556at7088.fas.ClipKIT            -0.027870             -0.018430
# 12347at7088.fas.ClipKIT            0.223546              0.305172
# 8902at7088.fas.ClipKIT             0.259454              0.102811
# 11693at7088.fas.ClipKIT           -0.012762              0.026653
#
#                          clock.fas.ClipKIT  cycle.fas.ClipKIT  \
# 11864at7088.fas.ClipKIT           0.150424          -0.026215
# 5091at7088.fas.ClipKIT            0.222957           0.398397
# 4306at7088.fas.ClipKIT            0.254799           0.285451
# 6279at7088.fas.ClipKIT            0.215835           0.324436
# 10940at7088.fas.ClipKIT           0.018738          -0.024439
# ...                                    ...                ...
# 3931at7088.fas.ClipKIT            0.178060          -0.020684
# 5556at7088.fas.ClipKIT           -0.101177          -0.168475
# 12347at7088.fas.ClipKIT           0.210068           0.278559
# 8902at7088.fas.ClipKIT            0.273053           0.343230
# 11693at7088.fas.ClipKIT           0.061467          -0.111385
#
#                          cwo.fas.ClipKIT  cry1a.fas.ClipKIT  \
# 11864at7088.fas.ClipKIT         0.000140           0.067408
# 5091at7088.fas.ClipKIT          0.198674           0.268230
# 4306at7088.fas.ClipKIT          0.105461           0.149656
# 6279at7088.fas.ClipKIT          0.296411           0.355952
# 10940at7088.fas.ClipKIT         0.209794           0.069225
# ...                                  ...                ...
# 3931at7088.fas.ClipKIT         -0.047138          -0.022686
# 5556at7088.fas.ClipKIT         -0.070346          -0.161849
# 12347at7088.fas.ClipKIT        -0.049279           0.125626
# 8902at7088.fas.ClipKIT          0.237359           0.312339
# 11693at7088.fas.ClipKIT        -0.036699          -0.193095
#
#                          cry1b.fas.ClipKIT  cry2.fas.ClipKIT  \
# 11864at7088.fas.ClipKIT           0.332783          0.109043
# 5091at7088.fas.ClipKIT            0.041644          0.196685
# 4306at7088.fas.ClipKIT           -0.057201          0.304661
# 6279at7088.fas.ClipKIT           -0.169957          0.130456
# 10940at7088.fas.ClipKIT           0.371774          0.103404
# ...                                    ...               ...
# 3931at7088.fas.ClipKIT            0.319646          0.067716
# 5556at7088.fas.ClipKIT            0.365526         -0.017896
# 12347at7088.fas.ClipKIT           0.121644          0.102338
# 8902at7088.fas.ClipKIT            0.019291          0.251545
# 11693at7088.fas.ClipKIT           0.338356         -0.074966
#
#                          timeout.fas.ClipKIT
# 11864at7088.fas.ClipKIT             0.221236
# 5091at7088.fas.ClipKIT             -0.121237
# 4306at7088.fas.ClipKIT              0.297496
# 6279at7088.fas.ClipKIT             -0.126368
# 10940at7088.fas.ClipKIT             0.208348
# ...                                      ...
# 3931at7088.fas.ClipKIT              0.093694
# 5556at7088.fas.ClipKIT              0.065192
# 12347at7088.fas.ClipKIT             0.044665
# 8902at7088.fas.ClipKIT              0.056990
# 11693at7088.fas.ClipKIT             0.218557
#
# [1230 rows x 9 columns]

# %%
string_to_remove = ".fas.ClipKIT"
csv_file.columns = csv_file.columns.str.replace(string_to_remove, "", regex=False)
csv_file.index = csv_file.index.str.replace(string_to_remove, "", regex=False)

candidate_gene=["period","timeless","clock","cycle","cwo","cry1a","cry1b","cry2","timeout"]
selected_columns = csv_file[candidate_gene]
# filtered_df = selected_columns.nlargest(100, 'period')
filtered_df = selected_columns[selected_columns.gt(0.3).any(axis=1)]
# filtered_df = filtered_df.fillna(1)

print(filtered_df)
# Out:
#                period  timeless     clock     cycle       cwo     cry1a  \
# 11864at7088  0.116013  0.147123  0.150424 -0.026215  0.000140  0.067408
# 5091at7088   0.208020  0.130465  0.222957  0.398397  0.198674  0.268230
# 4306at7088   0.313259  0.382990  0.254799  0.285451  0.105461  0.149656
# 6279at7088   0.023274  0.029238  0.215835  0.324436  0.296411  0.355952
# 10940at7088  0.178967  0.121752  0.018738 -0.024439  0.209794  0.069225
# ...               ...       ...       ...       ...       ...       ...
# 3931at7088   0.142316  0.149117  0.178060 -0.020684 -0.047138 -0.022686
# 5556at7088  -0.027870 -0.018430 -0.101177 -0.168475 -0.070346 -0.161849
# 12347at7088  0.223546  0.305172  0.210068  0.278559 -0.049279  0.125626
# 8902at7088   0.259454  0.102811  0.273053  0.343230  0.237359  0.312339
# 11693at7088 -0.012762  0.026653  0.061467 -0.111385 -0.036699 -0.193095
#
#                 cry1b      cry2   timeout
# 11864at7088  0.332783  0.109043  0.221236
# 5091at7088   0.041644  0.196685 -0.121237
# 4306at7088  -0.057201  0.304661  0.297496
# 6279at7088  -0.169957  0.130456 -0.126368
# 10940at7088  0.371774  0.103404  0.208348
# ...               ...       ...       ...
# 3931at7088   0.319646  0.067716  0.093694
# 5556at7088   0.365526 -0.017896  0.065192
# 12347at7088  0.121644  0.102338  0.044665
# 8902at7088   0.019291  0.251545  0.056990
# 11693at7088  0.338356 -0.074966  0.218557
#
# [1230 rows x 9 columns]

# %%
filtered_df.to_csv(f"{location}/ERC_clock_filtered_diapause.csv")

# %%
kmeans = KMeans(n_clusters=2)  # Change number of clusters as needed
kmeans.fit(filtered_df)

pca = PCA(n_components=2)
pca_result = pca.fit_transform(filtered_df)

# Create a new DataFrame with PCA results and cluster labels
filtered_df['PCA1'] = pca_result[:, 0]
filtered_df['PCA2'] = pca_result[:, 1]
filtered_df['Cluster'] = kmeans.labels_

highlight = filtered_df.loc[filtered_df.index.isin(candidate_gene)]
# Out:
# /home/saurav/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 5
#       2 kmeans.fit(filtered_df)
#       4 pca = PCA(n_components=2)
# ----> 5 pca_result = pca.fit_transform(filtered_df)
#       7 # Create a new DataFrame with PCA results and cluster labels
#       8 filtered_df['PCA1'] = pca_result[:, 0]
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~/.local/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/decomposition/_pca.py:460, in PCA.fit_transform(self, X, y)
#     437 @_fit_context(prefer_skip_nested_validation=True)
#     438 def fit_transform(self, X, y=None):
#     439     """Fit the model with X and apply the dimensionality reduction on X.
#     440
#     441     Parameters
#    (...)
#     458     C-ordered array, use 'np.ascontiguousarray'.
#     459     """
# --> 460     U, S, Vt = self._fit(X)
#     461     U = U[:, : self.n_components_]
#     463     if self.whiten:
#     464         # X_new = X * V / S * sqrt(n_samples) = U * sqrt(n_samples)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/decomposition/_pca.py:510, in PCA._fit(self, X)
#     508 # Call different fits for either full or truncated SVD
#     509 if self._fit_svd_solver == "full":
# --> 510     return self._fit_full(X, n_components)
#     511 elif self._fit_svd_solver in ["arpack", "randomized"]:
#     512     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/decomposition/_pca.py:524, in PCA._fit_full(self, X, n_components)
#     520         raise ValueError(
#     521             "n_components='mle' is only supported if n_samples >= n_features"
#     522         )
#     523 elif not 0 <= n_components <= min(n_samples, n_features):
# --> 524     raise ValueError(
#     525         "n_components=%r must be between 0 and "
#     526         "min(n_samples, n_features)=%r with "
#     527         "svd_solver='full'" % (n_components, min(n_samples, n_features))
#     528     )
#     530 # Center data
#     531 self.mean_ = np.mean(X, axis=0)
#
# ValueError: n_components=2 must be between 0 and min(n_samples, n_features)=1 with svd_solver='full'

# %%
# print(filtered_df)
# highlight = filtered_df.loc[filtered_df.index.isin(candidate_gene)]

# print(highlight)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(filtered_df['PCA1'], filtered_df['PCA2'], c=filtered_df['Cluster'], cmap='viridis')
candidate_gene=["period","timeless","clock","cycle","cwo","cry1a","cry1b","cry2","timeout"]
for gene_name in candidate_gene:
    if gene_name in highlight.index:
        plt.annotate(f"{gene_name}", (highlight.loc[gene_name,'PCA1'], highlight.loc[gene_name,'PCA2']), textcoords="offset points", xytext=(0,10), ha='center', color='red')
plt.title('K-Means Clustering Visualization')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
# plt.colorbar(label='Cluster')
plt.show()

# %%
# clock_cluster = filtered_df[(filtered_df["Cluster"] == 1) ]
# clock_cluster.to_csv(f"{location}/ERC_clock_cluster.csv")
print(filtered_df)
filtered_df.to_csv(f"{location}/ERC_period_filtered_new.csv")
# Out:
#               period
# cry2        0.471124
# 1422at7088  0.579632
# timeless    0.618855
# 2905at7088  0.881460
# clock       0.615619
# 2273at7088  0.468501
# period      1.000000
# 5474at7088  0.570752
# cycle       0.457639
# 2021at7088  0.468937
