# %%
location = "/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/unTrimmed/3.For_tree/2.ERC_100"
import pandas as pd
import os

list_of_files = os.listdir(location)
for file_name in list_of_files:
    gene_name = file_name.split("_")[1]

    csv_file = pd.read_csv(f"{location}/{file_name}")
    # print(csv_file)
    os.mkdir(f"{location}/GSEA_{gene_name}")
    csv_file.rename(columns={"Unnamed: 0": "geneid"}, inplace=True)
    selected_columns = csv_file["geneid"]
    # print(selected_columns)
    
    selected_columns.to_csv(f"{location}/GSEA_{gene_name}/candidate_gene_100.csv", index=False)
    # print(gene_name)
    # break
# print(list_of_files)
