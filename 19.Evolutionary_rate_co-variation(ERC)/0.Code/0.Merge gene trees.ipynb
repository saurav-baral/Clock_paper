# %%
from Bio import Phylo
gene_folder_list = ["6.Period Exon Analysis","7.Timeless Exon Analysis","9.CLOCK Exon Analysis","10.Cycle_Exon_Analysis","11.CWO_Exon_Analysis","12.Cryptochrome_1a_Exon_Analysis","13.Cryptochrome_1b_Exon_Analysis","14.Cryptochrome_2_Exon_Analysis","15.Timeout_Exon_Analysis"]
gene_list = ["period","timeless","CLOCK","Cycle","CWO","cry1a","cry1b","cry2","timeout"]
output = ''
for gene_folder, gene in zip(gene_folder_list,gene_list):
    # print(gene_folder, gene)
    location = f"/mnt/g/My Drive/Circadian Rhythm Genes Project/{gene_folder}/12.Family_specific_tests_{gene}/Nymphalidae"

    tree = Phylo.read(f"{location}/Nymphalidae_{gene.lower()}_nostop.fas.aligned.fas.trimal.fas.treefile_figtree", 'newick')
    species_list = [term.name for term in tree.get_terminals()]
    with open(f"{location}/Nymphalidae_{gene}_nostop.fas.aligned.fas.trimal.fas.treefile", 'r') as tree_file_open:
        tree_file = tree_file_open.readlines()[0]
        # print(tree_file)
    for species_name in species_list:
        tree_file = tree_file.replace(species_name, species_name.split("-")[0])
    with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/1.Trees_without_gene_name/{gene}_tree.nwk",'w') as out_file:
        out_file.write(tree_file)
#     output += f"{gene}\n{tree_file}\n"
# print(output)
# with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/combined_tree.nwk",'w') as out_file:
#     out_file.write(output)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 9
#       5 for gene_folder, gene in zip(gene_folder_list,gene_list):
#       6     # print(gene_folder, gene)
#       7     location = f"/mnt/g/My Drive/Circadian Rhythm Genes Project/{gene_folder}/12.Family_specific_tests_{gene}/Nymphalidae"
# ----> 9     tree = Phylo.read(f"{location}/Nymphalidae_{gene.lower()}_nostop.fas.aligned.fas.trimal.fas.treefile_figtree", 'newick')
#      10     species_list = [term.name for term in tree.get_terminals()]
#      11     with open(f"{location}/Nymphalidae_{gene}_nostop.fas.aligned.fas.trimal.fas.treefile", 'r') as tree_file_open:
#
# File ~/miniconda3/envs/genomic_work/lib/python3.11/site-packages/Bio/Phylo/_io.py:63, in read(file, format, **kwargs)
#      61 try:
#      62     tree_gen = parse(file, format, **kwargs)
# ---> 63     tree = next(tree_gen)
# ...

# %%
from Bio import Phylo
import os
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/"
list_of_files = os.listdir(f"{location}/1.Trees_without_gene_name")
if "desktop.ini" in list_of_files:
    list_of_files.remove("desktop.ini")

output = ''
for file in list_of_files:
    # print(gene_folder, gene)
    
    tree = Phylo.read(f"{location}/1.Trees_without_gene_name/{file}", 'newick')
    species_list_original = [term.name for term in tree.get_terminals()]
    species_list_original.remove("Danaus_chrysippus")
    species_list_original.remove("Heliconius_sara")
    print("species_list_orignnal", len(species_list_original) )
    break
for file in list_of_files:
    
    tree = Phylo.read(f"{location}/1.Trees_without_gene_name/{file}", 'newick')
    species_list = [term.name for term in tree.get_terminals()]
    # print(file, len(species_list))
    for species_name in species_list:
        if species_name not in species_list_original:
            tree.prune(species_name)
            # print(species_name)
    species_list = [term.name for term in tree.get_terminals()]
    for species_name in species_list_original:
        if species_name not in species_list:
            print(species_name)
    print(file, len(species_list))
    Phylo.write(tree, f"{location}/1.Trees_without_gene_name/{file}_pruned", "newick")
    # print(tree)
    # break
# Out:
# species_list_orignnal 43
# period_tree.nwk 43
# timeless_tree.nwk 43
# CLOCK_tree.nwk 43
# Cycle_tree.nwk 43
# CWO_tree.nwk 43
# cry1a_tree.nwk 43
# cry1b_tree.nwk 43
# cry2_tree.nwk 43
# timeout_tree.nwk 43

# %%
from Bio import Phylo
import os
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/"
list_of_files = os.listdir(f"{location}/4.HYPHY_branch_length_optimization")
if "desktop.ini" in list_of_files:
    list_of_files.remove("desktop.ini")

output = ''
for file in list_of_files:
    if file.endswith("_tree.nwk"):
        # print(file)
        with open(f"{location}/4.HYPHY_branch_length_optimization/{file}", 'r') as tree_file_open:
            tree_file = tree_file_open.readlines()[0]
        output += f"{file.split('_')[0]}\n{tree_file}\n"
print(output)
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/combined_tree.nwk",'w') as out_file:
     out_file.write(output)
# Out:
# clock
# ...

# %%
from Bio import SeqIO

fasta_file = SeqIO.parse(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/12.Family_specific_tests_period/Nymphalidae/Nymphalidae_period_nostop.fas.aligned.fas.best.fas", 'fasta')
for records in fasta_file:
    print(records.id)
# Out:
# Bicyclus_anynana-period
# Lasiommata_megera-period
# Pararge_aegeria-period
# Coenonympha_glycerion-period
# Erebia_aethiops-period
# Erebia_ligea-period
# Maniola_hyperantus-period
# Maniola_jurtina-period
# Hipparchia_semele-period
# Oeneis_ivallda-period
# Melanargia_galathea-period
# Euphydryas_editha-period
# Melitaea_cinxia-period
# Mellicta_athalia-period
# Hypolimnas_misippus-period
# Nymphalis_c-album-period
# Nymphalis_polychloros-period
# Nymphalis_io-period
# Nymphalis_urticae-period
# Vanessa_atalanta-period
# Vanessa_tameamea-period
# Vanessa_cardui-period
# Eueides_isabella-period
# Heliconius_charithonia-period
# Heliconius_sara-period
# Heliconius_nattereri-period
# Dryadula_phaetusa-period
# Dryas_iulia_moderata-period
# Philaethria_dido-period
# Argynnis_bischoffii_washingtonia-period
# Fabriciana_adippe-period
# Brenthis_daphne-period
# Brenthis_ino-period
# Brenthis_hecate-period
# Boloria_euphrosyne-period
# Boloria_selene-period
# Danaus_chrysippus-period
# ...
