# %%
import pandas as pd

location = "/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/trees_split"

csv_file = pd.read_csv(f"{location}/ERC_correlation_diapause.csv")
csv_file.index = csv_file.columns

# %%
string_to_remove = ".fas.best.fas.ClipKIT"
csv_file.columns = csv_file.columns.str.replace(string_to_remove, "", regex=False)
csv_file.index = csv_file.index.str.replace(string_to_remove, "", regex=False)


csv_file
# Out:
#              7749at7088  968at7088  6269at7088  5969at7088  15552at7088  \
# 7749at7088     1.000000   0.154309    0.355762    0.446762     0.054527
# 968at7088      0.154309   1.000000    0.156092    0.110216     0.003662
# 6269at7088     0.355762   0.156092         NaN    0.258645     0.088723
# 5969at7088     0.446762   0.110216    0.258645    1.000000     0.225455
# 15552at7088    0.054527   0.003662    0.088723    0.225455     1.000000
# ...                 ...        ...         ...         ...          ...
# 15126at7088    0.041966  -0.130609   -0.076821    0.118471    -0.061949
# 12668at7088    0.047550  -0.024311    0.151186    0.243605     0.211036
# 2236at7088    -0.134318   0.051220   -0.066601   -0.164121    -0.115843
# 9362at7088    -0.075427  -0.003359   -0.159794    0.175817     0.003389
# 1417at7088    -0.214736  -0.339054   -0.147579   -0.212700    -0.067704
#
#              1938at7088  159at7088  123at7088  6352at7088  2645at7088  ...  \
# ...

# %%
candidate_gene=["period","timeless","cry2","clock","cycle","cwo","cry1a","cry1b","timeout"]
index_order = ["period","timeless","cry2","clock","cycle","cwo","cry1a","cry1b","timeout"]


# candidate_gene=["12510at7088","11337at7088","13463at7088","12492at7088","14318at7088","12445at7088","14738at7088","4935at7088","7520at7088","1144at7088"]
# index_order = ["12510at7088","11337at7088","13463at7088","12492at7088","14318at7088","12445at7088","14738at7088","4935at7088","7520at7088","1144at7088"]

# candidate_gene=["5159at7088","3839at7088","65at7088","5301at7088","8637at7088","1904at7088","9367at7088","1130at7088","4623at7088","8735at7088","7935at7088","5969at7088"]
# index_order =["5159at7088","3839at7088","65at7088","5301at7088","8637at7088","1904at7088","9367at7088","1130at7088","4623at7088","8735at7088","7935at7088","5969at7088"]


selected_columns = csv_file[candidate_gene]
filtered_df = selected_columns[selected_columns.index.isin(candidate_gene)]
# print(filtered_df)

filtered_df = filtered_df.fillna(1)
gene_anno_dic = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/2.Two_state/correlation_2_with_annotation.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        gene_name = lines.split(",")[0].split("_")[0][1:]
        anno_name = lines.split(",")[-1].replace('"', '')
        gene_anno_dic[gene_name]= anno_name.strip()

# print(gene_anno_dic)

# %%
filtered_df = filtered_df.reindex(index=index_order, columns=index_order)

filtered_df_rn = filtered_df.rename(index=gene_anno_dic, columns=gene_anno_dic)
# filtered_df = filtered_df.sort_index(axis=1)
print(filtered_df_rn)
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

mask = np.triu(np.ones_like(filtered_df, dtype=bool))
# n = filtered_df_rn.shape[0]
# mask = np.fromfunction(lambda i, j: i + j < n - 1, (n, n), dtype=int)


plt.figure(figsize=(8, 8))
ax = sns.heatmap(filtered_df_rn, vmin=0.1, vmax=0.7,  mask=mask, annot=True, cmap='coolwarm', cbar=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')  # Vertical x-axis labels
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, ha='right') 
# plt.gca().yaxis.tick_right()
# plt.savefig(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/55.Plots_for_Figure_3_coorelations/2.Correlations/ERC_correlation_clock_full.pdf")
plt.show()
# Out:
#             period  timeless      cry2     clock     cycle       cwo  \
# period    1.000000  0.660021  0.559037  0.670373  0.458890  0.186772
# timeless  0.660021  1.000000  0.421711  0.498823  0.299321  0.014017
# cry2      0.559037  0.421711  1.000000  0.451632  0.337372  0.091310
# clock     0.670373  0.498823  0.451632  1.000000  0.427447  0.216968
# cycle     0.458890  0.299321  0.337372  0.427447  1.000000  0.140085
# cwo       0.186772  0.014017  0.091310  0.216968  0.140085  1.000000
# cry1a     0.204464  0.029557  0.206488  0.240013  0.457073  0.288920
# cry1b    -0.028497 -0.094912  0.004845 -0.153581 -0.073790  0.056349
# timeout   0.150539  0.123765  0.109447  0.009733 -0.068643 -0.107967
#
#              cry1a     cry1b   timeout
# period    0.204464 -0.028497  0.150539
# timeless  0.029557 -0.094912  0.123765
# cry2      0.206488  0.004845  0.109447
# clock     0.240013 -0.153581  0.009733
# cycle     0.457073 -0.073790 -0.068643
# ...

# %%
mask = np.triu(np.ones_like(filtered_df, dtype=bool))
# n = filtered_df_rn.shape[0]
# mask = np.fromfunction(lambda i, j: i + j < n - 1, (n, n), dtype=int)


plt.figure(figsize=(7, 8))
ax = sns.heatmap(filtered_df_rn, vmin=0.1, vmax=0.7,  mask=mask, annot=True, cmap='coolwarm', cbar=False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')  # Vertical x-axis labels
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, ha='right') 
# plt.gca().yaxis.tick_right()
plt.savefig(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/55.Plots_for_Figure_3_coorelations/2.Correlations/ERC_correlation_clock_diapause.pdf", bbox_inches='tight')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Flip the data
data_flipped = filtered_df_rn.iloc[:, ::-1]

# Create mask for upper triangle
n = filtered_df_rn.shape[0]
mask = np.fromfunction(lambda i, j: i + j < n, (n, n), dtype=int)


plt.figure(figsize=(7, 8))
ax = sns.heatmap(data_flipped, vmin=0.1, vmax=0.7,  mask=mask, annot=True, cmap='coolwarm',cbar=False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')  # Vertical x-axis labels
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, ha='right') 
ax.tick_params(axis='y', pad=50)
for label in ax.get_yticklabels():
    label.set_horizontalalignment('right')
plt.gca().yaxis.tick_right()
plt.savefig(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/55.Plots_for_Figure_3_coorelations/2.Correlations/ERC_correlation_clock_non_diapause.pdf", bbox_inches='tight')
plt.show()

# %%
|
