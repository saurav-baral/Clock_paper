# %%
extended_rho_set_positive = []
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/12.Rho_networks/2.Diapausing/Filtered_set_core_set.csv",'r') as extended_rho_file:
    for lines in extended_rho_file.readlines()[1:]:
        lines_split = lines.strip().split(",")
        if lines_split[0] not in extended_rho_set_positive:
            extended_rho_set_positive.append(lines_split[0])
        if lines_split[1] not in extended_rho_set_positive:
            extended_rho_set_positive.append(lines_split[1])
# print((extended_rho_set_positive))

# %%
extended_rho_set_negative = []
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/13.Rho_networks_negative/4.Diapause_cluster/Filtered_set_core_set.csv",'r') as extended_rho_file:
    for lines in extended_rho_file.readlines()[1:]:
        lines_split = lines.strip().split(",")
        if lines_split[0] not in extended_rho_set_negative:
            extended_rho_set_negative.append(lines_split[0])
        if lines_split[1] not in extended_rho_set_negative:
            extended_rho_set_negative.append(lines_split[1])
print(len(extended_rho_set_negative))
# Out:
# 567

# %%
rho_genes = []
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/1.Rerconverge_result/correlation_annotated.csv",'r') as rho_file:
    for lines in rho_file.readlines()[1:]:
        lines_split = lines.strip().split(",")
        
        # print(lines_split)
        # assert False
        gene = (lines_split[0][1:-1].split(".")[0])
        if float(lines_split[1]) > 0 and float(lines_split[5]) < 0.1:
            rho_genes.append(gene)
print(len(rho_genes))
# Out:
# 25

# %%
negative_rho_genes = []
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/1.Rerconverge_result/correlation_annotated.csv",'r') as rho_file:
    for lines in rho_file.readlines()[1:]:
        lines_split = lines.strip().split(",")
        
        # print(lines_split)
        # assert False
        gene = (lines_split[0][1:-1].split(".")[0])
        if float(lines_split[1]) < 0 and float(lines_split[5]) < 0.1:
            negative_rho_genes.append(gene)
print((negative_rho_genes))
# Out:
# ['11426at7088', '11702at7088', '15078at7088', '2418at7088', '2729at7088', '3887at7088', '3975at7088', '4180at7088', '4202at7088', '5723at7088', '6066at7088', '6782at7088', '6906at7088', '7001at7088', '7125at7088', '7253at7088', '7751at7088', '7830at7088', '8317at7088', '8504at7088', '8764at7088', '8898at7088', '9580at7088', '10225at7088', '10457at7088', '10709at7088', '1250at7088', '1490at7088', '2038at7088', '303at7088', '384at7088', '488at7088', '662at7088', '951at7088']

# %%
location = "/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/unTrimmed/3.For_tree"
gene_anno_dic = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/20.RERconverge/2.Modified_diapause/correlation_with_annotation.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        gene_name = lines.split(",")[0].split("_")[0]
        # print(gene_name)
        anno_name = lines.split(",")[-1].replace('"', '')
        gene_anno_dic[gene_name]= anno_name.strip()

def check_annotation(name):
    return gene_anno_dic.get(name, name)

# %%
import pandas as pd
top_hits = pd.read_csv("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/10.For_blast/top_hits_down.tsv", sep = "\t")
top_hits["Annotation_gene1"] = top_hits["sseqid"].apply(check_annotation)
top_hits.drop_duplicates(subset=['sseqid'], keep='first', inplace=True)
top_hits["rho_genes"] = top_hits["sseqid"].apply(lambda x: "Yes" if x in rho_genes else "No")
top_hits["negative_rho_genes"] = top_hits["sseqid"].apply(lambda x: "Yes" if x in negative_rho_genes else "No")
top_hits["extended_rho_set_negative"] = top_hits["sseqid"].apply(lambda x: "Yes" if x in extended_rho_set_negative else "No")
top_hits["extended_rho_set_positive"] = top_hits["sseqid"].apply(lambda x: "Yes" if x in extended_rho_set_positive else "No")
top_hits.to_csv("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/23.Negative_Rho_genes/1.Blast_results_Tetrapedia_diversipes/top_hits_down_with_rho.csv", sep=",", index=False)
