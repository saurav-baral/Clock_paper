# %%
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/5.Papilio_polytes"
import numpy 
fst_dictionary = {}
fst_list = []
with open(f"{location}/1.FST_peaks_from_chris/two_pool_5%_0.058_5kb_unmerged.fst",'r') as fst_file:
    for fst_lines in fst_file.readlines()[1:]:
        line_split = fst_lines.strip().split(",")
        
        fst_dictionary.setdefault(line_split[0],[])
        # # try:
        # # if float(line_split[3]) > 0.095:
        fst_dictionary[line_split[0]].append([[int(line_split[1]), int(line_split[2])],float(line_split[3])] )
        # # except:
            # pass
        # break
print(fst_dictionary)
# numpy.percentile(fst_list, 99)
# Out:
# {'NW_013524711.1': [[[108001, 109000], 0.0807041513793113], [[120001, 121000], 0.0771596820192433], [[216001, 217000], 0.067368798046927], [[318001, 319000], 0.1733037791531065], [[354001, 355000], 0.0584160673668284], [[355001, 356000], 0.1084451998937125], [[406001, 407000], 0.0590124793114922], [[407001, 408000], 0.1161259904854724], [[525001, 526000], 0.1475991506773735], [[544001, 545000], 0.0717092749080322], [[657001, 658000], 0.0800701280426319], [[661001, 662000], 0.0996171044177551], [[664001, 665000], 0.1646206362171141], [[681001, 682000], 0.1245205990565439], [[682001, 683000], 0.1343886525918295], [[832001, 833000], 0.0641600185897774], [[896001, 897000], 0.0678081261776858], [[950001, 951000], 0.087657432328524], [[951001, 952000], 0.0621696837467385], [[955001, 956000], 0.068664468547152], [[964001, 965000], 0.0793428646744201], [[975001, 976000], 0.1153769706847003], [[1036001, 1037000], 0.0910752740599758], [[1053001, 1054000], 0.0625053728911996], [[1054001, 1055000], 0.0711404613320694], [[1179001, 1180000], 0.0812925499707594]], 'NW_013524712.1': [[[30001, 31000], 0.0735112611968095], [[37001, 38000], 0.0802224979958274], [[62001, 63000], 0.0591007212292089], [[66001, 67000], 0.0747993629589418], [[106001, 107000], 0.0812670002277398], [[116001, 117000], 0.0647962385975226], [[132001, 133000], 0.0655692181550294], [[361001, 362000], 0.1244067522508685], [[391001, 392000], 0.0934821288598637], [[404001, 405000], 0.0812249564282769]], 'NW_013524739.1': [[[1, 1000], 0.0901165361734478]], 'NW_013524756.1': [[[25001, 26000], 0.1000262987567561], [[52001, 53000], 0.0585480093676814]], 'NW_013524767.1': [[[54001, 55000], 0.0621729589827265], [[108001, 109000], 0.0666874050612456], [[206001, 207000], 0.122745936767863], [[207001, 208000], 0.1179283269227679], [[232001, 233000], 0.1959373408048903], [[236001, 237000], 0.1061097509561504], [[241001, 242000], 0.11019920262237], [[246001, 247000], 0.0932592963207784], [[247001, 248000], 0.1156532490726748], [[253001, 254000], 0.1349810229785122], [[254001, 255000], 0.2031939172854164], [[260001, 261000], 0.1003101512725677], [[341001, 342000], 0.0754841420750889], [[379001, 380000], 0.1104074509325]], 'NW_013524785.1': [[[1, 1000], 0.0869978780312825]], 'NW_013524811.1': [[[9001, 10000], 0.1144923941908196], [[50001, 51000], 0.1453832713299247], [[125001, 126000], 0.0600448285584259], [[127001, 128000], 0.0727549642111163], [[158001, 159000], 0.0585616232997709], [[242001, 243000], 0.0954807301866884], [[278001, 279000], 0.0604986546615671], [[279001, 280000], 0.0713381766735776]], 'NW_013524822.1': [[[21001, 22000], 0.0606279199897526], [[128001, 129000], 0.0617560586679757], [[145001, 146000], 0.0933802742394093], [[245001, 246000], 0.065359206633298], [[314001, 315000], 0.1195114482549762], [[327001, 328000], 0.091366520508367], [[328001, 329000], 0.06252132872753], [[360001, 361000], 0.0598148042855839], [[365001, 366000], 0.0707632784438556], [[366001, 367000], 0.0816470683901149], [[379001, 380000], 0.0973920892890855], [[388001, 389000], 0.0918812816243028], [[505001, 506000], 0.0856153503376985], [[531001, 532000], 0.0689818780430765], [[648001, 649000], 0.072768056011774], [[649001, 650000], 0.0586700269630913], [[678001, 679000], 0.058169501897404], [[700001, 701000], 0.063734936498376], [[701001, 702000], 0.0973490013067196], [[745001, 746000], 0.0601252165273326], [[747001, 748000], 0.0819898876419879], [[748001, 749000], 0.1206026050118147], [[749001, 750000], 0.0854242037924041], [[757001, 758000], 0.0625153009168236], [[758001, 759000], 0.0646210288235861], [[761001, 762000], 0.0607188730010417], [[812001, 813000], 0.0636484413358478], [[822001, 823000], 0.0729225716268479], [[899001, 900000], 0.1013070645834709], [[906001, 907000], 0.0923348178823755], [[1128001, 1129000], 0.1205805070508517], [[1244001, 1245000], 0.0601704282157423], [[1284001, 1285000], 0.0823489151556304], [[1290001, 1291000], 0.1113052103067821], [[1358001, 1359000], 0.063120878266 ...

# %%
gene_anno_dic = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/2.Two_state/correlation_2_with_annotation.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        gene_name = lines.split(",")[0].split("_")[0][1:]
        anno_name = lines.split(",")[-1].replace('"', '')
        gene_anno_dic[gene_name]= anno_name.strip()

# print(gene_anno_dic)

# %%
gene_loc_dic = {}
with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'r') as gene_loc_file:
    for gene_line in gene_loc_file.readlines()[1:]:
        line_split = gene_line.strip().split("\t")
        gene_loc_dic[line_split[0]] = [line_split[1],line_split[2],line_split[3]]
# print(gene_loc_dic)



common_genes = []
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Present_in_all_3_5%/gene_list.txt", 'r') as common_genes_file:
    for common_gene_name in common_genes_file:
        common_genes.append(common_gene_name.strip())


rho_genes = []

with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/4.Rho_genes_and_RhoSet/25_rho_genes.txt", 'r') as rho_genes_file:
    for rho_gene in rho_genes_file:
        rho_genes.append(rho_gene.strip())


intersecting_genes = []
common_counter = []
rho_genes_counter = []
with open(f"{location}/3.Rho_set_genes/Rho_set_cluster.txt", 'r') as rho_set_file:
    for rho_set_count,lines in enumerate(rho_set_file.readlines()):
        rho_gene_name = lines.strip().split("\t")[0]

        try:
            chromosome,start,end = gene_loc_dic[rho_gene_name]
        except:
            print(rho_gene_name, "missing")
        
        
        for sections in (fst_dictionary[chromosome]):
            out_list = []
            
          
            if (((int(start) >= sections[0][0] and int(start) <= sections[0][1]) or (int(end) >= sections[0][0] and int(end) <= sections[0][1])) or ((sections[0][0] >= int(start) and sections[0][0] <= int(end)) or (sections[0][1] >= int(start) and sections[0][1] <= int(end)))) and len(sections) < 3:
                # print(sections)
                try:
                    sections.append(f"{gene_anno_dic[rho_gene_name]}")
                except:
                    sections.append(f"{rho_gene_name}")
                    print(rho_gene_name, "missing annottaion")
                if rho_gene_name in common_genes:
                    if rho_gene_name not in common_counter:
                        common_counter.append(rho_gene_name)
                    # common_counter += 1
                    try:
                        sections.append(f"{gene_anno_dic[rho_gene_name]}")
                    except:
                        sections.append(f"{rho_gene_name}")
                        print(rho_gene_name, "missing annottaion")
                    if rho_gene_name in rho_genes:
                        if rho_gene_name not in rho_genes_counter:
                            rho_genes_counter.append(rho_gene_name)
                        # common_counter += 1
                        try:
                            sections.append(f"{gene_anno_dic[rho_gene_name]}")
                        except:
                            sections.append(f"{rho_gene_name}")
                            print(rho_gene_name, "missing annottaion")
                # print(sections)
                # assert False
                    
                
                if rho_gene_name not in intersecting_genes:
                    intersecting_genes.append(rho_gene_name)
          
print("\n",len(intersecting_genes), rho_set_count, len(common_counter), len(rho_genes_counter))





common_genes = []
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Present_in_all_3_5%/gene_list.txt", 'r') as common_genes_file:
    for common_gene_name in common_genes_file:
        common_genes.append(common_gene_name.strip())


rho_genes = []

with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/4.Rho_genes_and_RhoSet/25_rho_genes.txt", 'r') as rho_genes_file:
    for rho_gene in rho_genes_file:
        rho_genes.append(rho_gene.strip())


intersecting_genes = []
common_counter = []
rho_genes_counter = []







intersecting_genes = []
with open(f"{location}/3.Rho_set_genes/Rho_set_cluster.txt", 'r') as rho_set_file:
    for rho_set_count,lines in enumerate(rho_set_file.readlines()):
        rho_gene_name = lines.strip().split("\t")[0]

        try:
            chromosome,start,end = gene_loc_dic[rho_gene_name]
        except:
            print(rho_gene_name, "missing")
        
        if chromosome in fst_dictionary:
            for sections in (fst_dictionary[chromosome]):
                out_list = []
              
                if ((int(start) >= sections[0][0] and int(start) <= sections[0][1]) or (int(end) >= sections[0][0] and int(end) <= sections[0][1])) or ((sections[0][0] >= int(start) and sections[0][0] <= int(end)) or (sections[0][1] >= int(start) and sections[0][1] <= int(end))):
                    try:
                        sections.append(gene_anno_dic[rho_gene_name])
                    except:
                        sections.append(rho_gene_name)
                        print(rho_gene_name, "missing annottaion")
                    
                    if rho_gene_name not in intersecting_genes:
                        intersecting_genes.append(rho_gene_name)
          
print("\n",len(intersecting_genes), rho_set_count)
# Out:
# cry1a missing
# cycle missing
# 1319at7088 missing
# 3030at7088 missing
# 7004at7088 missing
# 4746at7088 missing annottaion
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 36
#      32 except:
#      33     print(rho_gene_name, "missing")
# ---> 36 for sections in (fst_dictionary[chromosome]):
#      37     out_list = []
#      40     if (((int(start) >= sections[0][0] and int(start) <= sections[0][1]) or (int(end) >= sections[0][0] and int(end) <= sections[0][1])) or ((sections[0][0] >= int(start) and sections[0][0] <= int(end)) or (sections[0][1] >= int(start) and sections[0][1] <= int(end)))) and len(sections) < 3:
#      41         # print(sections)
#
# KeyError: 'NW_013525054.1'

# %%
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/5.Papilio_polytes"
import numpy 
fst_dictionary = {}
fst_list = []
with open(f"{location}/1.FST_peaks_from_chris/two_pool_5%_0.058_5kb_unmerged.fst",'r') as fst_file:
    for fst_lines in fst_file.readlines()[1:]:
        line_split = fst_lines.strip().split(",")
        
        fst_dictionary.setdefault(line_split[0],[])
        # # try:
        # # if float(line_split[3]) > 0.095:
        fst_dictionary[line_split[0]].append([[int(line_split[1]), int(line_split[2])],float(line_split[3])] )
        # # except:
            # pass
        # break
# print(fst_dictionary)


gene_loc_dic = {}
with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'r') as gene_loc_file:
    for gene_line in gene_loc_file.readlines()[1:]:
        line_split = gene_line.strip().split("\t")
        gene_loc_dic[line_split[0]] = [line_split[1],line_split[2],line_split[3]]
# print(gene_loc_dic)


common_genes = []
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Present_in_all_3_5%/gene_list.txt", 'r') as common_genes_file:
    for common_gene_name in common_genes_file:
        common_genes.append(common_gene_name.strip())


rho_genes = []

with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/4.Rho_genes_and_RhoSet/25_rho_genes.txt", 'r') as rho_genes_file:
    for rho_gene in rho_genes_file:
        rho_genes.append(rho_gene.strip())


intersecting_genes = []
common_counter = []
rho_genes_counter = []







intersecting_genes = []
with open(f"{location}/3.Rho_set_genes/Rho_set_cluster.txt", 'r') as rho_set_file:
    for rho_set_count,lines in enumerate(rho_set_file.readlines()):
        rho_gene_name = lines.strip().split("\t")[0]

        try:
            chromosome,start,end = gene_loc_dic[rho_gene_name]
        except:
            print(rho_gene_name, "missing")
        
        if chromosome in fst_dictionary:
            for sections in (fst_dictionary[chromosome]):
                out_list = []
                
              
                if (((int(start) >= sections[0][0] and int(start) <= sections[0][1]) or (int(end) >= sections[0][0] and int(end) <= sections[0][1])) or ((sections[0][0] >= int(start) and sections[0][0] <= int(end)) or (sections[0][1] >= int(start) and sections[0][1] <= int(end)))) and len(sections) < 3:
                    # print(sections)
                    try:
                        sections.append(f"{gene_anno_dic[rho_gene_name]}")
                    except:
                        sections.append(f"{rho_gene_name}")
                        print(rho_gene_name, "missing annottaion")
                    if rho_gene_name in common_genes:
                        if rho_gene_name not in common_counter:
                            common_counter.append(rho_gene_name)
                        # common_counter += 1
                        try:
                            sections.append(f"{gene_anno_dic[rho_gene_name]}")
                        except:
                            sections.append(f"{rho_gene_name}")
                            print(rho_gene_name, "missing annottaion")
                        if rho_gene_name in rho_genes:
                            if rho_gene_name not in rho_genes_counter:
                                rho_genes_counter.append(rho_gene_name)
                            # common_counter += 1
                            try:
                                sections.append(f"{gene_anno_dic[rho_gene_name]}")
                            except:
                                sections.append(f"{rho_gene_name}")
                                print(rho_gene_name, "missing annottaion")
                    # print(sections)
                    # assert False
                        
                    
                    if rho_gene_name not in intersecting_genes:
                        intersecting_genes.append(rho_gene_name)
            # else:
            #     print(chromosome)
          
print("\n",len(intersecting_genes), rho_set_count, len(common_counter), len(rho_genes_counter))
# Out:
# cry1a missing
# cycle missing
# 1319at7088 missing
# 3030at7088 missing
# 7004at7088 missing
# 4746at7088 missing annottaion
# 5364at7088 missing
# 10387at7088 missing annottaion
# 10387at7088 missing annottaion
# 10387at7088 missing annottaion
# 10387at7088 missing annottaion
# cry2 missing
# 14318at7088 missing annottaion
# 14318at7088 missing annottaion
# 10698at7088 missing annottaion
# 10698at7088 missing annottaion
# 11965at7088 missing annottaion
# 11965at7088 missing annottaion
# 11965at7088 missing annottaion
#
#  291 503 60 4

# %%
output = "CHR,BP,P,SNP,Common,Rho"
chrom_dic = {"NC_053180.1":"1","NC_053181.1":"2","NC_053182.1":"3","NC_053183.1":"4","NC_053184.1":"5","NC_053185.1":"6","NC_053186.1":"7","NC_053187.1":"8","NC_053188.1":"9","NC_053189.1":"10","NC_053190.1":"11","NC_053191.1":"12","NC_053192.1":"13","NC_053193.1":"14","NC_053194.1":"15","NC_053195.1":"16","NC_053196.1":"17","NC_053197.1":"18","NC_053198.1":"19","NC_053199.1":"20","NC_053200.1":"21","NC_053201.1":"22","NC_053202.1":"23","NC_053203.1":"24","NC_053204.1":"25","NC_053205.1":"26","NC_053206.1":"27","NC_053208.1":"Z","NC_053207.1":"W"}
for key,value in fst_dictionary.items():
    print(key)
    
    # chrom = chrom_dic[key]
    chrom = key
    print(chrom)
    for pos in value:
        midpoint = int((pos[0][0] + pos[0][1]) / 2)
        
        # Start building the row
        row = [chrom, midpoint]
        
        # pos[1] is assumed to always exist
        row.append(pos[1])
        
        # Check for pos[2] and pos[3]
        if len(pos) > 4 and pos[4] is not None:
            row.append(pos[2])
            row.append(pos[3])
            row.append(pos[4])
        elif len(pos) > 3 and pos[3] is not None:
            row.append(pos[2])
            row.append(pos[3])
            row.append('')
        elif len(pos) > 2 and pos[2] is not None:
            row.append(pos[2])
            row.append('')
            row.append('')
        else:
            row.append('')  # placeholder if pos[3] missing
            row.append('')
            row.append('')
        output += "\n" + ",".join(map(str, row))
        #     print(pos)
        # # print(output)
        # print(pos) 
        # assert False
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/7.Manhatten/dataset_5_papilio_unmerged.csv", 'w') as out_file:
    out_file.write(output)
# Out:
# NW_013524711.1
# NW_013524711.1
# NW_013524712.1
# NW_013524712.1
# NW_013524739.1
# NW_013524739.1
# NW_013524756.1
# NW_013524756.1
# NW_013524767.1
# NW_013524767.1
# NW_013524785.1
# NW_013524785.1
# NW_013524811.1
# NW_013524811.1
# NW_013524822.1
# NW_013524822.1
# NW_013524823.1
# NW_013524823.1
# NW_013524836.1
# NW_013524836.1
# NW_013524844.1
# NW_013524844.1
# NW_013524846.1
# NW_013524846.1
# NW_013524853.1
# NW_013524853.1
# NW_013524857.1
# NW_013524857.1
# NW_013524860.1
# NW_013524860.1
# NW_013524870.1
# NW_013524870.1
# NW_013524871.1
# NW_013524871.1
# NW_013524879.1
# NW_013524879.1
# NW_013524884.1
# NW_013524884.1
# NW_013524886.1
# NW_013524886.1
# NW_013524900.1
# NW_013524900.1
# NW_013524901.1
# NW_013524901.1
# NW_013524912.1
# NW_013524912.1
# NW_013524930.1
# NW_013524930.1
# NW_013524931.1
# NW_013524931.1
# NW_013524934.1
# NW_013524934.1
# NW_013524935.1
# NW_013524935.1
# NW_013524952.1
# NW_013524952.1
# NW_013524953.1
# NW_013524953.1
# NW_013524957.1
# NW_013524957.1
# NW_013524959.1
# NW_013524959.1
# NW_013524960.1
# NW_013524960.1
# NW_013524969.1
# NW_013524969.1
# NW_013524971.1
# NW_013524971.1
# NW_013524977.1
# NW_013524977.1
# NW_013524979.1
# NW_013524979.1
# NW_013524980.1
# NW_013524980.1
# NW_013524987.1
# NW_013524987.1
# NW_013524991.1
# NW_013524991.1
# NW_013524996.1
# NW_013524996.1
# NW_013525010.1
# NW_013525010.1
# NW_013525013.1
# NW_013525013.1
# NW_013525019.1
# NW_013525019.1
# NW_013525022.1
# NW_013525022.1
# NW_013525024.1
# NW_013525024.1
# NW_013525035.1
# NW_013525035.1
# NW_013525037.1
# NW_013525037.1
# NW_013525046.1
# NW_013525046.1
# NW_013525047.1
# NW_013525047.1
# NW_013525058.1
# NW_013525058.1
# NW_013525059.1
# NW_013525059.1
# NW_013525069.1
# NW_013525069.1
# NW_013525080.1
# NW_013525080.1
# NW_013525087.1
# NW_013525087.1
# NW_013525102.1
# NW_013525102.1
# NW_013525113.1
# NW_013525113.1
# NW_013525124.1
# NW_013525124.1
# NW_013525135.1
# NW_013525135.1
# NW_013525146.1
# NW_013525146.1
# NW_013525157.1
# NW_013525157.1
# NW_013525158.1
# NW_013525158.1
# NW_013525160.1
# NW_013525160.1
# NW_013525168.1
# NW_013525168.1
# NW_013525169.1
# NW_013525169.1
