# %%
location = "/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias"

import os
import subprocess

list_of_files = os.listdir(f"{location}/8.Merged_aligned")
if "desktop.ini" in list_of_files:
    list_of_files.remove("desktop.ini")

print(list_of_files)

for i, file_name in enumerate(list_of_files):
    # print(i)
	subprocess.run(f"clipkit '{location}/8.Merged_aligned/{file_name}' --codon -o  '{location}/9.Clipkit/{file_name}.ClipKIT.fas'", shell = True)
# Out:
# ['clock.fas.best.fas', 'cry1a.fas.best.fas', 'cry1b.fas.best.fas', 'cry2.fas.best.fas', 'cwo.fas.best.fas', 'cycle.fas.best.fas', 'period.fas.best.fas', 'timeless.fas.best.fas', 'timeout.fas.best.fas']
#
# -------------
# | Arguments |
# -------------
# Input file: /mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/8.Merged_aligned/clock.fas.best.fas (format: fasta)
# Output file: /mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/9.Clipkit/clock.fas.best.fas.ClipKIT.fas (format: fasta)
# Sequence type: Nucleotides
# Gaps threshold: 0.9884
# Gap characters: ['-', '?', '*', 'X', 'x', 'N', 'n']
# Trimming mode: smart-gap
# Create complementary output: False
# Process as codons: True
# Create log file: False
#
#
# ------------------------
# | Writing output files |
# ------------------------
# Trimmed alignment: /mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/9.Clipkit/clock.fas.best.fas.ClipKIT.fas
# Complement file: False
# Log file: False
#
#
# ...
