# %%
import os
from Bio import SeqIO
list_of_files = os.listdir("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/3.BUSCO_with_colias_fixed_aligned")
output = ''
for i,files in enumerate(list_of_files):
    if i % 100 == 0:
        print(i)
    fasta_file = SeqIO.parse(f"/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/3.BUSCO_with_colias_fixed_aligned/{files}", 'fasta')
    for record in fasta_file:
        output+= f">{files.split('.')[0]}\n{record.seq.translate().replace('-','')}\n"
        # print(output)
        break
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/10.For_blast/sequences.fas", 'w') as out_file:
    out_file.write(output)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
