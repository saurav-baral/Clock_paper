# %%
import pandas as pd
location = "/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias"

correlation_file = pd.read_csv(f"{location}/1.Rerconverge_result/correlation_annotated.csv")
print(correlation_file)

positive_rho = correlation_file[(correlation_file["q_value"] < 0.1) & (correlation_file["Rho"] < 0)]
print(positive_rho)
positive_rho_list = positive_rho["Name"].str.replace(".fas.best.fas.ClipKIT",'')
positive_rho_list.to_csv(f"{location}/6.GSEA_rho/2.Negative/gene_names.txt", index = False)
# Out:
#                                 Name       Rho    N         P     p.adj  \
# 0         clock.fas.best.fas.ClipKIT  0.216287  122  0.003708  0.150611
# 1         cry1a.fas.best.fas.ClipKIT  0.113959  111  0.145038  0.565190
# 2         cry1b.fas.best.fas.ClipKIT  0.032394   85  0.717723  0.933877
# 3          cry2.fas.best.fas.ClipKIT  0.159814  119  0.034233  0.337970
# 4           cwo.fas.best.fas.ClipKIT  0.179292  113  0.020686  0.287323
# ...                              ...       ...  ...       ...       ...
# 4566  988at7088.fas.best.fas.ClipKIT -0.111300  108  0.160449  0.586672
# 4567  992at7088.fas.best.fas.ClipKIT  0.068657  110  0.382152  0.771221
# 4568  993at7088.fas.best.fas.ClipKIT  0.092394   66  0.365208  0.759361
# 4569  994at7088.fas.best.fas.ClipKIT -0.155708   75  0.103174  0.495906
# 4570  998at7088.fas.best.fas.ClipKIT  0.084602   95  0.317625  0.724400
#
#        q_value  Pref_name
# 0     0.122277      clock
# 1     0.458863      cry1a
# ...
