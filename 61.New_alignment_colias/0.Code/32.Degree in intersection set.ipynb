# %%
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics"

intersection_gene_count = {}

species_folder_list = ["3.Pararge_aegeria","2.Pieris_napi","1.Lasiomatta_megera"]

for species_folder in species_folder_list:
    with open(f"{location}/{species_folder}/4.Intersections_test/intersection_set.txt",'r') as intersection_file:
        for lines in intersection_file:
            lines_split = lines.strip().split(",")
            intersection_gene_count.setdefault(lines_split[0],0)
            intersection_gene_count[lines_split[0]] += 1
            # print(lines_split)
            # break
    # intersection_gene_count
#     cluster_species[species_folder] = {}
#     for key in cluster_count_dict["Full"]:
#        cluster_species[species_folder][key] = 0 

#     
#         
#             cluster = gene_cluster_dict[lines_split[0]]
#             # print(lines,cluster)
#             cluster_species[species_folder][cluster]+= 1
# print(cluster_species)
print(len(intersection_gene_count))
# Out:
# 181

# %%
degree_dict = {}
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/12.Rho_networks/2.Diapausing/Gene_cluster_degree.csv") as degree_file:
    for line in degree_file.readlines()[1:]:
        
        lines_split = line.strip().split(",")
        # print(lines_split)
        degree_dict[lines_split[0]] = lines_split[4]
        # break

# %%
output = "Intersection,Degree"
for gene, count in intersection_gene_count.items():
    output += f"\n{str(count)},{degree_dict[gene]}"
print(output)
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/14.Plot degree vs intersction/intersection_countvsdegree.csv", 'w') as out_file:
    out_file.write(output)
# Out:
# Intersection,Degree
# 1,68
# 2,40
# 1,15
# 3,35
# 2,15
# 2,27
# 2,45
# 1,138
# 1,49
# 1,64
# 2,23
# 2,39
# 2,34
# 1,42
# 1,12
# 1,8
# 2,13
# 1,4
# 1,12
# 2,79
# 2,12
# 1,83
# 1,59
# 1,28
# 1,79
# 2,38
# 1,86
# 2,13
# 1,83
# 1,119
# 1,39
# 2,87
# 1,13
# 1,16
# 1,47
# 1,35
# 1,11
# 2,25
# 1,5
# 1,40
# 2,40
# 1,38
# 3,35
# 2,38
# 3,166
# 1,45
# 1,73
# 1,31
# 1,7
# 2,4
# 1,9
# 2,16
# 2,117
# 2,78
# 1,9
# 2,15
# 3,24
# 1,48
# 1,5
# 1,12
# 1,12
# 1,25
# 1,26
# 1,75
# 1,60
# 1,6
# 2,64
# 2,14
# 1,79
# 1,30
# 1,23
# 1,9
# 2,35
# 2,2
# 1,43
# 3,34
# 2,7
# 2,34
# 1,28
# 1,91
# 1,25
# 1,8
# 2,26
# 2,15
# 1,44
# 2,7
# 1,39
# 1,90
# 1,8
# 1,17
# 1,76
# 1,18
# 1,21
# 1,81
# 1,34
# 1,6
# 1,72
# 1,62
# 2,3
# 1,46
# 1,36
# 1,51
# 1,36
# 2,8
# 1,14
# 1,40
# 1,105
# 2,39
# 1,14
# 1,91
# 1,10
# 1,109
# 2,17
# 2,34
# 1,21
# 2,92
# 2,4
# 1,15
# 1,38
# 1,20
# 1,10
# 1,153
# 1,79
# 1,15
# 1,16
# 1,13
# 1,8
# 1,64
# 1,11
# 1,7
# 1,20
# 1,29
# 1,15
# 1,50
# 1,28
# 1,49
# 1,17
# 1,6
# 1,12
# 1,63
# 1,65
# ...
