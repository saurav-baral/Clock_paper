# %%
import os
from Bio import SeqIO

from Bio.Seq import Seq


def sequence_extractor(Species, Scaff, reverse_c, start, end, frame = 1, trans = 1 ):
    from Bio import SeqIO
    from Bio.Seq import Seq
    import os
    
    out_Seq = ''
    
    
    
    #Genome folder
    # entries = os.listdir("/mnt/f/Genomes_2023-12-26/"+Species)
    entries = os.listdir("/mnt/griffin/saubar/Genomes_2023-12-26/"+Species)
    
    #Get genome file from Genome folder
    for file_names  in entries:
        if ".nhr" in file_names:
            Genome_name = file_names[:-4]
            break
    
    #Read the genome file
    # fasta_file = SeqIO.parse(("/mnt/f/Genomes_2023-12-26/"+Species+"/"+Genome_name),'fasta')
    fasta_file = SeqIO.parse(("/mnt/griffin/saubar/Genomes_2023-12-26/"+Species+"/"+Genome_name),'fasta')
    
    #Extract the sequence 
    for record in fasta_file:
        if record.id == Scaff:
            sequence = str(record.seq)
            out_Seq = Seq(sequence[start-1:end])
            if reverse_c == 1:
                out_Seq = out_Seq.reverse_complement()
            break
                
    if len(out_Seq) < 10000: #fixing error due to mistake in typing the coordinate, change this for longer sequence
#        print (out_Seq)
        if frame == 1 :
            out_trans = out_Seq[0:]
        if frame == 2 :
            out_trans = out_Seq[1:]
        if frame == 3 :
            out_trans = out_Seq[2:]
    else:
        print ("too long")
        assert(False)
        
        
    #    break
    
    if trans == 1:
        return (out_trans.translate())
    else:
        return(out_Seq)

# %%
def get_sequence(Species, Scaff, reverse_c, start, end, frame = 1, trans = 1 ):
    
    #Genome folder
    entries = os.listdir("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/5.Genome/"+Species+"/1.Genome")
    
    #Get genome file from Genome folder
    for file_names  in entries:
        if ".nhr" in file_names:
            Genome_name = file_names[:-4]
            break
    
    #Read the genome file
    fasta_file = SeqIO.parse(("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/5.Genome/"+Species+"/1.Genome"+"/"+Genome_name),'fasta')
    
    #Extract the sequence 
    for record in fasta_file:
        if record.id == Scaff:
            sequence = str(record.seq)
#             out_Seq = Seq(sequence[start-1:end])
#             if reverse_c == 1:
#                 sequence = out_Seq.reverse_complement()
            return(sequence)
    
#

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue May 28 13:35:56 2024

@author: sauba
"""



# file_location = os.getcwd()
# family_group = file_location.split("/")[-1]

# blast_location = f"/mnt/griffin/saubar/Working_folder_circadian_rhythm/11.CWO_Exon_Analysis/{family_group}"

location  = "/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/5.Genome"


query_location = f"{location}/4.Queries"
query_transcript_list = os.listdir(f"{query_location}")

print(query_transcript_list)

# query_species = "Bicyclus_anynana"
# 
# if "desktop.ini" in query_transcript_list:
#     query_transcript_list.remove("desktop.ini")

species_list = ["1.Colias_eurytheme","2.Colias_palaeno"]

for query_transcript in query_transcript_list:
# query_transcript = query_transcript_list[0]
# #Get Species list, the list may be a list of files or a single species

# species_list = os.listdir(f"{blast_location}/1.Blast_result")

# if "desktop.ini" in species_list:
#     species_list.remove('desktop.ini')

# #get list of query names

    query_file = SeqIO.parse(f"{query_location}/{query_transcript}", 'fasta')
    query_name_list = []
    gene_name = query_transcript.split("_")[0]
    for records in query_file:
        query_name_list.append(records.id)



    for species in species_list:
        print(species)
#     # species = species_name.split(".")[1]
        header = "Species," + "Scaffold," + "Start," + "Stop," + "Complement," + "Error," + "Gene,"+ "Query_start," + "Query_stop,"+ "Query_Length\n" 
        Output_Sequence = header
        scaff = "Intial_value"
        scaff_old = "Intial_value"
        old_end = 0
    
# #Run for each query in the query list
        for i in range(len(query_name_list)):
            query_name = query_name_list[i]
# #         print(f"Query name = {query_name}")
            Length_switch = "0"
            with open(f"{location}/{species}/{gene_name}.txt",'r') as tblast_out:
                lines_in_file = tblast_out.readlines()
#         #print(lines_in_file)

            result_section_switch = 0
            start_coor_switch = 0
            query_start_coor_switch = 0
            stop_coor_switch = 0
            error = "N"
            break_switch = 0
    
            start = 0
            stop = 0
            start_coor = 0
            stop_coor = 0
            query_length = 0

            for lines in lines_in_file:

# #             print(lines)
                if query_name in lines:
# #                 print(lines)
# #                 assert False
#             #Initialize that results can now be checked
                    result_section_switch = 1
# #                 query_species_split = lines.split(" ")[1].split("_")
# #                 query_species = str(query_species_split[0].split(".")[1]+"_"+query_species_split[1].rstrip())
#                 print(query_species)
                if result_section_switch == 1 and "Lambda" in lines:
#             #This block indicates end of the results block in blast output
                    result_section_switch == 0
                
                    break

                if result_section_switch == 1:
#             #While checking the result
                    if "Length=" in lines and Length_switch == "0":
#                 #Get query length from the blast output
                    
                        query_length = int(lines.split("=")[1].rstrip())
                        
                        Length_switch = 1 #Indicated length has been acquired
                    
                    if ("Score" in lines or ">" in lines) and (start_coor_switch == 1):
#     #                print (lines)
                        break
        
                    if ">" in lines:
#                 #Start of the first result
                        # print(lines.split(" "))
                        if " " in lines:
                            scaff = lines.split(" ")[0][1:] #Scaffold from the result
                        else:
                            scaff = lines[1:-1]
                        print(scaff)
                        # assert False
                        if scaff_old != "Intial_value" and scaff_old != scaff:
                            error = "Y"
                        scaff_old = scaff
                    
                    if "Query" in lines and "=" not in lines:
#                 #Read the query line in output
                        if query_start_coor_switch == 0:
    #                        print(lines)
                            query_start_coor = int(lines.split(" ")[2])
                            query_start_coor_switch = 1
                            #Query start coordinate fixed
            
                        query_stop_coor =int(lines.split(" ")[-1][:-1])
#                     #Keep getting query stop coordinates for multiline result
#     #                print (stop_coor)
                    
                    if "Sbjct" in lines:
                    #Read the blast target line
                        if start_coor_switch == 0:
                            start_coor = int(lines.split(" ")[2])
                            start_coor_switch = 1
                        stop_coor =int(lines.split(" ")[-1][:-1])
                        #Keep getting target stop coordinates for multiline result
                
                

        
            if break_switch == 1:
                break

            if start_coor < stop_coor:
                complement = "0" #Forward complement
                
                length = (stop_coor-start_coor)/3
                start = start_coor
                stop = stop_coor
    
            elif start_coor > stop_coor:
                complement = "1" #Reverse complement
                length = (-stop_coor+start_coor)/3
                start = stop_coor
                stop = start_coor
    
            else:
                length = 0
                start = 000
                stop = 000
                query_start_coor = 000
                query_stop_coor = 000
                error = "Y"
                complement  = 0
        
        
        
        

#         #Check if the length of target (blast hit) is significantly smaller than query
            if length < query_length - 0.2*query_length:
                error = "Y"
    
            old_trans = ''
    #             print(start, stop)
            
    
    
        

# #Check for Met or STOP at the start and end
            sequence = ''
            while True and (start != 0 or stop != 0):
                if (query_name == query_name_list[0] or query_name == query_name_list[-1]):
                    frame = 1
    #                 translated_sequence = (sequence_extractor(species, scaff, int(complement), start, stop,frame ))
                    if sequence == '':
                        sequence = get_sequence(species, scaff, int(complement), start, stop,frame)
                    if int(complement) == 1:
                        translated_sequence = Seq(sequence[start-1:stop]).reverse_complement().translate()
                    else:
                        translated_sequence = Seq(sequence[start-1:stop]).translate()
                    if translated_sequence == old_trans:
                        break
                    
# #Check for Met at the beginning of first exon

                    if query_name == query_name_list[0] :
                        if translated_sequence[0] != "M":
                            print(translated_sequence)
    #                             print(start, stop)
                            if complement == "0":
                                start = int(start) - 3
                            if complement == "1":
                                stop = int(stop) + 3
                            old_trans = translated_sequence
                        if "*" in translated_sequence:
                            error = "Y"
                            break
                        if translated_sequence[0] == "M":
                            break

# #Check for stop at the end of last exon

                    if query_name == query_name_list[-1]:
                        if translated_sequence[-1] != "*":
                            print(translated_sequence)
    #                             print(start, stop)
                            if complement == "0":
                                stop = int(stop) + 3
                            if complement == "1":
                                start = int(start) - 3
                            old_trans = translated_sequence
                        if translated_sequence[-1] == "*":
    
                            break
                else:
                    break
        
        
# #Add offset at the beginning and end of each exon
            if (start != 0 or stop != 0):
                
                start_modifier = int(query_name.split("Frame")[1][1])
                stop_modifier = int(query_name.split("rightoh")[1][1])
            else:
                start_modifier = 0
                stop_modifier = 0            
    
            seq_length = query_length
        
        
# #Get exon start and end by adding or removing codons
        
#     #if not the beginning
            if query_start_coor != "1" and query_name != query_name_list[0]:
                if complement == "0":
                    start = int(start) - 3*(int(query_start_coor)-1)                
                if complement == "1":
                    stop = int(stop) + 3*(int(query_start_coor)-1)
        
        #For the end
            if query_stop_coor != str(seq_length) and query_name != query_name_list[-1]:
                if complement == "0":
                    stop = int(stop) + 3*(int(seq_length)-int(query_stop_coor))
                if complement == "1":
                    
    
                    start = int(start) - 3*(int(seq_length)-int(query_stop_coor))
     
        
        
        
# #Adding or removing 3' and 5' overhangs for forward and reverse complement
#     #For forward complement
            if complement == "0":
                start = int(start) - int(start_modifier)
                stop = int(stop) +  int(stop_modifier)
                if old_end != 0 and old_end > stop:
    
                    error = "Y"
                old_end = stop
    
        #For reverse complement
            if complement == "1":
                start = int(start) - int(stop_modifier)
                stop = int(stop) +  int(start_modifier)
                if old_end != 0 and old_end < stop:
                    error = "Y"
                old_end = stop
    
        #Simple check for lenghth
            if start == 0 or stop == 0:
                error = "Y"
            
           
            output_format = str(species.split("\n")[0])+"," + str(scaff) +"," + str(start)+"," + str(stop)+"," + str(complement)+"," + str(error)+  ","+ str(query_name)+","+ str(query_start_coor)+","+str(query_stop_coor)+","+str(query_length)+ "\n"  
            # print(output_format)
# #         assert False
            Output_Sequence = Output_Sequence + output_format

        print(Output_Sequence)
        # assert False
   
        output_file = open(f"{location}/{species}/{gene_name}_coordinates_old.csv",'w')
        output_file.write(Output_Sequence)
        output_file.close()
# Out:
# ['clock_query.fas', 'cry1_query.fas', 'cry2_query.fas', 'cwo_query.fas', 'cycle_query.fas', 'period_query.fas', 'timeless_query.fas', 'timeout_query.fas']
# 1.Colias_eurytheme
# CHR1
# CHR1
# CHR1
# CHR1
# CHR1
# CHR1
# CHR1
# CHR1
# CHR1
# CHR1
# CHR1
# CHR1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# 1.Colias_eurytheme,Intial_value,0,0,0,Y,Colias_croceus_XM_045653427.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
# 1.Colias_eurytheme,CHR1,11285717,11285865,0,N,Colias_croceus_XM_045653427.1_Frame_1_rightoh_1_query_Exon_2,1,48,49
# 1.Colias_eurytheme,CHR1,11286345,11286526,0,Y,Colias_croceus_XM_045653427.1_Frame_2_rightoh_0_query_Exon_3,1,39,60
# 1.Colias_eurytheme,CHR1,11286647,11286764,0,N,Colias_croceus_XM_045653427.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# 1.Colias_eurytheme,CHR1,11289148,11289243,0,N,Colias_croceus_XM_045653427.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# 1.Colias_eurytheme,CHR1,11289724,11289781,0,N,Colias_croceus_XM_045653427.1_Frame_2_rightoh_2_query_Exon_6,1,18,18
# 1.Colias_eurytheme,CHR1,11290135,11290373,0,N,Colias_croceus_XM_045653427.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# 1.Colias_eurytheme,CHR1,11290727,11290874,0,N,Colias_croceus_XM_045653427.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# 1.Colias_eurytheme,CHR1,11291170,11291350,0,N,Colias_croceus_XM_045653427.1_Frame_1_rightoh_0_query_Exon_9,1,60,60
# 1.Colias_eurytheme,CHR1,11291920,11292096,0,Y,Colias_croceus_XM_045653427.1_Frame_0_rightoh_0_query_Exon_10,27,48,59
# 1.Colias_eurytheme,CHR1,11293997,11294206,0,N,Colias_croceus_XM_045653427.1_Frame_0_rightoh_0_query_Exon_11,1,74,74
# 1.Colias_eurytheme,CHR1,11296771,11296905,0,N,Colias_croceus_XM_045653427.1_Frame_0_rightoh_0_query_Exon_12,1,45,45
# 1.Colias_eurytheme,CHR1,11298524,11298679,0,N,Zerene_cesonia_XM_038360269.1_Frame_0_rightoh_0_query_Exon_13,1,53,53
#
# 2.Colias_palaeno
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# 2.Colias_palaeno,Intial_value,0,0,0,Y,Colias_croceus_XM_045653427.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
# 2.Colias_palaeno,OZ177444.1,14018119,14018267,0,N,Colias_croceus_XM_045653427.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# 2.Colias_palaeno,OZ177444.1,14019646,14019827,0,N,Colias_croceus_XM_045653427.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# 2.Colias_palaeno,OZ177444.1,14019918,14020035,0,N,Colias_croceus_XM_045653427.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# 2.Colias_palaeno,OZ177444.1,14022470,14022565,0,N,Colias_croceus_XM_045653427.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# 2.Colias_palaeno,OZ177444.1,14023051,14023108,0,N,Colias_croceus_XM_045653427.1_Frame_2_rightoh_2_query_Exon_6,1,18,18
# 2.Colias_palaeno,OZ177444.1,14023268,14023506,0,N,Colias_croceus_XM_045653427.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# 2.Colias_palaeno,OZ177444.1,14023862,14024009,0,N,Colias_croceus_XM_045653427.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
0,N,14.Zerene_cesonia_XM_038360763.1_Frame_1_rightoh_1_query_Exon_3,1,51,51
# 1.Colias_eurytheme,CHR1,10770375,10770460,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_2_rightoh_0_query_Exon_4,1,29,29
# 1.Colias_eurytheme,CHR1,10772654,10772710,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_5,1,19,19
# 1.Colias_eurytheme,CHR1,10772945,10773076,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_6,1,44,44
# 1.Colias_eurytheme,CHR1,10774135,10774210,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_1_query_Exon_7,1,25,25
# 1.Colias_eurytheme,CHR1,10775895,10776086,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_2_rightoh_1_query_Exon_8,1,63,63
# 1.Colias_eurytheme,CHR1,10776440,10776668,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_2_rightoh_2_query_Exon_9,1,75,75
# 1.Colias_eurytheme,CHR1,10777525,10777636,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_1_rightoh_0_query_Exon_10,1,37,37
# 1.Colias_eurytheme,CHR1,10777749,10777868,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_11,1,40,40
# 1.Colias_eurytheme,CHR1,10778181,10778330,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_12,1,50,50
# 1.Colias_eurytheme,CHR1,10778671,10778789,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_2_query_Exon_13,1,39,39
# 1.Colias_eurytheme,CHR1,10779171,10779269,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_1_rightoh_2_query_Exon_14,1,32,32
# 1.Colias_eurytheme,CHR1,10779641,10779781,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_1_rightoh_2_query_Exon_15,1,46,46
# 1.Colias_eurytheme,CHR1,10780086,10780263,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_1_rightoh_0_query_Exon_16,1,59,59
# 1.Colias_eurytheme,CHR1,10782619,10782766,0,N,32.Colias_croceus_XM_045653731.1_Frame_0_rightoh_1_query_Exon_17,1,49,49
# 1.Colias_eurytheme,CHR1,10783421,10783528,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_2_rightoh_1_query_Exon_18,1,37,37
# 1.Colias_eurytheme,CHR1,10784023,10784127,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_2_rightoh_1_query_Exon_19,1,35,35
# 1.Colias_eurytheme,CHR1,10784616,10784779,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_2_rightoh_0_query_Exon_20,1,54,54
# 1.Colias_eurytheme,CHR1,10787231,10787374,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_21,1,48,48
# 1.Colias_eurytheme,CHR1,10788566,10788727,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_22,1,54,54
# 1.Colias_eurytheme,CHR1,10788955,10789041,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_23,1,29,29
# 1.Colias_eurytheme,CHR1,10789502,10789603,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_24,1,34,34
# 1.Colias_eurytheme,CHR1,10790266,10790409,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_25,1,48,48
# 1.Colias_eurytheme,CHR1,10791381,10791482,0,N,32.Colias_croceus_XM_045653731.1_Frame_0_rightoh_0_query_Exon_26,1,34,34
#
# 2.Colias_palaeno
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# OZ177444.1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# 2.Colias_palaeno,OZ177444.1,13389521,13389606,0,N,32.Colias_croceus_XM_045653731.1_Frame_0_rightoh_2_query_Exon_1,1,28,28
# 2.Colias_palaeno,OZ177444.1,13390443,13390526,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_1_rightoh_2_query_Exon_2,1,27,27
# 2.Colias_palaeno,OZ177444.1,13394117,13394271,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_1_rightoh_1_query_Exon_3,1,51,51
# 2.Colias_palaeno,OZ177444.1,13395386,13395474,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_2_rightoh_0_query_Exon_4,1,29,29
# 2.Colias_palaeno,OZ177444.1,13395940,13395996,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_5,1,19,19
# 2.Colias_palaeno,OZ177444.1,13397351,13397482,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_6,1,44,44
# 2.Colias_palaeno,OZ177444.1,13398551,13398626,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_1_query_Exon_7,1,25,25
# 2.Colias_palaeno,OZ177444.1,13400311,13400502,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_2_rightoh_1_query_Exon_8,1,63,63
# 2.Colias_palaeno,OZ177444.1,13400713,13400941,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_2_rightoh_2_query_Exon_9,1,75,75
# 2.Colias_palaeno,OZ177444.1,13401803,13401914,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_1_rightoh_0_query_Exon_10,1,37,37
# 2.Colias_palaeno,OZ177444.1,13402017,13402136,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_11,1,40,40
# 2.Colias_palaeno,OZ177444.1,13402261,13402410,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_12,1,50,50
# 2.Colias_palaeno,OZ177444.1,13402753,13402871,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_2_query_Exon_13,1,39,39
# 2.Colias_palaeno,OZ177444.1,13403259,13403357,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_1_rightoh_2_query_Exon_14,1,32,32
# 2.Colias_palaeno,OZ177444.1,13403556,13403696,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_1_rightoh_2_query_Exon_15,1,46,46
# 2.Colias_palaeno,OZ177444.1,13404186,13404363,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_1_rightoh_0_query_Exon_16,1,59,59
# 2.Colias_palaeno,OZ177444.1,13404672,13404819,0,N,32.Colias_croceus_XM_045653731.1_Frame_0_rightoh_1_query_Exon_17,2,49,49
# 2.Colias_palaeno,OZ177444.1,13405205,13405312,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_2_rightoh_1_query_Exon_18,1,37,37
# 2.Colias_palaeno,OZ177444.1,13405607,13405714,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_2_rightoh_1_query_Exon_19,1,35,35
# 2.Colias_palaeno,OZ177444.1,13408044,13408207,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_2_rightoh_0_query_Exon_20,1,54,54
# 2.Colias_palaeno,OZ177444.1,13410587,13410730,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_21,1,48,48
# 2.Colias_palaeno,OZ177444.1,13411920,13412081,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_22,1,54,54
# 2.Colias_palaeno,OZ177444.1,13412309,13412395,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_23,1,29,29
# 2.Colias_palaeno,OZ177444.1,13412521,13412622,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_24,1,34,34
# 2.Colias_palaeno,OZ177444.1,13412962,13413105,0,N,14.Zerene_cesonia_XM_038360763.1_Frame_0_rightoh_0_query_Exon_25,1,48,48
# 2.Colias_palaeno,OZ177444.1,13413654,13413755,0,N,32.Colias_croceus_XM_045653731.1_Frame_0_rightoh_0_query_Exon_26,1,34,34
#
# 1.Colias_eurytheme
# CHR2
# CHR2
# CHR2
# CHR2
# CHR2
# CHR2
# CHR2
# CHR2
# CHR2
# CHR2
# CHR2
# CHR2
# CHR2
# CHR2
# CHR2
# CHR2
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# 1.Colias_eurytheme,CHR2,7213038,7213134,1,N,Colias_croceus_XM_045654792.1_Frame_0_rightoh_1_query_Exon_1,1,32,32
# 1.Colias_eurytheme,CHR2,7211967,7212514,1,N,Zerene_cesonia_XM_038355360.1_Frame_2_rightoh_0_query_Exon_2,1,182,182
# 1.Colias_eurytheme,CHR2,7211339,7211492,1,N,Zerene_cesonia_XM_038355360.1_Frame_0_rightoh_1_query_Exon_3,1,51,51
# 1.Colias_eurytheme,CHR2,7211024,7211253,1,N,Zerene_cesonia_XM_038355360.1_Frame_2_rightoh_0_query_Exon_4,1,76,76
# 1.Colias_eurytheme,CHR2,7210588,7210880,1,N,Zerene_cesonia_XM_038355360.1_Frame_0_rightoh_2_query_Exon_5,1,97,97
# 1.Colias_eurytheme,CHR2,7210143,7210503,1,N,Zerene_cesonia_XM_038355360.1_Frame_1_rightoh_0_query_Exon_6,1,120,120
# 1.Colias_eurytheme,CHR2,7209634,7209825,1,N,Zerene_cesonia_XM_038355360.1_Frame_0_rightoh_0_query_Exon_7,1,64,64
# 1.Colias_eurytheme,CHR2,7209430,7209530,1,N,Zerene_cesonia_XM_038355360.1_Frame_0_rightoh_2_query_Exon_8,1,33,33
# 1.Colias_eurytheme,CHR2,7208396,7208594,1,N,Zerene_cesonia_XM_038355360.1_Frame_1_rightoh_0_query_Exon_9,1,66,66
# 1.Colias_eurytheme,CHR2,7208041,7208246,1,N,Zerene_cesonia_XM_038355360.1_Frame_0_rightoh_2_query_Exon_10,1,62,63
# 1.Colias_eurytheme,CHR2,7207329,7207819,1,N,Zerene_cesonia_XM_038355360.1_Frame_1_rightoh_1_query_Exon_11,1,163,163
# 1.Colias_eurytheme,CHR2,7207027,7207227,1,N,Zerene_cesonia_XM_038355360.1_Frame_2_rightoh_1_query_Exon_12,1,66,66
# 1.Colias_eurytheme,CHR2,7206702,7206873,1,N,Zerene_cesonia_XM_038355360.1_Frame_2_rightoh_2_query_Exon_13,2,54,54
# 1.Colias_eurytheme,CHR2,7206486,7206590,1,N,Zerene_cesonia_XM_038355360.1_Frame_1_rightoh_2_query_Exon_14,1,34,34
# 1.Colias_eurytheme,CHR2,7205901,7206101,1,N,Zerene_cesonia_XM_038355360.1_Frame_1_rightoh_2_query_Exon_15,1,67,67
# 1.Colias_eurytheme,CHR2,7205560,7205743,1,N,Colias_croceus_XM_045654792.1_Frame_1_rightoh_0_query_Exon_16,1,61,61
#
# 2.Colias_palaeno
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# OZ177447.1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# 2.Colias_palaeno,OZ177447.1,7566896,7566992,1,N,Colias_croceus_XM_045654792.1_Frame_0_rightoh_1_query_Exon_1,1,32,32
# 2.Colias_palaeno,OZ177447.1,7565813,7566360,1,N,Zerene_cesonia_XM_038355360.1_Frame_2_rightoh_0_query_Exon_2,1,182,182
# 2.Colias_palaeno,OZ177447.1,7565154,7565307,1,N,Zerene_cesonia_XM_038355360.1_Frame_0_rightoh_1_query_Exon_3,1,51,51
# 2.Colias_palaeno,OZ177447.1,7564795,7565024,1,N,Zerene_cesonia_XM_038355360.1_Frame_2_rightoh_0_query_Exon_4,1,76,76
# 2.Colias_palaeno,OZ177447.1,7564344,7564639,1,N,Zerene_cesonia_XM_038355360.1_Frame_0_rightoh_2_query_Exon_5,1,97,97
# 2.Colias_palaeno,OZ177447.1,7563898,7564258,1,N,Zerene_cesonia_XM_038355360.1_Frame_1_rightoh_0_query_Exon_6,1,120,120
# 2.Colias_palaeno,OZ177447.1,7562551,7562742,1,N,Zerene_cesonia_XM_038355360.1_Frame_0_rightoh_0_query_Exon_7,1,64,64
# 2.Colias_palaeno,OZ177447.1,7562347,7562447,1,N,Zerene_cesonia_XM_038355360.1_Frame_0_rightoh_2_query_Exon_8,1,33,33
# 2.Colias_palaeno,OZ177447.1,7561874,7562072,1,N,Zerene_cesonia_XM_038355360.1_Frame_1_rightoh_0_query_Exon_9,1,66,66
# 2.Colias_palaeno,OZ177447.1,7561498,7561703,1,N,Zerene_cesonia_XM_038355360.1_Frame_0_rightoh_2_query_Exon_10,1,63,63
# 2.Colias_palaeno,OZ177447.1,7560794,7561284,1,N,Zerene_cesonia_XM_038355360.1_Frame_1_rightoh_1_query_Exon_11,1,163,163
# 2.Colias_palaeno,OZ177447.1,7560493,7560693,1,N,Zerene_cesonia_XM_038355360.1_Frame_2_rightoh_1_query_Exon_12,1,66,66
# 2.Colias_palaeno,OZ177447.1,7560176,7560350,1,N,Zerene_cesonia_XM_038355360.1_Frame_2_rightoh_2_query_Exon_13,2,54,54
# 2.Colias_palaeno,OZ177447.1,7559866,7559970,1,N,Zerene_cesonia_XM_038355360.1_Frame_1_rightoh_2_query_Exon_14,1,34,34
# 2.Colias_palaeno,OZ177447.1,7559137,7559340,1,N,Zerene_cesonia_XM_038355360.1_Frame_1_rightoh_2_query_Exon_15,2,67,67
# 2.Colias_palaeno,OZ177447.1,7558811,7558994,1,N,Colias_croceus_XM_045654792.1_Frame_1_rightoh_0_query_Exon_16,1,61,61
#
# 1.Colias_eurytheme
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# CHR10
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# 1.Colias_eurytheme,CHR10,10917414,10917667,1,N,Zerene_cesonia_XM_038367126.1_Frame_0_rightoh_2_query_Exon_1,1,84,84
# 1.Colias_eurytheme,CHR10,10916978,10917161,1,N,Colias_croceus_XM_045638192.1_Frame_1_rightoh_0_query_Exon_2,1,61,61
# 1.Colias_eurytheme,CHR10,10916496,10916630,1,N,Colias_croceus_XM_045638192.1_Frame_0_rightoh_0_query_Exon_3,1,45,45
# 1.Colias_eurytheme,CHR10,10915808,10916064,1,N,Colias_croceus_XM_045638192.1_Frame_0_rightoh_2_query_Exon_4,1,85,85
# 1.Colias_eurytheme,CHR10,10914911,10915108,1,N,Colias_croceus_XM_045638192.1_Frame_1_rightoh_2_query_Exon_5,1,65,65
# 1.Colias_eurytheme,CHR10,10914325,10914507,1,N,Colias_croceus_XM_045638192.1_Frame_1_rightoh_2_query_Exon_6,1,60,60
# 1.Colias_eurytheme,CHR10,10913794,10913926,1,N,Colias_croceus_XM_045638192.1_Frame_1_rightoh_0_query_Exon_7,1,44,44
# 1.Colias_eurytheme,CHR10,10913259,10913413,1,N,Colias_croceus_XM_045638192.1_Frame_0_rightoh_2_query_Exon_8,1,51,51
# 1.Colias_eurytheme,CHR10,10912349,10912467,1,N,Colias_croceus_XM_045638192.1_Frame_1_rightoh_1_query_Exon_9,1,39,39
