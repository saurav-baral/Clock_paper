# %%
anno_dict = {}

with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/12.Rho_networks/2.Diapausing/Filtered_set_core_set.csv", 'r') as core_file:
    for lines in core_file.readlines()[1:]:
        lines_split = lines.strip().split(",")
        # print(lines_split)
        if lines_split[0] not in anno_dict:
            anno_dict[lines_split[3]] = lines_split[0]
        if lines_split[1] not in anno_dict:
            anno_dict[lines_split[4]] = lines_split[1]
        # print(anno_dict)
        # assert False

# %%
degre_dict = {}
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/12.Rho_networks/2.Diapausing/Filtered_set_core_set_degree.csv", 'r') as degree_file:
    for lines in degree_file.readlines()[1:]:
        lines_split = lines.strip().split(",")
        degre_dict[anno_dict[lines_split[0]]] = lines_split[1]
        # print(degre_dict)
        # assert False

# %%
import os
gene_list_degree_dict = {}

list_of_gene_lists = os.listdir("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Upset_plot_deconstructed_for_degree/1.Gene_lists")

for file_name in list_of_gene_lists:
    output = "Gene,Degree"
    gene_list_degree_dict[file_name[:-4]] = []
    with open(f"/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Upset_plot_deconstructed_for_degree/1.Gene_lists/{file_name}", 'r') as gene_list_file:
        for lines in gene_list_file:
            gene_name = lines.strip()
            gene_list_degree_dict[file_name[:-4]].append(degre_dict[gene_name])
            output += f"\n{gene_name},{degre_dict[gene_name]}"
            # print(output)
            # assert False
        with open(f"/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Upset_plot_deconstructed_for_degree/2.Gene_degree_list/{file_name}",'w') as out_file:
            out_file.write(output)

# %%
print(gene_list_degree_dict)
# Out:
# {'all_three': ['51', '153', '73', '23', '109', '27', '109', '48', '81', '35', '14', '64', '23', '12', '16', '6', '34', '23', '9', '28', '78', '26', '6', '12', '79', '32', '63', '3', '65', '13', '2', '35', '75', '56', '63', '40', '102', '2', '75', '69', '34', '21', '39', '3', '11', '4', '2', '46', '7', '34', '1', '25', '11', '16', '13', '11', '12', '24', '16', '25', '39', '20', '79', '91', '91', '78', '166', '86', '38', '38', '14', '15', '39', '58', '21', '83', '90', '8', '7', '4', '60', '14', '8', '25', '119', '26', '60', '75', '44', '25', '8', '11', '117', '83', '11'], 'lassiommata_only': ['12', '20', '38', '20', '79', '30', '26', '91', '13', '22', '18', '25', '22', '20', '9', '17', '26', '29', '41', '15', '28', '55', '20', '33', '15', '45', '125', '7', '2', '35', '16', '20', '17', '29', '12', '50', '31', '84', '20', '27', '4', '8', '33', '10', '5', '23', '55', '36', '29', '91', '34', '16', '42', '47'], 'las_napi_only': ['3', '29', '10', '70', '11', '39', '115', '15', '45', '49', '1
# ...

# %%
import os

list_of_gene_lists = os.listdir("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Upset_plot_deconstructed_for_degree/1.Gene_lists")

# %%
import pandas as pd

# df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in gene_list_degree_dict.items()]))
# print(df)

df = pd.DataFrame([
    {'group': key, 'degree': val}
    for key, vals in gene_list_degree_dict.items()
    for val in vals
])

print(df)
# Out:
#             group degree
# 0       all_three     51
# 1       all_three    153
# 2       all_three     73
# 3       all_three     23
# 4       all_three    109
# ..            ...    ...
# 429  pararge_only      4
# 430  pararge_only    124
# 431  pararge_only     16
# 432  pararge_only     31
# 433  pararge_only      6
#
# [434 rows x 2 columns]

# %%
df.to_csv("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Upset_plot_deconstructed_for_degree/group_degree.csv", index = False)
