# %%
anno_names_list = []

location = "/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/unTrimmed/3.For_tree"
gene_anno_dic = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/20.RERconverge/2.Modified_diapause/correlation_with_annotation.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        gene_name = lines.split(",")[0].split("_")[0]
        # print(gene_name)
        anno_name = lines.split(",")[-1].replace('"', '')
        if len(anno_name) < 2:
            # print(gene_name,anno_name)
            anno_name = gene_name
        
        gene_anno_dic[gene_name]= anno_name.strip()




with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/63.BUSCO_annotation/busco_names.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        lines_split = lines.strip().split(",")
        # print(lines_split)
        gene_name = lines_split[0]
        anno_name = lines_split[1]
       
            
        if gene_name not in gene_anno_dic:
            
            gene_anno_dic[gene_name]= anno_name
            # print(gene_name)
            continue
        if gene_anno_dic[gene_name] == gene_name:
            gene_anno_dic[gene_name]= anno_name

# %%
import pandas as pd

# location = 
rercoverge_file = pd.read_csv("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/1.Rerconverge_result/correlation_annotated_busco_category.csv")

positive_df = rercoverge_file[rercoverge_file["category"] == "Significant_Positive"]
positive_df["Name"] = positive_df["Name"].str.replace(".fas.best.fas.ClipKIT",'')
positive_gene_list = (positive_df["Name"].to_list())
# Out:
# /tmp/ipykernel_4551/1578575238.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_df["Name"] = positive_df["Name"].str.replace(".fas.best.fas.ClipKIT",'')

# %%
positive_gene_list[positive_gene_list.index("period")] = "2905at7088"
print(positive_gene_list)
# Out:
# ['cycle', '2905at7088', '12510at7088', '13263at7088', '16035at7088', '2560at7088', '3165at7088', '3362at7088', '3811at7088', '4043at7088', '4842at7088', '5326at7088', '5423at7088', '5474at7088', '5679at7088', '6081at7088', '8044at7088', '8751at7088', '8809at7088', '10001at7088', '1390at7088', '1422at7088', '1709at7088', '1846at7088', '2036at7088']

# %%
gene_dict = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/22.Busco_related/1.Annotation/MM_xnpmgii0.emapper.annotations.tsv", 'r') as anno_file:
    for anno_line in anno_file:
        if anno_line[0] != "#":
            anno_split = anno_line.strip().split("\t")
            if anno_split[0] in positive_gene_list:
                gene_dict[anno_split[0]] = anno_split[9].split(",")
                # print(anno_line)
print(gene_dict)
# Out:
# {'10001at7088': ['GO:0000302', 'GO:0000702', 'GO:0000703', 'GO:0003674', 'GO:0003676', 'GO:0003677', 'GO:0003690', 'GO:0003824', 'GO:0003906', 'GO:0004518', 'GO:0004519', 'GO:0005488', 'GO:0005575', 'GO:0005622', 'GO:0005623', 'GO:0005634', 'GO:0005654', 'GO:0005737', 'GO:0005739', 'GO:0006139', 'GO:0006220', 'GO:0006244', 'GO:0006259', 'GO:0006281', 'GO:0006284', 'GO:0006285', 'GO:0006289', 'GO:0006296', 'GO:0006304', 'GO:0006725', 'GO:0006753', 'GO:0006793', 'GO:0006796', 'GO:0006807', 'GO:0006950', 'GO:0006974', 'GO:0006979', 'GO:0008150', 'GO:0008152', 'GO:0008534', 'GO:0009056', 'GO:0009058', 'GO:0009117', 'GO:0009166', 'GO:0009219', 'GO:0009223', 'GO:0009262', 'GO:0009264', 'GO:0009394', 'GO:0009636', 'GO:0009987', 'GO:0010035', 'GO:0016787', 'GO:0016788', 'GO:0016798', 'GO:0016799', 'GO:0016829', 'GO:0016835', 'GO:0018130', 'GO:0019104', 'GO:0019438', 'GO:0019439', 'GO:0019637', 'GO:0019692', 'GO:0031974', 'GO:0031981', 'GO:0033554', 'GO:0033683', 'GO:0034042', 'GO:0034043', 'GO:0034404', 'GO:0034599', 'GO:0034614', 'GO:0034641', 'GO:0034654', 'GO:0034655', 'GO:0035690', 'GO:0042221', 'GO:0042493', 'GO:0042542', 'GO:0043170', 'GO:0043226', 'GO:0043227', 'GO:0043229', 'GO:0043231', 'GO:0043233', 'GO:0043412', 'GO:0044237', 'GO:0044238', 'GO:0044248', 'GO:0044249', 'GO:0044260', 'GO:0044270', 'GO:0044271', 'GO:0044281', 'GO:0044283', 'GO:0044422', 'GO:0044424', 'GO:0044428', 'GO:0044444', 'GO:0044446', 'GO:0044464', 'GO:0045008', 'GO:0046386', 'GO:0046434', 'GO:0046483', 'GO:0046677', 'GO:0046700', 'GO:0050896', 'GO:0051716', 'GO:0055086', 'GO:0070013', 'GO:0070301', 'GO:0070887', 'GO:0071236', 'GO:0071704', 'GO:0072527', 'GO:0072529', 'GO:0090304', 'GO:0090305', 'GO:0097159', 'GO:0097237', 'GO:0140078', 'GO:0140097', 'GO:1901135', 'GO:1901136', 'GO:1901292', 'GO:1901360', 'GO:1901361', 'GO:1901362', 'GO:1901363', 'GO:1901564', 'GO:1901565', 'GO:1901575', 'GO:1901576', 'GO:1901700', 'GO:1901701'], '12510at7088': ['GO:0000070', 'GO:0000278', 'GO:0000280', 'GO:0000815', 'GO:0000819', 'GO:0000920', 'GO:0003674', 'GO:0005488', 'GO:0005515', 'GO:0005575', 'GO:0005622', 'GO:0005623', 'GO:0005634', 'GO:0005737', 'GO:0005768', 'GO:0005770', 'GO:0006810', 'GO:0006996', 'GO:0006997', 'GO:0007032', 'GO:0007049', 'GO:0007059', 'GO:0007080', 'GO:0007088', 'GO:0007346', 'GO:0008104', 'GO:0008150', 'GO:0009966', 'GO:0009968', 'GO:0009987', 'GO:0010008', 'GO:0010256', 'GO:0010564', 'GO:0010646', 'GO:0010648', 'GO:0010824', 'GO:0012505', 'GO:0016020', 'GO:0016032', 'GO:0016043', 'GO:0016050', 'GO:0016192', 'GO:0016197', 'GO:0019058', 'GO:0019068', 'GO:0019904', 'GO:0022402', 'GO:0022411', 'GO:0022607', 'GO:0023051', 'GO:0023057', 'GO:0030117', 'GO:0030496', 'GO:0031090', 'GO:0031410', 'GO:0031982', 'GO:0032509', 'GO:0032886', 'GO:0032984', 'GO:0032991', 'GO:0033036', 'GO:0033043', 'GO:0036257', 'GO:0036258', 'GO:0036452', 'GO:0039702', 'GO:0042058', 'GO:0042059', 'GO:0042802', 'GO:0043226', 'GO:0043227', 'GO:0043229', 'GO:0043231', 'GO:0043933', 'GO:0044085', 'GO:0044087', 'GO:0044403', 'GO:0044419', 'GO:0044422', 'GO:0044424', 'GO:0044425', 'GO:0044433', 'GO:0044440', 'GO:0044444', 'GO:0044446', 'GO:0044464', 'GO:0045177', 'GO:0045184', 'GO:0046605', 'GO:0046755', 'GO:0046907', 'GO:0048285', 'GO:0048475', 'GO:0048519', 'GO:0048523', 'GO:0048583', 'GO:0048585', 'GO:0050000', 'GO:0050789', 'GO:0050794', 'GO:0051128', 'GO:0051179', 'GO:0051234', 'GO:0051276', 'GO:0051301', 'GO:0051303', 'GO:0051310', 'GO:0051493', 'GO:0051640', 'GO:0051641', 'GO:0051649', 'GO:0051656', 'GO:0051704', 'GO:0051726', 'GO:0051783', 'GO:0060236', 'GO:0065007', 'GO:0070507', 'GO:0070925', 'GO:0071840', 'GO:0071985', 'GO:0090169', 'GO:0090224', 'GO:0097708', 'GO:0098588', 'GO:0098796', 'GO:0098805', 'GO:0098813', 'GO:0140014', 'GO:1901184', 'GO:1901185', 'GO:1901673', 'GO:1902115', 'GO:1903047', 'GO:1904896', 'GO:1904903'], '13263at7088': ['GO:0000003', 'GO:0000226', 'GO:0000278', 'GO:0000281', 'GO:0000902', 'GO:0000904', 'GO:0000910', 'GO:0000912', 'GO:0000915', ' ...

# %%
from goatools.obo_parser import GODag

# Load GO DAG
obo_file = "/mnt/g/My Drive/Circadian Rhythm Genes Project/22.Busco_related/1.Annotation/go-basic.obo"  # Download from http://purl.obolibrary.org/obo/go/go-basic.obo
go_dag = GODag(obo_file)
# Out:
# /mnt/g/My Drive/Circadian Rhythm Genes Project/22.Busco_related/1.Annotation/go-basic.obo: fmt(1.2) rel(2025-06-01) 43,448 Terms

# %%
# Filter to only BP terms
def is_biological_process(go_id):
    # print(go_id)
    term = go_dag.get(go_id)
    # print(term)
    return term is not None and term.namespace == 'biological_process'

filtered_go_dict = {}
for gene, go_list in gene_dict.items():
    # print(gene, go_list)
    # for go in go_list:
    #     print(go)
    
    go_list_split = go_list[0].split(",")
    # print(go_list_split)
    # assert False
    filtered = [go for go in go_list_split if is_biological_process(go)]
    filtered_go_dict[gene] = set(filtered)



print(filtered_go_dict)
# Out:
# {'10001at7088': {'GO:0006244', 'GO:0072529', 'GO:0009166', 'GO:0051716', 'GO:0070887', 'GO:0006281', 'GO:1901701', 'GO:0043412', 'GO:0044283', 'GO:0009262', 'GO:0006289', 'GO:0070301', 'GO:0033554', 'GO:1901292', 'GO:0009636', 'GO:0046677', 'GO:0034655', 'GO:0034614', 'GO:0042493', 'GO:0034404', 'GO:0006259', 'GO:1901136', 'GO:0006220', 'GO:0006285', 'GO:0006979', 'GO:0006793', 'GO:0009056', 'GO:0035690', 'GO:0050896', 'GO:0071236', 'GO:0034599', 'GO:0090304', 'GO:0009058', 'GO:0009219', 'GO:0006284', 'GO:0000302', 'GO:0006950', 'GO:0006304', 'GO:0009394', 'GO:0009987', 'GO:0044281', 'GO:0055086', 'GO:0072527', 'GO:0097237', 'GO:0044238', 'GO:1901135', 'GO:0008152', 'GO:0043170', 'GO:0045008', 'GO:0034654', 'GO:0008150', 'GO:0006753', 'GO:0006796', 'GO:1901700', 'GO:0009264', 'GO:0006974', 'GO:0009117', 'GO:0042221', 'GO:0046434', 'GO:0019637', 'GO:0042542', 'GO:0006139', 'GO:0019692', 'GO:0009223', 'GO:0046386'}, '12510at7088': {'GO:1904903', 'GO:1903047', 'GO:0048585', 'GO:0046907', 'GO:0051649', 'GO:0022402', 'GO:0043933', 'GO:0045184', 'GO:1901673', 'GO:0050789', 'GO:0048523', 'GO:0042059', 'GO:0000070', 'GO:0036258', 'GO:0008150', 'GO:0000280', 'GO:0000920', 'GO:0051656', 'GO:0010256', 'GO:0016032', 'GO:0019068', 'GO:0098813', 'GO:0044419', 'GO:0006810', 'GO:0009966', 'GO:0022411', 'GO:0051726', 'GO:0036257', 'GO:0090169', 'GO:0016050', 'GO:1902115', 'GO:0051640', 'GO:1904896', 'GO:1901185', 'GO:0010564', 'GO:0006996', 'GO:0019058', 'GO:0000819', 'GO:0007080', 'GO:0033036', 'GO:0009968', 'GO:0007059', 'GO:0050794', 'GO:0090224', 'GO:0016192', 'GO:0051303', 'GO:0022607', 'GO:0140014', 'GO:0006997', 'GO:0010646', 'GO:0046755', 'GO:0032984', 'GO:0016043', 'GO:0046605', 'GO:0010824', 'GO:0051641', 'GO:0050000', 'GO:0023051', 'GO:0051276', 'GO:0007088', 'GO:0016197', 'GO:0044085', 'GO:0070925', 'GO:0048285', 'GO:0042058', 'GO:0007049', 'GO:0032886', 'GO:0051128', 'GO:0033043', 'GO:0000278', 'GO:0051493', 'GO:0071985', 'GO:0060236', 'GO:0044403', 'GO:0051179', 'GO:0023057', 'GO:1901184', 'GO:0007032', 'GO:0032509', 'GO:0048519', 'GO:0051783', 'GO:0008104', 'GO:0007346', 'GO:0009987', 'GO:0051310', 'GO:0071840', 'GO:0070507', 'GO:0051234', 'GO:0010648', 'GO:0065007', 'GO:0039702', 'GO:0044087', 'GO:0048583', 'GO:0051301'}, '13263at7088': {'GO:0022414', 'GO:0042462', 'GO:0007276', 'GO:0042592', 'GO:0051223', 'GO:0051495', 'GO:0030036', 'GO:0030832', 'GO:0110053', 'GO:0032271', 'GO:0032502', 'GO:1903047', 'GO:0007298', 'GO:0048737', 'GO:0010631', 'GO:0002066', 'GO:0048646', 'GO:0035114', 'GO:0022402', 'GO:0043933', 'GO:0030865', 'GO:0031032', 'GO:0002791', 'GO:0007297', 'GO:0032879', 'GO:0048731', 'GO:0007552', 'GO:0031334', 'GO:0046660', 'GO:0050789', 'GO:1904951', 'GO:0044837', 'GO:0120039', 'GO:0046545', 'GO:0007423', 'GO:0008150', 'GO:0008406', 'GO:0048729', 'GO:0048812', 'GO:0060322', 'GO:0042692', 'GO:0060429', 'GO:0051146', 'GO:0051222', 'GO:0061458', 'GO:0070201', 'GO:0031175', 'GO:0032956', 'GO:0035315', 'GO:0051130', 'GO:0000912', 'GO:0051258', 'GO:0048513', 'GO:0048871', 'GO:0007399', 'GO:0035220', 'GO:0035218', 'GO:0042461', 'GO:0010927', 'GO:0051047', 'GO:0009653', 'GO:0030239', 'GO:0007478', 'GO:0022411', 'GO:0048707', 'GO:0048609', 'GO:0007472', 'GO:0048518', 'GO:0000915', 'GO:0001754', 'GO:0003006', 'GO:1901881', 'GO:0032535', 'GO:0030031', 'GO:0000226', 'GO:0007164', 'GO:0016477', 'GO:0008585', 'GO:0035282', 'GO:1903532', 'GO:0001654', 'GO:0048858', 'GO:0033206', 'GO:0048749', 'GO:0006996', 'GO:0007476', 'GO:0030707', 'GO:0044089', 'GO:0060249', 'GO:0000281', 'GO:0009791', 'GO:0030240', 'GO:0007010', 'GO:0002065', 'GO:0034622', 'GO:0001745', 'GO:0009887', 'GO:0007480', 'GO:0009792', 'GO:0036011', 'GO:0035120', 'GO:0035285', 'GO:0061640', 'GO:0009888', 'GO:0002064', 'GO:0030866', 'GO:0032501', 'GO:0043243', 'GO:0051321', 'GO:0030041', 'GO:0071689', 'GO:0050794', 'GO:0055002', 'GO:0051050', 'GO:0048699', 'GO:0048736', 'GO:0051261', 'GO:0022607', 'GO:0030042', 'GO:0048667', 'GO:0008064', 'GO:0032506', 'GO:0014866', ' ...

# %%
# !pip3 install goatools
# Out:
# DEPRECATION: Loading egg at /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages/ete3-3.1.3-py3.10.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting goatools
#   Downloading goatools-1.4.12-py3-none-any.whl.metadata (14 kB)
# Collecting docopt (from goatools)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ftpretty (from goatools)
#   Downloading ftpretty-0.4.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /home/saurav/.local/lib/python3.11/site-packages (from goatools) (1.26.1)
# Collecting openpyxl (from goatools)
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pandas in /home/saurav/.local/lib/python3.11/site-packages (from goatools) (2.1.2)
# Collecting pydot (from goatools)
#   Downloading pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from goatools) (2.28.1)
# Requirement already satisfied: rich in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from goatools) (13.9.4)
# Requirement already satisfied: scipy in /home/saurav/.local/lib/python3.11/site-packages (from goatools) (1.14.0)
# Requirement already satisfied: setuptools in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from goatools) (70.1.1)
# Requirement already satisfied: statsmodels in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from goatools) (0.14.4)
# Collecting xlsxwriter (from goatools)
#   Downloading xlsxwriter-3.2.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: python-dateutil in /home/saurav/.local/lib/python3.11/site-packages (from ftpretty->goatools) (2.9.0.post0)
# Collecting et-xmlfile (from openpyxl->goatools)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from pandas->goatools) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/saurav/.local/lib/python3.11/site-packages (from pandas->goatools) (2024.1)
# Requirement already satisfied: pyparsing>=3.1.0 in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from pydot->goatools) (3.2.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from requests->goatools) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from requests->goatools) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from requests->goatools) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from requests->goatools) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from rich->goatools) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from rich->goatools) (2.18.0)
# Requirement already satisfied: patsy>=0.5.6 in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from statsmodels->goatools) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from statsmodels->goatools) (23.2)
# Requirement already satisfied: mdurl~=0.1 in /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->goatools) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/saurav/.local/lib/python3.11/site-packages (from python-dateutil->ftpretty->goatools) (1.16.0)
# Downloading goatools-1.4.12-py3-none-any.whl (15.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 3.2 MB/s eta 0:00:0000:0100:01
# Downloading ftpretty-0.4.0-py2.py3-none-any.whl (8.2 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 7.5 MB/s eta 0:00:00
# Downloading pydot-4.0.1-py3-none-any.whl (37 kB)
# Downloading xlsxwriter-3.2.5-py3-none-any.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.3/172.3 kB 8.0 MB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13707 sha256=b2add519d592d9bb3b897d5385292ad903d8894e0b01a18775223440f46a18d2
#   Stored in directory: /home/saurav/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built docopt
# Installing collected packages: docopt, xlsxwriter, pydot, et-xmlfile, openpyxl, ftpretty, goatools
# Successfully installed docopt-0.6.2 et-xmlfile-2.0.0 ftpretty-0.4.0 goatools-1.4.12 openpyxl-3.1.5 pydot-4.0.1 xlsxwriter-3.2.5

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform

# # Step 1: Your gene:GO dictionary
# go_dict = {
#     '10001at7088': [...],  # fill this in
#     '12510at7088': [...],
#     '13263at7088': [...],
#     # etc.
# }
go_dict = gene_dict
# Step 2: Convert GO lists to sets
for gene in go_dict:
    go_dict[gene] = set(go.strip() for go in go_dict[gene])

genes = list(go_dict.keys())

# Step 3: Calculate Jaccard distance matrix
n = len(genes)
distance_matrix = np.zeros((n, n))

for i in range(n):
    for j in range(n):
        if i < j:
            intersection = len(go_dict[genes[i]].intersection(go_dict[genes[j]]))
            union = len(go_dict[genes[i]].union(go_dict[genes[j]]))
            jaccard_dist = 1 - intersection / union if union > 0 else 1
            distance_matrix[i, j] = distance_matrix[j, i] = jaccard_dist

# Step 4: Hierarchical clustering
linkage_matrix = linkage(squareform(distance_matrix), method='average')  # or 'complete', 'ward'

# Step 5: Plot dendrogram
plt.figure(figsize=(10, 5))
dendrogram(linkage_matrix, labels=genes, leaf_rotation=90)
plt.title("Gene Clustering Based on Shared GO Terms")
plt.ylabel("Jaccard Distance (1 - similarity)")
for y in np.arange(0.2, 1.01, 0.02):
    plt.axhline(y=y, color='gray', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.show()

# %%
from scipy.cluster.hierarchy import fcluster

# Define number of clusters (or use a distance threshold)
# cluster_labels = fcluster(linkage_matrix, t=5, criterion='maxclust')  # for 4 clusters

cluster_labels = fcluster(linkage_matrix, t=0.82, criterion='distance')


from collections import defaultdict
cluster_to_genes = defaultdict(list)
for gene, label in zip(genes, cluster_labels):
    cluster_to_genes[label].append(gene)


from collections import Counter

cluster_descriptions = {}

for label, gene_list in cluster_to_genes.items():
    all_go_terms = []
    for gene in gene_list:
        all_go_terms.extend(filtered_go_dict[gene])
    
    # Count most common GO terms
    go_counts = Counter(all_go_terms)
    top_terms = go_counts.most_common(5)  # top 5 terms
    
    cluster_descriptions[label] = top_terms
print(cluster_to_genes)

for cluster, go_terms in cluster_descriptions.items():
    print(f"\nCluster {cluster}:")
    for go_id, count in go_terms:
        name = go_dag[go_id].name if go_id in go_dag else "Unknown term"
        print(f"  {go_id} ({name}) - found in {count} genes")
# Out:
# defaultdict(<class 'list'>, {8: ['10001at7088', '4043at7088'], 11: ['12510at7088'], 4: ['13263at7088', '8809at7088'], 7: ['1390at7088', '1422at7088', '2036at7088', '2905at7088', '5474at7088', '8044at7088'], 2: ['16035at7088', '2560at7088'], 10: ['1709at7088', '3362at7088'], 3: ['1846at7088'], 5: ['3165at7088'], 9: ['3811at7088', '5423at7088'], 6: ['4842at7088'], 1: ['5326at7088', '6081at7088'], 13: ['5679at7088'], 12: ['8751at7088']})
#
# Cluster 8:
#   GO:0009166 (nucleotide catabolic process) - found in 2 genes
#   GO:0044283 (small molecule biosynthetic process) - found in 2 genes
#   GO:1901292 (nucleoside phosphate catabolic process) - found in 2 genes
#   GO:0034655 (nucleobase-containing compound catabolic process) - found in 2 genes
#   GO:0034404 (nucleobase-containing small molecule biosynthetic process) - found in 2 genes
#
# Cluster 11:
#   GO:1904903 (ESCRT III complex disassembly) - found in 1 genes
#   GO:1903047 (mitotic cell cycle process) - found in 1 genes
#   GO:0048585 (negative regulation of response to stimulus) - found in 1 genes
#   GO:0046907 (intracellular transport) - found in 1 genes
#   GO:0051649 (establishment of localization in cell) - found in 1 genes
#
# Cluster 4:
#   GO:0022414 (reproductive process) - found in 2 genes
#   GO:0007276 (gamete generation) - found in 2 genes
#   GO:0030036 (actin cytoskeleton organization) - found in 2 genes
#   GO:0030832 (regulation of actin filament length) - found in 2 genes
#   GO:0110053 (regulation of actin filament organization) - found in 2 genes
#
# Cluster 7:
#   GO:0010556 (regulation of macromolecule biosynthetic process) - found in 6 genes
#   GO:0050789 (regulation of biological process) - found in 6 genes
#   GO:0008150 (biological_process) - found in 6 genes
#   GO:0019219 (regulation of nucleobase-containing compound metabolic process) - found in 6 genes
#   GO:0010468 (regulation of gene expression) - found in 6 genes
#
# Cluster 2:
#   GO:0048878 (chemical homeostasis) - found in 2 genes
#   GO:0042592 (homeostatic process) - found in 2 genes
#   GO:0019725 (cellular homeostasis) - found in 2 genes
#   GO:0032502 (developmental process) - found in 2 genes
#   GO:0050789 (regulation of biological process) - found in 2 genes
#
# Cluster 10:
#   GO:0016070 (RNA metabolic process) - found in 2 genes
#   GO:0006139 (nucleobase-containing compound metabolic process) - found in 2 genes
#   GO:0090304 (nucleic acid metabolic process) - found in 2 genes
#   GO:0009987 (cellular process) - found in 2 genes
#   GO:0044238 (primary metabolic process) - found in 2 genes
#
# Cluster 3:
#   GO:0030001 (metal ion transport) - found in 1 genes
#   GO:0015804 (neutral amino acid transport) - found in 1 genes
#   GO:0098656 (monoatomic anion transmembrane transport) - found in 1 genes
#   GO:0098655 (monoatomic cation transmembrane transport) - found in 1 genes
#   GO:0051179 (localization) - found in 1 genes
#
# Cluster 5:
#   GO:0022414 (reproductive process) - found in 1 genes
#   GO:0042462 (eye photoreceptor cell development) - found in 1 genes
#   GO:0010632 (regulation of epithelial cell migration) - found in 1 genes
#   GO:0007593 (chitin-based cuticle sclerotization) - found in 1 genes
#   GO:0048878 (chemical homeostasis) - found in 1 genes
#
# Cluster 9:
#   GO:0022414 (reproductive process) - found in 2 genes
#   GO:0007276 (gamete generation) - found in 2 genes
#   GO:0032502 (developmental process) - found in 2 genes
#   GO:0008150 (biological_process) - found in 2 genes
#   GO:0048609 (multicellular organismal reproductive process) - found in 2 genes
#
# Cluster 6:
#   GO:0022414 (reproductive process) - found in 1 genes
#   GO:0010639 (negative regulation of organelle organization) - found in 1 genes
#   GO:0048738 (cardiac muscle tissue development) - found in 1 genes
#   GO:0071495 (cellular response to endogenous stimulus) - found in 1 genes
#   GO:0009060 (aerobic respiration) - found in 1 genes
#
# Cluster 1:
#   GO:0009719 (response to endogenous stimulus) - found in 2 genes
#   GO:0051716 (cellular response to stimulus) - found in 2 genes
#   GO:0070887 (cellular response to chemical stimulus) - found in 2 genes
#   GO:0071495 (cellular response to endogenous stimulus) - found in 2 genes
#   GO:0032870 (cellular response to hormone stimulus) - found in 2 genes
#
# Cluster 13:
#
# Cluster 12:
#   GO:0060541 (respiratory system development) - found in 1 genes
#   GO:0048638 (regulation of developmental growth) - found in 1 genes
#   GO:0065008 (regulation of biological quality) - found in 1 genes
#   GO:0090066 (regulation of anatomical structure size) - found in 1 genes
#   GO:0032502 (developmental process) - found in 1 genes

# %%
print(cluster_to_genes)
# Out:
# defaultdict(<class 'list'>, {1: ['10001at7088', '4043at7088'], 9: ['12510at7088'], 5: ['13263at7088', '3165at7088', '4842at7088', '8809at7088'], 7: ['1390at7088', '1422at7088', '1709at7088', '2905at7088', '5474at7088'], 4: ['16035at7088', '1846at7088', '2560at7088'], 6: ['2036at7088', '5326at7088', '6081at7088', '8044at7088'], 3: ['3362at7088'], 2: ['3811at7088', '5423at7088'], 10: ['5679at7088'], 8: ['8751at7088']})

# %%
from collections import defaultdict, Counter

# Example structure of cluster_labels: {'10001at7088': 0, '12510at7088': 1, ...}

cluster_go_terms = defaultdict(list)

for gene, cluster_id in cluster_labels.items():
    go_terms = filtered_go_dict.get(gene, [])
    cluster_go_terms[cluster_id].extend(go_terms)

# Now count GO terms per cluster
cluster_go_counts = {cid: Counter(go_list) for cid, go_list in cluster_go_terms.items()}

from goatools.obo_parser import GODag

go_dag = GODag(obo_file)  # Already downloaded earlier

# Get top N GO term names per cluster
for cluster_id, counter in cluster_go_counts.items():
    print(f"\nCluster {cluster_id} top GO terms:")
    for go_id, count in counter.most_common(5):  # Top 5 terms
        go_name = go_dag[go_id].name if go_id in go_dag else "Unknown"
        print(f"  {go_id} ({go_name}): {count}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 7
#       3 # Example structure of cluster_labels: {'10001at7088': 0, '12510at7088': 1, ...}
#       5 cluster_go_terms = defaultdict(list)
# ----> 7 for gene, cluster_id in cluster_labels.items():
#       8     go_terms = filtered_go_dict.get(gene, [])
#       9     cluster_go_terms[cluster_id].extend(go_terms)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'items'

# %%
cluster_labels
# Out:
# array([ 1,  9,  5,  7,  7,  4,  7,  4,  6,  4,  7,  5,  3,  2,  1,  5,  6,
#         2,  7, 10,  6,  6,  8,  5], dtype=int32)

# %%
print(linkage_matrix)
# Out:
# [[ 4.         10.          0.55932203  2.        ]
#  [16.         20.          0.60416667  2.        ]
#  [ 8.         21.          0.60714286  2.        ]
#  [ 2.         23.          0.67050691  2.        ]
#  [18.         24.          0.73411426  3.        ]
#  [13.         17.          0.75138122  2.        ]
#  [ 3.         28.          0.75455912  4.        ]
#  [ 0.         14.          0.77704918  2.        ]
#  [ 5.          9.          0.77704918  2.        ]
#  [ 6.         12.          0.79518072  2.        ]
#  [26.         30.          0.81965178  6.        ]
#  [29.         33.          0.83552405  4.        ]
#  [ 7.         32.          0.8430532   3.        ]
#  [31.         35.          0.84469304  6.        ]
#  [11.         15.          0.84591195  2.        ]
#  [27.         38.          0.85634537  4.        ]
#  [25.         36.          0.87429672  5.        ]
#  [34.         37.          0.89239971 12.        ]
#  [39.         41.          0.9009709  16.        ]
#  [ 1.         42.          0.90536635 17.        ]
#  [40.         43.          0.91639461 22.        ]
#  [22.         44.          0.94654705 23.        ]
#  [19.         45.          1.         24.        ]]

# %%
cluster_labels = fcluster(linkage_matrix, t=0.85, criterion='distance')

# View result
print(cluster_labels)
# Out:
# [6 7 3 5 5 2 6 2 5 2 5 4 6 6 6 4 1 6 5 9 1 5 8 3]

# %%
output = "Cluster,Gene"
for key,value in cluster_to_genes.items():
    print(key)
    
    gene_names = []
    for gene in value:
        gene_names.append(gene_anno_dic[gene])
        # print(gene_anno_dic[gene])
        # output += f",{gene_anno_dic[gene]}"
    output += f"\n{key},{';'.join(gene_names)}"


with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/15.Rho_gene_clusturing_using GO_terms/positive_rho.csv", 'w') as out_file:
    out_file.write(output)
# Out:
# 8
# 11
# 4
# 7
# 2
# 10
# 3
# 5
# 9
# 6
# 1
# 13
# 12

# %%
cluster_to_genes = defaultdict(list)
for gene, label in zip(genes, cluster_labels):
    cluster_to_genes[label].append(gene)

# --- STEP 2: Count GO term occurrences per cluster ---
cluster_go_counts = {}
for cluster_id, gene_list in cluster_to_genes.items():
    all_go_terms = []
    for gene in gene_list:
        all_go_terms.extend(filtered_go_dict.get(gene, []))
    cluster_go_counts[cluster_id] = Counter(all_go_terms)

# --- STEP 3: Helper to filter redundant GO terms using GO hierarchy ---
def is_redundant(go_id, go_set):
    """Check if a parent of go_id is also in the set (i.e., go_id is redundant)."""
    term = go_dag.get(go_id)
    if term:
        return any(parent.id in go_set for parent in term.parents)
    return False

def get_non_redundant_terms(go_list):
    """Return GO terms that are not children of other terms in the list."""
    go_set = set(go_list)
    return {go_id for go_id in go_list if not is_redundant(go_id, go_set - {go_id})}

# --- STEP 4: Extract most relevant GO terms per cluster ---
for cluster_id, counter in cluster_go_counts.items():
    top_terms = [go for go, _ in counter.most_common(50)]  # Top N frequent GO terms
    non_redundant = get_non_redundant_terms(top_terms)
    # Sort remaining by frequency and depth
    sorted_terms = sorted(
        [(go_id, go_dag[go_id].depth, counter[go_id])
         for go_id in non_redundant if go_id in go_dag],
        key=lambda x: (-x[2], -x[1])  # prioritize by count, then depth
    )

    print(f"\nCluster {cluster_id} — Most Relevant GO Terms:")
    for go_id, depth, count in sorted_terms[:10]:
        print(f"  {go_id} ({go_dag[go_id].name}) — depth: {depth}, count: {count}")
# Out:
# Cluster 8 — Most Relevant GO Terms:
#   GO:0008150 (biological_process) — depth: 0, count: 2
#   GO:0043412 (macromolecule modification) — depth: 4, count: 1
#
# Cluster 11 — Most Relevant GO Terms:
#   GO:0036257 (multivesicular body organization) — depth: 7, count: 1
#   GO:1902115 (regulation of organelle assembly) — depth: 6, count: 1
#   GO:1904896 (ESCRT complex disassembly) — depth: 6, count: 1
#   GO:0000280 (nuclear division) — depth: 6, count: 1
#   GO:0045184 (establishment of protein localization) — depth: 5, count: 1
#   GO:0022411 (cellular component disassembly) — depth: 4, count: 1
#   GO:0022607 (cellular component assembly) — depth: 4, count: 1
#   GO:0048585 (negative regulation of response to stimulus) — depth: 4, count: 1
#   GO:0043933 (protein-containing complex organization) — depth: 4, count: 1
#   GO:0006996 (organelle organization) — depth: 4, count: 1
#
# Cluster 4 — Most Relevant GO Terms:
#   GO:0032956 (regulation of actin cytoskeleton organization) — depth: 7, count: 2
#   GO:0031175 (neuron projection development) — depth: 6, count: 2
#   GO:0048699 (generation of neurons) — depth: 5, count: 2
#   GO:0030031 (cell projection assembly) — depth: 5, count: 2
#   GO:0010631 (epithelial cell migration) — depth: 5, count: 2
#   GO:0044089 (positive regulation of cellular component biogenesis) — depth: 5, count: 2
#   GO:0002065 (columnar/cuboidal epithelial cell differentiation) — depth: 5, count: 2
#   GO:0009792 (embryo development ending in birth or egg hatching) — depth: 5, count: 2
#   GO:0051130 (positive regulation of cellular component organization) — depth: 5, count: 2
#   GO:0032535 (regulation of cellular component size) — depth: 4, count: 2
#
# Cluster 7 — Most Relevant GO Terms:
#   GO:0008150 (biological_process) — depth: 0, count: 6
#
# Cluster 2 — Most Relevant GO Terms:
#   GO:0008150 (biological_process) — depth: 0, count: 2
#   GO:0007430 (terminal branching, open tracheal system) — depth: 8, count: 1
#   GO:0007169 (cell surface receptor protein tyrosine kinase signaling pathway) — depth: 7, count: 1
#   GO:0001700 (embryonic development via the syncytial blastoderm) — depth: 6, count: 1
#   GO:0071495 (cellular response to endogenous stimulus) — depth: 3, count: 1
#
# Cluster 10 — Most Relevant GO Terms:
#   GO:0008150 (biological_process) — depth: 0, count: 2
#   GO:0007549 (sex-chromosome dosage compensation) — depth: 9, count: 1
#   GO:0080090 (regulation of primary metabolic process) — depth: 5, count: 1
#   GO:0060255 (regulation of macromolecule metabolic process) — depth: 5, count: 1
#   GO:0046661 (male sex differentiation) — depth: 4, count: 1
#   GO:0048731 (system development) — depth: 3, count: 1
#   GO:0007275 (multicellular organism development) — depth: 3, count: 1
#
# Cluster 3 — Most Relevant GO Terms:
#   GO:0008150 (biological_process) — depth: 0, count: 1
#
# Cluster 5 — Most Relevant GO Terms:
#   GO:0001963 (synaptic transmission, dopaminergic) — depth: 9, count: 1
#   GO:0051289 (protein homotetramerization) — depth: 8, count: 1
#   GO:0042416 (dopamine biosynthetic process) — depth: 7, count: 1
#   GO:0042462 (eye photoreceptor cell development) — depth: 6, count: 1
#   GO:0030334 (regulation of cell migration) — depth: 5, count: 1
#   GO:0048079 (regulation of cuticle pigmentation) — depth: 5, count: 1
#   GO:0032496 (response to lipopolysaccharide) — depth: 5, count: 1
#   GO:0007593 (chitin-based cuticle sclerotization) — depth: 4, count: 1
#   GO:0009415 (response to water) — depth: 4, count: 1
#   GO:0044057 (regulation of system process) — depth: 4, count: 1
#
# Cluster 9 — Most Relevant GO Terms:
#   GO:0008150 (biological_process) — depth: 0, count: 2
#   GO:0046470 (phosphatidylcholine metabolic process) — depth: 7, count: 1
#   GO:0006658 (phosphatidylserine metabolic process) — depth: 7, count: 1
#   GO:0046486 (glycerolipid metabolic process) — depth: 5, count: 1
#   GO:0040010 (positive regulation of growth rate) — depth: 5, count: 1
#   GO:0030258 (lipid modification) — depth: 5, count: 1
#   GO:0016477 (cell migration) — depth: 3, count: 1
#
# Cluster 6 — Most Relevant GO Terms:
#   GO:0032760 (positive regulation of tumor necrosis factor production) — depth: 11, count: 1
#   GO:0050731 (positive regulation of peptidyl-tyrosine phosphorylation) — depth: 10, count: 1
#   GO:0050771 (negative regulation of axonogenesis) — depth: 9, count: 1
#   GO:0045814 (negative regulation of gene expression, epigenetic) — depth: 9, count: 1
#   GO:0110020 (regulation of actomyosin structure organization) — depth: 8, count: 1
#   GO:0043124 (negative regulation of canonical NF-kappaB signal transduction) — depth: 8, count: 1
#   GO:0031400 (negative regulation of protein modification process) — depth: 8, count: 1
#   GO:0014015 (positive regulation of gliogenesis) — depth: 8, count: 1
#   GO:0090276 (regulation of peptide hormone secretion) — depth: 8, count: 1
#   GO:0043524 (negative regulation of neuron apoptotic process) — depth: 7, count: 1
#
# Cluster 1 — Most Relevant GO Terms:
#   GO:0008150 (biological_process) — depth: 0, count: 2
#   GO:0095500 (acetylcholine receptor signaling pathway) — depth: 6, count: 1
#
# Cluster 13 — Most Relevant GO Terms:
#
# Cluster 12 — Most Relevant GO Terms:
#   GO:0008150 (biological_process) — depth: 0, count: 1
