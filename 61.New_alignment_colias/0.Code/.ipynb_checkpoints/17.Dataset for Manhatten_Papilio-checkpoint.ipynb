# %%
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/3.Pararge_aegeria"
import numpy 
fst_dictionary = {}
fst_list = []
with open(f"{location}/1.FST_peaks_from_chris/two_pool_1%_0.149_5kb_merged.fst",'r') as fst_file:
    for fst_lines in fst_file.readlines()[1:]:
        line_split = fst_lines.strip().split(",")
        
        fst_dictionary.setdefault(line_split[0],[])
        # # try:
        # # if float(line_split[3]) > 0.095:
        fst_dictionary[line_split[0]].append([[int(line_split[1]), int(line_split[2])],float(line_split[3])] )
        # # except:
            # pass
        # break
print(fst_dictionary)
# numpy.percentile(fst_list, 99)
# Out:
# {'NC_053180.1': [[[691001, 692000], 0.173], [[2130001, 2131000], 0.165], [[2175001, 2176000], 0.213], [[2512001, 2515000], 0.189], [[2687001, 2688000], 0.153], [[2985001, 2986000], 0.159], [[2993001, 3006000], 0.18], [[3037001, 3038000], 0.17], [[3044001, 3045000], 0.156], [[3165001, 3166000], 0.149], [[3338001, 3339000], 0.153], [[3563001, 3564000], 0.175], [[4166001, 4168000], 0.189], [[4174001, 4181000], 0.185], [[4604001, 4605000], 0.154], [[4864001, 4865000], 0.198], [[6123001, 6124000], 0.164], [[6799001, 6800000], 0.3], [[6998001, 6999000], 0.151], [[7052001, 7053000], 0.157], [[7230001, 7231000], 0.194], [[7679001, 7680000], 0.221], [[7804001, 7805000], 0.212], [[8377001, 8378000], 0.25], [[8870001, 8871000], 0.157], [[9005001, 9006000], 0.245], [[9150001, 9151000], 0.243], [[9156001, 9159000], 0.198], [[9165001, 9169000], 0.203], [[9731001, 9746000], 0.196], [[9851001, 9852000], 0.174], [[9917001, 9921000], 0.236], [[9933001, 9934000], 0.173], [[9946001, 9947000], 0.217], [[10510001, 10514000], 0.205], [[10628001, 10629000], 0.171], [[10665001, 10680000], 0.203], [[10832001, 10833000], 0.209], [[11736001, 11737000], 0.163], [[11819001, 11827000], 0.304], [[11890001, 11892000], 0.209], [[11989001, 11991000], 0.186], [[12163001, 12172000], 0.183], [[12178001, 12179000], 0.162], [[12235001, 12246000], 0.214], [[12949001, 12950000], 0.166], [[12966001, 12967000], 0.236], [[13368001, 13375000], 0.257], [[13647001, 13657000], 0.222], [[13668001, 13669000], 0.198], [[13805001, 13806000], 0.183], [[13932001, 13933000], 0.16], [[13946001, 13947000], 0.15], [[13954001, 13955000], 0.178], [[14166001, 14167000], 0.165], [[14179001, 14180000], 0.232], [[14653001, 14654000], 0.214], [[14689001, 14700000], 0.178], [[14715001, 14730000], 0.224], [[15033001, 15035000], 0.221], [[15040001, 15043000], 0.195], [[15060001, 15063000], 0.242], [[15069001, 15081000], 0.207], [[15182001, 15183000], 0.164], [[15205001, 15206000], 0.158], [[15606001, 15615000], 0.225], [[15641001, 15644000], 0.212], [[15659001, 15663000], 0.184], [[15699001, 15721000], 0.172], [[15854001, 15857000], 0.165], [[15864001, 15865000], 0.163], [[16023001, 16024000], 0.201], [[16198001, 16199000], 0.165], [[16271001, 16274000], 0.175], [[16606001, 16607000], 0.204], [[16682001, 16683000], 0.153], [[16777001, 16779000], 0.196], [[16789001, 16790000], 0.209], [[16846001, 16847000], 0.199], [[16857001, 16864000], 0.199], [[16872001, 16881000], 0.178], [[17039001, 17042000], 0.22], [[17055001, 17056000], 0.155], [[17065001, 17066000], 0.155], [[17250001, 17251000], 0.162], [[17602001, 17604000], 0.17], [[17612001, 17613000], 0.158], [[17619001, 17620000], 0.239], [[18458001, 18459000], 0.153], [[18476001, 18477000], 0.155], [[18607001, 18608000], 0.149], [[18639001, 18641000], 0.181], [[18646001, 18647000], 0.206], [[19128001, 19129000], 0.253], [[19497001, 19498000], 0.181], [[19601001, 19602000], 0.19], [[20626001, 20628000], 0.184], [[20725001, 20727000], 0.226], [[20732001, 20734000], 0.226], [[20743001, 20746000], 0.199], [[20753001, 20755000], 0.187], [[20967001, 20968000], 0.152]], 'NC_053181.1': [[[589001, 607000], 0.189], [[1037001, 1039000], 0.168], [[1141001, 1142000], 0.161], [[2133001, 2134000], 0.164], [[2500001, 2502000], 0.178], [[2594001, 2595000], 0.248], [[3456001, 3457000], 0.183], [[3731001, 3732000], 0.151], [[3841001, 3842000], 0.186], [[4141001, 4144000], 0.188], [[4204001, 4208000], 0.194], [[4343001, 4344000], 0.211], [[4365001, 4389000], 0.281], [[4395001, 4396000], 0.167], [[4673001, 4675000], 0.182], [[4681001, 4682000], 0.157], [[5383001, 5388000], 0.187], [[6357001, 6360000], 0.171], [[6373001, 6377000], 0.184], [[6869001, 6870000], 0.175], [[6900001, 6901000], 0.152], [[7142001, 7147000], 0.186], [[7223001, 7225000], 0.187], [[7323001, 7324000], 0.153], [[7537001, 7538000], 0.185], [[8692001, 8694000], 0.185], [[8844001, 8845000], 0.173], [[8961001, 8962000], 0.167], [[9129001, 9130000], 0.158], [[9175001, 9176000], 0.161], [[9313001, 93140 ...

# %%
gene_anno_dic = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/2.Two_state/correlation_2_with_annotation.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        gene_name = lines.split(",")[0].split("_")[0][1:]
        anno_name = lines.split(",")[-1].replace('"', '')
        gene_anno_dic[gene_name]= anno_name.strip()

# print(gene_anno_dic)

# %%
gene_loc_dic = {}
with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'r') as gene_loc_file:
    for gene_line in gene_loc_file.readlines()[1:]:
        line_split = gene_line.strip().split("\t")
        gene_loc_dic[line_split[0]] = [line_split[1],line_split[2],line_split[3]]
# print(gene_loc_dic)



intersecting_genes = []
with open(f"{location}/3.Rho_set_genes/Rho_set_cluster.txt", 'r') as rho_set_file:
    for rho_set_count,lines in enumerate(rho_set_file.readlines()):
        rho_gene_name = lines.strip().split("\t")[0]

        try:
            chromosome,start,end = gene_loc_dic[rho_gene_name]
        except:
            print(rho_gene_name, "missing")
        
        
        for sections in (fst_dictionary[chromosome]):
            out_list = []
          
            if ((int(start) >= sections[0][0] and int(start) <= sections[0][1]) or (int(end) >= sections[0][0] and int(end) <= sections[0][1])) or ((sections[0][0] >= int(start) and sections[0][0] <= int(end)) or (sections[0][1] >= int(start) and sections[0][1] <= int(end))):
                try:
                    sections.append(gene_anno_dic[rho_gene_name])
                except:
                    sections.append(rho_gene_name)
                    print(rho_gene_name, "missing annottaion")
                
                if rho_gene_name not in intersecting_genes:
                    intersecting_genes.append(rho_gene_name)
          
print("\n",len(intersecting_genes), rho_set_count)
# Out:
# 3284at7088 missing
# cry1a missing
# cry1a missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
#
#  84 503

# %%
output = "CHR,BP,P,SNP"
chrom_dic = {"NC_053180.1":"1","NC_053181.1":"2","NC_053182.1":"3","NC_053183.1":"4","NC_053184.1":"5","NC_053185.1":"6","NC_053186.1":"7","NC_053187.1":"8","NC_053188.1":"9","NC_053189.1":"10","NC_053190.1":"11","NC_053191.1":"12","NC_053192.1":"13","NC_053193.1":"14","NC_053194.1":"15","NC_053195.1":"16","NC_053196.1":"17","NC_053197.1":"18","NC_053198.1":"19","NC_053199.1":"20","NC_053200.1":"21","NC_053201.1":"22","NC_053202.1":"23","NC_053203.1":"24","NC_053204.1":"25","NC_053205.1":"26","NC_053206.1":"27","NC_053208.1":"Z","NC_053207.1":"W"}
for key,value in fst_dictionary.items():
    print(key)
    
    chrom = chrom_dic[key]
    print(chrom)
    for pos in value:
        try:
            output += f"\n{chrom},{int((pos[0][0] + pos[0][1])/2)},{pos[1]},{pos[2]}"
        except IndexError:
            output += f"\n{chrom},{int((pos[0][0] + pos[0][1])/2)},{pos[1]},"
        #     print(pos)
        # # print(output)
        # print(pos) 
        # assert False
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/7.Manhatten/dataset_0.1_pararge.csv", 'w') as out_file:
    out_file.write(output)
# Out:
# NC_053180.1
# 1
# NC_053181.1
# 2
# NC_053182.1
# 3
# NC_053183.1
# 4
# NC_053184.1
# 5
# NC_053185.1
# 6
# NC_053186.1
# 7
# NC_053187.1
# 8
# NC_053188.1
# 9
# NC_053189.1
# 10
# NC_053190.1
# 11
# NC_053191.1
# 12
# NC_053192.1
# 13
# NC_053193.1
# 14
# NC_053194.1
# 15
# NC_053195.1
# 16
# NC_053196.1
# 17
# NC_053197.1
# 18
# NC_053198.1
# 19
# NC_053199.1
# 20
# NC_053200.1
# 21
# NC_053201.1
# 22
# NC_053202.1
# 23
# NC_053203.1
# 24
# NC_053204.1
# 25
# NC_053205.1
# 26
# NC_053206.1
# 27
# NC_053208.1
# Z
