# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = np.random.randn(100)

# Create histogram
plt.figure(figsize=(8, 4))
counts, bins, patches = plt.hist(data, bins=30)

# Invert the y-axis to make it "upside down"
plt.gca().invert_yaxis()

# Optional: Rotate x-ticks if needed
plt.xticks(rotation=90)

plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Upside-Down Histogram")
plt.tight_layout()
plt.show()

# %%
anno_dict = {}
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/12.Rho_networks/2.Diapausing/rho_set_core_25.txt", 'r') as rho_set:
    for lines in rho_set.readlines()[1:]:
        # print(lines)
        lines_split = lines.strip().split(",")
        # print(len(lines_split), end = ",")
        anno_dict[lines_split[1]]= lines_split[0]
print(anno_dict)
# Out:
# {'COPS5': '6826at7088', 'CTLSE2': '2201at7088', 'MRPS24': '12543at7088', 'bi': '7919at7088', 'CBLB': '1947at7088', 'SAP18': '13356at7088', 'DDX46': '1696at7088', 'SMC2': '1993at7088', 'NCDN': '1837at7088', 'MRPS25': '12705at7088', 'FIBP': '6874at7088', 'RRN3': '3689at7088', 'ARHGDIA': '11765at7088', 'CHAF1B': '5036at7088', 'HGH1': '8306at7088', 'CCT6A': '3853at7088', 'Zinc _4': '322at7088', 'NTAN1': '8819at7088', 'Trans_19': '6950at7088', 'PSMA3': '9564at7088', 'PCMTD1': '10476at7088', 'Ankyr_28': '4621at7088', 'SUGCT': '5486at7088', 'uncha_236': '7342at7088', 'KDM2A': '1076at7088', 'NEDD9': '5563at7088', 'ANKMY2': '6156at7088', 'FICD': '4406at7088', 'Met': '8044at7088', 'FAM46A': '5364at7088', 'Ribos_99': '14339at7088', 'SNW1': '4163at7088', 'KCNA2': '4176at7088', 'GPRDOP2': '6007at7088', 'GBF1': '652at7088', 'NHLH1': '14205at7088', 'VRK1': '2453at7088', 'UBE2I': '12326at7088', 'HNF4A': '6339at7088', 'SLCO4A1': '2979at7088', 'DDAH1': '10101at7088', 'PSMB1': '10180at7088', 'F46H5.3':
# ...

# %%
location = "/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/12.Rho_networks/2.Diapausing"
file_name = "Filtered_set_core_set"

list_of_degree = []
degree_dict = {}
with open(f"{location}/{file_name}_degree.csv", 'r') as out_file:
    for line in out_file:
        list_of_degree.append(int(line.strip().split(",")[1]))
        print(anno_dict[line.strip().split(",")[0].strip()])
        degree_dict[anno_dict[line.strip().split(",")[0].strip()]] = line.strip().split(",")[1]
# Out:
# 5969at7088
# 1943at7088
# 775at7088
# 1625at7088
# 7044at7088
# 3839at7088
# 7446at7088
# 2719at7088
# 2003at7088
# 1993at7088
# 13002at7088
# 983at7088
# cry1a
# 5891at7088
# 1076at7088
# 9518at7088
# cycle
# 5314at7088
# 1746at7088
# 10826at7088
# 5036at7088
# 263at7088
# 1319at7088
# 11115at7088
# 2984at7088
# 10186at7088
# 190at7088
# 1065at7088
# 10778at7088
# 1753at7088
# 338at7088
# 1130at7088
# 2081at7088
# 11337at7088
# 1330at7088
# 2166at7088
# 1530at7088
# 10916at7088
# 68at7088
# 795at7088
# 7656at7088
# 7855at7088
# 4064at7088
# 1218at7088
# 3023at7088
# 6885at7088
# 4163at7088
# 4305at7088
# 5508at7088
# 2451at7088
# 1696at7088
# 1904at7088
# 1300at7088
# 3069at7088
# 2873at7088
# 8819at7088
# 1605at7088
# 11416at7088
# 8735at7088
# 2240at7088
# 7935at7088
# 10904at7088
# 65at7088
# 3030at7088
# 4469at7088
# 4625at7088
# 6339at7088
# 2649at7088
# 8637at7088
# 3363at7088
# 5099at7088
# 1918at7088
# 2456at7088
# 6051at7088
# 2885at7088
# 5199at7088
# 9472at7088
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(list_of_degree, bins=int(max(list_of_degree)/5), edgecolor='black')
plt.gca().invert_yaxis()
# Add labels
# plt.title('Histogram')
plt.xlabel('Degree')
plt.ylabel('Count')

plt.savefig(f"/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/14.Plot degree vs intersction/degree_histogram_output.pdf", format='pdf', bbox_inches='tight')
plt.close()

# %%
gene_location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics"

species_list = ["1.Lasiomatta_megera","2.Pieris_napi","3.Pararge_aegeria"]
species_list = ["3.Pararge_aegeria"]
gene_list = []

for species in species_list:
    with open(f"{gene_location}/{species}/4.Intersections_test/intersection_set.txt", 'r') as intersection_list:
        for gene_line in intersection_list:
            gene_name = gene_line.strip().split(",")[0]
            if gene_name not in gene_list:
                gene_list.append(gene_name)
    print(len(gene_list))
# Out:
# 84

# %%
# print(gene_list)
anno_dict = {}
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/12.Rho_networks/2.Diapausing/rho_set_core_25.txt", 'r') as rho_set:
    for lines in rho_set.readlines()[1:]:
        lines_split = lines.strip().split(",")
        anno_dict[lines_split[1]]= lines_split[0]

# %%
list_of_degree = []
for gene_name in gene_list:
    list_of_degree.append(int(degree_dict[gene_name]))


plt.hist(list_of_degree, bins=int(max(list_of_degree)/5), edgecolor='black')
# plt.gca().invert_yaxis()
# Add labels
plt.title(species)
plt.xlabel('Degree')
plt.ylabel('Count')
plt.savefig(f"/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/14.Plot degree vs intersction/intersction_histogram_{species}.pdf", format='pdf', bbox_inches='tight')

# %%
print(gene_list)
# Out:
# ['2453at7088', '13413at7088', '15035at7088', '14245at7088', '1846at7088', '652at7088', '2599at7088', '5650at7088', '821at7088', '386at7088', '3127at7088', '1709at7088', '6156at7088', '3667at7088', '9535at7088', '2906at7088', '8465at7088', '12090at7088', '12180at7088', '274at7088', '12326at7088', '11858at7088', '11288at7088', '2938at7088', '5679at7088', '8306at7088', '2939at7088', '5486at7088', '12212at7088', '2813at7088', '11619at7088', '7044at7088', '4799at7088', '2003at7088', '6173at7088', '4078at7088', '1076at7088', 'cycle', '1319at7088', '11115at7088', '8048at7088', '7508at7088', '4089at7088', '68at7088', '7935at7088', '2019at7088', '14213at7088', '559at7088', '10142at7088', '10139at7088', '2160at7088', '5567at7088', '2335at7088', '3537at7088', '2234at7088', '7053at7088', '8793at7088', '4176at7088', '8595at7088', '2694at7088', '4625at7088', '12075at7088', '5858at7088', '2166at7088', '1246at7088', '993at7088', '7919at7088', '5563at7088', '5035at7088', '2428at7088', '515at7088', '2
# ...
