# %%
import os
location = "/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Upset_plot_deconstructed_for_degree/1.Gene_lists"
list_files = os.listdir(location)
gene_dictionry = {}

name_dictionary = {"all_three": "All three","lassiommata_only":"Lasiommata megera","las_napi_only":"L. megera & P. napi","las_para_only":"L. megera & P. aegeria","napi_only":"Pieris napi","napi_para_only":"P. napi & P. aegeria","pararge_only":"Pararge aegeria"}
for file in list_files:
    gene_dictionry[name_dictionary[file.split(".")[0]]] = []
    with open(f"{location}/{file}", 'r') as gene_list_file:
        for gene in gene_list_file:
            gene_dictionry[name_dictionary[file.split(".")[0]]].append(gene.strip())
            # assert False
print(gene_dictionry)
# Out:
# {'All three': ['3016at7088', '1846at7088', '4021at7088', '4480at7088', '190at7088', '2905at7088', '1947at7088', '3363at7088', '496at7088', '821at7088', '717at7088', '1709at7088', '3667at7088', '4595at7088', '13737at7088', '8222at7088', '4935at7088', '10101at7088', '10571at7088', '2201at7088', '5679at7088', '2939at7088', '5486at7088', '12212at7088', '1144at7088', '1628at7088', '2813at7088', '11619at7088', '7044at7088', '4799at7088', '6173at7088', '4078at7088', '1076at7088', 'cycle', '1319at7088', '11115at7088', '1753at7088', '8048at7088', '68at7088', '4064at7088', '2528at7088', '5474at7088', '65at7088', '8131at7088', '1422at7088', '3916at7088', '2639at7088', '113at7088', '2019at7088', '559at7088', '7342at7088', '8044at7088', '5567at7088', '2173at7088', '2234at7088', '13169at7088', '12572at7088', '4176at7088', '322at7088', '13038at7088', '553at7088', '2694at7088', '983at7088', '1746at7088', '569at7088', '1330at7088', '2166at7088', '1218at7088', '10963at7088', '993at7088', '389at7088', 
# ...

# %%
import pandas as pd
gene_cluster_dictionary = {}
cluster_file = pd.read_csv("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/19.Graph tool/gene_clusters_kmeans.csv")
cluster_count = {}
for row in cluster_file.iterrows():
    gene_cluster_dictionary[row[1].iloc[0]] = row[1][-1]
    if row[1].iloc[-1] not in cluster_count:
        cluster_count[row[1].iloc[-1]] = 0
    cluster_count[row[1].iloc[-1]]+=1
print(gene_cluster_dictionary)
# Out:
# {'DCAF7': 9, 'GDAP2': 9, 'SMU1': 9, 'BTBD9': 9, 'Chlor_1': 9, 'LLGL1': 9, 'ACTL6A': 9, 'KDM2A': 9, 'ARFIP1': 9, 'GATAD2A': 9, 'SEC23A': 5, 'SGPL1': 9, 'eef1g': 9, 'C16orf7': 9, 'BRAF': 9, 'SPARC': 9, 'EZH1': 9, 'LRBA': 9, 'MAU2': 9, 'SF1': 9, 'HID1': 9, 'USP3': 9, 'Calpo_1': 9, 'PCNX': 5, 'MTMR12': 9, 'COPZ1': 9, 'RSBN1': 9, 'HADHB': 9, 'CAPN15': 9, 'SLCO5A1': 5, 'NOVA1': 9, 'SSTR5': 9, 'PKP4': 5, 'SMARCA4': 5, 'cry1a': 9, 'IQSEC1': 5, 'PBRM1': 5, 'PPAT': 9, 'SURF4': 9, 'MAST4': 5, 'XPO5': 9, 'PLS3': 5, 'EFTUD2': 5, 'DDX46': 5, 'AP1B1': 5, 'TKT': 9, 'GTF2F1': 9, 'CdsA': 5, 'HNF4A': 5, 'GART': 5, 'TDO2': 5, 'Serpe_4': 5, 'MED17': 5, 'FAM46A': 5, 'PTPN14': 5, 'SUPT5H': 6, 'SGPP1': 6, 'SMC2': 6, 'cycle': 6, 'CHAF1B': 6, 'COPB2': 6, 'Missing': 6, 'NDC80': 6, 'CTL9': 6, 'CDK6': 6, 'WDR20': 6, 'BICC1': 6, 'GPSM2': 6, 'ATAD3A': 6, 'RPS3': 6, 'IGF2BP3': 6, 'FIBP': 6, 'EGR1': 6, 'UBE4A': 6, 'ACRC': 6, 'LOC10_16': 6, 'NFYC': 6, 'SLC39A6': 6, 'RNF113A': 6, 'KIAA043': 10, 'ACBD5': 6, 'PSMB5': 6,
# ...

# %%
anno_dic = {}
import pandas as pd
anno_file = pd.read_csv("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/12.Rho_networks/2.Diapausing/Filtered_set_core_set.csv")
for row in anno_file.iterrows():
    anno_dic[row[1].iloc[0]] = row[1].iloc[3]
    anno_dic[row[1].iloc[1]] = row[1].iloc[4]
print((anno_dic))
# Out:
# {'5969at7088': 'DCAF7', '1943at7088': 'PKP4', '775at7088': 'SMARCA4', '1625at7088': 'SUPT5H', '7044at7088': 'GDAP2', '3839at7088': 'SMU1', '7446at7088': 'SGPP1', '2719at7088': 'BTBD9', '2003at7088': 'Chlor_1', '1993at7088': 'SMC2', '13002at7088': 'RBM48', '983at7088': 'LLGL1', 'cry1a': 'cry1a', '5891at7088': 'ACTL6A', '1076at7088': 'KDM2A', '9518at7088': 'COPE', 'cycle': 'cycle', '5314at7088': 'GPROAR1', '1746at7088': 'IQSEC1', '10826at7088': 'ARFIP1', '5036at7088': 'CHAF1B', '263at7088': 'PBRM1', '1319at7088': 'COPB2', '11115at7088': 'Missing', '2984at7088': 'PPAT', '10186at7088': 'SURF4', '190at7088': 'NWD2', '1065at7088': 'MAST4', '10778at7088': 'GATAD2A', '1753at7088': 'XPO5', '338at7088': 'TAF1', '1130at7088': 'EEF2', '2081at7088': 'EIF3A', '11337at7088': 'ATP5F1', '1330at7088': 'SEC23A', '2166at7088': 'PLS3', '1530at7088': 'PWP2', '10916at7088': 'RPL7A', '68at7088': 'FRY', '795at7088': 'EFTUD2', '7656at7088': 'NDC80', '7855at7088': 'PDHB', '4064at7088': 'SGPL1', '1218at7088': '
# ...

# %%
output = "Cluster,Num Genes,Upset class,GeneID"
for key,value in gene_dictionry.items():
    for geneID in value:
        cluster = gene_cluster_dictionary[anno_dic[geneID]]
        output += f"\n{cluster},({str(cluster_count[cluster])}),{key},{geneID}"

with open(f"/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Upset_plot_deconstructed_for_degree/3.Intersection_genes_upset_cluster/Cluster.csv", 'w') as out_file:
    out_file.write(output)
        # print(cluster)
        # assert False

# %%
import os
location = "/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Upset_plot_deconstructed_for_degree/1.Gene_lists"
list_files = os.listdir(location)
gene_dictionry = {}
gene_list = []
name_dictionary = {"all_three": "All three","lassiommata_only":"Lasiommata megera","las_napi_only":"L. megera & P. napi","las_para_only":"L. megera & P. aegeria","napi_only":"Pieris napi","napi_para_only":"P. napi & P. aegeria","pararge_only":"Pararge aegeria"}
for file in list_files:
    # gene_dictionry[name_dictionary[file.split(".")[0]]] = []
    with open(f"{location}/{file}", 'r') as gene_list_file:
        for gene in gene_list_file:
            gene_list.append(gene.strip())
            gene_dictionry[gene.strip()] = name_dictionary[file.split(".")[0]]
            # assert False
print(gene_dictionry)
# Out:
# {'3016at7088': 'All three', '1846at7088': 'All three', '4021at7088': 'All three', '4480at7088': 'All three', '190at7088': 'All three', '2905at7088': 'All three', '1947at7088': 'All three', '3363at7088': 'All three', '496at7088': 'All three', '821at7088': 'All three', '717at7088': 'All three', '1709at7088': 'All three', '3667at7088': 'All three', '4595at7088': 'All three', '13737at7088': 'All three', '8222at7088': 'All three', '4935at7088': 'All three', '10101at7088': 'All three', '10571at7088': 'All three', '2201at7088': 'All three', '5679at7088': 'All three', '2939at7088': 'All three', '5486at7088': 'All three', '12212at7088': 'All three', '1144at7088': 'All three', '1628at7088': 'All three', '2813at7088': 'All three', '11619at7088': 'All three', '7044at7088': 'All three', '4799at7088': 'All three', '6173at7088': 'All three', '4078at7088': 'All three', '1076at7088': 'All three', 'cycle': 'All three', '1319at7088': 'All three', '11115at7088': 'All three', '1753at7088': 'All three', '
# ...

# %%
output = "Gene,Annotation,Lasiommata megera,Pieris napi,Pararge aegeria"
name_dictionary = {"all_three": "All three","lassiommata_only":"Lasiommata megera","las_napi_only":"L. megera & P. napi","las_para_only":"L. megera & P. aegeria","napi_only":"Pieris napi","napi_para_only":"P. napi & P. aegeria","pararge_only":"Pararge aegeria"}
for key,value in gene_dictionry.items():
    if value == "All three":
        output += f"\n{key},{anno_dic[key]},Present,Present,Present"
    elif value == "Lasiommata megera":
        output += f"\n{key},{anno_dic[key]},Present,Absent,Absent"
    elif value == "L. megera & P. napi":
        output += f"\n{key},{anno_dic[key]},Present,Present,Absent"
    elif value == "L. megera & P. aegeria":
        output += f"\n{key},{anno_dic[key]},Present,Absent,Present"
    elif value == "Pieris napi":
        output += f"\n{key},{anno_dic[key]},Absent,Present,Absent"
    elif value == "P. napi & P. aegeria":
        output += f"\n{key},{anno_dic[key]},Absent,Present,Present"
    elif value == "Pararge aegeria":
        output += f"\n{key},{anno_dic[key]},Absent,Absent,Present"
    else:
        print("error")
        assert False
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Upset_plot_deconstructed_for_degree/Gene_presence_absence_per_species.csv", 'w') as out_file:
    out_file.write(output)
