# %%
gene_anno_dic = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/20.RERconverge/2.Modified_diapause/correlation_with_annotation.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        gene_name = lines.split(",")[0].split("_")[0]
        # print(gene_name)
        anno_name = lines.split(",")[-1].replace('"', '')
        gene_anno_dic[gene_name]= anno_name.strip()

# %%
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/6.GSEA_rho/3.Positive_modi/gene_names.txt", 'r') as gene_name_file:
    for lines in gene_name_file.readlines()[1:]:
        print(lines.strip(), gene_anno_dic[lines.strip()])
# Out:
# 2905at7088 per
# 12510at7088 CHMP1B
# 13263at7088 DSTN
# 16035at7088 ATP6V1G1
# 2560at7088 LETM1
# 3165at7088 TH
# 3362at7088 NOP14
# 3811at7088 LPCAT3
# 4043at7088 ACAT1
# 4842at7088 HDAC2
# 5326at7088 NPFFR2
# 5423at7088 QRSL1
# 5474at7088 CLOCK
# 5679at7088 5679at7088
# 6081at7088 6081at7088
# 8044at7088 Met
# 8751at7088 8751at7088
# 8809at7088 ENAH
# 10001at7088 NTHL1
# 1390at7088 USP2
# 1422at7088 tim
# 1709at7088 CSDE1
# 1846at7088 SLC6A19
# 2036at7088 LINS

# %%
location = "/mnt/griffin/saubar/busco_runs_CDS_files/BUSCO_GCF_947172395.1_ilBicAnyn1.1_genomic.fna/run_lepidoptera_odb10/busco_sequences/single_copy_busco_sequences"

import os
from Bio import SeqIO

list_of_files = os.listdir(location)
output = ""
for i,file_name in enumerate(list_of_files):
    print(i, end = ",")
    if file_name.endswith(".faa"):
        fasta_file = SeqIO.parse(f"{location}/{file_name}", 'fasta')
        for records in fasta_file:
            output += f">{records.id}\n{records.seq}\n\n"

with open("/mnt/griffin/saubar/busco_runs_CDS_files/BUSCO_GCF_947172395.1_ilBicAnyn1.1_genomic.fna/just_aa.fas", 'w') as out_file:
    out_file.write(output)
