# %%
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/3.Pararge_aegeria"
import numpy 
fst_dictionary = {}
fst_list = []
with open(f"{location}/1.FST_peaks_from_chris/two_pool_5%_0.076_5kb_unmerged.fst",'r') as fst_file:
    for fst_lines in fst_file.readlines()[1:]:
        line_split = fst_lines.strip().split(",")
        
        fst_dictionary.setdefault(line_split[0],[])
        # # try:
        # # if float(line_split[3]) > 0.095:
        fst_dictionary[line_split[0]].append([[int(line_split[1]), int(line_split[2])],float(line_split[3])] )
        # # except:
            # pass
        # break
print(fst_dictionary)
# numpy.percentile(fst_list, 99)
# Out:
# {'NC_053189.1': [[[179001, 180000], 0.10128], [[215001, 216000], 0.0938657], [[219001, 220000], 0.102413], [[229001, 230000], 0.137239], [[232001, 233000], 0.121415], [[233001, 234000], 0.0764243], [[304001, 305000], 0.0773442], [[491001, 492000], 0.0876043], [[521001, 522000], 0.120471], [[553001, 554000], 0.125997], [[554001, 555000], 0.100408], [[555001, 556000], 0.121682], [[556001, 557000], 0.152123], [[557001, 558000], 0.170918], [[558001, 559000], 0.185852], [[559001, 560000], 0.200024], [[560001, 561000], 0.173361], [[561001, 562000], 0.0848307], [[564001, 565000], 0.15918], [[565001, 566000], 0.148853], [[566001, 567000], 0.189972], [[567001, 568000], 0.148104], [[569001, 570000], 0.138258], [[570001, 571000], 0.185168], [[571001, 572000], 0.134677], [[572001, 573000], 0.160873], [[648001, 649000], 0.0880829], [[830001, 831000], 0.0906089], [[1007001, 1008000], 0.14108], [[1062001, 1063000], 0.0798993], [[1064001, 1065000], 0.111274], [[1065001, 1066000], 0.155551], [[1066001, 1067000], 0.0970752], [[1077001, 1078000], 0.124372], [[1145001, 1146000], 0.201859], [[1147001, 1148000], 0.0765515], [[1148001, 1149000], 0.113773], [[1154001, 1155000], 0.0957883], [[1155001, 1156000], 0.183784], [[1156001, 1157000], 0.106449], [[1157001, 1158000], 0.153985], [[1158001, 1159000], 0.125604], [[1159001, 1160000], 0.120613], [[1234001, 1235000], 0.101204], [[1282001, 1283000], 0.0800482], [[1292001, 1293000], 0.096679], [[1316001, 1317000], 0.0874437], [[1403001, 1404000], 0.110945], [[1414001, 1415000], 0.157049], [[1415001, 1416000], 0.0918164], [[1417001, 1418000], 0.132061], [[1418001, 1419000], 0.089797], [[1419001, 1420000], 0.156048], [[1424001, 1425000], 0.124561], [[1427001, 1428000], 0.0890954], [[1437001, 1438000], 0.135378], [[1438001, 1439000], 0.0948337], [[1504001, 1505000], 0.107221], [[1508001, 1509000], 0.100222], [[1510001, 1511000], 0.0898914], [[1513001, 1514000], 0.100126], [[1515001, 1516000], 0.096951], [[1523001, 1524000], 0.0873284], [[1524001, 1525000], 0.0833424], [[1525001, 1526000], 0.0954393], [[1621001, 1622000], 0.112948], [[1633001, 1634000], 0.1688], [[1667001, 1668000], 0.120351], [[1743001, 1744000], 0.145171], [[1745001, 1746000], 0.143279], [[1849001, 1850000], 0.0789051], [[2082001, 2083000], 0.106299], [[2095001, 2096000], 0.0802313], [[2163001, 2164000], 0.109265], [[2198001, 2199000], 0.121655], [[2199001, 2200000], 0.139997], [[2200001, 2201000], 0.112583], [[2201001, 2202000], 0.159138], [[2202001, 2203000], 0.15931], [[2205001, 2206000], 0.128546], [[2206001, 2207000], 0.120471], [[2209001, 2210000], 0.133706], [[2210001, 2211000], 0.192307], [[2211001, 2212000], 0.127223], [[2212001, 2213000], 0.177574], [[2213001, 2214000], 0.193768], [[2214001, 2215000], 0.117195], [[2215001, 2216000], 0.0779363], [[2249001, 2250000], 0.100304], [[2313001, 2314000], 0.0904863], [[2419001, 2420000], 0.0877834], [[2470001, 2471000], 0.101532], [[2479001, 2480000], 0.0938561], [[2485001, 2486000], 0.136773], [[2555001, 2556000], 0.0873068], [[2571001, 2572000], 0.102824], [[2578001, 2579000], 0.0935788], [[2621001, 2622000], 0.0978276], [[2622001, 2623000], 0.0837851], [[2623001, 2624000], 0.0803154], [[2624001, 2625000], 0.0983726], [[2631001, 2632000], 0.121419], [[2711001, 2712000], 0.112763], [[2712001, 2713000], 0.0935559], [[2715001, 2716000], 0.114615], [[2728001, 2729000], 0.122507], [[2729001, 2730000], 0.082648], [[2730001, 2731000], 0.152916], [[2750001, 2751000], 0.0906423], [[2864001, 2865000], 0.0891587], [[2980001, 2981000], 0.122597], [[2981001, 2982000], 0.0906544], [[2982001, 2983000], 0.11822], [[3015001, 3016000], 0.0790374], [[3045001, 3046000], 0.0766781], [[3047001, 3048000], 0.101558], [[3050001, 3051000], 0.0965617], [[3107001, 3108000], 0.0770607], [[3111001, 3112000], 0.150748], [[3130001, 3131000], 0.0893691], [[3131001, 3132000], 0.0805347], [[3132001, 3133000], 0.11101], [[3257001, 3258000], 0.0824367], [[3258001, 3259000], 0.09481], [[3383001, 3384000], 0.102948], [[365 ...

# %%
gene_anno_dic = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/2.Two_state/correlation_2_with_annotation.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        gene_name = lines.split(",")[0].split("_")[0][1:]
        anno_name = lines.split(",")[-1].replace('"', '')
        gene_anno_dic[gene_name]= anno_name.strip()

# print(gene_anno_dic)

# %%
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/3.Pararge_aegeria"
import numpy 
fst_dictionary = {}
fst_list = []
with open(f"{location}/1.FST_peaks_from_chris/two_pool_5%_0.076_5kb_unmerged.fst",'r') as fst_file:
    for fst_lines in fst_file.readlines()[1:]:
        line_split = fst_lines.strip().split(",")
        
        fst_dictionary.setdefault(line_split[0],[])
        # # try:
        # # if float(line_split[3]) > 0.095:
        fst_dictionary[line_split[0]].append([[int(line_split[1]), int(line_split[2])],float(line_split[3])] )
        # # except:
            # pass
        # break
# print(fst_dictionary)
# numpy.percentile(fst_list, 99)

gene_loc_dic = {}
with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'r') as gene_loc_file:
    for gene_line in gene_loc_file.readlines()[1:]:
        line_split = gene_line.strip().split("\t")
        gene_loc_dic[line_split[0]] = [line_split[1],line_split[2],line_split[3]]
# print(gene_loc_dic)

common_genes = []
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Present_in_all_3_5%/gene_list.txt", 'r') as common_genes_file:
    for common_gene_name in common_genes_file:
        common_genes.append(common_gene_name.strip())


rho_genes = []

with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/4.Rho_genes_and_RhoSet/25_rho_genes.txt", 'r') as rho_genes_file:
    for rho_gene in rho_genes_file:
        rho_genes.append(rho_gene.strip())


intersecting_genes = []
common_counter = []
rho_genes_counter = []
with open(f"{location}/3.Rho_set_genes/Rho_set_cluster.txt", 'r') as rho_set_file:
    for rho_set_count,lines in enumerate(rho_set_file.readlines()):
        rho_gene_name = lines.strip().split("\t")[0]

        try:
            chromosome,start,end = gene_loc_dic[rho_gene_name]
        except:
            print(rho_gene_name, "missing")
        
        
        for sections in (fst_dictionary[chromosome]):
            out_list = []
            
          
            if (((int(start) >= sections[0][0] and int(start) <= sections[0][1]) or (int(end) >= sections[0][0] and int(end) <= sections[0][1])) or ((sections[0][0] >= int(start) and sections[0][0] <= int(end)) or (sections[0][1] >= int(start) and sections[0][1] <= int(end)))) and len(sections) < 3:
                # print(sections)
                try:
                    sections.append(f"{gene_anno_dic[rho_gene_name]}")
                except:
                    sections.append(f"{rho_gene_name}")
                    print(rho_gene_name, "missing annottaion")
                if rho_gene_name in common_genes:
                    if rho_gene_name not in common_counter:
                        common_counter.append(rho_gene_name)
                    # common_counter += 1
                    try:
                        sections.append(f"{gene_anno_dic[rho_gene_name]}")
                    except:
                        sections.append(f"{rho_gene_name}")
                        print(rho_gene_name, "missing annottaion")
                    if rho_gene_name in rho_genes:
                        if rho_gene_name not in rho_genes_counter:
                            rho_genes_counter.append(rho_gene_name)
                        # common_counter += 1
                        try:
                            sections.append(f"{gene_anno_dic[rho_gene_name]}")
                        except:
                            sections.append(f"{rho_gene_name}")
                            print(rho_gene_name, "missing annottaion")
                # print(sections)
                # assert False
                    
                
                if rho_gene_name not in intersecting_genes:
                    intersecting_genes.append(rho_gene_name)
          
print("\n",len(intersecting_genes), rho_set_count, len(common_counter), len(rho_genes_counter))
# Out:
# 3284at7088 missing
# cry1a missing
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# 4746at7088 missing annottaion
# 10387at7088 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# 10698at7088 missing annottaion
# 10698at7088 missing annottaion
#
#  242 503 94 8

# %%
output = "CHR,BP,P,SNP,Common,Rho"
chrom_dic = {"NC_053180.1":"1","NC_053181.1":"2","NC_053182.1":"3","NC_053183.1":"4","NC_053184.1":"5","NC_053185.1":"6","NC_053186.1":"7","NC_053187.1":"8","NC_053188.1":"9","NC_053189.1":"10","NC_053190.1":"11","NC_053191.1":"12","NC_053192.1":"13","NC_053193.1":"14","NC_053194.1":"15","NC_053195.1":"16","NC_053196.1":"17","NC_053197.1":"18","NC_053198.1":"19","NC_053199.1":"20","NC_053200.1":"21","NC_053201.1":"22","NC_053202.1":"23","NC_053203.1":"24","NC_053204.1":"25","NC_053205.1":"26","NC_053206.1":"27","NC_053208.1":"Z","NC_053207.1":"W"}
for key,value in fst_dictionary.items():
    print(key)
    
    chrom = chrom_dic[key]
    print(chrom)
    for pos in value:
        # Compute the midpoint
        midpoint = int((pos[0][0] + pos[0][1]) / 2)
        
        # Start building the row
        row = [chrom, midpoint]
        
        # pos[1] is assumed to always exist
        row.append(pos[1])
        
        # Check for pos[2] and pos[3]
        if len(pos) > 4 and pos[4] is not None:
            row.append(pos[2])
            row.append(pos[3])
            row.append(pos[4])
        elif len(pos) > 3 and pos[3] is not None:
            row.append(pos[2])
            row.append(pos[3])
            row.append('')
        elif len(pos) > 2 and pos[2] is not None:
            row.append(pos[2])
            row.append('')
            row.append('')
        else:
            row.append('')  # placeholder if pos[3] missing
            row.append('')
            row.append('')
        output += "\n" + ",".join(map(str, row))
        # try:
        #     output += f"\n{chrom},{int((pos[0][0] + pos[0][1])/2)},{pos[1]},{pos[2]}"
        # except IndexError:
        #     output += f"\n{chrom},{int((pos[0][0] + pos[0][1])/2)},{pos[1]},"
        #     print(pos)
        # # print(output)
        # print(pos) 
        # assert False
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/7.Manhatten/dataset_5P_pararge_unmerged.csv", 'w') as out_file:
    out_file.write(output)
# Out:
# NC_053189.1
# 10
# NC_053190.1
# 11
# NC_053191.1
# 12
# NC_053192.1
# 13
# NC_053193.1
# 14
# NC_053194.1
# 15
# NC_053195.1
# 16
# NC_053196.1
# 17
# NC_053197.1
# 18
# NC_053198.1
# 19
# NC_053180.1
# 1
# NC_053199.1
# 20
# NC_053200.1
# 21
# NC_053201.1
# 22
# NC_053202.1
# 23
# NC_053203.1
# 24
# NC_053204.1
# 25
# NC_053205.1
# 26
# NC_053206.1
# 27
# NC_053181.1
# 2
# NC_053182.1
# 3
# NC_053183.1
# 4
# NC_053184.1
# 5
# NC_053185.1
# 6
# NC_053186.1
# 7
# NC_053187.1
# 8
# NC_053188.1
# 9
# NC_053208.1
# Z
