# %%
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/2.Pieris_napi"
import numpy 
fst_dictionary = {}
fst_list = []
with open(f"{location}/1.FST_peaks_from_chris/two_pool_5%_0.05_5kb_merged.fst",'r') as fst_file:
    for fst_lines in fst_file.readlines()[1:]:
        line_split = fst_lines.strip().split(",")
        
        fst_dictionary.setdefault(line_split[0],[])
        # # try:
        # # if float(line_split[3]) > 0.095:
        fst_dictionary[line_split[0]].append([[int(line_split[1]), int(line_split[2])],float(line_split[3])] )
        # # except:
            # pass
        # break
print(fst_dictionary)
# numpy.percentile(fst_list, 99)
# Out:
# {'NC_062234.1': [[[12001, 13000], 0.072], [[126001, 128000], 0.082], [[282001, 283000], 0.057], [[334001, 335000], 0.086], [[349001, 350000], 0.066], [[433001, 438000], 0.119], [[518001, 519000], 0.054], [[531001, 539000], 0.077], [[552001, 553000], 0.057], [[575001, 586000], 0.058], [[604001, 605000], 0.057], [[632001, 633000], 0.058], [[645001, 649000], 0.053], [[656001, 662000], 0.071], [[698001, 699000], 0.05], [[714001, 715000], 0.075], [[738001, 739000], 0.051], [[744001, 745000], 0.051], [[753001, 764000], 0.068], [[778001, 779000], 0.06], [[789001, 790000], 0.061], [[800001, 804000], 0.067], [[818001, 820000], 0.075], [[828001, 831000], 0.077], [[847001, 851000], 0.09], [[856001, 860000], 0.072], [[866001, 867000], 0.06], [[908001, 909000], 0.058], [[949001, 950000], 0.063], [[984001, 993000], 0.088], [[1002001, 1003000], 0.052], [[1127001, 1128000], 0.059], [[1175001, 1181000], 0.057], [[1191001, 1196000], 0.096], [[1264001, 1270000], 0.052], [[1282001, 1283000], 0.079], [[1341001, 1342000], 0.077], [[1453001, 1454000], 0.052], [[1480001, 1483000], 0.067], [[1495001, 1496000], 0.055], [[1511001, 1512000], 0.058], [[1518001, 1519000], 0.058], [[1566001, 1567000], 0.067], [[1914001, 1919000], 0.057], [[1964001, 1969000], 0.054], [[1977001, 1978000], 0.058], [[1987001, 1992000], 0.098], [[2001001, 2004000], 0.053], [[2080001, 2081000], 0.066], [[2171001, 2172000], 0.14], [[2217001, 2218000], 0.054], [[2256001, 2257000], 0.055], [[2292001, 2293000], 0.057], [[2351001, 2352000], 0.056], [[2359001, 2362000], 0.053], [[2374001, 2375000], 0.259], [[2422001, 2423000], 0.063], [[2465001, 2468000], 0.062], [[2553001, 2554000], 0.084], [[2588001, 2589000], 0.063], [[2677001, 2678000], 0.091], [[2691001, 2695000], 0.068], [[2748001, 2749000], 0.07], [[2859001, 2867000], 0.053], [[2977001, 2978000], 0.086], [[3072001, 3073000], 0.052], [[3081001, 3082000], 0.08], [[3108001, 3110000], 0.071], [[3127001, 3128000], 0.05], [[3146001, 3147000], 0.063], [[3182001, 3183000], 0.072], [[3189001, 3190000], 0.064], [[3234001, 3235000], 0.062], [[3323001, 3324000], 0.068], [[3381001, 3382000], 0.053], [[3399001, 3405000], 0.11], [[3416001, 3422000], 0.052], [[3445001, 3453000], 0.107], [[3464001, 3465000], 0.053], [[3543001, 3546000], 0.09], [[3634001, 3635000], 0.076], [[3648001, 3649000], 0.072], [[3655001, 3656000], 0.058], [[3693001, 3694000], 0.088], [[3725001, 3726000], 0.054], [[3813001, 3814000], 0.06], [[3823001, 3824000], 0.057], [[3851001, 3852000], 0.055], [[3869001, 3870000], 0.054], [[3879001, 3880000], 0.056], [[3888001, 3889000], 0.066], [[3946001, 3965000], 0.07], [[3974001, 3975000], 0.052], [[3983001, 3984000], 0.166], [[4024001, 4025000], 0.062], [[4031001, 4032000], 0.074], [[4061001, 4064000], 0.055], [[4101001, 4102000], 0.055], [[4126001, 4127000], 0.053], [[4161001, 4162000], 0.052], [[4280001, 4281000], 0.071], [[4315001, 4320000], 0.096], [[4396001, 4397000], 0.058], [[4522001, 4523000], 0.057], [[4534001, 4540000], 0.069], [[4632001, 4633000], 0.101], [[4672001, 4673000], 0.07], [[4767001, 4768000], 0.064], [[4780001, 4781000], 0.067], [[4814001, 4815000], 0.077], [[4827001, 4834000], 0.092], [[4840001, 4844000], 0.07], [[4855001, 4857000], 0.085], [[4864001, 4865000], 0.058], [[4889001, 4890000], 0.066], [[5027001, 5028000], 0.059], [[5043001, 5047000], 0.053], [[5064001, 5065000], 0.087], [[5242001, 5249000], 0.061], [[5302001, 5304000], 0.075], [[5342001, 5343000], 0.058], [[5392001, 5396000], 0.053], [[5469001, 5470000], 0.065], [[5592001, 5593000], 0.061], [[5675001, 5677000], 0.059], [[5682001, 5683000], 0.056], [[5741001, 5742000], 0.062], [[5904001, 5905000], 0.056], [[5924001, 5925000], 0.054], [[5970001, 5971000], 0.066], [[6061001, 6062000], 0.318], [[6134001, 6136000], 0.103], [[6145001, 6146000], 0.416], [[6174001, 6176000], 0.084], [[6193001, 6199000], 0.096], [[6443001, 6444000], 0.078], [[6485001, 6486000], 0.079], [[6511001, 6512000], 0.093], [[6576001, 6577000], 0.053], [[6656001, 6657000], 0.077], ...

# %%
gene_anno_dic = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/2.Two_state/correlation_2_with_annotation.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        gene_name = lines.split(",")[0].split("_")[0][1:]
        anno_name = lines.split(",")[-1].replace('"', '')
        gene_anno_dic[gene_name]= anno_name.strip()

# print(gene_anno_dic)

# %%
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/2.Pieris_napi"
import numpy 
fst_dictionary = {}
fst_list = []
with open(f"{location}/1.FST_peaks_from_chris/two_pool_5%_0.05_5kb_unmerged.fst",'r') as fst_file:
    for fst_lines in fst_file.readlines()[1:]:
        line_split = fst_lines.strip().split(",")
        
        fst_dictionary.setdefault(line_split[0],[])
        # # try:
        # # if float(line_split[3]) > 0.095:
        fst_dictionary[line_split[0]].append([[int(line_split[1]), int(line_split[2])],float(line_split[3])] )
        # # except:
            # pass
        # break
# print(fst_dictionary)
# numpy.percentile(fst_list, 99)

gene_loc_dic = {}
with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'r') as gene_loc_file:
    for gene_line in gene_loc_file.readlines()[1:]:
        line_split = gene_line.strip().split("\t")
        gene_loc_dic[line_split[0]] = [line_split[1],line_split[2],line_split[3]]
# print(gene_loc_dic)

common_genes = []
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/22.Present_in_all_3_5%/gene_list.txt", 'r') as common_genes_file:
    for common_gene_name in common_genes_file:
        common_genes.append(common_gene_name.strip())

rho_genes = []

with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/4.Rho_genes_and_RhoSet/25_rho_genes.txt", 'r') as rho_genes_file:
    for rho_gene in rho_genes_file:
        rho_genes.append(rho_gene.strip())

intersecting_genes = []
common_counter = []
rho_genes_counter = []

with open(f"{location}/3.Rho_set_genes/Rho_set_cluster.txt", 'r') as rho_set_file:
    for rho_set_count,lines in enumerate(rho_set_file.readlines()):
        rho_gene_name = lines.strip().split("\t")[0]

        try:
            chromosome,start,end = gene_loc_dic[rho_gene_name]
        except:
            print(rho_gene_name, "missing")
        
        
        for sections in (fst_dictionary[chromosome]):
            out_list = []
            
          
            if (((int(start) >= sections[0][0] and int(start) <= sections[0][1]) or (int(end) >= sections[0][0] and int(end) <= sections[0][1])) or ((sections[0][0] >= int(start) and sections[0][0] <= int(end)) or (sections[0][1] >= int(start) and sections[0][1] <= int(end)))) and len(sections) < 3:
                # print(sections)
                try:
                    sections.append(f"{gene_anno_dic[rho_gene_name]}")
                except:
                    sections.append(f"{rho_gene_name}")
                    print(rho_gene_name, "missing annottaion")
                if rho_gene_name in common_genes:
                    if rho_gene_name not in common_counter:
                        common_counter.append(rho_gene_name)
                    # common_counter += 1
                    try:
                        sections.append(f"{gene_anno_dic[rho_gene_name]}")
                    except:
                        sections.append(f"{rho_gene_name}")
                        print(rho_gene_name, "missing annottaion")
                    if rho_gene_name in rho_genes:
                        if rho_gene_name not in rho_genes_counter:
                            rho_genes_counter.append(rho_gene_name)
                        # common_counter += 1
                        try:
                            sections.append(f"{gene_anno_dic[rho_gene_name]}")
                        except:
                            sections.append(f"{rho_gene_name}")
                            print(rho_gene_name, "missing annottaion")    
                # print(sections)
                # assert False
                    
                
                if rho_gene_name not in intersecting_genes:
                    intersecting_genes.append(rho_gene_name)
          
print("\n",len(intersecting_genes), rho_set_count, len(common_counter), len(rho_genes_counter))
# Out:
# 3161at7088 missing
# cry1a missing
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# cycle missing annottaion
# 10387at7088 missing
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# cry2 missing annottaion
# 14318at7088 missing annottaion
# 14318at7088 missing annottaion
# 13157at7088 missing annottaion
# 10698at7088 missing annottaion
# 11965at7088 missing annottaion
# 11965at7088 missing annottaion
# 11965at7088 missing annottaion
#
#  259 503 92 8

# %%
output = "CHR,BP,P,SNP,Common,Rho"
chrom_dic = {"NC_062234.1":"1","NC_062235.1":"2","NC_062236.1":"3","NC_062237.1":"4","NC_062238.1":"5","NC_062239.1":"6","NC_062240.1":"7","NC_062241.1":"8","NC_062242.1":"9","NC_062243.1":"10","NC_062244.1":"11","NC_062245.1":"12","NC_062246.1":"13","NC_062247.1":"14","NC_062248.1":"15","NC_062249.1":"16","NC_062250.1":"17","NC_062251.1":"18","NC_062252.1":"19","NC_062253.1":"20","NC_062254.1":"21","NC_062255.1":"22","NC_062256.1":"23","NC_062257.1":"24","NC_062258.1":"W","NC_062259.1":"Z","NW_025920860.1":"W1","NW_025920861.1":"W2","NW_025920862.1":"W3","NW_025920863.1":"W4"}
for key,value in fst_dictionary.items():
    print(key)
    try:
        chrom = chrom_dic[key]
    except:
        chrom = key 
    print(chrom)
    for pos in value:
        
        # Compute the midpoint
        midpoint = int((pos[0][0] + pos[0][1]) / 2)
        
        # Start building the row
        row = [chrom, midpoint]
        
        # pos[1] is assumed to always exist
        row.append(pos[1])
        
        # Check for pos[2] and pos[3]
        if len(pos) > 4 and pos[4] is not None:
            row.append(pos[2])
            row.append(pos[3])
            row.append(pos[4])
        elif len(pos) > 3 and pos[3] is not None:
            row.append(pos[2])
            row.append(pos[3])
            row.append('')
        elif len(pos) > 2 and pos[2] is not None:
            row.append(pos[2])
            row.append('')
            row.append('')
        else:
            row.append('')  # placeholder if pos[3] missing
            row.append('')
            row.append('')
        output += "\n" + ",".join(map(str, row))
        # try:
        #     output += f"\n{chrom},{int((pos[0][0] + pos[0][1])/2)},{pos[1]},{pos[2]}"
        # except IndexError:
        #     output += f"\n{chrom},{int((pos[0][0] + pos[0][1])/2)},{pos[1]},"
        # #     print(pos)
        # # print(output)
        # print(pos) 
        # assert False
with open("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/7.Manhatten/dataset_5_napi_missing.csv", 'w') as out_file:
    out_file.write(output)
# Out:
# NC_062234.1
# 1
# NC_062235.1
# 2
# NC_062236.1
# 3
# NC_062237.1
# 4
# NC_062238.1
# 5
# NC_062239.1
# 6
# NC_062240.1
# 7
# NC_062241.1
# 8
# NC_062242.1
# 9
# NC_062243.1
# 10
# NC_062244.1
# 11
# NC_062245.1
# 12
# NC_062246.1
# 13
# NC_062247.1
# 14
# NC_062248.1
# 15
# NC_062249.1
# 16
# NC_062250.1
# 17
# NC_062251.1
# 18
# NC_062252.1
# 19
# NC_062253.1
# 20
# NC_062254.1
# 21
# NC_062255.1
# 22
# NC_062256.1
# 23
# NC_062257.1
# 24
# NC_062258.1
# W
# NC_062259.1
# Z
# NW_025920860.1
# W1
# NW_025920861.1
# W2
# NW_025920862.1
# W3
# NW_025920863.1
# W4
# NW_025920864.1
# NW_025920864.1
# NW_025920865.1
# NW_025920865.1
# NW_025920868.1
# NW_025920868.1
# NW_025920872.1
# NW_025920872.1
# NW_025920874.1
# NW_025920874.1
