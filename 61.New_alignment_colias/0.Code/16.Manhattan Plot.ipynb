# %%
import pandas as pd
from dash import dcc
import dash_bio as dashbio
import plotly

df = pd.read_csv("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/7.Manhatten/dataset.csv")

# n_chr = 23  # number of chromosome pairs in humans
# assert 'CHR' in df.columns
# assert df['CHR'].max() == n_chr

# Trim down the data
# DATASET = df.groupby('CHR').apply(lambda u: u.head(50))
# DATASET = DATASET.droplevel('CHR').reset_index(drop=True)

manhattanplot = dashbio.ManhattanPlot(
    dataframe=df,
    chrm = "chrom",
    bp = "BP",
    p = "skane.lulea.fst",
    highlight_color='#00FFAA'
)

# dcc.Graph(figure=manhattanplot)

plotly.offline.plot(manhattanplot, image='png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 16
#       6 df = pd.read_csv("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/7.Manhatten/dataset.csv")
#       8 # n_chr = 23  # number of chromosome pairs in humans
#       9 # assert 'CHR' in df.columns
#      10 # assert df['CHR'].max() == n_chr
#    (...)
#      13 # DATASET = df.groupby('CHR').apply(lambda u: u.head(50))
#      14 # DATASET = DATASET.droplevel('CHR').reset_index(drop=True)
# ---> 16 manhattanplot = dashbio.ManhattanPlot(
#      17     dataframe=df,
#      18     chrm = "chrom",
#      19     bp = "BP",
#      20     p = "skane.lulea.fst",
#      21     highlight_color='#00FFAA'
#      22 )
#      24 # dcc.Graph(figure=manhattanplot)
#      26 plotly.offline.plot(manhattanplot, image='png')
#
# ...

# %%
# !pip3 install dash_bio
# Out:
# DEPRECATION: Loading egg at /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages/ete3-3.1.3-py3.10.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 8.6 MB/s eta 0:00:0000:010:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 9.3 MB/s eta 0:00:0000:0100:01m
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 10.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.1/811.1 kB 9.6 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 6.7 MB/s eta 0:00:0000:01
# ...

# %%
import numpy as np

dataframe = pd.DataFrame(
    np.random.randint(0,100,size=(100, 3)),
    columns=['P', 'CHR', 'BP'])
fig = dashbio.ManhattanPlot(dataframe, title='XYZ Manhattan plot')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 6
#       1 import numpy as np
#       3 dataframe = pd.DataFrame(
#       4     np.random.randint(0,100,size=(100, 3)),
#       5     columns=['P', 'CHR', 'BP'])
# ----> 6 fig = dashbio.ManhattanPlot(dataframe, title='XYZ Manhattan plot')
#       8 plotly.offline.plot(fig, image='png')
#
# File ~/miniconda3/envs/genomics_work/lib/python3.11/site-packages/dash_bio/component_factory/_manhattan.py:127, in ManhattanPlot(dataframe, chrm, bp, p, snp, gene, annotation, logp, title, showgrid, xlabel, ylabel, point_size, showlegend, col, suggestiveline_value, suggestiveline_color, suggestiveline_width, genomewideline_value, genomewideline_color, genomewideline_width, highlight, highlight_color)
#      15 def ManhattanPlot(
#      16         dataframe,
#      17         chrm="CHR",
#    (...)
# ...
