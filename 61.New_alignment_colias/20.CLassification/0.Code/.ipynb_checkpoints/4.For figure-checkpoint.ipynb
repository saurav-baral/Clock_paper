# %%
from Bio import Phylo

# Load the tree
tree = Phylo.read("/mnt/c/Users/sauba/Desktop/Drosophila_BUSCO_ERC/16.ERC_expanded/8.For_tree/merged_100sp.fas.figtree.nwk", "newick")

# Option 1: Get species in the order they appear in the tree tips
tip_order = [term.name for term in tree.get_terminals()]
print("Tip order:", tip_order)
# Out:
# Tip order: ['Drosophila_ananassae', 'Drosophila_pandora', 'Drosophila_bipectinata', 'Drosophila_parabipectinata', 'Drosophila_malerkotliana_malerkotliana', 'Drosophila_pseudoananassae_pseudoananassae', 'Drosophila_ironensis', 'Drosophila_setifemur', 'Drosophila_biarmipes', 'Drosophila_subpulchrella', 'Drosophila_suzukii', 'Drosophila_takahashii', 'Drosophila_erecta', 'Drosophila_santomea', 'Drosophila_yakuba', 'Drosophila_teissieri', 'Drosophila_mauritiana', 'Drosophila_sechellia', 'Drosophila_simulans', 'Drosophila_melanogaster', 'Drosophila_eugracilis', 'Drosophila_elegans', 'Drosophila_gunungcola', 'Drosophila_rhopaloa', 'Drosophila_ficusphila', 'Drosophila_kikkawai', 'Drosophila_serrata', 'Drosophila_bocqueti', 'Drosophila_jambulina', 'Drosophila_rufa', 'Drosophila_triauraria', 'Drosophila_guanche', 'Drosophila_madeirensis', 'Drosophila_subobscura', 'Drosophila_obscura', 'Drosophila_bifasciata', 'Drosophila_miranda', 'Drosophila_persimilis', 'Drosophila_pseudoobscura', 'Drosophil
# ...
