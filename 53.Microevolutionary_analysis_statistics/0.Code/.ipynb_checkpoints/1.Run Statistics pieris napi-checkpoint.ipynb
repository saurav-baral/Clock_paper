# %% [markdown]
# ## Expand Gene identities

# %%
# %reset
import pandas as pd
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/2.Pieris_napi"

gene_table = pd.read_csv(f"{location}/2.Annotation_busco_prediction/full_table.tsv", sep= "\t")
gene_table
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y
#          Busco_id    Status     Sequence  Gene_Start    Gene_End Strand  \
# 0         0at7088  Complete  NC_062252.1    641147.0    538914.0      -
# 1         1at7088  Complete  NC_062259.1   9931230.0  10025586.0      +
# 2         2at7088  Complete  NC_062243.1  10038037.0  10120567.0      +
# 3         3at7088  Complete  NC_062240.1   1488576.0   1636340.0      +
# 4         4at7088  Complete  NC_062253.1   1072096.0   1192687.0      +
# ...           ...       ...          ...         ...         ...    ...
# 5315  16855at7088  Complete  NC_062247.1  12577763.0  12578276.0      +
# 5316  16938at7088  Complete  NC_062256.1    333560.0    336762.0      +
# 5317  16982at7088  Complete  NC_062248.1    803081.0    801475.0      -
# 5318        cycle  Complete  NC_062259.1   2828816.0   2853025.0      -
# 5319         cry2  Complete  NC_062257.1   2060530.0   2078388.0      -
#
#         Score   Length                                   OrthoDB url  \
# 0     16924.2   7966.0      https://v10-1.orthodb.org/?query=0at7088
# 1      9353.3   4245.0      https://v10-1.orthodb.org/?query=1at7088
# 2     25094.3  14024.0      https://v10-1.orthodb.org/?query=2at7088
# 3     10339.2   5352.0      https://v10-1.orthodb.org/?query=3at7088
# 4     13332.1   6903.0      https://v10-1.orthodb.org/?query=4at7088
# ...       ...      ...                                           ...
# 5315    146.4     97.0  https://v10-1.orthodb.org/?query=16855at7088
# 5316    120.2    117.0  https://v10-1.orthodb.org/?query=16938at7088
# 5317    139.8    124.0  https://v10-1.orthodb.org/?query=16982at7088
# 5318    139.8    124.0  https://v10-1.orthodb.org/?query=16982at7088
# 5319    139.8    124.0  https://v10-1.orthodb.org/?query=16982at7088
#
#                                Description
# 0                           Immunoglobulin
# 1                           Immunoglobulin
# 2          EGF-like calcium-binding domain
# 3                          Spectrin repeat
# 4                          Spectrin repeat
# ...                                    ...
# 5315            AT hook, DNA-binding motif
# 5316  uncharacterized protein LOC111359467
# 5317  uncharacterized protein LOC110991765
# 5318                                 cycle
# 5319                                  cry2
#
# [5320 rows x 10 columns]

# %%
output = "Busco_id\tChromosome\tGene_Start\tGene_End"
for row_details in gene_table.itertuples():
    if not(pd.isna(row_details.Sequence)):
        if row_details.Gene_Start > row_details.Gene_End:
            gene_start = row_details.Gene_End
            gene_end = row_details.Gene_Start
        else:
            gene_start = row_details.Gene_Start
            gene_end = row_details.Gene_End
        try:
            output += f"\n{row_details.Busco_id}\t{row_details.Sequence}\t{int(max(0,gene_start-10000))}\t{int(gene_end+10000)}"
        except:
            print(row_details.Busco_id, gene_end+10000)
            assert False
    # print(row_details)
    # break
with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'w') as out_file:
    out_file.write(output)

# %%
fst_dictionary = {}
with open(f"{location}/1.FST_peaks_from_chris/two_pool_5%_0.05_5kb_merged.fst",'r') as fst_file:
    for fst_lines in fst_file.readlines()[1:]:
        line_split = fst_lines.strip().split(",")
        fst_dictionary.setdefault(line_split[0],[])
        
        fst_dictionary[line_split[0]].append([int(line_split[1]), int(line_split[2])])
        
print(fst_dictionary)
# Out:
# {'NC_062234.1': [[12001, 13000], [126001, 128000], [282001, 283000], [334001, 335000], [349001, 350000], [433001, 438000], [518001, 519000], [531001, 539000], [552001, 553000], [575001, 586000], [604001, 605000], [632001, 633000], [645001, 649000], [656001, 662000], [698001, 699000], [714001, 715000], [738001, 739000], [744001, 745000], [753001, 764000], [778001, 779000], [789001, 790000], [800001, 804000], [818001, 820000], [828001, 831000], [847001, 851000], [856001, 860000], [866001, 867000], [908001, 909000], [949001, 950000], [984001, 993000], [1002001, 1003000], [1127001, 1128000], [1175001, 1181000], [1191001, 1196000], [1264001, 1270000], [1282001, 1283000], [1341001, 1342000], [1453001, 1454000], [1480001, 1483000], [1495001, 1496000], [1511001, 1512000], [1518001, 1519000], [1566001, 1567000], [1914001, 1919000], [1964001, 1969000], [1977001, 1978000], [1987001, 1992000], [2001001, 2004000], [2080001, 2081000], [2171001, 2172000], [2217001, 2218000], [2256001, 2257000], [2292001, 2293000], [2351001, 2352000], [2359001, 2362000], [2374001, 2375000], [2422001, 2423000], [2465001, 2468000], [2553001, 2554000], [2588001, 2589000], [2677001, 2678000], [2691001, 2695000], [2748001, 2749000], [2859001, 2867000], [2977001, 2978000], [3072001, 3073000], [3081001, 3082000], [3108001, 3110000], [3127001, 3128000], [3146001, 3147000], [3182001, 3183000], [3189001, 3190000], [3234001, 3235000], [3323001, 3324000], [3381001, 3382000], [3399001, 3405000], [3416001, 3422000], [3445001, 3453000], [3464001, 3465000], [3543001, 3546000], [3634001, 3635000], [3648001, 3649000], [3655001, 3656000], [3693001, 3694000], [3725001, 3726000], [3813001, 3814000], [3823001, 3824000], [3851001, 3852000], [3869001, 3870000], [3879001, 3880000], [3888001, 3889000], [3946001, 3965000], [3974001, 3975000], [3983001, 3984000], [4024001, 4025000], [4031001, 4032000], [4061001, 4064000], [4101001, 4102000], [4126001, 4127000], [4161001, 4162000], [4280001, 4281000], [4315001, 4320000], [4396001, 4397000], [4522001, 4523000], [4534001, 4540000], [4632001, 4633000], [4672001, 4673000], [4767001, 4768000], [4780001, 4781000], [4814001, 4815000], [4827001, 4834000], [4840001, 4844000], [4855001, 4857000], [4864001, 4865000], [4889001, 4890000], [5027001, 5028000], [5043001, 5047000], [5064001, 5065000], [5242001, 5249000], [5302001, 5304000], [5342001, 5343000], [5392001, 5396000], [5469001, 5470000], [5592001, 5593000], [5675001, 5677000], [5682001, 5683000], [5741001, 5742000], [5904001, 5905000], [5924001, 5925000], [5970001, 5971000], [6061001, 6062000], [6134001, 6136000], [6145001, 6146000], [6174001, 6176000], [6193001, 6199000], [6443001, 6444000], [6485001, 6486000], [6511001, 6512000], [6576001, 6577000], [6656001, 6657000], [6668001, 6669000], [6709001, 6710000], [6715001, 6716000], [6750001, 6751000], [6781001, 6782000], [6812001, 6813000], [6829001, 6830000], [6861001, 6862000], [6902001, 6903000], [6923001, 6924000], [6949001, 6950000], [7106001, 7107000], [7133001, 7134000], [7152001, 7153000], [7185001, 7186000], [7199001, 7200000], [7237001, 7248000], [7265001, 7266000], [7335001, 7336000], [7378001, 7379000], [7428001, 7429000], [7491001, 7492000], [7577001, 7578000], [7601001, 7602000], [7711001, 7713000], [7764001, 7765000], [7898001, 7901000], [8221001, 8222000], [8713001, 8714000], [8864001, 8865000], [8927001, 8928000], [8957001, 8960000], [9165001, 9166000], [9247001, 9249000], [9264001, 9265000], [9312001, 9313000], [9361001, 9362000], [9373001, 9374000], [9428001, 9429000], [9451001, 9452000], [9817001, 9818000], [9835001, 9839000], [9902001, 9908000], [9915001, 9916000], [9986001, 9991000], [9996001, 9997000], [10004001, 10005000], [10013001, 10015000], [10054001, 10055000], [10136001, 10137000], [10173001, 10174000], [10181001, 10182000], [10212001, 10215000], [10322001, 10323000], [10365001, 10366000], [10399001, 10400000], [10512001, 10513000], [10534001, 10535000], [10540001, 10543000], [10552001, 10553000], [10579001, 105800 ...

# %%
gene_loc_dic = {}
with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'r') as gene_loc_file:
    for gene_line in gene_loc_file.readlines()[1:]:
        line_split = gene_line.strip().split("\t")
        gene_loc_dic[line_split[0]] = [line_split[1],line_split[2],line_split[3]]
print(gene_loc_dic)
# Out:
# {'0at7088': ['NC_062252.1', '528914', '651147'], '1at7088': ['NC_062259.1', '9921230', '10035586'], '2at7088': ['NC_062243.1', '10028037', '10130567'], '3at7088': ['NC_062240.1', '1478576', '1646340'], '4at7088': ['NC_062253.1', '1062096', '1202687'], '6at7088': ['NC_062253.1', '6898579', '7019896'], '11at7088': ['NC_062235.1', '81790', '140675'], '13at7088': ['NC_062253.1', '7433661', '7510157'], '18at7088': ['NC_062234.1', '14729525', '14769680'], '20at7088': ['NC_062243.1', '5304276', '5346187'], '25at7088': ['NC_062235.1', '3539753', '3571872'], '26at7088': ['NC_062247.1', '3341506', '3431179'], '27at7088': ['NC_062259.1', '13333622', '13413334'], '28at7088': ['NC_062248.1', '4575826', '4663996'], '31at7088': ['NC_062249.1', '6716720', '6775291'], '33at7088': ['NC_062240.1', '9618625', '9679869'], '34at7088': ['NC_062247.1', '916817', '982024'], '36at7088': ['NC_062241.1', '7634651', '7673136'], '37at7088': ['NC_062259.1', '8647456', '8721497'], '38at7088': ['NC_062249.1', '4390970', '4453417'], '41at7088': ['NC_062240.1', '2557693', '2631919'], '43at7088': ['NC_062236.1', '3159541', '3229050'], '46at7088': ['NC_062242.1', '6769956', '6831724'], '47at7088': ['NC_062240.1', '5027964', '5058220'], '48at7088': ['NC_062239.1', '2281130', '2350663'], '49at7088': ['NC_062245.1', '9313073', '9397127'], '50at7088': ['NC_062256.1', '6394571', '6487858'], '51at7088': ['NC_062240.1', '976707', '1020399'], '52at7088': ['NC_062254.1', '5892316', '5961951'], '54at7088': ['NC_062250.1', '724766', '926296'], '56at7088': ['NC_062243.1', '4083498', '4161182'], '57at7088': ['NC_062248.1', '6642365', '6681172'], '59at7088': ['NC_062235.1', '1287010', '1338320'], '60at7088': ['NC_062252.1', '2594162', '2634556'], '63at7088': ['NC_062242.1', '3824464', '3878361'], '64at7088': ['NC_062243.1', '10339187', '10391126'], '65at7088': ['NC_062257.1', '5432681', '5546305'], '66at7088': ['NC_062237.1', '10998109', '11041498'], '68at7088': ['NC_062259.1', '3043334', '3162534'], '69at7088': ['NC_062255.1', '3035577', '3069507'], '70at7088': ['NC_062238.1', '11383947', '11413744'], '72at7088': ['NC_062257.1', '3698202', '3852395'], '74at7088': ['NC_062237.1', '4393376', '4426467'], '78at7088': ['NC_062234.1', '3469232', '3533419'], '83at7088': ['NC_062249.1', '5239802', '5308054'], '84at7088': ['NC_062234.1', '1409921', '1475496'], '86at7088': ['NC_062238.1', '5344750', '5395506'], '88at7088': ['NC_062248.1', '8271504', '8305925'], '96at7088': ['NC_062259.1', '7925855', '7971688'], '101at7088': ['NC_062259.1', '7570476', '7679481'], '103at7088': ['NC_062239.1', '1989193', '2054418'], '105at7088': ['NC_062249.1', '6759864', '6848229'], '106at7088': ['NC_062238.1', '6655872', '6694073'], '112at7088': ['NC_062257.1', '4894796', '4983069'], '113at7088': ['NC_062259.1', '7478854', '7581505'], '116at7088': ['NC_062240.1', '9253410', '9284268'], '122at7088': ['NC_062244.1', '4266063', '4350348'], '123at7088': ['NC_062245.1', '3052798', '3109757'], '126at7088': ['NC_062235.1', '7656475', '7701310'], '127at7088': ['NC_062239.1', '3294796', '3351066'], '128at7088': ['NC_062238.1', '13340863', '13396084'], '133at7088': ['NC_062240.1', '10648783', '10699677'], '136at7088': ['NC_062247.1', '4235075', '4325973'], '137at7088': ['NC_062235.1', '7270417', '7328706'], '138at7088': ['NC_062250.1', '9861111', '9891473'], '139at7088': ['NC_062241.1', '12251187', '12296682'], '140at7088': ['NC_062249.1', '2856576', '3043084'], '145at7088': ['NC_062239.1', '2352970', '2394161'], '148at7088': ['NC_062255.1', '7034539', '7082093'], '155at7088': ['NC_062238.1', '163714', '195316'], '158at7088': ['NC_062234.1', '13861564', '13973370'], '159at7088': ['NC_062234.1', '1162425', '1198171'], '160at7088': ['NC_062247.1', '9148515', '9262461'], '163at7088': ['NC_062258.1', '1564027', '1662894'], '173at7088': ['NC_062235.1', '7989344', '8035473'], '179at7088': ['NC_062242.1', '5910162', '5957158'], '183at7088': ['NC_062242.1', '5719868', '5771269'], '184at7088': ['NC_062250.1', '8544188', ' ...

# %%
# output_rho_set_location = "Gene,Chromosome,Location"
# with open(f"{location}/3.Rho_set_genes/Rho_set_gene2.txt", 'r') as rho_set_file:
#     for lines in rho_set_file.readlines():
#         rho_gene_name = lines.strip().split("\t")[0]
#         # print(lines.strip(),gene_loc_dic[lines.strip()])
#         # print(rho_gene_name)
#         chromosome,start,end = gene_loc_dic[rho_gene_name]
#         # print(chromosome,start,end)
#         output_rho_set_location +=  f"\n{rho_gene_name},{chromosome},{start}"

# # print(output_rho_set_location)
# with open(f"{location}/3.Rho_set_genes/Rho_set_location.csv", 'w') as rho_out_file:
#     rho_out_file.write(output_rho_set_location)

# %%
intersecting_genes = []
with open(f"{location}/3.Rho_set_genes/Rho_set_cluster.txt", 'r') as rho_set_file:
    for rho_set_count,lines in enumerate(rho_set_file.readlines()):
        rho_gene_name = lines.strip().split("\t")[0]
        # print(lines.strip(),gene_loc_dic[lines.strip()])
        try:
            chromosome,start,end = gene_loc_dic[rho_gene_name]
        except:
            print(rho_gene_name, "misiing")
        # print(chromosome,start,end)
        try:
            for sections in (fst_dictionary[chromosome]):
                # print(sections)
                if ((int(start) >= sections[0] and int(start) <= sections[1]) or (int(end) >= sections[0] and int(end) <= sections[1])) or ((sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))):
                    # print(sections)
                    print(lines, end = "")
                    intersecting_genes.append(rho_gene_name)
                    break
                # elif (sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))
            # break
        except:
            print("missing",chromosome)
    

print("\n",len(intersecting_genes),len(set(intersecting_genes)),rho_set_count )
intersecting_genes = list(set(intersecting_genes))
final_gene_number = len(intersecting_genes)
# Out:
# 10801at7088
# 10549at7088
# 3016at7088
# 4406at7088
# 1003at7088
# 5821at7088
# 14245at7088
# 7853at7088
# 3683at7088
# 1846at7088
# 15100at7088
# 1910at7088
# 4021at7088
# 4480at7088
# 190at7088
# 2905at7088
# 10192at7088
# 4998at7088
# 4163at7088
# 1947at7088
# 2599at7088
# 6826at7088
# 3363at7088
# 496at7088
# 821at7088
# 4689at7088
# 5767at7088
# 5722at7088
# 721at7088
# 717at7088
# 9682at7088
# 3811at7088
# 13075at7088
# 13445at7088
# 9564at7088
# 13346at7088
# 6937at7088
# 9240at7088
# 10447at7088
# 14598at7088
# 5480at7088
# 1709at7088
# 8007at7088
# 6156at7088
# 3667at7088
# 9535at7088
# 12391at7088
# 13774at7088
# 4595at7088
# 2372at7088
# 14391at7088
# 3226at7088
# 7622at7088
# 10666at7088
# 14949at7088
# 11592at7088
# 14339at7088
# 13737at7088
# 8222at7088
# 2031at7088
# 1637at7088
# 12180at7088
# 5852at7088
# 4279at7088
# 4935at7088
# 10101at7088
# 10268at7088
# 3161at7088 misiing
# 3161at7088
# 10728at7088
# 10571at7088
# 12326at7088
# 2201at7088
# 2902at7088
# 11288at7088
# 1837at7088
# 5679at7088
# 8306at7088
# 2939at7088
# 5486at7088
# 4119at7088
# 12212at7088
# 3162at7088
# 1144at7088
# 1628at7088
# 15271at7088
# 2813at7088
# 11619at7088
# 7044at7088
# 4799at7088
# 2003at7088
# 6173at7088
# 10432at7088
# 4078at7088
# cry1a misiing
# cry1a
# 5891at7088
# 1076at7088
# cycle
# 1319at7088
# 11115at7088
# 15278at7088
# 1753at7088
# 8048at7088
# 2081at7088
# 7508at7088
# 68at7088
# 4064at7088
# 2905at7088
# 5508at7088
# 2528at7088
# 6874at7088
# 8529at7088
# 5474at7088
# 9135at7088
# 7935at7088
# 65at7088
# 2649at7088
# 10609at7088
# 8131at7088
# 1422at7088
# 3916at7088
# 2639at7088
# 1317at7088
# 7004at7088
# 5197at7088
# 14909at7088
# 113at7088
# 12055at7088
# 2019at7088
# 14213at7088
# 559at7088
# 2652at7088
# 5979at7088
# 10933at7088
# 7342at7088
# 8044at7088
# 5567at7088
# 2335at7088
# 13468at7088
# 4473at7088
# 2173at7088
# 4416at7088
# 2234at7088
# 13169at7088
# 8100at7088
# 8793at7088
# 12572at7088
# 4176at7088
# 322at7088
# 2672at7088
# 13038at7088
# 553at7088
# 4748at7088
# 11944at7088
# 2694at7088
# 4625at7088
# 2979at7088
# 1943at7088
# 3865at7088
# 1050at7088
# 12075at7088
# 983at7088
# 12834at7088
# 5364at7088
# 9518at7088
# 6607at7088
# 1746at7088
# 4307at7088
# 7755at7088
# 569at7088
# 10437at7088
# 6126at7088
# 5858at7088
# 8065at7088
# 6757at7088
# 1330at7088
# 1465at7088
# 2166at7088
# 1218at7088
# 13004at7088
# 13095at7088
# 10963at7088
# 4287at7088
# 1246at7088
# 7378at7088
# 993at7088
# 139at7088
# 1696at7088
# 389at7088
# 7919at7088
# 2873at7088
# 1577at7088
# 10294at7088
# 998at7088
# 530at7088
# 1278at7088
# 8515at7088
# 6413at7088
# 10387at7088 misiing
# 14094at7088
# 4469at7088
# 6339at7088
# 5038at7088
# 2428at7088
# 515at7088
# 11983at7088
# 5474at7088
# 5889at7088
# 2021at7088
# 1422at7088
# cry2
# 946at7088
# 9339at7088
# 6174at7088
# 12492at7088
# 10543at7088
# 14318at7088
# 2273at7088
# 5699at7088
# 8282at7088
# 1625at7088
# 2719at7088
# 13157at7088
# 1993at7088
# 3611at7088
# 4486at7088
# 8955at7088
# 11428at7088
# 2225at7088
# 1065at7088
# 138at7088
# 7656at7088
# 10698at7088
# 2931at7088
# 6191at7088
# 1335at7088
# 6051at7088
# 5964at7088
# 2885at7088
# 10896at7088
# 2829at7088
# 4142at7088
# 3259at7088
# 1685at7088
# 4934at7088
# 8571at7088
# 4685at7088
# 12218at7088
# 467at7088
# 13369at7088
# 417at7088
# 7449at7088
# 2339at7088
# 1760at7088
# 263at7088
# 12254at7088
# 6273at7088
# 12640at7088
# 1442at7088
# 11337at7088
# 6950at7088
# 10916at7088
# 11965at7088
# 11072at7088
# 11835at7088
# 7855at7088
# 6279at7088
# 1413at7088
# 9867at7088
# 8301at7088
# 1131at7088
# 1605at7088
# 6908at7088
# 3600at7088
# 4996at7088
# 1775at7088
# 10904at7088
# 2097at7088
# 5851at7088
# 5099at7088
#
#  278 275 503

# %%
gene_anno_dic = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/2.Two_state/correlation_2_with_annotation.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        gene_name = lines.split(",")[0].split("_")[0][1:]
        anno_name = lines.split(",")[-1].replace('"', '')
        gene_anno_dic[gene_name]= anno_name.strip()

instersecting_genes_output = ""
for intersecting_gene_name in intersecting_genes:
    if intersecting_gene_name in gene_anno_dic:
        instersecting_genes_output += intersecting_gene_name+","+gene_anno_dic[intersecting_gene_name] + "\n"
    else:
        instersecting_genes_output += intersecting_gene_name+","+intersecting_gene_name + "\n"
# print(intersecting_genes)
with open(f"{location}/4.Intersections_test/intersection_set.txt", 'w') as out_file:
    out_file.write(instersecting_genes_output)

# %%
instersecting_genes_output = "geneid\n"+"\n".join(set(intersecting_genes))
with open(f"{location}/4.Intersections_test/1.For GSEA/1.Rho Set/intersection_set.txt", 'w') as out_file:
    out_file.write(instersecting_genes_output)

# %%
busco_gene_list = []
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/0.Gene_id_list/Busco_gene_id.txt",'r') as busco_gene_list_file:
    for lines in busco_gene_list_file:
        busco_gene_list.append(lines.strip())
print(len(busco_gene_list))
# Out:
# 4564

# %%
rho_set_size = rho_set_count
import random
intersecting_genes_length_list = []
for i in range(1000):
    print("run ",i)
    test_gene_list = random.sample(busco_gene_list, rho_set_size)
    # print(len(test_gene_list), test_gene_list)
    intersecting_genes = []
    for gene_name in test_gene_list:
        try:
            chromosome,start,end = gene_loc_dic[gene_name]
        except:
            print(gene_name, "missing")
            pass
        # print(chromosome,start,end)
        try:
            for sections in (fst_dictionary[chromosome]):
                # print(sections)
                if ((int(start) >= sections[0] and int(start) <= sections[1]) or (int(end) >= sections[0] and int(end) <= sections[1])) or ((sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))):
                    # print(sections)
                    # print(gene_name,chromosome,start,end)
                    intersecting_genes.append(gene_name)
                    break
                    # elif (sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))
                # break
        except:
            pass
    intersecting_genes_length_list.append(len(intersecting_genes))
print(len(intersecting_genes_length_list))
# Out:
# run  0
# 8166at7088 missing
# 9108at7088 missing
# 12884at7088 missing
# 13189at7088 missing
# run  1
# 1504at7088 missing
# 5051at7088 missing
# 7181at7088 missing
# 11269at7088 missing
# 6951at7088 missing
# run  2
# 5051at7088 missing
# 8967at7088 missing
# 10387at7088 missing
# run  3
# 4118at7088 missing
# 7181at7088 missing
# 6951at7088 missing
# run  4
# 13532at7088 missing
# 1504at7088 missing
# run  5
# 12884at7088 missing
# 4967at7088 missing
# run  6
# 1576at7088 missing
# 5397at7088 missing
# 9345at7088 missing
# 12884at7088 missing
# run  7
# 13189at7088 missing
# 7181at7088 missing
# 1576at7088 missing
# 3389at7088 missing
# 9108at7088 missing
# 9345at7088 missing
# run  8
# 8166at7088 missing
# 6951at7088 missing
# run  9
# 7181at7088 missing
# run  10
# 8967at7088 missing
# 13532at7088 missing
# run  11
# 7400at7088 missing
# 9108at7088 missing
# run  12
# 13532at7088 missing
# 13189at7088 missing
# 6951at7088 missing
# 9108at7088 missing
# run  13
# 13532at7088 missing
# 1576at7088 missing
# run  14
# 11066at7088 missing
# 4118at7088 missing
# 177at7088 missing
# 1504at7088 missing
# 7181at7088 missing
# run  15
# 1576at7088 missing
# 7523at7088 missing
# run  16
# 5397at7088 missing
# 8967at7088 missing
# run  17
# 7181at7088 missing
# 6951at7088 missing
# 13532at7088 missing
# run  18
# 4118at7088 missing
# 6083at7088 missing
# 10387at7088 missing
# 9108at7088 missing
# run  19
# 177at7088 missing
# 12632at7088 missing
# 13189at7088 missing
# run  20
# 6083at7088 missing
# run  21
# run  22
# 14240at7088 missing
# 11269at7088 missing
# 7400at7088 missing
# 12884at7088 missing
# 6951at7088 missing
# 3389at7088 missing
# run  23
# 1576at7088 missing
# 7400at7088 missing
# 5051at7088 missing
# 11558at7088 missing
# 1504at7088 missing
# run  24
# 4118at7088 missing
# 1576at7088 missing
# 12632at7088 missing
# 5397at7088 missing
# run  25
# 10546at7088 missing
# 7400at7088 missing
# 10387at7088 missing
# run  26
# 7523at7088 missing
# 9345at7088 missing
# 4118at7088 missing
# 6951at7088 missing
# 10387at7088 missing
# 11066at7088 missing
# run  27
# 8166at7088 missing
# 5397at7088 missing
# run  28
# 11558at7088 missing
# 5051at7088 missing
# 4198at7088 missing
# 6083at7088 missing
# 6951at7088 missing
# 8166at7088 missing
# 7400at7088 missing
# 12632at7088 missing
# 1504at7088 missing
# 7181at7088 missing
# run  29
# 14240at7088 missing
# run  30
# 5397at7088 missing
# 14240at7088 missing
# run  31
# 4118at7088 missing
# 13189at7088 missing
# 1576at7088 missing
# run  32
# 8967at7088 missing
# 11066at7088 missing
# 8166at7088 missing
# run  33
# 4967at7088 missing
# 14240at7088 missing
# 13189at7088 missing
# run  34
# 9345at7088 missing
# 5397at7088 missing
# 6503at7088 missing
# 13189at7088 missing
# 7181at7088 missing
# 1576at7088 missing
# 10387at7088 missing
# 11066at7088 missing
# 4967at7088 missing
# run  35
# 8166at7088 missing
# 13532at7088 missing
# 7181at7088 missing
# 4198at7088 missing
# 5397at7088 missing
# 10387at7088 missing
# run  36
# 9108at7088 missing
# 5397at7088 missing
# 13532at7088 missing
# run  37
# 13532at7088 missing
# 13189at7088 missing
# 4967at7088 missing
# 3161at7088 missing
# 6503at7088 missing
# 1576at7088 missing
# run  38
# 13532at7088 missing
# 11066at7088 missing
# run  39
# 1504at7088 missing
# 1576at7088 missing
# 10546at7088 missing
# run  40
# 7400at7088 missing
# 14240at7088 missing
# 11558at7088 missing
# run  41
# 10387at7088 missing
# 11558at7088 missing
# 9345at7088 missing
# 5051at7088 missing
# 9108at7088 missing
# 5397at7088 missing
# run  42
# 11558at7088 missing
# 9345at7088 missing
# run  43
# 11269at7088 missing
# 7523at7088 missing
# 3389at7088 missing
# run  44
# 6503at7088 missing
# 7181at7088 missing
# run  45
# 3389at7088 missing
# 4967at7088 missing
# 5051at7088 missing
# 7400at7088 missing
# run  46
# 3389at7088 missing
# 12632at7088 missing
# run  47
# 10387at7088 missing
# 6951at7088 missing
# run  48
# 7523at7088 missing
# 12632at7088 missing
# 1504at7088 missing
# 9556at7088 missing
# 3389at7088 missing
# 4118at7088 missing
# run  49
# 13532at7088 missing
# 13189at7088 missing
# 5051at7088 missing
# run  50
# 1576at7088 missing
# 12632at7088 missing
# 9556at7088 missing
# 3161at7088 missing
# run  51
# 3161at7088 missing
# run  52
# 3389at7088 missing
# 4967at7088 missing
# 8166at7088 missing
# 9108at7088 missing
# run  53
# run  54
# 1504at7088 missing
# 5051at7088 missing
# 11269at7088 missing
# 6083at7088 missing
# 8166at7088 missing
# run  55
# 177at7088 missing
# 5051at7088 missing
# 11269at7088 missing
# 9556at7088 missing
# 9108at7088 missing
# 10546at7088 missing
# run  56
# 177at7088 missing
# 11269at7088 missing
# 8967at7088 missing
# 6083at7088 missing
# 9556at7088 missing
# 8166at7088 missing
# 9108at7088 missing
# 7400at7088 missing
# run  57
# 9556at7088 missing
# 12632at7088 missing
# 8967at7088 missing
# run  58
# 11066at7088 missing
# 12884at7088 missing
# 8166at7088 missing
# run  59
# 12884at7088 missing
# 177at7088 missing
# 1504at7088 missing
# run  60
# 6503at7088 missing
# 9556at7088 missing
# 4967at7088 missing
# run  61
# 5397at7088 missing
# 9556at7088 missing
# 9345at7088 missing
# 8166at7088 missing
# 6951at7088 missing
# 4118at7088 missing
# 4967at7088 missing
# run  62
# 4967at7088 missing
# 1504at7088 missing
# run  63
# 9108at7088 missing
# 4198at7088 missing
# 6503at7088 missing
# 7523at7088 missing
# 6951at7088 missing
# run  64
# 7523at7088 missing
# 14240at7088 missing
# 3161at7088 missing
# 6083at7088 missing
# 12884at7088 missing
# 9556at7088 missing
# run  65
# 12632at7088 missing
# 5051at7088 missing
# 7181at7088 missing
# 10387at7088 missing
# run  66
# 10546at7088 missing
# 1504at7088 missing
# 6951at7088 missing
# 11269at7088 missing
# 8166at7088 missing
# run  67
# 11269at7088 missing
# 4118at7088 missing
# 11066at7088 missing
# 5397at7088 missing
# 13189at7088 missing
# run  68
# 8166at7088 missing
# 12884at7088 missing
# 177at7088 missing
# 6083at7088 missing
# run  69
# 1576at7088 missing
# run  70
# 6503at7088 missing
# 5051at7088 missing
# 7400at7088 missing
# 12884at7088 missing
# 1576at7088 missing
# run  71
# 14240at7088 missing
# 12632at7088 missing
# run  72
# 9556at7088 missing
# 12884at7088 missing
# 9108at7088 missing
# 11558at7088 missing
# run  73
# 7523at7088 missing
# 7400at7088 missing
# run  74
# 11558at7088 missing
# 6083at7088 missing
# run  75
# 1576at7088 missing
# run  76
# 13532at7088 missing
# 3389at7088 missing
# 4118at7088 missing
# 177at7088 missing
# 3161at7088 missing
# run  77
# 177at7088 missing
# 9556at7088 missing
# 8166at7088 missing
# 5051at7088 missing
# run  78
# 12884at7088 missing
# 4118at7088 missing
# 6083at7088 missing
# 7523at7088 missing
# run  79
# 11269at7088 missing
# 12884at7088 missing
# 14240at7088 missing
# run  80
# 3161at7088 missing
# 10387at7088 missing
# run  81
# 8166at7088 missing
# 11269at7088 missing
# 6951at7088 missing
# 7400at7088 missing
# run  82
# 3161at7088 missing
# 11066at7088 missing
# run  83
# 4967at7088 missing
# 5397at7088 missing
# 12632at7088 missing
# 7400at7088 missing
# 1576at7088 missing
# 5051at7088 missing
# 6083at7088 missing
# run  84
# 13532at7088 missing
# 8967at7088 missing
# 13189at7088 missing
# 10546at7088 missing
# 9345at7088 missing
# run  85
# run  86
# 7400at7088 missing
# 11558at7088 missing
# 13532at7088 missing
# 7523at7088 missing
# run  87
# 6951at7088 missing
# 11066at7088 missing
# 10546at7088 missing
# run  88
# 1504at7088 missing
# 13189at7088 missing
# 13532at7088 missing
# 7523at7088 missing
# 5397at7088 missing
# run  89
# 10387at7088 missing
# 5397at7088 missing
# 13189at7088 missing
# 7400at7088 missing
# run  90
# 9556at7088 missing
# 10546at7088 missing
# 177at7088 missing
# 3389at7088 missing
# run  91
# 1576at7088 missing
# 9108at7088 missing
# 1504at7088 missing
# 9345at7088 missing
# 3161at7088 missing
# run  92
# 12884at7088 missing
# 6083at7088 missing
# 3161at7088 missing
# run  93
# 13532at7088 missing
# run  94
# 7400at7088 missing
# 5397at7088 missing
# 12884at7088 missing
# 6503at7088 missing
# run  95
# 11558at7088 missing
# 1504at7088 missing
# 11066at7088 missing
# 6083at7088 missing
# run  96
# 11558at7088 missing
# 7400at7088 missing
# 177at7088 missing
# 5397at7088 missing
# 13532at7088 missing
# 13189at7088 missing
# 3161at7088 missing
# run  97
# 5051at7088 missing
# 1504at7088 missing
# 1576at7088 missing
# run  98
# 1504at7088 missing
# run  99
# 11269at7088 missing
# 4118at7088 missing
# 10387at7088 missing
# 9108at7088 missing
# run  100
# 13532at7088 missing
# 8967at7088 missing
# 4118at7088 missing
# 9108at7088 missing
# run  101
# 4118at7088 missing
# 6951at7088 missing
# 11269at7088 missing
# 177at7088 missing
# 11066at7088 missing
# 8166at7088 missing
# 5051at7088 missing
# run  102
# 12632at7088 missing
# 13189at7088 missing
# 6083at7088 missing
# 11269at7088 missing
# 4198at7088 missing
# run  103
# 11066at7088 missing
# 177at7088 missing
# 14240at7088 missing
# 12884at7088 missing
# 3389at7088 missing
# run  104
# 13189at7088 missing
# 7523at7088 missing
# 4967at7088 missing
# 5051at7088 missing
# run  105
# 10546at7088 missing
# 6083at7088 missing
# 12884at7088 missing
# 8967at7088 missing
# 13532at7088 missing
# 1576at7088 missing
# run  106
# 12632at7088 missing
# 9345at7088 missing
# 10546at7088 missing
# run  107
# 14240at7088 missing
# 5397at7088 missing
# 1576at7088 missing
# 9345at7088 missing
# run  108
# run  109
# 1576at7088 missing
# 11558at7088 missing
# 9556at7088 missing
# 1504at7088 missing
# run  110
# 4198at7088 missing
# 9108at7088 missing
# 4118at7088 missing
# 6503at7088 missing
# run  111
# 7400at7088 missing
# 11269at7088 missing
# 7181at7088 missing
# 10546at7088 missing
# run  112
# run  113
# 5051at7088 missing
# 7181at7088 missing
# 14240at7088 missing
# 11066at7088 missing
# 4967at7088 missing
# 4198at7088 missing
# run  114
# 8166at7088 missing
# 9345at7088 missing
# 8967at7088 missing
# 1576at7088 missing
# 7400at7088 missing
# run  115
# run  116
# 5397at7088 missing
# run  117
# 3389at7088 missing
# 6503at7088 missing
# 6951at7088 missing
# 13532at7088 missing
# 11269at7088 missing
# 8166at7088 missing
# 4967at7088 missing
# run  118
# 12632at7088 missing
# 7400at7088 missing
# 14240at7088 missing
# run  119
# 11066at7088 missing
# 177at7088 missing
# 9556at7088 missing
# 6951at7088 missing
# run  120
# 6951at7088 missing
# 14240at7088 missing
# 4967at7088 missing
# 5397at7088 missing
# 7400at7088 missing
# run  121
# 8166at7088 missing
# 11066at7088 missing
# 6951at7088 missing
# run  122
# 11066at7088 missing
# 4198at7088 missing
# 5051at7088 missing
# run  123
# 177at7088 missing
# 8166at7088 missing
# 6503at7088 missing
# 10546at7088 missing
# 8967at7088 missing
# run  124
# 14240at7088 missing
# 7400at7088 missing
# 3161at7088 missing
# run  125
# 9345at7088 missing
# 11558at7088 missing
# run  126
# 9556at7088 missing
# run  127
# 9556at7088 missing
# 7181at7088 missing
# run  128
# 13532at7088 missing
# 9556at7088 missing
# 11558at7088 missing
# 3161at7088 missing
# 9345at7088 missing
# run  129
# 6951at7088 missing
# 13189at7088 missing
# 11066at7088 missing
# run  130
# 1504at7088 missing
# 3161at7088 missing
# 177at7088 missing
# 9556at7088 missing
# run  131
# 5051at7088 missing
# 12884at7088 missing
# 10546at7088 missing
# 1576at7088 missing
# run  132
# 3161at7088 missing
# 10546at7088 missing
# run  133
# 4198at7088 missing
# 13532at7088 missing
# 12884at7088 missing
# 5397at7088 missing
# run  134
# 7523at7088 missing
# 12884at7088 missing
# 8967at7088 missing
# 1576at7088 missing
# 9345at7088 missing
# 11558at7088 missing
# run  135
# 177at7088 missing
# 13532at7088 missing
# 4198at7088 missing
# 3389at7088 missing
# run  136
# 8166at7088 missing
# 11558at7088 missing
# run  137
# 8166at7088 missing
# 4198at7088 missing
# run  138
# 7181at7088 missing
# run  139
# 9345at7088 missing
# 6083at7088 missing
# 14240at7088 missing
# run  140
# 9108at7088 missing
# 11558at7088 missing
# 11269at7088 missing
# 6503at7088 missing
# run  141
# 11558at7088 missing
# 5397at7088 missing
# 177at7088 missing
# 4198at7088 missing
# 4118at7088 missing
# run  142
# 9345at7088 missing
# 4198at7088 missing
# 7181at7088 missing
# 1576at7088 missing
# 6083at7088 missing
# 10387at7088 missing
# run  143
# 4198at7088 missing
# run  144
# 9345at7088 missing
# 5051at7088 missing
# 4198at7088 missing
# run  145
# 7400at7088 missing
# 1504at7088 missing
# run  146
# 12884at7088 missing
# 9108at7088 missing
# run  147
# 5051at7088 missing
# 13532at7088 missing
# 14240at7088 missing
# run  148
# 10387at7088 missing
# 5397at7088 missing
# 3161at7088 missing
# run  149
# 11269at7088 missing
# 7523at7088 missing
# 9345at7088 missing
# 6083at7088 missing
# run  150
# 9556at7088 missing
# 6503at7088 missing
# 5051at7088 missing
# 4198at7088 missing
# 7400at7088 missing
# 7181at7088 missing
# run  151
# 3389at7088 missing
# 12884at7088 missing
# 8166at7088 missing
# 10387at7088 missing
# 5051at7088 missing
# run  152
# 13532at7088 missing
# 4118at7088 missing
# 1504at7088 missing
# 177at7088 missing
# 14240at7088 missing
# 12884at7088 missing
# run  153
# 6951at7088 missing
# 13532at7088 missing
# 6503at7088 missing
# 1504at7088 missing
# 13189at7088 missing
# run  154
# 6951at7088 missing
# 8166at7088 missing
# run  155
# 1504at7088 missing
# 4198at7088 missing
# 11066at7088 missing
# 10387at7088 missing
# 14240at7088 missing
# 12632at7088 missing
# run  156
# 11558at7088 missing
# 6083at7088 missing
# run  157
# 8166at7088 missing
# 4967at7088 missing
# 13532at7088 missing
# 7181at7088 missing
# run  158
# 9345at7088 missing
# run  159
# 7181at7088 missing
# 4118at7088 missing
# run  160
# 6503at7088 missing
# 9345at7088 missing
# run  161
# 3161at7088 missing
# 6951at7088 missing
# 6083at7088 missing
# 6503at7088 missing
# 9345at7088 missing
# run  162
# 11558at7088 missing
# 9345at7088 missing
# 6503at7088 missing
# run  163
# 3389at7088 missing
# 8166at7088 missing
# run  164
# 3389at7088 missing
# 5051at7088 missing
# 9345at7088 missing
# 13189at7088 missing
# run  165
# 11558at7088 missing
# run  166
# 13532at7088 missing
# 5051at7088 missing
# run  167
# run  168
# 6083at7088 missing
# 11066at7088 missing
# 12632at7088 missing
# 9556at7088 missing
# run  169
# 7400at7088 missing
# 8967at7088 missing
# 10546at7088 missing
# 7181at7088 missing
# run  170
# 4198at7088 missing
# 12632at7088 missing
# 13532at7088 missing
# run  171
# 7181at7088 missing
# 11558at7088 missing
# 6503at7088 missing
# 1576at7088 missing
# run  172
# 3389at7088 missing
# 11269at7088 missing
# 6951at7088 missing
# 10387at7088 missing
# 4198at7088 missing
# 11558at7088 missing
# run  173
# run  174
# 5397at7088 missing
# 6083at7088 missing
# run  175
# 7400at7088 missing
# 7181at7088 missing
# 11558at7088 missing
# 12632at7088 missing
# 9108at7088 missing
# run  176
# 8967at7088 missing
# 10387at7088 missing
# 9108at7088 missing
# run  177
# 8166at7088 missing
# 177at7088 missing
# 14240at7088 missing
# 1504at7088 missing
# run  178
# 3389at7088 missing
# 4967at7088 missing
# 12632at7088 missing
# run  179
# 14240at7088 missing
# 4118at7088 missing
# 6083at7088 missing
# 177at7088 missing
# 8967at7088 missing
# run  180
# 6951at7088 missing
# 6083at7088 missing
# 12884at7088 missing
# 7523at7088 missing
# run  181
# 6503at7088 missing
# 4198at7088 missing
# 3161at7088 missing
# 7181at7088 missing
# 14240at7088 missing
# 13189at7088 missing
# run  182
# 6951at7088 missing
# run  183
# 8166at7088 missing
# 10387at7088 missing
# run  184
# run  185
# 5397at7088 missing
# 6503at7088 missing
# 6951at7088 missing
# 7181at7088 missing
# run  186
# 7181at7088 missing
# 8967at7088 missing
# 14240at7088 missing
# 3389at7088 missing
# run  187
# 10546at7088 missing
# 5051at7088 missing
# 7523at7088 missing
# run  188
# 4967at7088 missing
# 12632at7088 missing
# 5397at7088 missing
# 9345at7088 missing
# run  189
# 7400at7088 missing
# 4118at7088 missing
# 11269at7088 missing
# 7181at7088 missing
# 8967at7088 missing
# run  190
# 14240at7088 missing
# run  191
# 8166at7088 missing
# 6083at7088 missing
# run  192
# 11558at7088 missing
# 6951at7088 missing
# 13189at7088 missing
# 14240at7088 missing
# run  193
# 8166at7088 missing
# 4198at7088 missing
# 9108at7088 missing
# 9345at7088 missing
# 1576at7088 missing
# 11269at7088 missing
# 6503at7088 missing
# run  194
# 8166at7088 missing
# 13532at7088 missing
# 3389at7088 missing
# 5397at7088 missing
# run  195
# 6503at7088 missing
# run  196
# 5051at7088 missing
# 7181at7088 missing
# run  197
# 7400at7088 missing
# 9556at7088 missing
# 12632at7088 missing
# 4967at7088 missing
# run  198
# 1576at7088 missing
# 11558at7088 missing
# 4198at7088 missing
# 13532at7088 missing
# 8166at7088 missing
# 12632at7088 missing
# run  199
# 12884at7088 missing
# 6951at7088 missing
# 5397at7088 missing
# 1504at7088 missing
# run  200
# 12884at7088 missing
# 13532at7088 missing
# 10387at7088 missing
# 11269at7088 missing
# run  201
# 14240at7088 missing
# 5397at7088 missing
# 12632at7088 missing
# 6503at7088 missing
# run  202
# 6083at7088 missing
# 177at7088 missing
# 6951at7088 missing
# 9108at7088 missing
# run  203
# 7400at7088 missing
# 5051at7088 missing
# 14240at7088 missing
# 7181at7088 missing
# run  204
# 11066at7088 missing
# 9345at7088 missing
# 11269at7088 missing
# run  205
# 13532at7088 missing
# 10387at7088 missing
# 13189at7088 missing
# run  206
# run  207
# 13532at7088 missing
# 5051at7088 missing
# 9108at7088 missing
# 4967at7088 missing
# 7523at7088 missing
# 3389at7088 missing
# run  208
# 6083at7088 missing
# 14240at7088 missing
# 11066at7088 missing
# run  209
# 4198at7088 missing
# 7523at7088 missing
# 14240at7088 missing
# 13189at7088 missing
# 177at7088 missing
# 11066at7088 missing
# run  210
# 6503at7088 missing
# run  211
# 4118at7088 missing
# 7523at7088 missing
# 11066at7088 missing
# run  212
# 1576at7088 missing
# 13532at7088 missing
# 9345at7088 missing
# 5397at7088 missing
# run  213
# 8166at7088 missing
# 13189at7088 missing
# 1504at7088 missing
# 7181at7088 missing
# 4118at7088 missing
# run  214
# 10387at7088 missing
# 9345at7088 missing
# 12884at7088 missing
# 10546at7088 missing
# run  215
# 8166at7088 missing
# 4198at7088 missing
# run  216
# 1576at7088 missing
# run  217
# 7523at7088 missing
# 9108at7088 missing
# 8967at7088 missing
# 4118at7088 missing
# run  218
# 14240at7088 missing
# 10546at7088 missing
# 9108at7088 missing
# 11066at7088 missing
# 9345at7088 missing
# run  219
# 11558at7088 missing
# 7181at7088 missing
# 4118at7088 missing
# 8166at7088 missing
# 7400at7088 missing
# run  220
# 3389at7088 missing
# 7523at7088 missing
# 13189at7088 missing
# 3161at7088 missing
# run  221
# 11066at7088 missing
# 4198at7088 missing
# run  222
# 4118at7088 missing
# 7181at7088 missing
# 7400at7088 missing
# run  223
# 7523at7088 missing
# 7181at7088 missing
# 6083at7088 missing
# 6951at7088 missing
# run  224
# 10387at7088 missing
# 11558at7088 missing
# 6951at7088 missing
# run  225
# 4118at7088 missing
# run  226
# 12884at7088 missing
# 177at7088 missing
# 10546at7088 missing
# 8166at7088 missing
# run  227
# 10387at7088 missing
# 5397at7088 missing
# 12884at7088 missing
# 1576at7088 missing
# 13532at7088 missing
# 10546at7088 missing
# run  228
# 4198at7088 missing
# 6951at7088 missing
# run  229
# 11066at7088 missing
# 4967at7088 missing
# 9345at7088 missing
# 1576at7088 missing
# run  230
# 11558at7088 missing
# 5051at7088 missing
# 6951at7088 missing
# run  231
# 3389at7088 missing
# 4198at7088 missing
# run  232
# 10546at7088 missing
# 11066at7088 missing
# 12884at7088 missing
# run  233
# 6503at7088 missing
# 14240at7088 missing
# 6951at7088 missing
# 10546at7088 missing
# 7400at7088 missing
# 1576at7088 missing
# run  234
# 11066at7088 missing
# 4118at7088 missing
# run  235
# 7400at7088 missing
# run  236
# 12884at7088 missing
# 12632at7088 missing
# run  237
# 1504at7088 missing
# run  238
# 9108at7088 missing
# 7181at7088 missing
# run  239
# 7181at7088 missing
# 5397at7088 missing
# 8967at7088 missing
# 11269at7088 missing
# 4198at7088 missing
# 11066at7088 missing
# run  240
# 13532at7088 missing
# 177at7088 missing
# 3389at7088 missing
# 11269at7088 missing
# 5051at7088 missing
# run  241
# 4118at7088 missing
# 9345at7088 missing
# 5397at7088 missing
# run  242
# 9345at7088 missing
# 10387at7088 missing
# run  243
# 13532at7088 missing
# 1576at7088 missing
# 7523at7088 missing
# run  244
# 9108at7088 missing
# 1576at7088 missing
# 6083at7088 missing
# run  245
# 10387at7088 missing
# 14240at7088 missing
# run  246
# 7523at7088 missing
# 4118at7088 missing
# 4198at7088 missing
# 10546at7088 missing
# run  247
# 4967at7088 missing
# 13532at7088 missing
# 1504at7088 missing
# 11558at7088 missing
# run  248
# 13189at7088 missing
# 177at7088 missing
# 13532at7088 missing
# 7400at7088 missing
# run  249
# 3161at7088 missing
# 4118at7088 missing
# 10546at7088 missing
# 4198at7088 missing
# run  250
# 7181at7088 missing
# 13532at7088 missing
# 11066at7088 missing
# 9108at7088 missing
# run  251
# 7523at7088 missing
# 1504at7088 missing
# 12884at7088 missing
# run  252
# 177at7088 missing
# 13189at7088 missing
# 6503at7088 missing
# 13532at7088 missing
# 11066at7088 missing
# 9345at7088 missing
# 6951at7088 missing
# run  253
# 10387at7088 missing
# run  254
# 11066at7088 missing
# 4118at7088 missing
# run  255
# 12632at7088 missing
# 4118at7088 missing
# run  256
# 3161at7088 missing
# 4967at7088 missing
# 13532at7088 missing
# run  257
# 11066at7088 missing
# 4118at7088 missing
# 3389at7088 missing
# 4967at7088 missing
# run  258
# 8967at7088 missing
# 1576at7088 missing
# 9108at7088 missing
# 13532at7088 missing
# run  259
# 11269at7088 missing
# run  260
# 7400at7088 missing
# 9556at7088 missing
# run  261
# 11558at7088 missing
# 7400at7088 missing
# 9108at7088 missing
# run  262
# 5397at7088 missing
# 10387at7088 missing
# run  263
# 4967at7088 missing
# 9345at7088 missing
# 11066at7088 missing
# 9556at7088 missing
# 3161at7088 missing
# run  264
# 6951at7088 missing
# 177at7088 missing
# run  265
# 6951at7088 missing
# 4118at7088 missing
# 10546at7088 missing
# 9556at7088 missing
# run  266
# 10387at7088 missing
# 13532at7088 missing
# 9108at7088 missing
# 7181at7088 missing
# 9345at7088 missing
# 8166at7088 missing
# run  267
# 1504at7088 missing
# 5397at7088 missing
# run  268
# 8166at7088 missing
# 8967at7088 missing
# 4967at7088 missing
# run  269
# 13532at7088 missing
# 8166at7088 missing
# 11066at7088 missing
# 12884at7088 missing
# 177at7088 missing
# 3389at7088 missing
# run  270
# 10546at7088 missing
# run  271
# 12632at7088 missing
# 4118at7088 missing
# 14240at7088 missing
# 6951at7088 missing
# 9108at7088 missing
# run  272
# 8967at7088 missing
# 5051at7088 missing
# 4198at7088 missing
# 13189at7088 missing
# 3389at7088 missing
# 11269at7088 missing
# run  273
# 5051at7088 missing
# 4118at7088 missing
# 3161at7088 missing
# run  274
# 11269at7088 missing
# 8967at7088 missing
# 14240at7088 missing
# 9108at7088 missing
# run  275
# 4967at7088 missing
# 4198at7088 missing
# 9108at7088 missing
# 177at7088 missing
# 11558at7088 missing
# run  276
# 9556at7088 missing
# 13189at7088 missing
# 1504at7088 missing
# 3389at7088 missing
# 9345at7088 missing
# 6083at7088 missing
# run  277
# 1576at7088 missing
# 11269at7088 missing
# 13189at7088 missing
# run  278
# 14240at7088 missing
# 10546at7088 missing
# run  279
# 13189at7088 missing
# 13532at7088 missing
# 12632at7088 missing
# 14240at7088 missing
# 1576at7088 missing
# 3161at7088 missing
# run  280
# 8967at7088 missing
# 1576at7088 missing
# run  281
# 177at7088 missing
# 5051at7088 missing
# run  282
# 6503at7088 missing
# 9556at7088 missing
# 6083at7088 missing
# run  283
# 13189at7088 missing
# run  284
# run  285
# run  286
# 1504at7088 missing
# 1576at7088 missing
# 12632at7088 missing
# 4198at7088 missing
# 14240at7088 missing
# 11066at7088 missing
# run  287
# 6083at7088 missing
# 13189at7088 missing
# run  288
# 12632at7088 missing
# 7523at7088 missing
# 6503at7088 missing
# 13532at7088 missing
# run  289
# 9108at7088 missing
# 4967at7088 missing
# 7181at7088 missing
# run  290
# 9345at7088 missing
# 5051at7088 missing
# 8967at7088 missing
# run  291
# 10546at7088 missing
# 8967at7088 missing
# 5051at7088 missing
# 11066at7088 missing
# run  292
# 6503at7088 missing
# 5051at7088 missing
# 7400at7088 missing
# run  293
# 10387at7088 missing
# 12884at7088 missing
# run  294
# 5397at7088 missing
# 7523at7088 missing
# 1504at7088 missing
# 8166at7088 missing
# run  295
# 5051at7088 missing
# 11066at7088 missing
# 10387at7088 missing
# 6503at7088 missing
# 6951at7088 missing
# run  296
# 7181at7088 missing
# run  297
# 5397at7088 missing
# 7523at7088 missing
# 8967at7088 missing
# 12884at7088 missing
# 6083at7088 missing
# run  298
# 4198at7088 missing
# 14240at7088 missing
# 12632at7088 missing
# 4118at7088 missing
# run  299
# 9556at7088 missing
# 4967at7088 missing
# 12884at7088 missing
# run  300
# 9108at7088 missing
# 11269at7088 missing
# 5051at7088 missing
# 10546at7088 missing
# 6083at7088 missing
# 7181at7088 missing
# 14240at7088 missing
# run  301
# 11066at7088 missing
# 13189at7088 missing
# 13532at7088 missing
# 14240at7088 missing
# run  302
# 8967at7088 missing
# 3161at7088 missing
# run  303
# 7523at7088 missing
# 14240at7088 missing
# 8967at7088 missing
# 177at7088 missing
# run  304
# 4198at7088 missing
# run  305
# 7181at7088 missing
# 5397at7088 missing
# 14240at7088 missing
# 3389at7088 missing
# 9108at7088 missing
# run  306
# 4118at7088 missing
# 7181at7088 missing
# 4198at7088 missing
# 12632at7088 missing
# run  307
# 4967at7088 missing
# run  308
# 11269at7088 missing
# 11066at7088 missing
# 5051at7088 missing
# 7523at7088 missing
# 4198at7088 missing
# 9345at7088 missing
# run  309
# 11558at7088 missing
# 9556at7088 missing
# 7181at7088 missing
# run  310
# 3389at7088 missing
# 6503at7088 missing
# 9345at7088 missing
# run  311
# 11066at7088 missing
# 9108at7088 missing
# 6503at7088 missing
# run  312
# 13532at7088 missing
# 9345at7088 missing
# run  313
# 11066at7088 missing
# 7523at7088 missing
# 8166at7088 missing
# 1576at7088 missing
# 8967at7088 missing
# run  314
# 11269at7088 missing
# 7523at7088 missing
# 1576at7088 missing
# 10387at7088 missing
# run  315
# 5051at7088 missing
# 4198at7088 missing
# 9556at7088 missing
# run  316
# 1576at7088 missing
# 8967at7088 missing
# 5397at7088 missing
# run  317
# 12884at7088 missing
# 9345at7088 missing
# 6083at7088 missing
# 13532at7088 missing
# 1504at7088 missing
# 9108at7088 missing
# run  318
# 13189at7088 missing
# 8166at7088 missing
# run  319
# 10546at7088 missing
# 7181at7088 missing
# 11269at7088 missing
# 1504at7088 missing
# run  320
# 4198at7088 missing
# 1504at7088 missing
# 10546at7088 missing
# 9108at7088 missing
# run  321
# 9108at7088 missing
# 13189at7088 missing
# 6083at7088 missing
# 4118at7088 missing
# 4198at7088 missing
# run  322
# 8166at7088 missing
# 11558at7088 missing
# run  323
# 8967at7088 missing
# run  324
# 11558at7088 missing
# 1504at7088 missing
# 11269at7088 missing
# run  325
# 7523at7088 missing
# 10546at7088 missing
# 9108at7088 missing
# 6083at7088 missing
# 5397at7088 missing
# 6951at7088 missing
# 1576at7088 missing
# 3161at7088 missing
# run  326
# 11269at7088 missing
# 9556at7088 missing
# run  327
# 8166at7088 missing
# 13189at7088 missing
# 9556at7088 missing
# 5051at7088 missing
# run  328
# 6951at7088 missing
# 10387at7088 missing
# 12884at7088 missing
# 7181at7088 missing
# run  329
# 6951at7088 missing
# 1576at7088 missing
# 4967at7088 missing
# run  330
# 9556at7088 missing
# 11066at7088 missing
# 7523at7088 missing
# 9108at7088 missing
# 1504at7088 missing
# run  331
# 6951at7088 missing
# 10387at7088 missing
# run  332
# 12632at7088 missing
# 9556at7088 missing
# 13532at7088 missing
# 4198at7088 missing
# run  333
# 7400at7088 missing
# 6503at7088 missing
# 3161at7088 missing
# 4967at7088 missing
# run  334
# 177at7088 missing
# 14240at7088 missing
# 7523at7088 missing
# 11558at7088 missing
# 3389at7088 missing
# run  335
# 6083at7088 missing
# 11269at7088 missing
# run  336
# 7523at7088 missing
# 9556at7088 missing
# 14240at7088 missing
# run  337
# 14240at7088 missing
# 11066at7088 missing
# 6503at7088 missing
# run  338
# 4967at7088 missing
# 6503at7088 missing
# 1504at7088 missing
# 12632at7088 missing
# 8967at7088 missing
# run  339
# 1504at7088 missing
# run  340
# 5397at7088 missing
# 12884at7088 missing
# 13189at7088 missing
# 177at7088 missing
# 7400at7088 missing
# run  341
# 7523at7088 missing
# 6083at7088 missing
# run  342
# 13189at7088 missing
# 6503at7088 missing
# 6083at7088 missing
# run  343
# 1504at7088 missing
# run  344
# 177at7088 missing
# 7523at7088 missing
# 5397at7088 missing
# 6083at7088 missing
# run  345
# 177at7088 missing
# 8967at7088 missing
# run  346
# 10387at7088 missing
# 14240at7088 missing
# 6503at7088 missing
# 6083at7088 missing
# 8166at7088 missing
# 3389at7088 missing
# run  347
# 13189at7088 missing
# 11269at7088 missing
# 11066at7088 missing
# run  348
# 4967at7088 missing
# 10546at7088 missing
# 13532at7088 missing
# run  349
# 9345at7088 missing
# 4198at7088 missing
# run  350
# 1576at7088 missing
# 13532at7088 missing
# 7523at7088 missing
# 5051at7088 missing
# run  351
# run  352
# 5397at7088 missing
# 6083at7088 missing
# 3389at7088 missing
# 13532at7088 missing
# run  353
# 10387at7088 missing
# 5397at7088 missing
# 12884at7088 missing
# run  354
# 6503at7088 missing
# 9345at7088 missing
# run  355
# 3389at7088 missing
# 7400at7088 missing
# 10546at7088 missing
# run  356
# 4118at7088 missing
# run  357
# 11269at7088 missing
# 5397at7088 missing
# 6951at7088 missing
# 1576at7088 missing
# run  358
# 6951at7088 missing
# 11269at7088 missing
# 1576at7088 missing
# run  359
# 4967at7088 missing
# 12884at7088 missing
# 7181at7088 missing
# 1576at7088 missing
# 14240at7088 missing
# run  360
# 11558at7088 missing
# 10546at7088 missing
# 11066at7088 missing
# 13189at7088 missing
# 6503at7088 missing
# 177at7088 missing
# run  361
# 7181at7088 missing
# 14240at7088 missing
# 12884at7088 missing
# run  362
# 13532at7088 missing
# 4967at7088 missing
# 11558at7088 missing
# run  363
# 177at7088 missing
# run  364
# 7181at7088 missing
# 8166at7088 missing
# run  365
# 6951at7088 missing
# 5397at7088 missing
# 12884at7088 missing
# run  366
# 9345at7088 missing
# 10387at7088 missing
# 10546at7088 missing
# 3161at7088 missing
# 12632at7088 missing
# run  367
# 8166at7088 missing
# 13532at7088 missing
# 4967at7088 missing
# 6503at7088 missing
# 1504at7088 missing
# run  368
# 4967at7088 missing
# 8967at7088 missing
# 10387at7088 missing
# 5051at7088 missing
# run  369
# 10387at7088 missing
# 5051at7088 missing
# 12884at7088 missing
# run  370
# 12884at7088 missing
# 12632at7088 missing
# 1504at7088 missing
# 5397at7088 missing
# run  371
# 11558at7088 missing
# run  372
# 177at7088 missing
# 7523at7088 missing
# 5397at7088 missing
# 9345at7088 missing
# run  373
# 13532at7088 missing
# 1504at7088 missing
# 4198at7088 missing
# 7523at7088 missing
# 13189at7088 missing
# run  374
# 6503at7088 missing
# 13532at7088 missing
# 3389at7088 missing
# run  375
# 10387at7088 missing
# 4967at7088 missing
# run  376
# 9345at7088 missing
# 3389at7088 missing
# 7400at7088 missing
# 13532at7088 missing
# 6083at7088 missing
# run  377
# 13189at7088 missing
# 9108at7088 missing
# run  378
# 5397at7088 missing
# 13532at7088 missing
# 7523at7088 missing
# 1576at7088 missing
# 4198at7088 missing
# 12632at7088 missing
# run  379
# 11066at7088 missing
# 8166at7088 missing
# 4118at7088 missing
# run  380
# 14240at7088 missing
# run  381
# 3161at7088 missing
# 4118at7088 missing
# run  382
# 12884at7088 missing
# 3161at7088 missing
# 9556at7088 missing
# run  383
# 6951at7088 missing
# 12632at7088 missing
# 10546at7088 missing
# 5397at7088 missing
# 13189at7088 missing
# 6083at7088 missing
# run  384
# 13189at7088 missing
# 4967at7088 missing
# 9345at7088 missing
# 5397at7088 missing
# 4198at7088 missing
# 9108at7088 missing
# run  385
# run  386
# 8166at7088 missing
# 13189at7088 missing
# 3161at7088 missing
# 10387at7088 missing
# 9556at7088 missing
# run  387
# 7523at7088 missing
# 8166at7088 missing
# 4198at7088 missing
# 11558at7088 missing
# run  388
# 1576at7088 missing
# 9556at7088 missing
# 3389at7088 missing
# 11066at7088 missing
# 8166at7088 missing
# run  389
# 1504at7088 missing
# 1576at7088 missing
# 4198at7088 missing
# 177at7088 missing
# 12884at7088 missing
# 11558at7088 missing
# run  390
# 11269at7088 missing
# 10387at7088 missing
# 4118at7088 missing
# 13532at7088 missing
# run  391
# 7400at7088 missing
# 13532at7088 missing
# 6951at7088 missing
# 8166at7088 missing
# 9108at7088 missing
# 8967at7088 missing
# 11269at7088 missing
# run  392
# 6083at7088 missing
# 9345at7088 missing
# run  393
# 13189at7088 missing
# 1504at7088 missing
# 1576at7088 missing
# 8967at7088 missing
# 10546at7088 missing
# run  394
# 5051at7088 missing
# 3161at7088 missing
# 7523at7088 missing
# 3389at7088 missing
# run  395
# 4967at7088 missing
# 4118at7088 missing
# 5397at7088 missing
# 11269at7088 missing
# run  396
# 5051at7088 missing
# 4118at7088 missing
# 11558at7088 missing
# 11066at7088 missing
# 177at7088 missing
# run  397
# 6503at7088 missing
# 10546at7088 missing
# 10387at7088 missing
# run  398
# 5051at7088 missing
# 4967at7088 missing
# 11558at7088 missing
# 11269at7088 missing
# run  399
# 13532at7088 missing
# 10546at7088 missing
# run  400
# 6083at7088 missing
# 11066at7088 missing
# 8967at7088 missing
# run  401
# 8967at7088 missing
# 6951at7088 missing
# 10387at7088 missing
# 5397at7088 missing
# 4967at7088 missing
# 12884at7088 missing
# 7400at7088 missing
# run  402
# 177at7088 missing
# 6503at7088 missing
# 4967at7088 missing
# run  403
# 11269at7088 missing
# 11558at7088 missing
# 4198at7088 missing
# 3389at7088 missing
# 12884at7088 missing
# run  404
# 177at7088 missing
# 14240at7088 missing
# 8967at7088 missing
# run  405
# 11269at7088 missing
# 177at7088 missing
# 8967at7088 missing
# run  406
# 9556at7088 missing
# run  407
# 4198at7088 missing
# 5051at7088 missing
# 3389at7088 missing
# run  408
# 6503at7088 missing
# 9345at7088 missing
# 11558at7088 missing
# run  409
# 4967at7088 missing
# 11558at7088 missing
# 13532at7088 missing
# run  410
# 6951at7088 missing
# run  411
# 4118at7088 missing
# 10387at7088 missing
# run  412
# 4198at7088 missing
# 6083at7088 missing
# 11269at7088 missing
# 9556at7088 missing
# 10546at7088 missing
# run  413
# 7400at7088 missing
# 8166at7088 missing
# 8967at7088 missing
# 11066at7088 missing
# 5397at7088 missing
# run  414
# 9345at7088 missing
# 9108at7088 missing
# 7181at7088 missing
# 6951at7088 missing
# run  415
# 8967at7088 missing
# 5397at7088 missing
# 6503at7088 missing
# 12632at7088 missing
# 1576at7088 missing
# 9108at7088 missing
# run  416
# 11269at7088 missing
# 6083at7088 missing
# run  417
# 11066at7088 missing
# run  418
# 9556at7088 missing
# 177at7088 missing
# 5397at7088 missing
# 9345at7088 missing
# 13189at7088 missing
# run  419
# 7181at7088 missing
# 1504at7088 missing
# 10387at7088 missing
# 7400at7088 missing
# 8967at7088 missing
# run  420
# 5397at7088 missing
# 5051at7088 missing
# 12884at7088 missing
# 6503at7088 missing
# run  421
# 3389at7088 missing
# 11066at7088 missing
# 11269at7088 missing
# 12884at7088 missing
# run  422
# 13189at7088 missing
# run  423
# 9345at7088 missing
# 8967at7088 missing
# 11066at7088 missing
# run  424
# 177at7088 missing
# run  425
# 1504at7088 missing
# 12632at7088 missing
# 7400at7088 missing
# 14240at7088 missing
# 8166at7088 missing
# run  426
# 7523at7088 missing
# 177at7088 missing
# run  427
# 4118at7088 missing
# 7181at7088 missing
# 3161at7088 missing
# 5051at7088 missing
# run  428
# 7523at7088 missing
# 10387at7088 missing
# 11066at7088 missing
# run  429
# 11066at7088 missing
# 4118at7088 missing
# 9345at7088 missing
# 10387at7088 missing
# 6951at7088 missing
# 8166at7088 missing
# 13189at7088 missing
# 7523at7088 missing
# 3389at7088 missing
# run  430
# 4198at7088 missing
# 8967at7088 missing
# 9345at7088 missing
# 7181at7088 missing
# run  431
# 4198at7088 missing
# 13189at7088 missing
# 12884at7088 missing
# 5397at7088 missing
# run  432
# 8967at7088 missing
# 10546at7088 missing
# 3161at7088 missing
# 12884at7088 missing
# 13532at7088 missing
# run  433
# 4118at7088 missing
# 1504at7088 missing
# 12632at7088 missing
# run  434
# 7181at7088 missing
# 8166at7088 missing
# 14240at7088 missing
# run  435
# 8967at7088 missing
# 7400at7088 missing
# 3389at7088 missing
# 4198at7088 missing
# 1576at7088 missing
# run  436
# 11269at7088 missing
# 9556at7088 missing
# 6503at7088 missing
# run  437
# 11558at7088 missing
# 7400at7088 missing
# run  438
# 11269at7088 missing
# 6503at7088 missing
# 8166at7088 missing
# run  439
# run  440
# 10546at7088 missing
# 7181at7088 missing
# 4118at7088 missing
# run  441
# 1576at7088 missing
# 13189at7088 missing
# 9556at7088 missing
# 7181at7088 missing
# 1504at7088 missing
# run  442
# 10387at7088 missing
# 3161at7088 missing
# run  443
# 9556at7088 missing
# run  444
# 1576at7088 missing
# 14240at7088 missing
# 11066at7088 missing
# 11269at7088 missing
# run  445
# 7523at7088 missing
# 1576at7088 missing
# run  446
# 3389at7088 missing
# 10387at7088 missing
# 13189at7088 missing
# 5397at7088 missing
# 9345at7088 missing
# run  447
# 4967at7088 missing
# 1576at7088 missing
# 12884at7088 missing
# run  448
# 8967at7088 missing
# 4198at7088 missing
# 10546at7088 missing
# run  449
# 10387at7088 missing
# 11269at7088 missing
# run  450
# 9345at7088 missing
# 7400at7088 missing
# 13189at7088 missing
# 8166at7088 missing
# run  451
# 3389at7088 missing
# 12632at7088 missing
# 7181at7088 missing
# 177at7088 missing
# 10387at7088 missing
# 5397at7088 missing
# run  452
# 9345at7088 missing
# 5051at7088 missing
# 3161at7088 missing
# 6083at7088 missing
# 4198at7088 missing
# 9108at7088 missing
# run  453
# 4967at7088 missing
# 3161at7088 missing
# run  454
# 1576at7088 missing
# 13189at7088 missing
# 4967at7088 missing
# run  455
# 11558at7088 missing
# 177at7088 missing
# run  456
# 7181at7088 missing
# 8166at7088 missing
# 5397at7088 missing
# 4198at7088 missing
# run  457
# 10546at7088 missing
# 4967at7088 missing
# 1576at7088 missing
# run  458
# 3389at7088 missing
# 9556at7088 missing
# 10387at7088 missing
# 7523at7088 missing
# run  459
# 7523at7088 missing
# 11558at7088 missing
# 4198at7088 missing
# 10546at7088 missing
# 5051at7088 missing
# run  460
# 11269at7088 missing
# 13189at7088 missing
# 14240at7088 missing
# 1504at7088 missing
# run  461
# 177at7088 missing
# 4967at7088 missing
# run  462
# 7523at7088 missing
# 14240at7088 missing
# 177at7088 missing
# 12632at7088 missing
# run  463
# 11558at7088 missing
# 12632at7088 missing
# run  464
# 10387at7088 missing
# 9345at7088 missing
# 1576at7088 missing
# run  465
# run  466
# 9108at7088 missing
# 3161at7088 missing
# 3389at7088 missing
# run  467
# 14240at7088 missing
# 9556at7088 missing
# 12884at7088 missing
# 10546at7088 missing
# 6083at7088 missing
# run  468
# 5051at7088 missing
# 11558at7088 missing
# 5397at7088 missing
# 9556at7088 missing
# 10546at7088 missing
# run  469
# 10546at7088 missing
# 10387at7088 missing
# 9345at7088 missing
# 7523at7088 missing
# run  470
# 8166at7088 missing
# 13189at7088 missing
# 4967at7088 missing
# run  471
# 9345at7088 missing
# 5397at7088 missing
# 13189at7088 missing
# 7523at7088 missing
# run  472
# 11269at7088 missing
# 8166at7088 missing
# 4118at7088 missing
# run  473
# 3389at7088 missing
# 9556at7088 missing
# 3161at7088 missing
# 5397at7088 missing
# 8166at7088 missing
# run  474
# 3161at7088 missing
# 6951at7088 missing
# 5397at7088 missing
# 4198at7088 missing
# run  475
# 11269at7088 missing
# 4967at7088 missing
# 12884at7088 missing
# 10387at7088 missing
# run  476
# 13189at7088 missing
# 7400at7088 missing
# run  477
# 10387at7088 missing
# 7523at7088 missing
# 4967at7088 missing
# 1576at7088 missing
# run  478
# 6503at7088 missing
# 8166at7088 missing
# 9108at7088 missing
# 10546at7088 missing
# run  479
# 9345at7088 missing
# 10387at7088 missing
# 7400at7088 missing
# run  480
# 5051at7088 missing
# 13532at7088 missing
# 9108at7088 missing
# run  481
# run  482
# run  483
# 9345at7088 missing
# 1576at7088 missing
# run  484
# 6083at7088 missing
# 13189at7088 missing
# 9108at7088 missing
# 1576at7088 missing
# run  485
# 7523at7088 missing
# 3389at7088 missing
# 8166at7088 missing
# run  486
# 11269at7088 missing
# 4118at7088 missing
# 6083at7088 missing
# 12632at7088 missing
# 3161at7088 missing
# run  487
# 6503at7088 missing
# 11066at7088 missing
# 7523at7088 missing
# 5397at7088 missing
# 13189at7088 missing
# 11558at7088 missing
# 10387at7088 missing
# 7181at7088 missing
# 1576at7088 missing
# run  488
# run  489
# 9108at7088 missing
# 7400at7088 missing
# 7181at7088 missing
# 6503at7088 missing
# 8967at7088 missing
# 8166at7088 missing
# run  490
# 8166at7088 missing
# 9345at7088 missing
# 7400at7088 missing
# 12884at7088 missing
# run  491
# 8967at7088 missing
# 13189at7088 missing
# run  492
# 5051at7088 missing
# 3161at7088 missing
# 6951at7088 missing
# 5397at7088 missing
# 6083at7088 missing
# run  493
# 6503at7088 missing
# 8967at7088 missing
# 1504at7088 missing
# run  494
# 9556at7088 missing
# 8967at7088 missing
# 11558at7088 missing
# 3389at7088 missing
# 6083at7088 missing
# run  495
# 6503at7088 missing
# 9108at7088 missing
# 12884at7088 missing
# 3161at7088 missing
# run  496
# 11066at7088 missing
# 14240at7088 missing
# 7400at7088 missing
# 1504at7088 missing
# 3389at7088 missing
# 1576at7088 missing
# run  497
# 9108at7088 missing
# 13532at7088 missing
# 12632at7088 missing
# 9345at7088 missing
# 9556at7088 missing
# run  498
# 177at7088 missing
# 13532at7088 missing
# 8967at7088 missing
# run  499
# 12884at7088 missing
# 11066at7088 missing
# 9345at7088 missing
# 4118at7088 missing
# run  500
# 9556at7088 missing
# 11558at7088 missing
# run  501
# 6083at7088 missing
# 6951at7088 missing
# 9556at7088 missing
# 13189at7088 missing
# run  502
# 12884at7088 missing
# 11269at7088 missing
# run  503
# 5051at7088 missing
# 4967at7088 missing
# 9556at7088 missing
# 10546at7088 missing
# 10387at7088 missing
# run  504
# 9108at7088 missing
# 4198at7088 missing
# 8967at7088 missing
# 6503at7088 missing
# 3389at7088 missing
# run  505
# 9345at7088 missing
# run  506
# 14240at7088 missing
# 9345at7088 missing
# 13189at7088 missing
# 6083at7088 missing
# 6951at7088 missing
# 5051at7088 missing
# 10387at7088 missing
# run  507
# 4967at7088 missing
# run  508
# 6503at7088 missing
# 13532at7088 missing
# 9556at7088 missing
# run  509
# 1576at7088 missing
# 11558at7088 missing
# run  510
# 3389at7088 missing
# 9556at7088 missing
# run  511
# 9556at7088 missing
# run  512
# 11558at7088 missing
# 11269at7088 missing
# 9108at7088 missing
# 6503at7088 missing
# 9345at7088 missing
# run  513
# 1504at7088 missing
# 9345at7088 missing
# 10387at7088 missing
# run  514
# 7181at7088 missing
# 13189at7088 missing
# 11558at7088 missing
# 12632at7088 missing
# 11269at7088 missing
# run  515
# 6503at7088 missing
# 10546at7088 missing
# 3389at7088 missing
# 11558at7088 missing
# run  516
# 9556at7088 missing
# 4118at7088 missing
# 8166at7088 missing
# run  517
# 9556at7088 missing
# run  518
# 6083at7088 missing
# 177at7088 missing
# run  519
# 5397at7088 missing
# 177at7088 missing
# 4198at7088 missing
# run  520
# 13189at7088 missing
# 5397at7088 missing
# 8166at7088 missing
# 3161at7088 missing
# 8967at7088 missing
# run  521
# 6503at7088 missing
# 11269at7088 missing
# 4967at7088 missing
# run  522
# 10387at7088 missing
# 1504at7088 missing
# run  523
# 11269at7088 missing
# 13532at7088 missing
# run  524
# 1576at7088 missing
# 11558at7088 missing
# 7400at7088 missing
# run  525
# 3389at7088 missing
# 6083at7088 missing
# 8967at7088 missing
# 9108at7088 missing
# 14240at7088 missing
# 10387at7088 missing
# run  526
# 8166at7088 missing
# 14240at7088 missing
# 11066at7088 missing
# 4967at7088 missing
# 9345at7088 missing
# run  527
# 8967at7088 missing
# 1576at7088 missing
# run  528
# 8166at7088 missing
# 8967at7088 missing
# 3389at7088 missing
# 7400at7088 missing
# run  529
# 5397at7088 missing
# 4198at7088 missing
# 12884at7088 missing
# 12632at7088 missing
# 10387at7088 missing
# 7523at7088 missing
# run  530
# 9345at7088 missing
# 10387at7088 missing
# 8967at7088 missing
# 12632at7088 missing
# run  531
# 7181at7088 missing
# 5397at7088 missing
# 3161at7088 missing
# 11558at7088 missing
# run  532
# 6951at7088 missing
# 4967at7088 missing
# 9108at7088 missing
# 11558at7088 missing
# 13189at7088 missing
# run  533
# 6951at7088 missing
# 12632at7088 missing
# 9345at7088 missing
# 6503at7088 missing
# run  534
# 6083at7088 missing
# 7400at7088 missing
# 10546at7088 missing
# 6503at7088 missing
# run  535
# 4118at7088 missing
# 13532at7088 missing
# run  536
# 13189at7088 missing
# 14240at7088 missing
# 10546at7088 missing
# run  537
# 9108at7088 missing
# 11269at7088 missing
# run  538
# 8967at7088 missing
# 7181at7088 missing
# 9556at7088 missing
# 1576at7088 missing
# 12884at7088 missing
# run  539
# 12632at7088 missing
# 13532at7088 missing
# 5397at7088 missing
# run  540
# 7523at7088 missing
# 6083at7088 missing
# run  541
# 1576at7088 missing
# 9108at7088 missing
# run  542
# 12632at7088 missing
# 4118at7088 missing
# 3389at7088 missing
# 6951at7088 missing
# 11558at7088 missing
# 9556at7088 missing
# run  543
# 10546at7088 missing
# 4198at7088 missing
# run  544
# 9108at7088 missing
# run  545
# 7181at7088 missing
# 9345at7088 missing
# run  546
# 4198at7088 missing
# 12632at7088 missing
# 13532at7088 missing
# run  547
# 6503at7088 missing
# 4118at7088 missing
# 3389at7088 missing
# 4198at7088 missing
# 4967at7088 missing
# run  548
# 11269at7088 missing
# 6083at7088 missing
# run  549
# 8166at7088 missing
# run  550
# 177at7088 missing
# 6083at7088 missing
# 4118at7088 missing
# 1504at7088 missing
# 9556at7088 missing
# 10387at7088 missing
# 5051at7088 missing
# run  551
# 177at7088 missing
# run  552
# 5397at7088 missing
# 9345at7088 missing
# 5051at7088 missing
# 6503at7088 missing
# run  553
# 6083at7088 missing
# 1576at7088 missing
# 9345at7088 missing
# 11269at7088 missing
# run  554
# 9345at7088 missing
# 1576at7088 missing
# 8166at7088 missing
# run  555
# 6951at7088 missing
# 3389at7088 missing
# run  556
# 7523at7088 missing
# run  557
# 8166at7088 missing
# 10546at7088 missing
# 6503at7088 missing
# 4118at7088 missing
# 3389at7088 missing
# 9108at7088 missing
# run  558
# 14240at7088 missing
# 13189at7088 missing
# run  559
# 11269at7088 missing
# 7181at7088 missing
# 177at7088 missing
# run  560
# 8967at7088 missing
# 11269at7088 missing
# run  561
# 6503at7088 missing
# 4198at7088 missing
# 11558at7088 missing
# 3161at7088 missing
# 8967at7088 missing
# 5397at7088 missing
# 10546at7088 missing
# 1504at7088 missing
# run  562
# 7400at7088 missing
# 4198at7088 missing
# 7523at7088 missing
# run  563
# 177at7088 missing
# 10387at7088 missing
# 11269at7088 missing
# 9108at7088 missing
# run  564
# 3161at7088 missing
# 11558at7088 missing
# run  565
# 9556at7088 missing
# 10387at7088 missing
# 6083at7088 missing
# run  566
# 6503at7088 missing
# 10546at7088 missing
# 4118at7088 missing
# 177at7088 missing
# 12632at7088 missing
# 11269at7088 missing
# run  567
# 8166at7088 missing
# 14240at7088 missing
# 1504at7088 missing
# 11558at7088 missing
# run  568
# 4198at7088 missing
# run  569
# 5051at7088 missing
# run  570
# 4967at7088 missing
# 7523at7088 missing
# run  571
# 13532at7088 missing
# 7400at7088 missing
# 9345at7088 missing
# 6951at7088 missing
# 14240at7088 missing
# 6503at7088 missing
# run  572
# 3161at7088 missing
# 13532at7088 missing
# 6951at7088 missing
# 7181at7088 missing
# run  573
# 3389at7088 missing
# 6503at7088 missing
# 14240at7088 missing
# run  574
# 7523at7088 missing
# 9345at7088 missing
# 5397at7088 missing
# 11558at7088 missing
# 9108at7088 missing
# run  575
# 7400at7088 missing
# 8166at7088 missing
# 1576at7088 missing
# run  576
# 12632at7088 missing
# 1576at7088 missing
# 9345at7088 missing
# 9108at7088 missing
# 11558at7088 missing
# 6083at7088 missing
# run  577
# 3389at7088 missing
# run  578
# 12632at7088 missing
# run  579
# 5397at7088 missing
# 3161at7088 missing
# 7400at7088 missing
# run  580
# 7400at7088 missing
# run  581
# 10546at7088 missing
# 14240at7088 missing
# 10387at7088 missing
# 4198at7088 missing
# 9108at7088 missing
# run  582
# 12632at7088 missing
# 11066at7088 missing
# 4198at7088 missing
# 6503at7088 missing
# run  583
# 11558at7088 missing
# 7181at7088 missing
# 6951at7088 missing
# run  584
# 11269at7088 missing
# run  585
# 6503at7088 missing
# 12632at7088 missing
# 12884at7088 missing
# 9556at7088 missing
# run  586
# 5051at7088 missing
# 7181at7088 missing
# 12632at7088 missing
# run  587
# 13532at7088 missing
# 9345at7088 missing
# 10546at7088 missing
# 8967at7088 missing
# run  588
# 11558at7088 missing
# 8967at7088 missing
# 12632at7088 missing
# run  589
# 9108at7088 missing
# run  590
# 7181at7088 missing
# 9345at7088 missing
# 10546at7088 missing
# 1504at7088 missing
# run  591
# run  592
# 4198at7088 missing
# 8166at7088 missing
# 9108at7088 missing
# 13532at7088 missing
# 9556at7088 missing
# run  593
# 9556at7088 missing
# 7400at7088 missing
# 10546at7088 missing
# run  594
# 13189at7088 missing
# 11269at7088 missing
# 9556at7088 missing
# 9108at7088 missing
# 1504at7088 missing
# run  595
# 11558at7088 missing
# 11066at7088 missing
# 5051at7088 missing
# 4118at7088 missing
# run  596
# 3389at7088 missing
# 9345at7088 missing
# 177at7088 missing
# 13532at7088 missing
# run  597
# 7181at7088 missing
# 6083at7088 missing
# 4198at7088 missing
# run  598
# 177at7088 missing
# 11558at7088 missing
# 11066at7088 missing
# 13532at7088 missing
# run  599
# 6083at7088 missing
# run  600
# 9556at7088 missing
# 14240at7088 missing
# 1576at7088 missing
# 6951at7088 missing
# run  601
# 13189at7088 missing
# 7181at7088 missing
# 9108at7088 missing
# 8967at7088 missing
# 7523at7088 missing
# run  602
# 5051at7088 missing
# 4967at7088 missing
# 14240at7088 missing
# 9556at7088 missing
# 10387at7088 missing
# 8166at7088 missing
# run  603
# 3389at7088 missing
# 7181at7088 missing
# run  604
# 10546at7088 missing
# 13189at7088 missing
# 5397at7088 missing
# run  605
# 177at7088 missing
# run  606
# run  607
# 9345at7088 missing
# 14240at7088 missing
# run  608
# 7181at7088 missing
# 12632at7088 missing
# 10387at7088 missing
# 12884at7088 missing
# run  609
# 7400at7088 missing
# 9345at7088 missing
# run  610
# 11558at7088 missing
# 6083at7088 missing
# 9345at7088 missing
# 12884at7088 missing
# run  611
# 8166at7088 missing
# 4118at7088 missing
# 6503at7088 missing
# 9556at7088 missing
# run  612
# 6503at7088 missing
# 9345at7088 missing
# run  613
# 7400at7088 missing
# 8967at7088 missing
# run  614
# 11558at7088 missing
# 12884at7088 missing
# 10387at7088 missing
# 10546at7088 missing
# 7181at7088 missing
# run  615
# 6951at7088 missing
# 9345at7088 missing
# 10546at7088 missing
# 4118at7088 missing
# run  616
# 12884at7088 missing
# 6503at7088 missing
# 9108at7088 missing
# 7400at7088 missing
# run  617
# 7400at7088 missing
# 4967at7088 missing
# 11269at7088 missing
# 5051at7088 missing
# 14240at7088 missing
# 9345at7088 missing
# 1576at7088 missing
# run  618
# 5397at7088 missing
# 5051at7088 missing
# 8967at7088 missing
# run  619
# 5051at7088 missing
# 8166at7088 missing
# run  620
# 5051at7088 missing
# 10387at7088 missing
# 4967at7088 missing
# 10546at7088 missing
# run  621
# 9556at7088 missing
# 6951at7088 missing
# 7523at7088 missing
# 4967at7088 missing
# run  622
# 5051at7088 missing
# 7523at7088 missing
# 11269at7088 missing
# run  623
# 13532at7088 missing
# run  624
# 12632at7088 missing
# 4118at7088 missing
# 11269at7088 missing
# 13189at7088 missing
# 6083at7088 missing
# 5397at7088 missing
# 3389at7088 missing
# 5051at7088 missing
# run  625
# 7400at7088 missing
# run  626
# 1576at7088 missing
# 3161at7088 missing
# 4967at7088 missing
# 4118at7088 missing
# 7181at7088 missing
# 11269at7088 missing
# 10546at7088 missing
# run  627
# 6951at7088 missing
# 10387at7088 missing
# 9556at7088 missing
# run  628
# 14240at7088 missing
# 4118at7088 missing
# 1504at7088 missing
# 3389at7088 missing
# 12632at7088 missing
# 13532at7088 missing
# run  629
# 9108at7088 missing
# run  630
# 13189at7088 missing
# 13532at7088 missing
# 4198at7088 missing
# 10546at7088 missing
# 6951at7088 missing
# 10387at7088 missing
# 9556at7088 missing
# run  631
# 10387at7088 missing
# 8166at7088 missing
# 9108at7088 missing
# 6503at7088 missing
# run  632
# 6951at7088 missing
# 11066at7088 missing
# run  633
# 11066at7088 missing
# 8166at7088 missing
# 12884at7088 missing
# 177at7088 missing
# 14240at7088 missing
# 4967at7088 missing
# run  634
# 3389at7088 missing
# 11269at7088 missing
# 11066at7088 missing
# 6083at7088 missing
# run  635
# 10546at7088 missing
# 11558at7088 missing
# run  636
# 11558at7088 missing
# 6503at7088 missing
# run  637
# run  638
# 7523at7088 missing
# 14240at7088 missing
# 9108at7088 missing
# run  639
# 11269at7088 missing
# 1576at7088 missing
# 4967at7088 missing
# run  640
# 8166at7088 missing
# 9556at7088 missing
# run  641
# 11558at7088 missing
# 6083at7088 missing
# 8166at7088 missing
# run  642
# 6083at7088 missing
# ...
# 11066at7088 missing
# 1576at7088 missing
# 9556at7088 missing
# run  783
# 7523at7088 missing
# run  784
# 7181at7088 missing
# 4967at7088 missing
# run  785
# 4118at7088 missing
# 177at7088 missing
# 10546at7088 missing
# 6503at7088 missing
# 9108at7088 missing
# 5397at7088 missing
# run  786
# 5397at7088 missing
# 3389at7088 missing
# run  787
# 3161at7088 missing
# 10546at7088 missing
# 12632at7088 missing
# 14240at7088 missing
# 177at7088 missing
# 7181at7088 missing
# run  788
# 1504at7088 missing
# 4118at7088 missing
# run  789
# 11558at7088 missing
# 6083at7088 missing
# 3161at7088 missing
# run  790
# 9345at7088 missing
# 12632at7088 missing
# 11269at7088 missing
# 177at7088 missing
# run  791
# 5397at7088 missing
# 11269at7088 missing
# 13532at7088 missing
# 4967at7088 missing
# run  792
# 6503at7088 missing
# 9108at7088 missing
# run  793
# 11558at7088 missing
# 8967at7088 missing
# 7523at7088 missing
# 9556at7088 missing
# 3389at7088 missing
# run  794
# 3161at7088 missing
# 6083at7088 missing
# 10387at7088 missing
# 5051at7088 missing
# 9108at7088 missing
# run  795
# 3389at7088 missing
# 8967at7088 missing
# run  796
# 5051at7088 missing
# 11558at7088 missing
# 3389at7088 missing
# 177at7088 missing
# run  797
# 9556at7088 missing
# 4118at7088 missing
# run  798
# 7523at7088 missing
# 12884at7088 missing
# 6083at7088 missing
# 11269at7088 missing
# run  799
# 10546at7088 missing
# 4967at7088 missing
# run  800
# 5397at7088 missing
# 3389at7088 missing
# 14240at7088 missing
# 8166at7088 missing
# 6503at7088 missing
# run  801
# 13189at7088 missing
# run  802
# 3389at7088 missing
# 4198at7088 missing
# 6951at7088 missing
# 9345at7088 missing
# run  803
# 13189at7088 missing
# 13532at7088 missing
# 7523at7088 missing
# run  804
# 1576at7088 missing
# 5051at7088 missing
# run  805
# 7181at7088 missing
# 6951at7088 missing
# 1576at7088 missing
# 7523at7088 missing
# 6083at7088 missing
# run  806
# 11558at7088 missing
# 11269at7088 missing
# 9108at7088 missing
# run  807
# 8967at7088 missing
# 177at7088 missing
# 10546at7088 missing
# 7181at7088 missing
# run  808
# 9556at7088 missing
# 7400at7088 missing
# 7181at7088 missing
# run  809
# 13532at7088 missing
# 10387at7088 missing
# 6951at7088 missing
# run  810
# 5397at7088 missing
# 4118at7088 missing
# 3389at7088 missing
# 6503at7088 missing
# 11066at7088 missing
# 5051at7088 missing
# run  811
# 5051at7088 missing
# run  812
# 8967at7088 missing
# run  813
# 12632at7088 missing
# 11558at7088 missing
# run  814
# 10387at7088 missing
# 4967at7088 missing
# 12884at7088 missing
# 9108at7088 missing
# run  815
# 6503at7088 missing
# 8166at7088 missing
# run  816
# 5397at7088 missing
# 1504at7088 missing
# 11269at7088 missing
# 7400at7088 missing
# run  817
# 9108at7088 missing
# 1576at7088 missing
# 7400at7088 missing
# 3389at7088 missing
# 9556at7088 missing
# 9345at7088 missing
# run  818
# 6503at7088 missing
# 8967at7088 missing
# run  819
# 11558at7088 missing
# 6951at7088 missing
# 177at7088 missing
# 10546at7088 missing
# 13532at7088 missing
# run  820
# 8967at7088 missing
# 7400at7088 missing
# run  821
# 10546at7088 missing
# 9345at7088 missing
# 3389at7088 missing
# 11558at7088 missing
# 8166at7088 missing
# run  822
# 7523at7088 missing
# 4118at7088 missing
# run  823
# 10387at7088 missing
# 1504at7088 missing
# run  824
# 12884at7088 missing
# 11269at7088 missing
# 1504at7088 missing
# 9556at7088 missing
# run  825
# 10387at7088 missing
# 5051at7088 missing
# 6951at7088 missing
# run  826
# 4967at7088 missing
# run  827
# 3161at7088 missing
# 6951at7088 missing
# run  828
# 5397at7088 missing
# 11269at7088 missing
# 6951at7088 missing
# run  829
# 6083at7088 missing
# 4967at7088 missing
# 9345at7088 missing
# 5051at7088 missing
# 9556at7088 missing
# run  830
# 14240at7088 missing
# 4198at7088 missing
# 6083at7088 missing
# 11558at7088 missing
# run  831
# 9345at7088 missing
# 13189at7088 missing
# 12632at7088 missing
# 10387at7088 missing
# run  832
# 4118at7088 missing
# 14240at7088 missing
# 12884at7088 missing
# 1576at7088 missing
# run  833
# 3389at7088 missing
# 4967at7088 missing
# 3161at7088 missing
# 9345at7088 missing
# 1504at7088 missing
# run  834
# 12884at7088 missing
# 11269at7088 missing
# 10387at7088 missing
# 3161at7088 missing
# run  835
# 12632at7088 missing
# run  836
# 1504at7088 missing
# 11066at7088 missing
# 3389at7088 missing
# run  837
# 1576at7088 missing
# 9345at7088 missing
# 3389at7088 missing
# 11558at7088 missing
# 13532at7088 missing
# 7181at7088 missing
# run  838
# 12884at7088 missing
# 10387at7088 missing
# 3161at7088 missing
# 5051at7088 missing
# 10546at7088 missing
# run  839
# 5397at7088 missing
# 177at7088 missing
# 11269at7088 missing
# run  840
# 9108at7088 missing
# 5397at7088 missing
# 3161at7088 missing
# 13532at7088 missing
# 7523at7088 missing
# 7181at7088 missing
# run  841
# 10387at7088 missing
# 11558at7088 missing
# run  842
# 11558at7088 missing
# 13532at7088 missing
# 10387at7088 missing
# 12884at7088 missing
# 177at7088 missing
# run  843
# run  844
# 4118at7088 missing
# 9108at7088 missing
# 12632at7088 missing
# 5397at7088 missing
# 14240at7088 missing
# 3389at7088 missing
# 10387at7088 missing
# run  845
# 14240at7088 missing
# 6083at7088 missing
# run  846
# 3389at7088 missing
# 10387at7088 missing
# 4198at7088 missing
# 8967at7088 missing
# 7181at7088 missing
# run  847
# 9108at7088 missing
# 11558at7088 missing
# 13532at7088 missing
# 177at7088 missing
# run  848
# 12632at7088 missing
# 9556at7088 missing
# 7523at7088 missing
# run  849
# 13532at7088 missing
# 9108at7088 missing
# 8967at7088 missing
# 7181at7088 missing
# run  850
# 177at7088 missing
# 11558at7088 missing
# 6951at7088 missing
# 13189at7088 missing
# 8166at7088 missing
# run  851
# 1576at7088 missing
# 4198at7088 missing
# 7523at7088 missing
# run  852
# 3161at7088 missing
# 4198at7088 missing
# run  853
# 1504at7088 missing
# 8967at7088 missing
# 7181at7088 missing
# 9345at7088 missing
# 3389at7088 missing
# 4198at7088 missing
# 3161at7088 missing
# run  854
# 6083at7088 missing
# 1576at7088 missing
# 9556at7088 missing
# 7181at7088 missing
# 13189at7088 missing
# run  855
# 7523at7088 missing
# run  856
# 11066at7088 missing
# run  857
# 10546at7088 missing
# 7181at7088 missing
# run  858
# 12632at7088 missing
# 13189at7088 missing
# run  859
# 8166at7088 missing
# 3161at7088 missing
# 11558at7088 missing
# run  860
# 9108at7088 missing
# 7523at7088 missing
# 4198at7088 missing
# 3389at7088 missing
# 4967at7088 missing
# run  861
# 9556at7088 missing
# 11066at7088 missing
# 11269at7088 missing
# 8166at7088 missing
# run  862
# 1504at7088 missing
# 11066at7088 missing
# 6083at7088 missing
# 11269at7088 missing
# 12632at7088 missing
# 14240at7088 missing
# run  863
# 1504at7088 missing
# run  864
# 6951at7088 missing
# 7181at7088 missing
# 6083at7088 missing
# run  865
# 7400at7088 missing
# 6951at7088 missing
# 4118at7088 missing
# run  866
# 8166at7088 missing
# 12632at7088 missing
# 5397at7088 missing
# 5051at7088 missing
# 9345at7088 missing
# run  867
# 7523at7088 missing
# 9108at7088 missing
# 1576at7088 missing
# 4967at7088 missing
# run  868
# 7181at7088 missing
# 3389at7088 missing
# 8967at7088 missing
# run  869
# 7400at7088 missing
# 1576at7088 missing
# run  870
# 4118at7088 missing
# 5051at7088 missing
# run  871
# 177at7088 missing
# 7400at7088 missing
# 5051at7088 missing
# 4967at7088 missing
# run  872
# 6503at7088 missing
# 11066at7088 missing
# 5051at7088 missing
# 4118at7088 missing
# 12632at7088 missing
# run  873
# 11558at7088 missing
# 4967at7088 missing
# 11066at7088 missing
# run  874
# 1576at7088 missing
# 9108at7088 missing
# 7400at7088 missing
# run  875
# 3389at7088 missing
# run  876
# 11269at7088 missing
# 6951at7088 missing
# 8166at7088 missing
# run  877
# 13189at7088 missing
# 7181at7088 missing
# 7523at7088 missing
# 4118at7088 missing
# run  878
# 6951at7088 missing
# 5397at7088 missing
# 177at7088 missing
# 13532at7088 missing
# 3161at7088 missing
# 9108at7088 missing
# run  879
# 7400at7088 missing
# 7181at7088 missing
# run  880
# 9556at7088 missing
# 9108at7088 missing
# run  881
# 12884at7088 missing
# 5397at7088 missing
# 11558at7088 missing
# 7181at7088 missing
# run  882
# 6951at7088 missing
# 7181at7088 missing
# 6083at7088 missing
# run  883
# 12884at7088 missing
# 7523at7088 missing
# 10546at7088 missing
# run  884
# 6951at7088 missing
# 6503at7088 missing
# run  885
# 10546at7088 missing
# 1504at7088 missing
# 13532at7088 missing
# 11269at7088 missing
# run  886
# 177at7088 missing
# 7181at7088 missing
# run  887
# 7181at7088 missing
# 3389at7088 missing
# 5397at7088 missing
# 7523at7088 missing
# run  888
# 13532at7088 missing
# 10546at7088 missing
# run  889
# 9556at7088 missing
# 11066at7088 missing
# 6083at7088 missing
# run  890
# 14240at7088 missing
# 10387at7088 missing
# run  891
# 5397at7088 missing
# 8967at7088 missing
# 10387at7088 missing
# 177at7088 missing
# 4198at7088 missing
# 11066at7088 missing
# run  892
# 10546at7088 missing
# 9108at7088 missing
# 6083at7088 missing
# 7181at7088 missing
# run  893
# 6951at7088 missing
# 9556at7088 missing
# run  894
# 9108at7088 missing
# 5397at7088 missing
# run  895
# 6951at7088 missing
# 1576at7088 missing
# 8166at7088 missing
# 7523at7088 missing
# 13532at7088 missing
# run  896
# 9556at7088 missing
# run  897
# 12884at7088 missing
# 3389at7088 missing
# 9108at7088 missing
# run  898
# 177at7088 missing
# 10387at7088 missing
# 11269at7088 missing
# 7523at7088 missing
# 9556at7088 missing
# 11558at7088 missing
# 5397at7088 missing
# 10546at7088 missing
# run  899
# run  900
# 4198at7088 missing
# run  901
# 4967at7088 missing
# run  902
# 10387at7088 missing
# 6083at7088 missing
# 14240at7088 missing
# run  903
# 9108at7088 missing
# 13532at7088 missing
# 9345at7088 missing
# run  904
# 11558at7088 missing
# 7400at7088 missing
# 5397at7088 missing
# 11269at7088 missing
# 12632at7088 missing
# run  905
# 4198at7088 missing
# 1504at7088 missing
# 5397at7088 missing
# run  906
# 11269at7088 missing
# 7181at7088 missing
# 3161at7088 missing
# run  907
# 4967at7088 missing
# 14240at7088 missing
# run  908
# 6951at7088 missing
# 4198at7088 missing
# 12632at7088 missing
# 1504at7088 missing
# 9556at7088 missing
# 11269at7088 missing
# run  909
# 13189at7088 missing
# 5051at7088 missing
# 13532at7088 missing
# 4118at7088 missing
# 7523at7088 missing
# run  910
# run  911
# 10387at7088 missing
# 13532at7088 missing
# 5397at7088 missing
# 7181at7088 missing
# 6503at7088 missing
# 7400at7088 missing
# run  912
# 7181at7088 missing
# 9345at7088 missing
# 8967at7088 missing
# 6083at7088 missing
# run  913
# 11558at7088 missing
# 4967at7088 missing
# 4118at7088 missing
# 14240at7088 missing
# 3161at7088 missing
# 7400at7088 missing
# run  914
# 6503at7088 missing
# run  915
# 13189at7088 missing
# 9108at7088 missing
# 10387at7088 missing
# 7523at7088 missing
# 6083at7088 missing
# run  916
# 8967at7088 missing
# 10546at7088 missing
# 12632at7088 missing
# 5051at7088 missing
# run  917
# 8166at7088 missing
# 6083at7088 missing
# 8967at7088 missing
# 14240at7088 missing
# 13189at7088 missing
# 13532at7088 missing
# 10546at7088 missing
# 7181at7088 missing
# run  918
# 3389at7088 missing
# 13189at7088 missing
# 1504at7088 missing
# run  919
# 13189at7088 missing
# 7181at7088 missing
# run  920
# 12632at7088 missing
# run  921
# 9556at7088 missing
# 1576at7088 missing
# 4967at7088 missing
# 8166at7088 missing
# 7400at7088 missing
# 4118at7088 missing
# run  922
# 4967at7088 missing
# 7400at7088 missing
# 12884at7088 missing
# 5397at7088 missing
# run  923
# 12632at7088 missing
# 12884at7088 missing
# 1576at7088 missing
# run  924
# 7400at7088 missing
# 1504at7088 missing
# 8967at7088 missing
# run  925
# run  926
# 7400at7088 missing
# 3161at7088 missing
# run  927
# 9108at7088 missing
# 3389at7088 missing
# 7181at7088 missing
# 7400at7088 missing
# 5051at7088 missing
# 5397at7088 missing
# 177at7088 missing
# run  928
# 3161at7088 missing
# 5397at7088 missing
# run  929
# 7523at7088 missing
# 5051at7088 missing
# 11066at7088 missing
# run  930
# 177at7088 missing
# 13532at7088 missing
# 14240at7088 missing
# 7181at7088 missing
# run  931
# 12884at7088 missing
# 13532at7088 missing
# 8166at7088 missing
# run  932
# 11066at7088 missing
# run  933
# 8166at7088 missing
# 7181at7088 missing
# 10387at7088 missing
# run  934
# 14240at7088 missing
# 11269at7088 missing
# run  935
# 4198at7088 missing
# 5397at7088 missing
# run  936
# 13189at7088 missing
# 6951at7088 missing
# 7400at7088 missing
# 5397at7088 missing
# run  937
# 1576at7088 missing
# 8967at7088 missing
# 10387at7088 missing
# 7523at7088 missing
# 3161at7088 missing
# run  938
# 4118at7088 missing
# 11558at7088 missing
# 12632at7088 missing
# 14240at7088 missing
# 12884at7088 missing
# run  939
# 12884at7088 missing
# 177at7088 missing
# 6951at7088 missing
# run  940
# 14240at7088 missing
# 11066at7088 missing
# run  941
# 10546at7088 missing
# 4118at7088 missing
# run  942
# 10387at7088 missing
# 5397at7088 missing
# run  943
# 3161at7088 missing
# 13532at7088 missing
# 10546at7088 missing
# run  944
# 177at7088 missing
# 5397at7088 missing
# 13189at7088 missing
# run  945
# 7523at7088 missing
# 10546at7088 missing
# run  946
# 7523at7088 missing
# 9556at7088 missing
# 1504at7088 missing
# 4967at7088 missing
# 10546at7088 missing
# run  947
# 12884at7088 missing
# 6503at7088 missing
# 13189at7088 missing
# 9108at7088 missing
# run  948
# 4118at7088 missing
# 11066at7088 missing
# 6951at7088 missing
# 9556at7088 missing
# 7523at7088 missing
# run  949
# 11066at7088 missing
# 13532at7088 missing
# run  950
# 13189at7088 missing
# 4198at7088 missing
# 9345at7088 missing
# 10387at7088 missing
# 14240at7088 missing
# run  951
# 1504at7088 missing
# 5051at7088 missing
# 13532at7088 missing
# 10546at7088 missing
# 9108at7088 missing
# run  952
# 6951at7088 missing
# 177at7088 missing
# 7523at7088 missing
# run  953
# 7400at7088 missing
# 1504at7088 missing
# 1576at7088 missing
# 177at7088 missing
# run  954
# 9556at7088 missing
# 12884at7088 missing
# 5051at7088 missing
# 1504at7088 missing
# run  955
# 7181at7088 missing
# 9345at7088 missing
# 13189at7088 missing
# 3161at7088 missing
# 177at7088 missing
# run  956
# 7523at7088 missing
# 3161at7088 missing
# 10546at7088 missing
# 6503at7088 missing
# 8967at7088 missing
# run  957
# 5397at7088 missing
# 9556at7088 missing
# 9108at7088 missing
# 177at7088 missing
# run  958
# 8166at7088 missing
# 11558at7088 missing
# 10546at7088 missing
# run  959
# 8967at7088 missing
# 4118at7088 missing
# 7400at7088 missing
# 6503at7088 missing
# run  960
# 9345at7088 missing
# 4198at7088 missing
# 13532at7088 missing
# run  961
# 6083at7088 missing
# run  962
# 13532at7088 missing
# run  963
# 177at7088 missing
# 13532at7088 missing
# 12884at7088 missing
# run  964
# 4967at7088 missing
# 9345at7088 missing
# run  965
# 1576at7088 missing
# 9345at7088 missing
# 1504at7088 missing
# run  966
# 10387at7088 missing
# 9556at7088 missing
# 177at7088 missing
# 3389at7088 missing
# run  967
# 6083at7088 missing
# 5051at7088 missing
# 1504at7088 missing
# 7181at7088 missing
# run  968
# 9556at7088 missing
# 7400at7088 missing
# 9345at7088 missing
# 11269at7088 missing
# 11558at7088 missing
# 14240at7088 missing
# 5397at7088 missing
# run  969
# 7523at7088 missing
# 4118at7088 missing
# 8166at7088 missing
# 10546at7088 missing
# 9345at7088 missing
# 5051at7088 missing
# 13189at7088 missing
# 8967at7088 missing
# run  970
# 10546at7088 missing
# 13189at7088 missing
# run  971
# 12884at7088 missing
# 6503at7088 missing
# 3389at7088 missing
# run  972
# 13532at7088 missing
# 3161at7088 missing
# run  973
# 4967at7088 missing
# 6503at7088 missing
# 9556at7088 missing
# 11269at7088 missing
# run  974
# 11066at7088 missing
# 6951at7088 missing
# 3389at7088 missing
# 7523at7088 missing
# run  975
# 14240at7088 missing
# 6083at7088 missing
# 177at7088 missing
# 5051at7088 missing
# run  976
# 9345at7088 missing
# 5051at7088 missing
# 8166at7088 missing
# run  977
# 7181at7088 missing
# 9345at7088 missing
# 1504at7088 missing
# run  978
# 3161at7088 missing
# run  979
# 5051at7088 missing
# 3161at7088 missing
# run  980
# run  981
# 8166at7088 missing
# 9345at7088 missing
# 13189at7088 missing
# 7523at7088 missing
# 7400at7088 missing
# run  982
# 177at7088 missing
# 14240at7088 missing
# 4118at7088 missing
# 11558at7088 missing
# run  983
# 4967at7088 missing
# 177at7088 missing
# 8967at7088 missing
# 10387at7088 missing
# run  984
# 5397at7088 missing
# 9345at7088 missing
# 1504at7088 missing
# 11066at7088 missing
# 5051at7088 missing
# run  985
# 5397at7088 missing
# 4967at7088 missing
# 3161at7088 missing
# 1576at7088 missing
# 13189at7088 missing
# 11066at7088 missing
# 9345at7088 missing
# run  986
# 4198at7088 missing
# 1504at7088 missing
# run  987
# run  988
# 13189at7088 missing
# 6951at7088 missing
# 12884at7088 missing
# 6083at7088 missing
# 177at7088 missing
# 3161at7088 missing
# 6503at7088 missing
# run  989
# 3389at7088 missing
# 11269at7088 missing
# 3161at7088 missing
# 6083at7088 missing
# run  990
# 5051at7088 missing
# 4967at7088 missing
# 7400at7088 missing
# 3161at7088 missing
# run  991
# 4198at7088 missing
# 177at7088 missing
# 13532at7088 missing
# run  992
# 3389at7088 missing
# 11066at7088 missing
# 11558at7088 missing
# 11269at7088 missing
# 4967at7088 missing
# run  993
# 6083at7088 missing
# 3161at7088 missing
# 9556at7088 missing
# 6503at7088 missing
# run  994
# run  995
# 4198at7088 missing
# 12884at7088 missing
# run  996
# 1576at7088 missing
# 177at7088 missing
# run  997
# 11066at7088 missing
# run  998
# 7400at7088 missing
# 11066at7088 missing
# 12884at7088 missing
# 6951at7088 missing
# run  999
# 9556at7088 missing
# 10387at7088 missing
# 1000

# %%
# import numpy as np
# # print((intersecting_genes_length_list))
# str_list = ""
# for num in intersecting_genes_length_list:
#     str_list += f"{num}\n"
# with open(f"{location}/4.Intersections_test/10000_runs_10kb.txt", 'w') as out_file:
#     out_file.write(str_list)

# %%
import matplotlib.pyplot as plt

# Sample data
data = intersecting_genes_length_list

# Define bins with size = 1
min_bin = min(data)
max_bin = max(data)
bins = range(min_bin, max_bin + 2)  # +2 to include the last value properly

# Plot
plt.figure(figsize=(20, 20))
plt.hist(data, bins=bins, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Bin Size = 1')
plt.xticks(bins)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.kdeplot(data, fill=True, linewidth=2, color="blue")

# Vertical line
defined_value = 10
plt.axvline(defined_value, color='red', linestyle='--', linewidth=2)

# Remove top & right spines (keep only x and y axes)
sns.despine(top=True, right=True)

plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Smooth Density Plot with Vertical Line")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Always show details
import scipy.stats as stats

# Updated list of observations
observations = intersecting_genes_length_list
# print(observations)
# [7, 7, 4, 7, 10, 2, 7, 10, 5, 10, 1, 0, 5, 4, 6, 7, 6, 9, 5, 1, 8, 7, 2, 10, 7, 9, 3, 11, 9, 0, 9, 5, 5, 2, 0, 12, 3, 6, 4, 2, 9, 5, 3, 2, 8, 2, 0, 6, 6, 1, 12, 3, 1, 3, 8, 12, 8, 0, 6, 4, 0, 7, 2, 7, 10, 2, 7, 3, 3, 1, 13, 8, 11, 8, 1, 6, 3, 0, 6, 5, 7, 2, 2, 7, 0, 11, 7, 9, 10, 8, 2, 4, 8, 7, 0, 3, 5, 0, 4, 8, 6, 4, 8, 1, 3, 5, 6, 6, 6, 0, 4, 6, 4, 2, 4, 4, 5, 10, 10, 0, 5, 3, 1, 7, 5, 2, 0, 0, 3, 0, 7, 8, 10, 6, 3, 4, 2, 8, 8, 0, 7, 5, 0, 7, 6, 5, 1, 0, 9, 7, 1, 13, 2, 10, 3, 9, 9, 5, 1, 5, 6, 7, 1, 2, 10, 8, 7, 1, 7, 6, 9, 5, 0, 11, 0, 0, 6, 2, 1, 1, 1, 6, 4, 9, 8, 4, 5, 9, 4, 15, 9, 0, 2, 0, 1, 3, 10, 3, 9, 3, 4, 2, 1, 7, 4, 1, 1, 5, 3, 4, 14, 0, 0, 5, 5, 8, 7, 0]

# Calculate the proportion of values greater than or equal to 10
value_of_interest = final_gene_number
print(value_of_interest)
count_extreme = sum(x >= value_of_interest for x in observations)
p_value = count_extreme / len(observations)

p_value
# Out:
# 275
# 0.042

# %%
import seaborn as sns
plt.figure(figsize=(6, 12))
sns.kdeplot(y=data, fill=True, linewidth=1, color="blue")

# Vertical line at defined place (example: x=10)
defined_value = value_of_interest
plt.axhline(defined_value, color='red', linestyle='--', linewidth=5, label=f"x = {defined_value}\nP = {p_value}")
sns.despine(top=True, right=True)
plt.ylabel("Number of Genes")
plt.xlabel("Density")
# plt.title("Smooth Density Plot with Vertical Line")
plt.legend(fontsize=40)
# plt.grid(axis='y', linestyle='--', alpha=0.7)


plt.savefig("/mnt/c/Users/sauba/Desktop/20.RERConverge_trimmed/3.New_colias/61.New_alignment_colias/7.Manhatten/1.Density_plots/napi_density_plot.pdf", format="pdf", bbox_inches="tight")
plt.show()
