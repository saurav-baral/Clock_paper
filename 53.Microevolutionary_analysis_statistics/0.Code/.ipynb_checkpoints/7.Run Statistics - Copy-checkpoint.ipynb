# %% [markdown]
# ## Expand Gene identities

# %%
# %reset
import pandas as pd
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/1.Lasiomatta_megera"

gene_table = pd.read_csv(f"{location}/2.Annotation_busco_prediction/full_table.tsv", sep= "\t")
gene_table
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y
#          Busco_id      Status Sequence  Gene_Start    Gene_End Strand  \
# 0         0at7088    Complete       24   4461569.0   4349795.0      -
# 1         1at7088    Complete        Z   1337207.0   1448954.0      +
# 2         2at7088    Complete        5   9524326.0   9613919.0      +
# 3         3at7088    Complete        8  16889554.0  17031555.0      +
# 4         4at7088    Complete        7   7646229.0   7751605.0      +
# ...           ...         ...      ...         ...         ...    ...
# 5306  16855at7088  Fragmented        6  11334273.0  11335323.0      +
# 5307  16938at7088    Complete       28   5240471.0   5245371.0      +
# 5308  16982at7088    Complete        6  18026995.0  18027492.0      +
# 5309        cycle    Complete        Z  27393173.0  27438198.0      +
# 5310         cry2    Complete        4   9868459.0   9877967.0      +
#
#         Score   Length                                   OrthoDB url  \
# 0     17074.6   8018.0      https://v10-1.orthodb.org/?query=0at7088
# 1      9131.8   4245.0      https://v10-1.orthodb.org/?query=1at7088
# 2     25469.1  14629.0      https://v10-1.orthodb.org/?query=2at7088
# 3     10478.1   5416.0      https://v10-1.orthodb.org/?query=3at7088
# 4     13223.7   6795.0      https://v10-1.orthodb.org/?query=4at7088
# ...       ...      ...                                           ...
# 5306    107.0     66.0  https://v10-1.orthodb.org/?query=16855at7088
# 5307     92.0    102.0  https://v10-1.orthodb.org/?query=16938at7088
# 5308    118.6    111.0  https://v10-1.orthodb.org/?query=16982at7088
# 5309    116.9    120.0  https://v10-1.orthodb.org/?query=16982at7088
# 5310    116.9    120.0  https://v10-1.orthodb.org/?query=16982at7088
#
#                                Description
# 0                           Immunoglobulin
# 1                           Immunoglobulin
# 2          EGF-like calcium-binding domain
# 3                          Spectrin repeat
# 4                          Spectrin repeat
# ...                                    ...
# 5306            AT hook, DNA-binding motif
# 5307  uncharacterized protein LOC111359467
# 5308  uncharacterized protein LOC110991765
# 5309                                 cycle
# 5310                                  cry2
#
# [5311 rows x 10 columns]

# %%
output = "Busco_id\tChromosome\tGene_Start\tGene_End"
for row_details in gene_table.itertuples():
    if not(pd.isna(row_details.Sequence)):
        if row_details.Gene_Start > row_details.Gene_End:
            gene_start = row_details.Gene_End
            gene_end = row_details.Gene_Start
        else:
            gene_start = row_details.Gene_Start
            gene_end = row_details.Gene_End
        try:
            output += f"\n{row_details.Busco_id}\t{row_details.Sequence}\t{int(max(0,gene_start-10000))}\t{int(gene_end+10000)}"
        except:
            print(row_details.Busco_id, gene_end+20000)
            assert False
    # print(row_details)
    # break
with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'w') as out_file:
    out_file.write(output)

# %%
fst_dictionary = {}
with open(f"{location}/1.FST_peaks_from_chris/two_pool_1%_0.154_5kb_merged.fst",'r') as fst_file:
    for fst_lines in fst_file.readlines()[1:]:
        line_split = fst_lines.strip().split(",")
        fst_dictionary.setdefault(line_split[0],[])
        
        fst_dictionary[line_split[0]].append([int(line_split[1]), int(line_split[2])])
        
print(fst_dictionary)
# Out:
# {'1': [[46001, 75000], [949001, 950000], [987001, 988000], [2242001, 2243000], [2505001, 2506000], [2673001, 2674000], [2683001, 2684000], [2790001, 2791000], [3428001, 3430000], [3440001, 3441000], [3645001, 3646000], [4547001, 4548000], [4637001, 4638000], [4643001, 4644000], [4666001, 4667000], [4686001, 4691000], [4711001, 4713000], [4989001, 4990000], [5147001, 5148000], [5161001, 5162000], [5942001, 5944000], [5949001, 5955000], [6140001, 6153000], [6159001, 6167000], [6607001, 6608000], [6855001, 6861000], [6896001, 6897000], [7664001, 7669000], [7847001, 7848000], [7909001, 7910000], [7915001, 7916000], [7937001, 7938000], [7946001, 7953000], [8129001, 8130000], [8221001, 8229000], [8251001, 8252000], [8731001, 8733000], [8904001, 8905000], [9085001, 9086000], [9723001, 9724000], [10017001, 10018000], [10960001, 10961000], [10997001, 10998000], [11570001, 11571000], [12031001, 12032000], [12159001, 12160000], [12212001, 12218000], [12339001, 12340000], [12365001, 12366000], [12654001, 12659000], [12692001, 12693000], [12731001, 12732000], [12792001, 12793000], [12879001, 12883000], [12888001, 12890000], [13180001, 13181000], [13190001, 13191000], [13966001, 13967000], [14555001, 14557000], [15053001, 15054000], [15655001, 15657000], [15753001, 15754000], [15762001, 15771000], [15782001, 15783000], [15822001, 15823000], [15931001, 15932000], [16114001, 16115000], [16715001, 16716000], [18372001, 18381000], [18871001, 18872000], [19243001, 19249000], [19782001, 19785000], [19898001, 19899000], [20610001, 20611000]], '10': [[354001, 355000], [395001, 396000], [751001, 752000], [781001, 782000], [1762001, 1763000], [2363001, 2364000], [2380001, 2381000], [2501001, 2502000], [3480001, 3481000], [3621001, 3626000], [3639001, 3643000], [3653001, 3654000], [3829001, 3830000], [4512001, 4513000], [4860001, 4861000], [5316001, 5317000], [5780001, 5781000], [5793001, 5794000], [5813001, 5819000], [5825001, 5828000], [5866001, 5867000], [5912001, 5913000], [5922001, 5925000], [6366001, 6367000], [6378001, 6379000], [6706001, 6707000], [7519001, 7520000], [7554001, 7555000], [7629001, 7632000], [7722001, 7723000], [8196001, 8197000], [8543001, 8548000], [8555001, 8559000], [8652001, 8653000], [8670001, 8671000], [10034001, 10035000], [10078001, 10083000], [10204001, 10214000], [10219001, 10222000], [10227001, 10228000], [10237001, 10244000], [10265001, 10266000], [10284001, 10285000], [11320001, 11321000], [11337001, 11345000], [11366001, 11367000], [11374001, 11375000], [11383001, 11384000], [11408001, 11418000], [11605001, 11613000], [11705001, 11706000], [11869001, 11870000], [12015001, 12018000], [12030001, 12046000], [12051001, 12053000], [12472001, 12473000], [12485001, 12490000], [12886001, 12887000], [13305001, 13306000], [13932001, 13933000], [14478001, 14479000], [14532001, 14537000], [14722001, 14723000], [14913001, 14916000], [14927001, 14928000], [15314001, 15315000], [15394001, 15395000], [15461001, 15462000], [15472001, 15473000], [15547001, 15548000], [15555001, 15556000], [16245001, 16249000], [16263001, 16264000], [16354001, 16355000], [16368001, 16373000], [16384001, 16385000], [16407001, 16408000], [16461001, 16462000], [16575001, 16576000], [16828001, 16829000], [16877001, 16882000], [16977001, 16978000], [17075001, 17076000], [17120001, 17126000], [17131001, 17134000], [17160001, 17161000], [17310001, 17312000], [17319001, 17320000], [17325001, 17337000], [17359001, 17360000], [17610001, 17611000], [17657001, 17658000], [17707001, 17711000], [17720001, 17721000], [17769001, 17772000], [17844001, 17845000], [17941001, 17942000]], '11': [[1420001, 1421000], [1443001, 1444000], [1920001, 1921000], [2772001, 2773000], [2781001, 2782000], [3000001, 3001000], [3327001, 3328000], [3780001, 3781000], [3830001, 3831000], [3850001, 3851000], [4202001, 4206000], [4932001, 4933000], [5143001, 5144000], [5422001, 5423000], [5485001, 5486000], [5612001, 5613000], [5768001, 5769000], [6825001, 6826000], [7162001, 7163000], [ ...

# %%
gene_loc_dic = {}
with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'r') as gene_loc_file:
    for gene_line in gene_loc_file.readlines()[1:]:
        line_split = gene_line.strip().split("\t")
        gene_loc_dic[line_split[0]] = [line_split[1],line_split[2],line_split[3]]
# print(gene_loc_dic)

# %%
output_rho_set_location = "Gene,Chromosome,Location"
with open(f"{location}/3.Rho_set_genes/Rho_set_gene2.txt", 'r') as rho_set_file:
    for lines in rho_set_file.readlines():
        rho_gene_name = lines.strip().split("\t")[0]
        # print(lines.strip(),gene_loc_dic[lines.strip()])
        # print(rho_gene_name)
        chromosome,start,end = gene_loc_dic[rho_gene_name]
        # print(chromosome,start,end)
        output_rho_set_location +=  f"\n{rho_gene_name},{chromosome},{start}"

# print(output_rho_set_location)
with open(f"{location}/3.Rho_set_genes/Rho_set_location.csv", 'w') as rho_out_file:
    rho_out_file.write(output_rho_set_location)

# %%
intersecting_genes = []
with open(f"{location}/3.Rho_set_genes/Rho_set_cluster.txt", 'r') as rho_set_file:
    for rho_set_count,lines in enumerate(rho_set_file.readlines()):
        rho_gene_name = lines.strip().split("\t")[0]
        # print(lines.strip(),gene_loc_dic[lines.strip()])
        try:
            chromosome,start,end = gene_loc_dic[rho_gene_name]
        except:
            continue
        # print(chromosome,start,end)
        for sections in (fst_dictionary[chromosome]):
            # print(sections)
            if ((int(start) >= sections[0] and int(start) <= sections[1]) or (int(end) >= sections[0] and int(end) <= sections[1])) or ((sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))):
                # print(sections)
                print(lines, end = "")
                intersecting_genes.append(rho_gene_name)
                break
            # elif (sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))
        # break
print("\n",len(intersecting_genes), rho_set_count, len(set((intersecting_genes))))
final_gene_number = len(intersecting_genes)
# Out:
# 2453at7088
# 13413at7088
# 15035at7088
# 14245at7088
# 1846at7088
# 652at7088
# 2599at7088
# 5650at7088
# 821at7088
# 386at7088
# 3127at7088
# 1709at7088
# 6156at7088
# 3667at7088
# 9535at7088
# 2906at7088
# 8465at7088
# 12090at7088
# 12180at7088
# 274at7088
# 12326at7088
# 11858at7088
# 11288at7088
# 2938at7088
# 5679at7088
# 8306at7088
# 2939at7088
# 5486at7088
# 12212at7088
# 2813at7088
# 11619at7088
# 7044at7088
# 4799at7088
# 2003at7088
# 6173at7088
# 4078at7088
# 1076at7088
# cycle
# 1319at7088
# 11115at7088
# 8048at7088
# 7508at7088
# 4089at7088
# 68at7088
# 7935at7088
# 2019at7088
# 14213at7088
# 559at7088
# 10142at7088
# 10139at7088
# 2160at7088
# 5567at7088
# 2335at7088
# 3537at7088
# 2234at7088
# 7053at7088
# 8793at7088
# 4176at7088
# 8595at7088
# 2694at7088
# 4625at7088
# 12075at7088
# 5858at7088
# 2166at7088
# 1246at7088
# 993at7088
# 7919at7088
# 5563at7088
# 5035at7088
# 2428at7088
# 515at7088
# 2021at7088
# 10662at7088
# 9339at7088
# 2273at7088
# 7415at7088
# 1993at7088
# 3611at7088
# 543at7088
# 11428at7088
# 2931at7088
# 7476at7088
# 5427at7088
# 1918at7088
# 11189at7088
# 3833at7088
# 2829at7088
# 12640at7088
# 1130at7088
# 11835at7088
# 8711at7088
# 1605at7088
# 10086at7088
# 4996at7088
#
#  94 503 94

# %%
gene_anno_dic = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/2.Two_state/correlation_2_with_annotation.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        gene_name = lines.split(",")[0].split("_")[0][1:]
        anno_name = lines.split(",")[-1].replace('"', '')
        gene_anno_dic[gene_name]= anno_name.strip()

# %%
instersecting_genes_output = ""
for intersecting_gene_name in intersecting_genes:
    if intersecting_gene_name in gene_anno_dic:
        instersecting_genes_output += gene_anno_dic[intersecting_gene_name] + "\n"
    else:
        instersecting_genes_output += intersecting_gene_name + "\n"
# print(intersecting_genes)
with open(f"{location}/4.Intersections_test/intersection_set.txt", 'w') as out_file:
    out_file.write(instersecting_genes_output)
# print(instersecting_genes_output)

# %%
instersecting_genes_output = "geneid\n"+"\n".join(set(intersecting_genes))
with open(f"{location}/4.Intersections_test/1.For GSEA/1.Rho Set/intersection_set.txt", 'w') as out_file:
    out_file.write(instersecting_genes_output)

# %%
busco_gene_list = []
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/0.Gene_id_list/Busco_gene_id.txt",'r') as busco_gene_list_file:
    for lines in busco_gene_list_file:
        busco_gene_list.append(lines.strip())
print(len(busco_gene_list))
# Out:
# 4564

# %%
rho_set_size = rho_set_count
import random
intersecting_genes_length_list = []
for i in range(1000):
    print("run ",i)
    test_gene_list = random.sample(busco_gene_list, rho_set_size)
    # print(len(test_gene_list), len(set(test_gene_list)))
    # assert False
    intersecting_genes = []
    for gene_name in test_gene_list:
        try:
            chromosome,start,end = gene_loc_dic[gene_name]
        except:
            print(gene_name, "missing")
            pass
        # print(chromosome,start,end)
        try:
            for sections in (fst_dictionary[chromosome]):
                # print(sections)
                if ((int(start) >= sections[0] and int(start) <= sections[1]) or (int(end) >= sections[0] and int(end) <= sections[1])) or ((sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))):
                    # print(sections)
                    # print(gene_name,chromosome,start,end)
                    intersecting_genes.append(gene_name)
                    break
                    # elif (sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))
                # break
        except:
            pass
    intersecting_genes_length_list.append(len(intersecting_genes))
print((intersecting_genes_length_list))
# Out:
# run  0
# 14521at7088 missing
# run  1
# 10387at7088 missing
# 4967at7088 missing
# 14521at7088 missing
# 14179at7088 missing
# 7506at7088 missing
# 1504at7088 missing
# run  2
# 9544at7088 missing
# 14521at7088 missing
# run  3
# 11558at7088 missing
# run  4
# 9544at7088 missing
# 13972at7088 missing
# 16088at7088 missing
# 13532at7088 missing
# run  5
# 7400at7088 missing
# 10319at7088 missing
# 13532at7088 missing
# 8811at7088 missing
# 10333at7088 missing
# 10546at7088 missing
# 15939at7088 missing
# run  6
# 10319at7088 missing
# 11066at7088 missing
# 12834at7088 missing
# 15939at7088 missing
# run  7
# 5251at7088 missing
# 6083at7088 missing
# 12660at7088 missing
# run  8
# 3161at7088 missing
# 9544at7088 missing
# run  9
# 5251at7088 missing
# 7506at7088 missing
# 11558at7088 missing
# 11264at7088 missing
# 7357at7088 missing
# 14179at7088 missing
# run  10
# 4967at7088 missing
# run  11
# 3212at7088 missing
# 5251at7088 missing
# 12660at7088 missing
# 4645at7088 missing
# 8001at7088 missing
# 1504at7088 missing
# run  12
# 10333at7088 missing
# 11264at7088 missing
# run  13
# 8001at7088 missing
# 10333at7088 missing
# 4967at7088 missing
# run  14
# 10333at7088 missing
# 3212at7088 missing
# 7400at7088 missing
# 1504at7088 missing
# 13532at7088 missing
# run  15
# 13972at7088 missing
# 8001at7088 missing
# 10319at7088 missing
# 3161at7088 missing
# 7506at7088 missing
# run  16
# 8001at7088 missing
# 15939at7088 missing
# run  17
# 3212at7088 missing
# 4967at7088 missing
# 1504at7088 missing
# run  18
# 3212at7088 missing
# 8811at7088 missing
# 3161at7088 missing
# 4118at7088 missing
# run  19
# 12834at7088 missing
# 13972at7088 missing
# 16088at7088 missing
# 11264at7088 missing
# 14521at7088 missing
# run  20
# 1504at7088 missing
# 9108at7088 missing
# 16513at7088 missing
# run  21
# 4645at7088 missing
# 13972at7088 missing
# 10333at7088 missing
# 8811at7088 missing
# 11066at7088 missing
# 9108at7088 missing
# run  22
# 13972at7088 missing
# 14404at7088 missing
# 4118at7088 missing
# 4967at7088 missing
# 8001at7088 missing
# run  23
# 8811at7088 missing
# 12632at7088 missing
# 4967at7088 missing
# 11558at7088 missing
# 4645at7088 missing
# run  24
# 8001at7088 missing
# 10319at7088 missing
# 16088at7088 missing
# run  25
# 6083at7088 missing
# 3212at7088 missing
# 1504at7088 missing
# 14404at7088 missing
# run  26
# 1504at7088 missing
# 12834at7088 missing
# 3161at7088 missing
# run  27
# 12834at7088 missing
# 10546at7088 missing
# 11558at7088 missing
# 10387at7088 missing
# 3212at7088 missing
# 9108at7088 missing
# 14404at7088 missing
# 7357at7088 missing
# 8001at7088 missing
# 4645at7088 missing
# 15939at7088 missing
# run  28
# 11066at7088 missing
# 15939at7088 missing
# 12834at7088 missing
# 10319at7088 missing
# 10387at7088 missing
# 16088at7088 missing
# run  29
# 16088at7088 missing
# 12632at7088 missing
# 13972at7088 missing
# 7357at7088 missing
# run  30
# 3161at7088 missing
# 13972at7088 missing
# 8001at7088 missing
# 11558at7088 missing
# 15939at7088 missing
# 3212at7088 missing
# 16088at7088 missing
# run  31
# 15939at7088 missing
# 13532at7088 missing
# 10387at7088 missing
# run  32
# 10546at7088 missing
# 3161at7088 missing
# 8811at7088 missing
# run  33
# 16513at7088 missing
# 11264at7088 missing
# 14521at7088 missing
# 12834at7088 missing
# 11558at7088 missing
# run  34
# 11264at7088 missing
# 4967at7088 missing
# 10387at7088 missing
# 12834at7088 missing
# run  35
# 4118at7088 missing
# 12632at7088 missing
# 11264at7088 missing
# 1504at7088 missing
# 10387at7088 missing
# run  36
# 13532at7088 missing
# 8811at7088 missing
# 13972at7088 missing
# 9544at7088 missing
# run  37
# 11558at7088 missing
# 12834at7088 missing
# run  38
# 7506at7088 missing
# 11066at7088 missing
# 3161at7088 missing
# run  39
# 10546at7088 missing
# run  40
# 10319at7088 missing
# 12632at7088 missing
# 4645at7088 missing
# run  41
# 3212at7088 missing
# run  42
# 10546at7088 missing
# 4645at7088 missing
# 3212at7088 missing
# run  43
# 7400at7088 missing
# 4645at7088 missing
# 11264at7088 missing
# 1504at7088 missing
# run  44
# 13972at7088 missing
# 16513at7088 missing
# 5251at7088 missing
# 12660at7088 missing
# run  45
# 14179at7088 missing
# 16513at7088 missing
# 5251at7088 missing
# 9544at7088 missing
# 12660at7088 missing
# 3161at7088 missing
# 10333at7088 missing
# run  46
# 14521at7088 missing
# 13532at7088 missing
# run  47
# 12834at7088 missing
# 7400at7088 missing
# 16088at7088 missing
# 15939at7088 missing
# run  48
# 16088at7088 missing
# 7357at7088 missing
# 8811at7088 missing
# run  49
# 13972at7088 missing
# run  50
# 6083at7088 missing
# 3161at7088 missing
# run  51
# 11264at7088 missing
# 10319at7088 missing
# 7400at7088 missing
# 16513at7088 missing
# 5251at7088 missing
# 16088at7088 missing
# 10387at7088 missing
# 12834at7088 missing
# run  52
# 6083at7088 missing
# 5251at7088 missing
# 4645at7088 missing
# 8001at7088 missing
# run  53
# 1504at7088 missing
# 14404at7088 missing
# 11558at7088 missing
# 7506at7088 missing
# 4645at7088 missing
# run  54
# 6083at7088 missing
# 9544at7088 missing
# 8811at7088 missing
# run  55
# 11558at7088 missing
# 8001at7088 missing
# run  56
# 11558at7088 missing
# 9108at7088 missing
# 7506at7088 missing
# run  57
# 11066at7088 missing
# 1504at7088 missing
# 16513at7088 missing
# 10546at7088 missing
# 9544at7088 missing
# run  58
# 10546at7088 missing
# 10333at7088 missing
# 14404at7088 missing
# run  59
# 16513at7088 missing
# 14404at7088 missing
# run  60
# 12834at7088 missing
# 7400at7088 missing
# 4967at7088 missing
# 10387at7088 missing
# run  61
# 12660at7088 missing
# 6083at7088 missing
# 13972at7088 missing
# run  62
# 10319at7088 missing
# 3212at7088 missing
# 12660at7088 missing
# 7357at7088 missing
# 16513at7088 missing
# 9108at7088 missing
# run  63
# 13532at7088 missing
# 7357at7088 missing
# run  64
# 11264at7088 missing
# run  65
# 12660at7088 missing
# 10319at7088 missing
# 15939at7088 missing
# 7400at7088 missing
# 11264at7088 missing
# 8811at7088 missing
# 11558at7088 missing
# 4645at7088 missing
# 3212at7088 missing
# run  66
# 9544at7088 missing
# 4645at7088 missing
# 16513at7088 missing
# 7357at7088 missing
# run  67
# 5251at7088 missing
# 13532at7088 missing
# 10387at7088 missing
# run  68
# 7506at7088 missing
# 10546at7088 missing
# 5251at7088 missing
# run  69
# 16088at7088 missing
# 12834at7088 missing
# 11558at7088 missing
# 4118at7088 missing
# 3212at7088 missing
# run  70
# 9108at7088 missing
# 11066at7088 missing
# 14404at7088 missing
# run  71
# 11066at7088 missing
# 3493at7088 missing
# 9544at7088 missing
# 3161at7088 missing
# run  72
# 8811at7088 missing
# 4645at7088 missing
# 3212at7088 missing
# 9544at7088 missing
# 10319at7088 missing
# 4967at7088 missing
# run  73
# 3161at7088 missing
# 10546at7088 missing
# run  74
# 8811at7088 missing
# 7357at7088 missing
# 12660at7088 missing
# run  75
# 9544at7088 missing
# 14404at7088 missing
# 11558at7088 missing
# 8811at7088 missing
# run  76
# 10333at7088 missing
# 8811at7088 missing
# 7506at7088 missing
# 9108at7088 missing
# 10546at7088 missing
# 16088at7088 missing
# run  77
# 10333at7088 missing
# 11066at7088 missing
# 11264at7088 missing
# 9544at7088 missing
# 4118at7088 missing
# 7506at7088 missing
# run  78
# 7506at7088 missing
# 11264at7088 missing
# 7357at7088 missing
# 14404at7088 missing
# 13532at7088 missing
# run  79
# 3493at7088 missing
# 1504at7088 missing
# run  80
# 4118at7088 missing
# 13532at7088 missing
# 14404at7088 missing
# 7506at7088 missing
# 6083at7088 missing
# 14521at7088 missing
# run  81
# 14521at7088 missing
# 7400at7088 missing
# run  82
# 14179at7088 missing
# 9544at7088 missing
# 13532at7088 missing
# 9108at7088 missing
# 16088at7088 missing
# 3212at7088 missing
# run  83
# 12632at7088 missing
# 12660at7088 missing
# 13972at7088 missing
# 9544at7088 missing
# 4118at7088 missing
# 10387at7088 missing
# run  84
# 4967at7088 missing
# 7357at7088 missing
# 12660at7088 missing
# 9544at7088 missing
# run  85
# 12834at7088 missing
# 12632at7088 missing
# 15939at7088 missing
# 16513at7088 missing
# 14521at7088 missing
# 10319at7088 missing
# run  86
# 10546at7088 missing
# run  87
# 11264at7088 missing
# 3161at7088 missing
# 12632at7088 missing
# run  88
# 3212at7088 missing
# 7400at7088 missing
# 16513at7088 missing
# 11558at7088 missing
# run  89
# 3212at7088 missing
# 9544at7088 missing
# 4967at7088 missing
# 14521at7088 missing
# 13532at7088 missing
# 11066at7088 missing
# 9108at7088 missing
# 15939at7088 missing
# run  90
# 13532at7088 missing
# 1504at7088 missing
# 3212at7088 missing
# 9544at7088 missing
# run  91
# 3161at7088 missing
# 5251at7088 missing
# 12834at7088 missing
# run  92
# 3161at7088 missing
# 8001at7088 missing
# 14521at7088 missing
# 6083at7088 missing
# run  93
# 10319at7088 missing
# 3493at7088 missing
# 3161at7088 missing
# run  94
# 12660at7088 missing
# 14404at7088 missing
# 7400at7088 missing
# run  95
# 10333at7088 missing
# 10546at7088 missing
# 4967at7088 missing
# run  96
# 1504at7088 missing
# 10546at7088 missing
# 11558at7088 missing
# 8001at7088 missing
# run  97
# 6083at7088 missing
# 11066at7088 missing
# run  98
# 11558at7088 missing
# 10546at7088 missing
# 12632at7088 missing
# 16513at7088 missing
# 4118at7088 missing
# 4967at7088 missing
# run  99
# 3493at7088 missing
# 8811at7088 missing
# 10319at7088 missing
# 13532at7088 missing
# run  100
# 11558at7088 missing
# 9108at7088 missing
# 13972at7088 missing
# run  101
# 16513at7088 missing
# 16088at7088 missing
# run  102
# 13532at7088 missing
# 9108at7088 missing
# run  103
# run  104
# 4645at7088 missing
# 9108at7088 missing
# 13532at7088 missing
# 10333at7088 missing
# 16513at7088 missing
# run  105
# 10333at7088 missing
# 16088at7088 missing
# 14179at7088 missing
# run  106
# 11264at7088 missing
# 3212at7088 missing
# 6083at7088 missing
# run  107
# 14404at7088 missing
# 12632at7088 missing
# 11264at7088 missing
# run  108
# 8811at7088 missing
# 4645at7088 missing
# 9108at7088 missing
# run  109
# 10333at7088 missing
# 16088at7088 missing
# 7357at7088 missing
# 14179at7088 missing
# run  110
# 9108at7088 missing
# 8001at7088 missing
# 3161at7088 missing
# run  111
# 10333at7088 missing
# 9108at7088 missing
# run  112
# 8001at7088 missing
# run  113
# 9544at7088 missing
# 7357at7088 missing
# 3493at7088 missing
# 4118at7088 missing
# run  114
# 12834at7088 missing
# 8001at7088 missing
# 7357at7088 missing
# run  115
# 9108at7088 missing
# 16513at7088 missing
# 5251at7088 missing
# 9544at7088 missing
# 10319at7088 missing
# run  116
# 15939at7088 missing
# 10387at7088 missing
# 16088at7088 missing
# 1504at7088 missing
# 4645at7088 missing
# run  117
# 14179at7088 missing
# 3212at7088 missing
# 3161at7088 missing
# 11558at7088 missing
# run  118
# 4118at7088 missing
# 7506at7088 missing
# 8811at7088 missing
# 10546at7088 missing
# 13972at7088 missing
# run  119
# 10333at7088 missing
# 8811at7088 missing
# run  120
# 7506at7088 missing
# 9544at7088 missing
# 12632at7088 missing
# 14521at7088 missing
# run  121
# 4645at7088 missing
# 15939at7088 missing
# run  122
# 15939at7088 missing
# 4118at7088 missing
# 11558at7088 missing
# 13972at7088 missing
# run  123
# 9544at7088 missing
# 14179at7088 missing
# 1504at7088 missing
# 12834at7088 missing
# 3493at7088 missing
# 7400at7088 missing
# 4645at7088 missing
# 6083at7088 missing
# run  124
# 12660at7088 missing
# 11558at7088 missing
# 16513at7088 missing
# 5251at7088 missing
# 16088at7088 missing
# run  125
# 9108at7088 missing
# 14404at7088 missing
# 7400at7088 missing
# 9544at7088 missing
# 7357at7088 missing
# 10387at7088 missing
# run  126
# 16513at7088 missing
# run  127
# 4967at7088 missing
# 7357at7088 missing
# 5251at7088 missing
# 14521at7088 missing
# 11066at7088 missing
# 7400at7088 missing
# run  128
# 12834at7088 missing
# 14521at7088 missing
# 10546at7088 missing
# run  129
# 11558at7088 missing
# 12632at7088 missing
# run  130
# 15939at7088 missing
# run  131
# 14179at7088 missing
# 16513at7088 missing
# 9544at7088 missing
# run  132
# 9108at7088 missing
# 10546at7088 missing
# 14404at7088 missing
# 16513at7088 missing
# 10387at7088 missing
# run  133
# 15939at7088 missing
# 11066at7088 missing
# 3161at7088 missing
# 16513at7088 missing
# run  134
# 10387at7088 missing
# 6083at7088 missing
# 14404at7088 missing
# 11066at7088 missing
# run  135
# 12834at7088 missing
# 3161at7088 missing
# 7506at7088 missing
# 13972at7088 missing
# run  136
# run  137
# 3493at7088 missing
# 5251at7088 missing
# 12834at7088 missing
# 14521at7088 missing
# 7506at7088 missing
# 12632at7088 missing
# run  138
# 12632at7088 missing
# 3161at7088 missing
# 5251at7088 missing
# 16513at7088 missing
# run  139
# 14404at7088 missing
# 11066at7088 missing
# 3161at7088 missing
# 15939at7088 missing
# 14179at7088 missing
# 13532at7088 missing
# 7357at7088 missing
# run  140
# 11264at7088 missing
# 1504at7088 missing
# 9544at7088 missing
# 10319at7088 missing
# 10546at7088 missing
# 16513at7088 missing
# 15939at7088 missing
# run  141
# 16088at7088 missing
# 15939at7088 missing
# 4118at7088 missing
# 12834at7088 missing
# 7357at7088 missing
# run  142
# 16088at7088 missing
# 8001at7088 missing
# run  143
# 7357at7088 missing
# 12660at7088 missing
# 13972at7088 missing
# 7400at7088 missing
# 7506at7088 missing
# run  144
# 4645at7088 missing
# 16088at7088 missing
# 3493at7088 missing
# run  145
# 1504at7088 missing
# 8001at7088 missing
# 8811at7088 missing
# run  146
# 4118at7088 missing
# run  147
# 11066at7088 missing
# 6083at7088 missing
# 4118at7088 missing
# 1504at7088 missing
# 4967at7088 missing
# run  148
# 11558at7088 missing
# 3161at7088 missing
# 11264at7088 missing
# 4645at7088 missing
# 5251at7088 missing
# 11066at7088 missing
# 10387at7088 missing
# 16088at7088 missing
# run  149
# 4645at7088 missing
# 7400at7088 missing
# 7506at7088 missing
# 10319at7088 missing
# run  150
# 11264at7088 missing
# run  151
# 12660at7088 missing
# 4118at7088 missing
# 3212at7088 missing
# run  152
# 1504at7088 missing
# 12632at7088 missing
# 13972at7088 missing
# 8001at7088 missing
# run  153
# 16088at7088 missing
# 12660at7088 missing
# 13532at7088 missing
# run  154
# 12632at7088 missing
# 13532at7088 missing
# 3161at7088 missing
# run  155
# 11558at7088 missing
# 11264at7088 missing
# run  156
# 4645at7088 missing
# 4118at7088 missing
# 8001at7088 missing
# 13532at7088 missing
# 6083at7088 missing
# run  157
# 3493at7088 missing
# 8001at7088 missing
# 12660at7088 missing
# 4645at7088 missing
# 13972at7088 missing
# 3161at7088 missing
# run  158
# 10546at7088 missing
# 10387at7088 missing
# 16513at7088 missing
# 12632at7088 missing
# run  159
# 15939at7088 missing
# 4118at7088 missing
# 1504at7088 missing
# 7357at7088 missing
# run  160
# 14404at7088 missing
# 8001at7088 missing
# 13972at7088 missing
# 5251at7088 missing
# 10546at7088 missing
# 7357at7088 missing
# run  161
# 13972at7088 missing
# 4645at7088 missing
# 11066at7088 missing
# 6083at7088 missing
# 14521at7088 missing
# run  162
# 11264at7088 missing
# 5251at7088 missing
# 16513at7088 missing
# 16088at7088 missing
# run  163
# 9108at7088 missing
# 10546at7088 missing
# 15939at7088 missing
# 10387at7088 missing
# 11066at7088 missing
# 4645at7088 missing
# 11264at7088 missing
# 3493at7088 missing
# run  164
# 11558at7088 missing
# 10387at7088 missing
# 9544at7088 missing
# 7400at7088 missing
# run  165
# 7400at7088 missing
# 1504at7088 missing
# 11264at7088 missing
# 4118at7088 missing
# run  166
# 10387at7088 missing
# 4645at7088 missing
# 4967at7088 missing
# run  167
# 13972at7088 missing
# 10319at7088 missing
# 14521at7088 missing
# 16513at7088 missing
# 12632at7088 missing
# 12660at7088 missing
# 5251at7088 missing
# run  168
# 10387at7088 missing
# 10319at7088 missing
# 6083at7088 missing
# run  169
# 16088at7088 missing
# 7506at7088 missing
# run  170
# 8001at7088 missing
# 10387at7088 missing
# 4645at7088 missing
# run  171
# 7357at7088 missing
# 14404at7088 missing
# 11558at7088 missing
# run  172
# 10319at7088 missing
# 11264at7088 missing
# 10387at7088 missing
# 6083at7088 missing
# 11066at7088 missing
# run  173
# 10333at7088 missing
# 10546at7088 missing
# run  174
# 5251at7088 missing
# 10319at7088 missing
# 11264at7088 missing
# 3161at7088 missing
# 4118at7088 missing
# run  175
# 14521at7088 missing
# 16513at7088 missing
# 11264at7088 missing
# 7506at7088 missing
# run  176
# 3161at7088 missing
# 8001at7088 missing
# 3493at7088 missing
# 6083at7088 missing
# run  177
# 13972at7088 missing
# 10546at7088 missing
# 7506at7088 missing
# 9544at7088 missing
# 12660at7088 missing
# 7357at7088 missing
# 4967at7088 missing
# run  178
# 15939at7088 missing
# 11558at7088 missing
# 7357at7088 missing
# 9108at7088 missing
# 10333at7088 missing
# 16513at7088 missing
# 7506at7088 missing
# 11066at7088 missing
# 4118at7088 missing
# 14404at7088 missing
# run  179
# 12660at7088 missing
# run  180
# 6083at7088 missing
# 10319at7088 missing
# run  181
# 10319at7088 missing
# 12834at7088 missing
# 8001at7088 missing
# 3493at7088 missing
# 5251at7088 missing
# run  182
# 12834at7088 missing
# 13972at7088 missing
# 4967at7088 missing
# 10333at7088 missing
# run  183
# 14404at7088 missing
# 10319at7088 missing
# 12632at7088 missing
# 8001at7088 missing
# 8811at7088 missing
# run  184
# 6083at7088 missing
# 11558at7088 missing
# run  185
# 3161at7088 missing
# run  186
# 4967at7088 missing
# 10333at7088 missing
# 9108at7088 missing
# 13532at7088 missing
# 16088at7088 missing
# 11264at7088 missing
# 7506at7088 missing
# run  187
# 5251at7088 missing
# 7506at7088 missing
# 7357at7088 missing
# 9108at7088 missing
# 10387at7088 missing
# 14179at7088 missing
# run  188
# 5251at7088 missing
# 14179at7088 missing
# run  189
# 11264at7088 missing
# 14404at7088 missing
# run  190
# 9544at7088 missing
# 14404at7088 missing
# run  191
# 13532at7088 missing
# 16513at7088 missing
# run  192
# 11558at7088 missing
# 15939at7088 missing
# run  193
# 10546at7088 missing
# run  194
# 7506at7088 missing
# 5251at7088 missing
# 9544at7088 missing
# 7400at7088 missing
# 10387at7088 missing
# 4645at7088 missing
# run  195
# 11558at7088 missing
# 14404at7088 missing
# 10387at7088 missing
# run  196
# 14179at7088 missing
# 4967at7088 missing
# 12660at7088 missing
# 3212at7088 missing
# run  197
# 7506at7088 missing
# 3493at7088 missing
# 3161at7088 missing
# 13532at7088 missing
# 1504at7088 missing
# 14404at7088 missing
# 4645at7088 missing
# 15939at7088 missing
# run  198
# 3161at7088 missing
# 7400at7088 missing
# 10546at7088 missing
# run  199
# 15939at7088 missing
# 16513at7088 missing
# 4645at7088 missing
# 14404at7088 missing
# 3493at7088 missing
# run  200
# 14521at7088 missing
# 3212at7088 missing
# 13972at7088 missing
# 13532at7088 missing
# 15939at7088 missing
# run  201
# 10387at7088 missing
# 13972at7088 missing
# run  202
# 14179at7088 missing
# 11558at7088 missing
# 11264at7088 missing
# 6083at7088 missing
# run  203
# 10387at7088 missing
# 4645at7088 missing
# 16088at7088 missing
# 11558at7088 missing
# run  204
# 10319at7088 missing
# 7400at7088 missing
# 16513at7088 missing
# 11066at7088 missing
# 12632at7088 missing
# 13532at7088 missing
# run  205
# 6083at7088 missing
# 4645at7088 missing
# run  206
# 4645at7088 missing
# 10387at7088 missing
# 9108at7088 missing
# 3212at7088 missing
# run  207
# 10546at7088 missing
# 14521at7088 missing
# 4118at7088 missing
# 9108at7088 missing
# run  208
# 1504at7088 missing
# 11066at7088 missing
# run  209
# 13532at7088 missing
# 12834at7088 missing
# 13972at7088 missing
# run  210
# 7357at7088 missing
# 9544at7088 missing
# 14179at7088 missing
# run  211
# 3161at7088 missing
# 11264at7088 missing
# 13972at7088 missing
# 5251at7088 missing
# run  212
# 4118at7088 missing
# 1504at7088 missing
# 8001at7088 missing
# 6083at7088 missing
# 7357at7088 missing
# 3161at7088 missing
# run  213
# 6083at7088 missing
# 10387at7088 missing
# 10546at7088 missing
# 8001at7088 missing
# 4645at7088 missing
# run  214
# 7357at7088 missing
# 4645at7088 missing
# 11066at7088 missing
# 14404at7088 missing
# 7506at7088 missing
# run  215
# 15939at7088 missing
# 7506at7088 missing
# 8811at7088 missing
# 11558at7088 missing
# 6083at7088 missing
# 12834at7088 missing
# run  216
# 5251at7088 missing
# 13972at7088 missing
# 6083at7088 missing
# 3212at7088 missing
# 11558at7088 missing
# run  217
# 12834at7088 missing
# 12632at7088 missing
# 11558at7088 missing
# 8001at7088 missing
# run  218
# 14521at7088 missing
# 7357at7088 missing
# 10387at7088 missing
# 12834at7088 missing
# run  219
# 7400at7088 missing
# 13972at7088 missing
# run  220
# 3493at7088 missing
# 10546at7088 missing
# 16088at7088 missing
# 11066at7088 missing
# run  221
# 12632at7088 missing
# 11066at7088 missing
# 14521at7088 missing
# 4118at7088 missing
# 8811at7088 missing
# run  222
# 14179at7088 missing
# 3493at7088 missing
# 4118at7088 missing
# run  223
# 5251at7088 missing
# 10546at7088 missing
# 4645at7088 missing
# 9544at7088 missing
# 4967at7088 missing
# run  224
# 12632at7088 missing
# 14179at7088 missing
# 3161at7088 missing
# 7506at7088 missing
# run  225
# 6083at7088 missing
# 13972at7088 missing
# 3212at7088 missing
# 9544at7088 missing
# 8811at7088 missing
# 4118at7088 missing
# run  226
# 8811at7088 missing
# 10546at7088 missing
# 7506at7088 missing
# 4967at7088 missing
# 9544at7088 missing
# run  227
# 11264at7088 missing
# 15939at7088 missing
# 1504at7088 missing
# 4645at7088 missing
# run  228
# 8001at7088 missing
# 11066at7088 missing
# 15939at7088 missing
# 6083at7088 missing
# 14521at7088 missing
# run  229
# 13972at7088 missing
# 16088at7088 missing
# 12660at7088 missing
# 9544at7088 missing
# run  230
# 13972at7088 missing
# 12660at7088 missing
# 14404at7088 missing
# run  231
# 6083at7088 missing
# 7357at7088 missing
# 3161at7088 missing
# run  232
# 10546at7088 missing
# 9544at7088 missing
# 16088at7088 missing
# 1504at7088 missing
# 13532at7088 missing
# run  233
# 8001at7088 missing
# 14179at7088 missing
# 3212at7088 missing
# 10387at7088 missing
# 10546at7088 missing
# run  234
# 3493at7088 missing
# 4967at7088 missing
# 6083at7088 missing
# 13532at7088 missing
# 4645at7088 missing
# 12834at7088 missing
# run  235
# 16088at7088 missing
# 4645at7088 missing
# 14404at7088 missing
# 11264at7088 missing
# 10387at7088 missing
# 1504at7088 missing
# run  236
# 10319at7088 missing
# 6083at7088 missing
# 3212at7088 missing
# 13532at7088 missing
# 3493at7088 missing
# 7506at7088 missing
# run  237
# 15939at7088 missing
# 14521at7088 missing
# 11066at7088 missing
# 9544at7088 missing
# run  238
# 14404at7088 missing
# run  239
# 3161at7088 missing
# 14179at7088 missing
# run  240
# 14404at7088 missing
# 12632at7088 missing
# 10546at7088 missing
# run  241
# 9544at7088 missing
# 14179at7088 missing
# 9108at7088 missing
# 3493at7088 missing
# 16513at7088 missing
# 3212at7088 missing
# 10387at7088 missing
# run  242
# 9108at7088 missing
# 14521at7088 missing
# 11066at7088 missing
# 10333at7088 missing
# 4967at7088 missing
# run  243
# 10333at7088 missing
# 4118at7088 missing
# 7357at7088 missing
# 10319at7088 missing
# run  244
# 11264at7088 missing
# 12632at7088 missing
# run  245
# 4967at7088 missing
# 7506at7088 missing
# 12660at7088 missing
# 3212at7088 missing
# 4118at7088 missing
# 13972at7088 missing
# 10319at7088 missing
# run  246
# 4967at7088 missing
# 11558at7088 missing
# run  247
# 1504at7088 missing
# 12660at7088 missing
# 10546at7088 missing
# 10387at7088 missing
# 11264at7088 missing
# run  248
# 11264at7088 missing
# run  249
# 7357at7088 missing
# run  250
# run  251
# 10333at7088 missing
# 9108at7088 missing
# 11066at7088 missing
# 7400at7088 missing
# run  252
# 9544at7088 missing
# 10546at7088 missing
# 10387at7088 missing
# 7506at7088 missing
# 14521at7088 missing
# run  253
# 14179at7088 missing
# 4967at7088 missing
# 15939at7088 missing
# 3212at7088 missing
# run  254
# 11264at7088 missing
# 11558at7088 missing
# 16088at7088 missing
# 13532at7088 missing
# run  255
# 11558at7088 missing
# 13972at7088 missing
# 4118at7088 missing
# 5251at7088 missing
# 12834at7088 missing
# 14404at7088 missing
# run  256
# 9544at7088 missing
# 9108at7088 missing
# 16513at7088 missing
# 13532at7088 missing
# 14179at7088 missing
# run  257
# 7506at7088 missing
# 5251at7088 missing
# 14179at7088 missing
# 7400at7088 missing
# 11558at7088 missing
# 11264at7088 missing
# 4118at7088 missing
# run  258
# 9544at7088 missing
# 6083at7088 missing
# run  259
# 10546at7088 missing
# 12632at7088 missing
# 13972at7088 missing
# 3212at7088 missing
# run  260
# 12660at7088 missing
# run  261
# 7357at7088 missing
# 10319at7088 missing
# 12660at7088 missing
# run  262
# 6083at7088 missing
# 16513at7088 missing
# 12660at7088 missing
# run  263
# 13972at7088 missing
# 4645at7088 missing
# 16088at7088 missing
# 15939at7088 missing
# 4967at7088 missing
# run  264
# 16088at7088 missing
# run  265
# 7400at7088 missing
# 13532at7088 missing
# run  266
# 7357at7088 missing
# 13972at7088 missing
# 14404at7088 missing
# run  267
# 12834at7088 missing
# 9544at7088 missing
# 10333at7088 missing
# run  268
# 4118at7088 missing
# 3161at7088 missing
# 15939at7088 missing
# run  269
# 9108at7088 missing
# 11558at7088 missing
# 11264at7088 missing
# 4118at7088 missing
# 12660at7088 missing
# 10546at7088 missing
# 8811at7088 missing
# 7506at7088 missing
# run  270
# 1504at7088 missing
# 6083at7088 missing
# 10387at7088 missing
# 3212at7088 missing
# run  271
# 13532at7088 missing
# 3212at7088 missing
# 11264at7088 missing
# 11066at7088 missing
# 16513at7088 missing
# run  272
# 14179at7088 missing
# 7506at7088 missing
# 11066at7088 missing
# 8001at7088 missing
# 4645at7088 missing
# run  273
# 7357at7088 missing
# run  274
# 16088at7088 missing
# 9108at7088 missing
# run  275
# 12632at7088 missing
# 6083at7088 missing
# run  276
# 14521at7088 missing
# 4118at7088 missing
# 10546at7088 missing
# run  277
# 10319at7088 missing
# 12660at7088 missing
# 14179at7088 missing
# 16088at7088 missing
# 13972at7088 missing
# 7357at7088 missing
# run  278
# 4967at7088 missing
# 7357at7088 missing
# 4645at7088 missing
# run  279
# 4645at7088 missing
# 4967at7088 missing
# 11558at7088 missing
# run  280
# 13532at7088 missing
# run  281
# 8811at7088 missing
# run  282
# 3161at7088 missing
# 11264at7088 missing
# 10387at7088 missing
# 1504at7088 missing
# 10319at7088 missing
# run  283
# 4118at7088 missing
# 14179at7088 missing
# 3212at7088 missing
# 12632at7088 missing
# run  284
# 3493at7088 missing
# 12632at7088 missing
# 4967at7088 missing
# run  285
# 9544at7088 missing
# 6083at7088 missing
# 8001at7088 missing
# 10387at7088 missing
# run  286
# 11066at7088 missing
# 10333at7088 missing
# run  287
# 15939at7088 missing
# 4118at7088 missing
# 11264at7088 missing
# 10546at7088 missing
# run  288
# 3161at7088 missing
# 10546at7088 missing
# 9544at7088 missing
# 3212at7088 missing
# run  289
# 16088at7088 missing
# 14404at7088 missing
# run  290
# 12632at7088 missing
# 14179at7088 missing
# 11264at7088 missing
# run  291
# 14404at7088 missing
# 1504at7088 missing
# run  292
# 10333at7088 missing
# 16513at7088 missing
# 10546at7088 missing
# 14521at7088 missing
# 4118at7088 missing
# 7400at7088 missing
# 10319at7088 missing
# run  293
# 4967at7088 missing
# 10319at7088 missing
# 14179at7088 missing
# 1504at7088 missing
# 3161at7088 missing
# 14521at7088 missing
# run  294
# 15939at7088 missing
# 3212at7088 missing
# 5251at7088 missing
# 10333at7088 missing
# 12632at7088 missing
# 12660at7088 missing
# 14521at7088 missing
# run  295
# 7506at7088 missing
# 10546at7088 missing
# 8811at7088 missing
# 10333at7088 missing
# run  296
# 15939at7088 missing
# run  297
# 4118at7088 missing
# 6083at7088 missing
# 1504at7088 missing
# 4967at7088 missing
# 3212at7088 missing
# 13972at7088 missing
# run  298
# 16513at7088 missing
# 6083at7088 missing
# 10546at7088 missing
# 9544at7088 missing
# run  299
# 8811at7088 missing
# run  300
# 12834at7088 missing
# 11264at7088 missing
# run  301
# 7400at7088 missing
# 4967at7088 missing
# 7357at7088 missing
# 8001at7088 missing
# run  302
# 3161at7088 missing
# 15939at7088 missing
# 4645at7088 missing
# 4118at7088 missing
# run  303
# 6083at7088 missing
# 8001at7088 missing
# 3161at7088 missing
# 14179at7088 missing
# 4645at7088 missing
# 8811at7088 missing
# run  304
# 10387at7088 missing
# 16088at7088 missing
# 11264at7088 missing
# 13532at7088 missing
# 13972at7088 missing
# 12834at7088 missing
# 11558at7088 missing
# 15939at7088 missing
# run  305
# 8001at7088 missing
# 10333at7088 missing
# 14179at7088 missing
# 10319at7088 missing
# 8811at7088 missing
# 12834at7088 missing
# run  306
# 14404at7088 missing
# 11066at7088 missing
# 7506at7088 missing
# 12632at7088 missing
# 9544at7088 missing
# 8811at7088 missing
# 14179at7088 missing
# run  307
# 5251at7088 missing
# 11264at7088 missing
# 10546at7088 missing
# 7357at7088 missing
# run  308
# 7400at7088 missing
# 4118at7088 missing
# 11558at7088 missing
# 7357at7088 missing
# 3493at7088 missing
# run  309
# 6083at7088 missing
# 9544at7088 missing
# 8001at7088 missing
# 16088at7088 missing
# 12632at7088 missing
# run  310
# 16513at7088 missing
# 8001at7088 missing
# 15939at7088 missing
# run  311
# 4967at7088 missing
# 10387at7088 missing
# 5251at7088 missing
# 10546at7088 missing
# 3212at7088 missing
# run  312
# 4967at7088 missing
# 7400at7088 missing
# 1504at7088 missing
# 15939at7088 missing
# run  313
# 4118at7088 missing
# 12834at7088 missing
# 5251at7088 missing
# 1504at7088 missing
# 10319at7088 missing
# run  314
# 5251at7088 missing
# 11558at7088 missing
# 8811at7088 missing
# run  315
# 7400at7088 missing
# 10546at7088 missing
# 7506at7088 missing
# run  316
# 11066at7088 missing
# 10319at7088 missing
# 3212at7088 missing
# 5251at7088 missing
# run  317
# 7506at7088 missing
# 11558at7088 missing
# run  318
# 9108at7088 missing
# 11558at7088 missing
# 6083at7088 missing
# 4118at7088 missing
# run  319
# 10333at7088 missing
# 9108at7088 missing
# 11264at7088 missing
# 7357at7088 missing
# 1504at7088 missing
# run  320
# 8001at7088 missing
# 9544at7088 missing
# 6083at7088 missing
# 11264at7088 missing
# run  321
# 13972at7088 missing
# 11066at7088 missing
# 15939at7088 missing
# 1504at7088 missing
# run  322
# 9544at7088 missing
# 14521at7088 missing
# 13972at7088 missing
# run  323
# 10333at7088 missing
# 4967at7088 missing
# 7506at7088 missing
# 5251at7088 missing
# 7357at7088 missing
# 10546at7088 missing
# run  324
# 8001at7088 missing
# 10319at7088 missing
# 3212at7088 missing
# run  325
# 14179at7088 missing
# 11066at7088 missing
# 3161at7088 missing
# 10387at7088 missing
# run  326
# 10333at7088 missing
# 12834at7088 missing
# 4967at7088 missing
# 10319at7088 missing
# run  327
# 5251at7088 missing
# 8001at7088 missing
# 6083at7088 missing
# 4645at7088 missing
# run  328
# 1504at7088 missing
# 3493at7088 missing
# 7357at7088 missing
# 14404at7088 missing
# 10319at7088 missing
# run  329
# 14521at7088 missing
# run  330
# 8001at7088 missing
# 8811at7088 missing
# 4645at7088 missing
# 14179at7088 missing
# run  331
# 3161at7088 missing
# 11264at7088 missing
# 13972at7088 missing
# 7400at7088 missing
# 12834at7088 missing
# run  332
# 7357at7088 missing
# 10387at7088 missing
# 10333at7088 missing
# 14521at7088 missing
# run  333
# 9108at7088 missing
# 7400at7088 missing
# 6083at7088 missing
# 11264at7088 missing
# run  334
# 16513at7088 missing
# 9108at7088 missing
# run  335
# 11558at7088 missing
# 8001at7088 missing
# 10333at7088 missing
# 14179at7088 missing
# 8811at7088 missing
# 10319at7088 missing
# run  336
# 12632at7088 missing
# 1504at7088 missing
# 5251at7088 missing
# 6083at7088 missing
# run  337
# 7357at7088 missing
# 11264at7088 missing
# 11066at7088 missing
# run  338
# 12660at7088 missing
# 10319at7088 missing
# 3161at7088 missing
# run  339
# 7357at7088 missing
# 10319at7088 missing
# 16088at7088 missing
# 9108at7088 missing
# 10387at7088 missing
# run  340
# 10333at7088 missing
# 11066at7088 missing
# run  341
# 10387at7088 missing
# 16513at7088 missing
# 13532at7088 missing
# 6083at7088 missing
# 7506at7088 missing
# run  342
# 11066at7088 missing
# 7400at7088 missing
# 8811at7088 missing
# run  343
# 10319at7088 missing
# 9544at7088 missing
# 10546at7088 missing
# 10333at7088 missing
# 16088at7088 missing
# run  344
# 14521at7088 missing
# 4645at7088 missing
# 14404at7088 missing
# 1504at7088 missing
# run  345
# 14521at7088 missing
# 11264at7088 missing
# 12834at7088 missing
# run  346
# 9544at7088 missing
# 4118at7088 missing
# 11264at7088 missing
# 8811at7088 missing
# run  347
# 8001at7088 missing
# 12632at7088 missing
# 3161at7088 missing
# 16513at7088 missing
# 14404at7088 missing
# 13532at7088 missing
# run  348
# 3212at7088 missing
# 10333at7088 missing
# 7400at7088 missing
# 14179at7088 missing
# 11066at7088 missing
# run  349
# 11264at7088 missing
# run  350
# 6083at7088 missing
# 10546at7088 missing
# 3493at7088 missing
# run  351
# 3212at7088 missing
# run  352
# 10387at7088 missing
# 4118at7088 missing
# run  353
# 3161at7088 missing
# 14521at7088 missing
# 7357at7088 missing
# 8001at7088 missing
# run  354
# run  355
# 15939at7088 missing
# 13532at7088 missing
# 4118at7088 missing
# 14521at7088 missing
# 16088at7088 missing
# run  356
# 8001at7088 missing
# 11264at7088 missing
# 3493at7088 missing
# 8811at7088 missing
# 10319at7088 missing
# run  357
# 10319at7088 missing
# 3212at7088 missing
# 11264at7088 missing
# 12834at7088 missing
# 16088at7088 missing
# 4118at7088 missing
# run  358
# 7400at7088 missing
# 3212at7088 missing
# 5251at7088 missing
# 8001at7088 missing
# 4118at7088 missing
# run  359
# run  360
# run  361
# 12660at7088 missing
# 5251at7088 missing
# 3212at7088 missing
# 15939at7088 missing
# run  362
# 14404at7088 missing
# 14521at7088 missing
# 8001at7088 missing
# run  363
# 14521at7088 missing
# 11558at7088 missing
# 15939at7088 missing
# 4118at7088 missing
# 7400at7088 missing
# 13972at7088 missing
# run  364
# 12834at7088 missing
# 7506at7088 missing
# 11264at7088 missing
# 10319at7088 missing
# 12660at7088 missing
# 4645at7088 missing
# run  365
# 6083at7088 missing
# 12660at7088 missing
# run  366
# 4967at7088 missing
# 16513at7088 missing
# 9544at7088 missing
# 5251at7088 missing
# 7357at7088 missing
# run  367
# 13532at7088 missing
# 4967at7088 missing
# 7400at7088 missing
# 12834at7088 missing
# 7506at7088 missing
# 14521at7088 missing
# 10319at7088 missing
# 3161at7088 missing
# run  368
# 3212at7088 missing
# 1504at7088 missing
# 4118at7088 missing
# run  369
# 11264at7088 missing
# run  370
# 14521at7088 missing
# 10387at7088 missing
# 9544at7088 missing
# 12632at7088 missing
# 4967at7088 missing
# run  371
# 14179at7088 missing
# 16088at7088 missing
# run  372
# 13532at7088 missing
# 9108at7088 missing
# run  373
# 12660at7088 missing
# 3161at7088 missing
# 10333at7088 missing
# 11066at7088 missing
# 8001at7088 missing
# run  374
# 12632at7088 missing
# 7400at7088 missing
# 12660at7088 missing
# 3212at7088 missing
# 8811at7088 missing
# run  375
# 10387at7088 missing
# 11558at7088 missing
# 10546at7088 missing
# 4118at7088 missing
# run  376
# 3161at7088 missing
# 14521at7088 missing
# run  377
# 9544at7088 missing
# 14179at7088 missing
# 16088at7088 missing
# 13972at7088 missing
# run  378
# 13532at7088 missing
# 10333at7088 missing
# run  379
# 14179at7088 missing
# 12660at7088 missing
# 11066at7088 missing
# 10333at7088 missing
# 4118at7088 missing
# 8001at7088 missing
# 5251at7088 missing
# 15939at7088 missing
# 12632at7088 missing
# run  380
# 8811at7088 missing
# 14404at7088 missing
# run  381
# 13532at7088 missing
# run  382
# 8001at7088 missing
# 6083at7088 missing
# 3161at7088 missing
# 4645at7088 missing
# 9544at7088 missing
# 10333at7088 missing
# run  383
# 16513at7088 missing
# run  384
# 10546at7088 missing
# 13972at7088 missing
# 1504at7088 missing
# 10319at7088 missing
# run  385
# 14179at7088 missing
# 3161at7088 missing
# 11558at7088 missing
# 10546at7088 missing
# run  386
# 11558at7088 missing
# 7506at7088 missing
# 8811at7088 missing
# 11264at7088 missing
# 4118at7088 missing
# 4967at7088 missing
# 3161at7088 missing
# run  387
# 3493at7088 missing
# 3161at7088 missing
# 14521at7088 missing
# 16088at7088 missing
# 12632at7088 missing
# 8811at7088 missing
# run  388
# 16088at7088 missing
# 3212at7088 missing
# 11264at7088 missing
# 11558at7088 missing
# 3161at7088 missing
# 7400at7088 missing
# 10319at7088 missing
# run  389
# run  390
# 10387at7088 missing
# 13532at7088 missing
# run  391
# 12632at7088 missing
# 8001at7088 missing
# 13972at7088 missing
# run  392
# 16513at7088 missing
# run  393
# 10387at7088 missing
# 7357at7088 missing
# run  394
# 9544at7088 missing
# 16088at7088 missing
# 13532at7088 missing
# 12660at7088 missing
# 16513at7088 missing
# run  395
# 7506at7088 missing
# 8811at7088 missing
# 4118at7088 missing
# 3161at7088 missing
# run  396
# 10546at7088 missing
# 8811at7088 missing
# 10319at7088 missing
# 7506at7088 missing
# 12632at7088 missing
# run  397
# 16513at7088 missing
# 1504at7088 missing
# 7506at7088 missing
# run  398
# 7400at7088 missing
# 5251at7088 missing
# 7357at7088 missing
# 16088at7088 missing
# 4118at7088 missing
# run  399
# 3161at7088 missing
# 8811at7088 missing
# 7506at7088 missing
# run  400
# 4645at7088 missing
# 8001at7088 missing
# 5251at7088 missing
# 13972at7088 missing
# run  401
# 6083at7088 missing
# 7357at7088 missing
# run  402
# 3493at7088 missing
# 11264at7088 missing
# 7357at7088 missing
# run  403
# 6083at7088 missing
# 14404at7088 missing
# 11558at7088 missing
# 3493at7088 missing
# 10387at7088 missing
# 12834at7088 missing
# 13532at7088 missing
# 13972at7088 missing
# run  404
# 14521at7088 missing
# 12660at7088 missing
# 10387at7088 missing
# 1504at7088 missing
# 3161at7088 missing
# run  405
# 14521at7088 missing
# 6083at7088 missing
# 4967at7088 missing
# run  406
# 10387at7088 missing
# 4967at7088 missing
# run  407
# 14179at7088 missing
# 13532at7088 missing
# 9544at7088 missing
# 8811at7088 missing
# run  408
# 15939at7088 missing
# 3493at7088 missing
# run  409
# 12632at7088 missing
# 1504at7088 missing
# 4967at7088 missing
# 8001at7088 missing
# run  410
# 4118at7088 missing
# 13532at7088 missing
# 5251at7088 missing
# run  411
# 4967at7088 missing
# 6083at7088 missing
# 3493at7088 missing
# run  412
# 10387at7088 missing
# 10546at7088 missing
# 16513at7088 missing
# run  413
# 10387at7088 missing
# 3161at7088 missing
# 6083at7088 missing
# 14179at7088 missing
# 11264at7088 missing
# run  414
# 11558at7088 missing
# 7357at7088 missing
# 14521at7088 missing
# 12660at7088 missing
# 10319at7088 missing
# run  415
# 6083at7088 missing
# run  416
# 10387at7088 missing
# 7506at7088 missing
# 7400at7088 missing
# 4118at7088 missing
# 12632at7088 missing
# 6083at7088 missing
# run  417
# 12834at7088 missing
# 12660at7088 missing
# 16088at7088 missing
# 4118at7088 missing
# 7506at7088 missing
# 14521at7088 missing
# 13532at7088 missing
# run  418
# 14404at7088 missing
# 12660at7088 missing
# 9544at7088 missing
# 16513at7088 missing
# 16088at7088 missing
# 1504at7088 missing
# 8001at7088 missing
# run  419
# 3161at7088 missing
# 4967at7088 missing
# 10546at7088 missing
# run  420
# 11264at7088 missing
# 7506at7088 missing
# 15939at7088 missing
# 16088at7088 missing
# run  421
# 5251at7088 missing
# 4967at7088 missing
# run  422
# 7400at7088 missing
# 14521at7088 missing
# 4967at7088 missing
# 11264at7088 missing
# run  423
# 8001at7088 missing
# 7506at7088 missing
# 10319at7088 missing
# run  424
# 15939at7088 missing
# 14404at7088 missing
# 12834at7088 missing
# 14521at7088 missing
# run  425
# 13972at7088 missing
# 10387at7088 missing
# 8811at7088 missing
# 9544at7088 missing
# 14521at7088 missing
# 12632at7088 missing
# 12834at7088 missing
# run  426
# 10333at7088 missing
# 11558at7088 missing
# 16088at7088 missing
# 9544at7088 missing
# run  427
# 16088at7088 missing
# 7357at7088 missing
# run  428
# 6083at7088 missing
# 9544at7088 missing
# 10319at7088 missing
# run  429
# 12660at7088 missing
# 8811at7088 missing
# 13972at7088 missing
# 14179at7088 missing
# run  430
# 3493at7088 missing
# 13972at7088 missing
# 6083at7088 missing
# run  431
# 7400at7088 missing
# 3493at7088 missing
# 10546at7088 missing
# run  432
# 4967at7088 missing
# run  433
# 9544at7088 missing
# 3161at7088 missing
# 16088at7088 missing
# 6083at7088 missing
# run  434
# 7400at7088 missing
# 16088at7088 missing
# 3161at7088 missing
# 10319at7088 missing
# 4967at7088 missing
# 9544at7088 missing
# run  435
# 9108at7088 missing
# 14179at7088 missing
# run  436
# 4118at7088 missing
# 16088at7088 missing
# 12632at7088 missing
# 10387at7088 missing
# run  437
# 10546at7088 missing
# 8001at7088 missing
# 11066at7088 missing
# run  438
# 7400at7088 missing
# 14521at7088 missing
# 11558at7088 missing
# run  439
# 7506at7088 missing
# 6083at7088 missing
# run  440
# 4118at7088 missing
# 16088at7088 missing
# 10319at7088 missing
# 6083at7088 missing
# 16513at7088 missing
# 9108at7088 missing
# 3161at7088 missing
# run  441
# 4118at7088 missing
# 1504at7088 missing
# 8811at7088 missing
# run  442
# 13532at7088 missing
# 1504at7088 missing
# 8001at7088 missing
# run  443
# 14521at7088 missing
# 3212at7088 missing
# 10333at7088 missing
# 16513at7088 missing
# 11264at7088 missing
# run  444
# 12660at7088 missing
# 4118at7088 missing
# 9108at7088 missing
# 11558at7088 missing
# 16513at7088 missing
# 13532at7088 missing
# run  445
# 15939at7088 missing
# 14404at7088 missing
# 5251at7088 missing
# 12660at7088 missing
# 11264at7088 missing
# run  446
# 7506at7088 missing
# 10319at7088 missing
# 6083at7088 missing
# 14179at7088 missing
# 14404at7088 missing
# 16513at7088 missing
# run  447
# 1504at7088 missing
# 10546at7088 missing
# run  448
# 16088at7088 missing
# 4645at7088 missing
# 4967at7088 missing
# 7357at7088 missing
# 13532at7088 missing
# 3212at7088 missing
# 15939at7088 missing
# run  449
# 14521at7088 missing
# run  450
# 3212at7088 missing
# 9544at7088 missing
# 15939at7088 missing
# run  451
# 8811at7088 missing
# run  452
# 10546at7088 missing
# 6083at7088 missing
# 10387at7088 missing
# 12660at7088 missing
# 14521at7088 missing
# run  453
# 3161at7088 missing
# run  454
# 4645at7088 missing
# 11264at7088 missing
# 12660at7088 missing
# 7400at7088 missing
# 5251at7088 missing
# 15939at7088 missing
# 11558at7088 missing
# run  455
# 6083at7088 missing
# 11558at7088 missing
# 12660at7088 missing
# 8001at7088 missing
# run  456
# 11264at7088 missing
# 14521at7088 missing
# 3161at7088 missing
# run  457
# 7506at7088 missing
# 14179at7088 missing
# 16513at7088 missing
# 5251at7088 missing
# run  458
# run  459
# 10546at7088 missing
# run  460
# 11264at7088 missing
# 4645at7088 missing
# 14404at7088 missing
# 13972at7088 missing
# 16513at7088 missing
# 12834at7088 missing
# run  461
# 10319at7088 missing
# 14404at7088 missing
# 3493at7088 missing
# run  462
# 3212at7088 missing
# 12834at7088 missing
# 3493at7088 missing
# 4118at7088 missing
# run  463
# 13972at7088 missing
# 12834at7088 missing
# 10319at7088 missing
# 6083at7088 missing
# run  464
# 5251at7088 missing
# 3493at7088 missing
# 15939at7088 missing
# 14521at7088 missing
# run  465
# 7400at7088 missing
# 12660at7088 missing
# 12834at7088 missing
# 3212at7088 missing
# 4118at7088 missing
# 7506at7088 missing
# 11066at7088 missing
# run  466
# 14521at7088 missing
# 10546at7088 missing
# 10333at7088 missing
# 11264at7088 missing
# 3161at7088 missing
# 12660at7088 missing
# run  467
# 12834at7088 missing
# 1504at7088 missing
# 12660at7088 missing
# 10319at7088 missing
# 11264at7088 missing
# 3161at7088 missing
# run  468
# 7357at7088 missing
# 14521at7088 missing
# 4967at7088 missing
# run  469
# 5251at7088 missing
# 7506at7088 missing
# 16513at7088 missing
# 4645at7088 missing
# run  470
# 11264at7088 missing
# 14179at7088 missing
# 13532at7088 missing
# 9544at7088 missing
# 6083at7088 missing
# run  471
# 7506at7088 missing
# 15939at7088 missing
# 11558at7088 missing
# run  472
# 12632at7088 missing
# 5251at7088 missing
# 8001at7088 missing
# 3161at7088 missing
# 4118at7088 missing
# run  473
# 6083at7088 missing
# 5251at7088 missing
# 3212at7088 missing
# 15939at7088 missing
# run  474
# 10546at7088 missing
# 12632at7088 missing
# 11066at7088 missing
# run  475
# 12660at7088 missing
# 12834at7088 missing
# 10319at7088 missing
# 11264at7088 missing
# run  476
# 6083at7088 missing
# 14404at7088 missing
# 1504at7088 missing
# run  477
# 16513at7088 missing
# 5251at7088 missing
# 12632at7088 missing
# 8001at7088 missing
# run  478
# 10319at7088 missing
# 9108at7088 missing
# run  479
# 7400at7088 missing
# 4645at7088 missing
# run  480
# 6083at7088 missing
# 7506at7088 missing
# 10333at7088 missing
# 11066at7088 missing
# 7400at7088 missing
# 11558at7088 missing
# 4967at7088 missing
# 3212at7088 missing
# run  481
# 7400at7088 missing
# 4645at7088 missing
# run  482
# 10546at7088 missing
# 11066at7088 missing
# 4645at7088 missing
# 3493at7088 missing
# 13972at7088 missing
# run  483
# 16513at7088 missing
# run  484
# 9108at7088 missing
# run  485
# 9108at7088 missing
# 11264at7088 missing
# 15939at7088 missing
# run  486
# 12660at7088 missing
# 8811at7088 missing
# run  487
# 3493at7088 missing
# 13972at7088 missing
# run  488
# 14179at7088 missing
# 4118at7088 missing
# 11264at7088 missing
# 7400at7088 missing
# 4967at7088 missing
# 3161at7088 missing
# run  489
# 10333at7088 missing
# 12660at7088 missing
# 8811at7088 missing
# run  490
# 14404at7088 missing
# 3212at7088 missing
# 4645at7088 missing
# 11066at7088 missing
# run  491
# 3161at7088 missing
# 1504at7088 missing
# run  492
# 3493at7088 missing
# 14179at7088 missing
# run  493
# 13972at7088 missing
# 10333at7088 missing
# 4645at7088 missing
# run  494
# 10319at7088 missing
# 9544at7088 missing
# 16088at7088 missing
# 4645at7088 missing
# 9108at7088 missing
# run  495
# 10387at7088 missing
# 16088at7088 missing
# 11264at7088 missing
# run  496
# 14179at7088 missing
# 9544at7088 missing
# 10333at7088 missing
# 9108at7088 missing
# run  497
# 3212at7088 missing
# 7506at7088 missing
# 9108at7088 missing
# run  498
# 15939at7088 missing
# 8811at7088 missing
# 9108at7088 missing
# 10387at7088 missing
# run  499
# 13972at7088 missing
# 3212at7088 missing
# run  500
# 14179at7088 missing
# 10319at7088 missing
# 6083at7088 missing
# run  501
# 9544at7088 missing
# 7506at7088 missing
# 1504at7088 missing
# 10319at7088 missing
# run  502
# 14521at7088 missing
# 9108at7088 missing
# run  503
# 11264at7088 missing
# 12660at7088 missing
# 14179at7088 missing
# 3493at7088 missing
# 14404at7088 missing
# 16513at7088 missing
# run  504
# 9544at7088 missing
# 10387at7088 missing
# 10546at7088 missing
# 3161at7088 missing
# 16088at7088 missing
# 4118at7088 missing
# run  505
# 9108at7088 missing
# 13972at7088 missing
# run  506
# 11558at7088 missing
# 12660at7088 missing
# 11264at7088 missing
# 14404at7088 missing
# 9544at7088 missing
# run  507
# 4645at7088 missing
# 8811at7088 missing
# 8001at7088 missing
# 7400at7088 missing
# run  508
# 7400at7088 missing
# run  509
# 15939at7088 missing
# 10546at7088 missing
# 12632at7088 missing
# 1504at7088 missing
# run  510
# 14404at7088 missing
# 15939at7088 missing
# 8001at7088 missing
# run  511
# 14179at7088 missing
# 10319at7088 missing
# 10546at7088 missing
# 3161at7088 missing
# run  512
# 9108at7088 missing
# 14404at7088 missing
# 12660at7088 missing
# 4118at7088 missing
# 4967at7088 missing
# run  513
# 10333at7088 missing
# 3493at7088 missing
# 9108at7088 missing
# 16088at7088 missing
# 6083at7088 missing
# 14521at7088 missing
# 10546at7088 missing
# run  514
# 10387at7088 missing
# 12660at7088 missing
# 7400at7088 missing
# 14404at7088 missing
# run  515
# 16513at7088 missing
# 4967at7088 missing
# 4645at7088 missing
# 9544at7088 missing
# 11066at7088 missing
# 12834at7088 missing
# run  516
# 5251at7088 missing
# 8811at7088 missing
# 15939at7088 missing
# 13532at7088 missing
# 12632at7088 missing
# 7400at7088 missing
# run  517
# 8001at7088 missing
# 9544at7088 missing
# 3493at7088 missing
# run  518
# 16088at7088 missing
# 5251at7088 missing
# 8001at7088 missing
# run  519
# 16513at7088 missing
# 4118at7088 missing
# 9108at7088 missing
# run  520
# 3493at7088 missing
# 4118at7088 missing
# 4967at7088 missing
# 1504at7088 missing
# 11264at7088 missing
# 11558at7088 missing
# 3212at7088 missing
# run  521
# 12632at7088 missing
# 8811at7088 missing
# 7400at7088 missing
# 9544at7088 missing
# 9108at7088 missing
# run  522
# 13532at7088 missing
# 4967at7088 missing
# 7506at7088 missing
# 8811at7088 missing
# 11558at7088 missing
# 16513at7088 missing
# 10546at7088 missing
# run  523
# 7357at7088 missing
# 6083at7088 missing
# 14404at7088 missing
# 1504at7088 missing
# run  524
# 16513at7088 missing
# 7506at7088 missing
# 6083at7088 missing
# 4645at7088 missing
# run  525
# 13532at7088 missing
# 14521at7088 missing
# 4118at7088 missing
# run  526
# 3212at7088 missing
# 10333at7088 missing
# run  527
# 7400at7088 missing
# 8001at7088 missing
# 5251at7088 missing
# 10546at7088 missing
# 9544at7088 missing
# run  528
# 11066at7088 missing
# 8001at7088 missing
# 10546at7088 missing
# 7400at7088 missing
# run  529
# 15939at7088 missing
# 10333at7088 missing
# 12660at7088 missing
# run  530
# 3212at7088 missing
# 16513at7088 missing
# 4967at7088 missing
# 14179at7088 missing
# run  531
# 12632at7088 missing
# run  532
# 7506at7088 missing
# 10387at7088 missing
# 6083at7088 missing
# 11066at7088 missing
# run  533
# 15939at7088 missing
# 11066at7088 missing
# run  534
# 14521at7088 missing
# 3161at7088 missing
# 16513at7088 missing
# 7400at7088 missing
# run  535
# 8811at7088 missing
# 16088at7088 missing
# 10387at7088 missing
# 16513at7088 missing
# 11264at7088 missing
# 10319at7088 missing
# 12660at7088 missing
# run  536
# 10387at7088 missing
# 7506at7088 missing
# 13532at7088 missing
# 12660at7088 missing
# 14404at7088 missing
# 9544at7088 missing
# 8001at7088 missing
# 7400at7088 missing
# run  537
# 12834at7088 missing
# run  538
# 7400at7088 missing
# 1504at7088 missing
# 14404at7088 missing
# 7357at7088 missing
# 11558at7088 missing
# 12660at7088 missing
# 6083at7088 missing
# run  539
# 7506at7088 missing
# 14521at7088 missing
# 6083at7088 missing
# 7400at7088 missing
# 14179at7088 missing
# 3212at7088 missing
# run  540
# 14404at7088 missing
# run  541
# 4645at7088 missing
# run  542
# 12660at7088 missing
# 14179at7088 missing
# 16088at7088 missing
# 15939at7088 missing
# run  543
# 13972at7088 missing
# 7357at7088 missing
# 16088at7088 missing
# 1504at7088 missing
# run  544
# 5251at7088 missing
# 13532at7088 missing
# 12660at7088 missing
# run  545
# 11264at7088 missing
# 16513at7088 missing
# 12660at7088 missing
# 3493at7088 missing
# 14521at7088 missing
# run  546
# 3493at7088 missing
# 7400at7088 missing
# 8001at7088 missing
# 3161at7088 missing
# 12834at7088 missing
# 11066at7088 missing
# 10387at7088 missing
# run  547
# 3212at7088 missing
# run  548
# 7506at7088 missing
# 1504at7088 missing
# 12660at7088 missing
# 8811at7088 missing
# run  549
# 4645at7088 missing
# 16088at7088 missing
# 9544at7088 missing
# 4118at7088 missing
# 15939at7088 missing
# 14521at7088 missing
# 13972at7088 missing
# 16513at7088 missing
# 11264at7088 missing
# 14404at7088 missing
# run  550
# 16513at7088 missing
# 10546at7088 missing
# 10333at7088 missing
# run  551
# 10546at7088 missing
# 13972at7088 missing
# 3493at7088 missing
# run  552
# 11066at7088 missing
# 3493at7088 missing
# 12660at7088 missing
# 9108at7088 missing
# run  553
# 8001at7088 missing
# 1504at7088 missing
# 4645at7088 missing
# 12660at7088 missing
# 10319at7088 missing
# run  554
# 10319at7088 missing
# 9108at7088 missing
# 16513at7088 missing
# run  555
# 14179at7088 missing
# 12834at7088 missing
# run  556
# 10333at7088 missing
# 12834at7088 missing
# 8001at7088 missing
# run  557
# 5251at7088 missing
# 10333at7088 missing
# 16513at7088 missing
# 12632at7088 missing
# 16088at7088 missing
# 13972at7088 missing
# run  558
# 4967at7088 missing
# 7357at7088 missing
# run  559
# 8811at7088 missing
# 5251at7088 missing
# 10546at7088 missing
# run  560
# 16088at7088 missing
# 10319at7088 missing
# 10546at7088 missing
# 15939at7088 missing
# 4118at7088 missing
# run  561
# 10546at7088 missing
# 7400at7088 missing
# 7357at7088 missing
# 12834at7088 missing
# 3212at7088 missing
# run  562
# 14521at7088 missing
# 12834at7088 missing
# 9544at7088 missing
# 14404at7088 missing
# 13972at7088 missing
# run  563
# 8001at7088 missing
# 13972at7088 missing
# 12660at7088 missing
# 8811at7088 missing
# run  564
# 7357at7088 missing
# 7506at7088 missing
# 1504at7088 missing
# 8811at7088 missing
# 3493at7088 missing
# 12834at7088 missing
# 4645at7088 missing
# 11558at7088 missing
# run  565
# 10546at7088 missing
# 10319at7088 missing
# 14179at7088 missing
# run  566
# 8001at7088 missing
# 3493at7088 missing
# 5251at7088 missing
# 12632at7088 missing
# run  567
# 15939at7088 missing
# 14404at7088 missing
# run  568
# 15939at7088 missing
# 9108at7088 missing
# 14404at7088 missing
# run  569
# 4967at7088 missing
# 6083at7088 missing
# 3493at7088 missing
# 8001at7088 missing
# 1504at7088 missing
# run  570
# 12632at7088 missing
# run  571
# 3161at7088 missing
# 14521at7088 missing
# run  572
# 9544at7088 missing
# 14404at7088 missing
# ...
# 10319at7088 missing
# 16088at7088 missing
# 12632at7088 missing
# run  853
# 12834at7088 missing
# 4645at7088 missing
# 7506at7088 missing
# run  854
# 10387at7088 missing
# 4118at7088 missing
# 3161at7088 missing
# 14179at7088 missing
# run  855
# 12660at7088 missing
# 12632at7088 missing
# 10546at7088 missing
# run  856
# 12834at7088 missing
# 7357at7088 missing
# run  857
# 7506at7088 missing
# 15939at7088 missing
# 9544at7088 missing
# run  858
# 8001at7088 missing
# 10387at7088 missing
# 1504at7088 missing
# run  859
# 4645at7088 missing
# 12632at7088 missing
# 12660at7088 missing
# 9544at7088 missing
# 14179at7088 missing
# run  860
# 13532at7088 missing
# 5251at7088 missing
# run  861
# 7357at7088 missing
# 4967at7088 missing
# 10546at7088 missing
# run  862
# 10333at7088 missing
# 8811at7088 missing
# 13532at7088 missing
# 3212at7088 missing
# run  863
# 11066at7088 missing
# run  864
# 10333at7088 missing
# 8001at7088 missing
# 14521at7088 missing
# 10387at7088 missing
# run  865
# 13532at7088 missing
# 12632at7088 missing
# 12834at7088 missing
# 10387at7088 missing
# 8001at7088 missing
# run  866
# 3493at7088 missing
# 11558at7088 missing
# 3161at7088 missing
# 1504at7088 missing
# 4967at7088 missing
# run  867
# 3493at7088 missing
# run  868
# 16513at7088 missing
# 12660at7088 missing
# 10387at7088 missing
# 7357at7088 missing
# 9108at7088 missing
# run  869
# 10546at7088 missing
# 14404at7088 missing
# 16513at7088 missing
# 10387at7088 missing
# 4645at7088 missing
# 4967at7088 missing
# run  870
# 13972at7088 missing
# 6083at7088 missing
# 12632at7088 missing
# 8811at7088 missing
# run  871
# 5251at7088 missing
# 12660at7088 missing
# run  872
# 15939at7088 missing
# run  873
# 9544at7088 missing
# 14404at7088 missing
# 8001at7088 missing
# 13532at7088 missing
# 9108at7088 missing
# run  874
# 12632at7088 missing
# 13532at7088 missing
# 12660at7088 missing
# 13972at7088 missing
# 14521at7088 missing
# 6083at7088 missing
# 9544at7088 missing
# run  875
# 10319at7088 missing
# 12660at7088 missing
# 15939at7088 missing
# 9544at7088 missing
# 10333at7088 missing
# run  876
# 12632at7088 missing
# 11558at7088 missing
# 8811at7088 missing
# 5251at7088 missing
# 11066at7088 missing
# run  877
# 14179at7088 missing
# 5251at7088 missing
# 8811at7088 missing
# 8001at7088 missing
# 3212at7088 missing
# run  878
# 9544at7088 missing
# 3212at7088 missing
# 4967at7088 missing
# 16513at7088 missing
# run  879
# 8001at7088 missing
# 3161at7088 missing
# 11264at7088 missing
# run  880
# 1504at7088 missing
# run  881
# 13972at7088 missing
# 3161at7088 missing
# run  882
# 13972at7088 missing
# 9544at7088 missing
# 16088at7088 missing
# 15939at7088 missing
# 1504at7088 missing
# run  883
# 3493at7088 missing
# 7506at7088 missing
# 14179at7088 missing
# run  884
# 10387at7088 missing
# 4645at7088 missing
# 16088at7088 missing
# 14521at7088 missing
# run  885
# 10319at7088 missing
# 3161at7088 missing
# 12660at7088 missing
# run  886
# 14521at7088 missing
# 3212at7088 missing
# 13532at7088 missing
# run  887
# 14179at7088 missing
# 13972at7088 missing
# 4967at7088 missing
# 3493at7088 missing
# 7357at7088 missing
# run  888
# 6083at7088 missing
# 8811at7088 missing
# 9108at7088 missing
# 10546at7088 missing
# 10333at7088 missing
# run  889
# 6083at7088 missing
# 7506at7088 missing
# run  890
# 16088at7088 missing
# 8001at7088 missing
# 4118at7088 missing
# 13972at7088 missing
# 10333at7088 missing
# run  891
# 15939at7088 missing
# 7357at7088 missing
# run  892
# 4118at7088 missing
# 10319at7088 missing
# 14179at7088 missing
# 15939at7088 missing
# 7357at7088 missing
# run  893
# 4118at7088 missing
# 14179at7088 missing
# 15939at7088 missing
# 12632at7088 missing
# 11066at7088 missing
# run  894
# 4118at7088 missing
# 13972at7088 missing
# 8811at7088 missing
# 3493at7088 missing
# 15939at7088 missing
# run  895
# 12834at7088 missing
# 11264at7088 missing
# 4645at7088 missing
# run  896
# 3212at7088 missing
# run  897
# 1504at7088 missing
# 16513at7088 missing
# run  898
# 1504at7088 missing
# run  899
# 10546at7088 missing
# 13972at7088 missing
# 5251at7088 missing
# 6083at7088 missing
# 10319at7088 missing
# run  900
# 11066at7088 missing
# 9108at7088 missing
# 3212at7088 missing
# run  901
# 12660at7088 missing
# 9544at7088 missing
# 12834at7088 missing
# run  902
# 12632at7088 missing
# 10546at7088 missing
# 10319at7088 missing
# 14179at7088 missing
# 3212at7088 missing
# run  903
# 13972at7088 missing
# 7506at7088 missing
# 8811at7088 missing
# 11066at7088 missing
# 4967at7088 missing
# 3493at7088 missing
# 7400at7088 missing
# 14404at7088 missing
# run  904
# 8001at7088 missing
# 4645at7088 missing
# 7357at7088 missing
# run  905
# 4967at7088 missing
# 8001at7088 missing
# run  906
# 8001at7088 missing
# 16513at7088 missing
# 4967at7088 missing
# 4645at7088 missing
# 16088at7088 missing
# 7357at7088 missing
# 12834at7088 missing
# run  907
# 9108at7088 missing
# 1504at7088 missing
# 7506at7088 missing
# 13532at7088 missing
# run  908
# 7506at7088 missing
# 16088at7088 missing
# 14179at7088 missing
# 8001at7088 missing
# 9108at7088 missing
# 7400at7088 missing
# 11066at7088 missing
# run  909
# 11558at7088 missing
# run  910
# 3493at7088 missing
# 1504at7088 missing
# 16513at7088 missing
# 13532at7088 missing
# run  911
# 6083at7088 missing
# 16088at7088 missing
# 7357at7088 missing
# 8001at7088 missing
# 14404at7088 missing
# 15939at7088 missing
# 9544at7088 missing
# run  912
# 8001at7088 missing
# 1504at7088 missing
# run  913
# 9544at7088 missing
# 11558at7088 missing
# 11264at7088 missing
# 12632at7088 missing
# run  914
# 9544at7088 missing
# run  915
# 16088at7088 missing
# 11558at7088 missing
# 1504at7088 missing
# 3493at7088 missing
# 9544at7088 missing
# run  916
# 3161at7088 missing
# 8811at7088 missing
# 11264at7088 missing
# run  917
# 14521at7088 missing
# 5251at7088 missing
# 12632at7088 missing
# 8001at7088 missing
# run  918
# 12660at7088 missing
# 16513at7088 missing
# 5251at7088 missing
# run  919
# 13532at7088 missing
# 5251at7088 missing
# 4118at7088 missing
# 1504at7088 missing
# 14404at7088 missing
# run  920
# 3493at7088 missing
# 13532at7088 missing
# 3161at7088 missing
# 4118at7088 missing
# 16513at7088 missing
# 7400at7088 missing
# run  921
# 3493at7088 missing
# run  922
# 13532at7088 missing
# 3161at7088 missing
# 5251at7088 missing
# 7400at7088 missing
# 7357at7088 missing
# 1504at7088 missing
# run  923
# 3212at7088 missing
# 15939at7088 missing
# 10333at7088 missing
# 16088at7088 missing
# 8001at7088 missing
# 11066at7088 missing
# run  924
# 14179at7088 missing
# 16513at7088 missing
# 3212at7088 missing
# 7357at7088 missing
# 12660at7088 missing
# 10319at7088 missing
# run  925
# 3493at7088 missing
# 5251at7088 missing
# 3212at7088 missing
# 11066at7088 missing
# 9544at7088 missing
# 6083at7088 missing
# 12834at7088 missing
# 4967at7088 missing
# run  926
# 11264at7088 missing
# 14521at7088 missing
# 12834at7088 missing
# 12660at7088 missing
# 3493at7088 missing
# run  927
# 10387at7088 missing
# 9108at7088 missing
# run  928
# 11066at7088 missing
# 8811at7088 missing
# 10319at7088 missing
# 8001at7088 missing
# run  929
# 9544at7088 missing
# 11066at7088 missing
# 10333at7088 missing
# run  930
# 4118at7088 missing
# 12834at7088 missing
# run  931
# 7400at7088 missing
# 11066at7088 missing
# 14404at7088 missing
# run  932
# 4967at7088 missing
# 8811at7088 missing
# run  933
# 6083at7088 missing
# 4118at7088 missing
# 16513at7088 missing
# run  934
# 13532at7088 missing
# 9108at7088 missing
# 3212at7088 missing
# 3493at7088 missing
# 13972at7088 missing
# run  935
# 13532at7088 missing
# 7357at7088 missing
# 8001at7088 missing
# 6083at7088 missing
# 7506at7088 missing
# 11264at7088 missing
# run  936
# run  937
# 8811at7088 missing
# run  938
# 4118at7088 missing
# 4645at7088 missing
# 10319at7088 missing
# run  939
# run  940
# 10319at7088 missing
# 11558at7088 missing
# 7357at7088 missing
# 8001at7088 missing
# 16513at7088 missing
# run  941
# 8001at7088 missing
# 11558at7088 missing
# run  942
# 5251at7088 missing
# run  943
# 10387at7088 missing
# 9108at7088 missing
# run  944
# 14404at7088 missing
# 4967at7088 missing
# 1504at7088 missing
# 4118at7088 missing
# run  945
# 16088at7088 missing
# 4645at7088 missing
# 10546at7088 missing
# 4118at7088 missing
# run  946
# 14521at7088 missing
# 16513at7088 missing
# 7400at7088 missing
# 8811at7088 missing
# 10319at7088 missing
# run  947
# 13972at7088 missing
# 4645at7088 missing
# run  948
# 14521at7088 missing
# 10546at7088 missing
# run  949
# 13532at7088 missing
# 10546at7088 missing
# 11264at7088 missing
# 15939at7088 missing
# run  950
# 14521at7088 missing
# 5251at7088 missing
# 11264at7088 missing
# 16513at7088 missing
# run  951
# 16513at7088 missing
# 9544at7088 missing
# run  952
# 7357at7088 missing
# 5251at7088 missing
# 1504at7088 missing
# 9108at7088 missing
# 16088at7088 missing
# run  953
# 14404at7088 missing
# run  954
# 13532at7088 missing
# 14521at7088 missing
# 4118at7088 missing
# 16088at7088 missing
# 12660at7088 missing
# run  955
# 4967at7088 missing
# 13972at7088 missing
# 3212at7088 missing
# 10319at7088 missing
# run  956
# 11066at7088 missing
# 12834at7088 missing
# 8001at7088 missing
# 3161at7088 missing
# run  957
# 13532at7088 missing
# 10546at7088 missing
# 15939at7088 missing
# 3212at7088 missing
# run  958
# 15939at7088 missing
# run  959
# 10387at7088 missing
# 4118at7088 missing
# 12660at7088 missing
# 11264at7088 missing
# run  960
# 7357at7088 missing
# 12660at7088 missing
# run  961
# 16088at7088 missing
# 10319at7088 missing
# run  962
# 4118at7088 missing
# 12660at7088 missing
# run  963
# 16513at7088 missing
# 13532at7088 missing
# run  964
# 7400at7088 missing
# 4118at7088 missing
# 16513at7088 missing
# 1504at7088 missing
# run  965
# 3493at7088 missing
# 10319at7088 missing
# 10546at7088 missing
# 15939at7088 missing
# 11264at7088 missing
# 4967at7088 missing
# 7400at7088 missing
# 9108at7088 missing
# 13972at7088 missing
# run  966
# 16088at7088 missing
# 10387at7088 missing
# 9108at7088 missing
# run  967
# 6083at7088 missing
# 15939at7088 missing
# 12632at7088 missing
# 10333at7088 missing
# 10319at7088 missing
# run  968
# 9544at7088 missing
# 16088at7088 missing
# 3212at7088 missing
# 1504at7088 missing
# 14404at7088 missing
# 3161at7088 missing
# run  969
# 4118at7088 missing
# 7357at7088 missing
# 3493at7088 missing
# 12632at7088 missing
# 8001at7088 missing
# 16088at7088 missing
# run  970
# 14179at7088 missing
# 3493at7088 missing
# 13972at7088 missing
# run  971
# 16088at7088 missing
# 10546at7088 missing
# 8001at7088 missing
# 14404at7088 missing
# 13532at7088 missing
# 5251at7088 missing
# run  972
# 4645at7088 missing
# 14521at7088 missing
# 16513at7088 missing
# run  973
# 12632at7088 missing
# 7357at7088 missing
# 12660at7088 missing
# 13972at7088 missing
# run  974
# 8001at7088 missing
# 6083at7088 missing
# 10546at7088 missing
# 4645at7088 missing
# 13972at7088 missing
# run  975
# 12632at7088 missing
# run  976
# 12834at7088 missing
# 10546at7088 missing
# 12632at7088 missing
# 11066at7088 missing
# 10319at7088 missing
# 14179at7088 missing
# run  977
# 4118at7088 missing
# 10333at7088 missing
# 9108at7088 missing
# 10319at7088 missing
# run  978
# 13532at7088 missing
# 14521at7088 missing
# 7506at7088 missing
# 10387at7088 missing
# run  979
# 12660at7088 missing
# 11264at7088 missing
# run  980
# 9544at7088 missing
# 8811at7088 missing
# 14404at7088 missing
# 13532at7088 missing
# run  981
# 3493at7088 missing
# 1504at7088 missing
# 5251at7088 missing
# run  982
# 9108at7088 missing
# 12632at7088 missing
# 11558at7088 missing
# 16088at7088 missing
# 13972at7088 missing
# run  983
# 16088at7088 missing
# 12632at7088 missing
# 4967at7088 missing
# 16513at7088 missing
# 11264at7088 missing
# run  984
# 4118at7088 missing
# 8811at7088 missing
# run  985
# 9108at7088 missing
# 4645at7088 missing
# 12834at7088 missing
# run  986
# 9108at7088 missing
# 5251at7088 missing
# 4967at7088 missing
# 8001at7088 missing
# 16513at7088 missing
# run  987
# 6083at7088 missing
# 14179at7088 missing
# 15939at7088 missing
# run  988
# 12660at7088 missing
# 16513at7088 missing
# 10319at7088 missing
# 12632at7088 missing
# 7357at7088 missing
# run  989
# 10546at7088 missing
# 1504at7088 missing
# run  990
# 4645at7088 missing
# 13972at7088 missing
# 5251at7088 missing
# run  991
# 4118at7088 missing
# 9544at7088 missing
# run  992
# 4118at7088 missing
# 12632at7088 missing
# 8811at7088 missing
# 10387at7088 missing
# run  993
# 10387at7088 missing
# 7357at7088 missing
# 7400at7088 missing
# 3212at7088 missing
# 12660at7088 missing
# 5251at7088 missing
# 14179at7088 missing
# run  994
# 11558at7088 missing
# 12632at7088 missing
# 5251at7088 missing
# 12834at7088 missing
# 1504at7088 missing
# 8001at7088 missing
# run  995
# 7506at7088 missing
# 11264at7088 missing
# 12632at7088 missing
# 14404at7088 missing
# run  996
# 10319at7088 missing
# 4645at7088 missing
# 3493at7088 missing
# 16088at7088 missing
# 11066at7088 missing
# run  997
# 5251at7088 missing
# 10546at7088 missing
# run  998
# 13972at7088 missing
# 14521at7088 missing
# 10387at7088 missing
# 4645at7088 missing
# 7357at7088 missing
# run  999
# 4645at7088 missing
# 12660at7088 missing
# 11066at7088 missing
# 9108at7088 missing
# [70, 75, 90, 93, 77, 68, 93, 98, 78, 99, 84, 72, 80, 74, 85, 84, 71, 90, 79, 73, 71, 69, 94, 82, 85, 81, 77, 77, 58, 69, 78, 73, 87, 74, 71, 65, 95, 77, 69, 71, 79, 72, 77, 70, 71, 73, 81, 88, 62, 77, 70, 68, 73, 83, 64, 80, 61, 80, 72, 82, 66, 67, 73, 85, 90, 85, 86, 89, 77, 85, 69, 69, 76, 80, 88, 70, 86, 71, 84, 82, 82, 72, 84, 83, 71, 84, 81, 81, 80, 85, 86, 80, 74, 67, 72, 78, 73, 72, 73, 73, 75, 61, 83, 71, 61, 74, 71, 79, 76, 71, 78, 67, 92, 79, 63, 88, 70, 69, 87, 72, 74, 70, 78, 79, 66, 85, 85, 79, 83, 77, 75, 73, 71, 86, 85, 71, 81, 63, 73, 69, 78, 75, 77, 85, 71, 76, 76, 72, 89, 100, 73, 92, 80, 80, 65, 100, 71, 65, 76, 82, 84, 69, 64, 88, 75, 88, 85, 85, 74, 83, 78, 78, 86, 67, 85, 94, 91, 62, 75, 79, 77, 87, 77, 77, 83, 88, 72, 69, 94, 76, 73, 63, 70, 77, 67, 85, 90, 84, 77, 66, 72, 72, 79, 86, 72, 69, 74, 71, 86, 74, 80, 71, 85, 85, 73, 89, 73, 82, 75, 73, 68, 81, 70, 81, 86, 87, 77, 72, 91, 71, 75, 77, 83, 69, 79, 76, 73, 68, 79, 90, 76, 67, 74, 87, 75, 78, 76, 70, 65, 78, 83, 81, 72, 69, 73, 88, 90, 77, 91, 73, 79, 78, 71, 71, 78, 73, 85, 84, 76, 74, 78, 68, 81, 72, 74, 71, 80, 60, 66, 79, 69, 76, 78, 87, 79, 81, 70, 79, 89, 67, 74, 91, 74, 76, 72, 88, 75, 68, 69, 72, 74, 89, 81, 82, 86, 90, 56, 75, 90, 76, 74, 72, 80, 69, 67, 84, 74, 82, 74, 63, 80, 97, 76, 84, 83, 75, 78, 80, 80, 81, 95, 76, 81, 90, 87, 68, 61, 68, 69, 75, 85, 74, 78, 80, 83, 81, 58, 76, 78, 69, 95, 81, 66, 80, 72, 64, 71, 98, 78, 79, 74, 60, 83, 58, 80, 86, 78, 66, 81, 68, 73, 71, 73, 67, 84, 87, 81, 66, 70, 85, 74, 66, 81, 66, 75, 77, 57, 85, 69, 85, 63, 62, 80, 74, 107, 63, 81, 70, 66, 60, 82, 96, 79, 67, 84, 74, 67, 64, 83, 64, 78, 79, 67, 79, 72, 82, 73, 72, 73, 71, 93, 98, 81, 74, 87, 72, 80, 69, 83, 77, 94, 81, 91, 78, 80, 79, 85, 65, 72, 84, 94, 88, 78, 89, 67, 73, 77, 79, 75, 77, 78, 74, 91, 81, 75, 72, 66, 80, 75, 80, 75, 77, 71, 71, 73, 77, 75, 88, 76, 65, 64, 83, 87, 77, 77, 75, 70, 83, 64, 72, 93, 69, 82, 86, 68, 72, 83, 81, 85, 77, 59, 83, 78, 71, 79, 63, 75, 92, 68, 72, 67, 79, 96, 75, 68, 76, 69, 75, 78, 83, 80, 70, 78, 72, 78, 78, 73, 91, 78, 73, 78, 88, 78, 78, 68, 74, 66, 89, 80, 85, 87, 81, 71, 79, 92, 89, 89, 68, 85, 75, 58, 83, 75, 57, 64, 83, 66, 77, 96, 72, 65, 85, 64, 70, 99, 65, 78, 78, 78, 75, 77, 89, 83, 87, 84, 81, 80, 75, 73, 70, 67, 86, 61, 78, 78, 74, 83, 71, 70, 71, 78, 86, 84, 80, 62, 83, 64, 84, 86, 72, 87, 74, 102, 79, 67, 87, 74, 69, 72, 75, 78, 70, 73, 79, 80, 83, 81, 83, 92, 97, 78, 75, 85, 68, 68, 74, 72, 60, 66, 61, 71, 87, 71, 72, 86, 86, 72, 62, 68, 75, 90, 82, 83, 75, 83, 72, 90, 69, 75, 76, 79, 83, 78, 78, 75, 80, 77, 71, 81, 72, 84, 68, 71, 72, 89, 69, 87, 94, 87, 77, 76, 91, 80, 77, 67, 78, 79, 97, 81, 73, 94, 77, 77, 81, 83, 92, 81, 70, 74, 70, 91, 84, 81, 83, 70, 90, 74, 80, 84, 78, 82, 81, 81, 84, 71, 85, 70, 55, 74, 71, 82, 79, 76, 80, 68, 77, 74, 65, 78, 76, 91, 81, 83, 79, 89, 68, 75, 66, 68, 65, 78, 93, 72, 66, 77, 77, 74, 78, 82, 69, 69, 72, 81, 78, 82, 76, 70, 77, 69, 78, 67, 58, 82, 70, 79, 83, 70, 85, 77, 63, 94, 80, 87, 94, 90, 75, 71, 80, 74, 68, 87, 82, 78, 73, 75, 69, 89, 76, 68, 79, 74, 80, 69, 74, 79, 74, 74, 80, 79, 92, 77, 83, 78, 78, 75, 86, 61, 81, 72, 76, 78, 76, 65, 75, 76, 77, 83, 78, 68, 76, 70, 78, 82, 80, 75, 92, 86, 68, 96, 78, 80, 66, 76, 69, 86, 89, 66, 79, 65, 79, 76, 78, 72, 69, 87, 73, 73, 71, 71, 78, 81, 73, 73, 62, 74, 81, 76, 87, 87, 85, 80, 74, 84, 93, 84, 76, 70, 76, 75, 77, 76, 73, 70, 81, 73, 84, 71, 71, 86, 85, 77, 82, 76, 72, 79, 75, 88, 85, 97, 71, 73, 75, 87, 63, 73, 79, 87, 83, 87, 83, 82, 64, 67, 76, 73, 64, 76, 81, 67, 77, 77, 78, 75, 76, 69, 81, 75, 85, 73, 77, 84, 81, 69, 70, 74, 81, 79, 74, 81, 63, 80, 78, 69, 69, 89, 78, 85, 75, 79, 74, 76, 80, 88, 73, 76, 75, 81, 86, 68, 73, 74, 90, 78, 82, 84, 87, 82, 72, 89, 81, 69, 77, 82, 66, 89, 79, 70, 81, 87, 75, 82, 85, 67, 76, 79, 79, 91, 69, 71, 66, 85, 76, 90, 67, 78, 86, 80, 78, 69, 87, 72, 84, 77, 70, 75, 84, 89, 90, 75, 69, 77, 89, 64, 87, 78, 66, 70, 84, 78, 77, 81, 79, 78, 95, 70, 82, 65, 77, 84, ...

# %%
# import numpy as np
# # print((intersecting_genes_length_list))
# str_list = ""
# for num in intersecting_genes_length_list:
#     str_list += f"{num}\n"
# with open(f"{location}/4.Intersections_test/10000_runs_5kb.txt", 'w') as out_file:
#     out_file.write(str_list)

# %%
import matplotlib.pyplot as plt

# Sample data
data = intersecting_genes_length_list

# Define bins with size = 1
min_bin = min(data)
max_bin = max(data)
bins = range(min_bin, max_bin + 2)  # +2 to include the last value properly

# Plot
plt.figure(figsize=(20, 20))
plt.hist(data, bins=bins, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Bin Size = 1')
plt.xticks(bins)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Always show details
import scipy.stats as stats

# Updated list of observations
observations = intersecting_genes_length_list

# [7, 7, 4, 7, 10, 2, 7, 10, 5, 10, 1, 0, 5, 4, 6, 7, 6, 9, 5, 1, 8, 7, 2, 10, 7, 9, 3, 11, 9, 0, 9, 5, 5, 2, 0, 12, 3, 6, 4, 2, 9, 5, 3, 2, 8, 2, 0, 6, 6, 1, 12, 3, 1, 3, 8, 12, 8, 0, 6, 4, 0, 7, 2, 7, 10, 2, 7, 3, 3, 1, 13, 8, 11, 8, 1, 6, 3, 0, 6, 5, 7, 2, 2, 7, 0, 11, 7, 9, 10, 8, 2, 4, 8, 7, 0, 3, 5, 0, 4, 8, 6, 4, 8, 1, 3, 5, 6, 6, 6, 0, 4, 6, 4, 2, 4, 4, 5, 10, 10, 0, 5, 3, 1, 7, 5, 2, 0, 0, 3, 0, 7, 8, 10, 6, 3, 4, 2, 8, 8, 0, 7, 5, 0, 7, 6, 5, 1, 0, 9, 7, 1, 13, 2, 10, 3, 9, 9, 5, 1, 5, 6, 7, 1, 2, 10, 8, 7, 1, 7, 6, 9, 5, 0, 11, 0, 0, 6, 2, 1, 1, 1, 6, 4, 9, 8, 4, 5, 9, 4, 15, 9, 0, 2, 0, 1, 3, 10, 3, 9, 3, 4, 2, 1, 7, 4, 1, 1, 5, 3, 4, 14, 0, 0, 5, 5, 8, 7, 0]

# Calculate the proportion of values greater than or equal to 10
value_of_interest = final_gene_number
print(value_of_interest)
count_extreme = sum(x >= value_of_interest for x in observations)
p_value = count_extreme / len(observations)

p_value
# Out:
# 94
# 0.03
