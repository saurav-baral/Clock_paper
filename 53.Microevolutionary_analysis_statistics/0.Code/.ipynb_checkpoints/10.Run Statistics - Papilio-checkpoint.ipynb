# %% [markdown]
# ## Expand Gene identities

# %%
# %reset
import pandas as pd
location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/1.Lasiomatta_megera"

gene_table = pd.read_csv(f"{location}/2.Annotation_busco_prediction/full_table.tsv", sep= "\t")
gene_table
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y
#          Busco_id      Status Sequence  Gene_Start    Gene_End Strand  \
# 0         0at7088    Complete       24   4461569.0   4349795.0      -
# 1         1at7088    Complete        Z   1337207.0   1448954.0      +
# 2         2at7088    Complete        5   9524326.0   9613919.0      +
# 3         3at7088    Complete        8  16889554.0  17031555.0      +
# 4         4at7088    Complete        7   7646229.0   7751605.0      +
# ...           ...         ...      ...         ...         ...    ...
# 5306  16855at7088  Fragmented        6  11334273.0  11335323.0      +
# 5307  16938at7088    Complete       28   5240471.0   5245371.0      +
# 5308  16982at7088    Complete        6  18026995.0  18027492.0      +
# 5309        cycle    Complete        Z  27393173.0  27438198.0      +
# 5310         cry2    Complete        4   9868459.0   9877967.0      +
#
#         Score   Length                                   OrthoDB url  \
# 0     17074.6   8018.0      https://v10-1.orthodb.org/?query=0at7088
# 1      9131.8   4245.0      https://v10-1.orthodb.org/?query=1at7088
# 2     25469.1  14629.0      https://v10-1.orthodb.org/?query=2at7088
# 3     10478.1   5416.0      https://v10-1.orthodb.org/?query=3at7088
# 4     13223.7   6795.0      https://v10-1.orthodb.org/?query=4at7088
# ...       ...      ...                                           ...
# 5306    107.0     66.0  https://v10-1.orthodb.org/?query=16855at7088
# 5307     92.0    102.0  https://v10-1.orthodb.org/?query=16938at7088
# 5308    118.6    111.0  https://v10-1.orthodb.org/?query=16982at7088
# 5309    116.9    120.0  https://v10-1.orthodb.org/?query=16982at7088
# 5310    116.9    120.0  https://v10-1.orthodb.org/?query=16982at7088
#
#                                Description
# 0                           Immunoglobulin
# 1                           Immunoglobulin
# 2          EGF-like calcium-binding domain
# 3                          Spectrin repeat
# 4                          Spectrin repeat
# ...                                    ...
# 5306            AT hook, DNA-binding motif
# 5307  uncharacterized protein LOC111359467
# 5308  uncharacterized protein LOC110991765
# 5309                                 cycle
# 5310                                  cry2
#
# [5311 rows x 10 columns]

# %%
output = "Busco_id\tChromosome\tGene_Start\tGene_End"
for row_details in gene_table.itertuples():
    if not(pd.isna(row_details.Sequence)):
        if row_details.Gene_Start > row_details.Gene_End:
            gene_start = row_details.Gene_End
            gene_end = row_details.Gene_Start
        else:
            gene_start = row_details.Gene_Start
            gene_end = row_details.Gene_End
        try:
            output += f"\n{row_details.Busco_id}\t{row_details.Sequence}\t{int(max(0,gene_start-10000))}\t{int(gene_end+10000)}"
        except:
            print(row_details.Busco_id, gene_end+20000)
            assert False
    # print(row_details)
    # break
with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'w') as out_file:
    out_file.write(output)

# %%
fst_dictionary = {}
with open(f"{location}/1.FST_peaks_from_chris/two_pool_1%_0.154_5kb_merged.fst",'r') as fst_file:
    for fst_lines in fst_file.readlines()[1:]:
        line_split = fst_lines.strip().split(",")
        fst_dictionary.setdefault(line_split[0],[])
        
        fst_dictionary[line_split[0]].append([int(line_split[1]), int(line_split[2])])
        
print(fst_dictionary)
# Out:
# {'1': [[46001, 75000], [949001, 950000], [987001, 988000], [2242001, 2243000], [2505001, 2506000], [2673001, 2674000], [2683001, 2684000], [2790001, 2791000], [3428001, 3430000], [3440001, 3441000], [3645001, 3646000], [4547001, 4548000], [4637001, 4638000], [4643001, 4644000], [4666001, 4667000], [4686001, 4691000], [4711001, 4713000], [4989001, 4990000], [5147001, 5148000], [5161001, 5162000], [5942001, 5944000], [5949001, 5955000], [6140001, 6153000], [6159001, 6167000], [6607001, 6608000], [6855001, 6861000], [6896001, 6897000], [7664001, 7669000], [7847001, 7848000], [7909001, 7910000], [7915001, 7916000], [7937001, 7938000], [7946001, 7953000], [8129001, 8130000], [8221001, 8229000], [8251001, 8252000], [8731001, 8733000], [8904001, 8905000], [9085001, 9086000], [9723001, 9724000], [10017001, 10018000], [10960001, 10961000], [10997001, 10998000], [11570001, 11571000], [12031001, 12032000], [12159001, 12160000], [12212001, 12218000], [12339001, 12340000], [12365001, 12366000], [12654001, 12659000], [12692001, 12693000], [12731001, 12732000], [12792001, 12793000], [12879001, 12883000], [12888001, 12890000], [13180001, 13181000], [13190001, 13191000], [13966001, 13967000], [14555001, 14557000], [15053001, 15054000], [15655001, 15657000], [15753001, 15754000], [15762001, 15771000], [15782001, 15783000], [15822001, 15823000], [15931001, 15932000], [16114001, 16115000], [16715001, 16716000], [18372001, 18381000], [18871001, 18872000], [19243001, 19249000], [19782001, 19785000], [19898001, 19899000], [20610001, 20611000]], '10': [[354001, 355000], [395001, 396000], [751001, 752000], [781001, 782000], [1762001, 1763000], [2363001, 2364000], [2380001, 2381000], [2501001, 2502000], [3480001, 3481000], [3621001, 3626000], [3639001, 3643000], [3653001, 3654000], [3829001, 3830000], [4512001, 4513000], [4860001, 4861000], [5316001, 5317000], [5780001, 5781000], [5793001, 5794000], [5813001, 5819000], [5825001, 5828000], [5866001, 5867000], [5912001, 5913000], [5922001, 5925000], [6366001, 6367000], [6378001, 6379000], [6706001, 6707000], [7519001, 7520000], [7554001, 7555000], [7629001, 7632000], [7722001, 7723000], [8196001, 8197000], [8543001, 8548000], [8555001, 8559000], [8652001, 8653000], [8670001, 8671000], [10034001, 10035000], [10078001, 10083000], [10204001, 10214000], [10219001, 10222000], [10227001, 10228000], [10237001, 10244000], [10265001, 10266000], [10284001, 10285000], [11320001, 11321000], [11337001, 11345000], [11366001, 11367000], [11374001, 11375000], [11383001, 11384000], [11408001, 11418000], [11605001, 11613000], [11705001, 11706000], [11869001, 11870000], [12015001, 12018000], [12030001, 12046000], [12051001, 12053000], [12472001, 12473000], [12485001, 12490000], [12886001, 12887000], [13305001, 13306000], [13932001, 13933000], [14478001, 14479000], [14532001, 14537000], [14722001, 14723000], [14913001, 14916000], [14927001, 14928000], [15314001, 15315000], [15394001, 15395000], [15461001, 15462000], [15472001, 15473000], [15547001, 15548000], [15555001, 15556000], [16245001, 16249000], [16263001, 16264000], [16354001, 16355000], [16368001, 16373000], [16384001, 16385000], [16407001, 16408000], [16461001, 16462000], [16575001, 16576000], [16828001, 16829000], [16877001, 16882000], [16977001, 16978000], [17075001, 17076000], [17120001, 17126000], [17131001, 17134000], [17160001, 17161000], [17310001, 17312000], [17319001, 17320000], [17325001, 17337000], [17359001, 17360000], [17610001, 17611000], [17657001, 17658000], [17707001, 17711000], [17720001, 17721000], [17769001, 17772000], [17844001, 17845000], [17941001, 17942000]], '11': [[1420001, 1421000], [1443001, 1444000], [1920001, 1921000], [2772001, 2773000], [2781001, 2782000], [3000001, 3001000], [3327001, 3328000], [3780001, 3781000], [3830001, 3831000], [3850001, 3851000], [4202001, 4206000], [4932001, 4933000], [5143001, 5144000], [5422001, 5423000], [5485001, 5486000], [5612001, 5613000], [5768001, 5769000], [6825001, 6826000], [7162001, 7163000], [ ...

# %%
gene_loc_dic = {}
with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'r') as gene_loc_file:
    for gene_line in gene_loc_file.readlines()[1:]:
        line_split = gene_line.strip().split("\t")
        gene_loc_dic[line_split[0]] = [line_split[1],line_split[2],line_split[3]]
# print(gene_loc_dic)

# %%
output_rho_set_location = "Gene,Chromosome,Location"
with open(f"{location}/3.Rho_set_genes/Rho_set_gene2.txt", 'r') as rho_set_file:
    for lines in rho_set_file.readlines():
        rho_gene_name = lines.strip().split("\t")[0]
        # print(lines.strip(),gene_loc_dic[lines.strip()])
        # print(rho_gene_name)
        chromosome,start,end = gene_loc_dic[rho_gene_name]
        # print(chromosome,start,end)
        output_rho_set_location +=  f"\n{rho_gene_name},{chromosome},{start}"

# print(output_rho_set_location)
with open(f"{location}/3.Rho_set_genes/Rho_set_location.csv", 'w') as rho_out_file:
    rho_out_file.write(output_rho_set_location)

# %%
intersecting_genes = []
with open(f"{location}/3.Rho_set_genes/rho_set_cluster_randomized.txt", 'r') as rho_set_file:
    for rho_set_count,lines in enumerate(rho_set_file.readlines()):
        rho_gene_name = lines.strip().split("\t")[0]
        # print(lines.strip(),gene_loc_dic[lines.strip()])
        try:
            chromosome,start,end = gene_loc_dic[rho_gene_name]
        except:
            continue
        # print(chromosome,start,end)
        for sections in (fst_dictionary[chromosome]):
            # print(sections)
            if ((int(start) >= sections[0] and int(start) <= sections[1]) or (int(end) >= sections[0] and int(end) <= sections[1])) or ((sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))):
                # print(sections)
                print(lines, end = "")
                intersecting_genes.append(rho_gene_name)
                break
            # elif (sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))
        # break
print("\n",len(intersecting_genes), rho_set_count, len(set((intersecting_genes))))
final_gene_number = len(intersecting_genes)
# Out:
# 7479at7088
# 3833at7088
# 1589at7088
# 13181at7088
# 1362at7088
# 4878at7088
# 6299at7088
# 10898at7088
# 8396at7088
# 15272at7088
# 7064at7088
# 12204at7088
# 4527at7088
# 1117at7088
# 1586at7088
# 599at7088
# 1076at7088
# 11070at7088
# 7053at7088
# 12640at7088
# 11870at7088
# 2166at7088
# 1901at7088
# 11110at7088
# 1488at7088
# 1532at7088
# 1918at7088
# 9374at7088
# 6701at7088
# 2666at7088
# 7699at7088
# 11621at7088
# 4032at7088
# 4108at7088
# 1924at7088
# 849at7088
# 1606at7088
# 5864at7088
# 1154at7088
# 3671at7088
# 8416at7088
# 2470at7088
# 9911at7088
# 5322at7088
# 3424at7088
# 10541at7088
# 10674at7088
# 68at7088
# 2003at7088
# 7988at7088
# 10109at7088
# 4144at7088
# 14443at7088
# 36at7088
# 1956at7088
# 3379at7088
# 7288at7088
# 296at7088
# 9169at7088
# 2994at7088
# 758at7088
# 9144at7088
# 9481at7088
# 780at7088
# 6025at7088
# 4680at7088
# 5858at7088
# 16140at7088
# 7627at7088
# 2834at7088
# 6723at7088
# 3485at7088
# 318at7088
# 2327at7088
# 962at7088
# 6119at7088
# 4877at7088
# 1993at7088
# 84at7088
# 1298at7088
# 5075at7088
# 1544at7088
# 6601at7088
# 5563at7088
# 3032at7088
# 5781at7088
# 2522at7088
# 4477at7088
# 4264at7088
# 2829at7088
# 83at7088
# 2482at7088
# 6427at7088
# 8465at7088
# 12668at7088
# 5168at7088
# 3137at7088
# 3795at7088
# 1441at7088
# 3029at7088
# 246at7088
# 1955at7088
# 7044at7088
# 11240at7088
# 11657at7088
# 4174at7088
# 2418at7088
# 1246at7088
# 2766at7088
# 7176at7088
# 183at7088
# 5078at7088
# 10244at7088
# 1130at7088
# 522at7088
# 7561at7088
# 9914at7088
# 10020at7088
# 1605at7088
# 5051at7088
#
#  120 719 120

# %%
gene_anno_dic = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/2.Two_state/correlation_2_with_annotation.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        gene_name = lines.split(",")[0].split("_")[0][1:]
        anno_name = lines.split(",")[-1].replace('"', '')
        gene_anno_dic[gene_name]= anno_name.strip()

# %%
# instersecting_genes_output = ""
# for intersecting_gene_name in intersecting_genes:
#     if intersecting_gene_name in gene_anno_dic:
#         instersecting_genes_output += gene_anno_dic[intersecting_gene_name] + "\n"
#     else:
#         instersecting_genes_output += intersecting_gene_name + "\n"
# # print(intersecting_genes)
# with open(f"{location}/4.Intersections_test/intersection_set.txt", 'w') as out_file:
#     out_file.write(instersecting_genes_output)
# # print(instersecting_genes_output)

# %%
# instersecting_genes_output = "geneid\n"+"\n".join(set(intersecting_genes))
# with open(f"{location}/4.Intersections_test/1.For GSEA/1.Rho Set/intersection_set.txt", 'w') as out_file:
#     out_file.write(instersecting_genes_output)

# %%
busco_gene_list = []
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/0.Gene_id_list/Busco_gene_id.txt",'r') as busco_gene_list_file:
    for lines in busco_gene_list_file:
        busco_gene_list.append(lines.strip())
print(len(busco_gene_list))
# Out:
# 4564

# %%
rho_set_size = rho_set_count
import random
intersecting_genes_length_list = []
for i in range(1000):
    print("run ",i)
    test_gene_list = random.sample(busco_gene_list, rho_set_size)
    # print(len(test_gene_list), len(set(test_gene_list)))
    # assert False
    intersecting_genes = []
    for gene_name in test_gene_list:
        try:
            chromosome,start,end = gene_loc_dic[gene_name]
        except:
            print(gene_name, "missing")
            pass
        # print(chromosome,start,end)
        try:
            for sections in (fst_dictionary[chromosome]):
                # print(sections)
                if ((int(start) >= sections[0] and int(start) <= sections[1]) or (int(end) >= sections[0] and int(end) <= sections[1])) or ((sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))):
                    # print(sections)
                    # print(gene_name,chromosome,start,end)
                    intersecting_genes.append(gene_name)
                    break
                    # elif (sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))
                # break
        except:
            pass
    intersecting_genes_length_list.append(len(intersecting_genes))
print((intersecting_genes_length_list))
# Out:
# run  0
# 9108at7088 missing
# 14404at7088 missing
# 10333at7088 missing
# 12834at7088 missing
# 5251at7088 missing
# run  1
# 4118at7088 missing
# 10387at7088 missing
# 3161at7088 missing
# 4967at7088 missing
# 5251at7088 missing
# run  2
# 10546at7088 missing
# 10333at7088 missing
# 3161at7088 missing
# 1504at7088 missing
# 11558at7088 missing
# 7357at7088 missing
# 6083at7088 missing
# run  3
# 15939at7088 missing
# 14179at7088 missing
# 6083at7088 missing
# 3161at7088 missing
# 7506at7088 missing
# 7400at7088 missing
# 8811at7088 missing
# 7357at7088 missing
# run  4
# 7400at7088 missing
# 6083at7088 missing
# 10387at7088 missing
# 13532at7088 missing
# 9544at7088 missing
# run  5
# 3212at7088 missing
# 8811at7088 missing
# 10387at7088 missing
# 12632at7088 missing
# 7506at7088 missing
# 11558at7088 missing
# 10546at7088 missing
# 4118at7088 missing
# run  6
# 6083at7088 missing
# 10387at7088 missing
# 11264at7088 missing
# 8001at7088 missing
# 4967at7088 missing
# 13532at7088 missing
# 5251at7088 missing
# 11558at7088 missing
# 11066at7088 missing
# run  7
# 13972at7088 missing
# 10333at7088 missing
# 11066at7088 missing
# 9544at7088 missing
# 3212at7088 missing
# 7357at7088 missing
# 11558at7088 missing
# 14521at7088 missing
# run  8
# 8001at7088 missing
# 7400at7088 missing
# 13532at7088 missing
# 16513at7088 missing
# 12660at7088 missing
# 10333at7088 missing
# run  9
# 12834at7088 missing
# 11264at7088 missing
# 12632at7088 missing
# 8811at7088 missing
# 16088at7088 missing
# 3161at7088 missing
# 8001at7088 missing
# 9544at7088 missing
# 10333at7088 missing
# run  10
# 11558at7088 missing
# 10319at7088 missing
# 14521at7088 missing
# 3212at7088 missing
# 14179at7088 missing
# run  11
# 9544at7088 missing
# 4118at7088 missing
# 13972at7088 missing
# 10333at7088 missing
# 3161at7088 missing
# run  12
# 1504at7088 missing
# 13532at7088 missing
# 9108at7088 missing
# run  13
# 15939at7088 missing
# 4967at7088 missing
# 11066at7088 missing
# 1504at7088 missing
# 9108at7088 missing
# 7400at7088 missing
# run  14
# 1504at7088 missing
# 12632at7088 missing
# 4645at7088 missing
# 13532at7088 missing
# 12660at7088 missing
# 16088at7088 missing
# 10546at7088 missing
# run  15
# 15939at7088 missing
# 3161at7088 missing
# 12660at7088 missing
# run  16
# 14521at7088 missing
# 6083at7088 missing
# 14179at7088 missing
# 11066at7088 missing
# 3161at7088 missing
# 8001at7088 missing
# run  17
# 10333at7088 missing
# 8001at7088 missing
# 8811at7088 missing
# 12632at7088 missing
# 13532at7088 missing
# 16088at7088 missing
# 9108at7088 missing
# run  18
# 4645at7088 missing
# 14404at7088 missing
# run  19
# 10319at7088 missing
# 5251at7088 missing
# 4967at7088 missing
# 14179at7088 missing
# 4118at7088 missing
# 12660at7088 missing
# 12632at7088 missing
# 10333at7088 missing
# run  20
# 3493at7088 missing
# 13972at7088 missing
# 4118at7088 missing
# run  21
# 4967at7088 missing
# 3161at7088 missing
# 11066at7088 missing
# 14179at7088 missing
# 7506at7088 missing
# 10546at7088 missing
# 13532at7088 missing
# run  22
# 3212at7088 missing
# 8001at7088 missing
# 7506at7088 missing
# 10333at7088 missing
# 14179at7088 missing
# run  23
# 12834at7088 missing
# 9108at7088 missing
# 12632at7088 missing
# 13972at7088 missing
# 1504at7088 missing
# 7357at7088 missing
# run  24
# 4967at7088 missing
# 11558at7088 missing
# 10546at7088 missing
# 11066at7088 missing
# 14521at7088 missing
# 9544at7088 missing
# 12632at7088 missing
# run  25
# 7357at7088 missing
# 8811at7088 missing
# 14179at7088 missing
# 10333at7088 missing
# 1504at7088 missing
# run  26
# 12632at7088 missing
# 16088at7088 missing
# 5251at7088 missing
# 3212at7088 missing
# 16513at7088 missing
# run  27
# 13532at7088 missing
# 5251at7088 missing
# 12660at7088 missing
# 6083at7088 missing
# run  28
# 14179at7088 missing
# 10333at7088 missing
# 8001at7088 missing
# 11264at7088 missing
# run  29
# 14404at7088 missing
# 9544at7088 missing
# run  30
# 10319at7088 missing
# 14521at7088 missing
# 6083at7088 missing
# 13532at7088 missing
# 4118at7088 missing
# 15939at7088 missing
# run  31
# 14521at7088 missing
# 16513at7088 missing
# 4967at7088 missing
# 11264at7088 missing
# run  32
# 4645at7088 missing
# 15939at7088 missing
# 12834at7088 missing
# 9544at7088 missing
# 10387at7088 missing
# 10333at7088 missing
# run  33
# 7357at7088 missing
# run  34
# 11066at7088 missing
# 12834at7088 missing
# 12660at7088 missing
# 5251at7088 missing
# 10319at7088 missing
# run  35
# 4645at7088 missing
# 4118at7088 missing
# 8811at7088 missing
# 16513at7088 missing
# 3161at7088 missing
# 13972at7088 missing
# 4967at7088 missing
# run  36
# 7400at7088 missing
# 10387at7088 missing
# 10333at7088 missing
# run  37
# 11066at7088 missing
# 12834at7088 missing
# 15939at7088 missing
# 11264at7088 missing
# run  38
# 4118at7088 missing
# 11264at7088 missing
# 6083at7088 missing
# 9108at7088 missing
# 3161at7088 missing
# run  39
# 15939at7088 missing
# 9544at7088 missing
# 6083at7088 missing
# 12632at7088 missing
# 5251at7088 missing
# 11066at7088 missing
# 3212at7088 missing
# run  40
# 10333at7088 missing
# 4118at7088 missing
# 11264at7088 missing
# 1504at7088 missing
# run  41
# 11558at7088 missing
# 7506at7088 missing
# 15939at7088 missing
# 16088at7088 missing
# run  42
# 1504at7088 missing
# 3212at7088 missing
# 5251at7088 missing
# 13532at7088 missing
# 6083at7088 missing
# run  43
# 8811at7088 missing
# 4967at7088 missing
# 7357at7088 missing
# 9108at7088 missing
# 3493at7088 missing
# 8001at7088 missing
# run  44
# 13972at7088 missing
# 10333at7088 missing
# run  45
# 10387at7088 missing
# 9108at7088 missing
# 7400at7088 missing
# 16088at7088 missing
# run  46
# 8001at7088 missing
# 1504at7088 missing
# 4967at7088 missing
# run  47
# 8811at7088 missing
# 14179at7088 missing
# 4645at7088 missing
# 7357at7088 missing
# 12632at7088 missing
# run  48
# 10319at7088 missing
# 16513at7088 missing
# 14521at7088 missing
# 15939at7088 missing
# 14179at7088 missing
# 4118at7088 missing
# run  49
# 14521at7088 missing
# 3212at7088 missing
# 4118at7088 missing
# 3161at7088 missing
# 11264at7088 missing
# 9108at7088 missing
# run  50
# 14179at7088 missing
# 10387at7088 missing
# 7400at7088 missing
# 12660at7088 missing
# 9108at7088 missing
# 9544at7088 missing
# 3212at7088 missing
# 14404at7088 missing
# 6083at7088 missing
# run  51
# 9544at7088 missing
# 3493at7088 missing
# 16088at7088 missing
# 13532at7088 missing
# run  52
# 14179at7088 missing
# 7357at7088 missing
# 4645at7088 missing
# 12632at7088 missing
# 10333at7088 missing
# 12660at7088 missing
# run  53
# 1504at7088 missing
# 8001at7088 missing
# 12834at7088 missing
# 9544at7088 missing
# run  54
# 10319at7088 missing
# 11066at7088 missing
# 7506at7088 missing
# 4967at7088 missing
# run  55
# 14179at7088 missing
# 15939at7088 missing
# 4118at7088 missing
# 7357at7088 missing
# 9544at7088 missing
# run  56
# 10319at7088 missing
# 6083at7088 missing
# 12834at7088 missing
# 5251at7088 missing
# 13532at7088 missing
# 4118at7088 missing
# 10387at7088 missing
# 7400at7088 missing
# 14521at7088 missing
# run  57
# 10333at7088 missing
# 7400at7088 missing
# 6083at7088 missing
# run  58
# 10387at7088 missing
# 11264at7088 missing
# 12632at7088 missing
# 16088at7088 missing
# run  59
# 9544at7088 missing
# 8811at7088 missing
# 7357at7088 missing
# 10333at7088 missing
# 15939at7088 missing
# 12632at7088 missing
# 3161at7088 missing
# run  60
# 12632at7088 missing
# 4645at7088 missing
# 5251at7088 missing
# run  61
# 12660at7088 missing
# 3493at7088 missing
# 9108at7088 missing
# 10387at7088 missing
# 5251at7088 missing
# 8811at7088 missing
# run  62
# 10319at7088 missing
# 4967at7088 missing
# 12834at7088 missing
# 7357at7088 missing
# 16088at7088 missing
# 10333at7088 missing
# 5251at7088 missing
# 10546at7088 missing
# run  63
# 10387at7088 missing
# 9108at7088 missing
# run  64
# 16088at7088 missing
# 11558at7088 missing
# 14179at7088 missing
# 7357at7088 missing
# run  65
# 8001at7088 missing
# 13972at7088 missing
# run  66
# 9108at7088 missing
# 12834at7088 missing
# 14521at7088 missing
# 1504at7088 missing
# 3212at7088 missing
# 3493at7088 missing
# run  67
# 10546at7088 missing
# 3493at7088 missing
# 15939at7088 missing
# 12632at7088 missing
# 10319at7088 missing
# run  68
# 13972at7088 missing
# 1504at7088 missing
# 12660at7088 missing
# 10319at7088 missing
# 11264at7088 missing
# 4967at7088 missing
# 7400at7088 missing
# run  69
# 14179at7088 missing
# 13972at7088 missing
# 10319at7088 missing
# 11264at7088 missing
# 12660at7088 missing
# 8811at7088 missing
# 11066at7088 missing
# 4967at7088 missing
# run  70
# 12632at7088 missing
# 16513at7088 missing
# 10546at7088 missing
# 9108at7088 missing
# 14179at7088 missing
# 3161at7088 missing
# 7506at7088 missing
# run  71
# 11558at7088 missing
# 14521at7088 missing
# 4645at7088 missing
# 10546at7088 missing
# 4967at7088 missing
# 12660at7088 missing
# run  72
# 8001at7088 missing
# 14521at7088 missing
# 16513at7088 missing
# 15939at7088 missing
# 11558at7088 missing
# 10319at7088 missing
# run  73
# 9544at7088 missing
# 3212at7088 missing
# 14521at7088 missing
# 8811at7088 missing
# 12632at7088 missing
# run  74
# 10387at7088 missing
# 16513at7088 missing
# 14404at7088 missing
# 11066at7088 missing
# 5251at7088 missing
# 10546at7088 missing
# 14521at7088 missing
# 1504at7088 missing
# run  75
# 12660at7088 missing
# 7357at7088 missing
# 5251at7088 missing
# 11066at7088 missing
# 16088at7088 missing
# 10319at7088 missing
# run  76
# 14521at7088 missing
# 12834at7088 missing
# 8811at7088 missing
# 7400at7088 missing
# 5251at7088 missing
# 10387at7088 missing
# 12632at7088 missing
# 8001at7088 missing
# 3212at7088 missing
# run  77
# 4645at7088 missing
# 3161at7088 missing
# 4118at7088 missing
# 14521at7088 missing
# 7357at7088 missing
# 11558at7088 missing
# run  78
# 16513at7088 missing
# 3161at7088 missing
# 3493at7088 missing
# 3212at7088 missing
# 4967at7088 missing
# 12834at7088 missing
# 7400at7088 missing
# 10387at7088 missing
# run  79
# 11558at7088 missing
# 10333at7088 missing
# 15939at7088 missing
# 12632at7088 missing
# 13532at7088 missing
# run  80
# 14179at7088 missing
# 15939at7088 missing
# 10319at7088 missing
# 3212at7088 missing
# 13532at7088 missing
# run  81
# 13972at7088 missing
# 10319at7088 missing
# 15939at7088 missing
# 4118at7088 missing
# run  82
# 12632at7088 missing
# 7357at7088 missing
# 3212at7088 missing
# 10319at7088 missing
# 10333at7088 missing
# run  83
# 4645at7088 missing
# 9108at7088 missing
# 6083at7088 missing
# 14521at7088 missing
# 4118at7088 missing
# 13972at7088 missing
# 12632at7088 missing
# 12834at7088 missing
# 7506at7088 missing
# 11558at7088 missing
# run  84
# 4645at7088 missing
# 9108at7088 missing
# 15939at7088 missing
# 7506at7088 missing
# 14179at7088 missing
# 4118at7088 missing
# 14404at7088 missing
# 16088at7088 missing
# run  85
# 7400at7088 missing
# 8811at7088 missing
# 4967at7088 missing
# 5251at7088 missing
# 13972at7088 missing
# 1504at7088 missing
# 12632at7088 missing
# run  86
# 9544at7088 missing
# 10387at7088 missing
# 11066at7088 missing
# 14179at7088 missing
# 16088at7088 missing
# 4645at7088 missing
# run  87
# 6083at7088 missing
# 16088at7088 missing
# 8001at7088 missing
# 4967at7088 missing
# 13532at7088 missing
# run  88
# 7506at7088 missing
# 4967at7088 missing
# 3161at7088 missing
# run  89
# 11264at7088 missing
# 14179at7088 missing
# 11066at7088 missing
# 10319at7088 missing
# 15939at7088 missing
# run  90
# 9544at7088 missing
# 6083at7088 missing
# 10319at7088 missing
# run  91
# 11264at7088 missing
# 8001at7088 missing
# 10319at7088 missing
# 4118at7088 missing
# 8811at7088 missing
# 9108at7088 missing
# 1504at7088 missing
# 7357at7088 missing
# run  92
# 12632at7088 missing
# 3212at7088 missing
# 12660at7088 missing
# 16513at7088 missing
# 14404at7088 missing
# run  93
# 14404at7088 missing
# 10546at7088 missing
# 3212at7088 missing
# 7357at7088 missing
# run  94
# 13972at7088 missing
# 1504at7088 missing
# 9544at7088 missing
# 3161at7088 missing
# 11558at7088 missing
# 15939at7088 missing
# 3493at7088 missing
# 4645at7088 missing
# run  95
# 6083at7088 missing
# 14521at7088 missing
# 11264at7088 missing
# 10333at7088 missing
# 7400at7088 missing
# 16088at7088 missing
# 5251at7088 missing
# 12660at7088 missing
# 14404at7088 missing
# 16513at7088 missing
# run  96
# 14521at7088 missing
# 12834at7088 missing
# 10546at7088 missing
# 4645at7088 missing
# 11066at7088 missing
# 6083at7088 missing
# run  97
# 14179at7088 missing
# run  98
# 13972at7088 missing
# 7400at7088 missing
# 10319at7088 missing
# 16088at7088 missing
# 14521at7088 missing
# 9544at7088 missing
# 7506at7088 missing
# run  99
# 9544at7088 missing
# 7357at7088 missing
# 11066at7088 missing
# 10546at7088 missing
# 16513at7088 missing
# run  100
# 7357at7088 missing
# 12834at7088 missing
# run  101
# 13972at7088 missing
# 3212at7088 missing
# 5251at7088 missing
# 12632at7088 missing
# 14404at7088 missing
# 14179at7088 missing
# run  102
# 6083at7088 missing
# 3212at7088 missing
# 11066at7088 missing
# 8811at7088 missing
# 13972at7088 missing
# 1504at7088 missing
# 12834at7088 missing
# 7400at7088 missing
# 8001at7088 missing
# 16513at7088 missing
# run  103
# 4118at7088 missing
# 6083at7088 missing
# 15939at7088 missing
# 4967at7088 missing
# 10319at7088 missing
# run  104
# 11264at7088 missing
# 16513at7088 missing
# 14179at7088 missing
# run  105
# 4645at7088 missing
# 16513at7088 missing
# 7400at7088 missing
# 12632at7088 missing
# run  106
# 13972at7088 missing
# 8001at7088 missing
# 11558at7088 missing
# 3212at7088 missing
# 6083at7088 missing
# run  107
# 4967at7088 missing
# 5251at7088 missing
# 15939at7088 missing
# 11264at7088 missing
# 7400at7088 missing
# run  108
# 15939at7088 missing
# 13972at7088 missing
# 13532at7088 missing
# 10387at7088 missing
# 12834at7088 missing
# 10319at7088 missing
# 7400at7088 missing
# run  109
# 3493at7088 missing
# 6083at7088 missing
# 11558at7088 missing
# 12632at7088 missing
# 15939at7088 missing
# run  110
# 15939at7088 missing
# run  111
# 1504at7088 missing
# 11264at7088 missing
# 4645at7088 missing
# 7506at7088 missing
# 13972at7088 missing
# 10319at7088 missing
# 3493at7088 missing
# run  112
# 11264at7088 missing
# 3493at7088 missing
# 4118at7088 missing
# 16088at7088 missing
# 3161at7088 missing
# 13972at7088 missing
# 7506at7088 missing
# run  113
# 4967at7088 missing
# 3493at7088 missing
# 13532at7088 missing
# 11558at7088 missing
# run  114
# 8001at7088 missing
# 7357at7088 missing
# 13532at7088 missing
# run  115
# 3493at7088 missing
# 14521at7088 missing
# 5251at7088 missing
# 14179at7088 missing
# run  116
# 12632at7088 missing
# 14404at7088 missing
# 13532at7088 missing
# run  117
# 11066at7088 missing
# 11264at7088 missing
# 13972at7088 missing
# 9544at7088 missing
# 12834at7088 missing
# 8001at7088 missing
# run  118
# 12834at7088 missing
# 6083at7088 missing
# 14404at7088 missing
# 1504at7088 missing
# run  119
# 7357at7088 missing
# 10319at7088 missing
# 5251at7088 missing
# 14404at7088 missing
# 12660at7088 missing
# run  120
# 5251at7088 missing
# 7400at7088 missing
# 7506at7088 missing
# run  121
# 12660at7088 missing
# 10387at7088 missing
# 7357at7088 missing
# 3212at7088 missing
# run  122
# 4645at7088 missing
# 11558at7088 missing
# 15939at7088 missing
# 8001at7088 missing
# 13972at7088 missing
# 13532at7088 missing
# 12632at7088 missing
# 3161at7088 missing
# run  123
# 1504at7088 missing
# 11558at7088 missing
# 12632at7088 missing
# run  124
# 11558at7088 missing
# 3493at7088 missing
# 5251at7088 missing
# 6083at7088 missing
# 4645at7088 missing
# 3161at7088 missing
# run  125
# 13972at7088 missing
# 12660at7088 missing
# 11558at7088 missing
# run  126
# 15939at7088 missing
# 7357at7088 missing
# 3212at7088 missing
# 1504at7088 missing
# run  127
# 15939at7088 missing
# 16513at7088 missing
# 10333at7088 missing
# 10546at7088 missing
# 4645at7088 missing
# run  128
# 4645at7088 missing
# 4118at7088 missing
# 11558at7088 missing
# 3212at7088 missing
# 14521at7088 missing
# run  129
# 8811at7088 missing
# 11558at7088 missing
# 7357at7088 missing
# 10319at7088 missing
# 16513at7088 missing
# 9544at7088 missing
# 16088at7088 missing
# run  130
# 15939at7088 missing
# 7400at7088 missing
# 7357at7088 missing
# 10333at7088 missing
# 11066at7088 missing
# run  131
# 11558at7088 missing
# 3493at7088 missing
# 13972at7088 missing
# 6083at7088 missing
# run  132
# 11264at7088 missing
# 10546at7088 missing
# 11066at7088 missing
# run  133
# 3493at7088 missing
# 11066at7088 missing
# 9544at7088 missing
# 14404at7088 missing
# 5251at7088 missing
# run  134
# 14404at7088 missing
# 11558at7088 missing
# 4645at7088 missing
# 13532at7088 missing
# 4967at7088 missing
# run  135
# 6083at7088 missing
# 14179at7088 missing
# 7357at7088 missing
# 12660at7088 missing
# run  136
# 6083at7088 missing
# 10319at7088 missing
# 3493at7088 missing
# 4645at7088 missing
# 11264at7088 missing
# 8001at7088 missing
# 7357at7088 missing
# 16088at7088 missing
# run  137
# 9544at7088 missing
# 15939at7088 missing
# 8811at7088 missing
# run  138
# 16513at7088 missing
# 12834at7088 missing
# 5251at7088 missing
# 3161at7088 missing
# 3493at7088 missing
# run  139
# 16513at7088 missing
# 10387at7088 missing
# 11264at7088 missing
# 13532at7088 missing
# 3493at7088 missing
# run  140
# 10387at7088 missing
# 8811at7088 missing
# 13972at7088 missing
# 1504at7088 missing
# run  141
# 11558at7088 missing
# 3212at7088 missing
# 4645at7088 missing
# 11066at7088 missing
# 10387at7088 missing
# run  142
# 13532at7088 missing
# 8001at7088 missing
# 5251at7088 missing
# 10546at7088 missing
# 6083at7088 missing
# 9108at7088 missing
# 3161at7088 missing
# 3493at7088 missing
# run  143
# 10333at7088 missing
# 14521at7088 missing
# 7506at7088 missing
# 11264at7088 missing
# 7400at7088 missing
# run  144
# 1504at7088 missing
# 13972at7088 missing
# 13532at7088 missing
# 7357at7088 missing
# 16513at7088 missing
# 8001at7088 missing
# 10333at7088 missing
# run  145
# 4118at7088 missing
# 7400at7088 missing
# 8811at7088 missing
# 13532at7088 missing
# run  146
# 12632at7088 missing
# 16088at7088 missing
# 7357at7088 missing
# 3212at7088 missing
# 5251at7088 missing
# 11264at7088 missing
# run  147
# 13532at7088 missing
# 10333at7088 missing
# 14179at7088 missing
# 16088at7088 missing
# run  148
# 6083at7088 missing
# 5251at7088 missing
# 14404at7088 missing
# 13972at7088 missing
# 12834at7088 missing
# 7357at7088 missing
# 1504at7088 missing
# 10319at7088 missing
# run  149
# 8001at7088 missing
# 16088at7088 missing
# 14404at7088 missing
# 11558at7088 missing
# run  150
# 12660at7088 missing
# 8001at7088 missing
# 3493at7088 missing
# 8811at7088 missing
# run  151
# 13532at7088 missing
# 10387at7088 missing
# 7506at7088 missing
# 4967at7088 missing
# 12834at7088 missing
# run  152
# 8811at7088 missing
# 16513at7088 missing
# 14521at7088 missing
# 7357at7088 missing
# 8001at7088 missing
# 3161at7088 missing
# 9108at7088 missing
# 4967at7088 missing
# run  153
# 10319at7088 missing
# 12834at7088 missing
# 13972at7088 missing
# 6083at7088 missing
# 7357at7088 missing
# 15939at7088 missing
# 8811at7088 missing
# run  154
# 14521at7088 missing
# 15939at7088 missing
# 11066at7088 missing
# run  155
# 10319at7088 missing
# 14179at7088 missing
# 12632at7088 missing
# 4118at7088 missing
# 7506at7088 missing
# 12834at7088 missing
# run  156
# 12632at7088 missing
# 10546at7088 missing
# 11558at7088 missing
# 7357at7088 missing
# 7400at7088 missing
# 5251at7088 missing
# run  157
# 10387at7088 missing
# 11558at7088 missing
# 14521at7088 missing
# 15939at7088 missing
# 10333at7088 missing
# 4645at7088 missing
# run  158
# 13532at7088 missing
# 5251at7088 missing
# 1504at7088 missing
# 8811at7088 missing
# 7357at7088 missing
# 12660at7088 missing
# 4118at7088 missing
# 7400at7088 missing
# run  159
# 7357at7088 missing
# 9544at7088 missing
# 4645at7088 missing
# run  160
# 3493at7088 missing
# 11264at7088 missing
# 14404at7088 missing
# 14179at7088 missing
# 16088at7088 missing
# 6083at7088 missing
# 9544at7088 missing
# 12660at7088 missing
# run  161
# 10387at7088 missing
# 3161at7088 missing
# 10333at7088 missing
# 7400at7088 missing
# 4118at7088 missing
# run  162
# 9108at7088 missing
# 10546at7088 missing
# 7400at7088 missing
# 13972at7088 missing
# 4967at7088 missing
# run  163
# 11066at7088 missing
# 12660at7088 missing
# 6083at7088 missing
# 8811at7088 missing
# run  164
# 4645at7088 missing
# 15939at7088 missing
# 11264at7088 missing
# 8001at7088 missing
# 13972at7088 missing
# 14179at7088 missing
# 6083at7088 missing
# run  165
# 8811at7088 missing
# 9108at7088 missing
# 13532at7088 missing
# 13972at7088 missing
# 14179at7088 missing
# 12660at7088 missing
# 8001at7088 missing
# 16513at7088 missing
# run  166
# 4967at7088 missing
# 11558at7088 missing
# 7400at7088 missing
# run  167
# 15939at7088 missing
# 13972at7088 missing
# 4118at7088 missing
# 4967at7088 missing
# 16088at7088 missing
# 12834at7088 missing
# 14179at7088 missing
# 3493at7088 missing
# 14521at7088 missing
# 12660at7088 missing
# 13532at7088 missing
# run  168
# 3493at7088 missing
# 6083at7088 missing
# run  169
# 7357at7088 missing
# 4967at7088 missing
# 12660at7088 missing
# 3493at7088 missing
# 11264at7088 missing
# 3212at7088 missing
# 8811at7088 missing
# 9544at7088 missing
# 11558at7088 missing
# run  170
# 1504at7088 missing
# 14404at7088 missing
# 15939at7088 missing
# 14521at7088 missing
# 11066at7088 missing
# 7400at7088 missing
# 4118at7088 missing
# 10333at7088 missing
# run  171
# 5251at7088 missing
# 9544at7088 missing
# 3161at7088 missing
# 16513at7088 missing
# 11066at7088 missing
# run  172
# 12660at7088 missing
# 7506at7088 missing
# 11264at7088 missing
# 16513at7088 missing
# 8001at7088 missing
# 7357at7088 missing
# run  173
# 5251at7088 missing
# 7357at7088 missing
# 9108at7088 missing
# 10333at7088 missing
# 10546at7088 missing
# run  174
# 3161at7088 missing
# 14521at7088 missing
# 11066at7088 missing
# 7400at7088 missing
# 10333at7088 missing
# run  175
# 16088at7088 missing
# 7506at7088 missing
# 1504at7088 missing
# 3212at7088 missing
# 14404at7088 missing
# run  176
# 13532at7088 missing
# 7357at7088 missing
# 12632at7088 missing
# 7400at7088 missing
# 11264at7088 missing
# 14404at7088 missing
# 8811at7088 missing
# run  177
# 4645at7088 missing
# 12660at7088 missing
# 7357at7088 missing
# run  178
# 15939at7088 missing
# 10546at7088 missing
# 16513at7088 missing
# 9108at7088 missing
# 9544at7088 missing
# 16088at7088 missing
# run  179
# 16088at7088 missing
# 3161at7088 missing
# 10387at7088 missing
# run  180
# 12660at7088 missing
# 4118at7088 missing
# 8811at7088 missing
# 14521at7088 missing
# 7506at7088 missing
# 9544at7088 missing
# 15939at7088 missing
# 5251at7088 missing
# 4645at7088 missing
# run  181
# 3212at7088 missing
# 10333at7088 missing
# 3493at7088 missing
# 12834at7088 missing
# run  182
# 9108at7088 missing
# 7506at7088 missing
# 10546at7088 missing
# 9544at7088 missing
# 10387at7088 missing
# 11558at7088 missing
# run  183
# 8811at7088 missing
# 10546at7088 missing
# 12834at7088 missing
# 12632at7088 missing
# run  184
# 13972at7088 missing
# 14404at7088 missing
# 4118at7088 missing
# run  185
# 15939at7088 missing
# 4967at7088 missing
# 12632at7088 missing
# run  186
# 13532at7088 missing
# run  187
# 11264at7088 missing
# 9108at7088 missing
# 7400at7088 missing
# 11066at7088 missing
# run  188
# 6083at7088 missing
# 9108at7088 missing
# run  189
# 8811at7088 missing
# 13972at7088 missing
# 4967at7088 missing
# 10546at7088 missing
# 10319at7088 missing
# 6083at7088 missing
# 12834at7088 missing
# 16088at7088 missing
# run  190
# 7400at7088 missing
# 9108at7088 missing
# 15939at7088 missing
# 7506at7088 missing
# run  191
# 3493at7088 missing
# 7357at7088 missing
# 7400at7088 missing
# 14404at7088 missing
# 1504at7088 missing
# 10333at7088 missing
# 11066at7088 missing
# run  192
# 5251at7088 missing
# 14521at7088 missing
# 3161at7088 missing
# 12834at7088 missing
# 9544at7088 missing
# 15939at7088 missing
# run  193
# 13972at7088 missing
# 10333at7088 missing
# 10319at7088 missing
# 15939at7088 missing
# 6083at7088 missing
# run  194
# 6083at7088 missing
# 5251at7088 missing
# 7506at7088 missing
# 15939at7088 missing
# 12632at7088 missing
# 10387at7088 missing
# run  195
# 11558at7088 missing
# 10387at7088 missing
# run  196
# 16088at7088 missing
# 4118at7088 missing
# 14521at7088 missing
# 12632at7088 missing
# 7506at7088 missing
# run  197
# 7400at7088 missing
# 13972at7088 missing
# 10546at7088 missing
# 8811at7088 missing
# 11264at7088 missing
# 13532at7088 missing
# 3493at7088 missing
# 3161at7088 missing
# run  198
# 12632at7088 missing
# 11558at7088 missing
# 7357at7088 missing
# 14404at7088 missing
# run  199
# 7400at7088 missing
# 16088at7088 missing
# 10387at7088 missing
# 14404at7088 missing
# 7506at7088 missing
# 13532at7088 missing
# 16513at7088 missing
# run  200
# 9108at7088 missing
# 4967at7088 missing
# 13532at7088 missing
# 14521at7088 missing
# 10333at7088 missing
# 3212at7088 missing
# run  201
# 3493at7088 missing
# 10387at7088 missing
# 4118at7088 missing
# 11264at7088 missing
# run  202
# 10387at7088 missing
# 4118at7088 missing
# 14404at7088 missing
# 10546at7088 missing
# 9544at7088 missing
# 1504at7088 missing
# run  203
# 3161at7088 missing
# 14404at7088 missing
# 10333at7088 missing
# 10546at7088 missing
# 16513at7088 missing
# run  204
# 10319at7088 missing
# 8811at7088 missing
# 16088at7088 missing
# 5251at7088 missing
# 4645at7088 missing
# 12632at7088 missing
# run  205
# 11558at7088 missing
# 15939at7088 missing
# 12660at7088 missing
# run  206
# 1504at7088 missing
# 7400at7088 missing
# 5251at7088 missing
# 14521at7088 missing
# 9544at7088 missing
# 14404at7088 missing
# run  207
# 11066at7088 missing
# 10546at7088 missing
# 13972at7088 missing
# 14179at7088 missing
# 9108at7088 missing
# 1504at7088 missing
# run  208
# 9544at7088 missing
# 6083at7088 missing
# 16513at7088 missing
# 13972at7088 missing
# 11558at7088 missing
# 8811at7088 missing
# run  209
# 4118at7088 missing
# 3212at7088 missing
# 11264at7088 missing
# 10319at7088 missing
# 3161at7088 missing
# 10546at7088 missing
# run  210
# 13532at7088 missing
# 12632at7088 missing
# 10333at7088 missing
# 7357at7088 missing
# 13972at7088 missing
# 11066at7088 missing
# 10546at7088 missing
# run  211
# 11066at7088 missing
# 3161at7088 missing
# 3212at7088 missing
# run  212
# 13972at7088 missing
# 16513at7088 missing
# 14521at7088 missing
# 9108at7088 missing
# run  213
# 12660at7088 missing
# 4118at7088 missing
# 7400at7088 missing
# 8001at7088 missing
# 16513at7088 missing
# run  214
# 11264at7088 missing
# 16513at7088 missing
# 3493at7088 missing
# 16088at7088 missing
# run  215
# 10319at7088 missing
# 7400at7088 missing
# run  216
# 9108at7088 missing
# 4967at7088 missing
# 3161at7088 missing
# 3493at7088 missing
# 16088at7088 missing
# 10546at7088 missing
# 14521at7088 missing
# run  217
# 6083at7088 missing
# 4645at7088 missing
# 8001at7088 missing
# run  218
# 4967at7088 missing
# 11558at7088 missing
# 11066at7088 missing
# 5251at7088 missing
# 14179at7088 missing
# run  219
# 3212at7088 missing
# 4118at7088 missing
# 3161at7088 missing
# 10333at7088 missing
# 14404at7088 missing
# 3493at7088 missing
# run  220
# 14521at7088 missing
# 10546at7088 missing
# 16513at7088 missing
# 3161at7088 missing
# 14179at7088 missing
# run  221
# 11264at7088 missing
# 12660at7088 missing
# 10319at7088 missing
# 9544at7088 missing
# 13532at7088 missing
# 7400at7088 missing
# 14404at7088 missing
# 10546at7088 missing
# 6083at7088 missing
# run  222
# 12632at7088 missing
# 16088at7088 missing
# 15939at7088 missing
# 14521at7088 missing
# 10333at7088 missing
# run  223
# 10387at7088 missing
# 10333at7088 missing
# 3493at7088 missing
# 13532at7088 missing
# 14179at7088 missing
# 10319at7088 missing
# run  224
# 10387at7088 missing
# 10333at7088 missing
# 4118at7088 missing
# 3212at7088 missing
# 10546at7088 missing
# 8001at7088 missing
# run  225
# 8811at7088 missing
# 8001at7088 missing
# 10387at7088 missing
# 4967at7088 missing
# 14404at7088 missing
# 11264at7088 missing
# run  226
# 10546at7088 missing
# 4645at7088 missing
# 12660at7088 missing
# 15939at7088 missing
# 16513at7088 missing
# 8001at7088 missing
# run  227
# 4645at7088 missing
# 8811at7088 missing
# 10546at7088 missing
# 10333at7088 missing
# run  228
# 9544at7088 missing
# 3212at7088 missing
# 12660at7088 missing
# 16088at7088 missing
# 12632at7088 missing
# 10387at7088 missing
# run  229
# 11066at7088 missing
# 5251at7088 missing
# 10333at7088 missing
# 16513at7088 missing
# run  230
# 10319at7088 missing
# 9108at7088 missing
# 3212at7088 missing
# 11264at7088 missing
# 1504at7088 missing
# 14404at7088 missing
# run  231
# 12834at7088 missing
# 11066at7088 missing
# 8001at7088 missing
# run  232
# 11558at7088 missing
# 12660at7088 missing
# 1504at7088 missing
# 15939at7088 missing
# 14404at7088 missing
# 12834at7088 missing
# run  233
# 14521at7088 missing
# 13532at7088 missing
# 16088at7088 missing
# 10319at7088 missing
# 16513at7088 missing
# 11558at7088 missing
# run  234
# 10333at7088 missing
# 5251at7088 missing
# 6083at7088 missing
# 4645at7088 missing
# 9108at7088 missing
# 16088at7088 missing
# 12834at7088 missing
# run  235
# 14404at7088 missing
# 9108at7088 missing
# 6083at7088 missing
# run  236
# 3161at7088 missing
# 3493at7088 missing
# 5251at7088 missing
# 15939at7088 missing
# 10319at7088 missing
# 3212at7088 missing
# 13532at7088 missing
# 12834at7088 missing
# run  237
# 9108at7088 missing
# 14404at7088 missing
# 14521at7088 missing
# 7506at7088 missing
# 15939at7088 missing
# 9544at7088 missing
# run  238
# 11558at7088 missing
# 10387at7088 missing
# 12632at7088 missing
# 5251at7088 missing
# run  239
# 1504at7088 missing
# 4118at7088 missing
# 5251at7088 missing
# 11558at7088 missing
# 3493at7088 missing
# run  240
# 3493at7088 missing
# 16088at7088 missing
# 14521at7088 missing
# 10546at7088 missing
# 8001at7088 missing
# run  241
# 5251at7088 missing
# 10546at7088 missing
# 12660at7088 missing
# 1504at7088 missing
# 4118at7088 missing
# 10319at7088 missing
# 16513at7088 missing
# run  242
# 3212at7088 missing
# 8811at7088 missing
# 16088at7088 missing
# 13532at7088 missing
# run  243
# 7506at7088 missing
# 9108at7088 missing
# 13532at7088 missing
# 12834at7088 missing
# 11264at7088 missing
# run  244
# 10333at7088 missing
# 1504at7088 missing
# 10546at7088 missing
# 4645at7088 missing
# 13972at7088 missing
# 3212at7088 missing
# 10387at7088 missing
# 3493at7088 missing
# run  245
# 6083at7088 missing
# 4118at7088 missing
# 16513at7088 missing
# 11264at7088 missing
# 3493at7088 missing
# 10319at7088 missing
# 12660at7088 missing
# 4967at7088 missing
# run  246
# 4118at7088 missing
# 10546at7088 missing
# 14179at7088 missing
# 3161at7088 missing
# 13972at7088 missing
# 3212at7088 missing
# 12834at7088 missing
# run  247
# 11066at7088 missing
# 12632at7088 missing
# 12834at7088 missing
# 14179at7088 missing
# 8811at7088 missing
# 11558at7088 missing
# run  248
# 11066at7088 missing
# 13532at7088 missing
# 14179at7088 missing
# 3493at7088 missing
# 11264at7088 missing
# 1504at7088 missing
# 7506at7088 missing
# 6083at7088 missing
# run  249
# 13972at7088 missing
# 11066at7088 missing
# 7506at7088 missing
# 11264at7088 missing
# 14404at7088 missing
# run  250
# 13972at7088 missing
# 8001at7088 missing
# run  251
# 4645at7088 missing
# 6083at7088 missing
# 1504at7088 missing
# 10387at7088 missing
# 4967at7088 missing
# 14179at7088 missing
# 16088at7088 missing
# 14521at7088 missing
# 11066at7088 missing
# run  252
# 3161at7088 missing
# 14179at7088 missing
# 9544at7088 missing
# 1504at7088 missing
# run  253
# 11066at7088 missing
# 4118at7088 missing
# 12660at7088 missing
# run  254
# 8001at7088 missing
# 11264at7088 missing
# 4118at7088 missing
# 3493at7088 missing
# 11066at7088 missing
# run  255
# 16513at7088 missing
# 4118at7088 missing
# 1504at7088 missing
# 3493at7088 missing
# 10333at7088 missing
# 7506at7088 missing
# 11066at7088 missing
# run  256
# 9108at7088 missing
# 14179at7088 missing
# 4118at7088 missing
# 14521at7088 missing
# 10387at7088 missing
# run  257
# 8811at7088 missing
# 3493at7088 missing
# 12834at7088 missing
# 3212at7088 missing
# run  258
# 13972at7088 missing
# 16513at7088 missing
# 8001at7088 missing
# 12834at7088 missing
# run  259
# 1504at7088 missing
# 4118at7088 missing
# 3161at7088 missing
# 8001at7088 missing
# run  260
# 10546at7088 missing
# 4967at7088 missing
# 7357at7088 missing
# 9108at7088 missing
# 5251at7088 missing
# 11264at7088 missing
# 12834at7088 missing
# run  261
# 14521at7088 missing
# 4645at7088 missing
# 3161at7088 missing
# 11066at7088 missing
# 3493at7088 missing
# 14179at7088 missing
# 9108at7088 missing
# 7357at7088 missing
# 4118at7088 missing
# run  262
# 14179at7088 missing
# 13532at7088 missing
# 16088at7088 missing
# 8001at7088 missing
# run  263
# 1504at7088 missing
# 11264at7088 missing
# 13532at7088 missing
# 11066at7088 missing
# run  264
# 3161at7088 missing
# 13532at7088 missing
# 9108at7088 missing
# 3493at7088 missing
# 14404at7088 missing
# run  265
# 12834at7088 missing
# 8001at7088 missing
# 10333at7088 missing
# 7357at7088 missing
# run  266
# 16088at7088 missing
# 8811at7088 missing
# 16513at7088 missing
# run  267
# 13972at7088 missing
# run  268
# 8001at7088 missing
# 14179at7088 missing
# 9544at7088 missing
# 10333at7088 missing
# 15939at7088 missing
# 12632at7088 missing
# 5251at7088 missing
# run  269
# 11264at7088 missing
# 8001at7088 missing
# 10333at7088 missing
# 10319at7088 missing
# 3161at7088 missing
# 10387at7088 missing
# 10546at7088 missing
# 14179at7088 missing
# run  270
# 10546at7088 missing
# 11558at7088 missing
# 3493at7088 missing
# 11264at7088 missing
# 4118at7088 missing
# 5251at7088 missing
# run  271
# 11558at7088 missing
# 14404at7088 missing
# 4118at7088 missing
# 8811at7088 missing
# 4967at7088 missing
# 9544at7088 missing
# 9108at7088 missing
# run  272
# 14179at7088 missing
# 8811at7088 missing
# 11264at7088 missing
# run  273
# 16088at7088 missing
# 12632at7088 missing
# 6083at7088 missing
# 14404at7088 missing
# run  274
# 12632at7088 missing
# 9108at7088 missing
# 3161at7088 missing
# run  275
# 11558at7088 missing
# 14179at7088 missing
# 4645at7088 missing
# 14521at7088 missing
# 4118at7088 missing
# 5251at7088 missing
# 6083at7088 missing
# 9544at7088 missing
# 15939at7088 missing
# run  276
# 8811at7088 missing
# 3493at7088 missing
# 15939at7088 missing
# 6083at7088 missing
# 11066at7088 missing
# 9544at7088 missing
# 7400at7088 missing
# 16513at7088 missing
# 4118at7088 missing
# 3212at7088 missing
# run  277
# 8811at7088 missing
# 4967at7088 missing
# 10319at7088 missing
# 11558at7088 missing
# 16088at7088 missing
# run  278
# 1504at7088 missing
# 10387at7088 missing
# 10546at7088 missing
# 7506at7088 missing
# 9544at7088 missing
# run  279
# 11558at7088 missing
# 4967at7088 missing
# 14521at7088 missing
# 15939at7088 missing
# 7357at7088 missing
# 9108at7088 missing
# 4645at7088 missing
# 13532at7088 missing
# 5251at7088 missing
# run  280
# 16088at7088 missing
# 7506at7088 missing
# 4645at7088 missing
# 14404at7088 missing
# 8811at7088 missing
# run  281
# 14404at7088 missing
# 12660at7088 missing
# 9544at7088 missing
# 8001at7088 missing
# 12632at7088 missing
# 11264at7088 missing
# 13972at7088 missing
# run  282
# 15939at7088 missing
# 7357at7088 missing
# 7400at7088 missing
# 10319at7088 missing
# 7506at7088 missing
# 3212at7088 missing
# 8001at7088 missing
# run  283
# 1504at7088 missing
# 10333at7088 missing
# 15939at7088 missing
# 10387at7088 missing
# run  284
# 4645at7088 missing
# 11066at7088 missing
# 6083at7088 missing
# 11264at7088 missing
# run  285
# 12632at7088 missing
# 1504at7088 missing
# 3161at7088 missing
# 7506at7088 missing
# 15939at7088 missing
# 3212at7088 missing
# 5251at7088 missing
# run  286
# 7506at7088 missing
# 8001at7088 missing
# 13532at7088 missing
# 1504at7088 missing
# run  287
# 16513at7088 missing
# 4118at7088 missing
# 7506at7088 missing
# 8811at7088 missing
# 10319at7088 missing
# 10333at7088 missing
# 4967at7088 missing
# run  288
# 4967at7088 missing
# 7506at7088 missing
# 16088at7088 missing
# run  289
# 10333at7088 missing
# 8811at7088 missing
# 14404at7088 missing
# 9108at7088 missing
# 1504at7088 missing
# 7357at7088 missing
# 11264at7088 missing
# 10319at7088 missing
# run  290
# 8811at7088 missing
# 14404at7088 missing
# 3161at7088 missing
# run  291
# 14179at7088 missing
# 5251at7088 missing
# 3493at7088 missing
# 14521at7088 missing
# 8811at7088 missing
# 12632at7088 missing
# run  292
# 5251at7088 missing
# 11558at7088 missing
# 12632at7088 missing
# 8811at7088 missing
# 3161at7088 missing
# 12834at7088 missing
# 14179at7088 missing
# 14521at7088 missing
# run  293
# 13972at7088 missing
# 13532at7088 missing
# run  294
# 6083at7088 missing
# 4967at7088 missing
# 7400at7088 missing
# 10387at7088 missing
# 14404at7088 missing
# run  295
# 16088at7088 missing
# 14521at7088 missing
# 3212at7088 missing
# 6083at7088 missing
# 15939at7088 missing
# 3493at7088 missing
# run  296
# 11264at7088 missing
# 10546at7088 missing
# 9544at7088 missing
# run  297
# 8811at7088 missing
# 11264at7088 missing
# 14404at7088 missing
# 15939at7088 missing
# 13972at7088 missing
# 10546at7088 missing
# 1504at7088 missing
# 11558at7088 missing
# run  298
# 8811at7088 missing
# 4118at7088 missing
# 7400at7088 missing
# 7506at7088 missing
# 3493at7088 missing
# 3161at7088 missing
# 14179at7088 missing
# 12660at7088 missing
# run  299
# 15939at7088 missing
# 3493at7088 missing
# 4118at7088 missing
# 12660at7088 missing
# 5251at7088 missing
# 10387at7088 missing
# 8811at7088 missing
# 11264at7088 missing
# 11066at7088 missing
# run  300
# 16513at7088 missing
# 14404at7088 missing
# 7506at7088 missing
# 10387at7088 missing
# 1504at7088 missing
# 4967at7088 missing
# run  301
# 3493at7088 missing
# 14179at7088 missing
# 8811at7088 missing
# 1504at7088 missing
# run  302
# 10319at7088 missing
# 16513at7088 missing
# 7506at7088 missing
# 3161at7088 missing
# 8001at7088 missing
# run  303
# 5251at7088 missing
# 9108at7088 missing
# 15939at7088 missing
# 4118at7088 missing
# 10333at7088 missing
# 7506at7088 missing
# 12632at7088 missing
# run  304
# 15939at7088 missing
# 11558at7088 missing
# 13972at7088 missing
# run  305
# 3493at7088 missing
# 10387at7088 missing
# 10546at7088 missing
# 10333at7088 missing
# 10319at7088 missing
# 8001at7088 missing
# run  306
# 13972at7088 missing
# 3161at7088 missing
# 12834at7088 missing
# 7357at7088 missing
# 9544at7088 missing
# 10387at7088 missing
# 10333at7088 missing
# run  307
# 4967at7088 missing
# 3161at7088 missing
# 9108at7088 missing
# 7400at7088 missing
# run  308
# 11066at7088 missing
# 4118at7088 missing
# run  309
# 11558at7088 missing
# 13532at7088 missing
# run  310
# 16513at7088 missing
# 8811at7088 missing
# 8001at7088 missing
# run  311
# 10387at7088 missing
# 7357at7088 missing
# 10319at7088 missing
# 14404at7088 missing
# 11558at7088 missing
# 10546at7088 missing
# run  312
# 14179at7088 missing
# 16088at7088 missing
# 13532at7088 missing
# 15939at7088 missing
# 13972at7088 missing
# run  313
# 12660at7088 missing
# 3493at7088 missing
# 5251at7088 missing
# 15939at7088 missing
# 11066at7088 missing
# 3161at7088 missing
# run  314
# 3161at7088 missing
# 5251at7088 missing
# run  315
# 4118at7088 missing
# 10333at7088 missing
# 14521at7088 missing
# 16088at7088 missing
# 11066at7088 missing
# 7400at7088 missing
# 3212at7088 missing
# run  316
# 10546at7088 missing
# 4645at7088 missing
# 11066at7088 missing
# 13972at7088 missing
# 3212at7088 missing
# run  317
# 15939at7088 missing
# 4118at7088 missing
# 3493at7088 missing
# 13972at7088 missing
# 9108at7088 missing
# 7506at7088 missing
# 13532at7088 missing
# run  318
# 4118at7088 missing
# 11066at7088 missing
# 10546at7088 missing
# 10319at7088 missing
# 12660at7088 missing
# run  319
# 11264at7088 missing
# 7357at7088 missing
# run  320
# 4645at7088 missing
# 14404at7088 missing
# 15939at7088 missing
# run  321
# 14179at7088 missing
# 9544at7088 missing
# 1504at7088 missing
# 14404at7088 missing
# run  322
# 13532at7088 missing
# 13972at7088 missing
# run  323
# 16513at7088 missing
# 10333at7088 missing
# 3161at7088 missing
# 10319at7088 missing
# 7357at7088 missing
# 10387at7088 missing
# 7400at7088 missing
# 12834at7088 missing
# 16088at7088 missing
# 9108at7088 missing
# run  324
# 14521at7088 missing
# 12660at7088 missing
# run  325
# 13972at7088 missing
# 3493at7088 missing
# 5251at7088 missing
# 1504at7088 missing
# run  326
# 14179at7088 missing
# 14521at7088 missing
# 7400at7088 missing
# 7357at7088 missing
# 3161at7088 missing
# 8001at7088 missing
# run  327
# 3161at7088 missing
# 3493at7088 missing
# 15939at7088 missing
# 1504at7088 missing
# 14404at7088 missing
# run  328
# 10319at7088 missing
# 3493at7088 missing
# 11264at7088 missing
# 12834at7088 missing
# 1504at7088 missing
# 7506at7088 missing
# run  329
# 10333at7088 missing
# 4967at7088 missing
# 3212at7088 missing
# 11066at7088 missing
# 5251at7088 missing
# 8811at7088 missing
# 14404at7088 missing
# 11558at7088 missing
# run  330
# 7506at7088 missing
# 3161at7088 missing
# run  331
# 3212at7088 missing
# 14179at7088 missing
# 1504at7088 missing
# 7506at7088 missing
# 13532at7088 missing
# 11264at7088 missing
# run  332
# 7357at7088 missing
# 12834at7088 missing
# 10319at7088 missing
# 6083at7088 missing
# run  333
# 16088at7088 missing
# 10333at7088 missing
# 3493at7088 missing
# 4967at7088 missing
# 14179at7088 missing
# 14521at7088 missing
# 12834at7088 missing
# 9544at7088 missing
# run  334
# 11066at7088 missing
# 6083at7088 missing
# 14521at7088 missing
# 13972at7088 missing
# run  335
# 12632at7088 missing
# 13532at7088 missing
# 7400at7088 missing
# 4967at7088 missing
# run  336
# 14179at7088 missing
# 10387at7088 missing
# 10333at7088 missing
# 7400at7088 missing
# 4967at7088 missing
# run  337
# 11558at7088 missing
# 14521at7088 missing
# 14179at7088 missing
# 11066at7088 missing
# 8001at7088 missing
# 4645at7088 missing
# 14404at7088 missing
# 9544at7088 missing
# 10319at7088 missing
# 10387at7088 missing
# 4118at7088 missing
# 1504at7088 missing
# 3161at7088 missing
# 3212at7088 missing
# run  338
# 14404at7088 missing
# 12660at7088 missing
# 13532at7088 missing
# 9544at7088 missing
# 11066at7088 missing
# 10319at7088 missing
# 15939at7088 missing
# run  339
# 9544at7088 missing
# 7400at7088 missing
# run  340
# 12660at7088 missing
# 9108at7088 missing
# 14179at7088 missing
# 11066at7088 missing
# 9544at7088 missing
# 7506at7088 missing
# run  341
# 3161at7088 missing
# 6083at7088 missing
# 12632at7088 missing
# 8001at7088 missing
# 7357at7088 missing
# 8811at7088 missing
# 10319at7088 missing
# 5251at7088 missing
# 16088at7088 missing
# 10546at7088 missing
# run  342
# 6083at7088 missing
# 16088at7088 missing
# 3161at7088 missing
# run  343
# 16513at7088 missing
# 10319at7088 missing
# run  344
# 4118at7088 missing
# 12834at7088 missing
# 11066at7088 missing
# 12660at7088 missing
# 7506at7088 missing
# 11558at7088 missing
# run  345
# 4645at7088 missing
# 9108at7088 missing
# 12834at7088 missing
# 14404at7088 missing
# 3161at7088 missing
# 10333at7088 missing
# 7357at7088 missing
# 9544at7088 missing
# run  346
# 3212at7088 missing
# 8811at7088 missing
# 12632at7088 missing
# 7400at7088 missing
# run  347
# 13532at7088 missing
# 16513at7088 missing
# 10333at7088 missing
# 4967at7088 missing
# 6083at7088 missing
# 3212at7088 missing
# 5251at7088 missing
# 16088at7088 missing
# 11558at7088 missing
# run  348
# 16088at7088 missing
# 4645at7088 missing
# 6083at7088 missing
# 3493at7088 missing
# run  349
# 4967at7088 missing
# 12834at7088 missing
# 14179at7088 missing
# 3493at7088 missing
# 14404at7088 missing
# 11066at7088 missing
# run  350
# 7506at7088 missing
# 14404at7088 missing
# 11264at7088 missing
# run  351
# 16088at7088 missing
# 12660at7088 missing
# 10319at7088 missing
# 9544at7088 missing
# 12632at7088 missing
# 8001at7088 missing
# 11066at7088 missing
# run  352
# 12632at7088 missing
# 11558at7088 missing
# 13532at7088 missing
# 9108at7088 missing
# 16513at7088 missing
# run  353
# 9544at7088 missing
# 5251at7088 missing
# 4118at7088 missing
# 16088at7088 missing
# 9108at7088 missing
# 8001at7088 missing
# run  354
# 4118at7088 missing
# 12632at7088 missing
# 7400at7088 missing
# 11066at7088 missing
# 10333at7088 missing
# 10319at7088 missing
# run  355
# 14521at7088 missing
# 3212at7088 missing
# 8001at7088 missing
# 7506at7088 missing
# 7357at7088 missing
# run  356
# 7357at7088 missing
# 11066at7088 missing
# 14179at7088 missing
# run  357
# 15939at7088 missing
# 11558at7088 missing
# 12660at7088 missing
# 12834at7088 missing
# 10546at7088 missing
# run  358
# 11264at7088 missing
# 8811at7088 missing
# 4645at7088 missing
# 12834at7088 missing
# 14521at7088 missing
# run  359
# 16513at7088 missing
# 1504at7088 missing
# 10319at7088 missing
# 4118at7088 missing
# run  360
# 11264at7088 missing
# 6083at7088 missing
# 12660at7088 missing
# 1504at7088 missing
# 8001at7088 missing
# 4645at7088 missing
# 10546at7088 missing
# 5251at7088 missing
# run  361
# 11264at7088 missing
# 12632at7088 missing
# 10546at7088 missing
# 8001at7088 missing
# 12834at7088 missing
# 16088at7088 missing
# run  362
# 4645at7088 missing
# 14521at7088 missing
# 11066at7088 missing
# 10387at7088 missing
# run  363
# 10387at7088 missing
# 5251at7088 missing
# 4645at7088 missing
# run  364
# 1504at7088 missing
# 5251at7088 missing
# 12632at7088 missing
# run  365
# 11264at7088 missing
# 12632at7088 missing
# 4118at7088 missing
# 10387at7088 missing
# run  366
# 14179at7088 missing
# 7357at7088 missing
# run  367
# 14179at7088 missing
# 16513at7088 missing
# run  368
# 11264at7088 missing
# 12632at7088 missing
# 3161at7088 missing
# 14521at7088 missing
# 12834at7088 missing
# run  369
# 15939at7088 missing
# 4645at7088 missing
# 10319at7088 missing
# 3161at7088 missing
# 13532at7088 missing
# 10333at7088 missing
# 14404at7088 missing
# run  370
# 10387at7088 missing
# 13532at7088 missing
# 11066at7088 missing
# 11264at7088 missing
# 16088at7088 missing
# 7506at7088 missing
# 4118at7088 missing
# 16513at7088 missing
# run  371
# 13532at7088 missing
# 4645at7088 missing
# 12632at7088 missing
# 11264at7088 missing
# run  372
# 11264at7088 missing
# 10387at7088 missing
# 4967at7088 missing
# 8811at7088 missing
# run  373
# 3161at7088 missing
# 14521at7088 missing
# 11066at7088 missing
# 10546at7088 missing
# 13532at7088 missing
# 7357at7088 missing
# 9544at7088 missing
# 4967at7088 missing
# run  374
# 16088at7088 missing
# 10387at7088 missing
# run  375
# 14521at7088 missing
# 12660at7088 missing
# 12834at7088 missing
# 14179at7088 missing
# 10387at7088 missing
# 11264at7088 missing
# run  376
# 13972at7088 missing
# 12834at7088 missing
# 12660at7088 missing
# 11264at7088 missing
# run  377
# 14404at7088 missing
# 14179at7088 missing
# 8001at7088 missing
# 10546at7088 missing
# 12632at7088 missing
# 7400at7088 missing
# 11066at7088 missing
# 12834at7088 missing
# 4645at7088 missing
# run  378
# 16088at7088 missing
# 10546at7088 missing
# 11264at7088 missing
# 7357at7088 missing
# 12660at7088 missing
# run  379
# 11066at7088 missing
# 12632at7088 missing
# 4645at7088 missing
# 11264at7088 missing
# 8811at7088 missing
# run  380
# 7357at7088 missing
# 3161at7088 missing
# 1504at7088 missing
# 4645at7088 missing
# 7400at7088 missing
# 13972at7088 missing
# run  381
# 14404at7088 missing
# 1504at7088 missing
# 5251at7088 missing
# 10546at7088 missing
# 14179at7088 missing
# 16513at7088 missing
# 13532at7088 missing
# run  382
# 16088at7088 missing
# 9544at7088 missing
# 15939at7088 missing
# 11264at7088 missing
# 7506at7088 missing
# run  383
# 11264at7088 missing
# 12834at7088 missing
# 6083at7088 missing
# 9544at7088 missing
# 4645at7088 missing
# 3212at7088 missing
# 14179at7088 missing
# run  384
# 3161at7088 missing
# 10387at7088 missing
# 4118at7088 missing
# 16513at7088 missing
# 15939at7088 missing
# run  385
# 1504at7088 missing
# 13972at7088 missing
# 4967at7088 missing
# run  386
# 9544at7088 missing
# 11558at7088 missing
# 12834at7088 missing
# 14521at7088 missing
# 14179at7088 missing
# 15939at7088 missing
# run  387
# 7400at7088 missing
# 16513at7088 missing
# 13972at7088 missing
# 11264at7088 missing
# run  388
# 4118at7088 missing
# 8811at7088 missing
# 3212at7088 missing
# 13972at7088 missing
# run  389
# 3161at7088 missing
# 10387at7088 missing
# 3493at7088 missing
# 5251at7088 missing
# 13972at7088 missing
# 10333at7088 missing
# run  390
# 16088at7088 missing
# 10387at7088 missing
# run  391
# 9108at7088 missing
# 8001at7088 missing
# 9544at7088 missing
# 10319at7088 missing
# run  392
# 11264at7088 missing
# 10333at7088 missing
# 12834at7088 missing
# 9108at7088 missing
# 16513at7088 missing
# 15939at7088 missing
# 7506at7088 missing
# 8001at7088 missing
# 14179at7088 missing
# run  393
# 4967at7088 missing
# 10319at7088 missing
# 3212at7088 missing
# 5251at7088 missing
# run  394
# 3493at7088 missing
# 7400at7088 missing
# 7506at7088 missing
# 16088at7088 missing
# 3161at7088 missing
# run  395
# 13532at7088 missing
# 7357at7088 missing
# 4967at7088 missing
# 9544at7088 missing
# 15939at7088 missing
# 3161at7088 missing
# 12660at7088 missing
# 16088at7088 missing
# run  396
# 3212at7088 missing
# 16088at7088 missing
# 12834at7088 missing
# 12660at7088 missing
# 7357at7088 missing
# run  397
# 14404at7088 missing
# 11066at7088 missing
# 3212at7088 missing
# 11558at7088 missing
# 9108at7088 missing
# run  398
# 10319at7088 missing
# 11066at7088 missing
# 1504at7088 missing
# 7400at7088 missing
# 12834at7088 missing
# run  399
# 8001at7088 missing
# 3161at7088 missing
# 10333at7088 missing
# 10319at7088 missing
# 8811at7088 missing
# 16513at7088 missing
# 11558at7088 missing
# run  400
# 14404at7088 missing
# 15939at7088 missing
# 11558at7088 missing
# run  401
# 9544at7088 missing
# 7400at7088 missing
# 7357at7088 missing
# 14521at7088 missing
# run  402
# 6083at7088 missing
# 4645at7088 missing
# 3493at7088 missing
# 1504at7088 missing
# run  403
# 12834at7088 missing
# 7400at7088 missing
# run  404
# 4118at7088 missing
# 13972at7088 missing
# 9544at7088 missing
# 8001at7088 missing
# 10387at7088 missing
# 10333at7088 missing
# run  405
# 4967at7088 missing
# 10546at7088 missing
# 7400at7088 missing
# 14179at7088 missing
# 3161at7088 missing
# run  406
# 3493at7088 missing
# 6083at7088 missing
# 14179at7088 missing
# 10387at7088 missing
# 10333at7088 missing
# 14521at7088 missing
# 8001at7088 missing
# run  407
# 4118at7088 missing
# 3493at7088 missing
# 8001at7088 missing
# 7400at7088 missing
# 13532at7088 missing
# 12632at7088 missing
# 11066at7088 missing
# 10319at7088 missing
# 8811at7088 missing
# 10333at7088 missing
# 7506at7088 missing
# 14521at7088 missing
# run  408
# 12834at7088 missing
# 8811at7088 missing
# 14404at7088 missing
# 4967at7088 missing
# 11066at7088 missing
# 11558at7088 missing
# run  409
# 8001at7088 missing
# 10387at7088 missing
# 9544at7088 missing
# 13532at7088 missing
# run  410
# 6083at7088 missing
# 11558at7088 missing
# 15939at7088 missing
# 12660at7088 missing
# 4967at7088 missing
# run  411
# 7400at7088 missing
# run  412
# 13532at7088 missing
# 6083at7088 missing
# 1504at7088 missing
# 4645at7088 missing
# 16513at7088 missing
# run  413
# 13972at7088 missing
# 11066at7088 missing
# 4645at7088 missing
# run  414
# 11558at7088 missing
# 6083at7088 missing
# 8001at7088 missing
# 11264at7088 missing
# 9544at7088 missing
# 14179at7088 missing
# run  415
# 4645at7088 missing
# 12834at7088 missing
# 4967at7088 missing
# 10319at7088 missing
# 3161at7088 missing
# 8811at7088 missing
# 9108at7088 missing
# run  416
# 8001at7088 missing
# 3161at7088 missing
# 4118at7088 missing
# run  417
# 5251at7088 missing
# 16088at7088 missing
# 13532at7088 missing
# 12834at7088 missing
# 4645at7088 missing
# 11066at7088 missing
# 7400at7088 missing
# 16513at7088 missing
# run  418
# 10387at7088 missing
# 13972at7088 missing
# 3212at7088 missing
# 9108at7088 missing
# 12660at7088 missing
# 12632at7088 missing
# run  419
# 14404at7088 missing
# 12632at7088 missing
# 7357at7088 missing
# 14521at7088 missing
# 4118at7088 missing
# 9108at7088 missing
# run  420
# 1504at7088 missing
# 11066at7088 missing
# 16088at7088 missing
# run  421
# 8811at7088 missing
# run  422
# 3493at7088 missing
# 8001at7088 missing
# 11264at7088 missing
# run  423
# 14521at7088 missing
# 3161at7088 missing
# 16513at7088 missing
# 7357at7088 missing
# 10333at7088 missing
# 8811at7088 missing
# 11264at7088 missing
# 14404at7088 missing
# run  424
# 8811at7088 missing
# 13972at7088 missing
# 7506at7088 missing
# 14179at7088 missing
# 11264at7088 missing
# 4118at7088 missing
# 14521at7088 missing
# run  425
# 8001at7088 missing
# 13972at7088 missing
# 12632at7088 missing
# 12660at7088 missing
# 10387at7088 missing
# 10546at7088 missing
# run  426
# 7506at7088 missing
# 13972at7088 missing
# 10387at7088 missing
# 3212at7088 missing
# 10333at7088 missing
# 4645at7088 missing
# run  427
# 8001at7088 missing
# 9544at7088 missing
# ...
# 7357at7088 missing
# 9108at7088 missing
# 12660at7088 missing
# run  889
# 16513at7088 missing
# 12632at7088 missing
# 5251at7088 missing
# 14179at7088 missing
# run  890
# 16088at7088 missing
# 10319at7088 missing
# 7506at7088 missing
# 1504at7088 missing
# 3493at7088 missing
# run  891
# 6083at7088 missing
# 7506at7088 missing
# 10387at7088 missing
# run  892
# 1504at7088 missing
# 11066at7088 missing
# 14404at7088 missing
# 4118at7088 missing
# run  893
# 3212at7088 missing
# 5251at7088 missing
# 11066at7088 missing
# 12834at7088 missing
# 14404at7088 missing
# run  894
# 7357at7088 missing
# 8811at7088 missing
# 10387at7088 missing
# 14521at7088 missing
# 4118at7088 missing
# run  895
# 14179at7088 missing
# 4645at7088 missing
# 12660at7088 missing
# 10387at7088 missing
# 4967at7088 missing
# run  896
# 4118at7088 missing
# 10546at7088 missing
# 3161at7088 missing
# 11558at7088 missing
# run  897
# 10387at7088 missing
# 15939at7088 missing
# 10546at7088 missing
# 12834at7088 missing
# run  898
# 4967at7088 missing
# run  899
# 12660at7088 missing
# 5251at7088 missing
# 16088at7088 missing
# 10387at7088 missing
# 4645at7088 missing
# 7357at7088 missing
# 6083at7088 missing
# run  900
# 4967at7088 missing
# 8001at7088 missing
# 10546at7088 missing
# 14404at7088 missing
# 3161at7088 missing
# run  901
# 7357at7088 missing
# 4118at7088 missing
# 10333at7088 missing
# 4645at7088 missing
# 7400at7088 missing
# run  902
# 12632at7088 missing
# 1504at7088 missing
# 16088at7088 missing
# 10333at7088 missing
# 8001at7088 missing
# 12834at7088 missing
# 15939at7088 missing
# 3161at7088 missing
# 14521at7088 missing
# 5251at7088 missing
# run  903
# 1504at7088 missing
# 5251at7088 missing
# 8811at7088 missing
# 14521at7088 missing
# 8001at7088 missing
# run  904
# 9544at7088 missing
# 10319at7088 missing
# 14521at7088 missing
# 7400at7088 missing
# run  905
# 14179at7088 missing
# 13972at7088 missing
# 12632at7088 missing
# 9544at7088 missing
# run  906
# 15939at7088 missing
# 10387at7088 missing
# 11264at7088 missing
# 13532at7088 missing
# 3212at7088 missing
# run  907
# 7357at7088 missing
# 7400at7088 missing
# 4645at7088 missing
# 10387at7088 missing
# 4967at7088 missing
# 3212at7088 missing
# run  908
# 12660at7088 missing
# 11264at7088 missing
# 11558at7088 missing
# 3161at7088 missing
# 13972at7088 missing
# 10319at7088 missing
# 14179at7088 missing
# 13532at7088 missing
# run  909
# 10333at7088 missing
# 8811at7088 missing
# 11264at7088 missing
# 13972at7088 missing
# 7400at7088 missing
# 16513at7088 missing
# run  910
# 3493at7088 missing
# 10333at7088 missing
# 12834at7088 missing
# 1504at7088 missing
# run  911
# 4645at7088 missing
# 12834at7088 missing
# 6083at7088 missing
# 10333at7088 missing
# 13532at7088 missing
# run  912
# 11066at7088 missing
# 16088at7088 missing
# 14404at7088 missing
# 9108at7088 missing
# 8001at7088 missing
# 16513at7088 missing
# run  913
# 8811at7088 missing
# 10319at7088 missing
# 3212at7088 missing
# 1504at7088 missing
# 3493at7088 missing
# 7506at7088 missing
# 7400at7088 missing
# run  914
# 9108at7088 missing
# 12660at7088 missing
# 7400at7088 missing
# 7506at7088 missing
# 9544at7088 missing
# 13972at7088 missing
# 3493at7088 missing
# run  915
# 10333at7088 missing
# 11264at7088 missing
# 13972at7088 missing
# 7400at7088 missing
# run  916
# 12632at7088 missing
# 3212at7088 missing
# 10319at7088 missing
# 13972at7088 missing
# run  917
# 4645at7088 missing
# 9108at7088 missing
# 7506at7088 missing
# 10546at7088 missing
# 8811at7088 missing
# 13972at7088 missing
# 11066at7088 missing
# run  918
# 10387at7088 missing
# 5251at7088 missing
# 14521at7088 missing
# 15939at7088 missing
# 8811at7088 missing
# 11558at7088 missing
# 10546at7088 missing
# 13532at7088 missing
# run  919
# 16088at7088 missing
# 13532at7088 missing
# 10387at7088 missing
# 6083at7088 missing
# run  920
# 9108at7088 missing
# 9544at7088 missing
# 7506at7088 missing
# 12632at7088 missing
# 3161at7088 missing
# run  921
# 14179at7088 missing
# 3161at7088 missing
# 11066at7088 missing
# 4645at7088 missing
# 3493at7088 missing
# 5251at7088 missing
# 12834at7088 missing
# run  922
# 4645at7088 missing
# 14521at7088 missing
# 3493at7088 missing
# 11264at7088 missing
# run  923
# 3161at7088 missing
# run  924
# 7400at7088 missing
# 8001at7088 missing
# 5251at7088 missing
# 16513at7088 missing
# 9544at7088 missing
# 3212at7088 missing
# run  925
# 7400at7088 missing
# 9544at7088 missing
# 10333at7088 missing
# 14179at7088 missing
# 11066at7088 missing
# 11264at7088 missing
# run  926
# 9108at7088 missing
# 10387at7088 missing
# 14179at7088 missing
# 12660at7088 missing
# 1504at7088 missing
# run  927
# 14521at7088 missing
# 6083at7088 missing
# 12632at7088 missing
# 5251at7088 missing
# 3212at7088 missing
# run  928
# 5251at7088 missing
# 12632at7088 missing
# 11066at7088 missing
# run  929
# 12660at7088 missing
# 11066at7088 missing
# 16088at7088 missing
# 7400at7088 missing
# 15939at7088 missing
# run  930
# 10333at7088 missing
# 7400at7088 missing
# run  931
# 9108at7088 missing
# 1504at7088 missing
# 10319at7088 missing
# 15939at7088 missing
# 11066at7088 missing
# run  932
# run  933
# 9544at7088 missing
# 16088at7088 missing
# 8811at7088 missing
# 4645at7088 missing
# 10387at7088 missing
# run  934
# 13972at7088 missing
# 3212at7088 missing
# 4645at7088 missing
# 11264at7088 missing
# 13532at7088 missing
# run  935
# 8811at7088 missing
# 4645at7088 missing
# 12660at7088 missing
# 8001at7088 missing
# 7400at7088 missing
# 16088at7088 missing
# run  936
# 3161at7088 missing
# run  937
# 4967at7088 missing
# 15939at7088 missing
# 11558at7088 missing
# 8001at7088 missing
# 3493at7088 missing
# run  938
# 3212at7088 missing
# 12632at7088 missing
# 1504at7088 missing
# 10333at7088 missing
# 6083at7088 missing
# 11066at7088 missing
# 11558at7088 missing
# run  939
# 7357at7088 missing
# 15939at7088 missing
# 4967at7088 missing
# 1504at7088 missing
# run  940
# 9108at7088 missing
# 3161at7088 missing
# 7400at7088 missing
# 14521at7088 missing
# 11558at7088 missing
# 14179at7088 missing
# 15939at7088 missing
# run  941
# 14179at7088 missing
# 8811at7088 missing
# 13972at7088 missing
# 16088at7088 missing
# run  942
# 7400at7088 missing
# 4118at7088 missing
# 11066at7088 missing
# 16088at7088 missing
# 6083at7088 missing
# 12834at7088 missing
# run  943
# 3161at7088 missing
# 13972at7088 missing
# 11558at7088 missing
# 15939at7088 missing
# 14521at7088 missing
# 8811at7088 missing
# 6083at7088 missing
# 16513at7088 missing
# run  944
# 16088at7088 missing
# 4967at7088 missing
# 10387at7088 missing
# 7506at7088 missing
# run  945
# 11558at7088 missing
# 7357at7088 missing
# 9108at7088 missing
# 7400at7088 missing
# 13972at7088 missing
# 10333at7088 missing
# 4645at7088 missing
# 4118at7088 missing
# 16088at7088 missing
# run  946
# 16513at7088 missing
# 1504at7088 missing
# run  947
# 16088at7088 missing
# 10387at7088 missing
# 8811at7088 missing
# run  948
# 14179at7088 missing
# 11558at7088 missing
# 10387at7088 missing
# 10546at7088 missing
# 7357at7088 missing
# 7400at7088 missing
# 3212at7088 missing
# run  949
# 11066at7088 missing
# 12660at7088 missing
# 4967at7088 missing
# 13972at7088 missing
# 9544at7088 missing
# run  950
# 3493at7088 missing
# 9544at7088 missing
# 10333at7088 missing
# run  951
# 15939at7088 missing
# 8811at7088 missing
# 10387at7088 missing
# 16088at7088 missing
# 12834at7088 missing
# 10319at7088 missing
# run  952
# run  953
# 1504at7088 missing
# 11066at7088 missing
# 4118at7088 missing
# 11264at7088 missing
# 3161at7088 missing
# 3493at7088 missing
# run  954
# 3212at7088 missing
# 4967at7088 missing
# 7506at7088 missing
# 13532at7088 missing
# 15939at7088 missing
# run  955
# 16088at7088 missing
# 9108at7088 missing
# 4118at7088 missing
# 4967at7088 missing
# run  956
# 3493at7088 missing
# 4118at7088 missing
# 16513at7088 missing
# 13532at7088 missing
# 10319at7088 missing
# 8811at7088 missing
# 6083at7088 missing
# 14179at7088 missing
# run  957
# 3493at7088 missing
# 12632at7088 missing
# run  958
# 4118at7088 missing
# 5251at7088 missing
# 7357at7088 missing
# 9108at7088 missing
# run  959
# 7357at7088 missing
# 10319at7088 missing
# run  960
# 6083at7088 missing
# 10333at7088 missing
# 15939at7088 missing
# run  961
# 11264at7088 missing
# 13532at7088 missing
# 3161at7088 missing
# 10333at7088 missing
# run  962
# 5251at7088 missing
# 13532at7088 missing
# 8811at7088 missing
# 14404at7088 missing
# 16513at7088 missing
# 3212at7088 missing
# run  963
# 13532at7088 missing
# 14521at7088 missing
# 9544at7088 missing
# 7506at7088 missing
# 9108at7088 missing
# 7357at7088 missing
# run  964
# 12660at7088 missing
# 6083at7088 missing
# 7400at7088 missing
# 11264at7088 missing
# 9108at7088 missing
# 3161at7088 missing
# 4645at7088 missing
# 4118at7088 missing
# 13532at7088 missing
# 10319at7088 missing
# run  965
# 1504at7088 missing
# 16088at7088 missing
# 15939at7088 missing
# 12660at7088 missing
# 7506at7088 missing
# 3161at7088 missing
# run  966
# 16513at7088 missing
# 6083at7088 missing
# 7506at7088 missing
# 12834at7088 missing
# 10546at7088 missing
# 11264at7088 missing
# run  967
# 11264at7088 missing
# 5251at7088 missing
# 6083at7088 missing
# 7506at7088 missing
# 7400at7088 missing
# 8001at7088 missing
# run  968
# 7400at7088 missing
# 14179at7088 missing
# 15939at7088 missing
# 16513at7088 missing
# 12834at7088 missing
# 9108at7088 missing
# 11558at7088 missing
# 4645at7088 missing
# 4118at7088 missing
# 14521at7088 missing
# 3161at7088 missing
# run  969
# 3493at7088 missing
# 1504at7088 missing
# run  970
# 9544at7088 missing
# 11066at7088 missing
# 4645at7088 missing
# 4118at7088 missing
# 10387at7088 missing
# 15939at7088 missing
# run  971
# 7506at7088 missing
# 13532at7088 missing
# 3212at7088 missing
# 10387at7088 missing
# 12632at7088 missing
# run  972
# 10387at7088 missing
# 14404at7088 missing
# 8811at7088 missing
# 9544at7088 missing
# 11066at7088 missing
# 12660at7088 missing
# run  973
# 9108at7088 missing
# 12660at7088 missing
# 10333at7088 missing
# 11558at7088 missing
# 7506at7088 missing
# 9544at7088 missing
# 8001at7088 missing
# 15939at7088 missing
# run  974
# 11066at7088 missing
# 11558at7088 missing
# 9108at7088 missing
# 8811at7088 missing
# 3212at7088 missing
# run  975
# 8811at7088 missing
# 3212at7088 missing
# 9108at7088 missing
# 5251at7088 missing
# 14404at7088 missing
# 3493at7088 missing
# 4645at7088 missing
# run  976
# 4645at7088 missing
# 5251at7088 missing
# 9544at7088 missing
# 12632at7088 missing
# 13532at7088 missing
# 8811at7088 missing
# run  977
# 5251at7088 missing
# run  978
# 15939at7088 missing
# 16513at7088 missing
# 10546at7088 missing
# 11264at7088 missing
# 13532at7088 missing
# 12632at7088 missing
# run  979
# 4967at7088 missing
# 4118at7088 missing
# 14404at7088 missing
# 5251at7088 missing
# 10546at7088 missing
# run  980
# 13532at7088 missing
# 7506at7088 missing
# 10319at7088 missing
# 13972at7088 missing
# 15939at7088 missing
# 9544at7088 missing
# 12834at7088 missing
# run  981
# 16088at7088 missing
# 10319at7088 missing
# 12632at7088 missing
# 5251at7088 missing
# run  982
# 7357at7088 missing
# 9108at7088 missing
# 10333at7088 missing
# 4118at7088 missing
# 7400at7088 missing
# 12632at7088 missing
# 12660at7088 missing
# 3212at7088 missing
# run  983
# 10333at7088 missing
# 3161at7088 missing
# 16513at7088 missing
# run  984
# 15939at7088 missing
# 5251at7088 missing
# 7357at7088 missing
# 4645at7088 missing
# 13532at7088 missing
# 12834at7088 missing
# 4118at7088 missing
# 13972at7088 missing
# run  985
# 14179at7088 missing
# 5251at7088 missing
# 16513at7088 missing
# 12660at7088 missing
# 10546at7088 missing
# 3161at7088 missing
# 10387at7088 missing
# 11264at7088 missing
# 12632at7088 missing
# 14521at7088 missing
# run  986
# 10333at7088 missing
# 11558at7088 missing
# 11066at7088 missing
# 14179at7088 missing
# 10387at7088 missing
# run  987
# 14179at7088 missing
# 11558at7088 missing
# 8001at7088 missing
# 8811at7088 missing
# run  988
# 14521at7088 missing
# 4967at7088 missing
# 10387at7088 missing
# 14179at7088 missing
# 16513at7088 missing
# 16088at7088 missing
# run  989
# 14521at7088 missing
# 7400at7088 missing
# 16513at7088 missing
# 10333at7088 missing
# run  990
# 4967at7088 missing
# 1504at7088 missing
# run  991
# 15939at7088 missing
# 12632at7088 missing
# 3161at7088 missing
# 14404at7088 missing
# run  992
# 6083at7088 missing
# 11558at7088 missing
# 12834at7088 missing
# 15939at7088 missing
# 10319at7088 missing
# run  993
# 8001at7088 missing
# 14521at7088 missing
# 15939at7088 missing
# 4118at7088 missing
# 10546at7088 missing
# 14404at7088 missing
# 14179at7088 missing
# run  994
# 3493at7088 missing
# 14521at7088 missing
# 8811at7088 missing
# 3161at7088 missing
# run  995
# 6083at7088 missing
# 15939at7088 missing
# run  996
# 3212at7088 missing
# 8811at7088 missing
# run  997
# 10546at7088 missing
# 4967at7088 missing
# 1504at7088 missing
# 9544at7088 missing
# 16088at7088 missing
# 9108at7088 missing
# 10387at7088 missing
# run  998
# 14404at7088 missing
# 16088at7088 missing
# 8001at7088 missing
# run  999
# 7357at7088 missing
# 4967at7088 missing
# 5251at7088 missing
# 7400at7088 missing
# 9108at7088 missing
# 13972at7088 missing
# 1504at7088 missing
# [90, 108, 116, 108, 95, 111, 126, 122, 109, 111, 97, 123, 109, 120, 108, 115, 110, 91, 114, 109, 116, 112, 120, 111, 102, 110, 104, 101, 104, 103, 101, 108, 108, 104, 119, 104, 121, 112, 113, 112, 114, 100, 112, 123, 108, 111, 118, 130, 129, 107, 117, 113, 119, 104, 110, 107, 124, 112, 116, 123, 110, 108, 115, 113, 119, 92, 98, 107, 121, 110, 119, 121, 98, 100, 107, 129, 104, 99, 106, 99, 105, 123, 101, 106, 116, 105, 104, 119, 108, 114, 98, 111, 105, 95, 118, 105, 102, 103, 102, 123, 106, 111, 96, 106, 113, 116, 105, 102, 92, 90, 102, 110, 124, 124, 105, 114, 120, 102, 108, 110, 106, 112, 103, 104, 100, 96, 89, 118, 112, 114, 118, 114, 113, 107, 103, 117, 105, 100, 110, 106, 105, 107, 132, 109, 130, 107, 126, 116, 96, 110, 122, 93, 108, 109, 121, 111, 106, 90, 109, 117, 112, 93, 116, 91, 97, 106, 103, 91, 119, 101, 106, 104, 113, 117, 111, 94, 102, 106, 124, 114, 107, 123, 112, 113, 120, 102, 104, 103, 111, 117, 108, 97, 124, 124, 103, 115, 103, 112, 104, 112, 105, 121, 110, 92, 119, 104, 111, 97, 117, 127, 98, 96, 102, 92, 109, 107, 117, 110, 108, 122, 108, 100, 112, 107, 115, 92, 103, 109, 111, 116, 130, 111, 120, 114, 111, 114, 108, 101, 109, 105, 123, 102, 122, 104, 111, 121, 112, 111, 107, 116, 131, 112, 118, 119, 114, 85, 115, 114, 124, 113, 115, 114, 102, 130, 111, 111, 104, 101, 97, 123, 105, 105, 107, 112, 100, 115, 87, 109, 101, 124, 122, 98, 127, 110, 109, 115, 102, 105, 96, 110, 117, 105, 113, 110, 102, 108, 112, 125, 109, 102, 98, 112, 109, 115, 107, 110, 104, 110, 115, 120, 117, 112, 116, 108, 113, 96, 102, 128, 103, 101, 100, 117, 105, 122, 104, 88, 103, 113, 96, 100, 103, 128, 104, 121, 101, 113, 112, 115, 116, 129, 105, 107, 93, 107, 105, 108, 113, 96, 106, 100, 113, 113, 93, 110, 128, 85, 106, 89, 104, 106, 112, 125, 103, 120, 102, 116, 108, 110, 104, 121, 119, 91, 120, 121, 132, 113, 106, 115, 114, 116, 116, 112, 108, 116, 125, 115, 106, 118, 103, 109, 114, 91, 111, 104, 122, 106, 107, 111, 100, 108, 109, 109, 113, 125, 112, 112, 115, 124, 106, 98, 93, 114, 111, 108, 124, 109, 109, 111, 119, 113, 108, 105, 96, 113, 96, 104, 110, 102, 102, 121, 119, 98, 108, 106, 107, 100, 110, 111, 119, 93, 116, 105, 102, 100, 100, 116, 104, 110, 110, 102, 119, 104, 103, 114, 109, 117, 114, 127, 103, 95, 125, 106, 93, 92, 113, 120, 105, 117, 103, 113, 114, 111, 114, 125, 97, 106, 108, 128, 117, 107, 111, 120, 103, 107, 104, 112, 120, 129, 118, 92, 112, 90, 112, 103, 115, 112, 117, 115, 122, 101, 116, 114, 97, 111, 90, 133, 128, 101, 101, 108, 98, 105, 114, 126, 126, 124, 125, 106, 122, 110, 112, 125, 121, 109, 121, 112, 111, 104, 110, 125, 99, 103, 104, 109, 95, 132, 114, 114, 89, 120, 101, 97, 104, 104, 113, 102, 92, 96, 122, 91, 99, 106, 102, 101, 110, 102, 108, 110, 106, 113, 102, 113, 101, 103, 105, 108, 104, 115, 103, 98, 98, 103, 87, 111, 113, 108, 106, 97, 98, 105, 105, 105, 117, 103, 100, 112, 117, 108, 106, 111, 121, 131, 108, 103, 107, 120, 111, 97, 107, 96, 116, 123, 117, 121, 99, 96, 103, 98, 115, 117, 119, 119, 85, 94, 109, 102, 105, 97, 107, 100, 111, 107, 110, 116, 108, 102, 109, 102, 106, 138, 99, 111, 112, 89, 121, 116, 108, 111, 123, 118, 106, 109, 123, 124, 112, 91, 108, 106, 120, 129, 107, 114, 106, 106, 116, 112, 113, 107, 102, 104, 100, 97, 115, 115, 117, 110, 112, 85, 107, 107, 113, 129, 111, 127, 119, 111, 92, 87, 108, 111, 95, 132, 107, 112, 108, 103, 91, 103, 99, 116, 115, 121, 114, 108, 113, 108, 127, 113, 92, 106, 108, 108, 105, 96, 107, 111, 109, 120, 94, 109, 120, 122, 118, 112, 109, 119, 100, 108, 115, 121, 108, 111, 110, 112, 102, 105, 133, 107, 120, 112, 120, 101, 109, 94, 119, 104, 99, 98, 114, 112, 105, 109, 115, 111, 113, 116, 117, 114, 122, 109, 121, 114, 109, 111, 107, 113, 107, 102, 102, 114, 124, 121, 112, 98, 110, 113, 101, 99, 114, 104, 105, 108, 92, 123, 111, 106, 111, 115, 111, 114, 99, 113, 124, 112, 121, 114, 109, 107, 121, 103, 119, 99, 98, 110, 104, 115, 98, 108, 101, 106, 117, 128, 104, 124, 102, 120, 110, 112, 114, 108, 91, 112, 109, 117, 118, 117, 94, 108, 106, 121, 118, 13 ...

# %%
# import numpy as np
# # print((intersecting_genes_length_list))
# str_list = ""
# for num in intersecting_genes_length_list:
#     str_list += f"{num}\n"
# with open(f"{location}/4.Intersections_test/10000_runs_5kb.txt", 'w') as out_file:
#     out_file.write(str_list)

# %%
import matplotlib.pyplot as plt

# Sample data
data = intersecting_genes_length_list

# Define bins with size = 1
min_bin = min(data)
max_bin = max(data)
bins = range(min_bin, max_bin + 2)  # +2 to include the last value properly

# Plot
plt.figure(figsize=(20, 20))
plt.hist(data, bins=bins, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Bin Size = 1')
plt.xticks(bins)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Always show details
import scipy.stats as stats

# Updated list of observations
observations = intersecting_genes_length_list

# [7, 7, 4, 7, 10, 2, 7, 10, 5, 10, 1, 0, 5, 4, 6, 7, 6, 9, 5, 1, 8, 7, 2, 10, 7, 9, 3, 11, 9, 0, 9, 5, 5, 2, 0, 12, 3, 6, 4, 2, 9, 5, 3, 2, 8, 2, 0, 6, 6, 1, 12, 3, 1, 3, 8, 12, 8, 0, 6, 4, 0, 7, 2, 7, 10, 2, 7, 3, 3, 1, 13, 8, 11, 8, 1, 6, 3, 0, 6, 5, 7, 2, 2, 7, 0, 11, 7, 9, 10, 8, 2, 4, 8, 7, 0, 3, 5, 0, 4, 8, 6, 4, 8, 1, 3, 5, 6, 6, 6, 0, 4, 6, 4, 2, 4, 4, 5, 10, 10, 0, 5, 3, 1, 7, 5, 2, 0, 0, 3, 0, 7, 8, 10, 6, 3, 4, 2, 8, 8, 0, 7, 5, 0, 7, 6, 5, 1, 0, 9, 7, 1, 13, 2, 10, 3, 9, 9, 5, 1, 5, 6, 7, 1, 2, 10, 8, 7, 1, 7, 6, 9, 5, 0, 11, 0, 0, 6, 2, 1, 1, 1, 6, 4, 9, 8, 4, 5, 9, 4, 15, 9, 0, 2, 0, 1, 3, 10, 3, 9, 3, 4, 2, 1, 7, 4, 1, 1, 5, 3, 4, 14, 0, 0, 5, 5, 8, 7, 0]

# Calculate the proportion of values greater than or equal to 10
value_of_interest = final_gene_number
print(value_of_interest)
count_extreme = sum(x >= value_of_interest for x in observations)
p_value = count_extreme / len(observations)

p_value
# Out:
# 120
# 0.142
