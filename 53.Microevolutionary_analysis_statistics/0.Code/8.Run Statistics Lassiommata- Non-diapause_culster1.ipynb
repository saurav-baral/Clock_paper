# %% [markdown]
# ## Expand Gene identities

# %%
# %reset
import pandas as pd
# location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/1.Lasiomatta_megera"

# gene_table = pd.read_csv(f"{location}/2.Annotation_busco_prediction/full_table.tsv", sep= "\t")
# gene_table

# %%
# output = "Busco_id\tChromosome\tGene_Start\tGene_End"
# for row_details in gene_table.itertuples():
#     if not(pd.isna(row_details.Sequence)):
#         if row_details.Gene_Start > row_details.Gene_End:
#             gene_start = row_details.Gene_End
#             gene_end = row_details.Gene_Start
#         else:
#             gene_start = row_details.Gene_Start
#             gene_end = row_details.Gene_End
#         try:
#             output += f"\n{row_details.Busco_id}\t{row_details.Sequence}\t{int(max(0,gene_start-10000))}\t{int(gene_end+10000)}"
#         except:
#             print(row_details.Busco_id, gene_end+20000)
#             assert False
#     # print(row_details)
#     # break
# with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'w') as out_file:
#     out_file.write(output)

# %%
fst_dictionary = {}
with open(f"{location}/1.FST_peaks_from_chris/two_pool_1%_0.154_5kb_merged.fst",'r') as fst_file:
    for fst_lines in fst_file.readlines()[1:]:
        line_split = fst_lines.strip().split(",")
        fst_dictionary.setdefault(line_split[0],[])
        
        fst_dictionary[line_split[0]].append([int(line_split[1]), int(line_split[2])])
        
print(fst_dictionary)
# Out:
# {'1': [[46001, 75000], [949001, 950000], [987001, 988000], [2242001, 2243000], [2505001, 2506000], [2673001, 2674000], [2683001, 2684000], [2790001, 2791000], [3428001, 3430000], [3440001, 3441000], [3645001, 3646000], [4547001, 4548000], [4637001, 4638000], [4643001, 4644000], [4666001, 4667000], [4686001, 4691000], [4711001, 4713000], [4989001, 4990000], [5147001, 5148000], [5161001, 5162000], [5942001, 5944000], [5949001, 5955000], [6140001, 6153000], [6159001, 6167000], [6607001, 6608000], [6855001, 6861000], [6896001, 6897000], [7664001, 7669000], [7847001, 7848000], [7909001, 7910000], [7915001, 7916000], [7937001, 7938000], [7946001, 7953000], [8129001, 8130000], [8221001, 8229000], [8251001, 8252000], [8731001, 8733000], [8904001, 8905000], [9085001, 9086000], [9723001, 9724000], [10017001, 10018000], [10960001, 10961000], [10997001, 10998000], [11570001, 11571000], [12031001, 12032000], [12159001, 12160000], [12212001, 12218000], [12339001, 12340000], [12365001, 12366000], [12654001, 12659000], [12692001, 12693000], [12731001, 12732000], [12792001, 12793000], [12879001, 12883000], [12888001, 12890000], [13180001, 13181000], [13190001, 13191000], [13966001, 13967000], [14555001, 14557000], [15053001, 15054000], [15655001, 15657000], [15753001, 15754000], [15762001, 15771000], [15782001, 15783000], [15822001, 15823000], [15931001, 15932000], [16114001, 16115000], [16715001, 16716000], [18372001, 18381000], [18871001, 18872000], [19243001, 19249000], [19782001, 19785000], [19898001, 19899000], [20610001, 20611000]], '10': [[354001, 355000], [395001, 396000], [751001, 752000], [781001, 782000], [1762001, 1763000], [2363001, 2364000], [2380001, 2381000], [2501001, 2502000], [3480001, 3481000], [3621001, 3626000], [3639001, 3643000], [3653001, 3654000], [3829001, 3830000], [4512001, 4513000], [4860001, 4861000], [5316001, 5317000], [5780001, 5781000], [5793001, 5794000], [5813001, 5819000], [5825001, 5828000], [5866001, 5867000], [5912001, 5913000], [5922001, 5925000], [6366001, 6367000], [6378001, 6379000], [6706001, 6707000], [7519001, 7520000], [7554001, 7555000], [7629001, 7632000], [7722001, 7723000], [8196001, 8197000], [8543001, 8548000], [8555001, 8559000], [8652001, 8653000], [8670001, 8671000], [10034001, 10035000], [10078001, 10083000], [10204001, 10214000], [10219001, 10222000], [10227001, 10228000], [10237001, 10244000], [10265001, 10266000], [10284001, 10285000], [11320001, 11321000], [11337001, 11345000], [11366001, 11367000], [11374001, 11375000], [11383001, 11384000], [11408001, 11418000], [11605001, 11613000], [11705001, 11706000], [11869001, 11870000], [12015001, 12018000], [12030001, 12046000], [12051001, 12053000], [12472001, 12473000], [12485001, 12490000], [12886001, 12887000], [13305001, 13306000], [13932001, 13933000], [14478001, 14479000], [14532001, 14537000], [14722001, 14723000], [14913001, 14916000], [14927001, 14928000], [15314001, 15315000], [15394001, 15395000], [15461001, 15462000], [15472001, 15473000], [15547001, 15548000], [15555001, 15556000], [16245001, 16249000], [16263001, 16264000], [16354001, 16355000], [16368001, 16373000], [16384001, 16385000], [16407001, 16408000], [16461001, 16462000], [16575001, 16576000], [16828001, 16829000], [16877001, 16882000], [16977001, 16978000], [17075001, 17076000], [17120001, 17126000], [17131001, 17134000], [17160001, 17161000], [17310001, 17312000], [17319001, 17320000], [17325001, 17337000], [17359001, 17360000], [17610001, 17611000], [17657001, 17658000], [17707001, 17711000], [17720001, 17721000], [17769001, 17772000], [17844001, 17845000], [17941001, 17942000]], '11': [[1420001, 1421000], [1443001, 1444000], [1920001, 1921000], [2772001, 2773000], [2781001, 2782000], [3000001, 3001000], [3327001, 3328000], [3780001, 3781000], [3830001, 3831000], [3850001, 3851000], [4202001, 4206000], [4932001, 4933000], [5143001, 5144000], [5422001, 5423000], [5485001, 5486000], [5612001, 5613000], [5768001, 5769000], [6825001, 6826000], [7162001, 7163000], [ ...

# %%
gene_loc_dic = {}
with open(f"{location}/2.Annotation_busco_prediction/padded_10k.tsv", 'r') as gene_loc_file:
    for gene_line in gene_loc_file.readlines()[1:]:
        line_split = gene_line.strip().split("\t")
        gene_loc_dic[line_split[0]] = [line_split[1],line_split[2],line_split[3]]
# print(gene_loc_dic)

# %%
# output_rho_set_location = "Gene,Chromosome,Location"
# with open(f"{location}/3.Rho_set_genes/Rho_set_gene2.txt", 'r') as rho_set_file:
#     for lines in rho_set_file.readlines():
#         rho_gene_name = lines.strip().split("\t")[0]
#         # print(lines.strip(),gene_loc_dic[lines.strip()])
#         # print(rho_gene_name)
#         chromosome,start,end = gene_loc_dic[rho_gene_name]
#         # print(chromosome,start,end)
#         output_rho_set_location +=  f"\n{rho_gene_name},{chromosome},{start}"

# # print(output_rho_set_location)
# with open(f"{location}/3.Rho_set_genes/Rho_set_location.csv", 'w') as rho_out_file:
#     rho_out_file.write(output_rho_set_location)

# %%
intersecting_genes = []
with open(f"{location}/3.Rho_set_genes/rho_set_cluster_1_non_diapause.txt", 'r') as rho_set_file:
    for rho_set_count,lines in enumerate(rho_set_file.readlines()):
        rho_gene_name = lines.strip().split("\t")[0]
        # print(lines.strip(),gene_loc_dic[lines.strip()])
        try:
            chromosome,start,end = gene_loc_dic[rho_gene_name]
        except:
            continue
        # print(chromosome,start,end)
        for sections in (fst_dictionary[chromosome]):
            # print(sections)
            if ((int(start) >= sections[0] and int(start) <= sections[1]) or (int(end) >= sections[0] and int(end) <= sections[1])) or ((sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))):
                # print(sections)
                print(lines, end = "")
                intersecting_genes.append(rho_gene_name)
                break
            # elif (sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))
        # break
print("\n",len(intersecting_genes), rho_set_count, len(set((intersecting_genes))))
final_gene_number = len(intersecting_genes)
# Out:
# 1789at7088
# 1718at7088
# 4176at7088
# 5708at7088
# 11218at7088
# 9169at7088
# 6386at7088
# 9768at7088
# 4350at7088
# 68at7088
# 9647at7088
# 1090at7088
# 1662at7088
# 4078at7088
# 7479at7088
# 4089at7088
# 15237at7088
# 1851at7088
# 3220at7088
# 11619at7088
# 6673at7088
# 2021at7088
# 2273at7088
# 7260at7088
# 7909at7088
# 4799at7088
# 2938at7088
# 2003at7088
# 1130at7088
# 2136at7088
# cycle
# 9534at7088
# 360at7088
#
#  33 150 33

# %%
gene_anno_dic = {}
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/19.Evolutionary_rate_co-variation(ERC)/2.Two_state/correlation_2_with_annotation.csv", 'r') as cor_file:
    for lines in cor_file.readlines()[1:]:
        gene_name = lines.split(",")[0].split("_")[0][1:]
        anno_name = lines.split(",")[-1].replace('"', '')
        gene_anno_dic[gene_name]= anno_name.strip()

# %%
# instersecting_genes_output = ""
# for intersecting_gene_name in intersecting_genes:
#     if intersecting_gene_name in gene_anno_dic:
#         instersecting_genes_output += gene_anno_dic[intersecting_gene_name] + "\n"
#     else:
#         instersecting_genes_output += intersecting_gene_name + "\n"
# # print(intersecting_genes)
# with open(f"{location}/4.Intersections_test/intersection_set.txt", 'w') as out_file:
#     out_file.write(instersecting_genes_output)
# # print(instersecting_genes_output)

# %%
# instersecting_genes_output = "geneid\n"+"\n".join(set(intersecting_genes))
# with open(f"{location}/4.Intersections_test/1.For GSEA/1.Rho Set/intersection_set.txt", 'w') as out_file:
#     out_file.write(instersecting_genes_output)

# %%
busco_gene_list = []
with open(f"/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/0.Gene_id_list/Busco_gene_id.txt",'r') as busco_gene_list_file:
    for lines in busco_gene_list_file:
        busco_gene_list.append(lines.strip())
print(len(busco_gene_list))
# Out:
# 4564

# %%
rho_set_size = rho_set_count
import random
intersecting_genes_length_list = []
for i in range(1000):
    print("run ",i)
    test_gene_list = random.sample(busco_gene_list, rho_set_size)
    # print(len(test_gene_list), len(set(test_gene_list)))
    # assert False
    intersecting_genes = []
    for gene_name in test_gene_list:
        try:
            chromosome,start,end = gene_loc_dic[gene_name]
        except:
            print(gene_name, "missing")
            pass
        # print(chromosome,start,end)
        try:
            for sections in (fst_dictionary[chromosome]):
                # print(sections)
                if ((int(start) >= sections[0] and int(start) <= sections[1]) or (int(end) >= sections[0] and int(end) <= sections[1])) or ((sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))):
                    # print(sections)
                    # print(gene_name,chromosome,start,end)
                    intersecting_genes.append(gene_name)
                    break
                    # elif (sections[0] >= int(start) and sections[0] <= int(end)) or (sections[1] >= int(start) and sections[1] <= int(end))
                # break
        except:
            pass
    intersecting_genes_length_list.append(len(intersecting_genes))
print((intersecting_genes_length_list))
# Out:
# run  0
# 7357at7088 missing
# run  1
# 7506at7088 missing
# 8001at7088 missing
# run  2
# 3161at7088 missing
# run  3
# 10546at7088 missing
# run  4
# 10319at7088 missing
# 13972at7088 missing
# 1504at7088 missing
# 14404at7088 missing
# run  5
# 16088at7088 missing
# 11558at7088 missing
# run  6
# 9108at7088 missing
# 13532at7088 missing
# 12660at7088 missing
# run  7
# 7400at7088 missing
# 9108at7088 missing
# run  8
# 1504at7088 missing
# 8811at7088 missing
# run  9
# run  10
# 11558at7088 missing
# run  11
# 4118at7088 missing
# 11066at7088 missing
# run  12
# 11558at7088 missing
# 5251at7088 missing
# run  13
# run  14
# 11558at7088 missing
# 11066at7088 missing
# run  15
# 10319at7088 missing
# 9108at7088 missing
# run  16
# 12834at7088 missing
# run  17
# run  18
# 10387at7088 missing
# 6083at7088 missing
# run  19
# 5251at7088 missing
# 10546at7088 missing
# run  20
# run  21
# 11264at7088 missing
# 11558at7088 missing
# 15939at7088 missing
# 3493at7088 missing
# run  22
# 3161at7088 missing
# 4967at7088 missing
# run  23
# run  24
# 7506at7088 missing
# 7400at7088 missing
# 3493at7088 missing
# run  25
# 7357at7088 missing
# run  26
# run  27
# run  28
# 9108at7088 missing
# run  29
# 7357at7088 missing
# run  30
# 16088at7088 missing
# 4118at7088 missing
# run  31
# run  32
# 14179at7088 missing
# run  33
# 16513at7088 missing
# run  34
# 12632at7088 missing
# 13972at7088 missing
# run  35
# 14521at7088 missing
# run  36
# run  37
# 10319at7088 missing
# 11264at7088 missing
# 3161at7088 missing
# run  38
# 4645at7088 missing
# run  39
# 1504at7088 missing
# 11558at7088 missing
# 16513at7088 missing
# run  40
# 3161at7088 missing
# 14179at7088 missing
# 14404at7088 missing
# run  41
# 9544at7088 missing
# 14179at7088 missing
# 10387at7088 missing
# run  42
# run  43
# run  44
# run  45
# 1504at7088 missing
# run  46
# run  47
# run  48
# 14521at7088 missing
# 8001at7088 missing
# run  49
# run  50
# 8001at7088 missing
# run  51
# run  52
# 7506at7088 missing
# run  53
# 3493at7088 missing
# run  54
# run  55
# run  56
# run  57
# 11066at7088 missing
# run  58
# run  59
# run  60
# 3493at7088 missing
# 11066at7088 missing
# run  61
# 12834at7088 missing
# run  62
# 12834at7088 missing
# 10546at7088 missing
# run  63
# 14179at7088 missing
# run  64
# 9544at7088 missing
# run  65
# 10319at7088 missing
# run  66
# 8811at7088 missing
# 13532at7088 missing
# 6083at7088 missing
# run  67
# 7400at7088 missing
# 10387at7088 missing
# run  68
# 6083at7088 missing
# 8811at7088 missing
# run  69
# run  70
# run  71
# run  72
# 4118at7088 missing
# run  73
# 9544at7088 missing
# run  74
# 10319at7088 missing
# 7400at7088 missing
# 8811at7088 missing
# run  75
# 7357at7088 missing
# run  76
# 12660at7088 missing
# run  77
# run  78
# 7357at7088 missing
# 1504at7088 missing
# run  79
# 14521at7088 missing
# run  80
# 11066at7088 missing
# run  81
# run  82
# 10546at7088 missing
# run  83
# 3212at7088 missing
# run  84
# run  85
# 3212at7088 missing
# run  86
# 6083at7088 missing
# run  87
# run  88
# run  89
# 15939at7088 missing
# 3161at7088 missing
# run  90
# run  91
# 14179at7088 missing
# 4118at7088 missing
# run  92
# 1504at7088 missing
# run  93
# 11558at7088 missing
# 16088at7088 missing
# 4967at7088 missing
# run  94
# run  95
# 9108at7088 missing
# run  96
# run  97
# 9108at7088 missing
# 5251at7088 missing
# run  98
# 9544at7088 missing
# run  99
# 7357at7088 missing
# 7400at7088 missing
# run  100
# run  101
# 10387at7088 missing
# run  102
# run  103
# 3212at7088 missing
# 7506at7088 missing
# run  104
# 9108at7088 missing
# 16088at7088 missing
# 13972at7088 missing
# 11558at7088 missing
# run  105
# 10319at7088 missing
# 16513at7088 missing
# run  106
# 12660at7088 missing
# run  107
# run  108
# run  109
# 3161at7088 missing
# run  110
# 16513at7088 missing
# run  111
# 4118at7088 missing
# run  112
# 14179at7088 missing
# run  113
# run  114
# 3493at7088 missing
# run  115
# 11264at7088 missing
# run  116
# run  117
# 16513at7088 missing
# 13972at7088 missing
# 7506at7088 missing
# run  118
# 14521at7088 missing
# 7506at7088 missing
# run  119
# 3493at7088 missing
# run  120
# 1504at7088 missing
# run  121
# 14179at7088 missing
# 12834at7088 missing
# run  122
# 1504at7088 missing
# 7506at7088 missing
# run  123
# run  124
# 12834at7088 missing
# run  125
# 11558at7088 missing
# 13532at7088 missing
# 12834at7088 missing
# 4118at7088 missing
# run  126
# run  127
# 8001at7088 missing
# run  128
# 3212at7088 missing
# 7506at7088 missing
# run  129
# run  130
# run  131
# 6083at7088 missing
# run  132
# 9544at7088 missing
# 7506at7088 missing
# run  133
# 10546at7088 missing
# run  134
# 4118at7088 missing
# 14404at7088 missing
# run  135
# 3161at7088 missing
# run  136
# 12834at7088 missing
# 10387at7088 missing
# run  137
# 7506at7088 missing
# 9544at7088 missing
# run  138
# 13972at7088 missing
# run  139
# run  140
# run  141
# 10546at7088 missing
# 12834at7088 missing
# run  142
# run  143
# run  144
# 12660at7088 missing
# run  145
# 3212at7088 missing
# run  146
# 4118at7088 missing
# run  147
# run  148
# 11066at7088 missing
# run  149
# 5251at7088 missing
# run  150
# run  151
# 11264at7088 missing
# run  152
# 10333at7088 missing
# 9544at7088 missing
# 1504at7088 missing
# 12660at7088 missing
# 10319at7088 missing
# run  153
# 13972at7088 missing
# run  154
# run  155
# 14404at7088 missing
# 8811at7088 missing
# run  156
# 4118at7088 missing
# 16513at7088 missing
# 3212at7088 missing
# run  157
# 11264at7088 missing
# 12834at7088 missing
# run  158
# run  159
# 13532at7088 missing
# 7506at7088 missing
# run  160
# 12660at7088 missing
# run  161
# 10319at7088 missing
# run  162
# run  163
# 3493at7088 missing
# 8811at7088 missing
# run  164
# 3212at7088 missing
# 4645at7088 missing
# run  165
# run  166
# 8001at7088 missing
# run  167
# 16513at7088 missing
# 13532at7088 missing
# 3212at7088 missing
# 1504at7088 missing
# run  168
# 4967at7088 missing
# run  169
# run  170
# 8001at7088 missing
# 7357at7088 missing
# 10387at7088 missing
# run  171
# run  172
# run  173
# run  174
# run  175
# 14179at7088 missing
# run  176
# run  177
# 11558at7088 missing
# 16088at7088 missing
# run  178
# run  179
# 9544at7088 missing
# 8811at7088 missing
# run  180
# 13972at7088 missing
# run  181
# run  182
# run  183
# 4967at7088 missing
# 11066at7088 missing
# run  184
# 16513at7088 missing
# 9544at7088 missing
# run  185
# 8001at7088 missing
# run  186
# 12632at7088 missing
# 10333at7088 missing
# 12834at7088 missing
# 9108at7088 missing
# run  187
# 12660at7088 missing
# run  188
# run  189
# 8811at7088 missing
# run  190
# 12834at7088 missing
# 12632at7088 missing
# run  191
# 6083at7088 missing
# 4645at7088 missing
# run  192
# run  193
# 7400at7088 missing
# run  194
# run  195
# 3212at7088 missing
# 11066at7088 missing
# 14404at7088 missing
# run  196
# run  197
# 9108at7088 missing
# run  198
# 9544at7088 missing
# 4967at7088 missing
# run  199
# run  200
# 10333at7088 missing
# 7357at7088 missing
# run  201
# 14521at7088 missing
# 12834at7088 missing
# run  202
# 7506at7088 missing
# run  203
# 11558at7088 missing
# run  204
# 10546at7088 missing
# 14404at7088 missing
# run  205
# run  206
# 7506at7088 missing
# 4645at7088 missing
# 6083at7088 missing
# run  207
# 12660at7088 missing
# run  208
# run  209
# 7400at7088 missing
# run  210
# 6083at7088 missing
# run  211
# 16088at7088 missing
# run  212
# 9544at7088 missing
# 14404at7088 missing
# 1504at7088 missing
# run  213
# run  214
# 3493at7088 missing
# run  215
# run  216
# 11264at7088 missing
# 12660at7088 missing
# run  217
# 9108at7088 missing
# 14179at7088 missing
# run  218
# 11066at7088 missing
# 13972at7088 missing
# 8811at7088 missing
# run  219
# 11264at7088 missing
# run  220
# run  221
# run  222
# run  223
# 1504at7088 missing
# run  224
# run  225
# 15939at7088 missing
# run  226
# run  227
# run  228
# 4967at7088 missing
# run  229
# 12660at7088 missing
# 4118at7088 missing
# run  230
# 10546at7088 missing
# 4645at7088 missing
# run  231
# 16513at7088 missing
# 8811at7088 missing
# run  232
# run  233
# 7400at7088 missing
# run  234
# 7400at7088 missing
# run  235
# run  236
# 5251at7088 missing
# run  237
# 15939at7088 missing
# run  238
# run  239
# 6083at7088 missing
# 4645at7088 missing
# 3493at7088 missing
# 9108at7088 missing
# run  240
# run  241
# 9108at7088 missing
# run  242
# run  243
# 12834at7088 missing
# 16088at7088 missing
# run  244
# run  245
# run  246
# 12660at7088 missing
# 12834at7088 missing
# run  247
# 11066at7088 missing
# run  248
# 6083at7088 missing
# 11264at7088 missing
# 7357at7088 missing
# run  249
# 14521at7088 missing
# run  250
# run  251
# 13972at7088 missing
# run  252
# 13972at7088 missing
# 3212at7088 missing
# 9108at7088 missing
# run  253
# 8001at7088 missing
# 12660at7088 missing
# 10546at7088 missing
# run  254
# run  255
# 4645at7088 missing
# run  256
# run  257
# 10333at7088 missing
# 11558at7088 missing
# run  258
# 16513at7088 missing
# run  259
# 3161at7088 missing
# 4118at7088 missing
# run  260
# run  261
# 1504at7088 missing
# 7506at7088 missing
# run  262
# 6083at7088 missing
# 10387at7088 missing
# 10333at7088 missing
# run  263
# 7506at7088 missing
# 13972at7088 missing
# run  264
# 10387at7088 missing
# run  265
# 4967at7088 missing
# 13532at7088 missing
# 9544at7088 missing
# 6083at7088 missing
# run  266
# 4967at7088 missing
# 16513at7088 missing
# run  267
# 7506at7088 missing
# run  268
# 11558at7088 missing
# 11264at7088 missing
# run  269
# run  270
# 10319at7088 missing
# 16513at7088 missing
# run  271
# run  272
# 3161at7088 missing
# 11264at7088 missing
# run  273
# run  274
# 3212at7088 missing
# run  275
# run  276
# 7506at7088 missing
# 8001at7088 missing
# run  277
# 16088at7088 missing
# run  278
# 12660at7088 missing
# run  279
# 14404at7088 missing
# run  280
# 4645at7088 missing
# run  281
# run  282
# 13532at7088 missing
# run  283
# 10319at7088 missing
# 16088at7088 missing
# 15939at7088 missing
# run  284
# 13972at7088 missing
# run  285
# 10546at7088 missing
# 14404at7088 missing
# 7506at7088 missing
# run  286
# 1504at7088 missing
# run  287
# 10333at7088 missing
# run  288
# run  289
# 12660at7088 missing
# 3161at7088 missing
# 7357at7088 missing
# run  290
# run  291
# 6083at7088 missing
# run  292
# run  293
# run  294
# 1504at7088 missing
# 14404at7088 missing
# run  295
# 14404at7088 missing
# run  296
# 5251at7088 missing
# 11264at7088 missing
# 12834at7088 missing
# 1504at7088 missing
# run  297
# 6083at7088 missing
# 10387at7088 missing
# run  298
# 4118at7088 missing
# run  299
# 16513at7088 missing
# 7400at7088 missing
# run  300
# run  301
# 8001at7088 missing
# run  302
# run  303
# 13532at7088 missing
# 4118at7088 missing
# run  304
# 7506at7088 missing
# run  305
# run  306
# run  307
# run  308
# 8811at7088 missing
# 15939at7088 missing
# run  309
# 6083at7088 missing
# run  310
# 11558at7088 missing
# 15939at7088 missing
# 10333at7088 missing
# run  311
# 8001at7088 missing
# 11066at7088 missing
# run  312
# run  313
# 14521at7088 missing
# 16513at7088 missing
# run  314
# run  315
# 10333at7088 missing
# run  316
# run  317
# run  318
# run  319
# 11558at7088 missing
# run  320
# 8001at7088 missing
# run  321
# run  322
# run  323
# 10546at7088 missing
# 4967at7088 missing
# run  324
# 10546at7088 missing
# 4118at7088 missing
# run  325
# 12834at7088 missing
# run  326
# 11264at7088 missing
# run  327
# 11264at7088 missing
# run  328
# 1504at7088 missing
# run  329
# run  330
# 13532at7088 missing
# run  331
# run  332
# run  333
# 5251at7088 missing
# 14179at7088 missing
# run  334
# 10319at7088 missing
# run  335
# 12660at7088 missing
# 7506at7088 missing
# run  336
# run  337
# run  338
# run  339
# 16088at7088 missing
# 9108at7088 missing
# run  340
# 5251at7088 missing
# 11066at7088 missing
# 14521at7088 missing
# 11558at7088 missing
# run  341
# 11264at7088 missing
# 10546at7088 missing
# run  342
# run  343
# 7400at7088 missing
# run  344
# 10333at7088 missing
# 14179at7088 missing
# run  345
# run  346
# 11264at7088 missing
# 14179at7088 missing
# run  347
# 8811at7088 missing
# 14179at7088 missing
# run  348
# run  349
# run  350
# 3161at7088 missing
# 15939at7088 missing
# run  351
# 16088at7088 missing
# run  352
# 5251at7088 missing
# run  353
# 10546at7088 missing
# 8811at7088 missing
# run  354
# 16088at7088 missing
# 9544at7088 missing
# run  355
# 3212at7088 missing
# 8811at7088 missing
# run  356
# 8811at7088 missing
# 5251at7088 missing
# run  357
# 1504at7088 missing
# run  358
# 4967at7088 missing
# run  359
# 9108at7088 missing
# run  360
# run  361
# 12632at7088 missing
# run  362
# 1504at7088 missing
# 12660at7088 missing
# 8001at7088 missing
# run  363
# 14404at7088 missing
# run  364
# 5251at7088 missing
# 9544at7088 missing
# run  365
# run  366
# run  367
# 4118at7088 missing
# run  368
# 5251at7088 missing
# 4118at7088 missing
# 4645at7088 missing
# run  369
# run  370
# 3161at7088 missing
# 4118at7088 missing
# run  371
# run  372
# 11264at7088 missing
# run  373
# 7506at7088 missing
# run  374
# 12660at7088 missing
# run  375
# 3493at7088 missing
# 4645at7088 missing
# 12660at7088 missing
# run  376
# 4967at7088 missing
# 4118at7088 missing
# run  377
# 8811at7088 missing
# 14179at7088 missing
# run  378
# 4645at7088 missing
# 6083at7088 missing
# run  379
# run  380
# 11264at7088 missing
# run  381
# 7357at7088 missing
# run  382
# run  383
# run  384
# run  385
# 16513at7088 missing
# 3493at7088 missing
# run  386
# run  387
# 11558at7088 missing
# run  388
# 15939at7088 missing
# run  389
# 12660at7088 missing
# run  390
# run  391
# 4967at7088 missing
# run  392
# 12834at7088 missing
# run  393
# 16088at7088 missing
# 14179at7088 missing
# run  394
# 12834at7088 missing
# run  395
# 7357at7088 missing
# run  396
# run  397
# 12834at7088 missing
# run  398
# 7506at7088 missing
# run  399
# 5251at7088 missing
# run  400
# 5251at7088 missing
# run  401
# run  402
# 7506at7088 missing
# run  403
# 10387at7088 missing
# 16513at7088 missing
# 3212at7088 missing
# run  404
# run  405
# 14179at7088 missing
# run  406
# 15939at7088 missing
# run  407
# 8001at7088 missing
# run  408
# run  409
# 16513at7088 missing
# 9544at7088 missing
# 3212at7088 missing
# run  410
# 4967at7088 missing
# run  411
# run  412
# 12660at7088 missing
# run  413
# 7357at7088 missing
# 13532at7088 missing
# 16513at7088 missing
# run  414
# run  415
# 3493at7088 missing
# 8001at7088 missing
# 13532at7088 missing
# run  416
# 11558at7088 missing
# run  417
# 1504at7088 missing
# 11264at7088 missing
# 4118at7088 missing
# run  418
# run  419
# 9108at7088 missing
# run  420
# 12632at7088 missing
# 7357at7088 missing
# 3161at7088 missing
# run  421
# run  422
# 14179at7088 missing
# run  423
# 7506at7088 missing
# run  424
# 1504at7088 missing
# run  425
# 16088at7088 missing
# run  426
# 9108at7088 missing
# run  427
# 8001at7088 missing
# 7357at7088 missing
# run  428
# 12632at7088 missing
# run  429
# run  430
# 10387at7088 missing
# 5251at7088 missing
# 10319at7088 missing
# run  431
# run  432
# 12834at7088 missing
# run  433
# 12632at7088 missing
# run  434
# 11066at7088 missing
# run  435
# 4967at7088 missing
# run  436
# run  437
# run  438
# 7357at7088 missing
# 8001at7088 missing
# 8811at7088 missing
# run  439
# 14404at7088 missing
# run  440
# 8811at7088 missing
# 7400at7088 missing
# run  441
# 10319at7088 missing
# 3161at7088 missing
# run  442
# 10319at7088 missing
# run  443
# 4967at7088 missing
# 13972at7088 missing
# run  444
# 7400at7088 missing
# 10319at7088 missing
# run  445
# 14179at7088 missing
# run  446
# 11558at7088 missing
# run  447
# 13972at7088 missing
# 14179at7088 missing
# run  448
# 3493at7088 missing
# 7400at7088 missing
# run  449
# run  450
# 11558at7088 missing
# run  451
# run  452
# 12834at7088 missing
# run  453
# 9108at7088 missing
# 11264at7088 missing
# 15939at7088 missing
# run  454
# run  455
# 1504at7088 missing
# 3161at7088 missing
# run  456
# 14179at7088 missing
# 3161at7088 missing
# 8001at7088 missing
# run  457
# run  458
# 5251at7088 missing
# 7400at7088 missing
# run  459
# 8001at7088 missing
# 15939at7088 missing
# 16513at7088 missing
# run  460
# 11264at7088 missing
# run  461
# 10333at7088 missing
# run  462
# 8811at7088 missing
# 16513at7088 missing
# run  463
# run  464
# 16088at7088 missing
# run  465
# 10546at7088 missing
# run  466
# 10546at7088 missing
# run  467
# 10333at7088 missing
# run  468
# run  469
# run  470
# run  471
# run  472
# 10546at7088 missing
# run  473
# run  474
# 4645at7088 missing
# run  475
# run  476
# run  477
# run  478
# run  479
# run  480
# run  481
# run  482
# 11066at7088 missing
# run  483
# 12660at7088 missing
# 10546at7088 missing
# run  484
# 1504at7088 missing
# 9544at7088 missing
# 8001at7088 missing
# run  485
# 14521at7088 missing
# 10333at7088 missing
# 16088at7088 missing
# run  486
# 8001at7088 missing
# run  487
# run  488
# 12660at7088 missing
# 13532at7088 missing
# run  489
# run  490
# run  491
# run  492
# 11264at7088 missing
# 12834at7088 missing
# 9108at7088 missing
# run  493
# 7400at7088 missing
# run  494
# 14179at7088 missing
# 12660at7088 missing
# run  495
# 8811at7088 missing
# run  496
# run  497
# run  498
# 4118at7088 missing
# run  499
# 15939at7088 missing
# run  500
# 8811at7088 missing
# 16513at7088 missing
# 11264at7088 missing
# run  501
# run  502
# 7506at7088 missing
# 3493at7088 missing
# run  503
# 14179at7088 missing
# 3493at7088 missing
# run  504
# 6083at7088 missing
# run  505
# run  506
# 7506at7088 missing
# run  507
# 15939at7088 missing
# run  508
# run  509
# 11066at7088 missing
# 16088at7088 missing
# 11558at7088 missing
# run  510
# 10546at7088 missing
# run  511
# 11264at7088 missing
# run  512
# 5251at7088 missing
# 14179at7088 missing
# 9544at7088 missing
# run  513
# run  514
# run  515
# run  516
# run  517
# run  518
# run  519
# 15939at7088 missing
# run  520
# run  521
# run  522
# 16088at7088 missing
# 8001at7088 missing
# 7357at7088 missing
# run  523
# 6083at7088 missing
# 12660at7088 missing
# run  524
# 12834at7088 missing
# 8001at7088 missing
# run  525
# 11558at7088 missing
# 5251at7088 missing
# run  526
# 12632at7088 missing
# 14521at7088 missing
# run  527
# 4118at7088 missing
# 13972at7088 missing
# run  528
# 14521at7088 missing
# 16513at7088 missing
# 8811at7088 missing
# run  529
# 13972at7088 missing
# 12660at7088 missing
# run  530
# 4118at7088 missing
# run  531
# 6083at7088 missing
# 16088at7088 missing
# run  532
# run  533
# run  534
# 10546at7088 missing
# 13532at7088 missing
# run  535
# 1504at7088 missing
# 4967at7088 missing
# run  536
# 10319at7088 missing
# run  537
# 5251at7088 missing
# run  538
# run  539
# 13972at7088 missing
# 10387at7088 missing
# run  540
# run  541
# 12834at7088 missing
# run  542
# run  543
# run  544
# 13972at7088 missing
# run  545
# 16513at7088 missing
# 11066at7088 missing
# run  546
# 3493at7088 missing
# 3161at7088 missing
# 10546at7088 missing
# run  547
# 10319at7088 missing
# run  548
# 3212at7088 missing
# run  549
# 12834at7088 missing
# 14179at7088 missing
# run  550
# 5251at7088 missing
# run  551
# run  552
# 3212at7088 missing
# run  553
# 6083at7088 missing
# 1504at7088 missing
# 7357at7088 missing
# 5251at7088 missing
# run  554
# run  555
# 1504at7088 missing
# 13532at7088 missing
# run  556
# 15939at7088 missing
# run  557
# run  558
# 6083at7088 missing
# run  559
# 14521at7088 missing
# 11558at7088 missing
# run  560
# 1504at7088 missing
# run  561
# 4118at7088 missing
# run  562
# 12632at7088 missing
# run  563
# run  564
# run  565
# 9544at7088 missing
# run  566
# 12834at7088 missing
# 16088at7088 missing
# 5251at7088 missing
# run  567
# 14521at7088 missing
# 13972at7088 missing
# 12632at7088 missing
# run  568
# 4118at7088 missing
# run  569
# 14521at7088 missing
# run  570
# 13972at7088 missing
# 5251at7088 missing
# run  571
# 3161at7088 missing
# 16088at7088 missing
# 8001at7088 missing
# run  572
# run  573
# 3212at7088 missing
# run  574
# run  575
# 14404at7088 missing
# run  576
# 12834at7088 missing
# 14179at7088 missing
# run  577
# 12660at7088 missing
# 4118at7088 missing
# run  578
# 1504at7088 missing
# run  579
# 12834at7088 missing
# run  580
# run  581
# run  582
# 11558at7088 missing
# 10387at7088 missing
# 9544at7088 missing
# 11264at7088 missing
# 4967at7088 missing
# run  583
# run  584
# 15939at7088 missing
# run  585
# 16513at7088 missing
# 15939at7088 missing
# run  586
# 14179at7088 missing
# 7506at7088 missing
# 1504at7088 missing
# run  587
# 7400at7088 missing
# run  588
# 3161at7088 missing
# run  589
# 7400at7088 missing
# 10319at7088 missing
# run  590
# run  591
# 6083at7088 missing
# run  592
# 10333at7088 missing
# run  593
# 7506at7088 missing
# run  594
# 14179at7088 missing
# 16513at7088 missing
# 3493at7088 missing
# 14521at7088 missing
# 10546at7088 missing
# run  595
# 4118at7088 missing
# 14404at7088 missing
# 12632at7088 missing
# run  596
# 11558at7088 missing
# 10546at7088 missing
# run  597
# run  598
# run  599
# run  600
# run  601
# run  602
# run  603
# 13532at7088 missing
# run  604
# run  605
# 14521at7088 missing
# 10333at7088 missing
# 12660at7088 missing
# run  606
# run  607
# run  608
# 3212at7088 missing
# run  609
# 16088at7088 missing
# run  610
# 7357at7088 missing
# 11558at7088 missing
# 8001at7088 missing
# run  611
# run  612
# 10546at7088 missing
# 12834at7088 missing
# run  613
# 4645at7088 missing
# run  614
# 14179at7088 missing
# 16088at7088 missing
# run  615
# run  616
# 9544at7088 missing
# run  617
# 12660at7088 missing
# 11264at7088 missing
# 6083at7088 missing
# 10333at7088 missing
# run  618
# 13532at7088 missing
# run  619
# run  620
# 8001at7088 missing
# 10546at7088 missing
# 14521at7088 missing
# run  621
# 4967at7088 missing
# run  622
# 8001at7088 missing
# run  623
# 12632at7088 missing
# run  624
# 3493at7088 missing
# 12632at7088 missing
# 16513at7088 missing
# run  625
# 11264at7088 missing
# run  626
# 9108at7088 missing
# 1504at7088 missing
# 11066at7088 missing
# run  627
# 10546at7088 missing
# run  628
# run  629
# run  630
# 9108at7088 missing
# run  631
# 11558at7088 missing
# run  632
# 12834at7088 missing
# 14521at7088 missing
# run  633
# 7400at7088 missing
# 7506at7088 missing
# run  634
# run  635
# 16088at7088 missing
# run  636
# 12834at7088 missing
# run  637
# run  638
# 14521at7088 missing
# run  639
# run  640
# 1504at7088 missing
# run  641
# 10546at7088 missing
# run  642
# run  643
# 5251at7088 missing
# 10387at7088 missing
# 8811at7088 missing
# run  644
# run  645
# run  646
# 6083at7088 missing
# 8001at7088 missing
# run  647
# 16513at7088 missing
# 13532at7088 missing
# run  648
# 8811at7088 missing
# 7400at7088 missing
# run  649
# 3493at7088 missing
# 5251at7088 missing
# run  650
# 16088at7088 missing
# run  651
# run  652
# 13972at7088 missing
# 10319at7088 missing
# run  653
# 8811at7088 missing
# 15939at7088 missing
# 10333at7088 missing
# run  654
# run  655
# run  656
# 14521at7088 missing
# run  657
# 14521at7088 missing
# 12632at7088 missing
# run  658
# run  659
# 15939at7088 missing
# run  660
# 3161at7088 missing
# run  661
# 4967at7088 missing
# 15939at7088 missing
# run  662
# run  663
# 3161at7088 missing
# run  664
# 11066at7088 missing
# 12632at7088 missing
# run  665
# 10333at7088 missing
# run  666
# run  667
# 13532at7088 missing
# run  668
# run  669
# 16088at7088 missing
# 3161at7088 missing
# 13532at7088 missing
# 3493at7088 missing
# run  670
# 3493at7088 missing
# 4967at7088 missing
# run  671
# 8001at7088 missing
# 10387at7088 missing
# run  672
# 3212at7088 missing
# run  673
# run  674
# 6083at7088 missing
# 10546at7088 missing
# run  675
# 4645at7088 missing
# 8001at7088 missing
# run  676
# 3161at7088 missing
# 13972at7088 missing
# 14179at7088 missing
# run  677
# run  678
# 9544at7088 missing
# run  679
# run  680
# 9544at7088 missing
# 10319at7088 missing
# run  681
# 10546at7088 missing
# 10387at7088 missing
# 14521at7088 missing
# run  682
# 4645at7088 missing
# run  683
# 13972at7088 missing
# run  684
# run  685
# run  686
# 4645at7088 missing
# run  687
# run  688
# run  689
# 7357at7088 missing
# 10546at7088 missing
# run  690
# run  691
# 16513at7088 missing
# run  692
# 8811at7088 missing
# run  693
# 11264at7088 missing
# run  694
# 1504at7088 missing
# run  695
# run  696
# 12632at7088 missing
# run  697
# 12632at7088 missing
# run  698
# 3212at7088 missing
# run  699
# 4967at7088 missing
# 6083at7088 missing
# run  700
# run  701
# run  702
# 13972at7088 missing
# run  703
# 10319at7088 missing
# 7506at7088 missing
# run  704
# run  705
# 13972at7088 missing
# run  706
# 3161at7088 missing
# run  707
# run  708
# 10387at7088 missing
# 11066at7088 missing
# 13972at7088 missing
# run  709
# 7506at7088 missing
# run  710
# 10546at7088 missing
# run  711
# 9108at7088 missing
# run  712
# 10333at7088 missing
# run  713
# 12632at7088 missing
# 12660at7088 missing
# run  714
# 12632at7088 missing
# 3212at7088 missing
# run  715
# 3212at7088 missing
# 3493at7088 missing
# run  716
# run  717
# run  718
# run  719
# run  720
# run  721
# 9108at7088 missing
# run  722
# 10319at7088 missing
# run  723
# 14404at7088 missing
# 8001at7088 missing
# 6083at7088 missing
# run  724
# run  725
# 1504at7088 missing
# run  726
# 10546at7088 missing
# run  727
# 8811at7088 missing
# run  728
# run  729
# 8001at7088 missing
# run  730
# run  731
# 11558at7088 missing
# run  732
# 12660at7088 missing
# 12632at7088 missing
# 16088at7088 missing
# 15939at7088 missing
# run  733
# run  734
# 10333at7088 missing
# 6083at7088 missing
# run  735
# 3493at7088 missing
# run  736
# run  737
# run  738
# 12834at7088 missing
# run  739
# 16513at7088 missing
# run  740
# run  741
# 4118at7088 missing
# run  742
# run  743
# 7400at7088 missing
# 7506at7088 missing
# 5251at7088 missing
# run  744
# 4118at7088 missing
# run  745
# 15939at7088 missing
# 10319at7088 missing
# run  746
# 3212at7088 missing
# run  747
# run  748
# 14521at7088 missing
# run  749
# run  750
# 15939at7088 missing
# run  751
# run  752
# run  753
# 10333at7088 missing
# 7506at7088 missing
# run  754
# 4118at7088 missing
# run  755
# 10546at7088 missing
# 9544at7088 missing
# 11558at7088 missing
# run  756
# 16513at7088 missing
# 3161at7088 missing
# 1504at7088 missing
# run  757
# run  758
# 11264at7088 missing
# run  759
# 7400at7088 missing
# 8001at7088 missing
# 14521at7088 missing
# run  760
# 7357at7088 missing
# 4645at7088 missing
# run  761
# 8001at7088 missing
# run  762
# 7506at7088 missing
# 13972at7088 missing
# run  763
# 3493at7088 missing
# 16088at7088 missing
# 8001at7088 missing
# run  764
# run  765
# 14521at7088 missing
# 11558at7088 missing
# run  766
# 9544at7088 missing
# 11264at7088 missing
# run  767
# 12834at7088 missing
# 13972at7088 missing
# run  768
# run  769
# 12632at7088 missing
# 11264at7088 missing
# run  770
# 9108at7088 missing
# run  771
# run  772
# run  773
# 11558at7088 missing
# 4967at7088 missing
# run  774
# 14404at7088 missing
# run  775
# 1504at7088 missing
# 10387at7088 missing
# 6083at7088 missing
# run  776
# 8811at7088 missing
# run  777
# 9544at7088 missing
# run  778
# run  779
# 11264at7088 missing
# 11066at7088 missing
# run  780
# 16088at7088 missing
# run  781
# run  782
# run  783
# run  784
# run  785
# 10387at7088 missing
# 14521at7088 missing
# run  786
# 3212at7088 missing
# run  787
# 3493at7088 missing
# 3161at7088 missing
# run  788
# 14404at7088 missing
# run  789
# 5251at7088 missing
# 16088at7088 missing
# 13972at7088 missing
# run  790
# run  791
# 9544at7088 missing
# 8001at7088 missing
# run  792
# run  793
# run  794
# 9108at7088 missing
# run  795
# 7400at7088 missing
# 6083at7088 missing
# 16088at7088 missing
# run  796
# 3493at7088 missing
# run  797
# run  798
# 13532at7088 missing
# run  799
# 16513at7088 missing
# run  800
# 7357at7088 missing
# run  801
# run  802
# run  803
# run  804
# 11264at7088 missing
# 16513at7088 missing
# run  805
# run  806
# run  807
# run  808
# 4645at7088 missing
# 9108at7088 missing
# run  809
# 13972at7088 missing
# 9544at7088 missing
# 9108at7088 missing
# 7400at7088 missing
# run  810
# 9108at7088 missing
# run  811
# 3212at7088 missing
# run  812
# 8001at7088 missing
# run  813
# 9544at7088 missing
# run  814
# 1504at7088 missing
# run  815
# run  816
# 7400at7088 missing
# run  817
# run  818
# 3493at7088 missing
# 4118at7088 missing
# run  819
# run  820
# 10319at7088 missing
# run  821
# run  822
# run  823
# run  824
# 12632at7088 missing
# 7357at7088 missing
# 11264at7088 missing
# run  825
# 14404at7088 missing
# run  826
# 11558at7088 missing
# 14521at7088 missing
# run  827
# 16088at7088 missing
# run  828
# 12632at7088 missing
# 6083at7088 missing
# 9544at7088 missing
# run  829
# 16513at7088 missing
# run  830
# run  831
# 11558at7088 missing
# run  832
# 16088at7088 missing
# run  833
# 12632at7088 missing
# run  834
# 14404at7088 missing
# run  835
# run  836
# 7506at7088 missing
# 3212at7088 missing
# run  837
# 11558at7088 missing
# run  838
# 11558at7088 missing
# 13972at7088 missing
# run  839
# 11066at7088 missing
# run  840
# run  841
# 10387at7088 missing
# run  842
# run  843
# 8001at7088 missing
# 10333at7088 missing
# run  844
# run  845
# 6083at7088 missing
# 3493at7088 missing
# 9544at7088 missing
# run  846
# run  847
# run  848
# run  849
# run  850
# 10546at7088 missing
# run  851
# run  852
# 11066at7088 missing
# run  853
# 12660at7088 missing
# 3212at7088 missing
# run  854
# 3493at7088 missing
# 16088at7088 missing
# run  855
# run  856
# 1504at7088 missing
# 7400at7088 missing
# 13532at7088 missing
# 8811at7088 missing
# run  857
# 9108at7088 missing
# 3161at7088 missing
# run  858
# 4118at7088 missing
# run  859
# run  860
# 6083at7088 missing
# 3161at7088 missing
# run  861
# 15939at7088 missing
# run  862
# 3161at7088 missing
# 11558at7088 missing
# run  863
# 11066at7088 missing
# run  864
# 12834at7088 missing
# 13532at7088 missing
# 4118at7088 missing
# run  865
# 4118at7088 missing
# 13972at7088 missing
# run  866
# 12632at7088 missing
# run  867
# run  868
# run  869
# 8001at7088 missing
# run  870
# run  871
# 12632at7088 missing
# run  872
# 11066at7088 missing
# run  873
# 7506at7088 missing
# run  874
# 10333at7088 missing
# run  875
# run  876
# 16088at7088 missing
# run  877
# 14521at7088 missing
# 10546at7088 missing
# run  878
# run  879
# 16088at7088 missing
# run  880
# 12632at7088 missing
# run  881
# 12632at7088 missing
# 14179at7088 missing
# run  882
# run  883
# 11066at7088 missing
# run  884
# 8001at7088 missing
# run  885
# 14521at7088 missing
# 9544at7088 missing
# run  886
# 15939at7088 missing
# run  887
# 14404at7088 missing
# 13532at7088 missing
# run  888
# 12660at7088 missing
# 9544at7088 missing
# run  889
# run  890
# 4645at7088 missing
# run  891
# 7506at7088 missing
# 16513at7088 missing
# run  892
# 14521at7088 missing
# 9544at7088 missing
# run  893
# run  894
# 10387at7088 missing
# run  895
# run  896
# run  897
# run  898
# 5251at7088 missing
# 4118at7088 missing
# run  899
# 8001at7088 missing
# run  900
# run  901
# 4118at7088 missing
# run  902
# 14521at7088 missing
# run  903
# run  904
# run  905
# 10387at7088 missing
# 7506at7088 missing
# run  906
# 16513at7088 missing
# 8001at7088 missing
# 11066at7088 missing
# 14179at7088 missing
# run  907
# 5251at7088 missing
# run  908
# 14521at7088 missing
# run  909
# 11558at7088 missing
# 10387at7088 missing
# run  910
# 8001at7088 missing
# 10319at7088 missing
# run  911
# 11066at7088 missing
# run  912
# run  913
# 4967at7088 missing
# run  914
# 16513at7088 missing
# run  915
# 3493at7088 missing
# run  916
# 8001at7088 missing
# run  917
# 8001at7088 missing
# 11264at7088 missing
# run  918
# 7506at7088 missing
# run  919
# run  920
# 4645at7088 missing
# run  921
# 3212at7088 missing
# run  922
# 8001at7088 missing
# 13972at7088 missing
# 3161at7088 missing
# 12660at7088 missing
# run  923
# 3493at7088 missing
# 5251at7088 missing
# 11264at7088 missing
# run  924
# run  925
# 8811at7088 missing
# 14179at7088 missing
# run  926
# 14404at7088 missing
# run  927
# 16088at7088 missing
# 12660at7088 missing
# run  928
# run  929
# run  930
# run  931
# run  932
# run  933
# 11066at7088 missing
# 8811at7088 missing
# run  934
# run  935
# 3161at7088 missing
# run  936
# 3493at7088 missing
# run  937
# 8001at7088 missing
# 3161at7088 missing
# run  938
# 11264at7088 missing
# run  939
# run  940
# 11558at7088 missing
# run  941
# 7357at7088 missing
# run  942
# 3161at7088 missing
# run  943
# run  944
# 3212at7088 missing
# 8001at7088 missing
# run  945
# 8811at7088 missing
# run  946
# 8001at7088 missing
# 12632at7088 missing
# run  947
# run  948
# 14521at7088 missing
# 6083at7088 missing
# 7357at7088 missing
# run  949
# 9544at7088 missing
# run  950
# run  951
# 6083at7088 missing
# run  952
# 1504at7088 missing
# 3212at7088 missing
# run  953
# 10546at7088 missing
# run  954
# 11066at7088 missing
# 11264at7088 missing
# run  955
# 16513at7088 missing
# run  956
# 14404at7088 missing
# 10319at7088 missing
# run  957
# run  958
# 13532at7088 missing
# run  959
# 3493at7088 missing
# run  960
# run  961
# 11264at7088 missing
# run  962
# 10546at7088 missing
# run  963
# 3161at7088 missing
# run  964
# 4967at7088 missing
# run  965
# run  966
# 12632at7088 missing
# 10333at7088 missing
# 4967at7088 missing
# run  967
# 12660at7088 missing
# run  968
# run  969
# run  970
# run  971
# 12632at7088 missing
# 3212at7088 missing
# run  972
# 10333at7088 missing
# run  973
# run  974
# run  975
# 12834at7088 missing
# 12660at7088 missing
# run  976
# 14404at7088 missing
# 5251at7088 missing
# run  977
# 8001at7088 missing
# 7357at7088 missing
# 4645at7088 missing
# run  978
# 13972at7088 missing
# run  979
# run  980
# run  981
# 7400at7088 missing
# run  982
# 8001at7088 missing
# run  983
# 13532at7088 missing
# 7506at7088 missing
# run  984
# 10546at7088 missing
# 4967at7088 missing
# 9544at7088 missing
# run  985
# 9108at7088 missing
# 10333at7088 missing
# run  986
# 11066at7088 missing
# 11264at7088 missing
# 12834at7088 missing
# 14179at7088 missing
# run  987
# 7400at7088 missing
# run  988
# 10319at7088 missing
# run  989
# 10319at7088 missing
# run  990
# run  991
# 4967at7088 missing
# 3212at7088 missing
# run  992
# 11066at7088 missing
# run  993
# 14179at7088 missing
# run  994
# 10319at7088 missing
# run  995
# 10333at7088 missing
# run  996
# run  997
# 16513at7088 missing
# 10387at7088 missing
# run  998
# run  999
# 5251at7088 missing
# [20, 25, 23, 18, 26, 22, 26, 21, 20, 27, 22, 24, 24, 15, 19, 25, 20, 23, 22, 20, 17, 15, 24, 19, 35, 17, 25, 23, 21, 19, 22, 29, 18, 19, 21, 22, 26, 22, 22, 22, 24, 18, 26, 25, 30, 24, 26, 16, 17, 19, 19, 18, 19, 28, 24, 20, 22, 20, 18, 13, 26, 24, 16, 24, 27, 22, 21, 22, 25, 16, 23, 23, 25, 23, 23, 23, 21, 22, 18, 27, 23, 22, 25, 15, 27, 25, 21, 24, 24, 13, 21, 20, 25, 27, 21, 24, 25, 19, 11, 26, 25, 30, 20, 21, 32, 29, 18, 28, 22, 22, 26, 14, 23, 32, 19, 25, 19, 24, 23, 24, 27, 12, 24, 23, 27, 32, 17, 22, 29, 24, 29, 18, 23, 16, 17, 18, 19, 22, 20, 20, 22, 27, 21, 19, 18, 20, 26, 24, 24, 23, 25, 27, 26, 18, 26, 26, 20, 27, 27, 24, 24, 25, 20, 25, 16, 31, 25, 22, 17, 23, 21, 17, 20, 14, 32, 18, 24, 30, 28, 20, 18, 32, 22, 18, 20, 26, 26, 18, 18, 16, 23, 20, 19, 24, 17, 21, 20, 25, 23, 28, 26, 32, 20, 17, 22, 17, 14, 21, 23, 28, 24, 26, 22, 24, 24, 24, 24, 21, 23, 19, 27, 21, 20, 33, 22, 21, 20, 25, 27, 27, 11, 19, 23, 15, 28, 29, 25, 15, 17, 26, 25, 22, 18, 26, 25, 17, 28, 20, 20, 14, 17, 26, 39, 12, 19, 17, 24, 21, 16, 28, 25, 24, 19, 20, 21, 24, 22, 16, 17, 25, 22, 19, 23, 15, 25, 21, 25, 17, 10, 23, 23, 22, 30, 26, 26, 24, 16, 18, 18, 30, 22, 28, 19, 25, 19, 27, 17, 21, 19, 22, 20, 28, 31, 27, 20, 20, 24, 23, 22, 21, 23, 25, 22, 20, 17, 29, 17, 22, 23, 18, 24, 29, 23, 22, 22, 23, 23, 21, 18, 23, 17, 29, 26, 16, 19, 23, 20, 20, 24, 28, 20, 22, 30, 15, 25, 24, 31, 25, 24, 23, 21, 22, 26, 28, 24, 17, 19, 22, 15, 18, 25, 18, 16, 25, 25, 21, 22, 24, 21, 24, 22, 19, 25, 23, 26, 17, 29, 17, 17, 18, 35, 27, 25, 37, 28, 25, 22, 16, 18, 20, 25, 32, 25, 24, 22, 23, 30, 21, 28, 26, 32, 25, 25, 20, 23, 23, 20, 29, 25, 20, 27, 28, 25, 24, 24, 30, 18, 22, 18, 27, 20, 28, 27, 26, 29, 21, 18, 28, 17, 22, 24, 25, 29, 21, 22, 27, 23, 33, 25, 26, 30, 25, 20, 23, 22, 25, 24, 27, 26, 28, 19, 22, 16, 20, 17, 19, 34, 24, 25, 29, 31, 24, 10, 18, 21, 18, 23, 28, 26, 21, 27, 28, 21, 12, 20, 22, 29, 17, 22, 24, 26, 20, 25, 19, 31, 19, 18, 27, 20, 15, 20, 24, 20, 21, 19, 14, 21, 20, 24, 19, 24, 20, 28, 25, 23, 30, 20, 28, 17, 23, 20, 23, 24, 27, 24, 21, 22, 22, 23, 22, 22, 24, 16, 21, 24, 22, 16, 26, 21, 21, 12, 23, 25, 21, 23, 19, 16, 26, 18, 21, 19, 13, 27, 26, 28, 18, 29, 21, 21, 24, 16, 23, 18, 25, 22, 26, 17, 21, 21, 22, 26, 18, 26, 20, 15, 15, 23, 22, 18, 33, 20, 23, 29, 31, 17, 29, 21, 25, 30, 25, 24, 15, 20, 27, 30, 27, 22, 22, 23, 25, 19, 18, 31, 21, 18, 26, 22, 26, 30, 19, 21, 24, 16, 17, 29, 19, 25, 22, 19, 19, 22, 16, 33, 24, 21, 25, 26, 25, 21, 18, 22, 19, 18, 25, 21, 25, 27, 23, 21, 26, 27, 21, 26, 27, 29, 17, 33, 19, 22, 22, 28, 22, 30, 28, 18, 19, 27, 18, 23, 27, 23, 18, 21, 14, 14, 27, 30, 12, 26, 23, 20, 21, 26, 24, 29, 22, 23, 19, 24, 20, 19, 18, 24, 22, 21, 22, 22, 22, 22, 27, 19, 23, 23, 36, 25, 14, 25, 26, 16, 24, 22, 20, 23, 15, 24, 19, 25, 15, 19, 17, 22, 26, 22, 24, 29, 19, 25, 22, 15, 26, 23, 25, 24, 22, 23, 26, 24, 24, 25, 23, 18, 22, 29, 24, 25, 17, 11, 27, 23, 29, 18, 21, 21, 14, 25, 18, 26, 22, 26, 23, 16, 20, 22, 20, 19, 22, 15, 25, 24, 26, 20, 23, 32, 21, 21, 17, 25, 30, 17, 28, 20, 18, 22, 26, 23, 21, 25, 18, 26, 21, 21, 16, 22, 27, 31, 18, 23, 21, 30, 31, 25, 23, 18, 22, 26, 24, 18, 15, 19, 20, 19, 17, 26, 24, 17, 22, 19, 24, 19, 23, 23, 21, 20, 30, 22, 21, 19, 26, 19, 27, 20, 19, 22, 23, 20, 24, 26, 29, 19, 23, 24, 28, 14, 19, 27, 25, 17, 21, 25, 27, 29, 21, 22, 26, 16, 24, 24, 23, 21, 23, 24, 36, 14, 23, 24, 15, 25, 22, 23, 15, 20, 25, 17, 24, 32, 25, 31, 20, 25, 17, 24, 18, 20, 25, 25, 26, 24, 28, 18, 25, 32, 28, 21, 34, 26, 22, 13, 25, 26, 27, 29, 24, 21, 26, 20, 22, 13, 18, 25, 14, 20, 27, 31, 28, 20, 33, 18, 24, 23, 28, 28, 21, 23, 24, 20, 21, 21, 21, 24, 18, 17, 19, 22, 28, 25, 31, 27, 25, 26, 24, 21, 27, 32, 16, 21, 26, 19, 18, 20, 22, 24, 30, 16, 20, 26, 15, 24, 25, 27, 28, 19, 19, 27, 22, 19, 17, 29, 20, 21, 20, 16, 27, 21, 22, 20, 22, 27, 20, 36, 18, 27, 24, 23, 26, 18, 16, 20, 24, 33, 29, 36, 21, 22, 24, 20, 23, 28, 21, 22, 20, 23, 22, 15, 26, 32, 16, 18, 19, 24, 22, 23, 17, 27, 27, 17, 20, 18, 26, 21, 30]

# %%
# import numpy as np
# # print((intersecting_genes_length_list))
# str_list = ""
# for num in intersecting_genes_length_list:
#     str_list += f"{num}\n"
# with open(f"{location}/4.Intersections_test/10000_runs_5kb.txt", 'w') as out_file:
#     out_file.write(str_list)

# %%
import matplotlib.pyplot as plt

# Sample data
data = intersecting_genes_length_list

# Define bins with size = 1
min_bin = min(data)
max_bin = max(data)
bins = range(min_bin, max_bin + 2)  # +2 to include the last value properly

# Plot
plt.figure(figsize=(20, 20))
plt.hist(data, bins=bins, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Bin Size = 1')
plt.xticks(bins)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Always show details
import scipy.stats as stats

# Updated list of observations
observations = intersecting_genes_length_list

# [7, 7, 4, 7, 10, 2, 7, 10, 5, 10, 1, 0, 5, 4, 6, 7, 6, 9, 5, 1, 8, 7, 2, 10, 7, 9, 3, 11, 9, 0, 9, 5, 5, 2, 0, 12, 3, 6, 4, 2, 9, 5, 3, 2, 8, 2, 0, 6, 6, 1, 12, 3, 1, 3, 8, 12, 8, 0, 6, 4, 0, 7, 2, 7, 10, 2, 7, 3, 3, 1, 13, 8, 11, 8, 1, 6, 3, 0, 6, 5, 7, 2, 2, 7, 0, 11, 7, 9, 10, 8, 2, 4, 8, 7, 0, 3, 5, 0, 4, 8, 6, 4, 8, 1, 3, 5, 6, 6, 6, 0, 4, 6, 4, 2, 4, 4, 5, 10, 10, 0, 5, 3, 1, 7, 5, 2, 0, 0, 3, 0, 7, 8, 10, 6, 3, 4, 2, 8, 8, 0, 7, 5, 0, 7, 6, 5, 1, 0, 9, 7, 1, 13, 2, 10, 3, 9, 9, 5, 1, 5, 6, 7, 1, 2, 10, 8, 7, 1, 7, 6, 9, 5, 0, 11, 0, 0, 6, 2, 1, 1, 1, 6, 4, 9, 8, 4, 5, 9, 4, 15, 9, 0, 2, 0, 1, 3, 10, 3, 9, 3, 4, 2, 1, 7, 4, 1, 1, 5, 3, 4, 14, 0, 0, 5, 5, 8, 7, 0]

# Calculate the proportion of values greater than or equal to 10
value_of_interest = final_gene_number
print(value_of_interest)
count_extreme = sum(x >= value_of_interest for x in observations)
p_value = count_extreme / len(observations)

p_value
# Out:
# 33
# 0.017
