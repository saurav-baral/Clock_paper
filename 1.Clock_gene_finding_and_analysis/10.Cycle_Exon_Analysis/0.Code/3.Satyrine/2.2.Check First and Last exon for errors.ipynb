# %%
import os
import subprocess

family_group = "8.Lycaenidae"

location = f"/mnt/h/My Drive/Circadian Rhythm Genes Project/10.Cycle Exon Analysis/{family_group}"

species_list = os.listdir(f"{location}/1.Blast_result")
if "desktop.ini" in species_list:
    species_list.remove("desktop.ini")
error_species = ''
# species_list=["Pararge_aegeria"]



for species in species_list:
    
    list_of_files_in_species_result_folder = os.listdir(f"{location}/1.Blast_result/{species}")
    backup_present = 0
    for files in list_of_files_in_species_result_folder:
        if files.endswith("_coordinates_old_backup.csv"):
            backup_present = 1

    if backup_present == 0:
        subprocess.run(f'cp "{location}/1.Blast_result/{species}/{species}_coordinates_old.csv" "{location}/1.Blast_result/{species}/{species}_coordinates_old_backup.csv"', shell = True)

    
    with open(f"{location}/1.Blast_result/{species}/{species}_coordinates_old_backup.csv", 'r') as coordinate_file:
        coordinate_list = coordinate_file.readlines()

    first_exon_error = coordinate_list[1].split(",")[5]
    last_exon_error = coordinate_list[-1].split(",")[5]
    
    
    
        
    if first_exon_error == "Y":
         
        print(f"\n\nFirst Exon: \n{coordinate_list[1]}")
        exon_name = coordinate_list[1].split(",")[6]
        while (True):

            fix_option = input("Fix!!\n1.Add New Coordinate\n2.Just change error from 'Y' to 'N'\n3.Stop 'n'")

            if fix_option == "n":
                assert False
            elif fix_option == "1":

                for i in range(len(coordinate_list)):
                    if coordinate_list[i].split(",")[5] == "N":
                        Species,Scaffold,Start,Stop,Complement = coordinate_list[i].split(",")[:5]
                        print(Species,Scaffold,Start,Stop,Complement)
                        if Complement == "0":
                            new_start = int(Start) - 2000*i
                            new_stop = int(Stop) - 2000*i
                        elif Complement == "1":
                            new_start = int(Start) + 2000*i
                            new_stop = int(Stop) + 2000*i

                        coordinate_list[1] = f"{Species},{Scaffold},{new_start},{new_stop},{Complement},N,{exon_name},0,0,0\n"             
                        break
                error_species +=f"{Species},{Scaffold},000,000,0,Y,Error_Exon_1,00,00,00\n"    
                break
            

            elif fix_option == "2":
                coordinate_list[1].replace(',Y,',',N,')
                break
            else:
                print("Retry?")
        

    if last_exon_error == "Y":
        print(f"\n\nLast Exon: \n{coordinate_list[-1]}")
        exon_name = coordinate_list[-1].split(",")[6]
        exon_number = exon_name.split("_")[-1]
        while (True):

            fix_option = input("Fix!!\n1.Add New Coordinate\n2.Just change error from 'Y' to 'N'\n3.Stop 'n'")

            if fix_option == "n":
                assert False
            elif fix_option == "1":

                for i in range(len(coordinate_list)):
                    position = len(coordinate_list)-1-i
                    if coordinate_list[position].split(",")[5] == "N":
                        Species,Scaffold,Start,Stop,Complement = coordinate_list[position].split(",")[:5]
    #                     print(Species,Scaffold,Start,Stop,Complement)
                        if Complement == "0":
                            new_start = int(Start) + 2000*i
                            new_stop = int(Stop) + 2000*i
                        elif Complement == "1":
                            new_start = int(Start) - 2000*i
                            new_stop = int(Stop) - 2000*i

                        coordinate_list[-1] = f"{Species},{Scaffold},{new_start},{new_stop},{Complement},N,{exon_name},0,0,0\n"             
                        
                        break
                    error_species +=f"{Species},{Scaffold},000,000,0,Y,Error_Exon_{exon_number},00,00,00\n"
                break

            elif fix_option == "2":
                coordinate_list[-1] = coordinate_list[-1].replace(',Y,',',N,')
                break
            else:
                print("Retry?")
        

    new_coordinates = "".join(coordinate_list)
    print(new_coordinates)

    with open(f"{location}/1.Blast_result/{species}/{species}_coordinates_old.csv", 'w') as out_coordinate_file:
        out_coordinate_file.write(new_coordinates)
    
with open(f"{location}/error_in_first_and_last.txt", 'w') as error_file:
    error_file.write(error_species)
print(error_species)
# Out:
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Aricia_agestis,NC_056428.1,38947413,38947501,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Aricia_agestis,NC_056428.1,39002099,39002227,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,42,42
# Aricia_agestis,NC_056410.1,13351175,13351366,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,11,40,62
# Aricia_agestis,NC_056428.1,39013056,39013127,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Aricia_agestis,NC_056428.1,39013952,39014288,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Aricia_agestis,NC_056428.1,39014373,39014490,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Aricia_agestis,NC_056428.1,39015162,39015377,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Aricia_agestis,NC_056428.1,39019918,39020122,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Aricia_agestis,NC_056428.1,39020578,39020781,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Aricia_agestis,NC_056428.1,39020965,39021077,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Aricia_agestis,NC_056428.1,39022747,39022940,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
# Aricia_agestis,NC_056428.1,39024403,39024639,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,1,79,79
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Aricia_artaxerxes,OW569310.1,42072820,42072908,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Aricia_artaxerxes,OW569310.1,42127507,42127635,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,42,42
# Aricia_artaxerxes,OW569292.1,8681074,8681265,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,11,40,62
# Aricia_artaxerxes,OW569310.1,42133058,42133129,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Aricia_artaxerxes,OW569310.1,42133909,42134245,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Aricia_artaxerxes,OW569310.1,42134330,42134447,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Aricia_artaxerxes,OW569310.1,42135143,42135358,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Aricia_artaxerxes,OW569310.1,42142304,42142508,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Aricia_artaxerxes,OW569310.1,42142964,42143167,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Aricia_artaxerxes,OW569310.1,42143351,42143463,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Aricia_artaxerxes,OW569310.1,42145606,42145799,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
# Aricia_artaxerxes,OW569310.1,42147269,42147505,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,1,79,79
#
#
#
# Last Exon:
# Calycopis_cecrops,LUGF01022778.1,130346,130582,0,Y,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,44,79,79
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'2
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Calycopis_cecrops,LUGF01022778.1,68223,68311,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Calycopis_cecrops,LUGF01059802.1,380576,380704,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,7,42,42
# Calycopis_cecrops,LUGF01044532.1,31038,31226,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,18,36,62
# Calycopis_cecrops,LUGF01044532.1,0,0,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,0,0,23
# Calycopis_cecrops,LUGF01022778.1,116042,116378,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Calycopis_cecrops,LUGF01022778.1,117027,117144,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Calycopis_cecrops,LUGF01022778.1,119222,119437,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Calycopis_cecrops,LUGF01022778.1,124443,124632,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Calycopis_cecrops,LUGF01022778.1,126111,126314,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Calycopis_cecrops,LUGF01022778.1,127539,127648,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Calycopis_cecrops,LUGF01022778.1,129616,129809,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,2,63,64
# Calycopis_cecrops,LUGF01022778.1,130346,130582,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,44,79,79
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Celastrina_argiolus,LR994583.1,20243347,20243435,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Celastrina_argiolus,LR994583.1,20302979,20303107,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,42,42
# Celastrina_argiolus,LR994577.1,11986729,11986917,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,11,41,62
# Celastrina_argiolus,LR994583.1,20305379,20305450,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Celastrina_argiolus,LR994583.1,20305612,20305948,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Celastrina_argiolus,LR994583.1,20306055,20306172,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Celastrina_argiolus,LR994583.1,20306285,20306506,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Celastrina_argiolus,LR994583.1,20309919,20310129,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Celastrina_argiolus,LR994583.1,20310715,20310918,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Celastrina_argiolus,LR994583.1,20311250,20311362,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Celastrina_argiolus,LR994583.1,20314542,20314735,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,1,63,64
# Celastrina_argiolus,LR994583.1,20315798,20316040,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,1,79,79
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Cyaniris_semiargus,LR994547.1,21448676,21448764,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Cyaniris_semiargus,LR994547.1,21490766,21490891,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,40,42
# Cyaniris_semiargus,LR994556.1,10241056,10241244,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,2,35,62
# Cyaniris_semiargus,LR994547.1,21493184,21493255,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Cyaniris_semiargus,LR994547.1,21493418,21493754,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Cyaniris_semiargus,LR994547.1,21494381,21494498,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Cyaniris_semiargus,LR994547.1,21495209,21495424,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Cyaniris_semiargus,LR994547.1,21502802,21503006,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Cyaniris_semiargus,LR994547.1,21504428,21504631,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Cyaniris_semiargus,LR994547.1,21504813,21504925,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Cyaniris_semiargus,LR994547.1,21506792,21506985,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
# Cyaniris_semiargus,LR994547.1,21508309,21508548,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,1,79,79
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Cyclargus_thomasi,JAOTAV010028830.1,6804,6892,1,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Cyclargus_thomasi,JAOTAV010032496.1,3771,3896,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,3,42,42
# Cyclargus_thomasi,JAOTAV010032496.1,0,0,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,0,0,62
# Cyclargus_thomasi,JAOTAV010032496.1,5515,5586,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Cyclargus_thomasi,JAOTAV010032496.1,5879,6215,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Cyclargus_thomasi,JAOTAV010032496.1,6322,6439,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Cyclargus_thomasi,JAOTAV010032496.1,6521,6745,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Cyclargus_thomasi,JAOTAV010032496.1,8387,8597,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Cyclargus_thomasi,JAOTAV010032496.1,8878,9081,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Cyclargus_thomasi,JAOTAV010032496.1,9274,9386,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Cyclargus_thomasi,JAOTAV010032496.1,10609,10802,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,1,63,64
# Cyclargus_thomasi,JAOTAV010032496.1,11079,11318,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,1,79,79
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Eumaeus_atala,JAFELO010001546.1,244564,244652,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Eumaeus_atala,JAFELO010001546.1,286602,286727,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,40,42
# Eumaeus_atala,JAFELO010000950.1,444014,444202,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,17,45,62
# Eumaeus_atala,JAFELO010001546.1,291075,291146,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Eumaeus_atala,JAFELO010001546.1,292194,292530,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Eumaeus_atala,JAFELO010001546.1,293363,293480,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Eumaeus_atala,JAFELO010001546.1,294420,294641,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Eumaeus_atala,JAFELO010001546.1,300616,300808,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Eumaeus_atala,JAFELO010001546.1,301677,301880,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Eumaeus_atala,JAFELO010001546.1,302668,302777,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Eumaeus_atala,JAFELO010001546.1,304640,304833,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,4,63,64
# Eumaeus_atala,JAFELO010001546.1,306418,306690,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,3,79,79
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Glaucopsyche_alexis,FR990042.1,23872528,23872619,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Glaucopsyche_alexis,FR990042.1,23913515,23913640,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,42,42
# Glaucopsyche_alexis,FR990062.1,8395581,8395766,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,11,45,62
# Glaucopsyche_alexis,FR990042.1,23921144,23921215,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Glaucopsyche_alexis,FR990042.1,23921369,23921705,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Glaucopsyche_alexis,FR990042.1,23921825,23921942,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Glaucopsyche_alexis,FR990042.1,23922050,23922262,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Glaucopsyche_alexis,FR990042.1,23924642,23924849,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Glaucopsyche_alexis,FR990042.1,23925167,23925370,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Glaucopsyche_alexis,FR990042.1,23925630,23925742,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Glaucopsyche_alexis,FR990042.1,23932218,23932411,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,1,63,64
# Glaucopsyche_alexis,FR990042.1,23937491,23937733,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,2,79,79
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Helleia_helle,OY971420.1,3766196,3766278,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Helleia_helle,OY971420.1,0,0,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,0,0,42
# Helleia_helle,OY971418.1,6539614,6539796,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,8,59,62
# Helleia_helle,OY971420.1,3805892,3805963,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Helleia_helle,OY971420.1,3806850,3807183,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Helleia_helle,OY971420.1,3807371,3807488,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Helleia_helle,OY971420.1,3807565,3807795,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Helleia_helle,OY971420.1,3810207,3810402,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Helleia_helle,OY971420.1,3810984,3811187,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Helleia_helle,OY971420.1,3811453,3811565,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Helleia_helle,OY971420.1,3815258,3815451,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,9,63,64
# Helleia_helle,OY971420.1,3815943,3816215,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,4,79,79
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Lycaena_phlaeas,HG995168.1,2861656,2861738,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Lycaena_phlaeas,HG995168.1,2900082,2900216,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,40,42
# Lycaena_phlaeas,HG995184.1,12806315,12806518,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,3,40,62
# Lycaena_phlaeas,HG995168.1,2904616,2904687,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Lycaena_phlaeas,HG995168.1,2905193,2905526,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Lycaena_phlaeas,HG995168.1,2907419,2907536,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Lycaena_phlaeas,HG995168.1,2909327,2909557,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Lycaena_phlaeas,HG995168.1,2912644,2912845,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Lycaena_phlaeas,HG995168.1,2913031,2913234,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Lycaena_phlaeas,HG995168.1,2913627,2913739,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Lycaena_phlaeas,HG995168.1,2916698,2916891,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,9,62,64
# Lycaena_phlaeas,HG995168.1,2917115,2917387,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,3,79,79
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Lysandra_bellargus,HG995319.1,3747156,3747244,1,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Lysandra_bellargus,HG995319.1,3697293,3697421,1,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,42,42
# Lysandra_bellargus,HG995334.1,222008,222184,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,23,55,62
# Lysandra_bellargus,HG995319.1,3687682,3687753,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Lysandra_bellargus,HG995319.1,3686379,3686715,1,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Lysandra_bellargus,HG995319.1,3686177,3686294,1,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Lysandra_bellargus,HG995319.1,3684221,3684445,1,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Lysandra_bellargus,HG995319.1,3679886,3680096,1,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Lysandra_bellargus,HG995319.1,3679161,3679364,1,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Lysandra_bellargus,HG995319.1,3678865,3678977,1,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Lysandra_bellargus,HG995319.1,3676288,3676475,1,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,1,63,64
# Lysandra_bellargus,HG995319.1,3675257,3675493,1,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,2,79,79
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Lysandra_coridon,HG992055.1,30223169,30223257,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Lysandra_coridon,HG992055.1,30301954,30302082,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,42,42
# Lysandra_coridon,HG992087.1,5775843,5776019,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,23,55,62
# Lysandra_coridon,HG992055.1,30313522,30313593,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Lysandra_coridon,HG992055.1,30314539,30314875,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Lysandra_coridon,HG992055.1,30314960,30315077,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Lysandra_coridon,HG992055.1,30316854,30317078,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Lysandra_coridon,HG992055.1,30324131,30324341,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Lysandra_coridon,HG992055.1,30324836,30325039,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Lysandra_coridon,HG992055.1,30325220,30325332,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Lysandra_coridon,HG992055.1,30325879,30326066,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,1,63,64
# Lysandra_coridon,HG992055.1,30326854,30327090,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,2,79,79
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Phengaris_arion,OY751437.1,22765131,22765225,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Phengaris_arion,OY751437.1,22798380,22798505,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,42,42
# Phengaris_arion,OY751438.1,18751479,18751664,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,1,46,62
# Phengaris_arion,OY751437.1,22805416,22805487,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Phengaris_arion,OY751437.1,22805725,22806061,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Phengaris_arion,OY751437.1,22806173,22806290,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Phengaris_arion,OY751437.1,22807721,22807945,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Phengaris_arion,OY751437.1,22810963,22811173,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Phengaris_arion,OY751437.1,22811490,22811693,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Phengaris_arion,OY751437.1,22811967,22812079,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Phengaris_arion,OY751437.1,22813555,22813748,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,1,63,64
# Phengaris_arion,OY751437.1,22814381,22814623,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,1,79,79
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Plebejus_argus,FR989932.1,2449917,2450005,1,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Plebejus_argus,FR989932.1,2423969,2424100,1,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,42,42
# Plebejus_argus,FR989938.1,7287521,7287709,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,22,45,62
# Plebejus_argus,FR989932.1,2420771,2420842,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,7,23,23
# Plebejus_argus,FR989932.1,2420210,2420546,1,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Plebejus_argus,FR989932.1,2420008,2420125,1,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Plebejus_argus,FR989932.1,2419708,2419932,1,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Plebejus_argus,FR989932.1,2415308,2415515,1,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Plebejus_argus,FR989932.1,2413044,2413247,1,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Plebejus_argus,FR989932.1,2412339,2412451,1,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Plebejus_argus,FR989932.1,2410872,2411059,1,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,1,63,64
# Plebejus_argus,FR989932.1,2409856,2410095,1,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,2,79,79
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Polyommatus_icarus,OW569320.1,36078997,36079085,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Polyommatus_icarus,OW569320.1,36155503,36155631,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,42,42
# Polyommatus_icarus,OW569332.1,11401334,11401510,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,23,55,62
# Polyommatus_icarus,OW569320.1,36158924,36158995,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Polyommatus_icarus,OW569320.1,36159282,36159618,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Polyommatus_icarus,OW569320.1,36159699,36159816,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Polyommatus_icarus,OW569320.1,36159890,36160105,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Polyommatus_icarus,OW569320.1,36163938,36164142,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Polyommatus_icarus,OW569320.1,36164584,36164787,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Polyommatus_icarus,OW569320.1,36165619,36165731,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Polyommatus_icarus,OW569320.1,36167618,36167811,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
# Polyommatus_icarus,OW569320.1,36169039,36169275,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,1,79,79
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Polyommatus_iphigenia,OY730178.1,37475996,37476084,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,1,29,29
# Polyommatus_iphigenia,OY730178.1,37547334,37547462,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,1,42,42
# Polyommatus_iphigenia,OY730177.1,13692328,13692516,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,26,58,62
# Polyommatus_iphigenia,OY730178.1,37550887,37550958,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Polyommatus_iphigenia,OY730178.1,37551266,37551602,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Polyommatus_iphigenia,OY730178.1,37551687,37551804,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Polyommatus_iphigenia,OY730178.1,37551877,37552092,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Polyommatus_iphigenia,OY730178.1,37556049,37556253,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Polyommatus_iphigenia,OY730178.1,37558774,37558977,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Polyommatus_iphigenia,OY730178.1,37559832,37559944,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Polyommatus_iphigenia,OY730178.1,37561796,37561989,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
# Polyommatus_iphigenia,OY730178.1,37562800,37563036,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,1,79,79
#
#
#
# First Exon:
# Calephelis_nemesis,Intial_value,0,0,0,Y,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,0,0,29
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Calephelis_nemesis NJDD01001239.1 246711 247047 0
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Calephelis_nemesis,NJDD01001239.1,236711,237047,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Calephelis_nemesis,Intial_value,0,0,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,0,0,42
# Calephelis_nemesis,NJDD01001239.1,238116,238304,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,2,27,62
# Calephelis_nemesis,NJDD01001239.1,0,0,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,0,0,23
# Calephelis_nemesis,NJDD01001239.1,246711,247047,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Calephelis_nemesis,NJDD01001239.1,247872,247989,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Calephelis_nemesis,NJDD01001239.1,249960,250184,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Calephelis_nemesis,NJDD01001239.1,250954,251164,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Calephelis_nemesis,NJDD01001239.1,252608,252811,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Calephelis_nemesis,NJDD01001239.1,253447,253559,0,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Calephelis_nemesis,NJDD01001239.1,254257,254450,0,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,9,63,64
# Calephelis_nemesis,NJDD01001239.1,254888,255163,0,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,3,74,79
#
#
#
# First Exon:
# Calephelis_virginiensis,Intial_value,0,0,0,Y,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,0,0,29
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Calephelis_virginiensis NJDC01000217.1 114883 115219 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Calephelis_virginiensis,NJDC01000217.1,124883,125219,1,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Calephelis_virginiensis,Intial_value,0,0,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_2,0,0,42
# Calephelis_virginiensis,NJDC01000217.1,123873,124061,1,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_3,3,35,62
# Calephelis_virginiensis,NJDC01000217.1,0,0,0,Y,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_4,0,0,23
# Calephelis_virginiensis,NJDC01000217.1,114883,115219,1,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Calephelis_virginiensis,NJDC01000217.1,113358,113475,1,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Calephelis_virginiensis,NJDC01000217.1,111793,112017,1,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_1_query_Exon_7,1,71,71
# Calephelis_virginiensis,NJDC01000217.1,110902,111112,1,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_2_query_Exon_8,1,67,67
# Calephelis_virginiensis,NJDC01000217.1,105888,106091,1,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Calephelis_virginiensis,NJDC01000217.1,105205,105317,1,N,Aricia_agestis_XM_042130624.1_Frame_1_rightoh_1_query_Exon_10,1,36,37
# Calephelis_virginiensis,NJDC01000217.1,104313,104506,1,N,Aricia_agestis_XM_042130624.1_Frame_2_rightoh_0_query_Exon_11,9,63,64
# Calephelis_virginiensis,NJDC01000217.1,103653,103928,1,N,Aricia_agestis_XM_042130624.1_Frame_0_rightoh_0_query_Exon_12,3,79,79
#
# Calephelis_nemesis,NJDD01001239.1,000,000,0,Y,Error_Exon_1,00,00,00
# Calephelis_virginiensis,NJDC01000217.1,000,000,0,Y,Error_Exon_1,00,00,00
