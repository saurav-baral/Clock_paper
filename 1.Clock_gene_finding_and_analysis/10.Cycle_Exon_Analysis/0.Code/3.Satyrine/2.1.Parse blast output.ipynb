# %%
def sequence_extractor(Species, Scaff, reverse_c, start, end, frame = 1, trans = 1 ):
    from Bio import SeqIO
    from Bio.Seq import Seq
    import os
    
    out_Seq = ''
    
    
    
    #Genome folder
    entries = os.listdir("/mnt/f/Genomes_2023-12-26/"+Species)
    
    #Get genome file from Genome folder
    for file_names  in entries:
        if ".nhr" in file_names:
            Genome_name = file_names[:-4]
            break
    
    #Read the genome file
    fasta_file = SeqIO.parse(("/mnt/f/Genomes_2023-12-26/"+Species+"/"+Genome_name),'fasta')
    
    #Extract the sequence 
    for record in fasta_file:
        if record.id == Scaff:
            sequence = str(record.seq)
            out_Seq = Seq(sequence[start-1:end])
            if reverse_c == 1:
                out_Seq = out_Seq.reverse_complement()
            break
                
    if len(out_Seq) < 10000: #fixing error due to mistake in typing the coordinate, change this for longer sequence
#        print (out_Seq)
        if frame == 1 :
            out_trans = out_Seq[0:]
        if frame == 2 :
            out_trans = out_Seq[1:]
        if frame == 3 :
            out_trans = out_Seq[2:]
    else:
        print ("too long")
        assert(False)
        
        
    #    break
    
    if trans == 1:
        return (out_trans.translate())
    else:
        return(out_Seq)
#

# %%
import os
from Bio import SeqIO

# %%
def get_sequence(Species, Scaff, reverse_c, start, end, frame = 1, trans = 1 ):
    
    #Genome folder
    entries = os.listdir("/mnt/f/Genomes_2023-12-26/"+Species)
    
    #Get genome file from Genome folder
    for file_names  in entries:
        if ".nhr" in file_names:
            Genome_name = file_names[:-4]
            break
    
    #Read the genome file
    fasta_file = SeqIO.parse(("/mnt/f/Genomes_2023-12-26/"+Species+"/"+Genome_name),'fasta')
    
    #Extract the sequence 
    for record in fasta_file:
        if record.id == Scaff:
            sequence = str(record.seq)
#             out_Seq = Seq(sequence[start-1:end])
#             if reverse_c == 1:
#                 sequence = out_Seq.reverse_complement()
            return(sequence)
    
#

# %%
#%reset -f

from Bio.Seq import Seq


family_group = "3.Satyrine"
blast_location = f"/mnt/h/My Drive/Circadian Rhythm Genes Project/10.Cycle Exon Analysis/{family_group}"
query_location = f"{blast_location}/1.Query"
query_species = "Maniola_jurtina"
query_transcript_list = os.listdir(f"{query_location}/{query_species}")
if "desktop.ini" in query_transcript_list:
    query_transcript_list.remove("desktop.ini")

query_transcript = query_transcript_list[0]
#Get Species list, the list may be a list of files or a single species

species_list = os.listdir(f"{blast_location}/1.Blast_result")
# species_list = ["Pararge_aegeria"]
if "desktop.ini" in species_list:
    species_list.remove('desktop.ini')

#get list of query names

query_file = SeqIO.parse(f"{blast_location}/1.Query/{query_species}/{query_transcript}/query_protein.fa", 'fasta')
query_name_list = []

for records in query_file:
    query_name_list.append(records.id)



for species in species_list:
    # print(species_name)
    # species = species_name.split(".")[1]
    header = "Species," + "Scaffold," + "Start," + "Stop," + "Complement," + "Error," + "Gene,"+ "Query_start," + "Query_stop,"+ "Query_Length\n" 
    Output_Sequence = header
    scaff = "Intial_value"
    scaff_old = "Intial_value"
    old_end = 0
    
#Run for each query in the query list
    for i in range(len(query_name_list)):
        query_name = query_name_list[i]
#         print(f"Query name = {query_name}")
        Length_switch = "0"
        with open(f"{blast_location}/1.Blast_result/{species}/{species}_blast_out.txt",'r') as tblast_out:
            lines_in_file = tblast_out.readlines()
        #print(lines_in_file)

        result_section_switch = 0
        start_coor_switch = 0
        query_start_coor_switch = 0
        stop_coor_switch = 0
        error = "N"
        break_switch = 0

        start = 0
        stop = 0
        start_coor = 0
        stop_coor = 0
        query_length = 0

        for lines in lines_in_file:

#             print(lines)
            if query_name in lines:
#                 print(lines)
#                 assert False
            #Initialize that results can now be checked
                result_section_switch = 1
#                 query_species_split = lines.split(" ")[1].split("_")
#                 query_species = str(query_species_split[0].split(".")[1]+"_"+query_species_split[1].rstrip())
                print(query_species)
            if result_section_switch == 1 and "Lambda" in lines:
            #This block indicates end of the results block in blast output
                result_section_switch == 0
                
                break

            if result_section_switch == 1:
            #While checking the result
                if "Length=" in lines and Length_switch == "0":
                #Get query length from the blast output
                    
                    query_length = int(lines.split("=")[1].rstrip())
                    
                    Length_switch = 1 #Indicated length has been acquired
                    
                if ("Score" in lines or ">" in lines) and (start_coor_switch == 1):
    #                print (lines)
                    break
        
                if ">" in lines:
                #Start of the first result
                    scaff = lines.split(" ")[0][1:] #Scaffold from the result
                    if scaff_old != "Intial_value" and scaff_old != scaff:
                        error = "Y"
                    scaff_old = scaff
                    
                if "Query" in lines and "=" not in lines:
                #Read the query line in output
                    if query_start_coor_switch == 0:
#                        print(lines)
                        query_start_coor = int(lines.split(" ")[2])
                        query_start_coor_switch = 1
                        #Query start coordinate fixed
            
                    query_stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting query stop coordinates for multiline result
    #                print (stop_coor)
                    
                if "Sbjct" in lines:
                #Read the blast target line
                    if start_coor_switch == 0:
                        start_coor = int(lines.split(" ")[2])
                        start_coor_switch = 1
                    stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting target stop coordinates for multiline result
                
                

        
        if break_switch == 1:
            break

        if start_coor < stop_coor:
            complement = "0" #Forward complement
            
            length = (stop_coor-start_coor)/3
            start = start_coor
            stop = stop_coor

        elif start_coor > stop_coor:
            complement = "1" #Reverse complement
            length = (-stop_coor+start_coor)/3
            start = stop_coor
            stop = start_coor

        else:
            length = 0
            start = 000
            stop = 000
            query_start_coor = 000
            query_stop_coor = 000
            error = "Y"
            complement  = 0
        
        
        
        

        #Check if the length of target (blast hit) is significantly smaller than query
        if length < query_length - 0.2*query_length:
            error = "Y"

        old_trans = ''
#             print(start, stop)
        
    
    
        

#Check for Met or STOP at the start and end
        sequence = ''
        while True and (start != 0 or stop != 0):
            if (query_name == query_name_list[0] or query_name == query_name_list[-1]):
                frame = 1
#                 translated_sequence = (sequence_extractor(species, scaff, int(complement), start, stop,frame ))
                if sequence == '':
                    sequence = get_sequence(species, scaff, int(complement), start, stop,frame)
                if int(complement) == 1:
                    translated_sequence = Seq(sequence[start-1:stop]).reverse_complement().translate()
                else:
                    translated_sequence = Seq(sequence[start-1:stop]).translate()
                if translated_sequence == old_trans:
                    break
                    
#Check for Met at the beginning of first exon

                if query_name == query_name_list[0] :
                    if translated_sequence[0] != "M":
                        print(translated_sequence)
#                             print(start, stop)
                        if complement == "0":
                            start = int(start) - 3
                        if complement == "1":
                            stop = int(stop) + 3
                        old_trans = translated_sequence
                    if "*" in translated_sequence:
                        error = "Y"
                        break
                    if translated_sequence[0] == "M":
                        break

#Check for stop at the end of last exon

                if query_name == query_name_list[-1]:
                    if translated_sequence[-1] != "*":
                        print(translated_sequence)
#                             print(start, stop)
                        if complement == "0":
                            stop = int(stop) + 3
                        if complement == "1":
                            start = int(start) - 3
                        old_trans = translated_sequence
                    if translated_sequence[-1] == "*":

                        break
            else:
                break
        
        
#Add offset at the beginning and end of each exon
        if (start != 0 or stop != 0):
            
            start_modifier = int(query_name.split("Frame")[1][1])
            stop_modifier = int(query_name.split("rightoh")[1][1])
        else:
            start_modifier = 0
            stop_modifier = 0            

        seq_length = query_length
        
        
#Get exon start and end by adding or removing codons
        
    #if not the beginning
        if query_start_coor != "1" and query_name != query_name_list[0]:
            if complement == "0":
                start = int(start) - 3*(int(query_start_coor)-1)                
            if complement == "1":
                stop = int(stop) + 3*(int(query_start_coor)-1)
    
    #For the end
        if query_stop_coor != str(seq_length) and query_name != query_name_list[-1]:
            if complement == "0":
                stop = int(stop) + 3*(int(seq_length)-int(query_stop_coor))
            if complement == "1":
                

                start = int(start) - 3*(int(seq_length)-int(query_stop_coor))
 
        
        
        
#Adding or removing 3' and 5' overhangs for forward and reverse complement
    #For forward complement
        if complement == "0":
            start = int(start) - int(start_modifier)
            stop = int(stop) +  int(stop_modifier)
            if old_end != 0 and old_end > stop:

                error = "Y"
            old_end = stop

    #For reverse complement
        if complement == "1":
            start = int(start) - int(stop_modifier)
            stop = int(stop) +  int(start_modifier)
            if old_end != 0 and old_end < stop:
                error = "Y"
            old_end = stop

    #Simple check for lenghth
        if start == 0 or stop == 0:
            error = "Y"
            
           
        output_format = str(species.split("\n")[0])+"," + str(scaff) +"," + str(start)+"," + str(stop)+"," + str(complement)+"," + str(error)+  ","+ str(query_name)+","+ str(query_start_coor)+","+str(query_stop_coor)+","+str(query_length)+ "\n"  
        print(output_format)
#         assert False
        Output_Sequence = Output_Sequence + output_format

    print(Output_Sequence)
   
    output_file = open(f"{blast_location}/1.Blast_result/{species}/{species}_coordinates_old.csv",'w')
    output_file.write(Output_Sequence)
    output_file.close()
# Out:
# Maniola_jurtina
# Elymnias_hypermnestra,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,0,0,31
#
# Maniola_jurtina
# Elymnias_hypermnestra,JACTOM010000013.1,1434015,1434206,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,4,53,56
#
# Maniola_jurtina
# Elymnias_hypermnestra,JACTOM010000013.1,0,0,0,Y,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,0,0,39
#
# Maniola_jurtina
# Elymnias_hypermnestra,JACTOM010000013.1,0,0,0,Y,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,0,0,23
#
# Maniola_jurtina
# Elymnias_hypermnestra,JACTOM010000013.1,1425543,1425879,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
#
# Maniola_jurtina
# Elymnias_hypermnestra,JACTOM010000013.1,1423409,1423526,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
#
# Maniola_jurtina
# Elymnias_hypermnestra,JACTOM010000013.1,1422665,1422904,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
#
# Maniola_jurtina
# Elymnias_hypermnestra,JACTOM010000013.1,1418508,1418727,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
#
# Maniola_jurtina
# Elymnias_hypermnestra,JACTOM010000013.1,1417395,1417598,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
#
# Maniola_jurtina
# Elymnias_hypermnestra,JACTOM010000013.1,1416914,1417026,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
#
# Maniola_jurtina
# Elymnias_hypermnestra,JACTOM010000013.1,1415028,1415221,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,4,64,64
#
# Maniola_jurtina
# Elymnias_hypermnestra,JACTOM010000013.1,1413867,1414148,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,2,94,94
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Elymnias_hypermnestra,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,0,0,31
# Elymnias_hypermnestra,JACTOM010000013.1,1434015,1434206,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,4,53,56
# Elymnias_hypermnestra,JACTOM010000013.1,0,0,0,Y,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,0,0,39
# Elymnias_hypermnestra,JACTOM010000013.1,0,0,0,Y,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,0,0,23
# Elymnias_hypermnestra,JACTOM010000013.1,1425543,1425879,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Elymnias_hypermnestra,JACTOM010000013.1,1423409,1423526,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Elymnias_hypermnestra,JACTOM010000013.1,1422665,1422904,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
# Elymnias_hypermnestra,JACTOM010000013.1,1418508,1418727,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
# Elymnias_hypermnestra,JACTOM010000013.1,1417395,1417598,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Elymnias_hypermnestra,JACTOM010000013.1,1416914,1417026,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Elymnias_hypermnestra,JACTOM010000013.1,1415028,1415221,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,4,64,64
# Elymnias_hypermnestra,JACTOM010000013.1,1413867,1414148,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,2,94,94
#
# Maniola_jurtina
# Erebia_aethiops,OV281079.1,2287647,2287741,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
#
# Maniola_jurtina
# Erebia_aethiops,OV281079.1,2260903,2261076,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,2,56,56
#
# Maniola_jurtina
# Erebia_aethiops,OV281079.1,2260031,2260150,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,1,39,39
#
# Maniola_jurtina
# Erebia_aethiops,OV281079.1,2248797,2248868,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
#
# Maniola_jurtina
# Erebia_aethiops,OV281079.1,2244767,2245103,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
#
# Maniola_jurtina
# Erebia_aethiops,OV281079.1,2243282,2243399,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
#
# Maniola_jurtina
# Erebia_aethiops,OV281079.1,2240449,2240676,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
#
# Maniola_jurtina
# Erebia_aethiops,OV281079.1,2238742,2238958,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
#
# Maniola_jurtina
# Erebia_aethiops,OV281079.1,2237059,2237262,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
#
# Maniola_jurtina
# Erebia_aethiops,OV281079.1,2235480,2235592,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
#
# Maniola_jurtina
# Erebia_aethiops,OV281079.1,2234619,2234812,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
#
# Maniola_jurtina
# Erebia_aethiops,OV281079.1,2232011,2232271,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Erebia_aethiops,OV281079.1,2287647,2287741,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
# Erebia_aethiops,OV281079.1,2260903,2261076,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,2,56,56
# Erebia_aethiops,OV281079.1,2260031,2260150,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,1,39,39
# Erebia_aethiops,OV281079.1,2248797,2248868,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Erebia_aethiops,OV281079.1,2244767,2245103,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Erebia_aethiops,OV281079.1,2243282,2243399,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Erebia_aethiops,OV281079.1,2240449,2240676,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
# Erebia_aethiops,OV281079.1,2238742,2238958,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
# Erebia_aethiops,OV281079.1,2237059,2237262,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Erebia_aethiops,OV281079.1,2235480,2235592,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Erebia_aethiops,OV281079.1,2234619,2234812,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
# Erebia_aethiops,OV281079.1,2232011,2232271,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
#
# Maniola_jurtina
# Erebia_ligea,OU785222.1,18917850,18917944,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
#
# Maniola_jurtina
# Erebia_ligea,OU785222.1,18957505,18957678,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,1,56,56
#
# Maniola_jurtina
# Erebia_ligea,OU785222.1,18958498,18958617,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,1,39,39
#
# Maniola_jurtina
# Erebia_ligea,OU785222.1,18974435,18974521,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
#
# Maniola_jurtina
# Erebia_ligea,OU785222.1,18975398,18975734,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
#
# Maniola_jurtina
# Erebia_ligea,OU785222.1,18977873,18977990,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
#
# Maniola_jurtina
# Erebia_ligea,OU785222.1,18979847,18980074,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
#
# Maniola_jurtina
# Erebia_ligea,OU785222.1,18981217,18981433,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
#
# Maniola_jurtina
# Erebia_ligea,OU785222.1,18983165,18983368,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
#
# Maniola_jurtina
# Erebia_ligea,OU785222.1,18985395,18985510,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
#
# Maniola_jurtina
# Erebia_ligea,OU785222.1,18987290,18987483,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
#
# Maniola_jurtina
# Erebia_ligea,OU785222.1,18990491,18990772,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Erebia_ligea,OU785222.1,18917850,18917944,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
# Erebia_ligea,OU785222.1,18957505,18957678,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,1,56,56
# Erebia_ligea,OU785222.1,18958498,18958617,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,1,39,39
# Erebia_ligea,OU785222.1,18974435,18974521,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Erebia_ligea,OU785222.1,18975398,18975734,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Erebia_ligea,OU785222.1,18977873,18977990,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Erebia_ligea,OU785222.1,18979847,18980074,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
# Erebia_ligea,OU785222.1,18981217,18981433,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
# Erebia_ligea,OU785222.1,18983165,18983368,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Erebia_ligea,OU785222.1,18985395,18985510,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Erebia_ligea,OU785222.1,18987290,18987483,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
# Erebia_ligea,OU785222.1,18990491,18990772,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
# Maniola_jurtina
# Hipparchia_semele,OW121737.1,1093162,1093256,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
#
# Maniola_jurtina
# Hipparchia_semele,OW121737.1,1122779,1122973,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,2,56,56
#
# Maniola_jurtina
# Hipparchia_semele,OW121715.1,9482947,9483060,1,Y,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,5,38,39
#
# Maniola_jurtina
# Hipparchia_semele,OW121737.1,1128639,1128710,0,Y,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
#
# Maniola_jurtina
# Hipparchia_semele,OW121737.1,1129802,1130138,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
#
# Maniola_jurtina
# Hipparchia_semele,OW121737.1,1130717,1130834,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
#
# Maniola_jurtina
# Hipparchia_semele,OW121737.1,1131556,1131783,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
#
# Maniola_jurtina
# Hipparchia_semele,OW121737.1,1132339,1132558,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
#
# Maniola_jurtina
# Hipparchia_semele,OW121737.1,1133209,1133412,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
#
# Maniola_jurtina
# Hipparchia_semele,OW121737.1,1134019,1134131,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
#
# Maniola_jurtina
# Hipparchia_semele,OW121737.1,1135460,1135653,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
#
# Maniola_jurtina
# Hipparchia_semele,OW121737.1,1136155,1136439,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Hipparchia_semele,OW121737.1,1093162,1093256,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
# Hipparchia_semele,OW121737.1,1122779,1122973,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,2,56,56
# Hipparchia_semele,OW121715.1,9482947,9483060,1,Y,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,5,38,39
# Hipparchia_semele,OW121737.1,1128639,1128710,0,Y,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Hipparchia_semele,OW121737.1,1129802,1130138,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Hipparchia_semele,OW121737.1,1130717,1130834,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Hipparchia_semele,OW121737.1,1131556,1131783,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
# Hipparchia_semele,OW121737.1,1132339,1132558,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
# Hipparchia_semele,OW121737.1,1133209,1133412,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Hipparchia_semele,OW121737.1,1134019,1134131,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Hipparchia_semele,OW121737.1,1135460,1135653,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
# Hipparchia_semele,OW121737.1,1136155,1136439,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
#
# Maniola_jurtina
# Maniola_hyperantus,NC_048564.1,1902034,1902128,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
#
# Maniola_jurtina
# Maniola_hyperantus,NC_048564.1,1883955,1884125,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,1,55,56
#
# Maniola_jurtina
# Maniola_hyperantus,NC_048564.1,1883221,1883340,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,1,39,39
#
# Maniola_jurtina
# Maniola_hyperantus,NC_048564.1,1875757,1875828,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
#
# Maniola_jurtina
# Maniola_hyperantus,NC_048564.1,1874331,1874667,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
#
# Maniola_jurtina
# Maniola_hyperantus,NC_048564.1,1866484,1866601,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
#
# Maniola_jurtina
# Maniola_hyperantus,NC_048564.1,1865756,1865980,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
#
# Maniola_jurtina
# Maniola_hyperantus,NC_048564.1,1865396,1865615,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
#
# Maniola_jurtina
# Maniola_hyperantus,NC_048564.1,1862804,1863007,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
#
# Maniola_jurtina
# Maniola_hyperantus,NC_048564.1,1862050,1862162,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
#
# Maniola_jurtina
# Maniola_hyperantus,NC_048564.1,1860996,1861189,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
#
# Maniola_jurtina
# Maniola_hyperantus,NC_048564.1,1860370,1860651,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Maniola_hyperantus,NC_048564.1,1902034,1902128,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
# Maniola_hyperantus,NC_048564.1,1883955,1884125,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,1,55,56
# Maniola_hyperantus,NC_048564.1,1883221,1883340,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,1,39,39
# Maniola_hyperantus,NC_048564.1,1875757,1875828,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Maniola_hyperantus,NC_048564.1,1874331,1874667,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Maniola_hyperantus,NC_048564.1,1866484,1866601,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Maniola_hyperantus,NC_048564.1,1865756,1865980,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
# Maniola_hyperantus,NC_048564.1,1865396,1865615,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
# Maniola_hyperantus,NC_048564.1,1862804,1863007,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Maniola_hyperantus,NC_048564.1,1862050,1862162,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Maniola_hyperantus,NC_048564.1,1860996,1861189,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
# Maniola_hyperantus,NC_048564.1,1860370,1860651,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
#
# Maniola_jurtina
# Maniola_jurtina,NC_060058.1,1576394,1576488,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
#
# Maniola_jurtina
# Maniola_jurtina,NC_060058.1,1554970,1555140,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,1,56,56
#
# Maniola_jurtina
# Maniola_jurtina,NC_060058.1,1554327,1554446,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,1,39,39
#
# Maniola_jurtina
# Maniola_jurtina,NC_060058.1,1545017,1545088,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
#
# Maniola_jurtina
# Maniola_jurtina,NC_060058.1,1544178,1544514,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
#
# Maniola_jurtina
# Maniola_jurtina,NC_060058.1,1543641,1543758,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
#
# Maniola_jurtina
# Maniola_jurtina,NC_060058.1,1543119,1543343,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
#
# Maniola_jurtina
# Maniola_jurtina,NC_060058.1,1542759,1542978,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
#
# Maniola_jurtina
# Maniola_jurtina,NC_060058.1,1542150,1542353,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
#
# Maniola_jurtina
# Maniola_jurtina,NC_060058.1,1541650,1541762,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
#
# Maniola_jurtina
# Maniola_jurtina,NC_060058.1,1539435,1539628,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
#
# Maniola_jurtina
# Maniola_jurtina,NC_060058.1,1538403,1538684,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Maniola_jurtina,NC_060058.1,1576394,1576488,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
# Maniola_jurtina,NC_060058.1,1554970,1555140,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,1,56,56
# Maniola_jurtina,NC_060058.1,1554327,1554446,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,1,39,39
# Maniola_jurtina,NC_060058.1,1545017,1545088,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Maniola_jurtina,NC_060058.1,1544178,1544514,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Maniola_jurtina,NC_060058.1,1543641,1543758,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Maniola_jurtina,NC_060058.1,1543119,1543343,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
# Maniola_jurtina,NC_060058.1,1542759,1542978,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
# Maniola_jurtina,NC_060058.1,1542150,1542353,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Maniola_jurtina,NC_060058.1,1541650,1541762,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Maniola_jurtina,NC_060058.1,1539435,1539628,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
# Maniola_jurtina,NC_060058.1,1538403,1538684,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
# Maniola_jurtina
# Melanargia_galathea,OV049860.1,1276615,1276712,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
#
# Maniola_jurtina
# Melanargia_galathea,OV049860.1,1321525,1321725,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,2,56,56
#
# Maniola_jurtina
# Melanargia_galathea,OV049860.1,1322580,1322693,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,1,39,39
#
# Maniola_jurtina
# Melanargia_galathea,OV049860.1,1341910,1341981,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
#
# Maniola_jurtina
# Melanargia_galathea,OV049860.1,1343876,1344212,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
#
# Maniola_jurtina
# Melanargia_galathea,OV049860.1,1349265,1349382,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
#
# Maniola_jurtina
# Melanargia_galathea,OV049860.1,1349452,1349679,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
#
# Maniola_jurtina
# Melanargia_galathea,OV049860.1,1349995,1350214,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
#
# Maniola_jurtina
# Melanargia_galathea,OV049860.1,1350718,1350921,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
#
# Maniola_jurtina
# Melanargia_galathea,OV049860.1,1351350,1351462,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
#
# Maniola_jurtina
# Melanargia_galathea,OV049860.1,1351698,1351891,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
#
# Maniola_jurtina
# Melanargia_galathea,OV049860.1,1352658,1352942,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Melanargia_galathea,OV049860.1,1276615,1276712,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
# Melanargia_galathea,OV049860.1,1321525,1321725,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,2,56,56
# Melanargia_galathea,OV049860.1,1322580,1322693,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,1,39,39
# Melanargia_galathea,OV049860.1,1341910,1341981,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Melanargia_galathea,OV049860.1,1343876,1344212,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Melanargia_galathea,OV049860.1,1349265,1349382,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Melanargia_galathea,OV049860.1,1349452,1349679,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
# Melanargia_galathea,OV049860.1,1349995,1350214,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
# Melanargia_galathea,OV049860.1,1350718,1350921,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Melanargia_galathea,OV049860.1,1351350,1351462,0,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Melanargia_galathea,OV049860.1,1351698,1351891,0,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
# Melanargia_galathea,OV049860.1,1352658,1352942,0,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
#
# Maniola_jurtina
# Oeneis_ivallda,JARPMR010000001.1,12553829,12553923,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
#
# Maniola_jurtina
# Oeneis_ivallda,JARPMR010000001.1,12506304,12506498,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,2,56,56
#
# Maniola_jurtina
# Oeneis_ivallda,JARPMR010000017.1,2556418,2556537,0,Y,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,2,21,39
#
# Maniola_jurtina
# Oeneis_ivallda,JARPMR010000001.1,12488143,12488214,1,Y,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
#
# Maniola_jurtina
# Oeneis_ivallda,JARPMR010000001.1,12486779,12487115,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
#
# Maniola_jurtina
# Oeneis_ivallda,JARPMR010000001.1,12485897,12486014,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
#
# Maniola_jurtina
# Oeneis_ivallda,JARPMR010000001.1,12484186,12484413,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
#
# Maniola_jurtina
# Oeneis_ivallda,JARPMR010000001.1,12482851,12483067,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
#
# Maniola_jurtina
# Oeneis_ivallda,JARPMR010000001.1,12482355,12482558,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
#
# Maniola_jurtina
# Oeneis_ivallda,JARPMR010000001.1,12481095,12481207,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
#
# Maniola_jurtina
# Oeneis_ivallda,JARPMR010000001.1,12479521,12479714,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
#
# Maniola_jurtina
# Oeneis_ivallda,JARPMR010000001.1,12478654,12478935,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Oeneis_ivallda,JARPMR010000001.1,12553829,12553923,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_2_query_Exon_1,1,31,31
# Oeneis_ivallda,JARPMR010000001.1,12506304,12506498,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_2,2,56,56
# Oeneis_ivallda,JARPMR010000017.1,2556418,2556537,0,Y,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_3,2,21,39
# Oeneis_ivallda,JARPMR010000001.1,12488143,12488214,1,Y,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_4,1,23,23
# Oeneis_ivallda,JARPMR010000001.1,12486779,12487115,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_0_query_Exon_5,1,112,112
# Oeneis_ivallda,JARPMR010000001.1,12485897,12486014,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_1_query_Exon_6,1,39,39
# Oeneis_ivallda,JARPMR010000001.1,12484186,12484413,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_1_query_Exon_7,1,74,74
# Oeneis_ivallda,JARPMR010000001.1,12482851,12483067,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_2_query_Exon_8,1,72,72
# Oeneis_ivallda,JARPMR010000001.1,12482355,12482558,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_2_query_Exon_9,1,67,67
# Oeneis_ivallda,JARPMR010000001.1,12481095,12481207,1,N,Maniola_jurtina_XM_045928647.1_Frame_1_rightoh_1_query_Exon_10,1,37,37
# Oeneis_ivallda,JARPMR010000001.1,12479521,12479714,1,N,Maniola_jurtina_XM_045928647.1_Frame_2_rightoh_0_query_Exon_11,1,64,64
# Oeneis_ivallda,JARPMR010000001.1,12478654,12478935,1,N,Maniola_jurtina_XM_045928647.1_Frame_0_rightoh_0_query_Exon_12,1,94,94
