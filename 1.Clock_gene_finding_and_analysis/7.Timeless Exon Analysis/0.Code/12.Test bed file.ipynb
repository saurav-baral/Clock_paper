# %%
from Bio import SeqIO
import os
location = "/mnt/c/Users/sauba/Desktop/Emails/For Email Timeless"
list_of_species = os.listdir(location)
if "desktop.ini" in list_of_species:
    list_of_species.remove("desktop.ini")
    
for species in list_of_species:
#     input(species)
    print(species)
    with open(f"{location}/{species}/Transcript.bed", 'r') as bed_file:
        bed_file_list= bed_file.readlines()
    left_overhang = 0
    right_overhang = 0
    for lines in bed_file_list:
        lines_split = lines.split("\t")
        start = int(lines_split[1])
        stop = int(lines_split[2])

        genome_file = SeqIO.parse(f"{location}/{species}/Genome_fragment.fa", "fasta")

        for records in genome_file:
            sequence = (records.seq[start:stop])
            
            translated_sequence = (sequence[left_overhang:].translate())
            
            
            if "*" in translated_sequence[:-1]:
                print(sequence)
                print(translated_sequence)
                print(lines_split[3])
                check = input("continue?")
                if check == "n":
                    assert False
                
            right_overhang = len(sequence[left_overhang:]) % 3
#             print(left_overhang,right_overhang)
            left_overhang = (3 - right_overhang)%3
    #         print(left_overhang,)
    #     print(start,stop)
# Out:
# Anthocharis_cardamines
# Aporia_crataegi
# Argynnis_bischoffii_washingtonia
# Aricia_agestis
# Aricia_artaxerxes
# Baronia_brevicornis
# Battus_philenor
# Bicyclus_anynana
# Boloria_euphrosyne
# Boloria_selene
# Brenthis_daphne
# Brenthis_hecate
# Brenthis_ino
# Calephelis_nemesis
# Calephelis_virginiensis
# Calycopis_cecrops
# Celastrina_argiolus
# Coenonympha_glycerion
# Colias_behrii
# Colias_croceus
# Colias_eurytheme
# Cyaniris_semiargus
# Danaus_plexippus
# Dircenna_loreta
# Dryadula_phaetusa
# Dryas_iulia_moderata
# Elymnias_hypermnestra
# Erebia_aethiops
# Erebia_ligea
# Eueides_isabella
# Eumaeus_atala
# Euphydryas_editha
# Eurema_hecabe
# Fabriciana_adippe
# Glaucopsyche_alexis
# Heliconius_charithonia
# Heliconius_nattereri
# Heliconius_sara
# Helleia_helle
# Hestina_assimilis
# Hipparchia_semele
# Hypolimnas_misippus
# Lasiommata_megera
# Leptidea_juvernica
# Leptidea_reali
# Leptidea_sinapis
# Leptophobia_aripa
# Limenitis_camilla
# Luehdorfia_chinensis
# Lycaena_phlaeas
# Lysandra_bellargus
# Lysandra_coridon
# Maniola_hyperantus
# Maniola_jurtina
# Mechanitis_mazaeus
# Mechanitis_messenoides
# Melanargia_galathea
# Melinaea_marsaeus_rileyi
# Melinaea_menophilus
# Melitaea_cinxia
# Mellicta_athalia
# Napeogenes_inachia
# Napeogenes_sylphis
# Nymphalis_c-album
# Nymphalis_io
# Nymphalis_polychloros
# Nymphalis_urticae
# Oeneis_ivallda
# Ornithoptera_alexandrae
# Ornithoptera_priamus
# Papilio_dardanus_tibullus
# Papilio_demoleus
# Papilio_elwesi
# Papilio_gigon
# Papilio_glaucus
# Papilio_machaon
# Papilio_memnon
# Papilio_protenor
# Papilio_xuthus
# Pararge_aegeria
# Phengaris_arion
# Philaethria_dido
# Pieris_brassicae
# Pieris_mannii
# Pieris_melete
# Pieris_napi
# Pieris_rapae
# Plebejus_argus
# Polyommatus_icarus
# Polyommatus_iphigenia
# Sericinus_montela
# Teinopalpus_imperialis
# Troides_aeacus
# Troides_oblongomaculatus
# Vanessa_atalanta
# Vanessa_cardui
# Vanessa_tameamea
# Zerene_cesonia
