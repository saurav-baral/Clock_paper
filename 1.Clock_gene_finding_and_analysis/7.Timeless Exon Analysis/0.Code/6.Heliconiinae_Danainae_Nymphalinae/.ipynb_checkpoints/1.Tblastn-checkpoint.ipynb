# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import os
import re
import io

# %%
def get_genome_file(genome_location,species):
    list_of_files_in_genome_folder = os.listdir(f"{genome_location}/{species}")
    for file in list_of_files_in_genome_folder:
        if file.endswith("_genomic.fna"):
            genome_file = file
    return(genome_file)

# %%
# list_of_species = os.listdir("/mnt/h/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/1.Annotated Species")
list_of_species = ["Hestina assimilis","Charaxes varanes","Danaus chrysippus","Danaus plexippus","Dircenna loreta","Mechanitis mazaeus","Mechanitis messenoides","Melinaea marsaeus rileyi","Melinaea menophilus","Napeogenes inachia","Napeogenes sylphis","Argynnis bischoffii washingtonia","Boloria euphrosyne","Boloria selene","Brenthis daphne","Brenthis hecate","Brenthis ino","Dryadula phaetusa","Dryas iulia moderata","Eueides isabella","Fabriciana adippe","Heliconius charithonia","Heliconius nattereri","Heliconius sara","Philaethria dido","Limenitis camilla","Euphydryas editha","Hypolimnas misippus","Melitaea cinxia","Mellicta athalia","Nymphalis c-album","Nymphalis io","Nymphalis polychloros","Nymphalis urticae","Vanessa atalanta","Vanessa cardui","Vanessa tameamea"]
query_species = "Danaus_plexippus"
family_group = "6.Heliconiinae_Danainae_Nymphalinae"
query_location = f"/mnt/h/My Drive/Circadian Rhythm Genes Project/7.Timeless Exon Analysis/{family_group}/1.Query"
query_transcript_list = os.listdir(f"{query_location}/{query_species}")
if "desktop.ini" in query_transcript_list:
    query_transcript_list.remove("desktop.ini")

query_transcript = query_transcript_list[0]
# list_of_species.remove(query_species)
if "desktop.ini" in list_of_species:
    list_of_species.remove("desktop.ini")
list_of_genomes = os.listdir("/mnt/f/Genomes_2023-12-26")
query_location = f"/mnt/h/My Drive/Circadian Rhythm Genes Project/7.Timeless Exon Analysis/{family_group}/1.Query/{query_species}/{query_transcript}/query_protein.fa"

# %%
genome_file = ''
output = ''
for species in list_of_species:
    species = species.replace(" ", "_")
    # if "
    # species = species_folder.split(".")[1]
    blast_output_location = f"/mnt/h/My Drive/Circadian Rhythm Genes Project/7.Timeless Exon Analysis/{family_group}/1.Blast_result"
    try:
        os.mkdir(blast_output_location)
    except:
        pass
    
    blast_output_folders = os.listdir(blast_output_location)
    if species not in blast_output_folders:
        os.mkdir(f"/mnt/h/My Drive/Circadian Rhythm Genes Project/7.Timeless Exon Analysis/{family_group}/1.Blast_result/{species}")
    
    genome_location = f"/mnt/f/Genomes_2023-12-26"
#     for genome in list_of_genomes:
#         if species == genome:
#             files_in_genome_folder = os.listdir(f"/mnt/f/Genomes_2023-12-26/{genome}")
#             for file in files_in_genome_folder:
#                 if re.search('_genomic.fna$', file):
#                     genome_file = file
#                     break
    genome_file = get_genome_file(genome_location,species)
    
    output += f'echo {species}\ntblastn -seg no -query "{query_location}" -db "/mnt/f/Genomes_2023-12-26/{species}/{genome_file}" -num_alignments 3 -out "{blast_output_location}/{species}/{species}_blast_out.htm" -html \n\n tblastn -seg no -query "{query_location}" -db "/mnt/f/Genomes_2023-12-26/{species}/{genome_file}" -num_alignments 3 -out "{blast_output_location}/{species}/{species}_blast_out.txt"\n\n'
    
with io.open(f"/mnt/h/My Drive/Circadian Rhythm Genes Project/7.Timeless Exon Analysis/{family_group}/tblastn_{query_species}.sh", "w", newline='\n') as outfile:
    outfile.write(output)
#             print("here",genome)
#     print(species_folder)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 25
#      17     genome_location = f"/mnt/f/Genomes_2023-12-26"
#      18 #     for genome in list_of_genomes:
#      19 #         if species == genome:
#      20 #             files_in_genome_folder = os.listdir(f"/mnt/f/Genomes_2023-12-26/{genome}")
#    (...)
#      23 #                     genome_file = file
#      24 #                     break
# ---> 25     genome_file = get_genome_file(genome_location,species)
# ...
