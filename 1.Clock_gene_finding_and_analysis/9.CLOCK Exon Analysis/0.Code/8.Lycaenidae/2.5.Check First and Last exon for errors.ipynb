# %%
import os
import subprocess

family_group = "8.Lycaenidae"

location = f"/mnt/h/My Drive/Circadian Rhythm Genes Project/9.CLOCK Exon Analysis/{family_group}"

species_list = os.listdir(f"{location}/1.Blast_result")
if "desktop.ini" in species_list:
    species_list.remove("desktop.ini")
error_species = ''
# species_list=["Pararge_aegeria"]



for species in species_list:
    
    list_of_files_in_species_result_folder = os.listdir(f"{location}/1.Blast_result/{species}")
    backup_present = 0
    for files in list_of_files_in_species_result_folder:
        if files.endswith("_coordinates_old_backup.csv"):
            backup_present = 1

    if backup_present == 0:
        subprocess.run(f'cp "{location}/1.Blast_result/{species}/{species}_coordinates_old.csv" "{location}/1.Blast_result/{species}/{species}_coordinates_old_backup.csv"', shell = True)

    
    with open(f"{location}/1.Blast_result/{species}/{species}_coordinates_old_backup.csv", 'r') as coordinate_file:
        coordinate_list = coordinate_file.readlines()

    first_exon_error = coordinate_list[1].split(",")[5]
    last_exon_error = coordinate_list[-1].split(",")[5]
    
    
    
        
    if first_exon_error == "Y":
         
        print(f"\n\nFirst Exon: \n{coordinate_list[1]}")
        exon_name = coordinate_list[1].split(",")[6]
        while (True):

            fix_option = input("Fix!!\n1.Add New Coordinate\n2.Just change error from 'Y' to 'N'\n3.Stop 'n'")

            if fix_option == "n":
                assert False
            elif fix_option == "1":

                for i in range(len(coordinate_list)):
                    if coordinate_list[i].split(",")[5] == "N":
                        Species,Scaffold,Start,Stop,Complement = coordinate_list[i].split(",")[:5]
                        print(Species,Scaffold,Start,Stop,Complement)
                        if Complement == "0":
                            new_start = int(Start) - 2000*i
                            new_stop = int(Stop) - 2000*i
                        elif Complement == "1":
                            new_start = int(Start) + 2000*i
                            new_stop = int(Stop) + 2000*i

                        coordinate_list[1] = f"{Species},{Scaffold},{new_start},{new_stop},{Complement},N,{exon_name},0,0,0\n"             
                        break
                error_species +=f"{Species},{Scaffold},000,000,0,Y,Error_Exon_1,00,00,00\n"    
                break
            

            elif fix_option == "2":
                coordinate_list[1].replace(',Y,',',N,')
                break
            else:
                print("Retry?")
        

    if last_exon_error == "Y":
        print(f"\n\nLast Exon: \n{coordinate_list[-1]}")
        exon_name = coordinate_list[-1].split(",")[6]
        exon_number = exon_name.split("_")[-1]
        while (True):

            fix_option = input("Fix!!\n1.Add New Coordinate\n2.Just change error from 'Y' to 'N'\n3.Stop 'n'")

            if fix_option == "n":
                assert False
            elif fix_option == "1":

                for i in range(len(coordinate_list)):
                    position = len(coordinate_list)-1-i
                    if coordinate_list[position].split(",")[5] == "N":
                        Species,Scaffold,Start,Stop,Complement = coordinate_list[position].split(",")[:5]
    #                     print(Species,Scaffold,Start,Stop,Complement)
                        if Complement == "0":
                            new_start = int(Start) + 2000*i
                            new_stop = int(Stop) + 2000*i
                        elif Complement == "1":
                            new_start = int(Start) - 2000*i
                            new_stop = int(Stop) - 2000*i

                        coordinate_list[-1] = f"{Species},{Scaffold},{new_start},{new_stop},{Complement},N,{exon_name},0,0,0\n"             
                        
                        break
                    error_species +=f"{Species},{Scaffold},000,000,0,Y,Error_Exon_{exon_number},00,00,00\n"
                break

            elif fix_option == "2":
                coordinate_list[-1] = coordinate_list[-1].replace(',Y,',',N,')
                break
            else:
                print("Retry?")
        

    new_coordinates = "".join(coordinate_list)
    print(new_coordinates)

    with open(f"{location}/1.Blast_result/{species}/{species}_coordinates_old.csv", 'w') as out_coordinate_file:
        out_coordinate_file.write(new_coordinates)
    
with open(f"{location}/error_in_first_and_last.txt", 'w') as error_file:
    error_file.write(error_species)
print(error_species)
# Out:
# First Exon:
# Aricia_agestis,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Aricia_agestis NC_056428.1 32771356 32771504 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Aricia_agestis,NC_056428.1,32775356,32775504,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Aricia_agestis,NC_056428.1,32771356,32771504,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Aricia_agestis,NC_056428.1,32771022,32771203,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Aricia_agestis,NC_056428.1,32769986,32770103,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Aricia_agestis,NC_056428.1,32765550,32765645,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Aricia_agestis,NC_056428.1,32763261,32763330,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,1,22,22
# Aricia_agestis,NC_056428.1,32748502,32748740,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Aricia_agestis,NC_056428.1,32746812,32746959,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Aricia_agestis,NC_056428.1,32732447,32732630,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Aricia_agestis,NC_056428.1,32729653,32729829,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,59,59
# Aricia_agestis,NC_056428.1,32728335,32728496,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Aricia_agestis,NC_056428.1,32724296,32724418,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Aricia_agestis,NC_056428.1,32721852,32722010,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,53,53
#
#
#
# First Exon:
# Aricia_artaxerxes,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Aricia_artaxerxes OW569310.1 35286983 35287131 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Aricia_artaxerxes,OW569310.1,35290983,35291131,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Aricia_artaxerxes,OW569310.1,35286983,35287131,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Aricia_artaxerxes,OW569310.1,35286645,35286826,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Aricia_artaxerxes,OW569310.1,35280363,35280480,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Aricia_artaxerxes,OW569310.1,35275927,35276022,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Aricia_artaxerxes,OW569310.1,35273674,35273743,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,1,22,22
# Aricia_artaxerxes,OW569310.1,35257816,35258054,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Aricia_artaxerxes,OW569310.1,35256139,35256286,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Aricia_artaxerxes,OW569310.1,35227952,35228135,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Aricia_artaxerxes,OW569310.1,35224167,35224343,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,59,59
# Aricia_artaxerxes,OW569310.1,35222852,35223013,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Aricia_artaxerxes,OW569310.1,35218342,35218464,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Aricia_artaxerxes,OW569310.1,35215759,35215917,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,53,53
#
#
#
# First Exon:
# Calycopis_cecrops,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Calycopis_cecrops LUGF01024967.1 165686 165834 0
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Calycopis_cecrops,LUGF01024967.1,161686,161834,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Calycopis_cecrops,LUGF01024967.1,165686,165834,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Calycopis_cecrops,LUGF01024967.1,166279,166460,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,59,60
# Calycopis_cecrops,LUGF01024967.1,167112,167229,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,1,33,39
# Calycopis_cecrops,LUGF01024967.1,168478,168573,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Calycopis_cecrops,LUGF01024967.1,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,0,0,22
# Calycopis_cecrops,LUGF01024967.1,176372,176610,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,78,79
# Calycopis_cecrops,LUGF01024984.1,144,291,0,Y,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Calycopis_cecrops,LUGF01024967.1,179941,180109,0,Y,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Calycopis_cecrops,LUGF01024967.1,181110,181289,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,2,32,59
# Calycopis_cecrops,LUGF01024967.1,182902,183057,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,5,54,54
# Calycopis_cecrops,LUGF01024967.1,185076,185198,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,2,41,41
# Calycopis_cecrops,LUGF01024967.1,186922,187083,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,53,53
#
#
#
# First Exon:
# Celastrina_argiolus,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Celastrina_argiolus LR994583.1 14028473 14028621 1
#
#
# Last Exon:
# Celastrina_argiolus,LR994583.1,13974580,13974741,1,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,37,53
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'2
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Celastrina_argiolus,LR994583.1,14032473,14032621,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Celastrina_argiolus,LR994583.1,14028473,14028621,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Celastrina_argiolus,LR994583.1,14025164,14025345,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Celastrina_argiolus,LR994583.1,14023847,14023964,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Celastrina_argiolus,LR994583.1,14021694,14021789,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Celastrina_argiolus,LR994583.1,14007848,14007917,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,1,22,22
# Celastrina_argiolus,LR994583.1,14005624,14005862,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Celastrina_argiolus,LR994583.1,14005048,14005195,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Celastrina_argiolus,LR994583.1,14002624,14002807,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Celastrina_argiolus,LR994583.1,13996892,13997068,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,56,59
# Celastrina_argiolus,LR994583.1,13993516,13993665,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,5,54,54
# Celastrina_argiolus,LR994583.1,13976562,13976684,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Celastrina_argiolus,LR994583.1,13974580,13974741,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,37,53
#
#
#
# First Exon:
# Cyaniris_semiargus,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Cyaniris_semiargus LR994547.1 14867294 14867442 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Cyaniris_semiargus,LR994547.1,14871294,14871442,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Cyaniris_semiargus,LR994547.1,14867294,14867442,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Cyaniris_semiargus,LR994547.1,14864821,14865002,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Cyaniris_semiargus,LR994547.1,14863270,14863387,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Cyaniris_semiargus,LR994547.1,14861380,14861475,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Cyaniris_semiargus,LR994547.1,14858364,14858433,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,1,22,22
# Cyaniris_semiargus,LR994547.1,14853026,14853264,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Cyaniris_semiargus,LR994547.1,14851806,14851953,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Cyaniris_semiargus,LR994547.1,14841161,14841344,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Cyaniris_semiargus,LR994547.1,14833531,14833707,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,59,59
# Cyaniris_semiargus,LR994547.1,14831869,14832030,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Cyaniris_semiargus,LR994547.1,14829070,14829192,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Cyaniris_semiargus,LR994547.1,14828405,14828563,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,53,53
# First Exon:
# Cyclargus_thomasi,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Cyclargus_thomasi JAOTAV010040489.1 2032 2180 0
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Cyclargus_thomasi,JAOTAV010040489.1,-1968,-1820,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Cyclargus_thomasi,JAOTAV010040489.1,2032,2180,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Cyclargus_thomasi,JAOTAV010040489.1,2893,3074,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Cyclargus_thomasi,JAOTAV010040489.1,3399,3516,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,1,35,39
# Cyclargus_thomasi,JAOTAV010040489.1,6342,6437,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Cyclargus_thomasi,JAOTAV010040489.1,8951,9020,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,1,22,22
# Cyclargus_thomasi,JAOTAV010040489.1,10092,10330,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Cyclargus_thomasi,JAOTAV010040489.1,10690,10837,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Cyclargus_thomasi,JAOTAV010040489.1,14763,14946,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Cyclargus_thomasi,JAOTAV010005790.1,15874,16050,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,54,59
# Cyclargus_thomasi,JAOTAV010005790.1,17951,18112,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,3,54,54
# Cyclargus_thomasi,JAOTAV010005790.1,18997,19119,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Cyclargus_thomasi,JAOTAV010005790.1,20204,20362,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,53,53
#
#
#
# First Exon:
# Eumaeus_atala,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Eumaeus_atala JAFELO010000500.1 632101 632249 0
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Eumaeus_atala,JAFELO010000500.1,628101,628249,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Eumaeus_atala,JAFELO010000500.1,632101,632249,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Eumaeus_atala,JAFELO010000500.1,632678,632859,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,59,60
# Eumaeus_atala,JAFELO010000500.1,633127,633244,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,2,33,39
# Eumaeus_atala,JAFELO010000500.1,634720,634815,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Eumaeus_atala,JAFELO010000500.1,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,0,0,22
# Eumaeus_atala,JAFELO010000500.1,642196,642434,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,78,79
# Eumaeus_atala,JAFELO010000500.1,643375,643522,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Eumaeus_atala,JAFELO010000557.1,214463,214646,0,Y,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Eumaeus_atala,JAFELO010000500.1,649199,649369,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,2,58,59
# Eumaeus_atala,JAFELO010000500.1,649834,649989,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,5,54,54
# Eumaeus_atala,JAFELO010000500.1,652584,652706,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,2,41,41
# Eumaeus_atala,JAFELO010000500.1,653415,653576,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,53,53
#
#
#
# First Exon:
# Glaucopsyche_alexis,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Glaucopsyche_alexis FR990042.1 16684690 16684838 1
#
#
# Last Exon:
# Glaucopsyche_alexis,FR990042.1,16637094,16637255,1,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,37,53
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'2
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Glaucopsyche_alexis,FR990042.1,16688690,16688838,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Glaucopsyche_alexis,FR990042.1,16684690,16684838,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Glaucopsyche_alexis,FR990042.1,16682973,16683154,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Glaucopsyche_alexis,FR990042.1,16680062,16680179,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,2,35,39
# Glaucopsyche_alexis,FR990042.1,16676341,16676436,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Glaucopsyche_alexis,FR990042.1,16673453,16673522,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,1,22,22
# Glaucopsyche_alexis,FR990042.1,16657035,16657273,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Glaucopsyche_alexis,FR990042.1,16655781,16655928,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Glaucopsyche_alexis,FR990042.1,16648851,16649034,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Glaucopsyche_alexis,FR990042.1,16645492,16645671,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,54,59
# Glaucopsyche_alexis,FR990042.1,16639744,16639896,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,2,54,54
# Glaucopsyche_alexis,FR990042.1,16638221,16638343,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Glaucopsyche_alexis,FR990042.1,16637094,16637255,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,37,53
#
#
#
# First Exon:
# Helleia_helle,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Helleia_helle OY971420.1 10390637 10390785 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Helleia_helle,OY971420.1,10394637,10394785,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Helleia_helle,OY971420.1,10390637,10390785,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Helleia_helle,OY971420.1,10390162,10390343,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,59,60
# Helleia_helle,OY971420.1,10389713,10389830,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,2,34,39
# Helleia_helle,OY971420.1,10388169,10388264,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,2,31,31
# Helleia_helle,OY971420.1,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,0,0,22
# Helleia_helle,OY971420.1,10381625,10381863,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Helleia_helle,OY971420.1,10380649,10380796,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Helleia_helle,OY971420.1,10379138,10379315,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,2,61,61
# Helleia_helle,OY971414.1,26929856,26930032,1,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,19,57,59
# Helleia_helle,OY971420.1,10376923,10377078,1,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,5,54,54
# Helleia_helle,OY971420.1,10374934,10375056,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Helleia_helle,OY971420.1,10373752,10373913,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,9,53,53
#
#
#
# First Exon:
# Lycaena_phlaeas,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Lycaena_phlaeas HG995168.1 8141948 8142096 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Lycaena_phlaeas,HG995168.1,8145948,8146096,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Lycaena_phlaeas,HG995168.1,8141948,8142096,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Lycaena_phlaeas,HG995168.1,8141122,8141303,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,59,60
# Lycaena_phlaeas,HG995168.1,8140461,8140578,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,3,34,39
# Lycaena_phlaeas,HG995168.1,8139486,8139581,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,2,31,31
# Lycaena_phlaeas,HG995168.1,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,0,0,22
# Lycaena_phlaeas,HG995168.1,8129483,8129721,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Lycaena_phlaeas,HG995168.1,8128958,8129105,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Lycaena_phlaeas,HG995168.1,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,0,0,61
# Lycaena_phlaeas,HG995168.1,8126003,8126176,1,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,33,59
# Lycaena_phlaeas,HG995168.1,8125320,8125475,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,5,54,54
# Lycaena_phlaeas,HG995168.1,8123383,8123505,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Lycaena_phlaeas,HG995168.1,8121646,8121807,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,9,53,53
# First Exon:
# Lysandra_bellargus,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Lysandra_bellargus HG995319.1 11312208 11312356 0
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Lysandra_bellargus,HG995319.1,11308208,11308356,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Lysandra_bellargus,HG995319.1,11312208,11312356,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Lysandra_bellargus,HG995319.1,11312524,11312705,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Lysandra_bellargus,HG995319.1,11313520,11313637,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Lysandra_bellargus,HG995319.1,11317020,11317115,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Lysandra_bellargus,HG995319.1,11320226,11320295,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,1,22,22
# Lysandra_bellargus,HG995319.1,11323549,11323787,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Lysandra_bellargus,HG995319.1,11324461,11324608,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Lysandra_bellargus,HG995319.1,11332381,11332564,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Lysandra_bellargus,HG995319.1,11335276,11335452,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,59,59
# Lysandra_bellargus,HG995319.1,11336101,11336262,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Lysandra_bellargus,HG995319.1,11339520,11339642,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Lysandra_bellargus,HG995319.1,11340290,11340448,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,53,53
#
#
#
# First Exon:
# Lysandra_coridon,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Lysandra_coridon HG992055.1 22362791 22362939 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Lysandra_coridon,HG992055.1,22366791,22366939,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Lysandra_coridon,HG992055.1,22362791,22362939,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Lysandra_coridon,HG992055.1,22362442,22362623,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Lysandra_coridon,HG992055.1,22361506,22361623,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Lysandra_coridon,HG992055.1,22358565,22358660,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Lysandra_coridon,HG992055.1,22353628,22353697,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,1,22,22
# Lysandra_coridon,HG992055.1,22350109,22350347,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Lysandra_coridon,HG992055.1,22349284,22349431,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Lysandra_coridon,HG992055.1,22340630,22340813,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Lysandra_coridon,HG992055.1,22337795,22337971,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,59,59
# Lysandra_coridon,HG992055.1,22336239,22336400,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Lysandra_coridon,HG992055.1,22332648,22332770,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Lysandra_coridon,HG992055.1,22331610,22331768,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,53,53
#
#
#
# First Exon:
# Phengaris_arion,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Phengaris_arion OY751437.1 15499293 15499441 1
#
#
# Last Exon:
# Phengaris_arion,OY751437.1,15452129,15452287,1,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,2,37,53
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'2
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Phengaris_arion,OY751437.1,15503293,15503441,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Phengaris_arion,OY751437.1,15499293,15499441,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Phengaris_arion,OY751437.1,15492568,15492749,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Phengaris_arion,OY751437.1,15489012,15489129,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Phengaris_arion,OY751437.1,15487510,15487605,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Phengaris_arion,OY751437.1,15475017,15475086,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,1,22,22
# Phengaris_arion,OY751437.1,15470304,15470542,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Phengaris_arion,OY751437.1,15468898,15469045,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Phengaris_arion,OY751437.1,15464531,15464714,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Phengaris_arion,OY751437.1,15459987,15460166,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,54,59
# Phengaris_arion,OY751437.1,15456782,15456919,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,2,54,54
# Phengaris_arion,OY751437.1,15452956,15453078,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Phengaris_arion,OY751437.1,15452129,15452287,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,2,37,53
#
#
#
# First Exon:
# Plebejus_argus,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Plebejus_argus FR989932.1 7588740 7588888 0
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Plebejus_argus,FR989932.1,7584740,7584888,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Plebejus_argus,FR989932.1,7588740,7588888,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Plebejus_argus,FR989932.1,7589027,7589208,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Plebejus_argus,FR989932.1,7590283,7590400,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,1,36,39
# Plebejus_argus,FR989932.1,7592983,7593078,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Plebejus_argus,FR989932.1,7599165,7599234,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,1,22,22
# Plebejus_argus,FR989932.1,7601629,7601867,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Plebejus_argus,FR989932.1,7602410,7602557,0,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Plebejus_argus,FR989932.1,7616111,7616294,0,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Plebejus_argus,FR989932.1,7616932,7617117,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,59,59
# Plebejus_argus,FR989932.1,7620842,7621003,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Plebejus_argus,FR989932.1,7623423,7623545,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Plebejus_argus,FR989932.1,7624654,7624812,0,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,53,53
#
#
#
# First Exon:
# Polyommatus_icarus,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Polyommatus_icarus OW569320.1 29182852 29183000 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Polyommatus_icarus,OW569320.1,29186852,29187000,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Polyommatus_icarus,OW569320.1,29182852,29183000,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Polyommatus_icarus,OW569320.1,29182330,29182511,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Polyommatus_icarus,OW569320.1,29181797,29181914,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,1,38,39
# Polyommatus_icarus,OW569320.1,29179896,29179991,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Polyommatus_icarus,OW569320.1,29173345,29173414,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,1,22,22
# Polyommatus_icarus,OW569320.1,29169731,29169969,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Polyommatus_icarus,OW569320.1,29169367,29169514,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Polyommatus_icarus,OW569320.1,29161879,29162062,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Polyommatus_icarus,OW569320.1,29160805,29160981,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,59,59
# Polyommatus_icarus,OW569320.1,29155484,29155645,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Polyommatus_icarus,OW569320.1,29153893,29154015,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Polyommatus_icarus,OW569320.1,29152738,29152896,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,53,53
# First Exon:
# Polyommatus_iphigenia,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Polyommatus_iphigenia OY730178.1 30245252 30245400 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Polyommatus_iphigenia,OY730178.1,30249252,30249400,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Polyommatus_iphigenia,OY730178.1,30245252,30245400,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Polyommatus_iphigenia,OY730178.1,30244815,30244996,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Polyommatus_iphigenia,OY730178.1,30244289,30244406,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Polyommatus_iphigenia,OY730178.1,30242242,30242337,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Polyommatus_iphigenia,OY730178.1,30238995,30239064,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_6,1,22,22
# Polyommatus_iphigenia,OY730178.1,30234007,30234245,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Polyommatus_iphigenia,OY730178.1,30230725,30230872,1,N,Aricia_agestis_XM_042131827.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Polyommatus_iphigenia,OY730178.1,30223612,30223795,1,N,Aricia_agestis_XM_042131827.1_Frame_1_rightoh_0_query_Exon_9,1,61,61
# Polyommatus_iphigenia,OY730178.1,30219598,30219774,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_10,1,57,59
# Polyommatus_iphigenia,OY730178.1,30216666,30216827,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Polyommatus_iphigenia,OY730178.1,30214712,30214834,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Polyommatus_iphigenia,OY730178.1,30213413,30213571,1,N,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_0_query_Exon_13,1,53,53
#
#
#
# First Exon:
# Calephelis_nemesis,Intial_value,0,0,0,Y,Aricia_agestis_XM_042131827.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
