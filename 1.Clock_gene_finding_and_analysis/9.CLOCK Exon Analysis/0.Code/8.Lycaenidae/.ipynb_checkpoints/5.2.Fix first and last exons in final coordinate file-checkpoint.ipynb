# %%
import os
import subprocess

family_group = "8.Lycaenidae"


location = f"/mnt/h/My Drive/Circadian Rhythm Genes Project/9.CLOCK Exon Analysis/{family_group}"

list_of_species = os.listdir(f"{location}/1.Blast_result")

if "desktop.ini" in list_of_species:
    list_of_species.remove("desktop.ini")

with open(f"{location}/error_in_first_and_last.txt", 'r') as error_file:
    error_list = error_file.readlines()
    
for error in error_list:
    print(error)
    error_split = error.split(",")
    error_species = error_split[0]
    error_exon = error_split[6].split("_")[-1]
    print(error_species, error_exon)

    #making backup
        
    list_of_files_in_species_folder = os.listdir(f"{location}/1.Blast_result/{error_species}")
    
    if "final_coordinates_backup.csv" not in list_of_files_in_species_folder:
        subprocess.run(f'cp "{location}/1.Blast_result/{error_species}/final_coordinates.csv" "{location}/1.Blast_result/{error_species}/final_coordinates_backup.csv"', shell = True)
    
    
    with open(f"{location}/1.Blast_result/{error_species}/final_coordinates.csv", 'r') as coordinate_file:
        coordinate_list = coordinate_file.readlines()
    
    if error_exon == "1":
        
        coordinate_list[1] = error
#         print("".join(coordinate_list))
    else:
        coordinate_list[-1] = error
        
    with open(f"{location}/1.Blast_result/{error_species}/final_coordinates.csv", 'w') as new_coordinate_file:
        new_coordinate_file.write("".join(coordinate_list))
#     assert False
# print(list_of_species)

# for species in
# Out:
# Aricia_agestis,NC_056428.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Aricia_agestis 1
# Aricia_artaxerxes,OW569310.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Aricia_artaxerxes 1
# Calycopis_cecrops,LUGF01024967.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Calycopis_cecrops 1
# Celastrina_argiolus,LR994583.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Celastrina_argiolus 1
# Cyaniris_semiargus,LR994547.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Cyaniris_semiargus 1
# Cyclargus_thomasi,JAOTAV010040489.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Cyclargus_thomasi 1
# Eumaeus_atala,JAFELO010000500.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Eumaeus_atala 1
# Glaucopsyche_alexis,FR990042.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Glaucopsyche_alexis 1
# Helleia_helle,OY971420.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Helleia_helle 1
# Lycaena_phlaeas,HG995168.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Lycaena_phlaeas 1
# Lysandra_bellargus,HG995319.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Lysandra_bellargus 1
# Lysandra_coridon,HG992055.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Lysandra_coridon 1
# Phengaris_arion,OY751437.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Phengaris_arion 1
# Plebejus_argus,FR989932.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Plebejus_argus 1
# Polyommatus_icarus,OW569320.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Polyommatus_icarus 1
# Polyommatus_iphigenia,OY730178.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Polyommatus_iphigenia 1
# Calephelis_nemesis,NJDD01001881.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Calephelis_nemesis 1
# Calephelis_virginiensis,NJDC01000156.1,000,000,0,Y,Error_Exon_1,00,00,00
#
# Calephelis_virginiensis 1
