# %%
import os
import subprocess

family_group = "6.Heliconiinae_Danainae_Nymphalinae"

location = f"/mnt/h/My Drive/Circadian Rhythm Genes Project/9.CLOCK Exon Analysis/{family_group}"

species_list = os.listdir(f"{location}/1.Blast_result")
if "desktop.ini" in species_list:
    species_list.remove("desktop.ini")
error_species = ''
# species_list=["Pararge_aegeria"]



for species in species_list:
    
    list_of_files_in_species_result_folder = os.listdir(f"{location}/1.Blast_result/{species}")
    backup_present = 0
    for files in list_of_files_in_species_result_folder:
        if files.endswith("_coordinates_old_backup.csv"):
            backup_present = 1

    if backup_present == 0:
        subprocess.run(f'cp "{location}/1.Blast_result/{species}/{species}_coordinates_old.csv" "{location}/1.Blast_result/{species}/{species}_coordinates_old_backup.csv"', shell = True)

    
    with open(f"{location}/1.Blast_result/{species}/{species}_coordinates_old_backup.csv", 'r') as coordinate_file:
        coordinate_list = coordinate_file.readlines()

    first_exon_error = coordinate_list[1].split(",")[5]
    last_exon_error = coordinate_list[-1].split(",")[5]
    
    
    
        
    if first_exon_error == "Y":
         
        print(f"\n\nFirst Exon: \n{coordinate_list[1]}")
        exon_name = coordinate_list[1].split(",")[6]
        while (True):

            fix_option = input("Fix!!\n1.Add New Coordinate\n2.Just change error from 'Y' to 'N'\n3.Stop 'n'")

            if fix_option == "n":
                assert False
            elif fix_option == "1":

                for i in range(len(coordinate_list)):
                    if coordinate_list[i].split(",")[5] == "N":
                        Species,Scaffold,Start,Stop,Complement = coordinate_list[i].split(",")[:5]
                        print(Species,Scaffold,Start,Stop,Complement)
                        if Complement == "0":
                            new_start = int(Start) - 2000*i
                            new_stop = int(Stop) - 2000*i
                        elif Complement == "1":
                            new_start = int(Start) + 2000*i
                            new_stop = int(Stop) + 2000*i

                        coordinate_list[1] = f"{Species},{Scaffold},{new_start},{new_stop},{Complement},N,{exon_name},0,0,0\n"             
                        break
                error_species +=f"{Species},{Scaffold},000,000,0,Y,Error_Exon_1,00,00,00\n"    
                break
            

            elif fix_option == "2":
                coordinate_list[1].replace(',Y,',',N,')
                break
            else:
                print("Retry?")
        

    if last_exon_error == "Y":
        print(f"\n\nLast Exon: \n{coordinate_list[-1]}")
        exon_name = coordinate_list[-1].split(",")[6]
        exon_number = exon_name.split("_")[-1]
        while (True):

            fix_option = input("Fix!!\n1.Add New Coordinate\n2.Just change error from 'Y' to 'N'\n3.Stop 'n'")

            if fix_option == "n":
                assert False
            elif fix_option == "1":

                for i in range(len(coordinate_list)):
                    position = len(coordinate_list)-1-i
                    if coordinate_list[position].split(",")[5] == "N":
                        Species,Scaffold,Start,Stop,Complement = coordinate_list[position].split(",")[:5]
    #                     print(Species,Scaffold,Start,Stop,Complement)
                        if Complement == "0":
                            new_start = int(Start) + 2000*i
                            new_stop = int(Stop) + 2000*i
                        elif Complement == "1":
                            new_start = int(Start) - 2000*i
                            new_stop = int(Stop) - 2000*i

                        coordinate_list[-1] = f"{Species},{Scaffold},{new_start},{new_stop},{Complement},N,{exon_name},0,0,0\n"             
                        
                        break
                    error_species +=f"{Species},{Scaffold},000,000,0,Y,Error_Exon_{exon_number},00,00,00\n"
                break

            elif fix_option == "2":
                coordinate_list[-1] = coordinate_list[-1].replace(',Y,',',N,')
                break
            else:
                print("Retry?")
        

    new_coordinates = "".join(coordinate_list)
    print(new_coordinates)

    with open(f"{location}/1.Blast_result/{species}/{species}_coordinates_old.csv", 'w') as out_coordinate_file:
        out_coordinate_file.write(new_coordinates)
    
with open(f"{location}/error_in_first_and_last.txt", 'w') as error_file:
    error_file.write(error_species)
print(error_species)
# Out:
# First Exon:
# Hestina_assimilis,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Hestina_assimilis CM041759.1 30882230 30882378 0
#
#
# Last Exon:
# Hestina_assimilis,CM041757.1,4615833,4616063,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,5,37,42
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Hestina_assimilis,CM041759.1,30878230,30878378,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Hestina_assimilis,CM041759.1,30882230,30882378,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Hestina_assimilis,CM041759.1,30882451,30882632,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Hestina_assimilis,CM041759.1,30882712,30882826,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,2,26,38
# Hestina_assimilis,CM041759.1,30885911,30886006,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Hestina_assimilis,CM041759.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Hestina_assimilis,CM041759.1,30888218,30888456,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Hestina_assimilis,CM041759.1,30888687,30888834,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Hestina_assimilis,CM041759.1,30888835,30889012,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,3,62,62
# Hestina_assimilis,CM041759.1,30889470,30889658,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,29,63,63
# Hestina_assimilis,CM041759.1,30891327,30891488,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,5,25,54
# Hestina_assimilis,CM041759.1,30891695,30891817,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Hestina_assimilis,CM041759.1,30893695,30893817,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,0
#
#
#
# First Exon:
# Charaxes_varanes,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Charaxes_varanes JANCMC010045471.1 75118 75266 0
#
#
# Last Exon:
# Charaxes_varanes,JANCMC010004801.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,42
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Charaxes_varanes,JANCMC010045471.1,71118,71266,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Charaxes_varanes,JANCMC010045471.1,75118,75266,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Charaxes_varanes,JANCMC010045471.1,75350,75531,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Charaxes_varanes,JANCMC010045471.1,75765,75879,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,2,26,38
# Charaxes_varanes,JANCMC010045471.1,77403,77498,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Charaxes_varanes,JANCMC010050420.1,14431708,14431768,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,1,15,19
# Charaxes_varanes,JANCMC010033613.1,13611896,13612134,0,Y,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Charaxes_varanes,JANCMC010033613.1,13612762,13612909,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Charaxes_varanes,JANCMC010033613.1,13614066,13614249,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Charaxes_varanes,JANCMC010004801.1,3443116,3443304,1,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,30,63,63
# Charaxes_varanes,JANCMC010004801.1,3442409,3442573,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,3,54,54
# Charaxes_varanes,JANCMC010004801.1,3441150,3441272,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Charaxes_varanes,JANCMC010004801.1,3439150,3439272,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,0
#
#
#
# First Exon:
# Danaus_chrysippus,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Danaus_chrysippus CAKASE010000043.1 3313971 3314119 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Danaus_chrysippus,CAKASE010000043.1,3317971,3318119,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Danaus_chrysippus,CAKASE010000043.1,3313971,3314119,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Danaus_chrysippus,CAKASE010000043.1,3313674,3313855,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Danaus_chrysippus,CAKASE010000043.1,3313474,3313591,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Danaus_chrysippus,CAKASE010000043.1,3312100,3312195,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Danaus_chrysippus,CAKASE010000043.1,3311806,3311866,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,1,19,19
# Danaus_chrysippus,CAKASE010000043.1,3309962,3310200,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Danaus_chrysippus,CAKASE010000043.1,3309497,3309644,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Danaus_chrysippus,CAKASE010000043.1,3309120,3309306,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Danaus_chrysippus,CAKASE010000043.1,3308468,3308656,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,1,63,63
# Danaus_chrysippus,CAKASE010000043.1,3305601,3305762,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Danaus_chrysippus,CAKASE010000043.1,3304871,3304993,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Danaus_chrysippus,CAKASE010000043.1,3303937,3304062,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,42,42
#
#
#
# First Exon:
# Danaus_plexippus,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Danaus_plexippus NC_083559.1 3290327 3290475 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Danaus_plexippus,NC_083559.1,3294327,3294475,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Danaus_plexippus,NC_083559.1,3290327,3290475,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Danaus_plexippus,NC_083559.1,3290030,3290211,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Danaus_plexippus,NC_083559.1,3289833,3289947,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Danaus_plexippus,NC_083559.1,3288152,3288247,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Danaus_plexippus,NC_083559.1,3287831,3287891,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,1,19,19
# Danaus_plexippus,NC_083559.1,3286698,3286936,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Danaus_plexippus,NC_083559.1,3286251,3286398,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Danaus_plexippus,NC_083559.1,3285853,3286039,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Danaus_plexippus,NC_083559.1,3285370,3285558,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,1,63,63
# Danaus_plexippus,NC_083559.1,3283187,3283348,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Danaus_plexippus,NC_083559.1,3282407,3282529,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Danaus_plexippus,NC_083559.1,3281134,3281259,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,42,42
#
#
#
# First Exon:
# Dircenna_loreta,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Dircenna_loreta OY743092.1 4423435 4423583 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Dircenna_loreta,OY743092.1,4427435,4427583,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Dircenna_loreta,OY743092.1,4423435,4423583,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Dircenna_loreta,OY743092.1,4422955,4423136,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Dircenna_loreta,OY743092.1,4422735,4422852,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Dircenna_loreta,OY743092.1,4420783,4420878,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Dircenna_loreta,OY743092.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Dircenna_loreta,OY743092.1,4416281,4416519,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Dircenna_loreta,OY743092.1,4415801,4415948,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Dircenna_loreta,OY743092.1,4415532,4415715,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Dircenna_loreta,OY743092.1,4413255,4413443,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,2,63,63
# Dircenna_loreta,OY743092.1,4412732,4412893,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Dircenna_loreta,OY743092.1,4412408,4412530,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Dircenna_loreta,OY743092.1,4409508,4409636,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,42,42
#
#
#
# First Exon:
# Mechanitis_mazaeus,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Mechanitis_mazaeus OY365748.1 16692373 16692521 0
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Mechanitis_mazaeus,OY365748.1,16688373,16688521,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Mechanitis_mazaeus,OY365748.1,16692373,16692521,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Mechanitis_mazaeus,OY365748.1,16692801,16692982,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Mechanitis_mazaeus,OY365748.1,16693051,16693168,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Mechanitis_mazaeus,OY365748.1,16695319,16695414,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Mechanitis_mazaeus,OY365748.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Mechanitis_mazaeus,OY365748.1,16697909,16698147,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Mechanitis_mazaeus,OY365748.1,16698733,16698880,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Mechanitis_mazaeus,OY365748.1,16698975,16699158,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Mechanitis_mazaeus,OY365748.1,16700040,16700228,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,2,52,63
# Mechanitis_mazaeus,OY365748.1,16701254,16701415,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Mechanitis_mazaeus,OY365748.1,16701618,16701740,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Mechanitis_mazaeus,OY365748.1,16705416,16705544,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,42,42
#
#
#
# First Exon:
# Mechanitis_messenoides,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Mechanitis_messenoides OY365760.1 4260130 4260278 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Mechanitis_messenoides,OY365760.1,4264130,4264278,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Mechanitis_messenoides,OY365760.1,4260130,4260278,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Mechanitis_messenoides,OY365760.1,4259668,4259849,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Mechanitis_messenoides,OY365760.1,4259482,4259599,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Mechanitis_messenoides,OY365760.1,4257161,4257256,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Mechanitis_messenoides,OY365760.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Mechanitis_messenoides,OY365760.1,4254446,4254684,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Mechanitis_messenoides,OY365760.1,4253688,4253835,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Mechanitis_messenoides,OY365760.1,4253406,4253589,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Mechanitis_messenoides,OY365760.1,4252418,4252606,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,2,52,63
# Mechanitis_messenoides,OY365760.1,4251248,4251409,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Mechanitis_messenoides,OY365760.1,4250917,4251039,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Mechanitis_messenoides,OY365760.1,4246817,4246945,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,42,42
#
#
#
# First Exon:
# Melinaea_marsaeus_rileyi,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Melinaea_marsaeus_rileyi OU911095.1 15458857 15459005 0
#
#
# Last Exon:
# Melinaea_marsaeus_rileyi,OU911095.1,15472540,15472671,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,27,42
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'2
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Melinaea_marsaeus_rileyi,OU911095.1,15454857,15455005,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Melinaea_marsaeus_rileyi,OU911095.1,15458857,15459005,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Melinaea_marsaeus_rileyi,OU911095.1,15459264,15459445,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Melinaea_marsaeus_rileyi,OU911095.1,15459523,15459640,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Melinaea_marsaeus_rileyi,OU911095.1,15461757,15461852,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Melinaea_marsaeus_rileyi,OU911095.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Melinaea_marsaeus_rileyi,OU911095.1,15469413,15469651,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Melinaea_marsaeus_rileyi,OU911095.1,15469861,15470008,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Melinaea_marsaeus_rileyi,OU911095.1,15470084,15470267,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Melinaea_marsaeus_rileyi,OU911095.1,15470908,15471096,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,2,63,63
# Melinaea_marsaeus_rileyi,OU911095.1,15471378,15471539,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Melinaea_marsaeus_rileyi,OU911095.1,15471732,15471854,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Melinaea_marsaeus_rileyi,OU911095.1,15472540,15472671,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,27,42
#
#
#
# First Exon:
# Melinaea_menophilus,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Melinaea_menophilus OU911050.1 15208101 15208249 0
#
#
# Last Exon:
# Melinaea_menophilus,OU911050.1,15225803,15225934,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,27,42
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'2
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Melinaea_menophilus,OU911050.1,15204101,15204249,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Melinaea_menophilus,OU911050.1,15208101,15208249,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Melinaea_menophilus,OU911050.1,15208499,15208680,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Melinaea_menophilus,OU911050.1,15208756,15208873,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Melinaea_menophilus,OU911050.1,15210947,15211042,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Melinaea_menophilus,OU911050.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Melinaea_menophilus,OU911050.1,15222631,15222869,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Melinaea_menophilus,OU911050.1,15223151,15223298,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Melinaea_menophilus,OU911050.1,15223374,15223557,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Melinaea_menophilus,OU911050.1,15224199,15224387,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,2,63,63
# Melinaea_menophilus,OU911050.1,15224583,15224744,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Melinaea_menophilus,OU911050.1,15224943,15225065,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Melinaea_menophilus,OU911050.1,15225803,15225934,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,27,42
#
#
#
# First Exon:
# Napeogenes_inachia,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
#
Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Boloria_euphrosyne OX637870.1 7443173 7443321 1
#
#
# Last Exon:
# Boloria_euphrosyne,OX637870.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,42
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Boloria_euphrosyne,OX637870.1,7447173,7447321,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Boloria_euphrosyne,OX637870.1,7443173,7443321,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Boloria_euphrosyne,OX637870.1,7442900,7443081,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,59,60
# Boloria_euphrosyne,OX637870.1,7442704,7442821,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Boloria_euphrosyne,OX637870.1,7439233,7439328,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Boloria_euphrosyne,OX637878.1,1713708,1713768,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,1,16,19
# Boloria_euphrosyne,OX637870.1,7438202,7438440,1,Y,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Boloria_euphrosyne,OX637870.1,7437778,7437925,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Boloria_euphrosyne,OX637870.1,7435299,7435482,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Boloria_euphrosyne,OX637870.1,7434493,7434678,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,4,63,63
# Boloria_euphrosyne,OX637870.1,7433573,7433737,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,2,48,54
# Boloria_euphrosyne,OX637870.1,7427260,7427382,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Boloria_euphrosyne,OX637870.1,7425260,7425382,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,0
#
#
#
# First Exon:
# Boloria_selene,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Boloria_selene HG993131.1 6821487 6821635 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Boloria_selene,HG993131.1,6825487,6825635,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Boloria_selene,HG993131.1,6821487,6821635,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Boloria_selene,HG993131.1,6821216,6821397,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,59,60
# Boloria_selene,HG993131.1,6821017,6821134,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,34,38
# Boloria_selene,HG993131.1,6818187,6818282,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Boloria_selene,HG993139.1,1843123,1843183,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,1,16,19
# Boloria_selene,HG993131.1,6816698,6816936,1,Y,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Boloria_selene,HG993131.1,6816273,6816420,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Boloria_selene,HG993131.1,6815330,6815513,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Boloria_selene,HG993131.1,6814462,6814650,1,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,31,62,63
# Boloria_selene,HG993131.1,6813200,6813361,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Boloria_selene,HG993131.1,6809898,6810020,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,2,41,41
# Boloria_selene,HG993131.1,6809383,6809541,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,42,42
#
#
#
# First Exon:
# Brenthis_daphne,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Brenthis_daphne OX352480.1 14688346 14688494 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Brenthis_daphne,OX352480.1,14692346,14692494,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Brenthis_daphne,OX352480.1,14688346,14688494,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Brenthis_daphne,OX352480.1,14688080,14688261,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,59,60
# Brenthis_daphne,OX352480.1,14687875,14687992,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,2,38,38
# Brenthis_daphne,OX352480.1,14683784,14683879,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Brenthis_daphne,OX352480.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Brenthis_daphne,OX352480.1,14681275,14681513,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Brenthis_daphne,OX352480.1,14680855,14681002,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Brenthis_daphne,OX352480.1,14679836,14680019,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Brenthis_daphne,OX352480.1,14678894,14679082,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,2,63,63
# Brenthis_daphne,OX352480.1,14677591,14677752,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,2,54,54
# Brenthis_daphne,OX352480.1,14675860,14675982,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Brenthis_daphne,OX352480.1,14674601,14674756,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,42,42
#
#
#
# First Exon:
# Brenthis_hecate,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Brenthis_hecate OX638251.1 14533444 14533592 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Brenthis_hecate,OX638251.1,14537444,14537592,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Brenthis_hecate,OX638251.1,14533444,14533592,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Brenthis_hecate,OX638251.1,14533178,14533359,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,59,60
# Brenthis_hecate,OX638251.1,14532973,14533090,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,2,38,38
# Brenthis_hecate,OX638251.1,14528784,14528879,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
#
1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Heliconius_nattereri,JAAIXI010000210.1,635453,635601,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Heliconius_nattereri,JAAIXI010000210.1,635188,635369,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Heliconius_nattereri,JAAIXI010000210.1,634706,634823,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,2,37,38
# Heliconius_nattereri,JAAIXI010000210.1,632084,632179,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Heliconius_nattereri,JAAIXI010000210.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Heliconius_nattereri,JAAIXI010000210.1,630489,630727,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Heliconius_nattereri,JAAIXI010000210.1,629449,629596,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Heliconius_nattereri,JAAIXI010000210.1,628349,628532,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Heliconius_nattereri,JAAIXI010000210.1,627575,627757,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,3,63,63
# Heliconius_nattereri,JAAIXI010000210.1,625694,625855,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,2,54,54
# Heliconius_nattereri,JAAIXI010000210.1,625235,625357,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Heliconius_nattereri,JAAIXI010000210.1,623235,623357,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,0
#
#
#
# First Exon:
# Heliconius_sara,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Heliconius_sara OU860800.1 4355735 4355883 0
#
#
# Last Exon:
# Heliconius_sara,OU860800.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,42
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Heliconius_sara,OU860800.1,4351735,4351883,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Heliconius_sara,OU860800.1,4355735,4355883,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Heliconius_sara,OU860800.1,4355968,4356149,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Heliconius_sara,OU860800.1,4356547,4356664,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,34,38
# Heliconius_sara,OU860800.1,4359367,4359462,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Heliconius_sara,OU860800.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Heliconius_sara,OU860800.1,4361787,4362025,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Heliconius_sara,OU860800.1,4363703,4363850,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Heliconius_sara,OU860800.1,4364845,4365028,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# ...
# Nymphalis_c-album,OY720586.1,11573487,11573660,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,3,57,63
# Nymphalis_c-album,OY720586.1,11573783,11573944,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,3,54,54
# Nymphalis_c-album,OY720586.1,11574297,11574419,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Nymphalis_c-album,OY720586.1,11576297,11576419,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,0
#
#
#
# First Exon:
# Nymphalis_io,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Nymphalis_io NC_065918.1 6534334 6534482 1
#
#
# Last Exon:
# Nymphalis_io,NC_065918.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,42
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Nymphalis_io,NC_065918.1,6538334,6538482,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Nymphalis_io,NC_065918.1,6534334,6534482,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Nymphalis_io,NC_065918.1,6534069,6534250,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Nymphalis_io,NC_065918.1,6533871,6533988,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Nymphalis_io,NC_065918.1,6531404,6531499,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Nymphalis_io,NC_065918.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Nymphalis_io,NC_065918.1,6525765,6526003,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Nymphalis_io,NC_065918.1,6525444,6525591,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Nymphalis_io,NC_065918.1,6524620,6524803,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Nymphalis_io,NC_065918.1,6523605,6523784,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,3,63,63
# Nymphalis_io,NC_065918.1,6523335,6523496,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,2,54,54
# Nymphalis_io,NC_065918.1,6522877,6522999,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Nymphalis_io,NC_065918.1,6520877,6520999,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,0
#
#
#
# First Exon:
# Nymphalis_polychloros,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Nymphalis_polychloros HG992241.1 11396533 11396681 0
#
#
# Last Exon:
# Nymphalis_polychloros,HG992246.1,285673,285789,1,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,9,33,42
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Nymphalis_polychloros,HG992241.1,11392533,11392681,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Nymphalis_polychloros,HG992241.1,11396533,11396681,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Nymphalis_polychloros,HG992241.1,11396764,11396945,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Nymphalis_polychloros,HG992241.1,11397030,11397147,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Nymphalis_polychloros,HG992241.1,11399312,11399407,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Nymphalis_polychloros,HG992241.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Nymphalis_polychloros,HG992241.1,11403745,11403983,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Nymphalis_polychloros,HG992241.1,11404139,11404286,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Nymphalis_polychloros,HG992241.1,11405070,11405253,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Nymphalis_polychloros,HG992241.1,11406440,11406619,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,3,63,63
# Nymphalis_polychloros,HG992241.1,11406749,11406910,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,3,54,54
# Nymphalis_polychloros,HG992241.1,11407237,11407359,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Nymphalis_polychloros,HG992241.1,11409237,11409359,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,0
#
#
#
# First Exon:
# Nymphalis_urticae,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Nymphalis_urticae LR989982.1 6508152 6508300 1
#
#
# Last Exon:
# Nymphalis_urticae,LR989982.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,42
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Nymphalis_urticae,LR989982.1,6512152,6512300,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Nymphalis_urticae,LR989982.1,6508152,6508300,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Nymphalis_urticae,LR989982.1,6507886,6508067,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Nymphalis_urticae,LR989982.1,6507686,6507803,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Nymphalis_urticae,LR989982.1,6505105,6505200,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Nymphalis_urticae,LR989982.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Nymphalis_urticae,LR989982.1,6499702,6499940,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Nymphalis_urticae,LR989982.1,6499363,6499510,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Nymphalis_urticae,LR989982.1,6497843,6498026,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Nymphalis_urticae,LR989982.1,6496356,6496535,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,3,63,63
# Nymphalis_urticae,LR989982.1,6496086,6496247,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,3,54,54
# Nymphalis_urticae,LR989982.1,6495628,6495750,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Nymphalis_urticae,LR989982.1,6493628,6493750,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,0,0,0
# First Exon:
# Vanessa_atalanta,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Vanessa_atalanta NC_061902.1 10275470 10275618 0
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Vanessa_atalanta,NC_061902.1,10271470,10271618,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Vanessa_atalanta,NC_061902.1,10275470,10275618,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Vanessa_atalanta,NC_061902.1,10275718,10275899,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Vanessa_atalanta,NC_061902.1,10275974,10276091,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Vanessa_atalanta,NC_061902.1,10277640,10277735,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Vanessa_atalanta,NC_061902.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Vanessa_atalanta,NC_061902.1,10281398,10281636,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Vanessa_atalanta,NC_061902.1,10281803,10281950,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Vanessa_atalanta,NC_061902.1,10282243,10282426,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Vanessa_atalanta,NC_061902.1,10282907,10283092,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,3,63,63
# Vanessa_atalanta,NC_061902.1,10283310,10283471,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,3,54,54
# Vanessa_atalanta,NC_061902.1,10283787,10283909,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Vanessa_atalanta,NC_061902.1,10285526,10285708,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,41,42
#
#
#
# First Exon:
# Vanessa_cardui,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Vanessa_cardui NC_061154.1 10737537 10737685 0
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Vanessa_cardui,NC_061154.1,10733537,10733685,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Vanessa_cardui,NC_061154.1,10737537,10737685,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Vanessa_cardui,NC_061154.1,10737786,10737967,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Vanessa_cardui,NC_061154.1,10738061,10738178,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Vanessa_cardui,NC_061154.1,10739865,10739960,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Vanessa_cardui,NC_061154.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Vanessa_cardui,NC_061154.1,10744193,10744431,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Vanessa_cardui,NC_061154.1,10744870,10745017,0,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Vanessa_cardui,NC_061154.1,10746005,10746188,0,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,59,62
# Vanessa_cardui,NC_061154.1,10747293,10747478,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,3,63,63
# Vanessa_cardui,NC_061154.1,10750419,10750580,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,3,54,54
# Vanessa_cardui,NC_061154.1,10751034,10751156,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Vanessa_cardui,NC_061154.1,10753003,10753185,0,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,41,42
#
#
#
# First Exon:
# Vanessa_tameamea,Intial_value,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Vanessa_tameamea NW_020662887.1 733261 733409 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Vanessa_tameamea,NW_020662887.1,737261,737409,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Vanessa_tameamea,NW_020662887.1,733261,733409,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Vanessa_tameamea,NW_020662887.1,732979,733160,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Vanessa_tameamea,NW_020662887.1,732784,732901,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_1_query_Exon_4,1,38,38
# Vanessa_tameamea,NW_020662887.1,731130,731225,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Vanessa_tameamea,NW_020662887.1,0,0,0,Y,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Vanessa_tameamea,NW_020662887.1,727058,727296,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Vanessa_tameamea,NW_020662887.1,726743,726890,1,N,Danaus_plexippus_XM_032670980.2_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Vanessa_tameamea,NW_020662887.1,726245,726428,1,N,Danaus_plexippus_XM_032670980.2_Frame_1_rightoh_0_query_Exon_9,1,62,62
# Vanessa_tameamea,NW_020662887.1,725430,725615,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_10,3,63,63
# Vanessa_tameamea,NW_020662887.1,725053,725214,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_11,3,54,54
# Vanessa_tameamea,NW_020662887.1,724615,724737,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Vanessa_tameamea,NW_020662887.1,722782,722964,1,N,Danaus_plexippus_XM_032670980.2_Frame_0_rightoh_0_query_Exon_13,1,41,42
#
# Hestina_assimilis,CM041759.1,000,000,0,Y,Error_Exon_1,00,00,00
# Hestina_assimilis,CM041759.1,000,000,0,Y,Error_Exon_13,00,00,00
# Charaxes_varanes,JANCMC010045471.1,000,000,0,Y,Error_Exon_1,00,00,00
# Charaxes_varanes,JANCMC010045471.1,000,000,0,Y,Error_Exon_13,00,00,00
# Danaus_chrysippus,CAKASE010000043.1,000,000,0,Y,Error_Exon_1,00,00,00
# Danaus_plexippus,NC_083559.1,000,000,0,Y,Error_Exon_1,00,00,00
# Dircenna_loreta,OY743092.1,000,000,0,Y,Error_Exon_1,00,00,00
# Mechanitis_mazaeus,OY365748.1,000,000,0,Y,Error_Exon_1,00,00,00
# Mechanitis_messenoides,OY365760.1,000,000,0,Y,Error_Exon_1,00,00,00
# Melinaea_marsaeus_rileyi,OU911095.1,000,000,0,Y,Error_Exon_1,00,00,00
# Melinaea_menophilus,OU911050.1,000,000,0,Y,Error_Exon_1,00,00,00
# Napeogenes_inachia,OY365800.1,000,000,0,Y,Error_Exon_1,00,00,00
# Napeogenes_sylphis,OY365784.1,000,000,0,Y,Error_Exon_1,00,00,00
# Argynnis_bischoffii_washingtonia,CM066637.1,000,000,0,Y,Error_Exon_1,00,00,00
# Boloria_euphrosyne,OX637870.1,000,000,0,Y,Error_Exon_1,00,00,00
# Boloria_euphrosyne,OX637870.1,000,000,0,Y,Error_Exon_13,00,00,00
# Boloria_selene,HG993131.1,000,000,0,Y,Error_Exon_1,00,00,00
# Brenthis_daphne,OX352480.1,000,000,0,Y,Error_Exon_1,00,00,00
# Brenthis_hecate,OX638251.1,000,000,0,Y,Error_Exon_1,00,00,00
# Brenthis_ino,OV170231.1,000,000,0,Y,Error_Exon_1,00,00,00
# Dryadula_phaetusa,JAOYRS010000001.1,000,000,0,Y,Error_Exon_1,00,00,00
# Dryadula_phaetusa,JAOYRS010000001.1,000,000,0,Y,Error_Exon_13,00,00,00
# Dryas_iulia_moderata,CM032415.1,000,000,0,Y,Error_Exon_1,00,00,00
# Eueides_isabella,CM032383.1,000,000,0,Y,Error_Exon_1,00,00,00
# Fabriciana_adippe,FR989982.1,000,000,0,Y,Error_Exon_1,00,00,00
# Heliconius_charithonia,CM060829.1,000,000,0,Y,Error_Exon_1,00,00,00
# Heliconius_nattereri,JAAIXI010000210.1,000,000,0,Y,Error_Exon_1,00,00,00
# Heliconius_nattereri,JAAIXI010000210.1,000,000,0,Y,Error_Exon_13,00,00,00
# Heliconius_sara,OU860800.1,000,000,0,Y,Error_Exon_1,00,00,00
# Heliconius_sara,OU860800.1,000,000,0,Y,Error_Exon_13,00,00,00
# Philaethria_dido,JAKGSA010000004.1,000,000,0,Y,Error_Exon_1,00,00,00
# Philaethria_dido,JAKGSA010000004.1,000,000,0,Y,Error_Exon_13,00,00,00
# Limenitis_camilla,LR990224.1,000,000,0,Y,Error_Exon_1,00,00,00
# Limenitis_camilla,LR990224.1,000,000,0,Y,Error_Exon_13,00,00,00
# Euphydryas_editha,CAKOGL010000026.1,000,000,0,Y,Error_Exon_1,00,00,00
# Euphydryas_editha,CAKOGL010000026.1,000,000,0,Y,Error_Exon_13,00,00,00
# Hypolimnas_misippus,SGBE01001438.1,000,000,0,Y,Error_Exon_1,00,00,00
# Hypolimnas_misippus,SGBE01001438.1,000,000,0,Y,Error_Exon_13,00,00,00
# Melitaea_cinxia,NC_059424.1,000,000,0,Y,Error_Exon_1,00,00,00
# Melitaea_cinxia,NC_059424.1,000,000,0,Y,Error_Exon_13,00,00,00
# Mellicta_athalia,HG992176.1,000,000,0,Y,Error_Exon_1,00,00,00
# Mellicta_athalia,HG992176.1,000,000,0,Y,Error_Exon_13,00,00,00
# Nymphalis_c-album,OY720586.1,000,000,0,Y,Error_Exon_1,00,00,00
# Nymphalis_c-album,OY720586.1,000,000,0,Y,Error_Exon_13,00,00,00
# Nymphalis_io,NC_065918.1,000,000,0,Y,Error_Exon_1,00,00,00
# Nymphalis_io,NC_065918.1,000,000,0,Y,Error_Exon_13,00,00,00
# Nymphalis_polychloros,HG992241.1,000,000,0,Y,Error_Exon_1,00,00,00
# Nymphalis_polychloros,HG992241.1,000,000,0,Y,Error_Exon_13,00,00,00
# Nymphalis_urticae,LR989982.1,000,000,0,Y,Error_Exon_1,00,00,00
# Nymphalis_urticae,LR989982.1,000,000,0,Y,Error_Exon_13,00,00,00
# Vanessa_atalanta,NC_061902.1,000,000,0,Y,Error_Exon_1,00,00,00
# Vanessa_cardui,NC_061154.1,000,000,0,Y,Error_Exon_1,00,00,00
# Vanessa_tameamea,NW_020662887.1,000,000,0,Y,Error_Exon_1,00,00,00
