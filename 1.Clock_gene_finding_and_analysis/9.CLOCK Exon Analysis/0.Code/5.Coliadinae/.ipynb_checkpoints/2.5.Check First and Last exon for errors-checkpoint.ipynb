# %%
import os
import subprocess

family_group = "5.Coliadinae"

location = f"/mnt/h/My Drive/Circadian Rhythm Genes Project/9.CLOCK Exon Analysis/{family_group}"

species_list = os.listdir(f"{location}/1.Blast_result")
if "desktop.ini" in species_list:
    species_list.remove("desktop.ini")
error_species = ''
# species_list=["Pararge_aegeria"]



for species in species_list:
    
    list_of_files_in_species_result_folder = os.listdir(f"{location}/1.Blast_result/{species}")
    backup_present = 0
    for files in list_of_files_in_species_result_folder:
        if files.endswith("_coordinates_old_backup.csv"):
            backup_present = 1

    if backup_present == 0:
        subprocess.run(f'cp "{location}/1.Blast_result/{species}/{species}_coordinates_old.csv" "{location}/1.Blast_result/{species}/{species}_coordinates_old_backup.csv"', shell = True)

    
    with open(f"{location}/1.Blast_result/{species}/{species}_coordinates_old_backup.csv", 'r') as coordinate_file:
        coordinate_list = coordinate_file.readlines()

    first_exon_error = coordinate_list[1].split(",")[5]
    last_exon_error = coordinate_list[-1].split(",")[5]
    
    
    
        
    if first_exon_error == "Y":
         
        print(f"\n\nFirst Exon: \n{coordinate_list[1]}")
        exon_name = coordinate_list[1].split(",")[6]
        while (True):

            fix_option = input("Fix!!\n1.Add New Coordinate\n2.Just change error from 'Y' to 'N'\n3.Stop 'n'")

            if fix_option == "n":
                assert False
            elif fix_option == "1":

                for i in range(len(coordinate_list)):
                    if coordinate_list[i].split(",")[5] == "N":
                        Species,Scaffold,Start,Stop,Complement = coordinate_list[i].split(",")[:5]
                        print(Species,Scaffold,Start,Stop,Complement)
                        if Complement == "0":
                            new_start = int(Start) - 2000*i
                            new_stop = int(Stop) - 2000*i
                        elif Complement == "1":
                            new_start = int(Start) + 2000*i
                            new_stop = int(Stop) + 2000*i

                        coordinate_list[1] = f"{Species},{Scaffold},{new_start},{new_stop},{Complement},N,{exon_name},0,0,0\n"             
                        break
                error_species +=f"{Species},{Scaffold},000,000,0,Y,Error_Exon_1,00,00,00\n"    
                break
            

            elif fix_option == "2":
                coordinate_list[1].replace(',Y,',',N,')
                break
            else:
                print("Retry?")
        

    if last_exon_error == "Y":
        print(f"\n\nLast Exon: \n{coordinate_list[-1]}")
        exon_name = coordinate_list[-1].split(",")[6]
        exon_number = exon_name.split("_")[-1]
        while (True):

            fix_option = input("Fix!!\n1.Add New Coordinate\n2.Just change error from 'Y' to 'N'\n3.Stop 'n'")

            if fix_option == "n":
                assert False
            elif fix_option == "1":

                for i in range(len(coordinate_list)):
                    position = len(coordinate_list)-1-i
                    if coordinate_list[position].split(",")[5] == "N":
                        Species,Scaffold,Start,Stop,Complement = coordinate_list[position].split(",")[:5]
    #                     print(Species,Scaffold,Start,Stop,Complement)
                        if Complement == "0":
                            new_start = int(Start) + 2000*i
                            new_stop = int(Stop) + 2000*i
                        elif Complement == "1":
                            new_start = int(Start) - 2000*i
                            new_stop = int(Stop) - 2000*i

                        coordinate_list[-1] = f"{Species},{Scaffold},{new_start},{new_stop},{Complement},N,{exon_name},0,0,0\n"             
                        
                        break
                    error_species +=f"{Species},{Scaffold},000,000,0,Y,Error_Exon_{exon_number},00,00,00\n"
                break

            elif fix_option == "2":
                coordinate_list[-1] = coordinate_list[-1].replace(',Y,',',N,')
                break
            else:
                print("Retry?")
        

    new_coordinates = "".join(coordinate_list)
    print(new_coordinates)

    with open(f"{location}/1.Blast_result/{species}/{species}_coordinates_old.csv", 'w') as out_coordinate_file:
        out_coordinate_file.write(new_coordinates)
    
with open(f"{location}/error_in_first_and_last.txt", 'w') as error_file:
    error_file.write(error_species)
print(error_species)
# Out:
# First Exon:
# Bicyclus_anynana,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Bicyclus_anynana NC_069110.1 8758140 8758288 1
#
#
# Last Exon:
# Bicyclus_anynana,NC_069110.1,8738842,8740872,1,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,34,58
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'2
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Bicyclus_anynana,NC_069110.1,8762140,8762288,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Bicyclus_anynana,NC_069110.1,8758140,8758288,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Bicyclus_anynana,NC_069110.1,8757713,8757894,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Bicyclus_anynana,NC_069110.1,8757213,8757330,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_1_query_Exon_4,1,38,39
# Bicyclus_anynana,NC_069110.1,8753106,8753201,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Bicyclus_anynana,NC_069110.1,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Bicyclus_anynana,NC_069110.1,8748753,8748991,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Bicyclus_anynana,NC_069110.1,8747915,8748062,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Bicyclus_anynana,NC_069110.1,8747493,8747673,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_0_query_Exon_9,1,52,60
# Bicyclus_anynana,NC_069110.1,8746856,8747044,1,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_10,3,52,63
# Bicyclus_anynana,NC_069110.1,8746134,8746295,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Bicyclus_anynana,NC_069110.1,8742083,8742205,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Bicyclus_anynana,NC_069110.1,8738842,8740872,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,34,58
#
#
#
# First Exon:
# Coenonympha_glycerion,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Coenonympha_glycerion OY979626.1 8026636 8026784 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Coenonympha_glycerion,OY979626.1,8030636,8030784,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Coenonympha_glycerion,OY979626.1,8026636,8026784,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Coenonympha_glycerion,OY979626.1,8025728,8025909,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_0_query_Exon_3,2,60,60
# Coenonympha_glycerion,OY979626.1,8024708,8024825,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Coenonympha_glycerion,OY979626.1,8021461,8021556,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Coenonympha_glycerion,OY979626.1,8020296,8020356,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_6,1,19,19
# Coenonympha_glycerion,OY979626.1,8019257,8019495,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Coenonympha_glycerion,OY979626.1,8018430,8018577,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Coenonympha_glycerion,OY979626.1,8017170,8017350,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_0_query_Exon_9,1,60,60
# Coenonympha_glycerion,OY979626.1,8016337,8016525,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_10,1,59,63
# Coenonympha_glycerion,OY979626.1,8014779,8014940,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Coenonympha_glycerion,OY979626.1,8014015,8014137,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Coenonympha_glycerion,OY979626.1,8008322,8008531,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,53,58
#
#
#
# First Exon:
# Elymnias_hypermnestra,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Elymnias_hypermnestra JACTOM010000009.1 959018 959166 1
#
#
# Last Exon:
# Elymnias_hypermnestra,JACTOM010000009.1,935910,936413,1,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,35,58
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'2
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Elymnias_hypermnestra,JACTOM010000009.1,963018,963166,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Elymnias_hypermnestra,JACTOM010000009.1,959018,959166,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Elymnias_hypermnestra,JACTOM010000009.1,958752,958933,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_0_query_Exon_3,1,59,60
# Elymnias_hypermnestra,JACTOM010000009.1,958181,958298,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_1_query_Exon_4,1,35,39
# Elymnias_hypermnestra,JACTOM010000009.1,955439,955534,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Elymnias_hypermnestra,JACTOM010000009.1,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Elymnias_hypermnestra,JACTOM010000009.1,949934,950172,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Elymnias_hypermnestra,JACTOM010000009.1,948837,948984,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Elymnias_hypermnestra,JACTOM010000009.1,947012,947198,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_0_query_Exon_9,1,60,60
# Elymnias_hypermnestra,JACTOM010000009.1,945889,946077,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_10,1,63,63
# Elymnias_hypermnestra,JACTOM010000009.1,939785,939940,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Elymnias_hypermnestra,JACTOM010000009.1,937244,937366,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Elymnias_hypermnestra,JACTOM010000009.1,935910,936413,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,35,58
#
#
#
# First Exon:
# Erebia_aethiops,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Erebia_aethiops OV281079.1 8492961 8493109 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Erebia_aethiops,OV281079.1,8496961,8497109,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Erebia_aethiops,OV281079.1,8492961,8493109,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Erebia_aethiops,OV281079.1,8492139,8492320,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Erebia_aethiops,OV281079.1,8491523,8491640,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Erebia_aethiops,OV281079.1,8489614,8489709,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Erebia_aethiops,OV281079.1,8489309,8489366,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_6,1,19,19
# Erebia_aethiops,OV281079.1,8488382,8488620,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Erebia_aethiops,OV281079.1,8486522,8486669,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Erebia_aethiops,OV281079.1,8485777,8485957,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_0_query_Exon_9,1,60,60
# Erebia_aethiops,OV281079.1,8485158,8485346,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_10,1,63,63
# Erebia_aethiops,OV281079.1,8482913,8483074,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Erebia_aethiops,OV281079.1,8480591,8480713,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Erebia_aethiops,OV281079.1,8477430,8477612,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,58,58
#
#
#
# First Exon:
# Erebia_ligea,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Erebia_ligea OU785222.1 12335447 12335595 0
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Erebia_ligea,OU785222.1,12331447,12331595,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Erebia_ligea,OU785222.1,12335447,12335595,0,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Erebia_ligea,OU785222.1,12336352,12336533,0,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Erebia_ligea,OU785222.1,12337023,12337140,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Erebia_ligea,OU785222.1,12338611,12338706,0,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Erebia_ligea,OU785222.1,12338963,12339023,0,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_6,1,19,19
# Erebia_ligea,OU785222.1,12340528,12340766,0,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Erebia_ligea,OU785222.1,12341474,12341621,0,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Erebia_ligea,OU785222.1,12342390,12342570,0,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_0_query_Exon_9,1,60,60
# Erebia_ligea,OU785222.1,12343462,12343650,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_10,1,63,63
# Erebia_ligea,OU785222.1,12344287,12344448,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Erebia_ligea,OU785222.1,12346820,12346942,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Erebia_ligea,OU785222.1,12350208,12350387,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,58,58
#
#
#
# First Exon:
# Hipparchia_semele,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Hipparchia_semele OW121737.1 6431576 6431724 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Hipparchia_semele,OW121737.1,6435576,6435724,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Hipparchia_semele,OW121737.1,6431576,6431724,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Hipparchia_semele,OW121737.1,6430956,6431137,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Hipparchia_semele,OW121737.1,6430337,6430454,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Hipparchia_semele,OW121737.1,6428287,6428382,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Hipparchia_semele,OW121737.1,6427942,6428002,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_6,1,18,19
# Hipparchia_semele,OW121737.1,6426800,6427038,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Hipparchia_semele,OW121737.1,6425426,6425573,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Hipparchia_semele,OW121737.1,6424647,6424827,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_0_query_Exon_9,1,60,60
# Hipparchia_semele,OW121737.1,6423604,6423792,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_10,1,63,63
# Hipparchia_semele,OW121737.1,6422239,6422400,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Hipparchia_semele,OW121737.1,6419495,6419617,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Hipparchia_semele,OW121737.1,6417741,6417914,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,58,58
#
#
#
# First Exon:
# Lasiommata_megera,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Lasiommata_megera OV743307.1 16306870 16307018 0
#
#
# Last Exon:
# Lasiommata_megera,OV743307.1,16317119,16318561,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,46,58
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'2
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Lasiommata_megera,OV743307.1,16302870,16303018,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Lasiommata_megera,OV743307.1,16306870,16307018,0,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_2,4,49,49
# Lasiommata_megera,OV743307.1,16307938,16308119,0,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Lasiommata_megera,OV743307.1,16308256,16308373,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Lasiommata_megera,OV743307.1,16309617,16309712,0,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Lasiommata_megera,OV743307.1,16310114,16310174,0,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_6,1,19,19
# Lasiommata_megera,OV743307.1,16310958,16311196,0,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Lasiommata_megera,OV743307.1,16311556,16311703,0,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Lasiommata_megera,OV743307.1,16313360,16313552,0,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_0_query_Exon_9,1,60,60
# Lasiommata_megera,OV743307.1,16314242,16314427,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_10,3,63,63
# Lasiommata_megera,OV743307.1,16315191,16315352,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_11,3,54,54
# Lasiommata_megera,OV743307.1,16316353,16316475,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Lasiommata_megera,OV743307.1,16317119,16318561,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,46,58
#
#
#
# First Exon:
# Maniola_hyperantus,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Maniola_hyperantus NC_048564.1 7131223 7131371 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Maniola_hyperantus,NC_048564.1,7135223,7135371,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Maniola_hyperantus,NC_048564.1,7131223,7131371,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Maniola_hyperantus,NC_048564.1,7130629,7130810,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Maniola_hyperantus,NC_048564.1,7129825,7129942,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Maniola_hyperantus,NC_048564.1,7128258,7128353,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Maniola_hyperantus,NC_048564.1,7127647,7127707,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_6,2,19,19
# Maniola_hyperantus,NC_048564.1,7127038,7127276,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Maniola_hyperantus,NC_048564.1,7125161,7125308,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Maniola_hyperantus,NC_048564.1,7122996,7123176,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_0_query_Exon_9,1,60,60
# Maniola_hyperantus,NC_048564.1,7122567,7122755,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_10,1,52,63
# Maniola_hyperantus,NC_048564.1,7121785,7121946,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Maniola_hyperantus,NC_048564.1,7119621,7119743,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Maniola_hyperantus,NC_048564.1,7118619,7118792,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,58,58
#
#
#
# First Exon:
# Maniola_jurtina,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Maniola_jurtina NC_060058.1 6682591 6682739 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Maniola_jurtina,NC_060058.1,6686591,6686739,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Maniola_jurtina,NC_060058.1,6682591,6682739,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Maniola_jurtina,NC_060058.1,6682015,6682196,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Maniola_jurtina,NC_060058.1,6681416,6681533,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Maniola_jurtina,NC_060058.1,6679388,6679483,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Maniola_jurtina,NC_060058.1,6678977,6679037,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_6,1,19,19
# Maniola_jurtina,NC_060058.1,6678312,6678550,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Maniola_jurtina,NC_060058.1,6677429,6677576,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Maniola_jurtina,NC_060058.1,6676994,6677174,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_0_query_Exon_9,1,60,60
# Maniola_jurtina,NC_060058.1,6676423,6676611,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_10,1,63,63
# Maniola_jurtina,NC_060058.1,6675559,6675720,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Maniola_jurtina,NC_060058.1,6674159,6674281,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Maniola_jurtina,NC_060058.1,6673302,6673475,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,58,58
#
#
#
# First Exon:
# Melanargia_galathea,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Melanargia_galathea OV049860.1 11232528 11232676 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Melanargia_galathea,OV049860.1,11236528,11236676,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Melanargia_galathea,OV049860.1,11232528,11232676,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Melanargia_galathea,OV049860.1,11229181,11229362,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Melanargia_galathea,OV049860.1,11206555,11206672,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Melanargia_galathea,OV049860.1,11204234,11204329,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Melanargia_galathea,OV049860.1,11202991,11203051,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_6,1,18,19
# Melanargia_galathea,OV049860.1,11201754,11201992,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Melanargia_galathea,OV049860.1,11200648,11200795,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Melanargia_galathea,OV049860.1,11199538,11199718,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_0_query_Exon_9,1,60,60
# Melanargia_galathea,OV049860.1,11197941,11198129,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_10,1,63,63
# Melanargia_galathea,OV049860.1,11194326,11194487,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Melanargia_galathea,OV049860.1,11190140,11190262,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Melanargia_galathea,OV049860.1,11188699,11188917,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,58,58
#
#
#
# First Exon:
# Oeneis_ivallda,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Oeneis_ivallda JARPMR010000001.1 15505054 15505202 1
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Oeneis_ivallda,JARPMR010000001.1,15509054,15509202,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Oeneis_ivallda,JARPMR010000001.1,15505054,15505202,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_2,1,49,49
# Oeneis_ivallda,JARPMR010000001.1,15503616,15503797,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Oeneis_ivallda,JARPMR010000001.1,15502717,15502834,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Oeneis_ivallda,JARPMR010000001.1,15494472,15494567,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_1_query_Exon_5,2,31,31
# Oeneis_ivallda,JARPMR010000001.1,15491656,15491716,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_6,1,18,19
# Oeneis_ivallda,JARPMR010000001.1,15490125,15490363,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Oeneis_ivallda,JARPMR010000001.1,15489053,15489200,1,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Oeneis_ivallda,JARPMR010000001.1,15488313,15488493,1,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_0_query_Exon_9,1,60,60
# Oeneis_ivallda,JARPMR010000001.1,15487451,15487639,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_10,1,52,63
# Oeneis_ivallda,JARPMR010000001.1,15486644,15486805,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_11,1,54,54
# Oeneis_ivallda,JARPMR010000001.1,15474575,15474697,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_12,1,41,41
# Oeneis_ivallda,JARPMR010000001.1,15471325,15471495,1,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,56,58
#
#
#
# First Exon:
# Pararge_aegeria,Intial_value,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,12
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'1
# Pararge_aegeria NC_053208.1 15873830 15873978 0
#
#
# Last Exon:
# Pararge_aegeria,NC_053208.1,15895634,15897916,0,Y,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,28,58
#
# Fix!!
# 1.Add New Coordinate
# 2.Just change error from 'Y' to 'N'
# 3.Stop 'n'2
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Pararge_aegeria,NC_053208.1,15869830,15869978,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_2_query_Exon_1,0,0,0
# Pararge_aegeria,NC_053208.1,15873830,15873978,0,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_2,1,48,49
# Pararge_aegeria,NC_053208.1,15874741,15874922,0,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_0_query_Exon_3,1,60,60
# Pararge_aegeria,NC_053208.1,15875256,15875373,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_1_query_Exon_4,1,39,39
# Pararge_aegeria,NC_053208.1,15878807,15878902,0,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_1_query_Exon_5,1,31,31
# Pararge_aegeria,NC_053208.1,0,0,0,Y,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_6,0,0,19
# Pararge_aegeria,NC_053208.1,15882208,15882446,0,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_1_query_Exon_7,1,79,79
# Pararge_aegeria,NC_053208.1,15882917,15883064,0,N,Maniola_jurtina_XM_045928040.1_Frame_2_rightoh_2_query_Exon_8,1,48,48
# Pararge_aegeria,NC_053208.1,15883571,15883751,0,N,Maniola_jurtina_XM_045928040.1_Frame_1_rightoh_0_query_Exon_9,1,54,60
# Pararge_aegeria,NC_053208.1,15885353,15885544,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_10,3,59,63
# Pararge_aegeria,NC_053208.1,15886716,15886877,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_11,4,54,54
# Pararge_aegeria,NC_053208.1,15889752,15889874,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_12,2,41,41
# Pararge_aegeria,NC_053208.1,15895634,15897916,0,N,Maniola_jurtina_XM_045928040.1_Frame_0_rightoh_0_query_Exon_13,1,28,58
#
# Bicyclus_anynana,NC_069110.1,000,000,0,Y,Error_Exon_1,00,00,00
# Coenonympha_glycerion,OY979626.1,000,000,0,Y,Error_Exon_1,00,00,00
# Elymnias_hypermnestra,JACTOM010000009.1,000,000,0,Y,Error_Exon_1,00,00,00
# Erebia_aethiops,OV281079.1,000,000,0,Y,Error_Exon_1,00,00,00
# Erebia_ligea,OU785222.1,000,000,0,Y,Error_Exon_1,00,00,00
# Hipparchia_semele,OW121737.1,000,000,0,Y,Error_Exon_1,00,00,00
# Lasiommata_megera,OV743307.1,000,000,0,Y,Error_Exon_1,00,00,00
# Maniola_hyperantus,NC_048564.1,000,000,0,Y,Error_Exon_1,00,00,00
# Maniola_jurtina,NC_060058.1,000,000,0,Y,Error_Exon_1,00,00,00
# Melanargia_galathea,OV049860.1,000,000,0,Y,Error_Exon_1,00,00,00
# Oeneis_ivallda,JARPMR010000001.1,000,000,0,Y,Error_Exon_1,00,00,00
# Pararge_aegeria,NC_053208.1,000,000,0,Y,Error_Exon_1,00,00,00
