# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import requests
from bs4 import BeautifulSoup
import os

location = "J:/My Drive/Circadian Rhythm Genes Project/3.Genes from NCBI/1.Period"
list_of_species = os.listdir(f"{location}/0.Species")
# gene = "LOC106113722"
# species = "Papilio xuthus".replace(" ", "_")
species_folder = ''

with open(f"{location}/gene_detail.txt", 'r') as gene_file:
    gene_list = gene_file.readlines()

for i in range(1, len(gene_list)):
    gene_list_split = gene_list[i].split("\t")
    species = gene_list_split[0].replace(" ", "_")
    gene = gene_list_split[2]
    print(species, gene)
#     
#     print (gene_list[i])

    for folder_name in list_of_species:
        if species in folder_name:
            species_folder = folder_name
            print(folder_name)
            break

    url=f'https://www.ncbi.nlm.nih.gov/gene/?term={gene}&report=gene_table&format=text'
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "xml")
#     print(soup.text)

    with open(f"{location}/0.Species/{species_folder}/Gene_table.txt", 'w') as out_file:
        out_file.write(soup.text)
# Out:
# Papilio_polytes LOC106110082
#
# 17.Papilio_polytes
# Bombyx_mandarina LOC114246916
#
# 18.Bombyx_mandarina
# Trichoplusia_ni LOC113493972
#
# 19.Trichoplusia_ni
# Vanessa_tameamea LOC113403059
#
# 20.Vanessa_tameamea
# Amyelois_transitella LOC106130500
#
# 21.Amyelois_transitella
# Pieris_brassicae LOC123718685
#
# 22.Pieris_brassicae
# Vanessa_atalanta LOC125076188
#
# 23.Vanessa_atalanta
# Spodoptera_frugiperda LOC118261937
#
# 24.Spodoptera_frugiperda
# Pieris_napi LOC125062481
#
# 25.Pieris_napi
# Vanessa_cardui LOC124543195
#
# 26.Vanessa_cardui
# Maniola_hyperantus LOC117995700
#
# 27.Maniola_hyperantus
# Maniola_jurtina LOC123880638
#
# 28.Maniola_jurtina
# Nymphalis_io LOC126780285
#
# 29.Nymphalis_io
# Leptidea_sinapis LOC126979027
#
# 30.Leptidea_sinapis
# Leguminivora_glycinivorella LOC125240683
#
# 31.Leguminivora_glycinivorella
# Colias_croceus LOC123705108
#
# 32.Colias_croceus
# Pararge_aegeria LOC120636016
#
# 33.Pararge_aegeria
# Achroia_grisella LOC131841862
#
# 35.Achroia_grisella_2
# Melitaea_cinxia LOC123668776
#
# 36.Melitaea_cinxia
# Aricia_agestis LOC121739130
#
# 37.Aricia_agestis
# Papilio_machaon LOC106719908
#
# 38.Papilio_machaon
# Ostrinia_furnacalis LOC114365005
#
# 43.Ostrinia_furnacalis

# %%
import re 


location = "J:/My Drive/Circadian Rhythm Genes Project/3.Genes from NCBI/1.Period"
list_of_species = os.listdir(f"{location}/0.Species")
list_of_species.remove("names")
list_of_species.remove("desktop.ini")
species_folder = ''
exon_list = "Exon1,Exon2,Exon3,Exon4,Exon5,Exon6,Exon7,Exon8,Exon9,Exon10,Exon11,Exon12,Exon13,Exon14,Exon15,Exon16,Exon17,Exon18,Exon19,Exon20,Exon21,Exon22,Exon23,Exon24,Exon25,Exon26,Exon27,Exon28,Exon29,Exon30,Exon31,Exon32,Exon33,Exon34".split(",")
for species in list_of_species:
    print(species)
    with open(f"{location}/0.Species/{species}/Gene_table.txt","r") as gene_table_file:
        gene_table_list = gene_table_file.readlines()
#         print(gene_table_list)

    

    i = 0
    switch = 0
    output = "mRNA Accession\tExon Number\tCoding Length\tGenome Start Point\tGenome Stop Point\n" 
    output2 = "mRNA Accession\tProtein Accession\tExon Number\tAlignment Score with Bombyx mori\n"
    exon_counter = 0

    while i < (len(gene_table_list)):

        if "Exon table for  mRNA  " in gene_table_list[i]:
            gene_table_line = gene_table_list[i]
            while re.search("[ ]{2,}", gene_table_line):
                gene_table_line = gene_table_line.replace("  "," ")

            mrna_accession = gene_table_line.split(" ")[4]
        
            switch = 1
            i += 3
        if switch == 1:

            gene_table_line = gene_table_list[i]
            while re.search("[\t]{2,}", gene_table_line):
                gene_table_line = gene_table_line.replace("\t\t","\t")
            if len(gene_table_line.split("\t")) == 7 or len(gene_table_line.split("\t")) == 6:

                coding_exon_length =  ((gene_table_line.split("\t")[5]))
                genome_start_point,genome_end_point = ((gene_table_line.split("\t")[1]).split("-"))
#                 print((gene_table_line.split("\t")[1]).split("-"))
                output += f"{mrna_accession}\t{exon_list[exon_counter]}\t{coding_exon_length.rstrip()}\t{genome_start_point}\t{genome_end_point}\n"
            
        
                exon_counter += 1

            if switch == 1 and re.search("^mRNA",gene_table_list[i]):
                switch = 0
                print(exon_counter)
                output += "\n\n"
                exon_counter = 0

        i += 1

    with open(f"{location}/0.Species/{species}/Gene_table_processed.tsv",'w') as out_file:
        out_file.write(output)
# Out:
# 1.Bombyx_mori
# 26
# 26
# 24
# 26
# 25
# 25
# 24
# 24
# 24
# 25
# 2.Galleria_mellonella
# 28
# 27
# 28
# 3.Spodoptera_litura
# 29
# 29
# 28
# 30
# 29
# 29
# 27
# 28
# 28
# 28
# 29
# 29
# 30
# 26
# 43.Ostrinia_furnacalis
# 27
# 26
# 27
# 27
# 25
# 25
# 25
# 32.Colias_croceus
# 27
# 27
# 26
# 31.Leguminivora_glycinivorella
# 26
# 26
# 26
# 30.Leptidea_sinapis
# 26
# 25
# 26
# 29.Nymphalis_io
# 28
# 27
# 28
# 28.Maniola_jurtina
# 27
# 27
# 27
# 26
# 24
# 27.Maniola_hyperantus
# 26.Vanessa_cardui
# 29
# 29
# 25
# 27
# 28
# 28
# 25.Pieris_napi
# 26
# 27
# 21
# 27
# 27
# 26
# 24.Spodoptera_frugiperda
# 30
# 30
# 29
# 30
# 29
# 27
# 27
# 29
# 27
# 30
# 27
# 28
# 27
# 27
# 28
# 29
# 29
# 29
# 30
# 27
# 28
# 28
# 29
# 30
# 26
# 27
# 28
# 27
# 28
# 29
# 25
# 27
# 23.Vanessa_atalanta
# 27
# 28
# 28
# 27
# 28
# 28
# 29
# 29
# 29
# 29
# 28
# 29
# 29
# 29
# 23
# 22.Pieris_brassicae
# 27
# 26
# 27
# 26
# 27
# 27
# 26
# 27
# 27
# 27
# 21.Amyelois_transitella
# 24
# 24
# 24
# 20.Vanessa_tameamea
# 28
# 19.Trichoplusia_ni
# 29
# 28
# 27
# 28
# 28
# 28
# 26
# 29
# 28
# 26
# 28
# 18.Bombyx_mandarina
# 26
# 26
# 25
# 23
# 23
# 24
# 24
# 38.Papilio_machaon
# 37.Aricia_agestis
# 36.Melitaea_cinxia
# 33.Pararge_aegeria
# 26
# 17.Papilio_polytes
# 26
# 27
# 27
# 27
# 26
# 27
# 25
# 24
# 16.Papilio_xuthus
# 27
# 25
# 27
# 27
# 15.Hyposmocoma_kahamanoa
# 27
# 27
# 26
# 26
# 26
# 26
# 26
# 25
# 14.Zerene_cesonia
# 27
# 26
# 27
# 27
# 13.Danaus_plexippus
# 26
# 25
# 26
# 26
# 26
# 26
# 12.Manduca_sexta
# 27
# 27
# 27
# 25
# 26
# 27
# 25
# 26
# 27
# 10.Plutella_xylostella
# 28
# 28
# 9.Pieris_rapae
# 27
# 26
# 27
# 8.Plodia_interpunctella
# 25
# 25
# 25
# 7.Helicoverpa_zea
# 26
# 28
# 27
# 28
# 26
# 25
# 28
# 28
# 27
# 26
# 28
# 27
# 6.Pectinophora_gossypiella
# 26
# 26
# 26
# 26
# 26
# 26
# 26
# 26
# 5.Bicyclus_anynana
# 27
# 26
# 26
# 27
# 26
# 26
# 4.Helicoverpa_armigera
# 27
# 26
# 27
# 27
# 27
# 25
# 26
# 26
# 27
# 27
# 24
# 23
