# %%
with open("/mnt/h/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/3.Satyrine/5.For Email_padded/Bicyclus_anynana/Transcript_vairant_1.bed", 'r') as input_file:
    input_bed_file = input_file.readlines()

chromosome_start = input_bed_file[0].split("\t")[1]
chromosome = input_bed_file[0].split("\t")[0]
# print(input_bed_file[-1])
chromosome_end = input_bed_file[-1].split("\t")[2]
print(chromosome_end,chromosome_start)

output = f"{chromosome}\t{chromosome_start}\t{chromosome_end}\tPeriod\t0\t+\t{chromosome_start}\t{chromosome_end}\t0\t{len(input_bed_file)}\t"

# print(output)
size_dictionary = {}
sizes = ''
pos = ''
pos_dictionary = {}
for i in range(0,len(input_bed_file)):
    line_split = input_bed_file[i].split("\t")
    sizes += f"{int(line_split[2])-int(line_split[1])},"
    size_dictionary[f"Exon_{i+1}"] = int(line_split[2])-int(line_split[1])
    pos_dictionary = int(line_split[1]) - 100000
    pos += f"{int(line_split[1]) - 100000},"
#     print(input_bed_file[i])

# print(sizes,pos)
    
output += f"{sizes}\t{pos}"
print(output)
# Out:
# 138211 100000
# Bicyclus_anynana_NC_069110.1_7726744_8064955	100000	138211	Period	0	+	100000	138211	0	2788,71,175,85,68,131,87,203,228,111,119,149,118,104,158,165,135,104,101,122,163,140,188,107,101,149,95,	0,6419,6675,8768,9197,10158,12499,14707,16560,19186,19699,20156,21463,21886,23126,24582,25545,26905,28144,29199,30213,32889,34492,34929,36243,36423,38116,
