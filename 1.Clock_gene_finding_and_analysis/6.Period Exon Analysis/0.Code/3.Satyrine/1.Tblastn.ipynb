# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import os
import re
import io

# %%
list_of_species = os.listdir("/mnt/h/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/1.Annotated Species")
list_of_species = ["Bicyclus_anynana","Coenonympha_glycerion","Elymnias_hypermnestra","Erebia_aethiops","Erebia_ligea","Hipparchia_semele","Lasiommata_megera","Maniola_hyperantus","Maniola_jurtina","Melanargia_galathea","Oeneis_ivallda","Pararge_aegeria"]
query_species = "5.Bicyclus_anynana"
query_transcript = "XM_024088150.2"
# list_of_species.remove(query_species)
if "desktop.ini" in list_of_species:
    list_of_species.remove("desktop.ini")
list_of_genomes = os.listdir("/mnt/f/Genomes_2023-12-26")
query_location = f"/mnt/h/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/3.Satyrine/1.Query/{query_species}/{query_transcript}/query_protein.fa"

# %%
genome_file = ''
output = ''
for species in list_of_species:
    # if "
    # species = species_folder.split(".")[1]
    blast_output_location = "/mnt/h/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/3.Satyrine/1.Blast_result"
    blast_output_folders = os.listdir(blast_output_location)
    if species not in blast_output_folders:
        os.mkdir(f"/mnt/h/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/3.Satyrine/1.Blast_result/{species}")
    
    
    for genome in list_of_genomes:
        if species == genome:
            files_in_genome_folder = os.listdir(f"/mnt/f/Genomes_2023-12-26/{genome}")
            for file in files_in_genome_folder:
                if re.search('_genomic.fna$', file):
                    genome_file = file
                    break
    
    output += f'echo {species}\ntblastn -seg no -query "{query_location}" -db "/mnt/f/Genomes_2023-12-26/{species}/{genome_file}" -num_alignments 3 -out "{blast_output_location}/{species}/{species}_blast_out.htm" -html \n\n tblastn -seg no -query "{query_location}" -db "/mnt/f/Genomes_2023-12-26/{species}/{genome_file}" -num_alignments 3 -out "{blast_output_location}/{species}/{species}_blast_out.txt"\n\n'
    
with io.open("/mnt/h/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/3.Satyrine/tblastn.sh", "w", newline='\n') as outfile:
    outfile.write(output)
#             print("here",genome)
#     print(species_folder)
