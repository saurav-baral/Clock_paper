# %%
import subprocess
subprocess.run('pwd')
subprocess.run('cd ..' , shell=True)
subprocess.run('pwd')
subprocess.run('samtools faidx "/mnt/f/Genomes_2023-12-26/Pararge_aegeria/GCF_905163445.1_ilParAegt1.1_genomic.fna"')
# Out:
# /mnt/h/My Drive/Circadian Rhythm Genes Project
# /mnt/h/My Drive/Circadian Rhythm Genes Project
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 5
#       3 subprocess.run('cd ..' , shell=True)
#       4 subprocess.run('pwd')
# ----> 5 subprocess.run('samtools faidx "/mnt/f/Genomes_2023-12-26/Pararge_aegeria/GCF_905163445.1_ilParAegt1.1_genomic.fna"')
#
# File /usr/lib/python3.8/subprocess.py:489, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486     kwargs['stdout'] = PIPE
#     487     kwargs['stderr'] = PIPE
# --> 489 with Popen(*popenargs, **kwargs) as process:
#     490     try:
#     491         stdout, stderr = process.communicate(input, timeout=timeout)
#
# ...

# %%
import os
from Bio import SeqIO
location = "/mnt/h/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/3.Satyrine/1.Blast_result/Coenonympha_glycerion/Period_gene_genomic_sequence_individual_exon/Exon_20/for_alignment"
files = os.listdir(location)
for file in files:
    if file.endswith(".fa"):
        fasta_file = SeqIO.parse(f"{location}/{file}", 'fasta')
        for records in fasta_file:
            if "NMNPYNMNQGQMNESNLVFQINSVN" in records.seq:
                 print(file)
        # print(file)
# Out:
# Exon_20_translated_genomic_sequence_27_frame1.fa
