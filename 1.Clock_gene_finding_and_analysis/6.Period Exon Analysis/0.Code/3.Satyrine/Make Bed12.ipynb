# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
with open("/mnt/g/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/3.Satyrine/1.Blast_result/Maniola_jurtina/final_coordinates.csv", 'r') as coordinate_file:
    coordinate_list = coordinate_file.readlines()

print(coordinate_list[0])

gene_name = "Period"

complement  = coordinate_list[1].split(",")[4]
chromosome  = coordinate_list[1].split(",")[1]
if complement == "0":
    chromosome_start = coordinate_list[1].split(",")[2]
    chromosome_end = coordinate_list[-1].split(",")[3]
    comp_char = "+"
if complement == "1":
    chromosome_start = coordinate_list[-1].split(",")[2]
    chromosome_end = coordinate_list[1].split(",")[3]
    comp_char = "-"
output = f"{chromosome}\t{int(chromosome_start)-1}\t{chromosome_end}\t{gene_name}\t0\t{comp_char}\t{int(chromosome_start)-1}\t{chromosome_end}\t0\t{len(coordinate_list)-1}\t"

size_dictionary = {}
sizes = ''
pos = ''
pos_dictionary = {}
for i in range(1,len(coordinate_list)):
    line_split = coordinate_list[i].split(",")
    sizes += f"{int(line_split[3])-int(line_split[2])+1},"
    size_dictionary[f"Exon_{i+1}"] = int(line_split[3])-int(line_split[2])
    pos_dictionary = int(line_split[2]) - int(chromosome_start)
    pos += f"{int(line_split[2]) - int(chromosome_start)},"



output += f"{sizes}\t{pos}"

print(chromosome, chromosome_start, chromosome_end)
print(output)
# Out:
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
#
# NC_060058.1 5746955 5778306
# NC_060058.1	5746954	5778306	Period	0	+	5746954	5778306	0	27	89,84,176,89,75,132,76,204,229,112,120,150,119,105,144,172,136,105,102,171,155,144,180,114,102,138,102,	0,1874,2193,3070,3746,4023,4662,6111,7233,8934,9585,10000,11045,11368,12452,12681,13018,13508,13755,14259,15141,19170,28492,29092,30005,30657,31250,
