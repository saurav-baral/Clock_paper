# %%
import os

scaffold = "Hmel221001o"
gene_location = "4145623"


hmel_genome_location = "/mnt/c/Users/sauba/Desktop/Hmel2.5"

list_of_files = os.listdir(hmel_genome_location)

for file_names in list_of_files:
    if file_names.endswith(".gff3"):
        gff3_file = file_names

with open(f"{hmel_genome_location}/{gff3_file}") as gff_file_open:
    gff_file_list = gff_file_open.readlines()
gene_found = 0
complement = ''
exon_count = 1
exon_dictionary = {}
for line in gff_file_list:
    if scaffold in line:
        if "CDS" in line.split("\t"):
            if "g16970" in line:
                print(line)
                gene_found = 1
                gene_start = 
                if complement == '':
                    complement = line.split("\t")[5]
        if "exon" in line.split("\t") and gene_found == 1:
            break
print(complement)
#         if gene_location in line.split("\t"):
#           print(line)
#           break
# Out:
# Hmel221001o	AUGUSTUS	CDS	4123440	4123544	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:1;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4124209	4124346	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:2;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4124790	4124891	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:3;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4125068	4125172	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:4;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4125398	4125580	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:5;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4127775	4127921	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:6;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4129681	4129832	1	-	2	ID=CDS___3439;Name=g16970.t1:CDS:7;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4130456	4130605	1	-	2	ID=CDS___3439;Name=g16970.t1:CDS:8;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4131045	4131146	1	-	2	ID=CDS___3439;Name=g16970.t1:CDS:9;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4132230	4132334	1	-	2	ID=CDS___3439;Name=g16970.t1:CDS:10;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4133084	4133222	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:11;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4133782	4133959	1	-	1	ID=CDS___3439;Name=g16970.t1:CDS:12;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4134304	4134453	1	-	1	ID=CDS___3439;Name=g16970.t1:CDS:13;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4135033	4135122	1	-	1	ID=CDS___3439;Name=g16970.t1:CDS:14;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4135527	4135645	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:15;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4136413	4136562	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:16;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4137872	4137991	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:17;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4138435	4138546	1	-	1	ID=CDS___3439;Name=g16970.t1:CDS:18;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4139257	4139485	1	-	2	ID=CDS___3439;Name=g16970.t1:CDS:19;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4140365	4140568	1	-	2	ID=CDS___3439;Name=g16970.t1:CDS:20;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4141631	4141706	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:21;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4142049	4142180	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:22;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4142568	4142639	1	-	0	ID=CDS___3439;Name=g16970.t1:CDS:23;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4142932	4143026	1	-	2	ID=CDS___3439;Name=g16970.t1:CDS:24;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4143566	4143723	1	-	1	ID=CDS___3439;Name=g16970.t1:CDS:25;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4144716	4144799	1	-	1	ID=CDS___3439;Name=g16970.t1:CDS:26;Parent=HMEL003979g1.t1
#
# Hmel221001o	AUGUSTUS	CDS	4145535	4145623	0.98	-	0	ID=CDS___3439;Name=g16970.t1:CDS:27;Parent=HMEL003979g1.t1
#
# 1
