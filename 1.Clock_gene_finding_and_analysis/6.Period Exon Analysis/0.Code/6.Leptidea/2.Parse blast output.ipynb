# %%
def sequence_extractor(Species, Scaff, reverse_c, start, end, frame = 1, trans = 1 ):
    from Bio import SeqIO
    from Bio.Seq import Seq
    import os
    
    out_Seq = ''
    
    
    #Genome folder
    entries = os.listdir("/mnt/f/Genomes_2023-12-26/"+Species)
    
    #Get genome file from Genome folder
    for file_names  in entries:
        if ".nhr" in file_names:
            Genome_name = file_names[:-4]
            break
    
    #Read the genome file
    fasta_file = open(("/mnt/f/Genomes_2023-12-26/"+Species+"/"+Genome_name),'r')
    
    #Extract the sequence 
    for record in SeqIO.parse(fasta_file,"fasta"):
        if record.id == Scaff:
            sequence = str(record.seq)
            out_Seq = Seq(sequence[start-1:end])
            if reverse_c == 1:
                out_Seq = out_Seq.reverse_complement()
                
    if len(out_Seq) < 10000: #fixing error due to mistake in typing the coordinate, change this for longer sequence
#        print (out_Seq)
        if frame == 1 :
            out_trans = out_Seq[0:]
        if frame == 2 :
            out_trans = out_Seq[1:]
        if frame == 3 :
            out_trans = out_Seq[2:]
    else:
        print ("too long")
        assert(False)
        
        
    #    break
    fasta_file.close()
    if trans == 1:
        return (out_trans.translate())
    else:
        return(out_Seq)
#

# %%
import os
from Bio import SeqIO

# %%
#%reset -f
blast_location = "/mnt/h/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/6.Leptidea"
query_location = f"{blast_location}/1.Query"
query_species = "30.Leptidea_sinapis"
query_transcript_list = os.listdir(f"{query_location}/{query_species}")
if "desktop.ini" in query_transcript_list:
    query_transcript_list.remove("desktop.ini")

query_transcript = query_transcript_list[0]
#Get Species list, the list may be a list of files or a single species
# query_species = "22.Pieris_brassicae"
# phylo_species = open("C:/Users/sauba/Desktop/Work_Stuff/MRJP/0.for_automation_temp_files/phylo_species.txt",'r')
# species_list = phylo_species.readlines()
# species_list = ["10.Plutella_xylostella","11.Bombyx_mori","12.Manduca_sexta","13.Danaus_plexippus","14.Zerene_cesonia","15.Hyposmocoma_kahamanoa","16.Papilio_xuthus","17.Papilio_polytes","18.Bombyx_mandarina","19.Trichoplusia_ni","2.Galleria_mellonella","20.Vanessa_tameamea","21.Amyelois_transitella","22.Pieris_brassicae","23.Vanessa_atalanta","24.Spodoptera_frugiperda","25.Pieris_napi","26.Vanessa_cardui","27.Maniola_hyperantus","28.Maniola_jurtina","29.Nymphalis_io","3.Spodoptera_litura","30.Leptidea_sinapis","31.Leguminivora_glycinivorella","32.Colias_croceus","33.Pararge_aegeria","36.Melitaea_cinxia","37.Aricia_agestis","38.Papilio_machaon","39.Leptidea_sinapis","4.Helicoverpa_armigera","40.Colias_croceus","41.Manduca_sexta","42.Spodoptera_frugiperda","43.Ostrinia_furnacalis","5.Bicyclus_anynana","6.Pectinophora_gossypiella","7.Helicoverpa_zea","8.Plodia_interpunctella","9.Pieris_rapae"]
species_list = os.listdir(f"{blast_location}/1.Blast_result")
species_list.remove('desktop.ini')
# species_list = ["5.Bicyclus_anynana"]
# species_list = ["29.Nymphalis_io","3.Spodoptera_litura","30.Leptidea_sinapis","31.Leguminivora_glycinivorella","32.Colias_croceus","33.Pararge_aegeria","36.Melitaea_cinxia","37.Aricia_agestis","38.Papilio_machaon","39.Leptidea_sinapis","4.Helicoverpa_armigera","40.Colias_croceus","41.Manduca_sexta","42.Spodoptera_frugiperda","43.Ostrinia_furnacalis","5.Bicyclus_anynana","6.Pectinophora_gossypiella","7.Helicoverpa_zea","8.Plodia_interpunctella","9.Pieris_rapae"]
# species_list = ["36.Melitaea_cinxia","37.Aricia_agestis","38.Papilio_machaon","39.Leptidea_sinapis","4.Helicoverpa_armigera","40.Colias_croceus","41.Manduca_sexta","42.Spodoptera_frugiperda","43.Ostrinia_furnacalis","5.Bicyclus_anynana","6.Pectinophora_gossypiella","7.Helicoverpa_zea","8.Plodia_interpunctella","9.Pieris_rapae"]
#print(species_list)
# species_list = ["3.Spodoptera_litura"]
#get list of query names

query_file = SeqIO.parse(f"{blast_location}/1.Query/{query_species}/{query_transcript}/query_protein.fa", 'fasta')
query_name_list = []

for records in query_file:
    query_name_list.append(records.id)



for species in species_list:
    # print(species_name)
    # species = species_name.split(".")[1]
    header = "Species," + "Scaffold," + "Start," + "Stop," + "Complement," + "Error," + "Gene,"+ "Query_start," + "Query_stop,"+ "Query_Length\n" 
    Output_Sequence = header
    scaff = "Intial_value"
    scaff_old = "Intial_value"
    old_end = 0
    
#Run for each query in the query list
    for i in range(len(query_name_list)):
        query_name = query_name_list[i]
#         print(f"Query name = {query_name}")
        Length_switch = "0"
        with open(f"{blast_location}/1.Blast_result/{species}/{species}_blast_out.txt",'r') as tblast_out:
            lines_in_file = tblast_out.readlines()
        #print(lines_in_file)

        result_section_switch = 0
        start_coor_switch = 0
        query_start_coor_switch = 0
        stop_coor_switch = 0
        error = "N"
        break_switch = 0

        start = 0
        stop = 0
        start_coor = 0
        stop_coor = 0
        query_length = 0

        for lines in lines_in_file:

#             print(lines)
            if query_name in lines:
#                 print(lines)
#                 assert False
            #Initialize that results can now be checked
                result_section_switch = 1
                query_species_split = lines.split(" ")[1].split("_")
                query_species = str(query_species_split[0].split(".")[1]+"_"+query_species_split[1].rstrip())
                print(query_species)
            if result_section_switch == 1 and "Lambda" in lines:
            #This block indicates end of the results block in blast output
                result_section_switch == 0
                
                break

            if result_section_switch == 1:
            #While checking the result
                if "Length=" in lines and Length_switch == "0":
                #Get query length from the blast output
                    
                    query_length = int(lines.split("=")[1].rstrip())
                    
                    Length_switch = 1 #Indicated length has been acquired
                    
                if ("Score" in lines or ">" in lines) and (start_coor_switch == 1):
    #                print (lines)
                    break
        
                if ">" in lines:
                #Start of the first result
                    scaff = lines.split(" ")[0][1:] #Scaffold from the result
                    if scaff_old != "Intial_value" and scaff_old != scaff:
                        error = "Y"
                    scaff_old = scaff
                    
                if "Query" in lines and "=" not in lines:
                #Read the query line in output
                    if query_start_coor_switch == 0:
#                        print(lines)
                        query_start_coor = int(lines.split(" ")[2])
                        query_start_coor_switch = 1
                        #Query start coordinate fixed
            
                    query_stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting query stop coordinates for multiline result
    #                print (stop_coor)
                    
                if "Sbjct" in lines:
                #Read the blast target line
                    if start_coor_switch == 0:
                        start_coor = int(lines.split(" ")[2])
                        start_coor_switch = 1
                    stop_coor =int(lines.split(" ")[-1][:-1])
                    #Keep getting target stop coordinates for multiline result
                
                

        
        if break_switch == 1:
            break

        if start_coor < stop_coor:
            complement = "0" #Forward complement
            
            length = (stop_coor-start_coor)/3
            start = start_coor
            stop = stop_coor

        elif start_coor > stop_coor:
            complement = "1" #Reverse complement
            length = (-stop_coor+start_coor)/3
            start = stop_coor
            stop = start_coor

        else:
            length = 0
            start = 000
            stop = 000
            query_start_coor = 000
            query_stop_coor = 000
            error = "Y"
            complement  = 0
        
        
        
        

        #Check if the length of target (blast hit) is significantly smaller than query
        if length < query_length - 0.2*query_length:
            error = "Y"

        old_trans = ''
#             print(start, stop)


#Check for Met or STOP at the start and end
        while True and (start != 0 or stop != 0):
            if (query_name == query_name_list[0] or query_name == query_name_list[-1]):
                frame = 1
                translated_sequence = (sequence_extractor(species, scaff, int(complement), start, stop,frame ))

                if translated_sequence == old_trans:
                    break
                    
#Check for Met at the beginning of first exon

                if query_name == query_name_list[0] :
                    if translated_sequence[0] != "M":
                        print(translated_sequence)
#                             print(start, stop)
                        if complement == "0":
                            start = int(start) - 3
                        if complement == "1":
                            stop = int(stop) + 3
                        old_trans = translated_sequence
                    if "*" in translated_sequence:
                        error = "Y"
                        break
                    if translated_sequence[0] == "M":
                        break

#Check for stop at the end of last exon

                if query_name == query_name_list[-1]:
                    if translated_sequence[-1] != "*":
                        print(translated_sequence)
#                             print(start, stop)
                        if complement == "0":
                            stop = int(stop) + 3
                        if complement == "1":
                            start = int(start) - 3
                        old_trans = translated_sequence
                    if translated_sequence[-1] == "*":

                        break
            else:
                break
        
        
#Add offset at the beginning and end of each exon
        if (start != 0 or stop != 0):
            
            start_modifier = int(query_name.split("Frame")[1][1])
            stop_modifier = int(query_name.split("rightoh")[1][1])
        else:
            start_modifier = 0
            stop_modifier = 0            

        seq_length = query_length
        
        
#Get exon start and end by adding or removing codons
        
    #if not the beginning
        if query_start_coor != "1" and query_name != query_name_list[0]:
            if complement == "0":
                start = int(start) - 3*(int(query_start_coor)-1)                
            if complement == "1":
                stop = int(stop) + 3*(int(query_start_coor)-1)
    
    #For the end
        if query_stop_coor != str(seq_length) and query_name != query_name_list[-1]:
            if complement == "0":
                stop = int(stop) + 3*(int(seq_length)-int(query_stop_coor))
            if complement == "1":
                

                start = int(start) - 3*(int(seq_length)-int(query_stop_coor))
 
        
        
        
#Adding or removing 3' and 5' overhangs for forward and reverse complement
    #For forward complement
        if complement == "0":
            start = int(start) - int(start_modifier)
            stop = int(stop) +  int(stop_modifier)
            if old_end != 0 and old_end > stop:

                error = "Y"
            old_end = stop

    #For reverse complement
        if complement == "1":
            start = int(start) - int(stop_modifier)
            stop = int(stop) +  int(start_modifier)
            if old_end != 0 and old_end < stop:
                error = "Y"
            old_end = stop

    #Simple check for lenghth
        if start == 0 or stop == 0:
            error = "Y"
            
           
        output_format = str(species.split("\n")[0])+"," + str(scaff) +"," + str(start)+"," + str(stop)+"," + str(complement)+"," + str(error)+  ","+ str(query_name)+","+ str(query_start_coor)+","+str(query_stop_coor)+","+str(query_length)+ "\n"  
        print(output_format)
#         assert False
        Output_Sequence = Output_Sequence + output_format

    print(Output_Sequence)
   
    output_file = open(f"{blast_location}/1.Blast_result/{species}/{species}_coordinates_old.csv",'w')
    output_file.write(Output_Sequence)
    output_file.close()
# Out:
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23465986,23466071,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_2_query_Exon_1,1,28,28
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23463649,23463732,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_2,1,27,27
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23461671,23461822,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_1_query_Exon_3,1,50,50
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23460184,23460296,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_0_query_Exon_4,1,37,37
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,0,0,0,Y,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_5,0,0,19
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23459204,23459335,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_6,1,44,44
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23456373,23456442,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_1_query_Exon_7,1,23,23
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23456037,23456234,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_1_query_Exon_8,1,65,65
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23454839,23455067,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_2_query_Exon_9,1,75,75
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23452644,23452755,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_0_query_Exon_10,1,37,37
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23451049,23451168,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_11,1,40,40
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23450511,23450660,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_12,1,50,50
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23449447,23449565,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_2_query_Exon_13,1,39,39
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23446239,23446340,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_14,1,33,33
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23442742,23442879,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_15,1,45,45
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23441978,23442143,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_0_query_Exon_16,1,55,55
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23440160,23440301,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_1_query_Exon_17,1,47,47
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23439715,23439822,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_1_query_Exon_18,1,35,35
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23437801,23437931,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_0_query_Exon_19,1,43,43
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23435823,23435969,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_20,1,49,49
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23431304,23431465,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_21,1,54,54
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23429029,23429115,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_22,1,29,29
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23428280,23428381,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_23,1,34,34
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23426782,23426916,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_24,1,45,45
#
# Leptidea_sinapis
# Leptidea_juvernica,CATIXQ010000001.1,23424656,23424760,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_25,1,35,35
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Leptidea_juvernica,CATIXQ010000001.1,23465986,23466071,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_2_query_Exon_1,1,28,28
# Leptidea_juvernica,CATIXQ010000001.1,23463649,23463732,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_2,1,27,27
# Leptidea_juvernica,CATIXQ010000001.1,23461671,23461822,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_1_query_Exon_3,1,50,50
# Leptidea_juvernica,CATIXQ010000001.1,23460184,23460296,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_0_query_Exon_4,1,37,37
# Leptidea_juvernica,CATIXQ010000001.1,0,0,0,Y,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_5,0,0,19
# Leptidea_juvernica,CATIXQ010000001.1,23459204,23459335,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_6,1,44,44
# Leptidea_juvernica,CATIXQ010000001.1,23456373,23456442,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_1_query_Exon_7,1,23,23
# Leptidea_juvernica,CATIXQ010000001.1,23456037,23456234,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_1_query_Exon_8,1,65,65
# Leptidea_juvernica,CATIXQ010000001.1,23454839,23455067,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_2_query_Exon_9,1,75,75
# Leptidea_juvernica,CATIXQ010000001.1,23452644,23452755,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_0_query_Exon_10,1,37,37
# Leptidea_juvernica,CATIXQ010000001.1,23451049,23451168,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_11,1,40,40
# Leptidea_juvernica,CATIXQ010000001.1,23450511,23450660,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_12,1,50,50
# Leptidea_juvernica,CATIXQ010000001.1,23449447,23449565,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_2_query_Exon_13,1,39,39
# Leptidea_juvernica,CATIXQ010000001.1,23446239,23446340,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_14,1,33,33
# Leptidea_juvernica,CATIXQ010000001.1,23442742,23442879,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_15,1,45,45
# Leptidea_juvernica,CATIXQ010000001.1,23441978,23442143,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_0_query_Exon_16,1,55,55
# Leptidea_juvernica,CATIXQ010000001.1,23440160,23440301,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_1_query_Exon_17,1,47,47
# Leptidea_juvernica,CATIXQ010000001.1,23439715,23439822,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_1_query_Exon_18,1,35,35
# Leptidea_juvernica,CATIXQ010000001.1,23437801,23437931,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_0_query_Exon_19,1,43,43
# Leptidea_juvernica,CATIXQ010000001.1,23435823,23435969,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_20,1,49,49
# Leptidea_juvernica,CATIXQ010000001.1,23431304,23431465,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_21,1,54,54
# Leptidea_juvernica,CATIXQ010000001.1,23429029,23429115,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_22,1,29,29
# Leptidea_juvernica,CATIXQ010000001.1,23428280,23428381,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_23,1,34,34
# Leptidea_juvernica,CATIXQ010000001.1,23426782,23426916,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_24,1,45,45
# Leptidea_juvernica,CATIXQ010000001.1,23424656,23424760,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_25,1,35,35
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20872199,20872284,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_2_query_Exon_1,1,28,28
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20869128,20869211,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_2,1,27,27
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20867172,20867323,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_1_query_Exon_3,1,50,50
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20865668,20865780,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_0_query_Exon_4,1,37,37
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,0,0,0,Y,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_5,0,0,19
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20864687,20864818,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_6,1,44,44
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20860990,20861059,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_1_query_Exon_7,1,23,23
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20860654,20860851,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_1_query_Exon_8,1,65,65
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20859522,20859750,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_2_query_Exon_9,1,75,75
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20857303,20857414,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_0_query_Exon_10,1,37,37
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20855719,20855838,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_11,1,40,40
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20855164,20855313,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_12,1,50,50
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20853999,20854117,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_2_query_Exon_13,1,39,39
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20850912,20851013,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_14,1,33,33
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20847444,20847581,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_15,1,45,45
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20846678,20846843,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_0_query_Exon_16,1,55,55
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20844733,20844874,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_1_query_Exon_17,1,47,47
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20844288,20844395,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_1_query_Exon_18,1,35,35
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20840120,20840250,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_0_query_Exon_19,1,43,43
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20838239,20838385,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_20,1,49,49
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20833695,20833856,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_21,1,54,54
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20831478,20831564,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_22,1,29,29
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20830744,20830845,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_23,1,34,34
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20829595,20829729,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_24,1,45,45
#
# Leptidea_sinapis
# Leptidea_reali,CATIXK010000002.1,20826883,20826987,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_25,1,35,35
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Leptidea_reali,CATIXK010000002.1,20872199,20872284,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_2_query_Exon_1,1,28,28
# Leptidea_reali,CATIXK010000002.1,20869128,20869211,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_2,1,27,27
# Leptidea_reali,CATIXK010000002.1,20867172,20867323,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_1_query_Exon_3,1,50,50
# Leptidea_reali,CATIXK010000002.1,20865668,20865780,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_0_query_Exon_4,1,37,37
# Leptidea_reali,CATIXK010000002.1,0,0,0,Y,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_5,0,0,19
# Leptidea_reali,CATIXK010000002.1,20864687,20864818,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_6,1,44,44
# Leptidea_reali,CATIXK010000002.1,20860990,20861059,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_1_query_Exon_7,1,23,23
# Leptidea_reali,CATIXK010000002.1,20860654,20860851,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_1_query_Exon_8,1,65,65
# Leptidea_reali,CATIXK010000002.1,20859522,20859750,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_2_query_Exon_9,1,75,75
# Leptidea_reali,CATIXK010000002.1,20857303,20857414,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_0_query_Exon_10,1,37,37
# Leptidea_reali,CATIXK010000002.1,20855719,20855838,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_11,1,40,40
# Leptidea_reali,CATIXK010000002.1,20855164,20855313,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_12,1,50,50
# Leptidea_reali,CATIXK010000002.1,20853999,20854117,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_2_query_Exon_13,1,39,39
# Leptidea_reali,CATIXK010000002.1,20850912,20851013,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_14,1,33,33
# Leptidea_reali,CATIXK010000002.1,20847444,20847581,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_15,1,45,45
# Leptidea_reali,CATIXK010000002.1,20846678,20846843,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_0_query_Exon_16,1,55,55
# Leptidea_reali,CATIXK010000002.1,20844733,20844874,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_1_query_Exon_17,1,47,47
# Leptidea_reali,CATIXK010000002.1,20844288,20844395,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_1_query_Exon_18,1,35,35
# Leptidea_reali,CATIXK010000002.1,20840120,20840250,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_0_query_Exon_19,1,43,43
# Leptidea_reali,CATIXK010000002.1,20838239,20838385,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_20,1,49,49
# Leptidea_reali,CATIXK010000002.1,20833695,20833856,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_21,1,54,54
# Leptidea_reali,CATIXK010000002.1,20831478,20831564,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_22,1,29,29
# Leptidea_reali,CATIXK010000002.1,20830744,20830845,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_23,1,34,34
# Leptidea_reali,CATIXK010000002.1,20829595,20829729,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_24,1,45,45
# Leptidea_reali,CATIXK010000002.1,20826883,20826987,1,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_25,1,35,35
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12062394,12062479,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_2_query_Exon_1,1,28,28
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12065348,12065431,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_2,1,27,27
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12067234,12067385,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_1_query_Exon_3,1,50,50
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12068744,12068856,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_0_query_Exon_4,1,37,37
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12069218,12069274,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_5,1,19,19
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12069724,12069855,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_6,1,44,44
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12073465,12073534,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_1_query_Exon_7,1,23,23
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12073673,12073870,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_1_query_Exon_8,1,65,65
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12074642,12074870,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_2_query_Exon_9,1,75,75
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12076986,12077097,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_0_query_Exon_10,1,37,37
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12078571,12078690,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_11,1,40,40
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12079123,12079272,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_12,1,50,50
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12080318,12080436,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_2_query_Exon_13,1,39,39
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12083947,12084048,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_14,1,33,33
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12087404,12087541,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_15,1,45,45
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12088141,12088306,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_0_query_Exon_16,1,55,55
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12090232,12090373,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_1_query_Exon_17,1,47,47
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12090711,12090818,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_1_query_Exon_18,1,35,35
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12095129,12095259,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_0_query_Exon_19,1,43,43
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12096987,12097133,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_20,1,49,49
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12101422,12101583,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_21,1,54,54
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12103768,12103854,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_22,1,29,29
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12105113,12105214,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_23,1,34,34
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12106588,12106722,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_24,1,45,45
#
# Leptidea_sinapis
# Leptidea_sinapis,NC_066312.1,12109248,12109352,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_25,1,35,35
#
# Species,Scaffold,Start,Stop,Complement,Error,Gene,Query_start,Query_stop,Query_Length
# Leptidea_sinapis,NC_066312.1,12062394,12062479,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_2_query_Exon_1,1,28,28
# Leptidea_sinapis,NC_066312.1,12065348,12065431,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_2,1,27,27
# Leptidea_sinapis,NC_066312.1,12067234,12067385,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_1_query_Exon_3,1,50,50
# Leptidea_sinapis,NC_066312.1,12068744,12068856,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_0_query_Exon_4,1,37,37
# Leptidea_sinapis,NC_066312.1,12069218,12069274,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_5,1,19,19
# Leptidea_sinapis,NC_066312.1,12069724,12069855,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_6,1,44,44
# Leptidea_sinapis,NC_066312.1,12073465,12073534,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_1_query_Exon_7,1,23,23
# Leptidea_sinapis,NC_066312.1,12073673,12073870,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_1_query_Exon_8,1,65,65
# Leptidea_sinapis,NC_066312.1,12074642,12074870,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_2_query_Exon_9,1,75,75
# Leptidea_sinapis,NC_066312.1,12076986,12077097,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_0_query_Exon_10,1,37,37
# Leptidea_sinapis,NC_066312.1,12078571,12078690,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_11,1,40,40
# Leptidea_sinapis,NC_066312.1,12079123,12079272,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_12,1,50,50
# Leptidea_sinapis,NC_066312.1,12080318,12080436,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_2_query_Exon_13,1,39,39
# Leptidea_sinapis,NC_066312.1,12083947,12084048,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_14,1,33,33
# Leptidea_sinapis,NC_066312.1,12087404,12087541,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_2_query_Exon_15,1,45,45
# Leptidea_sinapis,NC_066312.1,12088141,12088306,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_1_rightoh_0_query_Exon_16,1,55,55
# Leptidea_sinapis,NC_066312.1,12090232,12090373,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_1_query_Exon_17,1,47,47
# Leptidea_sinapis,NC_066312.1,12090711,12090818,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_1_query_Exon_18,1,35,35
# Leptidea_sinapis,NC_066312.1,12095129,12095259,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_2_rightoh_0_query_Exon_19,1,43,43
# Leptidea_sinapis,NC_066312.1,12096987,12097133,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_20,1,49,49
# Leptidea_sinapis,NC_066312.1,12101422,12101583,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_21,1,54,54
# Leptidea_sinapis,NC_066312.1,12103768,12103854,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_22,1,29,29
# Leptidea_sinapis,NC_066312.1,12105113,12105214,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_23,1,34,34
# Leptidea_sinapis,NC_066312.1,12106588,12106722,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_24,1,45,45
# Leptidea_sinapis,NC_066312.1,12109248,12109352,0,N,30.Leptidea_sinapis_XM_050828181.1_Frame_0_rightoh_0_query_Exon_25,1,35,35
