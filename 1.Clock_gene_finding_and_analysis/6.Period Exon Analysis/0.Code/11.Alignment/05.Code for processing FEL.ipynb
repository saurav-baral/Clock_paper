# %%
import json 

with open("/mnt/g/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment/04.FEL/period.masceDNA_without_STOP.fas.FEL.json", 'r') as f:
  data = json.load(f)

# print(data["MLE"])
output = "Site\tSyn_Rate\tNSyn_Rate\tOmega\tpvalue"
dataset = (data["MLE"]["content"]["0"])
for  i in range(len(dataset)):
    snonynums_substitution_rate = float(dataset[i][0])
    non_synonymous_subs_rate = float(dataset[i][1])
    pvalue = float(dataset[i][4])
    try:
        omega = non_synonymous_subs_rate/snonynums_substitution_rate
    except ZeroDivisionError:
        omega = 10.0
    # print(omega, pvalue)
    if omega > 1 and pvalue < 0.05:
    # if pvalue < 0.01:
        print(i,dataset[i])
    output += f"\n{i+1}\t{snonynums_substitution_rate}\t{non_synonymous_subs_rate}\t{omega}\t{pvalue}"
    # print(output)
    # break
with open("/mnt/g/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment/04.FEL/FEL_rate.txt", 'w') as out_file:
  out_file.write(output)


# output_split  = output.split("\n")
# output2 = "Site\tRate"
# counter = 1
# site_number = 1
# while counter < len(output_split):
#     new_rate = (float(output_split[counter].split("\t")[1]) + float(output_split[counter+1].split("\t")[1]) + float(output_split[counter+2].split("\t")[1]))/3
#     output2 += f"\n{site_number}\t{new_rate}"
#     site_number += 1
#     counter += 3
# with open("/mnt/g/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment/04.FEL/LEISR_rate_codon.txt", 'w') as out_file:
#   out_file.write(output2)
# # print(output2)
# Out:
# 1275 [0, 0.1482449601889168, 0.09878388947978445, 4.904478948232295, 0.0267871320397276, 3.227412785208724]
