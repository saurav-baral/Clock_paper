# %%
library(ggplot2)
library(cowplot)


phastCon_data = read.table("G:/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment/01.PhastCon/scores_phastcon.wig", sep = "\t", header = T)
phastCon_plot = ggplot() + geom_line(data = phastCon_data, aes(x = Pos, y = Score), color = "#1B7593") + theme_cowplot(12) 
phastCon_plot

# %%
pdf(file = "G:/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment/01.PhastCon/scores_phastcon.pdf",   # The directory you want to save the file in
    width = 10, # The width of the plot in inches
    height = 4)
phastCon_plot

# %%
dev.off()
# Out:
# Positron Graphics Device
#                        2

# %%
library(ggplot2)
library(cowplot)


phastCon_codon_data = read.table("G:/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment/01.PhastCon/scores_phastcon_codon.txt", sep = "\t", header = T)
phastCon_codon_plot = ggplot() + geom_line(data = phastCon_codon_data, aes(x = Site, y = Rate), color = "#1B7593") + theme_cowplot(12) 
phastCon_codon_plot

# %%
pdf(file = "G:/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment/01.PhastCon/scores_phastcon_codon.pdf",   # The directory you want to save the file in
    width = 10, # The width of the plot in inches
    height = 4)
phastCon_codon_plot

# %%
dev.off()
# Out:
# Positron Graphics Device
#                        2
