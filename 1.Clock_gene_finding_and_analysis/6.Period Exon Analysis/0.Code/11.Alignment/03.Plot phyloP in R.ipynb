# %%
library(ggplot2)
library(cowplot)


phyloP_data = read.table("G:/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment/02.phyloP/scores_phyloP.wig", sep = "\t", header = T)
phyloP_plot = ggplot() +geom_hline(yintercept=0,col = "salmon")+ geom_line(data = phyloP_data, aes(x = Pos, y = Score), color = "#1B7593") + theme_cowplot(12) 
phyloP_plot

# %%
pdf(file = "G:/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment/02.phyloP/scores_phyloP.pdf",   # The directory you want to save the file in
    width = 10, # The width of the plot in inches
    height = 4)
phyloP_plot

# %%
dev.off()
# Out:
# Positron Graphics Device
#                        2

# %%
library(ggplot2)
library(cowplot)


phyloP_codon_data = read.table("G:/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment/02.phyloP/scores_phyloP_codon.txt", sep = "\t", header = T)
phyloP_codon_plot = ggplot()+geom_hline(yintercept=0,col = "salmon") + geom_line(data = phyloP_codon_data, aes(x = Site, y = Rate), color = "#1B7593") + theme_cowplot(12) 
phyloP_codon_plot

# %%
pdf(file = "G:/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment/02.phyloP/scores_phyloP_codon.pdf",   # The directory you want to save the file in
    width = 10, # The width of the plot in inches
    height = 4)
phyloP_codon_plot

# %%
dev.off()
# Out:
# Positron Graphics Device
#                        2
