# %%
from Bio import SeqIO
import os
import subprocess

location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment"

fasta_file = SeqIO.parse(f"{location}/period.masceDNA.fas", 'fasta')

list_of_sequences_ids = []

for records in fasta_file:
    list_of_sequences_ids.append(records.id)
print(list_of_sequences_ids)
# list_of_folders = os.listdir(f"{location}")
# print(list_of_folders)
# if "00.Temp_alignment" in list_of_folders:
#     print("AA")
#     subprocess.run(f'rm -r "{location}/00.Temp_alignment/"', shell = True)

# os.mkdir(f"{location}/00.Temp_alignment")


for i in range(len(list_of_sequences_ids)):
    output = ''
    fasta_file = SeqIO.parse(f"{location}/period.masceDNA.fas", 'fasta')
    for records in fasta_file:
        sequence = f">{records.id}\n{records.seq}\n"
        if list_of_sequences_ids[i] == records.id:
            output = sequence + output
        else:
            output += sequence
    with open(f"{location}/00.Temp_alignment/{list_of_sequences_ids[i]}.fas", 'w') as out_file:
        out_file.write(output)
    # subprocess.run(f'cd "{location}"\nphyloFit --tree period.masceDNA.fas.treefile --subst-mod REV --out-root "./01.Temp_phastcon/modelfile" "./00.Temp_alignment/{list_of_sequences_ids[i]}.fas"', shell = True)
    
    # subprocess.run(f'cd "{location}/01.Temp_phastcon"\nphastCons --target-coverage 0.25 --expected-length 12 --estimate-trees mytrees ../00.Temp_alignment/{list_of_sequences_ids[i]}.fas modelfile.mod --no-post-probs', shell = True)
    
    subprocess.run(f'cd "{location}/01.Temp_phastcon"\nphastCons --target-coverage 0.25 --expected-length 12 ../00.Temp_alignment/{list_of_sequences_ids[i]}.fas mytrees.cons.mod,mytrees.noncons.mod > scores.wig', shell = True)

    fasta_file = SeqIO.parse(f"{location}/00.Temp_alignment/{list_of_sequences_ids[i]}.fas", 'fasta')

    for records in fasta_file:
        sequence = records.seq
        sequence_name = records.id
        break
    
    with open(f"{location}/01.Temp_phastcon/scores.wig", 'r') as score_file:
        scores = score_file.readlines()
    
    output = 'Pos\tScore'
    score_counter = 1
    for j in range(len(sequence)):
        if sequence[j] != "-":
            output += f"\n{j+1}\t{scores[score_counter].strip()}"
            score_counter += 1
        else:
            output += f"\n{j+1}\tN/A"
    
    # print(output)
    with open(f"{location}/01.Temp_phastcon/scores_fixed_{list_of_sequences_ids[i]}.wig", 'w') as out_file:
        out_file.write(output)
        # assert False
# Out:
# ['Heliconius_charithonia-period', 'Napeogenes_sylphis-period', 'Mechanitis_messenoides-period', 'Mechanitis_mazaeus-period', 'Aricia_artaxerxes-period', 'Aricia_agestis-period', 'Polyommatus_iphigenia-period', 'Phengaris_arion-period', 'Celastrina_argiolus-period', 'Cyaniris_semiargus-period', 'Heliconius_nattereri-period', 'Dircenna_loreta-period', 'Eueides_isabella-period', 'Melitaea_cinxia-period', 'Lasiommata_megera-period', 'Pararge_aegeria-period', 'Danaus_chrysippus-period', 'Nymphalis_c-album-period', 'Coenonympha_glycerion-period', 'Maniola_hyperantus-period', 'Brenthis_hecate-period', 'Fabriciana_adippe-period', 'Nymphalis_urticae-period', 'Calycopis_cecrops-period', 'Hypolimnas_misippus-period', 'Hipparchia_semele-period', 'Maniola_jurtina-period', 'Melanargia_galathea-period', 'Mellicta_athalia-period', 'Oeneis_ivallda-period', 'Philaethria_dido-period', 'Napeogenes_inachia-period', 'Euphydryas_editha-period', 'Nymphalis_polychloros-period', 'Melinaea_menophilus-period', 'Polyommatus_icarus-period', 'Boloria_selene-period', 'Leptidea_juvernica-period', 'Lysandra_bellargus-period', 'Leptophobia_aripa-period', 'Leptidea_sinapis-period', 'Bicyclus_anynana-period', 'Vanessa_cardui-period', 'Brenthis_daphne-period', 'Papilio_demoleus-period', 'Zerene_cesonia-period', 'Parnassius_glacialis-period', 'Ornithoptera_alexandrae-period', 'Pieris_melete-period', 'Troides_oblongomaculatus-period', 'Glaucopsyche_alexis-period', 'Plebejus_argus-period', 'Lysandra_coridon-period', 'Nymphalis_io-period', 'Phoebis_sennae-period', 'Dryadula_phaetusa-period', 'Erebia_aethiops-period', 'Leptidea_reali-period', 'Pieris_mannii-period', 'Papilio_glaucus-period', 'Argynnis_bischoffii_washingtonia-period', 'Colias_nastes-period', 'Vanessa_atalanta-period', 'Aporia_crataegi-period', 'Battus_philenor-period', 'Papilio_dardanus_tibullus-period', 'Papilio_elwesi-period', 'Vanessa_tameamea-period', 'Boloria_euphrosyne-period', 'Brenthis_ino-period', 'Melinaea_marsaeus_rileyi-period', 'Papilio_protenor-period', 'Erebia_ligea-period', 'Pieris_napi-period', 'Dryas_iulia_moderata-period', 'Pieris_brassicae-period', 'Heliconius_sara-period', 'Anthocharis_cardamines-period', 'Eurema_hecabe-period', 'Danaus_plexippus-period', 'Ornithoptera_priamus-period', 'Troides_aeacus-period', 'Colias_eurytheme-period', 'Papilio_xuthus-period', 'Papilio_machaon-period', 'Colias_croceus-period', 'Pieris_rapae-period', 'Papilio_memnon-period', 'Teinopalpus_imperialis-period', 'Papilio_polytes-period']
# Reading alignment from ./00.Temp_alignment/Heliconius_charithonia-period.fas ...
# Extracting sufficient statistics ...
# Compacting sufficient statistics ...
# Fitting tree model to ./00.Temp_alignment/Heliconius_charithonia-period.fas using REV ...
# numpar = 183
# Done.  log(likelihood) = -148048.277255 numeval=37224
# WARNING: BFGS algorithm reached its maximum number of iterations.
# Writing model to ./01.Temp_phastcon/modelfile.mod ...
# Done.
# Reading tree model from modelfile.mod...
# Reading alignment from ../00.Temp_alignment/Heliconius_charithonia-period.fas...
# Creating 'conserved' and 'nonconserved' states in HMM...
# Computing emission probs (state 0, cat 0, mod 0)...
# Computing emission probs (state 1, cat 1, mod 1)...
# Finding MLE for ([tree models])...
# Writing re-estimated tree models to mytrees.cons.mod and mytrees.noncons.mod...
# Done.
# Reading tree model from mytrees.cons.mod...
# Reading tree model from mytrees.noncons.mod...
# Reading alignment from ../00.Temp_alignment/Heliconius_charithonia-period.fas...
# Creating 'conserved' and 'nonconserved' states in HMM...
# Computing emission probs (state 0, cat 0, mod 0)...
# Computing emission probs (state 1, cat 1, mod 1)...
# Computing posterior probabilities...
# Done.
# Reading alignment from ./00.Temp_alignment/Napeogenes_sylphis-period.fas ...
# Extracting sufficient statistics ...
# Compacting sufficient statistics ...
# Fitting tree model to ./00.Temp_alignment/Napeogenes_sylphis-period.fas using REV ...
# numpar = 183
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f03752d8110>>
# Traceback (most recent call last):
#   File "/home/saurav/miniconda3/envs/genomic_work/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 790, in _clean_thread_parent_frames
#     active_threads = {thread.ident for thread in threading.enumerate()}
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/saurav/miniconda3/envs/genomic_work/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 790, in <setcomp>
#     active_threads = {thread.ident for thread in threading.enumerate()}
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 34
#      32 with open(f"{location}/00.Temp_alignment/{list_of_sequences_ids[i]}.fas", 'w') as out_file:
#      33     out_file.write(output)
# ---> 34 subprocess.run(f'cd "{location}"\nphyloFit --tree period.masceDNA.fas.treefile --subst-mod REV --out-root "./01.Temp_phastcon/modelfile" "./00.Temp_alignment/{list_of_sequences_ids[i]}.fas"', shell = True)
#      36 subprocess.run(f'cd "{location}/01.Temp_phastcon"\nphastCons --target-coverage 0.25 --expected-length 12 --estimate-trees mytrees ../00.Temp_alignment/{list_of_sequences_ids[i]}.fas modelfile.mod --no-post-probs', shell = True)
#      38 subprocess.run(f'cd "{location}/01.Temp_phastcon"\nphastCons --target-coverage 0.25 --expected-length 12 ../00.Temp_alignment/{list_of_sequences_ids[i]}.fas mytrees.cons.mod,mytrees.noncons.mod > scores.wig', shell = True)
#
# File ~/miniconda3/envs/genomic_work/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/miniconda3/envs/genomic_work/lib/python3.11/subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File ~/miniconda3/envs/genomic_work/lib/python3.11/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File ~/miniconda3/envs/genomic_work/lib/python3.11/subprocess.py:2053, in Popen._wait(self, timeout)
#    2051 if self.returncode is not None:
#    2052     break  # Another thread waited.
# -> 2053 (pid, sts) = self._try_wait(0)
#    2054 # Check the pid and loop as waitpid has been known to
#    2055 # return 0 even without WNOHANG in odd situations.
#    2056 # http://bugs.python.org/issue14396.
#    2057 if pid == self.pid:
#
# File ~/miniconda3/envs/genomic_work/lib/python3.11/subprocess.py:2011, in Popen._try_wait(self, wait_flags)
#    2009 """All callers to this function MUST hold self._waitpid_lock."""
#    2010 try:
# -> 2011     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012 except ChildProcessError:
#    2013     # This happens if SIGCLD is set to be ignored or waiting
#    2014     # for child processes has otherwise been disabled for our
#    2015     # process.  This child is dead, we can't get the status.
#    2016     pid = self.pid
#
# KeyboardInterrupt:
