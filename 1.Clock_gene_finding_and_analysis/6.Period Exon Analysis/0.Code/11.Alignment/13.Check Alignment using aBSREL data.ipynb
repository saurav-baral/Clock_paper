# %%
import json
from Bio import SeqIO
from Bio import Phylo
import math 


tree = Phylo.read(f"{location}/period.masceDNA.fas.treefile_figtree", 'newick')
species_list = [term.name for term in tree.get_terminals()]
# print(species_list)

location = "/mnt/g/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/11.Alignment"

with open(f"{location}/00.Temp_runs/result(1).json", 'r') as json_file:
    absrel_results = json.load(json_file)

for species_name in species_list:
    sequence_name = (species_name.replace("-","_").upper())
    print(species_name)
    if sequence_name not in absrel_results["Site Log Likelihood"]["tested"]:
        continue
    for codon_number in range(len(absrel_results["Site Log Likelihood"]["tested"][sequence_name][0])):
        evidence_ratio = round(math.e**(float(absrel_results["Site Log Likelihood"]["unconstrained"][0][codon_number]) - float(absrel_results["Site Log Likelihood"]["tested"][sequence_name][0][codon_number])),4) 
        if evidence_ratio > 5:
            print(species_name,codon_number+1,"\t\t\t", evidence_ratio)
            input()
    # break

    # for key,value in absrel_results["Site Log Likelihood"].items():
        
    #     print(key)
    

# print(absrel_results["Site Log Likelihood"]["tested"][sequence_name])
# Out:
# Leptidea_reali-period 172 			 16771.7881
# Leptidea_reali-period 174 			 27777.1429
# Leptidea_reali-period 175 			 61.6936
# Pieris_napi-period 738 			 16.0987
# Pieris_napi-period 943 			 29.6126
# Pieris_napi-period 946 			 9.2363
# Pieris_brassicae-period 779 			 8.0776
# Pieris_brassicae-period 945 			 14.3723
# Pieris_brassicae-period 946 			 6.2023
# Pieris_brassicae-period 947 			 8.7114
# Pieris_brassicae-period 953 			 12.4904
# Pieris_brassicae-period 954 			 17.1204
# Pieris_brassicae-period 1069 			 36.0649
# Pieris_brassicae-period 1293 			 5.6922
# Pieris_brassicae-period 1409 			 16.7023
# Pieris_brassicae-period 1424 			 8.3745
# Colias_nastes-period 1059 			 27.332
# Colias_nastes-period 1060 			 26.5122
# Colias_nastes-period 1061 			 23.7468
# Colias_nastes-period 1063 			 95.9569
# Colias_nastes-period 1436 			 23.8943
# Colias_croceus-period 957 			 63.1453
# Papilio_protenor-period 705 			 19.1855
# Papilio_protenor-period 725 			 5.2036
# ...
