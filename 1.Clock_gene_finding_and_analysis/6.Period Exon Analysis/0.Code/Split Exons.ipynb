# %%
location_1 = "H:/My Drive/Circadian Rhythm Genes Project/6.Period Exon Analysis/1.Annotated Species/"
species = "Bombyx mori"


import os
from Bio import Entrez
Entrez.email = 'saubaralwork@gmail.com'

list_of_species = os.listdir(location_1)
if "names" in list_of_species:
    list_of_species.remove('names')
try:
    list_of_species.remove('desktop.ini')
except:
    print(list_of_species)
for species_folder in list_of_species:
    location = location_1 + species_folder
    species = species_folder.split(".")[1]
    print(species)
#     assert False


    with open(location + "/Gene_table_noncoding_processed.tsv", 'r') as gene_table_file:
        gene_table_list = gene_table_file.readlines()

    mrna_accession = ''
    # mrna_accession_extracted = "new"
    for i in range(1, len(gene_table_list)):
        if len(gene_table_list[i]) > 1:
            mrna_accession_extracted = gene_table_list[i].split("\t")[0]
            if mrna_accession != mrna_accession_extracted:
                mrna_accession = mrna_accession_extracted
                print(mrna_accession)
#                 mrna_detail = Entrez.efetch(db='nucleotide',id=mrna_accession, rettype = 'gb', retmode= 'text')
#                 mrna_detail_list = (mrna_detail.read().split("\n"))
#                 for lines in mrna_detail_list:
#                     if  lines.strip().startswith("CDS") and (".." in lines):
#                         try:
#                             start,stop = (lines.split(" ")[-1].split(".."))
#                         except:
#                             print(lines.strip())
#                         print(start,stop)
#                         break
                mrna_sequence = Entrez.efetch(db='nucleotide',id=mrna_accession, rettype = 'fasta', retmode= 'text')
                sequence = "".join(mrna_sequence.read().split("\n")[1:])
#             print("length = ", len(gene_table_list[i]))
            exon = gene_table_list[i].split("\t")[1]
            exon_length = int(gene_table_list[i].split("\t")[2])
            exon_sequence = sequence[:exon_length]
#             print(exon,"\n",exon_sequence)
            sequence = sequence[exon_length:]
        #     print(sequence)

        #     print (exon_sequence)
        #     print(len(exon_sequence))

            list_of_folders = os.listdir(location)
            if "Transcripts_noncoding" not in list_of_folders:
                os.mkdir(f"{location}/Transcripts_noncoding")
            list_of_folders_2 = os.listdir(f"{location}/Transcripts_noncoding")
            if mrna_accession not in list_of_folders_2:
                print("not there")
                os.mkdir(f"{location}/Transcripts_noncoding/{mrna_accession}")

            with open(f"{location}/Transcripts_noncoding/{mrna_accession}/{exon}.fa", 'w') as out_file:
                out_file.write(f">{species}_{mrna_accession}_{exon}\n{exon_sequence}")


#     mrna_access
#     break
# Out:
# Leptidea_sinapis
# XM_050828181.1
# not there
# XM_050828183.1
# not there
# XM_050828182.1
# not there
# XM_050828184.1
# not there
# Colias_croceus
# XM_045653731.1
# not there
# XM_045653733.1
# not there
# XM_045653735.1
# not there
# XM_045653732.1
# not there
# Bicyclus_anynana
# XM_024088150.2
# not there
# XM_024088385.2
# not there
# XM_024088306.2
# not there
# XM_024088225.2
# not there
# XM_024088542.2
# not there
# XM_024088466.2
# not there
# XM_052890815.1
# not there
# Danaus_plexippus
# XM_061526465.1
# not there
# XM_032671537.2
# not there
# XM_061526467.1
# not there
# XM_061526468.1
# not there
# XM_061526469.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7312\86942321.py in <module>
#      42 #                         print(start,stop)
#      43 #                         break
# ---> 44                 mrna_sequence = Entrez.efetch(db='nucleotide',id=mrna_accession, rettype = 'fasta', retmode= 'text')
#      45                 sequence = "".join(mrna_sequence.read().split("\n")[1:])
#      46 #             print("length = ", len(gene_table_list[i]))
#
# ~\Anaconda3\lib\site-packages\Bio\Entrez\__init__.py in efetch(db, **keywords)
#     205             # more than about 200 IDs
#     206             post = True
# --> 207     return _open(cgi, variables, post=post)
#     208
#     209
#
# ~\Anaconda3\lib\site-packages\Bio\Entrez\__init__.py in _open(cgi, params, post, ecitmatch)
#     604                 handle = urlopen(cgi, data=options.encode("utf8"))
#     605             else:
# --> 606                 handle = urlopen(cgi)
#     607         except HTTPError as exception:
#     608             # Reraise if the final try fails
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1315             try:
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# ~\Anaconda3\lib\http\client.py in connect(self)
#    1382             "Connect to a host on a given (SSL) port."
#    1383
# -> 1384             super().connect()
#    1385
#    1386             if self._tunnel_host:
#
# ~\Anaconda3\lib\http\client.py in connect(self)
#     926         """Connect to the host and port specified in __init__."""
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     930
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# KeyboardInterrupt:
