# %%
import os
import subprocess
location = "/mnt/griffin/saubar/busco_runs_CDS_files"
target_location = "/mnt/griffin/saubar/Busco_runs_to_copy"
list_of_folders = os.listdir(location)
list_of_folders_target = os.listdir(target_location)
list_of_target_folders = os.listdir()
# print(list_of_folders)
genomic_folders_list = []
for folder_name in list_of_folders:
    if folder_name.endswith("_genomic.fna"):
        if folder_name not in list_of_folders_target:
            os.mkdir(f"{target_location}/{folder_name}")
        subprocess.run(f'cp -v -r {location}/{folder_name}/CDS  {target_location}/{folder_name}', shell = True)
        #assert False
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 import os
#       3 location = "/mnt/griffin/saubar/busco_runs_CDS_files"
# ----> 5 list_of_folders = os.listdir(location)
#       6 # print(list_of_folders)
#       7 genomic_folders_list = []
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/griffin/saubar/busco_runs_CDS_files'
