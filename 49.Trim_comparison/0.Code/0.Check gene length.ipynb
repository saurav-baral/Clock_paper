# %%
from Bio import SeqIO
import os

list_of_untrimmed = os.listdir("/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/unTrimmed/1.Alignment")
list_of_untrimmed_length = []
for file_name in list_of_untrimmed:
    fasta_file = SeqIO.parse(f"/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/unTrimmed/1.Alignment/{file_name}", 'fasta')
    for records in fasta_file:
        # print(len(records.seq))
        list_of_untrimmed_length.append(len(records.seq))
        break
    
    # print(file_name)
    # break
# print(list_of_untrimmed_length)
# Out:
# [5433, 2967, 3138, 2439, 936, 2832, 4650, 1059, 4542, 12807, 4758, 897, 720, 750, 846, 4455, 909, 1005, 807, 1905, 837, 1014, 3165, 2736, 1086, 3756, 9261, 2271, 681, 666, 6066, 1035, 843, 1209, 1032, 7737, 1455, 4515, 756, 6165, 1014, 1350, 1143, 1539, 906, 3855, 1080, 2094, 1608, 6879, 7818, 9135, 1410, 3198, 1053, 1158, 2406, 1434, 882, 945, 1860, 960, 696, 927, 1020, 831, 888, 954, 1293, 1170, 840, 2199, 2997, 1662, 1254, 2463, 1026, 804, 1209, 1809, 1476, 2154, 1398, 5619, 3912, 2919, 1737, 4317, 717, 2301, 921, 999, 11034, 1458, 3393, 1101, 753, 5553, 1389, 2037, 1689, 1563, 2241, 1818, 975, 1506, 1287, 4371, 3483, 1536, 714, 1188, 1986, 2502, 639, 810, 771, 765, 948, 2187, 1437, 1836, 1086, 822, 6012, 669, 681, 7698, 1002, 1029, 1080, 3765, 1386, 10203, 2073, 1011, 879, 1464, 3048, 1578, 870, 795, 1086, 1119, 1239, 1164, 1143, 795, 1146, 1464, 2064, 1236, 789, 2910, 1674, 2256, 2721, 5094, 1398, 2241, 7191, 849, 879, 924, 4590, 1719, 1725, 1548, 1155, 1392, 888, 708, 1446, 225
# ...

# %%
list_of_untrimmed_clock = os.listdir("/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/unTrimmed/Clock")
for file_name in list_of_untrimmed_clock:
    fasta_file = SeqIO.parse(f"/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/unTrimmed/Clock/{file_name}", 'fasta')
    for records in fasta_file:
        # print(len(records.seq))
        list_of_untrimmed_length.append(len(records.seq))
        break
print(list_of_untrimmed_length)
# Out:
# [5433, 2967, 3138, 2439, 936, 2832, 4650, 1059, 4542, 12807, 4758, 897, 720, 750, 846, 4455, 909, 1005, 807, 1905, 837, 1014, 3165, 2736, 1086, 3756, 9261, 2271, 681, 666, 6066, 1035, 843, 1209, 1032, 7737, 1455, 4515, 756, 6165, 1014, 1350, 1143, 1539, 906, 3855, 1080, 2094, 1608, 6879, 7818, 9135, 1410, 3198, 1053, 1158, 2406, 1434, 882, 945, 1860, 960, 696, 927, 1020, 831, 888, 954, 1293, 1170, 840, 2199, 2997, 1662, 1254, 2463, 1026, 804, 1209, 1809, 1476, 2154, 1398, 5619, 3912, 2919, 1737, 4317, 717, 2301, 921, 999, 11034, 1458, 3393, 1101, 753, 5553, 1389, 2037, 1689, 1563, 2241, 1818, 975, 1506, 1287, 4371, 3483, 1536, 714, 1188, 1986, 2502, 639, 810, 771, 765, 948, 2187, 1437, 1836, 1086, 822, 6012, 669, 681, 7698, 1002, 1029, 1080, 3765, 1386, 10203, 2073, 1011, 879, 1464, 3048, 1578, 870, 795, 1086, 1119, 1239, 1164, 1143, 795, 1146, 1464, 2064, 1236, 789, 2910, 1674, 2256, 2721, 5094, 1398, 2241, 7191, 849, 879, 924, 4590, 1719, 1725, 1548, 1155, 1392, 888, 708, 1446, 225
# ...

# %%
list_of_trimal = os.listdir("/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/1.Alignment")
list_of_trimal_length = []
for file_name in list_of_trimal:
    fasta_file = SeqIO.parse(f"/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/1.Alignment/{file_name}", 'fasta')
    for records in fasta_file:
        # print(len(records.seq))
        list_of_trimal_length.append(len(records.seq))
        break
print(list_of_trimal_length)
# Out:
# [678, 570, 3003, 1116, 564, 1182, 729, 951, 1074, 882, 2760, 867, 684, 741, 819, 3708, 846, 915, 702, 1209, 747, 813, 2706, 567, 969, 1824, 429, 924, 624, 666, 3759, 660, 774, 831, 903, 3249, 906, 1509, 732, 2907, 795, 870, 960, 690, 819, 3099, 861, 822, 1101, 1458, 4098, 585, 1020, 981, 681, 951, 741, 1092, 726, 831, 1257, 558, 696, 645, 855, 435, 822, 840, 885, 906, 723, 669, 2904, 921, 927, 1407, 711, 747, 768, 1413, 933, 981, 936, 687, 837, 1107, 969, 1698, 672, 1596, 834, 825, 2514, 765, 2436, 1053, 693, 768, 690, 660, 1017, 1320, 1743, 630, 858, 651, 837, 2235, 1338, 699, 603, 753, 1008, 738, 633, 744, 738, 759, 933, 1017, 1209, 669, 822, 807, 2847, 516, 558, 3420, 648, 675, 714, 639, 912, 8256, 837, 735, 858, 1266, 1620, 684, 747, 780, 834, 876, 900, 819, 1029, 639, 783, 936, 1104, 648, 744, 729, 816, 699, 741, 3456, 1044, 1383, 855, 714, 696, 864, 3390, 882, 1119, 924, 1065, 1344, 762, 708, 726, 933, 795, 660, 582, 2796, 732, 549, 777, 822, 831, 1086, 711, 1149, 984, 513, 747
# ...

# %%
list_of_trimal_clock = os.listdir("/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/2.ForTree/clock_checked")
for file_name in list_of_trimal_clock:
    fasta_file = SeqIO.parse(f"/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/2.ForTree/clock_checked/{file_name}", 'fasta')
    for records in fasta_file:
        # print(len(records.seq))
        list_of_trimal_length.append(len(records.seq))
        break
# print(list_of_trimal_length)

# %%
import statistics

print(statistics.mean(list_of_untrimmed_length))
print(statistics.mean(list_of_trimal_length))
# Out:
# 2659.055348938963
# 1460.1996931170538

# %%
import statistics

print(statistics.mean(list_of_untrimmed_length))
print(statistics.mean(list_of_trimal_length))
# Out:
# 2659.055348938963
# 1461.221225382932

# %%
list_of_clipkit = os.listdir("/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/unTrimmed/2.Trimmed_alignment")
list_of_clipkit_length = []
for file_name in list_of_clipkit:
    fasta_file = SeqIO.parse(f"/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/unTrimmed/2.Trimmed_alignment/{file_name}", 'fasta')
    for records in fasta_file:
        # print(len(records.seq))
        list_of_clipkit_length.append(len(records.seq))
        break
print(list_of_clipkit_length)
# Out:
# [4239, 1920, 3135, 1758, 780, 2262, 3111, 990, 1404, 6609, 3792, 873, 693, 747, 828, 4158, 882, 918, 783, 1710, 810, 936, 2985, 2079, 1026, 2925, 3957, 1797, 645, 666, 4536, 801, 822, 1032, 969, 6210, 1311, 2790, 750, 4896, 927, 1248, 1044, 858, 897, 3687, 939, 1335, 1464, 2673, 7815, 9105, 1404, 2958, 792, 1143, 1419, 1209, 819, 843, 1647, 678, 696, 786, 984, 810, 873, 870, 1287, 987, 792, 1377, 2964, 1125, 1161, 1917, 840, 789, 870, 1413, 1320, 2145, 1344, 2400, 3909, 2013, 1272, 3915, 687, 1806, 879, 861, 6633, 933, 3210, 1068, 726, 1026, 1050, 1116, 1575, 1437, 1980, 918, 939, 792, 945, 3765, 2508, 879, 702, 816, 1170, 1524, 636, 711, 744, 762, 945, 1353, 1371, 834, 924, 819, 5805, 642, 669, 5994, 813, 1008, 966, 2070, 1131, 8667, 1248, 879, 876, 1056, 3039, 906, 768, 783, 978, 882, 900, 1038, 1023, 759, 1002, 1332, 1419, 828, 750, 1731, 1359, 1341, 2694, 4608, 1275, 2232, 5712, 837, 783, 897, 4563, 1227, 1119, 1530, 1131, 1374, 825, 708, 948, 1965, 3582, 660, 1233, 3009, 1113, 9
# ...

# %%
list_of_clipkit_clock = os.listdir("/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/unTrimmed/clock_trimmed")
for file_name in list_of_clipkit_clock:
    if file_name.endswith(".ClipKIT.fas"):
        fasta_file = SeqIO.parse(f"/mnt/c/Users/Saurav Baral/Desktop/20.RERConverge_trimmed/unTrimmed/clock_trimmed/{file_name}", 'fasta')
        for records in fasta_file:
            print(len(records.seq))
            list_of_clipkit_length.append(len(records.seq))
            break
# Out:
# 3504
# 1617
# 1554
# 4542
# 2598
# 4461
# 4863
# 7608
# 5919

# %%
output = "Untrimmed,Trimal,Clipkit"
for ut,tr,cli in zip(list_of_untrimmed_length,list_of_trimal_length,list_of_clipkit_length):
    output += f"\n{ut},{tr},{cli}"
    # print(ut,tr,cli)
    # break
print(output)
with open("/mnt/g/My Drive/Circadian Rhythm Genes Project/49.Trim_comparison/trim_comparison.csv", 'w') as out_file:
    out_file.write(output)
# Out:
# Untrimmed,Trimal,Clipkit
# 5433,678,4239
# 2967,570,1920
# 3138,3003,3135
# 2439,1116,1758
# 936,564,780
# 2832,1182,2262
# 4650,729,3111
# 1059,951,990
# 4542,1074,1404
# 12807,882,6609
# 4758,2760,3792
# 897,867,873
# 720,684,693
# 750,741,747
# 846,819,828
# 4455,3708,4158
# 909,846,882
# 1005,915,918
# 807,702,783
# 1905,1209,1710
# 837,747,810
# 1014,813,936
# 3165,2706,2985
# 2736,567,2079
# 1086,969,1026
# 3756,1824,2925
# 9261,429,3957
# 2271,924,1797
# 681,624,645
# 666,666,666
# 6066,3759,4536
# 1035,660,801
# 843,774,822
# 1209,831,1032
# 1032,903,969
# 7737,3249,6210
# 1455,906,1311
# 4515,1509,2790
# 756,732,750
# 6165,2907,4896
# 1014,795,927
# 1350,870,1248
# 1143,960,1044
# 1539,690,858
# 906,819,897
# 3855,3099,3687
# 1080,861,939
# 2094,822,1335
# 1608,1101,1464
# 6879,1458,2673
# 7818,4098,7815
# 9135,585,9105
# 1410,1020,1404
# 3198,981,2958
# 1053,681,792
# 1158,951,1143
# 2406,741,1419
# 1434,1092,1209
# 882,726,819
# 945,831,843
# 1860,1257,1647
# 960,558,678
# ...

# %%
output = "Condition,Length"

for ut in list_of_untrimmed_length:
    output += f"\nUntrimmed,{ut}"

for ut in list_of_trimal_length:
    output += f"\nTrimal,{ut}"

for ut in list_of_clipkit_length:
    output += f"\nClipKIT,{ut}"


# for ut,tr,cli in zip(list_of_untrimmed_length,list_of_trimal_length,list_of_clipkit_length):
#     output += f"\n{ut},{tr},{cli}"
#     # print(ut,tr,cli)
#     # break
print(output)
with open("/mnt/g/My Drive/Circadian Rhythm Genes Project/49.Trim_comparison/trim_comparison_long.csv", 'w') as out_file:
    out_file.write(output)
# Out:
# Condition,Length
# Untrimmed,5433
# Untrimmed,2967
# Untrimmed,3138
# Untrimmed,2439
# Untrimmed,936
# Untrimmed,2832
# Untrimmed,4650
# Untrimmed,1059
# Untrimmed,4542
# Untrimmed,12807
# Untrimmed,4758
# Untrimmed,897
# Untrimmed,720
# Untrimmed,750
# Untrimmed,846
# Untrimmed,4455
# Untrimmed,909
# Untrimmed,1005
# Untrimmed,807
# Untrimmed,1905
# Untrimmed,837
# Untrimmed,1014
# Untrimmed,3165
# Untrimmed,2736
# Untrimmed,1086
# Untrimmed,3756
# Untrimmed,9261
# Untrimmed,2271
# Untrimmed,681
# Untrimmed,666
# Untrimmed,6066
# Untrimmed,1035
# Untrimmed,843
# Untrimmed,1209
# Untrimmed,1032
# Untrimmed,7737
# Untrimmed,1455
# Untrimmed,4515
# Untrimmed,756
# Untrimmed,6165
# Untrimmed,1014
# Untrimmed,1350
# Untrimmed,1143
# Untrimmed,1539
# Untrimmed,906
# Untrimmed,3855
# Untrimmed,1080
# Untrimmed,2094
# Untrimmed,1608
# Untrimmed,6879
# Untrimmed,7818
# Untrimmed,9135
# Untrimmed,1410
# Untrimmed,3198
# Untrimmed,1053
# Untrimmed,1158
# Untrimmed,2406
# Untrimmed,1434
# ...
