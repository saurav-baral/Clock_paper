# %%
from Bio import SeqIO

with open("/mnt/c/Users/sauba/Desktop/For Email/Lycaena_phlaeas/Transcript.bed", 'r') as bed_file:
    bed_file_list= bed_file.readlines()
left_overhang = 0
right_overhang = 0
for lines in bed_file_list:
    lines_split = lines.split("\t")
    start = int(lines_split[1])
    stop = int(lines_split[2])
    print(lines_split[3])
    genome_file = SeqIO.parse("/mnt/c/Users/sauba/Desktop/For Email/Lycaena_phlaeas/Genome_fragment.fa", "fasta")
    
    for records in genome_file:
        sequence = (records.seq[start:stop])
        print(sequence)
        print(sequence[left_overhang:].translate())
        right_overhang = len(sequence[left_overhang:]) % 3
        print(left_overhang,right_overhang)
        left_overhang = (3 - right_overhang)%3
#         print(left_overhang,)
#     print(start,stop)
