# %%
# !pip3 install geneview
# Out:
# DEPRECATION: Loading egg at /home/saurav/miniconda3/envs/genomics_work/lib/python3.11/site-packages/ete3-3.1.3-py3.10.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for geneview: filename=geneview-0.2.1-py3-none-any.whl size=54471 sha256=f3d1aaa0a9b7906a3f6bd04258ab2c3e576c7bf6ff5003647be696cc62032e74
#   Stored in directory: /home/saurav/.cache/pip/wheels/28/60/fd/adc6b52d2599d2c3accdf76a7a154a5a53212e038b2fd82454
# Successfully built geneview
# ...

# %%
import matplotlib.pyplot as plt
import geneview as gv

# load data
df = gv.load_dataset("gwas")
# Plot a basic manhattan plot with horizontal xtick labels and the figure will display in screen.
ax = gv.manhattanplot(data=df)
plt.show()

# %%
df
# Out:
#      #CHROM        POS           ID REF ALT A1 TEST  OBS_CT      BETA  \
# 0      chr1     904165     1_904165   G   A  A  ADD     282 -0.090890
# 1      chr1    1563691    1_1563691   T   G  G  ADD     271  0.447021
# 2      chr1    1707740    1_1707740   T   G  G  ADD     283  0.149911
# 3      chr1    2284195    1_2284195   T   C  C  ADD     275 -0.024704
# 4      chr1    2779043    1_2779043   T   C  T  ADD     272 -0.111771
# ...     ...        ...          ...  ..  .. ..  ...     ...       ...
# 9212   chrX  151616708  X_151616708   A   G  A  ADD     265 -0.102974
# 9213   chrX  152091153  X_152091153   A   C  A  ADD     273 -0.298747
# 9214   chrX  152596189  X_152596189   G   A  G  ADD     275 -0.057860
# 9215   chrX  152660491  X_152660491   C   G  G  ADD     266  0.050713
# 9216   chrX  154087368  X_154087368   T   A  T  ADD     277 -0.123774
#
#             SE    T_STAT         P
# 0     0.195476 -0.464967  0.642344
# 1     0.422194  1.058800  0.290715
# ...

# %%
gv.manhattanplot(data=df.loc[:,["#CHROM","POS","P"]], 
                 hline_kws={"linestyle": "--", "lw": 1.3},
                 xlabel="Chromosome", 
                 ylabel="-Log10(P-value)",
                 xticklabel_kws={"rotation": 45},
                 xtick_label_set = set(xtick))
plt.tight_layout(df = gv.utils.load_dataset("gwas"))
plt.show()

# %%
df = gv.utils.load_dataset("gwas")

# %%
help(gv.manhattanplot)
# Out:
# Help on function manhattanplot in module geneview.gwas._manhattan:
#
# manhattanplot(data, chrom='#CHROM', pos='POS', pv='P', snp='ID', logp=True, ax=None, marker='.', color='#3B5488,#53BBD5', alpha=0.8, title=None, xlabel='Chromosome', ylabel='$-log_{10}{(P)}$', xtick_label_set=None, CHR=None, xticklabel_kws=None, suggestiveline=1e-05, genomewideline=5e-08, sign_line_cols='#D62728,#2CA02C', hline_kws=None, sign_marker_p=None, sign_marker_color='r', is_annotate_topsnp=False, text_kws=None, ld_block_size=50000, **kwargs)
#     Creates a manhattan plot from PLINK assoc output (or any data frame with chromosome, position, and p-value).
#
#     Parameters
#     ----------
#     data : DataFrame.
#         A DataFrame with columns "#CHROM," "POS," "P," and optionally, "SNP."
#
#     chrom : string, default is "#CHROM", optional
#         A string denoting the column name for chromosome. Defaults to be PLINK2.x's "#CHROM".
#         Said column must be a character.
#
# ...

# %%
import pandas as pd
from pandas.api.types import CategoricalDtype

fst_data = pd.read_csv("/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/1.Lasiomatta_megera/1.FST_peaks_from_chris/Lmeg_fst_sorted.txt", sep = "\t")

# chrom_order = [str(i) for i in range(1, 29)] + ['Z', 'W', "mitochondrion","S31","S34","S35","S36","SUPER_28_unloc_1","SUPER_28_unloc_3","SUPER_W_unloc_1","SUPER_W_unloc_2","SUPER_W_unloc_3","SUPER_W_unloc_4","SUPER_W_unloc_5"]

# chrom_dtype = CategoricalDtype(categories=chrom_order, ordered=True)

# fst_data['chromosome'] = fst_data['chromosome'].astype(chrom_dtype)
# fst_data = fst_data.sort_values('chromosome')
# Out:
# /tmp/ipykernel_15309/554882748.py:4: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   fst_data = pd.read_csv("/mnt/g/My Drive/Circadian Rhythm Genes Project/53.Microevolutionary_analysis_statistics/1.Lasiomatta_megera/1.FST_peaks_from_chris/Lmeg_fst_sorted.txt", sep = "\t")

# %%
fst_data
# Out:
#            pop1    pop2 chromosome  window_pos_1  window_pos_2  avg_wc_fst  \
# 0       Germany  Sweden          1         15001         16000    0.000385
# 1       Germany  Sweden          1         16001         17000    0.098950
# 2       Germany  Sweden          1         17001         18000    0.012760
# 3       Germany  Sweden          1         20001         21000   -0.003303
# 4       Germany  Sweden          1         21001         22000    0.043298
# ...         ...     ...        ...           ...           ...         ...
# 468027  Germany  Sweden          Z      27632001      27633000    0.043329
# 468028  Germany  Sweden          Z      27633001      27634000    0.035311
# 468029  Germany  Sweden          Z      27634001      27635000    0.064203
# 468030  Germany  Sweden          Z      27635001      27636000    0.038908
# 468031  Germany  Sweden          Z      27636001      27637000    0.028824
#
#         no_snps         SNP
# 0             2     1_15001
# ...

# %%
ax = gv.manhattanplot(data=fst_data, chrom = "chromosome", pos = "window_pos_1", pv = "avg_wc_fst", logp = False,
                     xticklabel_kws={"rotation": "vertical"}, ylabel = "Fst", suggestiveline = 0.2, genomewideline = None, snp = "SNP")


plt.show()
